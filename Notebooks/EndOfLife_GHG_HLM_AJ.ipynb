# %% [markdown]
# # GHG HLM on Scope 3 source End of Life Treatment of Sold Products

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_log_error, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GroupShuffleSplit
from scipy.stats import zscore
import scipy.stats as stats
from sklearn.feature_selection import mutual_info_regression
from sklearn.impute import SimpleImputer
import warnings
from statsmodels.regression.mixed_linear_model import MixedLM


#read in dataset from GHG_post_outliers data set
end_of_life=pd.read_csv('/Users/amberjensen/Desktop/GHG_Emissions_Project/end_of_life.csv')

# %%
#check for info
end_of_life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_name                2200 non-null   object
#  1   account_id                  2200 non-null   int64
#  2   Year                        2200 non-null   int64
#  3   incorporated_country        2200 non-null   object
#  4   Primary activity            2200 non-null   object
#  5   Primary sector              2200 non-null   object
#  6   Market_Cap_USD              1956 non-null   float64
#  7   Third_party_verification    2199 non-null   object
#  8   Revenue_USD                 1957 non-null   float64
#  9   ebitda_USD                  1957 non-null   float64
#  10  grossProfit_USD             1957 non-null   float64
#  11  netIncome_USD               1957 non-null   float64
#  12  cashAndCashEquivalents_USD  1957 non-null   float64
#  13  shortTermInvestments_USD    1957 non-null   float64
#  14  longTermInvestments_USD     1957 non-null   float64
#  15  totalAssets_USD             1957 non-null   float64
#  16  totalLiabilities_USD        1957 non-null   float64
#  17  totalInvestments_USD        1957 non-null   float64
#  18  totalDebt_USD               1957 non-null   float64
#  19  totalEquity_USD             1957 non-null   float64
#  20  Scope_3_emissions_type      2200 non-null   object
#  21  Scope_3_emissions_amount    2200 non-null   float64
#  22  scope_1_2_emissions_amount  2196 non-null   float64
#  23  Year_sq                     2200 non-null   int64
# dtypes: float64(15), int64(3), object(6)
# memory usage: 412.6+ KB

# %%
#show a df for end_of_life
end_of_life.head()
# Out:
#       account_name  account_id  Year incorporated_country  \
# 0            Aptiv        4407  2018       United Kingdom
# 1      AstraZeneca        1104  2018       United Kingdom
# 2         BT Group        2377  2018       United Kingdom
# 3       Diageo Plc        4702  2018       United Kingdom
# 4  GlaxoSmithKline        7374  2018       United Kingdom
#
#               Primary activity  \
# 0         Electrical equipment
# 1              Pharmaceuticals
# 2  Telecommunications services
# 3          Alcoholic beverages
# 4              Pharmaceuticals
#
#                                      Primary sector  Market_Cap_USD  \
# 0                 Electrical & electronic equipment    1.595156e+10
# 1                                  Biotech & pharma    7.441091e+10
# 2  Media, telecommunications & data center services    2.997109e+10
# 3                        Food & beverage processing    8.583054e+10
# 4                                  Biotech & pharma    7.508927e+10
#
#                             Third_party_verification   Revenue_USD  \
# 0           No third-party verification or assurance  1.443500e+10
# 1  Third-party verification or assurance process ...  2.209000e+10
# 2  Third-party verification or assurance process ...  2.975356e+10
# 3  Third-party verification or assurance process ...  1.544701e+10
# 4  Third-party verification or assurance process ...  3.914267e+10
#
#      ebitda_USD  ...  longTermInvestments_USD  totalAssets_USD  \
# 0  2.260000e+09  ...             9.900000e+07     1.248000e+10
# 1  7.165000e+09  ...             1.130000e+08     6.065100e+10
# 2  9.392920e+09  ...             1.282700e+08     5.878449e+10
# 3  5.896610e+09  ...             4.066540e+09     3.773805e+10
# 4  9.344660e+09  ...             1.871980e+09     7.374382e+10
#
#    totalLiabilities_USD  totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0          8.810000e+09          1.710000e+08   4.344000e+09     3.670000e+09
# 1          4.660700e+10          9.220000e+08   1.911300e+10     1.404400e+10
# 2          4.587240e+10          1.282700e+08   2.143252e+10     1.291209e+10
# 3          2.286254e+10          4.110990e+09   1.257554e+10     1.487551e+10
# 4          6.908038e+10          1.978660e+09   3.310128e+10     4.663440e+09
#
#                    Scope_3_emissions_type  Scope_3_emissions_amount  \
# 0  End of life treatment of sold products                   87100.0
# 1  End of life treatment of sold products                   23597.0
# 2  End of life treatment of sold products                    1000.0
# 3  End of life treatment of sold products                   23500.0
# 4  End of life treatment of sold products                  100140.0
#
#    scope_1_2_emissions_amount  Year_sq
# 0                3.804718e+05  4072324
# 1                7.072529e+05  4072324
# 2                4.572819e+05  4072324
# 3                6.226582e+05  4072324
# 4                1.227269e+06  4072324
#
# [5 rows x 24 columns]

# %%
#define a list of numeric columns
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD',
       'grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD',
       'shortTermInvestments_USD', 'longTermInvestments_USD',
       'totalAssets_USD', 'totalLiabilities_USD', 'totalInvestments_USD',
       'totalDebt_USD', 'totalEquity_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount']

# %%
#plot the heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(end_of_life[numeric_cols].corr(), annot=True, annot_kws={"size": 8})
plt.show()

# %%
#correlation matrix
end_of_life[numeric_cols].corr()
# Out:
#                             Market_Cap_USD  Revenue_USD  ebitda_USD  \
# Market_Cap_USD                    1.000000     0.506954    0.594462
# Revenue_USD                       0.506954     1.000000    0.878690
# ebitda_USD                        0.594462     0.878690    1.000000
# grossProfit_USD                   0.518056     0.862861    0.907301
# netIncome_USD                     0.616736     0.822639    0.942329
# cashAndCashEquivalents_USD        0.119376     0.263927    0.299700
# shortTermInvestments_USD          0.242356     0.342588    0.432832
# longTermInvestments_USD           0.095510     0.241022    0.264462
# totalAssets_USD                   0.146833     0.335051    0.378432
# totalLiabilities_USD              0.131292     0.314163    0.347095
# totalInvestments_USD              0.136735     0.267841    0.316154
# totalDebt_USD                     0.244954     0.546037    0.590562
# totalEquity_USD                   0.306396     0.566851    0.645878
# Scope_3_emissions_amount          0.006213     0.016432   -0.010391
# scope_1_2_emissions_amount        0.002664     0.063424    0.022189
#
#                             grossProfit_USD  netIncome_USD  \
# Market_Cap_USD                     0.518056       0.616736
# Revenue_USD                        0.862861       0.822639
# ebitda_USD                         0.907301       0.942329
# grossProfit_USD                    1.000000       0.854673
# netIncome_USD                      0.854673       1.000000
# cashAndCashEquivalents_USD         0.445610       0.329183
# shortTermInvestments_USD           0.540980       0.473055
# longTermInvestments_USD            0.435076       0.309330
# totalAssets_USD                    0.546793       0.387081
# totalLiabilities_USD               0.520943       0.366493
# totalInvestments_USD               0.455424       0.357192
# totalDebt_USD                      0.710073       0.520136
# totalEquity_USD                    0.758211       0.586906
# Scope_3_emissions_amount          -0.018972      -0.020675
# scope_1_2_emissions_amount         0.006743      -0.007404
#
#                             cashAndCashEquivalents_USD  \
# Market_Cap_USD                                0.119376
# Revenue_USD                                   0.263927
# ebitda_USD                                    0.299700
# grossProfit_USD                               0.445610
# netIncome_USD                                 0.329183
# cashAndCashEquivalents_USD                    1.000000
# shortTermInvestments_USD                      0.734854
# longTermInvestments_USD                       0.907946
# totalAssets_USD                               0.936433
# totalLiabilities_USD                          0.878995
# totalInvestments_USD                          0.855324
# totalDebt_USD                                 0.708418
# totalEquity_USD                               0.734821
# Scope_3_emissions_amount                     -0.028076
# scope_1_2_emissions_amount                   -0.015193
#
#                             shortTermInvestments_USD  longTermInvestments_USD  \
# Market_Cap_USD                              0.242356                 0.095510
# Revenue_USD                                 0.342588                 0.241022
# ebitda_USD                                  0.432832                 0.264462
# grossProfit_USD                             0.540980                 0.435076
# netIncome_USD                               0.473055                 0.309330
# cashAndCashEquivalents_USD                  0.734854                 0.907946
# shortTermInvestments_USD                    1.000000                 0.768187
# longTermInvestments_USD                     0.768187                 1.000000
# totalAssets_USD                             0.814640                 0.953280
# totalLiabilities_USD                        0.843260                 0.921541
# totalInvestments_USD                        0.809446                 0.940809
# totalDebt_USD                               0.713991                 0.729249
# totalEquity_USD                             0.769332                 0.717634
# Scope_3_emissions_amount                   -0.022649                -0.027766
# scope_1_2_emissions_amount                 -0.016822                -0.024250
#
#                             totalAssets_USD  totalLiabilities_USD  \
# Market_Cap_USD                     0.146833              0.131292
# Revenue_USD                        0.335051              0.314163
# ebitda_USD                         0.378432              0.347095
# grossProfit_USD                    0.546793              0.520943
# netIncome_USD                      0.387081              0.366493
# cashAndCashEquivalents_USD         0.936433              0.878995
# shortTermInvestments_USD           0.814640              0.843260
# longTermInvestments_USD            0.953280              0.921541
# totalAssets_USD                    1.000000              0.953160
# totalLiabilities_USD               0.953160              1.000000
# totalInvestments_USD               0.913814              0.883306
# totalDebt_USD                      0.852651              0.833376
# totalEquity_USD                    0.833943              0.794992
# Scope_3_emissions_amount          -0.021108             -0.019455
# scope_1_2_emissions_amount        -0.007364             -0.008297
#
#                             totalInvestments_USD  totalDebt_USD  \
# Market_Cap_USD                          0.136735       0.244954
# Revenue_USD                             0.267841       0.546037
# ebitda_USD                              0.316154       0.590562
# grossProfit_USD                         0.455424       0.710073
# netIncome_USD                           0.357192       0.520136
# cashAndCashEquivalents_USD              0.855324       0.708418
# shortTermInvestments_USD                0.809446       0.713991
# longTermInvestments_USD                 0.940809       0.729249
# totalAssets_USD                         0.913814       0.852651
# totalLiabilities_USD                    0.883306       0.833376
# totalInvestments_USD                    1.000000       0.716397
# totalDebt_USD                           0.716397       1.000000
# totalEquity_USD                         0.724228       0.836622
# Scope_3_emissions_amount               -0.027028       0.000515
# scope_1_2_emissions_amount             -0.024123       0.026332
#
#                             totalEquity_USD  Scope_3_emissions_amount  \
# Market_Cap_USD                     0.306396                  0.006213
# Revenue_USD                        0.566851                  0.016432
# ebitda_USD                         0.645878                 -0.010391
# grossProfit_USD                    0.758211                 -0.018972
# netIncome_USD                      0.586906                 -0.020675
# cashAndCashEquivalents_USD         0.734821                 -0.028076
# shortTermInvestments_USD           0.769332                 -0.022649
# longTermInvestments_USD            0.717634                 -0.027766
# totalAssets_USD                    0.833943                 -0.021108
# totalLiabilities_USD               0.794992                 -0.019455
# totalInvestments_USD               0.724228                 -0.027028
# totalDebt_USD                      0.836622                  0.000515
# totalEquity_USD                    1.000000                  0.003940
# Scope_3_emissions_amount           0.003940                  1.000000
# scope_1_2_emissions_amount         0.043479                  0.255597
#
#                             scope_1_2_emissions_amount
# Market_Cap_USD                                0.002664
# Revenue_USD                                   0.063424
# ebitda_USD                                    0.022189
# grossProfit_USD                               0.006743
# netIncome_USD                                -0.007404
# cashAndCashEquivalents_USD                   -0.015193
# shortTermInvestments_USD                     -0.016822
# longTermInvestments_USD                      -0.024250
# totalAssets_USD                              -0.007364
# totalLiabilities_USD                         -0.008297
# totalInvestments_USD                         -0.024123
# totalDebt_USD                                 0.026332
# totalEquity_USD                               0.043479
# Scope_3_emissions_amount                      0.255597
# scope_1_2_emissions_amount                    1.000000

# %%
#drop columns due to collinearity, keeping total
end_of_life=end_of_life.drop(columns=['ebitda_USD', 'grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD', 'shortTermInvestments_USD', 
                                      'longTermInvestments_USD', 'totalLiabilities_USD', 'totalInvestments_USD', 'totalDebt_USD', 'totalEquity_USD',
                                      "account_name", "Third_party_verification", "Scope_3_emissions_type"])

# %%
end_of_life.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  2200 non-null   int64
#  1   Year                        2200 non-null   int64
#  2   incorporated_country        2200 non-null   object
#  3   Primary activity            2200 non-null   object
#  4   Primary sector              2200 non-null   object
#  5   Market_Cap_USD              1956 non-null   float64
#  6   Revenue_USD                 1957 non-null   float64
#  7   totalAssets_USD             1957 non-null   float64
#  8   Scope_3_emissions_amount    2200 non-null   float64
#  9   scope_1_2_emissions_amount  2196 non-null   float64
#  10  Year_sq                     2200 non-null   int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 189.2+ KB

# %%
sns.boxplot(end_of_life)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# copy dataframe
end_of_life_no_transform = end_of_life.copy()
# Change 'incorporated_country' to 'Countries' in end_of_life dataframe
end_of_life_no_transform = end_of_life_no_transform.rename(columns={'incorporated_country': 'Countries',
                                                       'Primary activity': 'Primary_activity',
                                                        'Primary sector': 'Primary_sector'})

print(end_of_life_no_transform.info())
end_of_life_no_transform.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  2200 non-null   int64
#  1   Year                        2200 non-null   int64
#  2   Countries                   2200 non-null   object
#  3   Primary_activity            2200 non-null   object
#  4   Primary_sector              2200 non-null   object
#  5   Market_Cap_USD              1956 non-null   float64
#  6   Revenue_USD                 1957 non-null   float64
#  7   totalAssets_USD             1957 non-null   float64
#  8   Scope_3_emissions_amount    2200 non-null   float64
#  9   scope_1_2_emissions_amount  2196 non-null   float64
#  10  Year_sq                     2200 non-null   int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 189.2+ KB
# None
#    account_id  Year       Countries             Primary_activity  \
# 0        4407  2018  United Kingdom         Electrical equipment
# 1        1104  2018  United Kingdom              Pharmaceuticals
# 2        2377  2018  United Kingdom  Telecommunications services
# 3        4702  2018  United Kingdom          Alcoholic beverages
# 4        7374  2018  United Kingdom              Pharmaceuticals
#
#                                      Primary_sector  Market_Cap_USD  \
# 0                 Electrical & electronic equipment    1.595156e+10
# 1                                  Biotech & pharma    7.441091e+10
# 2  Media, telecommunications & data center services    2.997109e+10
# 3                        Food & beverage processing    8.583054e+10
# 4                                  Biotech & pharma    7.508927e+10
#
#     Revenue_USD  totalAssets_USD  Scope_3_emissions_amount  \
# 0  1.443500e+10     1.248000e+10                   87100.0
# 1  2.209000e+10     6.065100e+10                   23597.0
# 2  2.975356e+10     5.878449e+10                    1000.0
# 3  1.544701e+10     3.773805e+10                   23500.0
# 4  3.914267e+10     7.374382e+10                  100140.0
#
#    scope_1_2_emissions_amount  Year_sq
# 0                3.804718e+05  4072324
# 1                7.072529e+05  4072324
# 2                4.572819e+05  4072324
# 3                6.226582e+05  4072324
# 4                1.227269e+06  4072324

# %%
end_of_life_no_transform['Primary_sector'].value_counts()
# Out:
# Primary_sector
# Electrical & electronic equipment                     293
# Chemicals                                             263
# Food & beverage processing                            176
# Biotech & pharma                                      137
# Construction                                          127
# Media, telecommunications & data center services      125
# Powered machinery                                      86
# Discretionary retail                                   84
# Financial services                                     71
# Medical equipment & supplies                           71
# Convenience retail                                     60
# Paper products & packaging                             52
# Metal products manufacturing                           46
# Transportation equipment                               44
# Specialized professional services                      39
# Print & publishing services                            39
# Trading, wholesale, distribution, rental & leasing     37
# Leisure & home manufacturing                           35
# Wood & rubber products                                 32
# Other materials                                        28
# Apparel design                                         26
# Metal smelting, refining & forming                     24
# Plastic product manufacturing                          23
# Tobacco                                                23
# Bars, hotels & restaurants                             23
# Light manufacturing                                    21
# Intermodal transport & logistics                       19
# Textiles & fabric goods                                19
# Wood & paper materials                                 18
# Metallic mineral mining                                16
# Commercial & consumer services                         14
# Thermal power generation                               14
# IT & software development                              12
# Renewable energy equipment                             10
# Accessories                                             9
# Other services                                          9
# Web & marketing services                                8
# 0                                                       7
# Marine transport                                        7
# Energy utility networks                                 7
# Logging & rubber tapping                                6
# Oil & gas processing                                    6
# Fish & animal farming                                   6
# Non-energy utilities                                    5
# Cement & concrete                                       5
# Industrial support services                             4
# Oil & gas retailing                                     3
# Air transport                                           3
# Land & property ownership & development                 3
# Road transport                                          2
# Health care provision                                   2
# Rail transport                                          1
# Name: count, dtype: int64

# %%
end_of_life_no_transform['Primary_activity'].value_counts().head(20)
# Out:
# Primary_activity
# Telecommunications services              119
# Pharmaceuticals                          109
# Personal care & household products        90
# Electronic components                     89
# Other base chemicals                      82
# Electronic equipment                      77
# Specialty chemicals                       73
# Other food processing                     68
# Supermarkets, food & drugstores           60
# Alcoholic beverages                       54
# Paper products                            52
# Banks                                     46
# Communications equipment                  46
# Industrial machinery                      45
# Non-residential building construction     43
# Electrical equipment                      43
# Automobiles                               42
# Medical equipment                         41
# Other professional services               39
# Residential building construction         38
# Name: count, dtype: int64

# %%
# Looking at missing data
print(end_of_life_no_transform.isnull().mean().sort_values(ascending=False).round(3) * 100)
# Out:
# Market_Cap_USD                11.1
# Revenue_USD                   11.0
# totalAssets_USD               11.0
# scope_1_2_emissions_amount     0.2
# account_id                     0.0
# Year                           0.0
# Countries                      0.0
# Primary_activity               0.0
# Primary_sector                 0.0
# Scope_3_emissions_amount       0.0
# Year_sq                        0.0
# dtype: float64

# %% [markdown]
# Apply signed log transformation and split data by company and year into train_df (2018-2022) and test_df (2023):

# %%
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'totalAssets_USD',
                'Scope_3_emissions_amount', 'scope_1_2_emissions_amount'
]
required_cols = [
    'account_id', 'Year', 'Year_sq', 'Countries', 'Primary_activity', 'Primary_sector'
] + numeric_cols

# --- Prepare Data ---
df = end_of_life_no_transform[required_cols].dropna()

# --- Signed log transform ---
def signed_log(x):
    return np.sign(x) * np.log(np.abs(x) + 1)

for col in numeric_cols:
    df[f'slog_{col}'] = signed_log(df[col])

# --- Company-level split by year ---
train_df = df[df['Year'].between(2018, 2022)].copy()
test_df  = df[df['Year'] == 2023].copy()

# Keep only companies present in training
valid_companies = set(train_df['account_id'].unique())
test_df = test_df[test_df['account_id'].isin(valid_companies)].copy()

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (1537, 16)
# Test shape: (342, 16)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1537 entries, 0 to 1729
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       1537 non-null   int64
#  1   Year                             1537 non-null   int64
#  2   Year_sq                          1537 non-null   int64
#  3   Countries                        1537 non-null   object
#  4   Primary_activity                 1537 non-null   object
#  5   Primary_sector                   1537 non-null   object
#  6   Market_Cap_USD                   1537 non-null   float64
#  7   Revenue_USD                      1537 non-null   float64
#  8   totalAssets_USD                  1537 non-null   float64
#  9   Scope_3_emissions_amount         1537 non-null   float64
#  10  scope_1_2_emissions_amount       1537 non-null   float64
#  11  slog_Market_Cap_USD              1537 non-null   float64
#  12  slog_Revenue_USD                 1537 non-null   float64
#  13  slog_totalAssets_USD             1537 non-null   float64
#  14  slog_Scope_3_emissions_amount    1537 non-null   float64
#  15  slog_scope_1_2_emissions_amount  1537 non-null   float64
# dtypes: float64(10), int64(3), object(3)
# memory usage: 204.1+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 342 entries, 1732 to 2194
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       342 non-null    int64
#  1   Year                             342 non-null    int64
#  2   Year_sq                          342 non-null    int64
#  3   Countries                        342 non-null    object
#  4   Primary_activity                 342 non-null    object
#  5   Primary_sector                   342 non-null    object
#  6   Market_Cap_USD                   342 non-null    float64
#  7   Revenue_USD                      342 non-null    float64
#  8   totalAssets_USD                  342 non-null    float64
#  9   Scope_3_emissions_amount         342 non-null    float64
#  10  scope_1_2_emissions_amount       342 non-null    float64
#  11  slog_Market_Cap_USD              342 non-null    float64
#  12  slog_Revenue_USD                 342 non-null    float64
#  13  slog_totalAssets_USD             342 non-null    float64
#  14  slog_Scope_3_emissions_amount    342 non-null    float64
#  15  slog_scope_1_2_emissions_amount  342 non-null    float64
# dtypes: float64(10), int64(3), object(3)
# memory usage: 45.4+ KB

# %%
# Check number of 0's in train and test df's
print((train_df == 0).sum().sum())
print((test_df == 0).sum().sum())
# Out:
# 4
# 0

# %% [markdown]
# ## End of Life Treatment of Sold Products Null Mixed-Effects Model
#
# Null mixed-effects model (random intercept only) to predict log-transformed Scope 3 emissions. The model serves as a baseline, capturing only the average emission level for each company, without incorporating any explanatory variables, and quantifies the improvement gained by including additional features and structure. The model is trained on 2018–2022 data and evaluated on a test set from 2023.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies
# - Fixed Effects:
#     - Intercept only (no predictors)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE NULL MODEL (random intercept only) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    null_model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ 1",
        train_df,
        groups=train_df["account_id"]
    )
    null_result = null_model.fit(method="lbfgs")

if not null_result.converged:
    print("WARNING: Null model did not fully converge.")

print(null_result.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_null'] = null_result.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_null']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_null'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics text
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[0], color='gray')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Null Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[1], color='gray')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Null Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Null Model Predicted")
plt.xscale("log")
plt.title("Null Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
null_model_metrics = {
    "Model": "Null (RI)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "Random intercept only"
}
# Out:
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 1537    Method:             REML
# No. Groups:       406     Scale:              0.8702
# Min. group size:  1       Log-Likelihood:     -2806.5046
# Max. group size:  5       Converged:          Yes
# Mean group size:  3.8
# ------------------------------------------------------------------------------
#                  Coef.     Std.Err.       z        P>|z|     [0.025     0.975]
# ------------------------------------------------------------------------------
# Intercept        9.788        0.155     63.219     0.000      9.485     10.092
# Group Var        9.411        0.855
# ==========================================================================
#
# R²(log):    -1.20%
# R²(orig):   -4.45%
# MAPE:       46647.66%
# MAPE(log):  56.77%
# MAE(log):   2.51
# RMSLE:      3.07
# RMSE:       2183339.11
# MAE:        462113.77

# %% [markdown]
# ## End of Life Treatment of Sold Products Two-Level Mixed-Effects Model
#
# Two-level hierarchical linear mixed-effects model to predict log-transformed Scope 3 emissions at the company level. The model is fit to training data (from 2018–2022), and predictions are evaluated on a test set (from 2023).  This model provides a baseline for including time trends and company-level variability.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies.<br>
# - Fixed Effects:
#     - Year (numeric)
#     - Year squared ('Year_sq', quadratic time trend)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- Check group sizes ---
group_sizes = train_df.groupby('account_id').size()
print("Two-Level Model: Company/year group size summary:")
print(group_sizes.describe())

# --- FIT THE TWO-LEVEL MODEL (random intercept, +Year, +Year_sq) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ Year + Year_sq",
        train_df,
        groups=train_df["account_id"],
        re_formula="1"
    )
    result_twolevel = model.fit(method="lbfgs")

if not result_twolevel.converged:
    print("WARNING: Two-level mixed model did not fully converge.")

print(result_twolevel.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_twolevel.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_mixed']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='orange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Two-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='orange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Two-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="orange", alpha=0.5, label="Two-Level Model Predicted")
plt.xscale("log")
plt.title("Two-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
two_level_model_metrics = {
    "Model": "2-level (RI+S)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "+Year, Year_sq"
}
# Out:
# Two-Level Model: Company/year group size summary:
# count    406.000000
# mean       3.785714
# std        1.568484
# min        1.000000
# 25%        2.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000
# dtype: float64
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 1537    Method:             REML
# No. Groups:       406     Scale:              0.8704
# Min. group size:  1       Log-Likelihood:     -2812.1382
# Max. group size:  5       Converged:          Yes
# Mean group size:  3.8
# ---------------------------------------------------------------------------
#                 Coef.      Std.Err.    z     P>|z|     [0.025      0.975]
# ---------------------------------------------------------------------------
# Intercept     -15362.222  60616.485  -0.253  0.800  -134168.349  103443.905
# Year              15.198     60.015   0.253  0.800     -102.429     132.824
# Year_sq           -0.004      0.015  -0.253  0.800       -0.033       0.025
# Group Var          9.419      0.855
# ==========================================================================
#
# R²(log):    -0.99%
# R²(orig):   -4.44%
# MAPE:       48151.73%
# MAPE(log):  56.90%
# MAE(log):   2.50
# RMSLE:      3.06
# RMSE:       2183220.46
# MAE:        462009.89

# %% [markdown]
# ## End of Life Treatment of Sold Products Three-Level Mixed-Effects Model
#
# A three-level hierarchical linear mixed-effects model is used to predict log-transformed Scope 3 emissions. It takes into account differences between primary activity, differences between companies, and changes over time. The model is trained using data from 2018 to 2022, and then tested on new data from 2023. This model provides insight on how emissions are influenced by primary activity, by individual companies, by financial and emissions factors, and by trends over time.
#
# Model Structure:
#
# - Level 3 (Primary Activity):<br>
#     - Random intercept and random slope for Year for each primary activity ('Primary_activity'), capturing baseline primary activity and primary activity-specific time trends.<br>
# - Level 2 (Account/Company):
#     - Random intercept for each company ('account_id'), capturing company-level deviations within each primary activity.
# - Level 1 (Yearly Observations):
#     - Repeated annual observations within each company.
#
# - Fixed Effects:
#     - Signed log-transformed market cap ('slog_Market_Cap_USD')
#     - Signed log-transformed revenue ('slog_Revenue_USD')
#     - *Removed: Signed log-transformed EBITDA ('slog_ebitda_USD') due to collinearity*
#     - Signed log-transformed Scope 1 & 2 emissions ('slog_scope_1_2_emissions_amount')

# %%
# --- Ensure grouping/categorical variables are string ---
for col in ['Countries', 'account_id', 'Primary_activity', 'Primary_sector']:
    train_df[col] = train_df[col].astype(str)
    test_df[col] = test_df[col].astype(str)

# --- Center the Year variable ---
year_mean = train_df['Year'].mean()
train_df['Year_centered'] = train_df['Year'] - year_mean
test_df['Year_centered'] = test_df['Year'] - year_mean

# --- Ensure log-transformed target exists ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE 3-LEVEL MIXED MODEL with Primary_activity as Level 3 group ---
vc = {'account_id': '0 + C(account_id)'}  # Level 2: account_id random intercept

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model_3level = MixedLM.from_formula(
        'log_Scope_3_emissions_amount ~ slog_Market_Cap_USD + slog_Revenue_USD + slog_scope_1_2_emissions_amount',
        groups='Primary_activity',
        re_formula='~Year_centered',
        vc_formula=vc,
        data=train_df
    )
    result_3level = model_3level.fit(method="lbfgs", maxiter=1000)

if not result_3level.converged:
    print("WARNING: Three-level mixed model did not fully converge.")

print(result_3level.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_3level.predict(test_df)

# --- Compute back-transformed values ---
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])

# --- Robust Mask for finite values everywhere ---
mask = (
    np.isfinite(test_df['log_Scope_3_emissions_amount']) &
    np.isfinite(test_df['predicted_mixed']) &
    np.isfinite(test_df['Reported_Scope_3']) &
    np.isfinite(test_df['Predicted_Scope_3'])
)
test_df = test_df.loc[mask].copy()

y_true_log = test_df['log_Scope_3_emissions_amount'].values
y_pred_log = test_df['predicted_mixed'].values
y_true = test_df['Reported_Scope_3'].values
y_pred = test_df['Predicted_Scope_3'].values

# Final defensive check and diagnostics
arrays = {
    "y_true_log": y_true_log,
    "y_pred_log": y_pred_log,
    "y_true": y_true,
    "y_pred": y_pred,
}
for arr_name, arr in arrays.items():
    if not np.all(np.isfinite(arr)):
        print(f"ERROR: {arr_name} contains non-finite values!")
        print(f"Non-finite indices: {np.where(~np.isfinite(arr))[0]}")
        print(f"Values: {arr[~np.isfinite(arr)]}")
        raise ValueError(f"{arr_name} contains infs or NaNs after masking!")

# --- METRICS ---
mae_log = mean_absolute_error(y_true_log, y_pred_log)
nonzero_mask = y_true_log != 0
if np.any(nonzero_mask):
    mape_log = np.mean(np.abs((y_true_log[nonzero_mask] - y_pred_log[nonzero_mask]) / y_true_log[nonzero_mask])) * 100
else:
    mape_log = np.nan

r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)

metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
if len(np.unique(y_pred_log)) > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Three-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()
axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

if len(np.unique(y_pred)) > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Three-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()
axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Filter strictly positive values for histogram (log x-axis requires >0)
y_true_pos = y_true[y_true > 0]
y_pred_pos = y_pred[y_pred > 0]

if y_true_pos.size > 0 and y_pred_pos.size > 0:
    min_val = min(y_true_pos.min(), y_pred_pos.min())
    max_val = max(y_true_pos.max(), y_pred_pos.max())
    if min_val == max_val:
        print("Skipping histogram: Only one unique positive value present.")
    else:
        log_bins = np.logspace(np.log10(min_val), np.log10(max_val), 100)

        plt.figure(figsize=(8, 5))
        sns.histplot(y_true_pos, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
        sns.histplot(y_pred_pos, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Three-Level Model Predicted")
        plt.xscale("log")
        plt.title("Three-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
        plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
        plt.ylabel("Density")
        plt.legend()
        plt.tight_layout()
        plt.show()
else:
    print("Skipping histogram: Not enough positive values in y_true or y_pred for log-scale histogram.")

# --- RETURN METRICS FOR SUMMARY TABLE ---
three_level_model_metrics = {
    "Model": "3-level (Primary Activity/Account/Year)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,
    "MAPE(log)": mape_log,
}
# Out:
#                       Mixed Linear Model Regression Results
# =================================================================================
# Model:               MixedLM   Dependent Variable:   log_Scope_3_emissions_amount
# No. Observations:    1537      Method:               REML
# No. Groups:          92        Scale:                0.8009
# Min. group size:     1         Log-Likelihood:       -2693.4632
# Max. group size:     83        Converged:            Yes
# Mean group size:     16.7
# ---------------------------------------------------------------------------------
#                                       Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# ---------------------------------------------------------------------------------
# Intercept                            -11.777    2.065 -5.703 0.000 -15.824 -7.729
# slog_Market_Cap_USD                   -0.051    0.070 -0.723 0.470  -0.188  0.087
# slog_Revenue_USD                       0.920    0.116  7.922 0.000   0.692  1.147
# slog_scope_1_2_emissions_amount        0.154    0.044  3.534 0.000   0.069  0.239
# Primary_activity Var                   3.354    0.895
# Primary_activity x Year_centered Cov   0.125    0.082
# Year_centered Var                      0.040    0.016
# account_id Var                         4.189    0.476
# =================================================================================
#
# R²(log):    19.48%
# R²(orig):   -3.60%
# MAPE:       13861.09%
# MAPE(log):  47.80%
# MAE(log):   2.19
# RMSLE:      2.74
# RMSE:       2174397.67
# MAE:        454791.09

# %% [markdown]
# ## End of Life Treatment of Sold Products Full Mixed-Effects Model
#
# A full mixed-effects model is used to predict company Scope 3 emissions, using financial and emissions data, along with information about country, industry, and year. The model is trained on data from 2018 to 2022, and tested on data from 2023. This full model helps provides insights into how a company’s finances, emissions, primary activity, country and the year influence emissions.<br>
#
# Model Structure:<br>
#
# - Random Effects:<br>
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:<br>
#     - Signed log-transformed financial and emissions features:<br>
#         - Market Cap ('slog_Market_Cap_USD')<br>
#         - Revenue ('slog_Revenue_USD')<br>
#         - Total Assets ('slog_totalAssets_USD')<br>
#         - Scope 1&2 Emissions ('slog_scope_1_2_emissions_amount')<br>
#     - Country ('Countries', as a categorical variable)<br>
#     - Primary Activity ('Primary_activity', as a categorical variable)<br>
#     - Year (numeric)<br>

# %%
numeric_cols
# Out:
# ['Market_Cap_USD',
#  'Revenue_USD',
#  'totalAssets_USD',
#  'Scope_3_emissions_amount',
#  'scope_1_2_emissions_amount']

# %%
# --- Feature and target columns ---
numeric_cols = ['Market_Cap_USD',
 'Revenue_USD',
 'totalAssets_USD',
 'Scope_3_emissions_amount',
 'scope_1_2_emissions_amount'
]
feature_cols_slog = [f'slog_{col}' for col in numeric_cols if col != 'Scope_3_emissions_amount']
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
required_cols = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_full = train_df.dropna(subset=required_cols).copy()
test_df_full = test_df.dropna(subset=required_cols).copy()

if test_df_full.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the full mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_full, groups=train_df_full['account_id'])
        mdf = md.fit(reml=False)
    print(mdf.summary())

    # --- Predict on test set ---
    test_df_full['predicted_log'] = mdf.predict(test_df_full)
    test_df_full['predicted'] = np.sign(test_df_full['predicted_log']) * (np.expm1(np.abs(test_df_full['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_full[target_col_slog]
    y_pred_log = test_df_full['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_full['predicted']

    # Mask for finite values
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nFull Mixed-Effects Model (Full Model) Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf.params,
        'pvalue': mdf.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Full Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Full Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Full Model Predicted")
    plt.xscale("log")
    plt.title("Full Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    full_model_metrics = {
        "Model": "Full Model",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
# /Users/amberjensen/anaconda3/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2704: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))
#                                               Mixed Linear Model Regression Results
# ==================================================================================================================================
# Model:                               MixedLM                   Dependent Variable:                   slog_Scope_3_emissions_amount
# No. Observations:                    1537                      Method:                               ML
# No. Groups:                          406                       Scale:                                1.0219
# Min. group size:                     1                         Log-Likelihood:                       -2581.5474
# Max. group size:                     5                         Converged:                            Yes
# Mean group size:                     3.8
# ----------------------------------------------------------------------------------------------------------------------------------
#                                                                             Coef.    Std.Err.    z     P>|z|   [0.025     0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                     34.998   40.030    0.874 0.382    -43.460    113.456
# C(Countries)[T.Belgium]                                                        2.696    1.006    2.681 0.007      0.725      4.667
# C(Countries)[T.Brazil]                                                         1.896    1.495    1.268 0.205     -1.035      4.827
# C(Countries)[T.Canada]                                                         1.728    1.396    1.238 0.216     -1.008      4.465
# C(Countries)[T.Chile]                                                          3.664    1.985    1.845 0.065     -0.227      7.554
# C(Countries)[T.China]                                                          3.156    1.094    2.885 0.004      1.011      5.300
# C(Countries)[T.Denmark]                                                    79705.008  410.198  194.309 0.000  78901.036  80508.981
# C(Countries)[T.Finland]                                                        2.286    0.964    2.370 0.018      0.396      4.175
# C(Countries)[T.France]                                                         2.263    0.918    2.464 0.014      0.463      4.063
# C(Countries)[T.Germany]                                                        3.302    0.929    3.554 0.000      1.481      5.123
# C(Countries)[T.Greece]                                                         3.691    1.626    2.270 0.023      0.504      6.879
# C(Countries)[T.Hungary]                                                        3.400    1.645    2.067 0.039      0.177      6.624
# C(Countries)[T.Ireland]                                                        3.844    1.299    2.960 0.003      1.299      6.389
# C(Countries)[T.Italy]                                                         -1.811    1.254   -1.444 0.149     -4.269      0.648
# C(Countries)[T.Japan]                                                          1.871    0.848    2.206 0.027      0.209      3.533
# C(Countries)[T.Mexico]                                                    -16101.401
# C(Countries)[T.Netherlands]                                                    3.500    1.121    3.122 0.002      1.303      5.697
# C(Countries)[T.New Zealand]                                                    2.424    1.889    1.284 0.199     -1.277      6.126
# C(Countries)[T.Norway]                                                         2.085    1.247    1.672 0.094     -0.358      4.528
# C(Countries)[T.Portugal]                                                      -2.088    1.490   -1.402 0.161     -5.008      0.831
# C(Countries)[T.Singapore]                                                      3.845    1.861    2.066 0.039      0.197      7.493
# C(Countries)[T.South Africa]                                                   1.874    1.085    1.728 0.084     -0.252      4.000
# C(Countries)[T.South Korea]                                                    0.683    0.939    0.727 0.467     -1.157      2.522
# C(Countries)[T.Spain]                                                          2.512    1.078    2.331 0.020      0.400      4.624
# C(Countries)[T.Sweden]                                                         3.346    1.197    2.795 0.005      1.000      5.692
# C(Countries)[T.Switzerland]                                                    2.119    0.997    2.126 0.033      0.166      4.073
# C(Countries)[T.Thailand]                                                       3.608    1.203    2.999 0.003      1.250      5.966
# C(Countries)[T.Turkey]                                                        -6.044    1.969   -3.070 0.002     -9.902     -2.186
# C(Countries)[T.USA]                                                            2.075    0.849    2.445 0.014      0.411      3.738
# C(Countries)[T.United Kingdom]                                                 1.775    0.872    2.036 0.042      0.066      3.484
# C(Primary_activity)[T.Agricultural chemicals]                                  1.420    1.963    0.723 0.470     -2.428      5.268
# C(Primary_activity)[T.Agriculture, construction & mining machinery]           -0.458    1.234   -0.372 0.710     -2.876      1.960
# C(Primary_activity)[T.Alcoholic beverages]                                    -0.307    1.152   -0.267 0.790     -2.564      1.950
# C(Primary_activity)[T.Animal processing]                                       0.251    1.462    0.172 0.863     -2.614      3.117
# C(Primary_activity)[T.Apparel & footwear design]                              -0.454    1.240   -0.366 0.714     -2.884      1.976
# C(Primary_activity)[T.Apparel stores]                                         -0.662    1.168   -0.567 0.571     -2.951      1.627
# C(Primary_activity)[T.Aquaculture]                                            -1.808    1.773   -1.020 0.308     -5.282      1.666
# C(Primary_activity)[T.Asset managers]                                         -2.921    1.461   -1.999 0.046     -5.784     -0.057
# C(Primary_activity)[T.Automobiles]                                             0.175    1.209    0.145 0.885     -2.194      2.545
# C(Primary_activity)[T.Baked goods & cereals]                                   1.821    1.830    0.995 0.320     -1.766      5.407
# C(Primary_activity)[T.Banks]                                                  -2.922    1.185   -2.465 0.014     -5.245     -0.599
# C(Primary_activity)[T.Batteries]                                               3.093    1.515    2.042 0.041      0.124      6.063
# C(Primary_activity)[T.Biotechnology]                                          -2.574    1.237   -2.081 0.037     -4.997     -0.150
# C(Primary_activity)[T.Building sub-contractors]                                0.624    1.363    0.458 0.647     -2.047      3.295
# C(Primary_activity)[T.CCGT generation]                                         1.967    1.538    1.279 0.201     -1.047      4.980
# C(Primary_activity)[T.Cement]                                              16104.577
# C(Primary_activity)[T.Clothing manufacture]                                    0.429    1.295    0.331 0.740     -2.109      2.968
# C(Primary_activity)[T.Commercial services]                                    -3.696    1.442   -2.563 0.010     -6.522     -0.869
# C(Primary_activity)[T.Communications equipment]                               -1.255    1.187   -1.058 0.290     -3.582      1.071
# C(Primary_activity)[T.Computer hardware]                                      -1.253    1.270   -0.987 0.324     -3.741      1.236
# C(Primary_activity)[T.Consumer services]                                      -0.895    1.871   -0.478 0.633     -4.562      2.773
# C(Primary_activity)[T.Dairy & egg products]                                    0.809    1.445    0.560 0.575     -2.022      3.641
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                     1.463    1.285    1.139 0.255     -1.055      3.981
# C(Primary_activity)[T.Department stores]                                       0.279    1.315    0.212 0.832     -2.299      2.856
# C(Primary_activity)[T.Discretionary delivery retail]                           1.311    1.445    0.907 0.364     -1.522      4.144
# C(Primary_activity)[T.Education services]                                      0.465    1.730    0.269 0.788     -2.925      3.855
# C(Primary_activity)[T.Electrical equipment]                                   -0.641    1.152   -0.556 0.578     -2.899      1.618
# C(Primary_activity)[T.Electronic components]                                  -3.361    1.092   -3.078 0.002     -5.501     -1.221
# C(Primary_activity)[T.Electronic equipment]                                    0.235    1.101    0.213 0.831     -1.923      2.393
# C(Primary_activity)[T.Energy infrastructure construction]                      0.505    1.551    0.325 0.745     -2.535      3.544
# C(Primary_activity)[T.Energy services & equipment]                            -6.544    1.938   -3.377 0.001    -10.342     -2.746
# C(Primary_activity)[T.Engines & motors]                                        0.656    1.303    0.504 0.615     -1.898      3.211
# C(Primary_activity)[T.Fabricated metal components]                             0.605    1.203    0.503 0.615     -1.753      2.963
# C(Primary_activity)[T.Fast food]                                               1.898    1.367    1.388 0.165     -0.781      4.577
# C(Primary_activity)[T.Food & beverage amenities]                               1.407    1.452    0.969 0.332     -1.438      4.252
# C(Primary_activity)[T.Food & beverage wholesale]                              -1.286    1.780   -0.723 0.470     -4.775      2.203
# C(Primary_activity)[T.Furniture]                                               1.807    1.328    1.361 0.174     -0.796      4.410
# C(Primary_activity)[T.Gas utilities]                                          -6.935    1.741   -3.983 0.000    -10.347     -3.522
# C(Primary_activity)[T.Glass products]                                          3.358    1.372    2.448 0.014      0.670      6.047
# C(Primary_activity)[T.Grain & corn milling]                                   -1.052    1.975   -0.533 0.594     -4.922      2.818
# C(Primary_activity)[T.Health care facilities]                                 -4.845    1.963   -2.468 0.014     -8.692     -0.998
# C(Primary_activity)[T.Health care services]                                   -0.744    1.963   -0.379 0.705     -4.592      3.104
# C(Primary_activity)[T.Health care supplies]                                    0.048    1.221    0.039 0.969     -2.345      2.440
# C(Primary_activity)[T.Homeware]                                                1.827    1.777    1.028 0.304     -1.656      5.309
# C(Primary_activity)[T.Hotels & lodging]                                       -3.690    1.590   -2.321 0.020     -6.806     -0.574
# C(Primary_activity)[T.Industrial machinery]                                   -0.780    1.159   -0.673 0.501     -3.051      1.491
# C(Primary_activity)[T.Inorganic base chemicals]                                3.441    1.456    2.364 0.018      0.588      6.294
# C(Primary_activity)[T.Insurance]                                              -4.777    1.346   -3.550 0.000     -7.414     -2.139
# C(Primary_activity)[T.Iron & steel]                                           -2.446    1.574   -1.554 0.120     -5.532      0.639
# C(Primary_activity)[T.Logging]                                                 0.471    1.733    0.272 0.786     -2.926      3.867
# C(Primary_activity)[T.Logistics - 3rd party]                                  -3.966    1.469   -2.701 0.007     -6.844     -1.088
# C(Primary_activity)[T.Marketing]                                              -5.385    2.108   -2.554 0.011     -9.517     -1.253
# C(Primary_activity)[T.Medical equipment]                                      -1.494    1.131   -1.321 0.186     -3.710      0.722
# C(Primary_activity)[T.Metal containers & packaging]                            1.864    1.340    1.391 0.164     -0.763      4.491
# C(Primary_activity)[T.Metal processing]                                        0.574    1.812    0.317 0.751     -2.977      4.125
# C(Primary_activity)[T.Non-alcoholic beverages]                                -0.262    1.270   -0.206 0.837     -2.751      2.228
# C(Primary_activity)[T.Non-residential building construction]                  -1.041    1.156   -0.901 0.368     -3.306      1.223
# C(Primary_activity)[T.Oil & gas marketing & retailing]                        -4.910    1.753   -2.800 0.005     -8.347     -1.474
# C(Primary_activity)[T.Oil & gas refining]                                      2.610    1.815    1.438 0.150     -0.948      6.168
# C(Primary_activity)[T.Other base chemicals]                                    2.215    1.128    1.964 0.050      0.005      4.426
# C(Primary_activity)[T.Other containers & packaging]                            1.610    1.456    1.106 0.269     -1.244      4.465
# C(Primary_activity)[T.Other food processing]                                   0.870    1.141    0.762 0.446     -1.367      3.106
# C(Primary_activity)[T.Other non-ferrous ore mining]                            1.433    1.749    0.819 0.413     -1.995      4.862
# C(Primary_activity)[T.Other non-wood building materials]                       3.138    1.743    1.800 0.072     -0.279      6.555
# C(Primary_activity)[T.Other professional services]                            -2.960    1.160   -2.552 0.011     -5.233     -0.687
# C(Primary_activity)[T.Other renewable energy equipment]                   -79704.923  413.140 -192.925 0.000 -80514.662 -78895.185
# C(Primary_activity)[T.Paper products]                                          1.844    1.195    1.543 0.123     -0.498      4.186
# C(Primary_activity)[T.Passenger airlines]                                     -8.247    1.968   -4.190 0.000    -12.105     -4.389
# C(Primary_activity)[T.Personal care & household products]                      1.836    1.112    1.651 0.099     -0.344      4.016
# C(Primary_activity)[T.Pharmaceuticals]                                        -1.403    1.089   -1.288 0.198     -3.538      0.732
# C(Primary_activity)[T.Plastic products]                                        2.987    1.333    2.241 0.025      0.374      5.600
# C(Primary_activity)[T.Precious metals & minerals mining]                      -5.052    1.516   -3.333 0.001     -8.022     -2.081
# C(Primary_activity)[T.Print publishing]                                        1.025    1.395    0.735 0.462     -1.709      3.759
# C(Primary_activity)[T.Printing services]                                       2.818    1.434    1.964 0.050      0.006      5.629
# C(Primary_activity)[T.Pulp & paper mills]                                      2.682    1.484    1.807 0.071     -0.227      5.591
# C(Primary_activity)[T.REIT]                                                   -0.961    1.995   -0.482 0.630     -4.871      2.949
# C(Primary_activity)[T.Real estate services]                                    2.047    1.996    1.026 0.305     -1.865      5.960
# C(Primary_activity)[T.Residential building construction]                       1.090    1.164    0.936 0.349     -1.191      3.370
# C(Primary_activity)[T.Rubber products]                                         2.525    1.238    2.040 0.041      0.099      4.951
# C(Primary_activity)[T.Servers & data centers]                                 -1.459    1.743   -0.837 0.403     -4.875      1.958
# C(Primary_activity)[T.Software]                                               -4.990    1.446   -3.451 0.001     -7.823     -2.156
# C(Primary_activity)[T.Solar energy equipment]                                 -2.493    1.749   -1.425 0.154     -5.921      0.936
# C(Primary_activity)[T.Specialist retail]                                       1.011    1.293    0.782 0.434     -1.524      3.545
# C(Primary_activity)[T.Specialty chemicals]                                     2.172    1.125    1.931 0.054     -0.033      4.376
# C(Primary_activity)[T.Supermarkets, food & drugstores]                         0.134    1.150    0.116 0.907     -2.121      2.389
# C(Primary_activity)[T.Telecommunications services]                            -4.331    1.105   -3.921 0.000     -6.496     -2.166
# C(Primary_activity)[T.Textiles]                                               -1.284    1.969   -0.652 0.515     -5.144      2.577
# C(Primary_activity)[T.Tobacco products]                                       -0.017    1.260   -0.013 0.989     -2.487      2.453
# C(Primary_activity)[T.Transportation infrastructure & other construction]     -3.344    1.410   -2.371 0.018     -6.109     -0.580
# C(Primary_activity)[T.Water supply networks]                                   1.767    1.556    1.136 0.256     -1.283      4.817
# C(Primary_activity)[T.Wood furniture]                                          3.199    1.775    1.802 0.072     -0.281      6.678
# slog_Market_Cap_USD                                                           -0.118    0.073   -1.613 0.107     -0.261      0.025
# slog_Revenue_USD                                                               1.023    0.119    8.617 0.000      0.791      1.256
# slog_totalAssets_USD                                                           0.029    0.046    0.623 0.533     -0.062      0.119
# slog_scope_1_2_emissions_amount                                                0.189    0.047    4.052 0.000      0.098      0.280
# Year                                                                          -0.025    0.020   -1.252 0.211     -0.064      0.014
# Group Var                                                                      1.692    0.133
# ==================================================================================================================================
#
#
# Full Mixed-Effects Model (Full Model) Test Set Performance Metrics:
# R²(log):    69.17%
# R²(orig):   0.32%
# MAPE:       787.74%
# MAPE(log):  26.01%
# MAE(log):   1.31
# RMSLE:      1.69
# RMSE:       2132828.65
# MAE:        404652.37
#
# Top Influential Features (by p-value):
#                                                             coef        pvalue
# C(Primary_activity)[T.Other renewable energy eq... -79704.923372  0.000000e+00
# C(Countries)[T.Denmark]                             79705.008072  0.000000e+00
# Group Var                                               1.655890  2.951233e-36
# slog_Revenue_USD                                        1.023474  6.856076e-18
# C(Primary_activity)[T.Passenger airlines]              -8.246928  2.795481e-05
# slog_scope_1_2_emissions_amount                         0.189024  5.086146e-05
# C(Primary_activity)[T.Gas utilities]                   -6.934550  6.803692e-05
# C(Primary_activity)[T.Telecommunications services]     -4.330919  8.819442e-05
# C(Countries)[T.Germany]                                 3.301559  3.799709e-04
# C(Primary_activity)[T.Insurance]                       -4.776863  3.855062e-04

# %% [markdown]
# ## End of Life Treatment of Sold Products Optimized Mixed-Effects Model
#
# An optimized mixed-effects model is used to predict company Scope 3 emissions. The model provides accurate prediction using only the most significant predictive features, while still accounting for primary activity, country and company level effects. The model is trained on data from 2018–2022 and evaluated on test data from 2023.
#
# Model Structure:
#
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:
#     - Signed log-transformed features:
#         - Revenue ('slog_Revenue_USD')
#         - Total Assets ('slog_totalAssets_USD')
#         - Scope 1 & 2 Emissions ('slog_scope_1_2_emissions_amount')
#     - Country ('Countries', as a categorical variable)
#     - Primary Activity ('Primary_activity', as a categorical variable)

# %%
feature_cols_slog = [
    'slog_Revenue_USD',
    'slog_totalAssets_USD',
    'slog_scope_1_2_emissions_amount'
]
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
all_model_vars = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_opt = train_df.dropna(subset=all_model_vars).copy()
test_df_opt = test_df.dropna(subset=all_model_vars).copy()

if test_df_opt.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity)'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the optimized mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_opt, groups=train_df_opt['account_id'])
        mdf_optimized = md.fit(reml=False)
    print(mdf_optimized.summary())

    # --- Predict on test set ---
    test_df_opt['predicted_log'] = mdf_optimized.predict(test_df_opt)
    test_df_opt['predicted'] = np.sign(test_df_opt['predicted_log']) * (np.expm1(np.abs(test_df_opt['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_opt[target_col_slog]
    y_pred_log = test_df_opt['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_opt['predicted']

    # Mask for valid/finites
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <-- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nOptimized Mixed-Effects Model: Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf_optimized.params,
        'pvalue': mdf_optimized.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Optimized Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Optimized Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Optimized Model Predicted")
    plt.xscale("log")
    plt.title("Optimized Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    optimized_model_metrics = {
        "Model": "Optimized",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
# /Users/amberjensen/anaconda3/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2704: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))
#                                                                     Mixed Linear Model Regression Results
# =============================================================================================================================================================================
# Model:                                              MixedLM                                 Dependent Variable:                                 slog_Scope_3_emissions_amount
# No. Observations:                                   1537                                    Method:                                             ML
# No. Groups:                                         406                                     Scale:                                              0.9583
# Min. group size:                                    1                                       Log-Likelihood:                                     -2574.7779
# Max. group size:                                    5                                       Converged:                                          Yes
# Mean group size:                                    3.8
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                                   Coef.                Std.Err.         z    P>|z|         [0.025               0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                                -10.705
# C(Countries)[T.Belgium]                                                                    2.227                1.253  1.778 0.075                -0.228                4.682
# C(Countries)[T.Brazil]                                                                     0.563                1.633  0.345 0.730                -2.637                3.764
# C(Countries)[T.Canada]                                                                     1.353                1.648  0.821 0.412                -1.877                4.582
# C(Countries)[T.Chile]                                                                      3.025                1.860  1.627 0.104                -0.620                6.670
# C(Countries)[T.China]                                                                      2.682                1.526  1.758 0.079                -0.308                5.672
# C(Countries)[T.Denmark]                                                    13125831328149310.000
# C(Countries)[T.Finland]                                                                    1.637                1.249  1.310 0.190                -0.812                4.085
# C(Countries)[T.France]                                                                     1.850                1.280  1.445 0.148                -0.659                4.359
# C(Countries)[T.Germany]                                                                    2.877                1.273  2.260 0.024                 0.382                5.373
# C(Countries)[T.Greece]                                                                     3.002                1.833  1.637 0.102                -0.591                6.595
# C(Countries)[T.Hungary]                                                                    3.112                2.068  1.505 0.132                -0.941                7.166
# C(Countries)[T.Ireland]                                                                    3.500                1.434  2.441 0.015                 0.689                6.311
# C(Countries)[T.Italy]                                                                     -2.575                1.428 -1.804 0.071                -5.374                0.223
# C(Countries)[T.Japan]                                                                      1.376                0.987  1.394 0.163                -0.558                3.311
# C(Countries)[T.Mexico]                                                      -785337869342054.375 1749768360962240.000 -0.449 0.654 -4214820838115726.500 2644145099431617.500
# C(Countries)[T.Netherlands]                                                                3.234                1.463  2.210 0.027                 0.366                6.101
# C(Countries)[T.New Zealand]                                                                1.581                2.180  0.725 0.468                -2.692                5.854
# C(Countries)[T.Norway]                                                                     1.463                1.405  1.042 0.298                -1.290                4.217
# C(Countries)[T.Portugal]                                                                  -2.864                1.774 -1.614 0.107                -6.342                0.614
# C(Countries)[T.Singapore]                                                                  3.124                1.717  1.820 0.069                -0.241                6.489
# C(Countries)[T.South Africa]                                                               1.190                1.258  0.946 0.344                -1.275                3.656
# C(Countries)[T.South Korea]                                                                0.222                1.166  0.190 0.849                -2.064                2.508
# C(Countries)[T.Spain]                                                                      1.941                1.293  1.501 0.133                -0.593                4.475
# C(Countries)[T.Sweden]                                                                     2.814                1.534  1.834 0.067                -0.193                5.820
# C(Countries)[T.Switzerland]                                                                1.478                1.011  1.462 0.144                -0.503                3.458
# C(Countries)[T.Thailand]                                                                   3.246                1.263  2.569 0.010                 0.770                5.723
# C(Countries)[T.Turkey]                                                                    -6.212                2.050 -3.030 0.002               -10.229               -2.194
# C(Countries)[T.USA]                                                                        1.648                1.149  1.435 0.151                -0.603                3.899
# C(Countries)[T.United Kingdom]                                                             1.249                1.131  1.104 0.269                -0.967                3.466
# C(Primary_activity)[T.Agricultural chemicals]                                              0.007                1.727  0.004 0.997                -3.378                3.393
# C(Primary_activity)[T.Agriculture, construction & mining machinery]                       -1.537                0.920 -1.671 0.095                -3.341                0.266
# C(Primary_activity)[T.Alcoholic beverages]                                                -1.529                0.664 -2.303 0.021                -2.830               -0.228
# C(Primary_activity)[T.Animal processing]                                                  -0.896                1.182 -0.758 0.449                -3.213                1.421
# C(Primary_activity)[T.Apparel & footwear design]                                          -1.702                0.797 -2.135 0.033                -3.264               -0.139
# C(Primary_activity)[T.Apparel stores]                                                     -1.794                0.659 -2.723 0.006                -3.086               -0.503
# C(Primary_activity)[T.Aquaculture]                                                        -3.220                1.384 -2.326 0.020                -5.933               -0.506
# C(Primary_activity)[T.Asset managers]                                                     -3.949                1.009 -3.915 0.000                -5.926               -1.972
# C(Primary_activity)[T.Automobiles]                                                        -0.753                0.919 -0.820 0.412                -2.554                1.047
# C(Primary_activity)[T.Baked goods & cereals]                                               0.614                1.573  0.390 0.696                -2.469                3.697
# C(Primary_activity)[T.Banks]                                                              -4.028                0.661 -6.091 0.000                -5.323               -2.732
# C(Primary_activity)[T.Batteries]                                                           1.811                1.327  1.364 0.172                -0.791                4.413
# C(Primary_activity)[T.Biotechnology]                                                      -3.882                0.678 -5.727 0.000                -5.210               -2.553
# C(Primary_activity)[T.Building sub-contractors]                                           -0.459                1.032 -0.444 0.657                -2.483                1.565
# C(Primary_activity)[T.CCGT generation]                                                     0.557
# C(Primary_activity)[T.Cement]                                                785337869342055.750 1749768360962239.000  0.449 0.654 -2644145099431615.000 4214820838115726.000
# C(Primary_activity)[T.Clothing manufacture]                                               -0.830                0.776 -1.069 0.285                -2.351                0.692
# C(Primary_activity)[T.Commercial services]                                                -4.973                1.103 -4.510 0.000                -7.134               -2.811
# C(Primary_activity)[T.Communications equipment]                                           -2.403                0.701 -3.429 0.001                -3.776               -1.029
# C(Primary_activity)[T.Computer hardware]                                                  -2.400                0.931 -2.577 0.010                -4.224               -0.575
# C(Primary_activity)[T.Consumer services]                                                  -2.369                1.750 -1.353 0.176                -5.799                1.062
# C(Primary_activity)[T.Dairy & egg products]                                               -0.294                1.128 -0.261 0.794                -2.504                1.917
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                                 0.414                0.843  0.491 0.623                -1.238                2.066
# C(Primary_activity)[T.Department stores]                                                  -0.884                0.985 -0.897 0.370                -2.814                1.047
# C(Primary_activity)[T.Discretionary delivery retail]                                       0.103                1.215  0.085 0.933                -2.279                2.484
# C(Primary_activity)[T.Education services]                                                 -0.727                1.652 -0.440 0.660                -3.964                2.510
# C(Primary_activity)[T.Electrical equipment]                                               -1.853                0.580 -3.192 0.001                -2.990               -0.715
# C(Primary_activity)[T.Electronic components]                                              -4.587                0.586 -7.827 0.000                -5.736               -3.439
# C(Primary_activity)[T.Electronic equipment]                                               -0.900                0.668 -1.349 0.177                -2.209                0.408
# C(Primary_activity)[T.Energy infrastructure construction]                                 -0.543                1.379 -0.393 0.694                -3.246                2.160
# C(Primary_activity)[T.Energy services & equipment]                                        -8.394                1.775 -4.729 0.000               -11.873               -4.915
# C(Primary_activity)[T.Engines & motors]                                                   -0.445                0.811 -0.549 0.583                -2.034                1.145
# C(Primary_activity)[T.Fabricated metal components]                                        -0.485                0.708 -0.685 0.494                -1.874                0.904
# C(Primary_activity)[T.Fast food]                                                           0.475                0.991  0.479 0.632                -1.467                2.417
# C(Primary_activity)[T.Food & beverage amenities]                                           0.307                1.060  0.290 0.772                -1.771                2.385
# C(Primary_activity)[T.Food & beverage wholesale]                                          -1.989                1.515 -1.313 0.189                -4.958                0.980
# C(Primary_activity)[T.Furniture]                                                           0.556                1.074  0.517 0.605                -1.550                2.662
# C(Primary_activity)[T.Gas utilities]                                                      -7.985                1.586 -5.034 0.000               -11.094               -4.876
# C(Primary_activity)[T.Glass products]                                                      2.155                0.894  2.410 0.016                 0.403                3.908
# C(Primary_activity)[T.Grain & corn milling]                                               -2.293                1.710 -1.340 0.180                -5.645                1.060
# C(Primary_activity)[T.Health care facilities]                                             -6.038                1.726 -3.498 0.000                -9.422               -2.655
# C(Primary_activity)[T.Health care services]                                               -2.297                1.743 -1.318 0.188                -5.713                1.119
# C(Primary_activity)[T.Health care supplies]                                               -1.261                0.723 -1.744 0.081                -2.679                0.156
# C(Primary_activity)[T.Homeware]                                                            0.387                1.545  0.251 0.802                -2.640                3.415
# C(Primary_activity)[T.Hotels & lodging]                                                   -5.012                1.185 -4.229 0.000                -7.336               -2.689
# C(Primary_activity)[T.Industrial machinery]                                               -2.143                0.762 -2.811 0.005                -3.637               -0.649
# C(Primary_activity)[T.Inorganic base chemicals]                                            2.305                1.185  1.945 0.052                -0.018                4.627
# C(Primary_activity)[T.Insurance]                                                          -5.641                1.010 -5.584 0.000                -7.620               -3.661
# C(Primary_activity)[T.Iron & steel]                                                       -3.355                1.270 -2.641 0.008                -5.844               -0.865
# C(Primary_activity)[T.Logging]                                                            -0.514                1.606 -0.320 0.749                -3.663                2.634
# C(Primary_activity)[T.Logistics - 3rd party]                                              -4.923                1.121 -4.391 0.000                -7.121               -2.726
# C(Primary_activity)[T.Marketing]                                                          -6.906                1.875 -3.684 0.000               -10.580               -3.232
# C(Primary_activity)[T.Medical equipment]                                                  -2.923                0.653 -4.478 0.000                -4.202               -1.644
# C(Primary_activity)[T.Metal containers & packaging]                                        0.675                0.973  0.694 0.488                -1.232                2.583
# C(Primary_activity)[T.Metal processing]                                                   -0.552                1.463 -0.377 0.706                -3.420                2.316
# C(Primary_activity)[T.Non-alcoholic beverages]                                            -1.474                0.794 -1.857 0.063                -3.030                0.081
# C(Primary_activity)[T.Non-residential building construction]                              -2.088                0.747 -2.796 0.005                -3.552               -0.625
# C(Primary_activity)[T.Oil & gas marketing & retailing]                                    -6.229                1.873 -3.325 0.001                -9.901               -2.557
# C(Primary_activity)[T.Oil & gas refining]                                                  1.647                1.601  1.029 0.304                -1.491                4.785
# C(Primary_activity)[T.Other base chemicals]                                                0.982                0.936  1.048 0.294                -0.853                2.816
# C(Primary_activity)[T.Other containers & packaging]                                        0.518                1.032  0.502 0.616                -1.505                2.541
# C(Primary_activity)[T.Other food processing]                                              -0.319                0.603 -0.528 0.597                -1.501                0.864
# C(Primary_activity)[T.Other non-ferrous ore mining]                                        0.507                1.588  0.319 0.750                -2.606                3.619
# C(Primary_activity)[T.Other non-wood building materials]                                   1.831                1.589  1.152 0.249                -1.284                4.946
# C(Primary_activity)[T.Other professional services]                                        -4.134                0.796 -5.195 0.000                -5.693               -2.574
# C(Primary_activity)[T.Other renewable energy equipment]                   -13125831328149310.000
# C(Primary_activity)[T.Paper products]                                                      0.693                0.477  1.455 0.146                -0.241                1.628
# C(Primary_activity)[T.Passenger airlines]                                                 -9.451                1.717 -5.505 0.000               -12.816               -6.086
# C(Primary_activity)[T.Personal care & household products]                                  0.562                0.483  1.165 0.244                -0.384                1.509
# C(Primary_activity)[T.Pharmaceuticals]                                                    -2.631                0.444 -5.928 0.000                -3.501               -1.761
# C(Primary_activity)[T.Plastic products]                                                    1.732                0.942  1.839 0.066                -0.113                3.578
# C(Primary_activity)[T.Precious metals & minerals mining]                                  -6.165                1.084 -5.690 0.000                -8.289               -4.042
# C(Primary_activity)[T.Print publishing]                                                   -0.240                0.878 -0.273 0.785                -1.961                1.481
# C(Primary_activity)[T.Printing services]                                                   1.785                1.188  1.502 0.133                -0.544                4.113
# C(Primary_activity)[T.Pulp & paper mills]                                                  1.704                1.022  1.667 0.095                -0.299                3.707
# C(Primary_activity)[T.REIT]                                                               -2.895                1.743 -1.661 0.097                -6.311                0.521
# C(Primary_activity)[T.Real estate services]                                                0.164                1.716  0.095 0.924                -3.200                3.527
# C(Primary_activity)[T.Residential building construction]                                  -0.087                0.729 -0.119 0.905                -1.515                1.341
# C(Primary_activity)[T.Rubber products]                                                     1.426                0.861  1.656 0.098                -0.262                3.114
# C(Primary_activity)[T.Servers & data centers]                                             -2.446                1.499 -1.632 0.103                -5.385                0.492
# C(Primary_activity)[T.Software]                                                           -6.353                1.099 -5.779 0.000                -8.508               -4.198
# C(Primary_activity)[T.Solar energy equipment]                                             -3.979                1.481 -2.686 0.007                -6.883               -1.076
# C(Primary_activity)[T.Specialist retail]                                                  -0.170                0.869 -0.196 0.845                -1.874                1.534
# C(Primary_activity)[T.Specialty chemicals]                                                 0.848
# C(Primary_activity)[T.Supermarkets, food & drugstores]                                    -0.727
# C(Primary_activity)[T.Telecommunications services]                                        -5.436
# C(Primary_activity)[T.Textiles]                                                           -2.762                1.742 -1.586 0.113                -6.175                0.652
# C(Primary_activity)[T.Tobacco products]                                                   -1.135                0.749 -1.516 0.130                -2.602                0.332
# C(Primary_activity)[T.Transportation infrastructure & other construction]                 -4.362                1.029 -4.239 0.000                -6.379               -2.345
# C(Primary_activity)[T.Water supply networks]                                               0.603                1.154  0.522 0.601                -1.659                2.865
# C(Primary_activity)[T.Wood furniture]                                                      1.974                1.666  1.185 0.236                -1.291                5.239
# slog_Revenue_USD                                                                           0.772                0.111  6.928 0.000                 0.554                0.991
# slog_totalAssets_USD                                                                       0.027                0.043  0.626 0.531                -0.058                0.111
# slog_scope_1_2_emissions_amount                                                            0.193                0.051  3.816 0.000                 0.094                0.292
# Group Var                                                                                  2.035                0.176
# =============================================================================================================================================================================
#
#
# Optimized Mixed-Effects Model: Test Set Performance Metrics:
# R²(log):    68.41%
# R²(orig):   -0.59%
# MAPE:       973.84%
# MAPE(log):  26.91%
# MAE(log):   1.33
# RMSLE:      1.71
# RMSE:       2142617.06
# MAE:        418074.98
#
# Top Influential Features (by p-value):
#                                                         coef        pvalue
# Group Var                                           2.123484  4.978489e-32
# C(Primary_activity)[T.Electronic components]       -4.587292  5.010324e-15
# slog_Revenue_USD                                    0.772339  4.282575e-12
# C(Primary_activity)[T.Banks]                       -4.027514  1.120785e-09
# C(Primary_activity)[T.Pharmaceuticals]             -2.631140  3.066014e-09
# C(Primary_activity)[T.Software]                    -6.353187  7.531462e-09
# C(Primary_activity)[T.Biotechnology]               -3.881518  1.024802e-08
# C(Primary_activity)[T.Precious metals & mineral... -6.165415  1.269855e-08
# C(Primary_activity)[T.Insurance]                   -5.640626  2.347996e-08
# C(Primary_activity)[T.Passenger airlines]          -9.450943  3.689954e-08
#
# All feature coefficients sorted by absolute value:
#                                                             coef        pvalue
# C(Countries)[T.Denmark]                             1.312583e+16           NaN
# C(Primary_activity)[T.Other renewable energy eq... -1.312583e+16           NaN
# C(Primary_activity)[T.Cement]                       7.853379e+14  6.535587e-01
# C(Countries)[T.Mexico]                             -7.853379e+14  6.535587e-01
# C(Primary_activity)[T.Passenger airlines]          -9.450943e+00  3.689954e-08
# ...                                                          ...           ...
# C(Primary_activity)[T.Real estate services]         1.635945e-01  9.240445e-01
# C(Primary_activity)[T.Discretionary delivery re...  1.029003e-01  9.325106e-01
# C(Primary_activity)[T.Residential building cons... -8.696315e-02  9.050135e-01
# slog_totalAssets_USD                                2.699128e-02  5.312500e-01
# C(Primary_activity)[T.Agricultural chemicals]       7.220402e-03  9.966647e-01
#
# [124 rows x 2 columns]

# %%
metrics_text_log = (
    f"R²(log):   {r2_log_pct:.2f}%\n"
    f"R²(orig):  {r2_pct:.2f}%\n"
    f"MAPE:      {mape_orig:.2f}%\n"
    f"MAPE(log): {mape_log:.2f}%\n"
    f"MAE(log):  {mae_log:.2f}\n"
    f"RMSLE:     {rmsle:.2f}\n"
    f"RMSE:      {rmse_orig:.2f}\n"
    f"MAE:       {mae_orig:.2f}"
)

fig, ax = plt.subplots(figsize=(9.5, 6))  # Wider to make room for the box

if hasattr(y_pred_log, "nunique"):
    multiple_vals = y_pred_log.nunique() > 1
else:
    multiple_vals = len(set(y_pred_log)) > 1

if multiple_vals:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=ax, color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    ax.plot([], [], ' ', label="Predicted: constant value (no KDE)")

ax.set_title("End of Life Optimized Model: signed log(Scope 3 Emissions)")
ax.set_xlabel("signed log(metric tons + 1)")
ax.set_ylabel("Density")
ax.legend()

# Place metrics box outside plot to the right
fig.text(
    0.82, 0.75, metrics_text_log,
    va='top', ha='left',
    fontsize=12, bbox=dict(boxstyle='round', alpha=0.15)
)

plt.subplots_adjust(right=0.8)  # Make sure there's room for the box
fig.savefig("end_of_life_scope3_log_density.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Metrics Table for End of Life Treatment of Sold Products

# %%
metrics_dicts = [
    null_model_metrics,
    two_level_model_metrics,
    three_level_model_metrics,
    full_model_metrics,
    optimized_model_metrics
]

for metrics, train, test in zip(
        metrics_dicts,
        [train_df, train_df, train_df, train_df, train_df],
        [test_df, test_df, test_df, test_df, test_df]):
    
    metrics["# Obs (train)"] = len(train)
    metrics["# Obs (test)"] = len(test)
    metrics["# Obs (train/test)"] = f"{len(train)}/{len(test)}"

metrics_df = pd.DataFrame(metrics_dicts)

# Ensure all relevant columns are ordered and present
desired_order = [
    "Model", "R2_log", "R2_orig", "RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "# Obs (train/test)"
]


# Ensure MAE_log is present, fill with NaN if missing
if "MAE_log" not in metrics_df.columns:
    metrics_df["MAE_log"] = np.nan

metrics_df = metrics_df[[col for col in desired_order if col in metrics_df.columns]]

metrics_df_display = metrics_df.copy()
if "R2_log" in metrics_df_display.columns:
    metrics_df_display["R2_log"] = (metrics_df_display["R2_log"] * 100).map("{:.2f}%".format)
if "R2_orig" in metrics_df_display.columns:
    metrics_df_display["R2_orig"] = (metrics_df_display["R2_orig"] * 100).map("{:.2f}%".format)
for col in ["RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "MAPE(log)"]:
    if col in metrics_df_display.columns:
        metrics_df_display[col] = metrics_df_display[col].map("{:.2f}".format)

from IPython.display import display
display(metrics_df_display)
# Out:
#                                      Model  R2_log R2_orig        RMSE  \
# 0                                Null (RI)  -1.20%  -4.45%  2183339.11
# 1                           2-level (RI+S)  -0.99%  -4.44%  2183220.46
# 2  3-level (Primary Activity/Account/Year)  19.48%  -3.60%  2174397.67
# 3                               Full Model  69.17%   0.32%  2132828.65
# 4                                Optimized  68.41%  -0.59%  2142617.06
#
#          MAE MAE_log RMSLE      MAPE # Obs (train/test)
# 0  462113.77    2.51  3.07  46647.66           1537/342
# 1  462009.89    2.50  3.06  48151.73           1537/342
# 2  454791.09    2.19  2.74  13861.09           1537/342
# 3  404652.37    1.31  1.69    787.74           1537/342
# 4  418074.98    1.33  1.71    973.84           1537/342
