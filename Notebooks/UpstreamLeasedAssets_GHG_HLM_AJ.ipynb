# %% [markdown]
# # GHG HLM on Scope 3 source Upstream Leased Assets

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_log_error, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GroupShuffleSplit
from scipy.stats import zscore
import scipy.stats as stats
from sklearn.feature_selection import mutual_info_regression
from sklearn.impute import SimpleImputer
import warnings
from statsmodels.regression.mixed_linear_model import MixedLM


#read in dataset from GHG_post_outliers data set
upstream_leased_assets=pd.read_csv('/Users/amberjensen/Desktop/GHG_Emissions_Project/upstream_leased_assets.csv')

# %%
#check for info
upstream_leased_assets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1172 entries, 0 to 1171
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_name                1172 non-null   object
#  1   account_id                  1172 non-null   int64
#  2   Year                        1172 non-null   int64
#  3   incorporated_country        1172 non-null   object
#  4   Primary activity            1172 non-null   object
#  5   Primary sector              1172 non-null   object
#  6   Market_Cap_USD              1038 non-null   float64
#  7   Third_party_verification    1169 non-null   object
#  8   Revenue_USD                 1044 non-null   float64
#  9   ebitda_USD                  1044 non-null   float64
#  10  grossProfit_USD             1044 non-null   float64
#  11  netIncome_USD               1044 non-null   float64
#  12  cashAndCashEquivalents_USD  1044 non-null   float64
#  13  shortTermInvestments_USD    1044 non-null   float64
#  14  longTermInvestments_USD     1044 non-null   float64
#  15  totalAssets_USD             1044 non-null   float64
#  16  totalLiabilities_USD        1044 non-null   float64
#  17  totalInvestments_USD        1044 non-null   float64
#  18  totalDebt_USD               1044 non-null   float64
#  19  totalEquity_USD             1044 non-null   float64
#  20  Scope_3_emissions_type      1172 non-null   object
#  21  Scope_3_emissions_amount    1172 non-null   float64
#  22  scope_1_2_emissions_amount  1169 non-null   float64
#  23  Year_sq                     1172 non-null   int64
# dtypes: float64(15), int64(3), object(6)
# memory usage: 219.9+ KB

# %%
#show a df for upstream_leased_assets
upstream_leased_assets.head()
# Out:
#                account_name  account_id  Year incorporated_country  \
# 0  Associated British Foods        1085  2018       United Kingdom
# 1               AstraZeneca        1104  2018       United Kingdom
# 2                  BT Group        2377  2018       United Kingdom
# 3  Domino's Pizza Group plc        4835  2018       United Kingdom
# 4                Drax Group        4906  2018       United Kingdom
#
#               Primary activity  \
# 0               Apparel stores
# 1              Pharmaceuticals
# 2  Telecommunications services
# 3                    Fast food
# 4          Non-CCGT generation
#
#                                      Primary sector  Market_Cap_USD  \
# 0                              Discretionary retail    2.051429e+10
# 1                                  Biotech & pharma    7.441091e+10
# 2  Media, telecommunications & data center services    2.997109e+10
# 3                        Bars, hotels & restaurants    1.451019e+09
# 4                          Thermal power generation    1.845032e+09
#
#                             Third_party_verification   Revenue_USD  \
# 0  Third-party verification or assurance process ...  1.977898e+10
# 1  Third-party verification or assurance process ...  2.209000e+10
# 2  Third-party verification or assurance process ...  2.975356e+10
# 3           No third-party verification or assurance  6.785610e+08
# 4                            Question not applicable  5.370830e+09
#
#      ebitda_USD  ...  longTermInvestments_USD  totalAssets_USD  \
# 0  2.363470e+09  ...              342900000.0     1.738884e+10
# 1  7.165000e+09  ...              113000000.0     6.065100e+10
# 2  9.392920e+09  ...              128270000.0     5.878449e+10
# 3  1.296670e+08  ...              113157000.0     5.060950e+08
# 4  4.086860e+08  ...              697357000.0     5.753481e+09
#
#    totalLiabilities_USD  totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0          5.582920e+09           381000000.0   9.880600e+08     1.180592e+10
# 1          4.660700e+10           922000000.0   1.911300e+10     1.404400e+10
# 2          4.587240e+10           128270000.0   2.143252e+10     1.291209e+10
# 3          5.029200e+08            63119000.0   2.896870e+08     3.175000e+06
# 4          3.504311e+09             3048000.0   7.722870e+08     2.249170e+09
#
#    Scope_3_emissions_type  Scope_3_emissions_amount  \
# 0  Upstream leased assets                    4300.0
# 1  Upstream leased assets                   26623.0
# 2  Upstream leased assets                   56000.0
# 3  Upstream leased assets                     386.0
# 4  Upstream leased assets                     987.0
#
#    scope_1_2_emissions_amount  Year_sq
# 0                2.801746e+06  4072324
# 1                7.072529e+05  4072324
# 2                4.572819e+05  4072324
# 3                1.112175e+04  4072324
# 4                1.085401e+07  4072324
#
# [5 rows x 24 columns]

# %%
#define a list of numeric columns
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD',
       'grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD',
       'shortTermInvestments_USD', 'longTermInvestments_USD',
       'totalAssets_USD', 'totalLiabilities_USD', 'totalInvestments_USD',
       'totalDebt_USD', 'totalEquity_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount']

# %%
#plot the heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(upstream_leased_assets[numeric_cols].corr(), annot=True, annot_kws={"size": 8})
plt.show()

# %%
#correlation matrix
upstream_leased_assets[numeric_cols].corr()
# Out:
#                             Market_Cap_USD  Revenue_USD  ebitda_USD  \
# Market_Cap_USD                    1.000000     0.130869    0.174910
# Revenue_USD                       0.130869     1.000000    0.631240
# ebitda_USD                        0.174910     0.631240    1.000000
# grossProfit_USD                   0.133316     0.733677    0.641015
# netIncome_USD                     0.184076     0.583844    0.885028
# cashAndCashEquivalents_USD        0.011718     0.097664    0.175303
# shortTermInvestments_USD          0.005155     0.160199    0.054512
# longTermInvestments_USD           0.005045     0.173133    0.164563
# totalAssets_USD                   0.025716     0.228902    0.305127
# totalLiabilities_USD              0.016256     0.193964    0.243113
# totalInvestments_USD              0.007558     0.183656    0.168467
# totalDebt_USD                     0.046520     0.297682    0.497123
# totalEquity_USD                   0.138208     0.586150    0.762180
# Scope_3_emissions_amount          0.001042     0.110729    0.102460
# scope_1_2_emissions_amount       -0.002232     0.123098    0.129575
#
#                             grossProfit_USD  netIncome_USD  \
# Market_Cap_USD                     0.133316       0.184076
# Revenue_USD                        0.733677       0.583844
# ebitda_USD                         0.641015       0.885028
# grossProfit_USD                    1.000000       0.661073
# netIncome_USD                      0.661073       1.000000
# cashAndCashEquivalents_USD         0.213648       0.225024
# shortTermInvestments_USD           0.372985       0.117445
# longTermInvestments_USD            0.405541       0.245337
# totalAssets_USD                    0.438838       0.343482
# totalLiabilities_USD               0.399795       0.286411
# totalInvestments_USD               0.425135       0.245844
# totalDebt_USD                      0.400461       0.432652
# totalEquity_USD                    0.672611       0.707538
# Scope_3_emissions_amount           0.026681      -0.001419
# scope_1_2_emissions_amount        -0.003314       0.037083
#
#                             cashAndCashEquivalents_USD  \
# Market_Cap_USD                                0.011718
# Revenue_USD                                   0.097664
# ebitda_USD                                    0.175303
# grossProfit_USD                               0.213648
# netIncome_USD                                 0.225024
# cashAndCashEquivalents_USD                    1.000000
# shortTermInvestments_USD                      0.224985
# longTermInvestments_USD                       0.761252
# totalAssets_USD                               0.809054
# totalLiabilities_USD                          0.779534
# totalInvestments_USD                          0.738828
# totalDebt_USD                                 0.637800
# totalEquity_USD                               0.473075
# Scope_3_emissions_amount                     -0.005037
# scope_1_2_emissions_amount                   -0.018958
#
#                             shortTermInvestments_USD  longTermInvestments_USD  \
# Market_Cap_USD                              0.005155                 0.005045
# Revenue_USD                                 0.160199                 0.173133
# ebitda_USD                                  0.054512                 0.164563
# grossProfit_USD                             0.372985                 0.405541
# netIncome_USD                               0.117445                 0.245337
# cashAndCashEquivalents_USD                  0.224985                 0.761252
# shortTermInvestments_USD                    1.000000                 0.641828
# longTermInvestments_USD                     0.641828                 1.000000
# totalAssets_USD                             0.442981                 0.900735
# totalLiabilities_USD                        0.454099                 0.819379
# totalInvestments_USD                        0.711417                 0.985005
# totalDebt_USD                               0.105340                 0.631318
# totalEquity_USD                             0.311928                 0.541656
# Scope_3_emissions_amount                   -0.006515                -0.023105
# scope_1_2_emissions_amount                 -0.025896                -0.040948
#
#                             totalAssets_USD  totalLiabilities_USD  \
# Market_Cap_USD                     0.025716              0.016256
# Revenue_USD                        0.228902              0.193964
# ebitda_USD                         0.305127              0.243113
# grossProfit_USD                    0.438838              0.399795
# netIncome_USD                      0.343482              0.286411
# cashAndCashEquivalents_USD         0.809054              0.779534
# shortTermInvestments_USD           0.442981              0.454099
# longTermInvestments_USD            0.900735              0.819379
# totalAssets_USD                    1.000000              0.948805
# totalLiabilities_USD               0.948805              1.000000
# totalInvestments_USD               0.883847              0.820893
# totalDebt_USD                      0.759410              0.696207
# totalEquity_USD                    0.640394              0.555994
# Scope_3_emissions_amount          -0.005430             -0.015378
# scope_1_2_emissions_amount        -0.011172             -0.019077
#
#                             totalInvestments_USD  totalDebt_USD  \
# Market_Cap_USD                          0.007558       0.046520
# Revenue_USD                             0.183656       0.297682
# ebitda_USD                              0.168467       0.497123
# grossProfit_USD                         0.425135       0.400461
# netIncome_USD                           0.245844       0.432652
# cashAndCashEquivalents_USD              0.738828       0.637800
# shortTermInvestments_USD                0.711417       0.105340
# longTermInvestments_USD                 0.985005       0.631318
# totalAssets_USD                         0.883847       0.759410
# totalLiabilities_USD                    0.820893       0.696207
# totalInvestments_USD                    1.000000       0.575931
# totalDebt_USD                           0.575931       1.000000
# totalEquity_USD                         0.544791       0.644195
# Scope_3_emissions_amount               -0.017366       0.035608
# scope_1_2_emissions_amount             -0.039018       0.070045
#
#                             totalEquity_USD  Scope_3_emissions_amount  \
# Market_Cap_USD                     0.138208                  0.001042
# Revenue_USD                        0.586150                  0.110729
# ebitda_USD                         0.762180                  0.102460
# grossProfit_USD                    0.672611                  0.026681
# netIncome_USD                      0.707538                 -0.001419
# cashAndCashEquivalents_USD         0.473075                 -0.005037
# shortTermInvestments_USD           0.311928                 -0.006515
# longTermInvestments_USD            0.541656                 -0.023105
# totalAssets_USD                    0.640394                 -0.005430
# totalLiabilities_USD               0.555994                 -0.015378
# totalInvestments_USD               0.544791                 -0.017366
# totalDebt_USD                      0.644195                  0.035608
# totalEquity_USD                    1.000000                  0.122093
# Scope_3_emissions_amount           0.122093                  1.000000
# scope_1_2_emissions_amount         0.130749                  0.292152
#
#                             scope_1_2_emissions_amount
# Market_Cap_USD                               -0.002232
# Revenue_USD                                   0.123098
# ebitda_USD                                    0.129575
# grossProfit_USD                              -0.003314
# netIncome_USD                                 0.037083
# cashAndCashEquivalents_USD                   -0.018958
# shortTermInvestments_USD                     -0.025896
# longTermInvestments_USD                      -0.040948
# totalAssets_USD                              -0.011172
# totalLiabilities_USD                         -0.019077
# totalInvestments_USD                         -0.039018
# totalDebt_USD                                 0.070045
# totalEquity_USD                               0.130749
# Scope_3_emissions_amount                      0.292152
# scope_1_2_emissions_amount                    1.000000

# %%
#drop columns due to collinearity, keeping total
upstream_leased_assets=upstream_leased_assets.drop(columns=['longTermInvestments_USD', 'totalInvestments_USD', 'cashAndCashEquivalents_USD',
                                                            'totalLiabilities_USD', 'totalDebt_USD', 'netIncome_USD',
                                                            "account_name", "Third_party_verification", "Scope_3_emissions_type"])

# %%
upstream_leased_assets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1172 entries, 0 to 1171
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  1172 non-null   int64
#  1   Year                        1172 non-null   int64
#  2   incorporated_country        1172 non-null   object
#  3   Primary activity            1172 non-null   object
#  4   Primary sector              1172 non-null   object
#  5   Market_Cap_USD              1038 non-null   float64
#  6   Revenue_USD                 1044 non-null   float64
#  7   ebitda_USD                  1044 non-null   float64
#  8   grossProfit_USD             1044 non-null   float64
#  9   shortTermInvestments_USD    1044 non-null   float64
#  10  totalAssets_USD             1044 non-null   float64
#  11  totalEquity_USD             1044 non-null   float64
#  12  Scope_3_emissions_amount    1172 non-null   float64
#  13  scope_1_2_emissions_amount  1169 non-null   float64
#  14  Year_sq                     1172 non-null   int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 137.5+ KB

# %%
sns.boxplot(upstream_leased_assets)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# copy dataframe
upstream_leased_assets_no_transform = upstream_leased_assets.copy()
# Change 'incorporated_country' to 'Countries' in upstream_leased_assets dataframe
upstream_leased_assets_no_transform = upstream_leased_assets_no_transform.rename(columns={'incorporated_country': 'Countries',
                                                       'Primary activity': 'Primary_activity',
                                                        'Primary sector': 'Primary_sector'})

print(upstream_leased_assets_no_transform.info())
upstream_leased_assets_no_transform.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1172 entries, 0 to 1171
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  1172 non-null   int64
#  1   Year                        1172 non-null   int64
#  2   Countries                   1172 non-null   object
#  3   Primary_activity            1172 non-null   object
#  4   Primary_sector              1172 non-null   object
#  5   Market_Cap_USD              1038 non-null   float64
#  6   Revenue_USD                 1044 non-null   float64
#  7   ebitda_USD                  1044 non-null   float64
#  8   grossProfit_USD             1044 non-null   float64
#  9   shortTermInvestments_USD    1044 non-null   float64
#  10  totalAssets_USD             1044 non-null   float64
#  11  totalEquity_USD             1044 non-null   float64
#  12  Scope_3_emissions_amount    1172 non-null   float64
#  13  scope_1_2_emissions_amount  1169 non-null   float64
#  14  Year_sq                     1172 non-null   int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 137.5+ KB
# None
#    account_id  Year       Countries             Primary_activity  \
# 0        1085  2018  United Kingdom               Apparel stores
# 1        1104  2018  United Kingdom              Pharmaceuticals
# 2        2377  2018  United Kingdom  Telecommunications services
# 3        4835  2018  United Kingdom                    Fast food
# 4        4906  2018  United Kingdom          Non-CCGT generation
#
#                                      Primary_sector  Market_Cap_USD  \
# 0                              Discretionary retail    2.051429e+10
# 1                                  Biotech & pharma    7.441091e+10
# 2  Media, telecommunications & data center services    2.997109e+10
# 3                        Bars, hotels & restaurants    1.451019e+09
# 4                          Thermal power generation    1.845032e+09
#
#     Revenue_USD    ebitda_USD  grossProfit_USD  shortTermInvestments_USD  \
# 0  1.977898e+10  2.363470e+09     4.551680e+09              3.810000e+07
# 1  2.209000e+10  7.165000e+09     1.715400e+10              8.490000e+08
# 2  2.975356e+10  9.392920e+09     1.954276e+10              4.081780e+09
# 3  6.785610e+08  1.296670e+08     2.834640e+08             -5.003800e+07
# 4  5.370830e+09  4.086860e+08     8.120380e+08             -6.943090e+08
#
#    totalAssets_USD  totalEquity_USD  Scope_3_emissions_amount  \
# 0     1.738884e+10     1.180592e+10                    4300.0
# 1     6.065100e+10     1.404400e+10                   26623.0
# 2     5.878449e+10     1.291209e+10                   56000.0
# 3     5.060950e+08     3.175000e+06                     386.0
# 4     5.753481e+09     2.249170e+09                     987.0
#
#    scope_1_2_emissions_amount  Year_sq
# 0                2.801746e+06  4072324
# 1                7.072529e+05  4072324
# 2                4.572819e+05  4072324
# 3                1.112175e+04  4072324
# 4                1.085401e+07  4072324

# %%
upstream_leased_assets_no_transform['Primary_sector'].value_counts()
# Out:
# Primary_sector
# Financial services                                    151
# Electrical & electronic equipment                     142
# Chemicals                                             110
# Construction                                           66
# Specialized professional services                      62
# Media, telecommunications & data center services       61
# Biotech & pharma                                       59
# Food & beverage processing                             58
# Trading, wholesale, distribution, rental & leasing     45
# Discretionary retail                                   30
# Medical equipment & supplies                           28
# Other services                                         24
# IT & software development                              22
# Powered machinery                                      19
# Energy utility networks                                18
# Thermal power generation                               16
# Metal smelting, refining & forming                     15
# Metal products manufacturing                           15
# Industrial support services                            15
# Entertainment facilities                               15
# Rail transport                                         15
# Print & publishing services                            14
# Land & property ownership & development                13
# Oil & gas storage & transportation                     12
# Non-energy utilities                                   12
# Paper products & packaging                             10
# Bars, hotels & restaurants                              9
# Oil & gas extraction & production                       9
# Textiles & fabric goods                                 9
# Air transport                                           8
# Health care provision                                   8
# Leisure & home manufacturing                            8
# Commercial & consumer services                          7
# Transportation equipment                                7
# Tobacco                                                 6
# Wood & rubber products                                  6
# Renewable power generation                              6
# Web & marketing services                                6
# 0                                                       5
# Oil & gas retailing                                     5
# Intermodal transport & logistics                        5
# Apparel design                                          4
# Renewable energy equipment                              4
# Convenience retail                                      3
# Light manufacturing                                     2
# Road transport                                          2
# Marine transport                                        2
# Wood & paper materials                                  1
# Plastic product manufacturing                           1
# Metallic mineral mining                                 1
# Cement & concrete                                       1
# Name: count, dtype: int64

# %%
upstream_leased_assets_no_transform['Primary_activity'].value_counts().head(20)
# Out:
# Primary_activity
# Insurance                                61
# Telecommunications services              59
# Other professional services              58
# Pharmaceuticals                          54
# Electronic components                    50
# Banks                                    45
# Other base chemicals                     37
# Non-residential building construction    32
# Electronic equipment                     32
# Personal care & household products       32
# REIT                                     30
# Dealers, wholesalers & distributors      24
# Software                                 22
# Electrical equipment                     21
# Alcoholic beverages                      21
# Other food processing                    20
# Communications equipment                 19
# Specialty chemicals                      18
# Inorganic base chemicals                 17
# Medical equipment                        16
# Name: count, dtype: int64

# %%
# Looking at missing data
print(upstream_leased_assets_no_transform.isnull().mean().sort_values(ascending=False).round(3) * 100)
# Out:
# Market_Cap_USD                11.4
# Revenue_USD                   10.9
# ebitda_USD                    10.9
# grossProfit_USD               10.9
# shortTermInvestments_USD      10.9
# totalAssets_USD               10.9
# totalEquity_USD               10.9
# scope_1_2_emissions_amount     0.3
# account_id                     0.0
# Year                           0.0
# Countries                      0.0
# Primary_activity               0.0
# Primary_sector                 0.0
# Scope_3_emissions_amount       0.0
# Year_sq                        0.0
# dtype: float64

# %% [markdown]
# Apply signed log transformation and split data by company and year into train_df (2018-2022) and test_df (2023):

# %%
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD', 'grossProfit_USD', 'shortTermInvestments_USD', 'totalAssets_USD',
                'totalEquity_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount'
]
required_cols = [
    'account_id', 'Year', 'Year_sq', 'Countries', 'Primary_activity', 'Primary_sector'
] + numeric_cols

# --- Prepare Data ---
df = upstream_leased_assets_no_transform[required_cols].dropna()

# --- Signed log transform ---
def signed_log(x):
    return np.sign(x) * np.log(np.abs(x) + 1)

for col in numeric_cols:
    df[f'slog_{col}'] = signed_log(df[col])

# --- Company-level split by year ---
train_df = df[df['Year'].between(2018, 2022)].copy()
test_df  = df[df['Year'] == 2023].copy()

# Keep only companies present in training
valid_companies = set(train_df['account_id'].unique())
test_df = test_df[test_df['account_id'].isin(valid_companies)].copy()

# --- Remove rare categories in Primary_activity and Countries (≤2 rows) to prevent singular matrices ---
for col in ['Primary_activity', 'Countries']:
    value_counts = train_df[col].value_counts()
    allowed = value_counts[value_counts > 2].index
    train_df = train_df[train_df[col].isin(allowed)].copy()
    test_df = test_df[test_df[col].isin(allowed)].copy()

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (779, 24)
# Test shape: (158, 24)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 779 entries, 0 to 915
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       779 non-null    int64
#  1   Year                             779 non-null    int64
#  2   Year_sq                          779 non-null    int64
#  3   Countries                        779 non-null    object
#  4   Primary_activity                 779 non-null    object
#  5   Primary_sector                   779 non-null    object
#  6   Market_Cap_USD                   779 non-null    float64
#  7   Revenue_USD                      779 non-null    float64
#  8   ebitda_USD                       779 non-null    float64
#  9   grossProfit_USD                  779 non-null    float64
#  10  shortTermInvestments_USD         779 non-null    float64
#  11  totalAssets_USD                  779 non-null    float64
#  12  totalEquity_USD                  779 non-null    float64
#  13  Scope_3_emissions_amount         779 non-null    float64
#  14  scope_1_2_emissions_amount       779 non-null    float64
#  15  slog_Market_Cap_USD              779 non-null    float64
#  16  slog_Revenue_USD                 779 non-null    float64
#  17  slog_ebitda_USD                  779 non-null    float64
#  18  slog_grossProfit_USD             779 non-null    float64
#  19  slog_shortTermInvestments_USD    779 non-null    float64
#  20  slog_totalAssets_USD             779 non-null    float64
#  21  slog_totalEquity_USD             779 non-null    float64
#  22  slog_Scope_3_emissions_amount    779 non-null    float64
#  23  slog_scope_1_2_emissions_amount  779 non-null    float64
# dtypes: float64(18), int64(3), object(3)
# memory usage: 152.1+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, 917 to 1170
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       158 non-null    int64
#  1   Year                             158 non-null    int64
#  2   Year_sq                          158 non-null    int64
#  3   Countries                        158 non-null    object
#  4   Primary_activity                 158 non-null    object
#  5   Primary_sector                   158 non-null    object
#  6   Market_Cap_USD                   158 non-null    float64
#  7   Revenue_USD                      158 non-null    float64
#  8   ebitda_USD                       158 non-null    float64
#  9   grossProfit_USD                  158 non-null    float64
#  10  shortTermInvestments_USD         158 non-null    float64
#  11  totalAssets_USD                  158 non-null    float64
#  12  totalEquity_USD                  158 non-null    float64
#  13  Scope_3_emissions_amount         158 non-null    float64
#  14  scope_1_2_emissions_amount       158 non-null    float64
#  15  slog_Market_Cap_USD              158 non-null    float64
#  16  slog_Revenue_USD                 158 non-null    float64
#  17  slog_ebitda_USD                  158 non-null    float64
#  18  slog_grossProfit_USD             158 non-null    float64
#  19  slog_shortTermInvestments_USD    158 non-null    float64
#  20  slog_totalAssets_USD             158 non-null    float64
#  21  slog_totalEquity_USD             158 non-null    float64
#  22  slog_Scope_3_emissions_amount    158 non-null    float64
#  23  slog_scope_1_2_emissions_amount  158 non-null    float64
# dtypes: float64(18), int64(3), object(3)
# memory usage: 30.9+ KB

# %%
# Check number of 0's in train and test df's
print((train_df == 0).sum().sum())
print((test_df == 0).sum().sum())
# Out:
# 262
# 82

# %% [markdown]
# ## Upstream Leased Assets Null Mixed-Effects Model
#
# Null mixed-effects model (random intercept only) to predict log-transformed Scope 3 emissions. The model serves as a baseline, capturing only the average emission level for each company, without incorporating any explanatory variables, and quantifies the improvement gained by including additional features and structure. The model is trained on 2018–2022 data and evaluated on a test set from 2023.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies
# - Fixed Effects:
#     - Intercept only (no predictors)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE NULL MODEL (random intercept only) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    null_model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ 1",
        train_df,
        groups=train_df["account_id"]
    )
    null_result = null_model.fit(method="lbfgs")

if not null_result.converged:
    print("WARNING: Null model did not fully converge.")

print(null_result.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_null'] = null_result.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_null']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_null'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics text
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[0], color='gray')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Null Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[1], color='gray')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Null Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Null Model Predicted")
plt.xscale("log")
plt.title("Null Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
null_model_metrics = {
    "Model": "Null (RI)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "Random intercept only"
}
# Out:
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 779     Method:             REML
# No. Groups:       230     Scale:              0.7119
# Min. group size:  1       Log-Likelihood:     -1330.8600
# Max. group size:  5       Converged:          Yes
# Mean group size:  3.4
# ------------------------------------------------------------------------------
#                  Coef.     Std.Err.       z        P>|z|     [0.025     0.975]
# ------------------------------------------------------------------------------
# Intercept        7.846        0.154     50.935     0.000      7.544      8.148
# Group Var        5.166        0.722
# ==========================================================================
#
# R²(log):    -0.02%
# R²(orig):   -6.75%
# MAPE:       3789.40%
# MAPE(log):  38.38%
# MAE(log):   1.88
# RMSLE:      2.27
# RMSE:       75880.74
# MAE:        20907.15

# %% [markdown]
# ## Upstream Leased Assets Two-Level Mixed-Effects Model
#
# Two-level hierarchical linear mixed-effects model to predict log-transformed Scope 3 emissions at the company level. The model is fit to training data (from 2018–2022), and predictions are evaluated on a test set (from 2023).  This model provides a baseline for including time trends and company-level variability.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies.<br>
# - Fixed Effects:
#     - Year (numeric)
#     - Year squared ('Year_sq', quadratic time trend)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- Check group sizes ---
group_sizes = train_df.groupby('account_id').size()
print("Two-Level Model: Company/year group size summary:")
print(group_sizes.describe())

# --- FIT THE TWO-LEVEL MODEL (random intercept, +Year, +Year_sq) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ Year + Year_sq",
        train_df,
        groups=train_df["account_id"],
        re_formula="1"
    )
    result_twolevel = model.fit(method="lbfgs")

if not result_twolevel.converged:
    print("WARNING: Two-level mixed model did not fully converge.")

print(result_twolevel.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_twolevel.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_mixed']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='orange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Two-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='orange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Two-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="orange", alpha=0.5, label="Two-Level Model Predicted")
plt.xscale("log")
plt.title("Two-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
two_level_model_metrics = {
    "Model": "2-level (RI+S)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "+Year, Year_sq"
}
# Out:
# Two-Level Model: Company/year group size summary:
# count    230.000000
# mean       3.386957
# std        1.547728
# min        1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# dtype: float64
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 779     Method:             REML
# No. Groups:       230     Scale:              0.6973
# Min. group size:  1       Log-Likelihood:     -1329.8929
# Max. group size:  5       Converged:          Yes
# Mean group size:  3.4
# ---------------------------------------------------------------------------
#                  Coef.      Std.Err.    z     P>|z|     [0.025      0.975]
# ---------------------------------------------------------------------------
# Intercept      -56358.247  77224.787  -0.730  0.466  -207716.047  94999.553
# Year               55.895     76.458   0.731  0.465      -93.960    205.751
# Year_sq            -0.014      0.019  -0.732  0.464       -0.051      0.023
# Group Var           5.167      0.729
# ==========================================================================
#
# R²(log):    -2.62%
# R²(orig):   -7.28%
# MAPE:       2712.54%
# MAPE(log):  36.93%
# MAE(log):   1.89
# RMSLE:      2.30
# RMSE:       76066.82
# MAE:        20936.08

# %% [markdown]
# ## Upstream Leased Assets Three-Level Mixed-Effects Model
#
# A three-level hierarchical linear mixed-effects model is used to predict log-transformed Scope 3 emissions. It takes into account differences between primary activity, differences between companies, and changes over time. The model is trained using data from 2018 to 2022, and then tested on new data from 2023. This model provides insight on how emissions are influenced by primary activity, by individual companies, by financial and emissions factors, and by trends over time.
#
# Model Structure:
#
# - Level 3 (Primary Activity):<br>
#     - Random intercept and random slope for Year for each primary activity ('Primary_activity'), capturing baseline primary activity and primary activity-specific time trends.<br>
# - Level 2 (Account/Company):
#     - Random intercept for each company ('account_id'), capturing company-level deviations within each primary activity.
# - Level 1 (Yearly Observations):
#     - Repeated annual observations within each company.
#
# - Fixed Effects:
#     - Signed log-transformed market cap ('slog_Market_Cap_USD')
#     - Signed log-transformed revenue ('slog_Revenue_USD')
#     - Signed log-transformed EBITDA ('slog_ebitda_USD')
#     - Signed log-transformed Scope 1 & 2 emissions ('slog_scope_1_2_emissions_amount')

# %%
# --- Ensure grouping/categorical variables are string ---
for col in ['Countries', 'account_id', 'Primary_activity', 'Primary_sector']:
    train_df[col] = train_df[col].astype(str)
    test_df[col] = test_df[col].astype(str)

# --- Center the Year variable ---
year_mean = train_df['Year'].mean()
train_df['Year_centered'] = train_df['Year'] - year_mean
test_df['Year_centered'] = test_df['Year'] - year_mean

# --- Ensure log-transformed target exists ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE 3-LEVEL MIXED MODEL with Primary_activity as Level 3 group ---
vc = {'account_id': '0 + C(account_id)'}  # Level 2: account_id random intercept

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model_3level = MixedLM.from_formula(
        'log_Scope_3_emissions_amount ~ slog_Market_Cap_USD + slog_Revenue_USD + slog_ebitda_USD + slog_scope_1_2_emissions_amount',
        groups='Primary_activity',
        re_formula='~Year_centered',
        vc_formula=vc,
        data=train_df
    )
    result_3level = model_3level.fit(method="lbfgs", maxiter=1000)

if not result_3level.converged:
    print("WARNING: Three-level mixed model did not fully converge.")

print(result_3level.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_3level.predict(test_df)

# --- Compute back-transformed values ---
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])

# --- Robust Mask for finite values everywhere ---
mask = (
    np.isfinite(test_df['log_Scope_3_emissions_amount']) &
    np.isfinite(test_df['predicted_mixed']) &
    np.isfinite(test_df['Reported_Scope_3']) &
    np.isfinite(test_df['Predicted_Scope_3'])
)
test_df = test_df.loc[mask].copy()

y_true_log = test_df['log_Scope_3_emissions_amount'].values
y_pred_log = test_df['predicted_mixed'].values
y_true = test_df['Reported_Scope_3'].values
y_pred = test_df['Predicted_Scope_3'].values

# Final defensive check and diagnostics
arrays = {
    "y_true_log": y_true_log,
    "y_pred_log": y_pred_log,
    "y_true": y_true,
    "y_pred": y_pred,
}
for arr_name, arr in arrays.items():
    if not np.all(np.isfinite(arr)):
        print(f"ERROR: {arr_name} contains non-finite values!")
        print(f"Non-finite indices: {np.where(~np.isfinite(arr))[0]}")
        print(f"Values: {arr[~np.isfinite(arr)]}")
        raise ValueError(f"{arr_name} contains infs or NaNs after masking!")

# --- METRICS ---
mae_log = mean_absolute_error(y_true_log, y_pred_log)
nonzero_mask = y_true_log != 0
if np.any(nonzero_mask):
    mape_log = np.mean(np.abs((y_true_log[nonzero_mask] - y_pred_log[nonzero_mask]) / y_true_log[nonzero_mask])) * 100
else:
    mape_log = np.nan

r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)

metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
if len(np.unique(y_pred_log)) > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Three-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()
axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

if len(np.unique(y_pred)) > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Three-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()
axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Filter strictly positive values for histogram (log x-axis requires >0)
y_true_pos = y_true[y_true > 0]
y_pred_pos = y_pred[y_pred > 0]

if y_true_pos.size > 0 and y_pred_pos.size > 0:
    min_val = min(y_true_pos.min(), y_pred_pos.min())
    max_val = max(y_true_pos.max(), y_pred_pos.max())
    if min_val == max_val:
        print("Skipping histogram: Only one unique positive value present.")
    else:
        log_bins = np.logspace(np.log10(min_val), np.log10(max_val), 100)

        plt.figure(figsize=(8, 5))
        sns.histplot(y_true_pos, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
        sns.histplot(y_pred_pos, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Three-Level Model Predicted")
        plt.xscale("log")
        plt.title("Three-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
        plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
        plt.ylabel("Density")
        plt.legend()
        plt.tight_layout()
        plt.show()
else:
    print("Skipping histogram: Not enough positive values in y_true or y_pred for log-scale histogram.")

# --- RETURN METRICS FOR SUMMARY TABLE ---
three_level_model_metrics = {
    "Model": "3-level (Primary Activity/Account/Year)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,
    "MAPE(log)": mape_log,
}
# Out:
#                      Mixed Linear Model Regression Results
# ================================================================================
# Model:              MixedLM   Dependent Variable:   log_Scope_3_emissions_amount
# No. Observations:   779       Method:               REML
# No. Groups:         70        Scale:                0.6380
# Min. group size:    3         Log-Likelihood:       -1314.1191
# Max. group size:    48        Converged:            Yes
# Mean group size:    11.1
# --------------------------------------------------------------------------------
#                                      Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# --------------------------------------------------------------------------------
# Intercept                            -5.603    2.441 -2.296 0.022 -10.387 -0.819
# slog_Market_Cap_USD                   0.148    0.088  1.690 0.091  -0.024  0.321
# slog_Revenue_USD                      0.402    0.123  3.266 0.001   0.161  0.644
# slog_ebitda_USD                      -0.004    0.006 -0.746 0.456  -0.016  0.007
# slog_scope_1_2_emissions_amount       0.086    0.046  1.850 0.064  -0.005  0.177
# Primary_activity Var                  0.005    0.286
# Primary_activity x Year_centered Cov  0.015    0.071
# Year_centered Var                     0.043    0.020
# account_id Var                        4.457    0.694
# ================================================================================
#
# R²(log):    12.03%
# R²(orig):   -5.50%
# MAPE:       2043.01%
# MAPE(log):  35.18%
# MAE(log):   1.74
# RMSLE:      2.13
# RMSE:       75435.81
# MAE:        20413.24

# %% [markdown]
# ## Upstream Leased Assets Full Mixed-Effects Model
#
# A full mixed-effects model is used to predict company Scope 3 emissions, using financial and emissions data, along with information about country, industry, and year. The model is trained on data from 2018 to 2022, and tested on data from 2023. This full model helps provides insights into how a company’s finances, emissions, primary activity, country and the year influence emissions.<br>
#
# Model Structure:<br>
#
# - Random Effects:<br>
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:<br>
#     - Signed log-transformed financial and emissions features:<br>
#         - Market Cap ('slog_Market_Cap_USD')<br>
#         - Revenue ('slog_Revenue_USD')<br>
#         - EBITDA ('slog_ebitda_USD')<br>
#         - Gross Profit ('slog_grossProfit_USD')<br>
#         - Short Term Investments ('slog_shortTermInvestments_USD')<br>
#         - Total Assets ('slog_totalAssets_USD')<br>
#         - Total Equity ('slog_totalEquity_USD')<br>
#         - Scope 1&2 Emissions ('slog_scope_1_2_emissions_amount')<br>
#     - Country ('Countries', as a categorical variable)<br>
#     - Primary Activity ('Primary_activity', as a categorical variable)<br>
#     - Year (numeric)<br>

# %%
# --- Feature and target columns ---
numeric_cols = ['Market_Cap_USD',
 'Revenue_USD',
 'ebitda_USD',
 'grossProfit_USD',
 'shortTermInvestments_USD',
 'totalAssets_USD',
 'totalEquity_USD',
 'Scope_3_emissions_amount',
 'scope_1_2_emissions_amount'
]
feature_cols_slog = [f'slog_{col}' for col in numeric_cols if col != 'Scope_3_emissions_amount']
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
required_cols = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_full = train_df.dropna(subset=required_cols).copy()
test_df_full = test_df.dropna(subset=required_cols).copy()

if test_df_full.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the full mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_full, groups=train_df_full['account_id'])
        mdf = md.fit(reml=False)
    print(mdf.summary())

    # --- Predict on test set ---
    test_df_full['predicted_log'] = mdf.predict(test_df_full)
    test_df_full['predicted'] = np.sign(test_df_full['predicted_log']) * (np.expm1(np.abs(test_df_full['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_full[target_col_slog]
    y_pred_log = test_df_full['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_full['predicted']

    # Mask for finite values
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nFull Mixed-Effects Model (Full Model) Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf.params,
        'pvalue': mdf.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Full Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Full Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Full Model Predicted")
    plt.xscale("log")
    plt.title("Full Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    full_model_metrics = {
        "Model": "Full Model",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                                            Mixed Linear Model Regression Results
# ===========================================================================================================================================================
# Model:                                        MixedLM                           Dependent Variable:                           slog_Scope_3_emissions_amount
# No. Observations:                             779                               Method:                                       ML
# No. Groups:                                   230                               Scale:                                        1.1473
# Min. group size:                              1                                 Log-Likelihood:                               -1321.8989
# Max. group size:                              5                                 Converged:                                    Yes
# Mean group size:                              3.4
# -----------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                            Coef.        Std.Err.        z    P>|z|        [0.025               0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 169.327
# C(Countries)[T.Brazil]                                                     -4.319               1.091 -3.959 0.000               -6.457              -2.181
# C(Countries)[T.Canada]                                                     -1.863               0.787 -2.367 0.018               -3.405              -0.320
# C(Countries)[T.China]                                                      -1.905               0.903 -2.109 0.035               -3.675              -0.134
# C(Countries)[T.France]                                                     -2.549               0.820 -3.107 0.002               -4.156              -0.941
# C(Countries)[T.Germany]                                                    -0.483               0.871 -0.554 0.579               -2.191               1.225
# C(Countries)[T.Ireland]                                                    -1.623               1.116 -1.454 0.146               -3.811               0.564
# C(Countries)[T.Italy]                                                      -1.221               1.118 -1.092 0.275               -3.411               0.970
# C(Countries)[T.Japan]                                                      -2.530               0.719 -3.519 0.000               -3.939              -1.121
# C(Countries)[T.Netherlands]                                                -0.720               0.981 -0.734 0.463               -2.643               1.202
# C(Countries)[T.New Zealand]                                                -2.567               1.594 -1.610 0.107               -5.692               0.558
# C(Countries)[T.Norway]                                                     -1.734               1.206 -1.438 0.150               -4.097               0.629
# C(Countries)[T.Portugal]                                                   -2.231 144889679361219.594 -0.000 1.000 -283978553279549.125 283978553279544.625
# C(Countries)[T.South Africa]                                               -0.998               0.961 -1.039 0.299               -2.881               0.884
# C(Countries)[T.South Korea]                                                -1.967               0.852 -2.308 0.021               -3.636              -0.297
# C(Countries)[T.Spain]                                                      -1.584               0.898 -1.764 0.078               -3.344               0.176
# C(Countries)[T.Sweden]                                                     -2.355               1.103 -2.135 0.033               -4.516              -0.193
# C(Countries)[T.Switzerland]                                                -1.947               1.014 -1.919 0.055               -3.935               0.041
# C(Countries)[T.Thailand]                                                   -0.446               1.273 -0.350 0.726               -2.940               2.048
# C(Countries)[T.USA]                                                        -1.111               0.705 -1.576 0.115               -2.491               0.270
# C(Countries)[T.United Kingdom]                                             -1.174               0.746 -1.573 0.116               -2.636               0.288
# C(Primary_activity)[T.Alcoholic beverages]                                  4.125               1.251  3.298 0.001                1.674               6.576
# C(Primary_activity)[T.Animal processing]                                    2.158               1.300  1.660 0.097               -0.390               4.706
# C(Primary_activity)[T.Apparel & footwear design]                            3.081               1.854  1.661 0.097               -0.554               6.715
# C(Primary_activity)[T.Apparel stores]                                       0.445               1.305  0.341 0.733               -2.113               3.002
# C(Primary_activity)[T.Asset managers]                                       2.771               1.313  2.110 0.035                0.197               5.345
# C(Primary_activity)[T.Banks]                                                2.155               1.120  1.924 0.054               -0.040               4.350
# C(Primary_activity)[T.Biotechnology]                                        4.453               1.473  3.024 0.002                1.567               7.339
# C(Primary_activity)[T.Building sub-contractors]                             1.510               1.486  1.016 0.310               -1.403               4.422
# C(Primary_activity)[T.CCGT generation]                                      2.667               1.465  1.820 0.069               -0.205               5.539
# C(Primary_activity)[T.Clothing manufacture]                                 2.130               1.393  1.529 0.126               -0.601               4.861
# C(Primary_activity)[T.Commercial services]                                  0.537               1.450  0.370 0.711               -2.305               3.380
# C(Primary_activity)[T.Communications equipment]                             2.290               1.233  1.857 0.063               -0.127               4.706
# C(Primary_activity)[T.Computer hardware]                                    1.960               1.256  1.561 0.119               -0.501               4.422
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                  3.362               1.312  2.563 0.010                0.791               5.933
# C(Primary_activity)[T.Department stores]                                    4.810               1.596  3.014 0.003                1.682               7.937
# C(Primary_activity)[T.Electrical equipment]                                 2.953               1.280  2.307 0.021                0.445               5.462
# C(Primary_activity)[T.Electronic components]                                1.397               1.124  1.243 0.214               -0.807               3.601
# C(Primary_activity)[T.Electronic equipment]                                 3.193               1.197  2.668 0.008                0.847               5.538
# C(Primary_activity)[T.Energy services & equipment]                          1.412               1.551  0.911 0.363               -1.627               4.451
# C(Primary_activity)[T.Engines & motors]                                     0.521               1.491  0.350 0.727               -2.401               3.444
# C(Primary_activity)[T.Fabricated metal components]                          4.491               1.430  3.140 0.002                1.688               7.295
# C(Primary_activity)[T.Fast food]                                            1.597               1.691  0.944 0.345               -1.718               4.912
# C(Primary_activity)[T.Finished wood products]                               5.100               1.768  2.885 0.004                1.635               8.564
# C(Primary_activity)[T.Food & beverage wholesale]                            4.024               1.729  2.328 0.020                0.636               7.412
# C(Primary_activity)[T.Furniture]                                            3.177               1.432  2.219 0.026                0.371               5.984
# C(Primary_activity)[T.Gambling]                                             0.953               1.299  0.733 0.463               -1.593               3.499
# C(Primary_activity)[T.Gas utilities]                                        1.126               1.432  0.786 0.432               -1.681               3.932
# C(Primary_activity)[T.Health care facilities]                               1.289               1.722  0.749 0.454               -2.086               4.664
# C(Primary_activity)[T.Health care services]                                 2.378               1.295  1.836 0.066               -0.161               4.916
# C(Primary_activity)[T.Health care supplies]                                 1.900               1.370  1.387 0.165               -0.785               4.585
# C(Primary_activity)[T.Hotels & lodging]                                     5.363               1.714  3.129 0.002                2.004               8.723
# C(Primary_activity)[T.Industrial machinery]                                 3.925               1.295  3.032 0.002                1.387               6.462
# C(Primary_activity)[T.Inorganic base chemicals]                             2.156               1.359  1.586 0.113               -0.508               4.821
# C(Primary_activity)[T.Insurance]                                            1.550               1.108  1.399 0.162               -0.621               3.720
# C(Primary_activity)[T.Iron & steel]                                         3.491               1.425  2.450 0.014                0.698               6.283
# C(Primary_activity)[T.Marketing]                                            3.364               1.466  2.294 0.022                0.490               6.238
# C(Primary_activity)[T.Medical equipment]                                    3.534               1.218  2.901 0.004                1.146               5.921
# C(Primary_activity)[T.Metal containers & packaging]                         3.366               1.635  2.058 0.040                0.161               6.572
# C(Primary_activity)[T.Non-CCGT generation]                                 -1.131               1.650 -0.685 0.493               -4.365               2.104
# C(Primary_activity)[T.Non-residential building construction]                2.773               1.227  2.260 0.024                0.368               5.178
# C(Primary_activity)[T.Oil & gas extraction]                                 2.270               1.450  1.566 0.117               -0.572               5.112
# C(Primary_activity)[T.Oil & gas marketing & retailing]                      4.471               1.618  2.763 0.006                1.299               7.643
# C(Primary_activity)[T.Oil & gas pipelines & storage]                        1.277               1.476  0.865 0.387               -1.616               4.169
# C(Primary_activity)[T.Other base chemicals]                                 2.112               1.215  1.739 0.082               -0.269               4.494
# C(Primary_activity)[T.Other food processing]                                2.028               1.299  1.561 0.118               -0.518               4.573
# C(Primary_activity)[T.Other professional services]                          2.742               1.129  2.429 0.015                0.529               4.955
# C(Primary_activity)[T.Other renewable generation]                           4.345 144889679361219.469  0.000 1.000 -283978553279542.250 283978553279551.000
# C(Primary_activity)[T.Paper products]                                       2.302               1.408  1.635 0.102               -0.458               5.063
# C(Primary_activity)[T.Passenger airlines]                                   2.032               1.456  1.395 0.163               -0.822               4.886
# C(Primary_activity)[T.Personal care & household products]                   3.916               1.233  3.176 0.001                1.499               6.333
# C(Primary_activity)[T.Pharmaceuticals]                                      3.010               1.123  2.681 0.007                0.809               5.211
# C(Primary_activity)[T.Print publishing]                                     1.117               1.913  0.584 0.559               -2.633               4.866
# C(Primary_activity)[T.Printing services]                                    1.954               1.624  1.203 0.229               -1.230               5.137
# C(Primary_activity)[T.REIT]                                                 0.916               1.143  0.801 0.423               -1.325               3.156
# C(Primary_activity)[T.Rail freight]                                         0.676               1.440  0.470 0.639               -2.146               3.498
# C(Primary_activity)[T.Real estate owners & developers]                      0.082               1.391  0.059 0.953               -2.644               2.808
# C(Primary_activity)[T.Real estate services]                                 3.847               1.311  2.934 0.003                1.277               6.417
# C(Primary_activity)[T.Residential building construction]                    1.831               1.476  1.241 0.215               -1.061               4.724
# C(Primary_activity)[T.Software]                                             2.417               1.198  2.018 0.044                0.069               4.766
# C(Primary_activity)[T.Solar energy equipment]                               0.986               1.646  0.599 0.549               -2.241               4.213
# C(Primary_activity)[T.Specialist retail]                                    2.902               1.449  2.003 0.045                0.062               5.742
# C(Primary_activity)[T.Specialty chemicals]                                  2.797               1.332  2.100 0.036                0.187               5.408
# C(Primary_activity)[T.Telecommunications services]                          2.751               1.144  2.404 0.016                0.508               4.994
# C(Primary_activity)[T.Tobacco products]                                     0.969               1.612  0.601 0.548               -2.191               4.130
# C(Primary_activity)[T.Transportation infrastructure & other construction]   4.784               1.452  3.295 0.001                1.938               7.629
# C(Primary_activity)[T.Transportation support services]                     -1.133               1.698 -0.668 0.504               -4.461               2.194
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]                2.276               1.311  1.736 0.083               -0.294               4.846
# C(Primary_activity)[T.Waste management]                                     0.891               1.405  0.634 0.526               -1.864               3.646
# C(Primary_activity)[T.Water supply networks]                                4.253               1.776  2.395 0.017                0.772               7.733
# slog_Market_Cap_USD                                                        -0.013               0.101 -0.132 0.895               -0.211               0.185
# slog_Revenue_USD                                                            0.418               0.141  2.964 0.003                0.142               0.695
# slog_ebitda_USD                                                            -0.008               0.008 -1.058 0.290               -0.023               0.007
# slog_grossProfit_USD                                                        0.020               0.027  0.727 0.467               -0.033               0.073
# slog_shortTermInvestments_USD                                               0.010               0.006  1.643 0.100               -0.002               0.022
# slog_totalAssets_USD                                                        0.002               0.050  0.034 0.973               -0.096               0.100
# slog_totalEquity_USD                                                        0.012               0.013  0.924 0.356               -0.013               0.037
# slog_scope_1_2_emissions_amount                                             0.139               0.060  2.326 0.020                0.022               0.255
# Year                                                                       -0.086
# Group Var                                                                   1.172               0.109
# ===========================================================================================================================================================
#
#
# Full Mixed-Effects Model (Full Model) Test Set Performance Metrics:
# R²(log):    38.90%
# R²(orig):   6.31%
# MAPE:       1124.47%
# MAPE(log):  28.12%
# MAE(log):   1.38
# RMSLE:      1.77
# RMSE:       71088.87
# MAE:        17796.55
#
# Top Influential Features (by p-value):
#                                                         coef        pvalue
# Group Var                                           1.021513  9.451048e-24
# C(Countries)[T.Brazil]                             -4.319079  7.523565e-05
# C(Countries)[T.Japan]                              -2.529930  4.332401e-04
# C(Primary_activity)[T.Alcoholic beverages]          4.124932  9.728711e-04
# C(Primary_activity)[T.Transportation infrastruc...  4.783532  9.854824e-04
# C(Primary_activity)[T.Personal care & household...  3.916271  1.495352e-03
# C(Primary_activity)[T.Fabricated metal components]  4.491454  1.688412e-03
# C(Primary_activity)[T.Hotels & lodging]             5.363409  1.754741e-03
# C(Countries)[T.France]                             -2.548592  1.892337e-03
# C(Primary_activity)[T.Industrial machinery]         3.924599  2.431626e-03
# /Users/amberjensen/anaconda3/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2704: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))

# %% [markdown]
# ## Upstream Leased Assets Optimized Mixed-Effects Model
#
# An optimized mixed-effects model is used to predict company Scope 3 emissions. The model provides accurate prediction using only the most significant predictive features, while still accounting for primary activity, country and company level effects. The model is trained on data from 2018–2022 and evaluated on test data from 2023.
#
# Model Structure:
#
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:
#     - Signed log-transformed features:
#         - Revenue ('slog_Revenue_USD')
#         - Scope 1 & 2 Emissions ('slog_scope_1_2_emissions_amount')
#     - Country ('Countries', as a categorical variable)
#     - Primary Activity ('Primary_activity', as a categorical variable)

# %%
feature_cols_slog = [
    'slog_Revenue_USD',
    'slog_scope_1_2_emissions_amount'
]
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
all_model_vars = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_opt = train_df.dropna(subset=all_model_vars).copy()
test_df_opt = test_df.dropna(subset=all_model_vars).copy()

if test_df_opt.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity)'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the optimized mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_opt, groups=train_df_opt['account_id'])
        mdf_optimized = md.fit(reml=False)
    print(mdf_optimized.summary())

    # --- Predict on test set ---
    test_df_opt['predicted_log'] = mdf_optimized.predict(test_df_opt)
    test_df_opt['predicted'] = np.sign(test_df_opt['predicted_log']) * (np.expm1(np.abs(test_df_opt['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_opt[target_col_slog]
    y_pred_log = test_df_opt['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_opt['predicted']

    # Mask for valid/finites
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <-- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nOptimized Mixed-Effects Model: Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf_optimized.params,
        'pvalue': mdf_optimized.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Optimized Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Optimized Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Optimized Model Predicted")
    plt.xscale("log")
    plt.title("Optimized Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    optimized_model_metrics = {
        "Model": "Optimized",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                               Mixed Linear Model Regression Results
# ==================================================================================================================================
# Model:                               MixedLM                   Dependent Variable:                   slog_Scope_3_emissions_amount
# No. Observations:                    779                       Method:                               ML
# No. Groups:                          230                       Scale:                                0.9394
# Min. group size:                     1                         Log-Likelihood:                       -1293.9537
# Max. group size:                     5                         Converged:                            Yes
# Mean group size:                     3.4
# ----------------------------------------------------------------------------------------------------------------------------------
#                                                                                  Coef.         Std.Err.   z    P>|z| [0.025 0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                               -3.282
# C(Countries)[T.Brazil]                                                                  -4.158    1.401 -2.969 0.003 -6.904 -1.413
# C(Countries)[T.Canada]                                                                  -1.775    1.029 -1.726 0.084 -3.791  0.241
# C(Countries)[T.China]                                                                   -1.806    1.218 -1.483 0.138 -4.194  0.581
# C(Countries)[T.France]                                                                  -2.430    1.212 -2.004 0.045 -4.806 -0.054
# C(Countries)[T.Germany]                                                                 -0.450    1.373 -0.328 0.743 -3.142  2.241
# C(Countries)[T.Ireland]                                                                 -1.459    1.445 -1.009 0.313 -4.291  1.373
# C(Countries)[T.Italy]                                                                   -1.243    1.466 -0.848 0.397 -4.116  1.630
# C(Countries)[T.Japan]                                                                   -2.426    1.016 -2.388 0.017 -4.417 -0.435
# C(Countries)[T.Netherlands]                                                             -0.638    1.362 -0.468 0.639 -3.308  2.032
# C(Countries)[T.New Zealand]                                                             -2.285    1.793 -1.275 0.202 -5.799  1.228
# C(Countries)[T.Norway]                                                                  -1.840    1.673 -1.100 0.271 -5.119  1.439
# C(Countries)[T.Portugal]                                                   207701286364924.000
# C(Countries)[T.South Africa]                                                            -1.002    1.216 -0.824 0.410 -3.386  1.382
# C(Countries)[T.South Korea]                                                             -1.799    1.145 -1.571 0.116 -4.044  0.446
# C(Countries)[T.Spain]                                                                   -1.466    1.297 -1.130 0.259 -4.008  1.077
# C(Countries)[T.Sweden]                                                                  -2.381    1.544 -1.542 0.123 -5.407  0.645
# C(Countries)[T.Switzerland]                                                             -1.711    1.299 -1.318 0.188 -4.257  0.834
# C(Countries)[T.Thailand]                                                                -0.268    1.533 -0.175 0.861 -3.272  2.736
# C(Countries)[T.USA]                                                                     -0.924    1.044 -0.886 0.376 -2.970  1.121
# C(Countries)[T.United Kingdom]                                                          -1.114    1.059 -1.053 0.292 -3.189  0.960
# C(Primary_activity)[T.Alcoholic beverages]                                               4.140    1.077  3.843 0.000  2.028  6.252
# C(Primary_activity)[T.Animal processing]                                                 2.185    1.027  2.128 0.033  0.173  4.198
# C(Primary_activity)[T.Apparel & footwear design]                                         3.155    1.848  1.707 0.088 -0.468  6.778
# C(Primary_activity)[T.Apparel stores]                                                    0.571    1.173  0.487 0.626 -1.728  2.870
# C(Primary_activity)[T.Asset managers]                                                    2.734    1.314  2.081 0.037  0.159  5.309
# C(Primary_activity)[T.Banks]                                                             2.135    0.907  2.353 0.019  0.356  3.913
# C(Primary_activity)[T.Biotechnology]                                                     4.528    1.388  3.262 0.001  1.807  7.250
# C(Primary_activity)[T.Building sub-contractors]                                          1.534    1.352  1.135 0.257 -1.116  4.184
# C(Primary_activity)[T.CCGT generation]                                                   2.718    0.705  3.857 0.000  1.337  4.099
# C(Primary_activity)[T.Clothing manufacture]                                              2.050    1.386  1.479 0.139 -0.666  4.766
# C(Primary_activity)[T.Commercial services]                                               0.452    1.308  0.346 0.730 -2.111  3.015
# C(Primary_activity)[T.Communications equipment]                                          2.257    0.921  2.450 0.014  0.452  4.062
# C(Primary_activity)[T.Computer hardware]                                                 1.952    0.975  2.002 0.045  0.041  3.863
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                               3.337    1.566  2.130 0.033  0.267  6.406
# C(Primary_activity)[T.Department stores]                                                 4.730    1.487  3.181 0.001  1.816  7.644
# C(Primary_activity)[T.Electrical equipment]                                              3.014    1.115  2.703 0.007  0.829  5.200
# C(Primary_activity)[T.Electronic components]                                             1.482    0.854  1.736 0.083 -0.192  3.155
# C(Primary_activity)[T.Electronic equipment]                                              3.416    0.953  3.583 0.000  1.547  5.285
# C(Primary_activity)[T.Energy services & equipment]                                       1.135    1.210  0.938 0.348 -1.237  3.507
# C(Primary_activity)[T.Engines & motors]                                                  0.688    1.408  0.488 0.625 -2.072  3.448
# C(Primary_activity)[T.Fabricated metal components]                                       4.644    1.301  3.569 0.000  2.094  7.194
# C(Primary_activity)[T.Fast food]                                                         1.199    1.523  0.787 0.431 -1.786  4.183
# C(Primary_activity)[T.Finished wood products]                                            5.362    1.437  3.733 0.000  2.547  8.178
# C(Primary_activity)[T.Food & beverage wholesale]                                         4.383    2.017  2.173 0.030  0.429  8.337
# C(Primary_activity)[T.Furniture]                                                         3.006    1.119  2.687 0.007  0.813  5.198
# C(Primary_activity)[T.Gambling]                                                          1.026    0.970  1.057 0.291 -0.876  2.928
# C(Primary_activity)[T.Gas utilities]                                                     1.188    1.246  0.954 0.340 -1.254  3.631
# C(Primary_activity)[T.Health care facilities]                                            1.584    1.854  0.855 0.393 -2.049  5.217
# C(Primary_activity)[T.Health care services]                                              2.405    1.309  1.837 0.066 -0.161  4.971
# C(Primary_activity)[T.Health care supplies]                                              2.088    1.191  1.753 0.080 -0.247  4.423
# C(Primary_activity)[T.Hotels & lodging]                                                  5.136    1.601  3.209 0.001  1.999  8.273
# C(Primary_activity)[T.Industrial machinery]                                              3.742    1.024  3.654 0.000  1.735  5.749
# C(Primary_activity)[T.Inorganic base chemicals]                                          2.241    1.239  1.809 0.070 -0.187  4.669
# C(Primary_activity)[T.Insurance]                                                         1.734    0.928  1.869 0.062 -0.085  3.553
# C(Primary_activity)[T.Iron & steel]                                                      3.792    1.208  3.139 0.002  1.424  6.159
# C(Primary_activity)[T.Marketing]                                                         3.366    1.407  2.392 0.017  0.608  6.124
# C(Primary_activity)[T.Medical equipment]                                                 3.551    0.954  3.721 0.000  1.681  5.422
# C(Primary_activity)[T.Metal containers & packaging]                                      3.193    1.518  2.103 0.035  0.217  6.169
# C(Primary_activity)[T.Non-CCGT generation]                                              -1.244    1.473 -0.844 0.398 -4.132  1.644
# C(Primary_activity)[T.Non-residential building construction]                             2.862    1.106  2.588 0.010  0.695  5.029
# C(Primary_activity)[T.Oil & gas extraction]                                              2.537    0.836  3.034 0.002  0.898  4.176
# C(Primary_activity)[T.Oil & gas marketing & retailing]                                   4.600    1.679  2.740 0.006  1.309  7.890
# C(Primary_activity)[T.Oil & gas pipelines & storage]                                     1.532    1.200  1.276 0.202 -0.821  3.884
# C(Primary_activity)[T.Other base chemicals]                                              2.310    0.954  2.421 0.015  0.440  4.180
# C(Primary_activity)[T.Other food processing]                                             1.890    0.979  1.930 0.054 -0.029  3.810
# C(Primary_activity)[T.Other professional services]                                       2.603    0.956  2.722 0.006  0.729  4.478
# C(Primary_activity)[T.Other renewable generation]                         -207701286364921.562
# C(Primary_activity)[T.Paper products]                                                    2.295    1.060  2.166 0.030  0.218  4.372
# C(Primary_activity)[T.Passenger airlines]                                                2.150    1.092  1.969 0.049  0.010  4.291
# C(Primary_activity)[T.Personal care & household products]                                4.058    1.063  3.819 0.000  1.976  6.141
# C(Primary_activity)[T.Pharmaceuticals]                                                   3.250    1.026  3.167 0.002  1.239  5.262
# C(Primary_activity)[T.Print publishing]                                                  0.934    1.955  0.478 0.633 -2.898  4.766
# C(Primary_activity)[T.Printing services]                                                 2.200    1.606  1.370 0.171 -0.948  5.347
# C(Primary_activity)[T.REIT]                                                              0.871    0.396  2.200 0.028  0.095  1.647
# C(Primary_activity)[T.Rail freight]                                                      0.812    1.040  0.781 0.435 -1.226  2.849
# C(Primary_activity)[T.Real estate owners & developers]                                  -0.057    1.205 -0.048 0.962 -2.420  2.305
# C(Primary_activity)[T.Real estate services]                                              3.858    1.185  3.256 0.001  1.536  6.181
# C(Primary_activity)[T.Residential building construction]                                 2.113    1.506  1.403 0.161 -0.839  5.064
# C(Primary_activity)[T.Software]                                                          2.402    0.915  2.625 0.009  0.608  4.195
# C(Primary_activity)[T.Solar energy equipment]                                            1.157    1.327  0.872 0.383 -1.444  3.757
# C(Primary_activity)[T.Specialist retail]                                                 2.860    1.405  2.036 0.042  0.107  5.613
# C(Primary_activity)[T.Specialty chemicals]                                               3.026    1.112  2.722 0.006  0.847  5.205
# C(Primary_activity)[T.Telecommunications services]                                       2.981    0.934  3.191 0.001  1.150  4.812
# C(Primary_activity)[T.Tobacco products]                                                  1.222    1.666  0.733 0.463 -2.043  4.487
# C(Primary_activity)[T.Transportation infrastructure & other construction]                4.921    1.427  3.447 0.001  2.123  7.718
# C(Primary_activity)[T.Transportation support services]                                  -1.252    1.769 -0.708 0.479 -4.718  2.214
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]                             2.190    1.287  1.702 0.089 -0.332  4.712
# C(Primary_activity)[T.Waste management]                                                  0.941    0.779  1.208 0.227 -0.586  2.468
# C(Primary_activity)[T.Water supply networks]                                             4.659    1.756  2.653 0.008  1.217  8.101
# slog_Revenue_USD                                                                         0.390
# slog_scope_1_2_emissions_amount                                                          0.122
# Group Var                                                                                1.675    0.176
# ==================================================================================================================================
#
#
# Optimized Mixed-Effects Model: Test Set Performance Metrics:
# R²(log):    38.64%
# R²(orig):   8.15%
# MAPE:       1506.04%
# MAPE(log):  29.06%
# MAE(log):   1.38
# RMSLE:      1.77
# RMSE:       70385.02
# MAE:        17735.19
#
# Top Influential Features (by p-value):
#                                                         coef        pvalue
# Group Var                                           1.782712  9.244977e-23
# C(Primary_activity)[T.CCGT generation]              2.717870  1.148361e-04
# C(Primary_activity)[T.Alcoholic beverages]          4.140002  1.217276e-04
# C(Primary_activity)[T.Personal care & household...  4.058191  1.338383e-04
# C(Primary_activity)[T.Finished wood products]       5.362201  1.894004e-04
# C(Primary_activity)[T.Medical equipment]            3.551458  1.982043e-04
# C(Primary_activity)[T.Industrial machinery]         3.742101  2.582413e-04
# C(Primary_activity)[T.Electronic equipment]         3.415960  3.396691e-04
# C(Primary_activity)[T.Fabricated metal components]  4.644198  3.580614e-04
# C(Primary_activity)[T.Transportation infrastruc...  4.920507  5.668632e-04
#
# All feature coefficients sorted by absolute value:
#                                                             coef    pvalue
# C(Countries)[T.Portugal]                            2.077013e+14       NaN
# C(Primary_activity)[T.Other renewable generation]  -2.077013e+14       NaN
# C(Primary_activity)[T.Finished wood products]       5.362201e+00  0.000189
# C(Primary_activity)[T.Hotels & lodging]             5.136179e+00  0.001333
# C(Primary_activity)[T.Transportation infrastruc...  4.920507e+00  0.000567
# ...                                                          ...       ...
# C(Countries)[T.Germany]                            -4.501406e-01  0.743064
# slog_Revenue_USD                                    3.897229e-01       NaN
# C(Countries)[T.Thailand]                           -2.680809e-01  0.861169
# slog_scope_1_2_emissions_amount                     1.220180e-01       NaN
# C(Primary_activity)[T.Real estate owners & deve... -5.743683e-02  0.961995
#
# [92 rows x 2 columns]
# /Users/amberjensen/anaconda3/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2704: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))

# %%
metrics_text_log = (
    f"R²(log):   {r2_log_pct:.2f}%\n"
    f"R²(orig):  {r2_pct:.2f}%\n"
    f"MAPE:      {mape_orig:.2f}%\n"
    f"MAPE(log): {mape_log:.2f}%\n"
    f"MAE(log):  {mae_log:.2f}\n"
    f"RMSLE:     {rmsle:.2f}\n"
    f"RMSE:      {rmse_orig:.2f}\n"
    f"MAE:       {mae_orig:.2f}"
)

fig, ax = plt.subplots(figsize=(9.5, 6))  # Wider to make room for the box

if hasattr(y_pred_log, "nunique"):
    multiple_vals = y_pred_log.nunique() > 1
else:
    multiple_vals = len(set(y_pred_log)) > 1

if multiple_vals:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=ax, color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    ax.plot([], [], ' ', label="Predicted: constant value (no KDE)")

ax.set_title("Upstream Leased Assets Optimized Model: signed log(Scope 3 Emissions)")
ax.set_xlabel("signed log(metric tons + 1)")
ax.set_ylabel("Density")
ax.legend()

# Place metrics box outside plot to the right
fig.text(
    0.82, 0.75, metrics_text_log,
    va='top', ha='left',
    fontsize=12, bbox=dict(boxstyle='round', alpha=0.15)
)

plt.subplots_adjust(right=0.8)  # Make sure there's room for the box
fig.savefig("upstream_leased_assets_scope3_log_density.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Metrics Table for Upstream Leased Assets

# %%
metrics_dicts = [
    null_model_metrics,
    two_level_model_metrics,
    three_level_model_metrics,
    full_model_metrics,
    optimized_model_metrics
]

for metrics, train, test in zip(
        metrics_dicts,
        [train_df, train_df, train_df, train_df, train_df],
        [test_df, test_df, test_df, test_df, test_df]):
    
    metrics["# Obs (train)"] = len(train)
    metrics["# Obs (test)"] = len(test)
    metrics["# Obs (train/test)"] = f"{len(train)}/{len(test)}"

metrics_df = pd.DataFrame(metrics_dicts)

# Ensure all relevant columns are ordered and present
desired_order = [
    "Model", "R2_log", "R2_orig", "RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "# Obs (train/test)"
]


# Ensure MAE_log is present, fill with NaN if missing
if "MAE_log" not in metrics_df.columns:
    metrics_df["MAE_log"] = np.nan

metrics_df = metrics_df[[col for col in desired_order if col in metrics_df.columns]]

metrics_df_display = metrics_df.copy()
if "R2_log" in metrics_df_display.columns:
    metrics_df_display["R2_log"] = (metrics_df_display["R2_log"] * 100).map("{:.2f}%".format)
if "R2_orig" in metrics_df_display.columns:
    metrics_df_display["R2_orig"] = (metrics_df_display["R2_orig"] * 100).map("{:.2f}%".format)
for col in ["RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "MAPE(log)"]:
    if col in metrics_df_display.columns:
        metrics_df_display[col] = metrics_df_display[col].map("{:.2f}".format)

from IPython.display import display
display(metrics_df_display)
# Out:
#                                      Model  R2_log R2_orig      RMSE  \
# 0                                Null (RI)  -0.02%  -6.75%  75880.74
# 1                           2-level (RI+S)  -2.62%  -7.28%  76066.82
# 2  3-level (Primary Activity/Account/Year)  12.03%  -5.50%  75435.81
# 3                               Full Model  38.90%   6.31%  71088.87
# 4                                Optimized  38.64%   8.15%  70385.02
#
#         MAE MAE_log RMSLE     MAPE # Obs (train/test)
# 0  20907.15    1.88  2.27  3789.40            779/158
# 1  20936.08    1.89  2.30  2712.54            779/158
# 2  20413.24    1.74  2.13  2043.01            779/158
# 3  17796.55    1.38  1.77  1124.47            779/158
# 4  17735.19    1.38  1.77  1506.04            779/158
