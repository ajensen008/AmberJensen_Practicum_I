# %% [markdown]
# # GHG HLM on Scope 3 source Waste

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_log_error, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GroupShuffleSplit
from scipy.stats import zscore
import scipy.stats as stats
from sklearn.feature_selection import mutual_info_regression
from sklearn.impute import SimpleImputer
import warnings
from statsmodels.regression.mixed_linear_model import MixedLM


#read in dataset GHG_post_outliers data set
waste=pd.read_csv('/Users/amberjensen/Desktop/GHG_Emissions_Project/waste.csv')

# %%
#check for info
waste.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_name                4809 non-null   object
#  1   account_id                  4809 non-null   int64
#  2   Year                        4809 non-null   int64
#  3   incorporated_country        4809 non-null   object
#  4   Primary activity            4809 non-null   object
#  5   Primary sector              4809 non-null   object
#  6   Market_Cap_USD              4092 non-null   float64
#  7   Third_party_verification    4807 non-null   object
#  8   Revenue_USD                 4109 non-null   float64
#  9   ebitda_USD                  4109 non-null   float64
#  10  grossProfit_USD             4109 non-null   float64
#  11  netIncome_USD               4109 non-null   float64
#  12  cashAndCashEquivalents_USD  4109 non-null   float64
#  13  shortTermInvestments_USD    4109 non-null   float64
#  14  longTermInvestments_USD     4109 non-null   float64
#  15  totalAssets_USD             4109 non-null   float64
#  16  totalLiabilities_USD        4109 non-null   float64
#  17  totalInvestments_USD        4109 non-null   float64
#  18  totalDebt_USD               4109 non-null   float64
#  19  totalEquity_USD             4109 non-null   float64
#  20  Scope_3_emissions_type      4809 non-null   object
#  21  Scope_3_emissions_amount    4809 non-null   float64
#  22  scope_1_2_emissions_amount  4796 non-null   float64
#  23  Year_sq                     4809 non-null   int64
# dtypes: float64(15), int64(3), object(6)
# memory usage: 901.8+ KB

# %%
#show a df for waste
waste.head()
# Out:
#   account_name  account_id  Year incorporated_country      Primary activity  \
# 0     3i Group          44  2018       United Kingdom        Asset managers
# 1        abrdn       17604  2018       United Kingdom             Insurance
# 2        Aptiv        4407  2018       United Kingdom  Electrical equipment
# 3  AstraZeneca        1104  2018       United Kingdom       Pharmaceuticals
# 4    Aviva plc        1268  2018       United Kingdom             Insurance
#
#                       Primary sector  Market_Cap_USD  \
# 0                 Financial services    9.548124e+09
# 1                 Financial services    1.019344e+10
# 2  Electrical & electronic equipment    1.595156e+10
# 3                   Biotech & pharma    7.441091e+10
# 4                 Financial services    1.880010e+10
#
#                             Third_party_verification   Revenue_USD  \
# 0  Third-party verification or assurance process ...  1.728470e+09
# 1  Third-party verification or assurance process ...  2.912110e+09
# 2           No third-party verification or assurance  1.443500e+10
# 3  Third-party verification or assurance process ...  2.209000e+10
# 4  Third-party verification or assurance process ...  2.828417e+10
#
#      ebitda_USD  ...  longTermInvestments_USD  totalAssets_USD  \
# 0  1.565910e+09  ...             8.544560e+09     1.107567e+10
# 1  1.482090e+09  ...             6.626860e+09     1.589659e+10
# 2  2.260000e+09  ...             9.900000e+07     1.248000e+10
# 3  7.165000e+09  ...             1.130000e+08     6.065100e+10
# 4  2.565400e+08  ...             7.073011e+10     5.454917e+11
#
#    totalLiabilities_USD  totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0          1.031240e+09          8.544560e+09   7.302500e+08     1.004443e+10
# 1          6.322060e+09          6.626860e+09   1.647190e+09     9.574530e+09
# 2          8.810000e+09          1.710000e+08   4.344000e+09     3.670000e+09
# 3          4.660700e+10          9.220000e+08   1.911300e+10     1.404400e+10
# 4          1.164463e+10          8.914511e+10   1.360678e+10     2.343785e+10
#
#           Scope_3_emissions_type  Scope_3_emissions_amount  \
# 0  Waste generated in operations                     57.21
# 1  Waste generated in operations                     14.13
# 2  Waste generated in operations                 104000.00
# 3  Waste generated in operations                  25361.00
# 4  Waste generated in operations                     81.00
#
#    scope_1_2_emissions_amount  Year_sq
# 0                  338.950000  4072324
# 1                 7197.250000  4072324
# 2               380471.810000  4072324
# 3               707252.916667  4072324
# 4                61086.500000  4072324
#
# [5 rows x 24 columns]

# %%
#define a list of numeric columns
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD',
       'grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD',
       'shortTermInvestments_USD', 'longTermInvestments_USD',
       'totalAssets_USD', 'totalLiabilities_USD', 'totalInvestments_USD',
       'totalDebt_USD', 'totalEquity_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount']

# %%
#plot the heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(waste[numeric_cols].corr(), annot=True, annot_kws={"size": 8})
plt.show()

# %%
#correlation matrix
waste[numeric_cols].corr()
# Out:
#                             Market_Cap_USD  Revenue_USD  ebitda_USD  \
# Market_Cap_USD                    1.000000     0.192112    0.297925
# Revenue_USD                       0.192112     1.000000    0.647697
# ebitda_USD                        0.297925     0.647697    1.000000
# grossProfit_USD                   0.210875     0.764566    0.682058
# netIncome_USD                     0.329176     0.572035    0.854561
# cashAndCashEquivalents_USD        0.039779     0.198832    0.261414
# shortTermInvestments_USD          0.054924     0.156660    0.192638
# longTermInvestments_USD           0.036536     0.246233    0.303209
# totalAssets_USD                   0.065320     0.324572    0.399370
# totalLiabilities_USD              0.054857     0.299719    0.359107
# totalInvestments_USD              0.053665     0.260812    0.325155
# totalDebt_USD                     0.080634     0.379497    0.451193
# totalEquity_USD                   0.193313     0.584376    0.742044
# Scope_3_emissions_amount          0.030644     0.111960    0.064804
# scope_1_2_emissions_amount        0.001608     0.076166    0.053413
#
#                             grossProfit_USD  netIncome_USD  \
# Market_Cap_USD                     0.210875       0.329176
# Revenue_USD                        0.764566       0.572035
# ebitda_USD                         0.682058       0.854561
# grossProfit_USD                    1.000000       0.674131
# netIncome_USD                      0.674131       1.000000
# cashAndCashEquivalents_USD         0.387942       0.314005
# shortTermInvestments_USD           0.301689       0.201021
# longTermInvestments_USD            0.513583       0.345902
# totalAssets_USD                    0.584624       0.431429
# totalLiabilities_USD               0.552336       0.398316
# totalInvestments_USD               0.536412       0.368919
# totalDebt_USD                      0.544538       0.423130
# totalEquity_USD                    0.744039       0.692068
# Scope_3_emissions_amount           0.019137       0.032822
# scope_1_2_emissions_amount        -0.019238      -0.001894
#
#                             cashAndCashEquivalents_USD  \
# Market_Cap_USD                                0.039779
# Revenue_USD                                   0.198832
# ebitda_USD                                    0.261414
# grossProfit_USD                               0.387942
# netIncome_USD                                 0.314005
# cashAndCashEquivalents_USD                    1.000000
# shortTermInvestments_USD                     -0.086006
# longTermInvestments_USD                       0.697869
# totalAssets_USD                               0.853816
# totalLiabilities_USD                          0.816114
# totalInvestments_USD                          0.639714
# totalDebt_USD                                 0.778196
# totalEquity_USD                               0.605917
# Scope_3_emissions_amount                     -0.032558
# scope_1_2_emissions_amount                   -0.033172
#
#                             shortTermInvestments_USD  longTermInvestments_USD  \
# Market_Cap_USD                              0.054924                 0.036536
# Revenue_USD                                 0.156660                 0.246233
# ebitda_USD                                  0.192638                 0.303209
# grossProfit_USD                             0.301689                 0.513583
# netIncome_USD                               0.201021                 0.345902
# cashAndCashEquivalents_USD                 -0.086006                 0.697869
# shortTermInvestments_USD                    1.000000                 0.390676
# longTermInvestments_USD                     0.390676                 1.000000
# totalAssets_USD                             0.195466                 0.877718
# totalLiabilities_USD                        0.183149                 0.789320
# totalInvestments_USD                        0.487874                 0.959805
# totalDebt_USD                              -0.030385                 0.606113
# totalEquity_USD                             0.268836                 0.684280
# Scope_3_emissions_amount                   -0.023125                -0.049826
# scope_1_2_emissions_amount                 -0.021123                -0.052864
#
#                             totalAssets_USD  totalLiabilities_USD  \
# Market_Cap_USD                     0.065320              0.054857
# Revenue_USD                        0.324572              0.299719
# ebitda_USD                         0.399370              0.359107
# grossProfit_USD                    0.584624              0.552336
# netIncome_USD                      0.431429              0.398316
# cashAndCashEquivalents_USD         0.853816              0.816114
# shortTermInvestments_USD           0.195466              0.183149
# longTermInvestments_USD            0.877718              0.789320
# totalAssets_USD                    1.000000              0.939452
# totalLiabilities_USD               0.939452              1.000000
# totalInvestments_USD               0.841592              0.761710
# totalDebt_USD                      0.834220              0.815052
# totalEquity_USD                    0.789868              0.732589
# Scope_3_emissions_amount          -0.039494             -0.035191
# scope_1_2_emissions_amount        -0.034778             -0.033959
#
#                             totalInvestments_USD  totalDebt_USD  \
# Market_Cap_USD                          0.053665       0.080634
# Revenue_USD                             0.260812       0.379497
# ebitda_USD                              0.325155       0.451193
# grossProfit_USD                         0.536412       0.544538
# netIncome_USD                           0.368919       0.423130
# cashAndCashEquivalents_USD              0.639714       0.778196
# shortTermInvestments_USD                0.487874      -0.030385
# longTermInvestments_USD                 0.959805       0.606113
# totalAssets_USD                         0.841592       0.834220
# totalLiabilities_USD                    0.761710       0.815052
# totalInvestments_USD                    1.000000       0.569003
# totalDebt_USD                           0.569003       1.000000
# totalEquity_USD                         0.679662       0.717343
# Scope_3_emissions_amount               -0.050888       0.009112
# scope_1_2_emissions_amount             -0.052170       0.018707
#
#                             totalEquity_USD  Scope_3_emissions_amount  \
# Market_Cap_USD                     0.193313                  0.030644
# Revenue_USD                        0.584376                  0.111960
# ebitda_USD                         0.742044                  0.064804
# grossProfit_USD                    0.744039                  0.019137
# netIncome_USD                      0.692068                  0.032822
# cashAndCashEquivalents_USD         0.605917                 -0.032558
# shortTermInvestments_USD           0.268836                 -0.023125
# longTermInvestments_USD            0.684280                 -0.049826
# totalAssets_USD                    0.789868                 -0.039494
# totalLiabilities_USD               0.732589                 -0.035191
# totalInvestments_USD               0.679662                 -0.050888
# totalDebt_USD                      0.717343                  0.009112
# totalEquity_USD                    1.000000                 -0.012937
# Scope_3_emissions_amount          -0.012937                  1.000000
# scope_1_2_emissions_amount         0.031420                  0.138547
#
#                             scope_1_2_emissions_amount
# Market_Cap_USD                                0.001608
# Revenue_USD                                   0.076166
# ebitda_USD                                    0.053413
# grossProfit_USD                              -0.019238
# netIncome_USD                                -0.001894
# cashAndCashEquivalents_USD                   -0.033172
# shortTermInvestments_USD                     -0.021123
# longTermInvestments_USD                      -0.052864
# totalAssets_USD                              -0.034778
# totalLiabilities_USD                         -0.033959
# totalInvestments_USD                         -0.052170
# totalDebt_USD                                 0.018707
# totalEquity_USD                               0.031420
# Scope_3_emissions_amount                      0.138547
# scope_1_2_emissions_amount                    1.000000

# %%
#drop columns due to collinearity, keeping total
waste=waste.drop(columns=['cashAndCashEquivalents_USD','longTermInvestments_USD',"totalLiabilities_USD",
                                              "account_name", "Third_party_verification", "Scope_3_emissions_type"])

# %%
waste.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  4809 non-null   int64
#  1   Year                        4809 non-null   int64
#  2   incorporated_country        4809 non-null   object
#  3   Primary activity            4809 non-null   object
#  4   Primary sector              4809 non-null   object
#  5   Market_Cap_USD              4092 non-null   float64
#  6   Revenue_USD                 4109 non-null   float64
#  7   ebitda_USD                  4109 non-null   float64
#  8   grossProfit_USD             4109 non-null   float64
#  9   netIncome_USD               4109 non-null   float64
#  10  shortTermInvestments_USD    4109 non-null   float64
#  11  totalAssets_USD             4109 non-null   float64
#  12  totalInvestments_USD        4109 non-null   float64
#  13  totalDebt_USD               4109 non-null   float64
#  14  totalEquity_USD             4109 non-null   float64
#  15  Scope_3_emissions_amount    4809 non-null   float64
#  16  scope_1_2_emissions_amount  4796 non-null   float64
#  17  Year_sq                     4809 non-null   int64
# dtypes: float64(12), int64(3), object(3)
# memory usage: 676.4+ KB

# %%
sns.boxplot(waste)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# copy dataframe
waste_no_transform = waste.copy()
# Change 'incorporated_country' to 'Countries' in waste dataframe
waste_no_transform = waste_no_transform.rename(columns={'incorporated_country': 'Countries',
                                                       'Primary activity': 'Primary_activity',
                                                        'Primary sector': 'Primary_sector'})

print(waste_no_transform.info())
waste_no_transform.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  4809 non-null   int64
#  1   Year                        4809 non-null   int64
#  2   Countries                   4809 non-null   object
#  3   Primary_activity            4809 non-null   object
#  4   Primary_sector              4809 non-null   object
#  5   Market_Cap_USD              4092 non-null   float64
#  6   Revenue_USD                 4109 non-null   float64
#  7   ebitda_USD                  4109 non-null   float64
#  8   grossProfit_USD             4109 non-null   float64
#  9   netIncome_USD               4109 non-null   float64
#  10  shortTermInvestments_USD    4109 non-null   float64
#  11  totalAssets_USD             4109 non-null   float64
#  12  totalInvestments_USD        4109 non-null   float64
#  13  totalDebt_USD               4109 non-null   float64
#  14  totalEquity_USD             4109 non-null   float64
#  15  Scope_3_emissions_amount    4809 non-null   float64
#  16  scope_1_2_emissions_amount  4796 non-null   float64
#  17  Year_sq                     4809 non-null   int64
# dtypes: float64(12), int64(3), object(3)
# memory usage: 676.4+ KB
# None
#    account_id  Year       Countries      Primary_activity  \
# 0          44  2018  United Kingdom        Asset managers
# 1       17604  2018  United Kingdom             Insurance
# 2        4407  2018  United Kingdom  Electrical equipment
# 3        1104  2018  United Kingdom       Pharmaceuticals
# 4        1268  2018  United Kingdom             Insurance
#
#                       Primary_sector  Market_Cap_USD   Revenue_USD  \
# 0                 Financial services    9.548124e+09  1.728470e+09
# 1                 Financial services    1.019344e+10  2.912110e+09
# 2  Electrical & electronic equipment    1.595156e+10  1.443500e+10
# 3                   Biotech & pharma    7.441091e+10  2.209000e+10
# 4                 Financial services    1.880010e+10  2.828417e+10
#
#      ebitda_USD  grossProfit_USD  netIncome_USD  shortTermInvestments_USD  \
# 0  1.565910e+09     1.728470e+09   1.577340e+09              0.000000e+00
# 1  1.482090e+09     2.814320e+09   1.054100e+09              7.620000e+06
# 2  2.260000e+09     2.729000e+09   1.067000e+09              7.200000e+07
# 3  7.165000e+09     1.715400e+10   2.155000e+09              8.490000e+08
# 4  2.565400e+08     2.828417e+10   1.991360e+09              1.841500e+10
#
#    totalAssets_USD  totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0     1.107567e+10          8.544560e+09   7.302500e+08     1.004443e+10
# 1     1.589659e+10          6.626860e+09   1.647190e+09     9.574530e+09
# 2     1.248000e+10          1.710000e+08   4.344000e+09     3.670000e+09
# 3     6.065100e+10          9.220000e+08   1.911300e+10     1.404400e+10
# 4     5.454917e+11          8.914511e+10   1.360678e+10     2.343785e+10
#
#    Scope_3_emissions_amount  scope_1_2_emissions_amount  Year_sq
# 0                     57.21                  338.950000  4072324
# 1                     14.13                 7197.250000  4072324
# 2                 104000.00               380471.810000  4072324
# 3                  25361.00               707252.916667  4072324
# 4                     81.00                61086.500000  4072324

# %%
waste_no_transform['Primary_sector'].value_counts()
# Out:
# Primary_sector
# Financial services                                    799
# Electrical & electronic equipment                     501
# Chemicals                                             388
# Construction                                          245
# Food & beverage processing                            196
# Biotech & pharma                                      193
# Media, telecommunications & data center services      190
# Specialized professional services                     153
# Discretionary retail                                  133
# Powered machinery                                     122
# Convenience retail                                    118
# Trading, wholesale, distribution, rental & leasing    105
# Energy utility networks                                95
# Medical equipment & supplies                           89
# Thermal power generation                               78
# Bars, hotels & restaurants                             75
# Metal products manufacturing                           70
# Other services                                         66
# Transportation equipment                               65
# Paper products & packaging                             59
# Plastic product manufacturing                          59
# Leisure & home manufacturing                           54
# Rail transport                                         51
# IT & software development                              49
# Web & marketing services                               49
# Metallic mineral mining                                44
# Metal smelting, refining & forming                     42
# Wood & rubber products                                 42
# Print & publishing services                            41
# Light manufacturing                                    41
# Intermodal transport & logistics                       40
# 0                                                      38
# Textiles & fabric goods                                37
# Air transport                                          34
# Commercial & consumer services                         34
# Industrial support services                            33
# Land & property ownership & development                33
# Marine transport                                       33
# Fish & animal farming                                  29
# Entertainment facilities                               26
# Wood & paper materials                                 25
# Non-energy utilities                                   25
# Tobacco                                                23
# Apparel design                                         22
# Health care provision                                  21
# Oil & gas storage & transportation                     19
# Oil & gas extraction & production                      18
# Renewable power generation                             17
# Cement & concrete                                      16
# Other materials                                        16
# Road transport                                         11
# Renewable energy equipment                             10
# Oil & gas retailing                                    10
# Accessories                                             9
# Other mineral mining                                    6
# Logging & rubber tapping                                6
# Oil & gas processing                                    6
# Name: count, dtype: int64

# %%
waste_no_transform['Primary_activity'].value_counts().head(20)
# Out:
# Primary_activity
# Banks                                                 381
# Insurance                                             231
# Electronic components                                 197
# Telecommunications services                           173
# Pharmaceuticals                                       151
# Other professional services                           146
# REIT                                                  131
# Other base chemicals                                  125
# Supermarkets, food & drugstores                       118
# Specialty chemicals                                   114
# Electrical equipment                                  103
# Personal care & household products                    101
# Electronic equipment                                   86
# Transportation infrastructure & other construction     81
# Electricity networks                                   78
# Non-residential building construction                  76
# Other food processing                                  69
# CCGT generation                                        67
# Apparel stores                                         66
# Industrial machinery                                   62
# Name: count, dtype: int64

# %%
# Looking at missing data
print(waste_no_transform.isnull().mean().sort_values(ascending=False).round(3) * 100)
# Out:
# Market_Cap_USD                14.9
# netIncome_USD                 14.6
# totalInvestments_USD          14.6
# totalEquity_USD               14.6
# Revenue_USD                   14.6
# ebitda_USD                    14.6
# grossProfit_USD               14.6
# totalDebt_USD                 14.6
# shortTermInvestments_USD      14.6
# totalAssets_USD               14.6
# scope_1_2_emissions_amount     0.3
# Scope_3_emissions_amount       0.0
# account_id                     0.0
# Year                           0.0
# Primary_sector                 0.0
# Primary_activity               0.0
# Countries                      0.0
# Year_sq                        0.0
# dtype: float64

# %% [markdown]
# Apply signed log transformation and split data by company and year into train_df (2018-2022) and test_df (2023):

# %%
numeric_cols = [
    'Market_Cap_USD', 'totalInvestments_USD', 'Revenue_USD', 'ebitda_USD', 'grossProfit_USD',
    'netIncome_USD', 'totalDebt_USD', 'shortTermInvestments_USD', 'totalAssets_USD',
    'totalEquity_USD', 'scope_1_2_emissions_amount', 'Scope_3_emissions_amount'
]
required_cols = [
    'account_id', 'Year', 'Year_sq', 'Countries', 'Primary_activity', 'Primary_sector'
] + numeric_cols

# --- Prepare Data ---
df = waste_no_transform[required_cols].dropna()

# --- Signed log transform ---
def signed_log(x):
    return np.sign(x) * np.log(np.abs(x) + 1)

for col in numeric_cols:
    df[f'slog_{col}'] = signed_log(df[col])

# --- Company-level split by year ---
train_df = df[df['Year'].between(2018, 2022)].copy()
test_df  = df[df['Year'] == 2023].copy()

# Keep only companies present in training
valid_companies = set(train_df['account_id'].unique())
test_df = test_df[test_df['account_id'].isin(valid_companies)].copy()

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (3282, 30)
# Test shape: (678, 30)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3282 entries, 0 to 3882
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       3282 non-null   int64
#  1   Year                             3282 non-null   int64
#  2   Year_sq                          3282 non-null   int64
#  3   Countries                        3282 non-null   object
#  4   Primary_activity                 3282 non-null   object
#  5   Primary_sector                   3282 non-null   object
#  6   Market_Cap_USD                   3282 non-null   float64
#  7   totalInvestments_USD             3282 non-null   float64
#  8   Revenue_USD                      3282 non-null   float64
#  9   ebitda_USD                       3282 non-null   float64
#  10  grossProfit_USD                  3282 non-null   float64
#  11  netIncome_USD                    3282 non-null   float64
#  12  totalDebt_USD                    3282 non-null   float64
#  13  shortTermInvestments_USD         3282 non-null   float64
#  14  totalAssets_USD                  3282 non-null   float64
#  15  totalEquity_USD                  3282 non-null   float64
#  16  scope_1_2_emissions_amount       3282 non-null   float64
#  17  Scope_3_emissions_amount         3282 non-null   float64
#  18  slog_Market_Cap_USD              3282 non-null   float64
#  19  slog_totalInvestments_USD        3282 non-null   float64
#  20  slog_Revenue_USD                 3282 non-null   float64
#  21  slog_ebitda_USD                  3282 non-null   float64
#  22  slog_grossProfit_USD             3282 non-null   float64
#  23  slog_netIncome_USD               3282 non-null   float64
#  24  slog_totalDebt_USD               3282 non-null   float64
#  25  slog_shortTermInvestments_USD    3282 non-null   float64
#  26  slog_totalAssets_USD             3282 non-null   float64
#  27  slog_totalEquity_USD             3282 non-null   float64
#  28  slog_scope_1_2_emissions_amount  3282 non-null   float64
#  29  slog_Scope_3_emissions_amount    3282 non-null   float64
# dtypes: float64(24), int64(3), object(3)
# memory usage: 794.9+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 678 entries, 3885 to 4806
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       678 non-null    int64
#  1   Year                             678 non-null    int64
#  2   Year_sq                          678 non-null    int64
#  3   Countries                        678 non-null    object
#  4   Primary_activity                 678 non-null    object
#  5   Primary_sector                   678 non-null    object
#  6   Market_Cap_USD                   678 non-null    float64
#  7   totalInvestments_USD             678 non-null    float64
#  8   Revenue_USD                      678 non-null    float64
#  9   ebitda_USD                       678 non-null    float64
#  10  grossProfit_USD                  678 non-null    float64
#  11  netIncome_USD                    678 non-null    float64
#  12  totalDebt_USD                    678 non-null    float64
#  13  shortTermInvestments_USD         678 non-null    float64
#  14  totalAssets_USD                  678 non-null    float64
#  15  totalEquity_USD                  678 non-null    float64
#  16  scope_1_2_emissions_amount       678 non-null    float64
#  17  Scope_3_emissions_amount         678 non-null    float64
#  18  slog_Market_Cap_USD              678 non-null    float64
#  19  slog_totalInvestments_USD        678 non-null    float64
#  20  slog_Revenue_USD                 678 non-null    float64
#  21  slog_ebitda_USD                  678 non-null    float64
#  22  slog_grossProfit_USD             678 non-null    float64
#  23  slog_netIncome_USD               678 non-null    float64
#  24  slog_totalDebt_USD               678 non-null    float64
#  25  slog_shortTermInvestments_USD    678 non-null    float64
#  26  slog_totalAssets_USD             678 non-null    float64
#  27  slog_totalEquity_USD             678 non-null    float64
#  28  slog_scope_1_2_emissions_amount  678 non-null    float64
#  29  slog_Scope_3_emissions_amount    678 non-null    float64
# dtypes: float64(24), int64(3), object(3)
# memory usage: 164.2+ KB

# %%
print((train_df == 0).sum().sum())
print((test_df == 0).sum().sum())
# Out:
# 1474
# 452

# %% [markdown]
# ## Waste Null Mixed-Effects Model
#
# Null mixed-effects model (random intercept only) to predict log-transformed Scope 3 emissions. The model serves as a baseline, capturing only the average emission level for each company, without incorporating any explanatory variables, and quantifies the improvement gained by including additional features and structure. The model is trained on 2018–2022 data and evaluated on a test set from 2023.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies
# - Fixed Effects:
#     - Intercept only (no predictors)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE NULL MODEL (random intercept only) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    null_model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ 1",
        train_df,
        groups=train_df["account_id"]
    )
    null_result = null_model.fit(method="lbfgs")

if not null_result.converged:
    print("WARNING: Null model did not fully converge.")

print(null_result.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_null'] = null_result.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_null']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_null'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics text
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[0], color='gray')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Null Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[1], color='gray')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Null Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Null Model Predicted")
plt.xscale("log")
plt.title("Null Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
null_model_metrics = {
    "Model": "Null (RI)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "Random intercept only"
}
# Out:
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 3282    Method:             REML
# No. Groups:       769     Scale:              0.7766
# Min. group size:  1       Log-Likelihood:     -5530.7918
# Max. group size:  5       Converged:          Yes
# Mean group size:  4.3
# ------------------------------------------------------------------------------
#                  Coef.     Std.Err.       z        P>|z|     [0.025     0.975]
# ------------------------------------------------------------------------------
# Intercept        7.956        0.085     93.307     0.000      7.789      8.123
# Group Var        5.369        0.370
# ==========================================================================
#
# R²(log):    -0.62%
# R²(orig):   -9.20%
# MAPE:       4000.78%
# MAPE(log):  39.28%
# MAE(log):   1.98
# RMSLE:      2.41
# RMSE:       85600.06
# MAE:        26617.98

# %% [markdown]
# ## Waste Two-Level Mixed-Effects Model
#
# Two-level hierarchical linear mixed-effects model to predict log-transformed Scope 3 emissions at the company level. The model is fit to training data (from 2018–2022), and predictions are evaluated on a test set (from 2023).  This model provides a baseline for including time trends and company-level variability.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies.<br>
# - Fixed Effects:
#     - Year (numeric)
#     - Year squared ('Year_sq', quadratic time trend)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- Check group sizes ---
group_sizes = train_df.groupby('account_id').size()
print("Two-Level Model: Company/year group size summary:")
print(group_sizes.describe())

# --- FIT THE TWO-LEVEL MODEL (random intercept, +Year, +Year_sq) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ Year + Year_sq",
        train_df,
        groups=train_df["account_id"],
        re_formula="1"
    )
    result_twolevel = model.fit(method="lbfgs")

if not result_twolevel.converged:
    print("WARNING: Two-level mixed model did not fully converge.")

print(result_twolevel.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_twolevel.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_mixed']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='orange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Two-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='orange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Two-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="orange", alpha=0.5, label="Two-Level Model Predicted")
plt.xscale("log")
plt.title("Two-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
two_level_model_metrics = {
    "Model": "2-level (RI+S)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "+Year, Year_sq"
}
# Out:
# Two-Level Model: Company/year group size summary:
# count    769.000000
# mean       4.267880
# std        1.259762
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000
# dtype: float64
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 3282    Method:             REML
# No. Groups:       769     Scale:              0.7769
# Min. group size:  1       Log-Likelihood:     -5537.7493
# Max. group size:  5       Converged:          Yes
# Mean group size:  4.3
# ----------------------------------------------------------------------------
#                Coef.      Std.Err.     z      P>|z|     [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept    16210.412   38333.178    0.423   0.672   -58921.235   91342.060
# Year           -16.050      37.953   -0.423   0.672      -90.436      58.337
# Year_sq          0.004       0.009    0.423   0.672       -0.014       0.022
# Group Var        5.371       0.370
# ==========================================================================
#
# R²(log):    -0.34%
# R²(orig):   -9.10%
# MAPE:       4201.89%
# MAPE(log):  39.44%
# MAE(log):   1.97
# RMSLE:      2.41
# RMSE:       85558.41
# MAE:        26597.18

# %% [markdown]
# ## Waste Three-Level Mixed-Effects Model
#
# A three-level hierarchical linear mixed-effects model is used to predict log-transformed Scope 3 emissions. It takes into account differences between primary activity, differences between companies, and changes over time. The model is trained using data from 2018 to 2022, and then tested on new data from 2023. This model provides insight on how emissions are influenced by primary activity, by individual companies, by financial and emissions factors, and by trends over time.
#
# Model Structure:
#
# - Level 3 (Primary Activity):<br>
#     - Random intercept and random slope for Year for each primary activity ('Primary_activity'), capturing baseline primary activity and primary activity-specific time trends.<br>
# - Level 2 (Account/Company):
#     - Random intercept for each company ('account_id'), capturing company-level deviations within each primary activity.
# - Level 1 (Yearly Observations):
#     - Repeated annual observations within each company.
#
# - Fixed Effects:
#     - Signed log-transformed market cap ('slog_Market_Cap_USD')
#     - Signed log-transformed revenue ('slog_Revenue_USD')
#     - Signed log-transformed EBITDA ('slog_ebitda_USD')
#     - Signed log-transformed Scope 1 & 2 emissions ('slog_scope_1_2_emissions_amount')

# %%
# --- Ensure grouping/categorical variables are string ---
for col in ['Countries', 'account_id', 'Primary_activity', 'Primary_sector']:
    train_df[col] = train_df[col].astype(str)
    test_df[col] = test_df[col].astype(str)

# --- Center the Year variable ---
year_mean = train_df['Year'].mean()
train_df['Year_centered'] = train_df['Year'] - year_mean
test_df['Year_centered'] = test_df['Year'] - year_mean

# --- Ensure log-transformed target exists ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE 3-LEVEL MIXED MODEL with Primary_activity as Level 3 group ---
vc = {'account_id': '0 + C(account_id)'}  # Level 2: account_id random intercept

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model_3level = MixedLM.from_formula(
        'log_Scope_3_emissions_amount ~ slog_Market_Cap_USD + slog_Revenue_USD + slog_ebitda_USD + slog_scope_1_2_emissions_amount',
        groups='Primary_activity',
        re_formula='~Year_centered',
        vc_formula=vc,
        data=train_df
    )
    result_3level = model_3level.fit(method="lbfgs", maxiter=1000)

if not result_3level.converged:
    print("WARNING: Three-level mixed model did not fully converge.")

print(result_3level.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_3level.predict(test_df)

# --- Compute back-transformed values ---
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])

# --- Robust Mask for finite values everywhere ---
mask = (
    np.isfinite(test_df['log_Scope_3_emissions_amount']) &
    np.isfinite(test_df['predicted_mixed']) &
    np.isfinite(test_df['Reported_Scope_3']) &
    np.isfinite(test_df['Predicted_Scope_3'])
)
test_df = test_df.loc[mask].copy()

y_true_log = test_df['log_Scope_3_emissions_amount'].values
y_pred_log = test_df['predicted_mixed'].values
y_true = test_df['Reported_Scope_3'].values
y_pred = test_df['Predicted_Scope_3'].values

# Final defensive check and diagnostics
arrays = {
    "y_true_log": y_true_log,
    "y_pred_log": y_pred_log,
    "y_true": y_true,
    "y_pred": y_pred,
}
for arr_name, arr in arrays.items():
    if not np.all(np.isfinite(arr)):
        print(f"ERROR: {arr_name} contains non-finite values!")
        print(f"Non-finite indices: {np.where(~np.isfinite(arr))[0]}")
        print(f"Values: {arr[~np.isfinite(arr)]}")
        raise ValueError(f"{arr_name} contains infs or NaNs after masking!")

# --- METRICS ---
mae_log = mean_absolute_error(y_true_log, y_pred_log)
nonzero_mask = y_true_log != 0
if np.any(nonzero_mask):
    mape_log = np.mean(np.abs((y_true_log[nonzero_mask] - y_pred_log[nonzero_mask]) / y_true_log[nonzero_mask])) * 100
else:
    mape_log = np.nan

r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)

metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
if len(np.unique(y_pred_log)) > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Three-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()
axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

if len(np.unique(y_pred)) > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Three-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()
axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Filter strictly positive values for histogram (log x-axis requires >0)
y_true_pos = y_true[y_true > 0]
y_pred_pos = y_pred[y_pred > 0]

if y_true_pos.size > 0 and y_pred_pos.size > 0:
    min_val = min(y_true_pos.min(), y_pred_pos.min())
    max_val = max(y_true_pos.max(), y_pred_pos.max())
    if min_val == max_val:
        print("Skipping histogram: Only one unique positive value present.")
    else:
        log_bins = np.logspace(np.log10(min_val), np.log10(max_val), 100)

        plt.figure(figsize=(8, 5))
        sns.histplot(y_true_pos, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
        sns.histplot(y_pred_pos, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Three-Level Model Predicted")
        plt.xscale("log")
        plt.title("Three-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
        plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
        plt.ylabel("Density")
        plt.legend()
        plt.tight_layout()
        plt.show()
else:
    print("Skipping histogram: Not enough positive values in y_true or y_pred for log-scale histogram.")

# --- RETURN METRICS FOR SUMMARY TABLE ---
three_level_model_metrics = {
    "Model": "3-level (Primary Activity/Account/Year)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,
    "MAPE(log)": mape_log,
}
# Out:
#                      Mixed Linear Model Regression Results
# ===============================================================================
# Model:               MixedLM  Dependent Variable:  log_Scope_3_emissions_amount
# No. Observations:    3282     Method:              REML
# No. Groups:          122      Scale:               0.7234
# Min. group size:     1        Log-Likelihood:      -5328.3593
# Max. group size:     254      Converged:           Yes
# Mean group size:     26.9
# -------------------------------------------------------------------------------
#                                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------------
# Intercept                            -0.929    0.780 -1.190 0.234 -2.458  0.601
# slog_Market_Cap_USD                   0.213    0.034  6.245 0.000  0.146  0.280
# slog_Revenue_USD                      0.018    0.010  1.867 0.062 -0.001  0.037
# slog_ebitda_USD                      -0.000    0.003 -0.040 0.968 -0.006  0.006
# slog_scope_1_2_emissions_amount       0.323    0.025 12.942 0.000  0.274  0.371
# Primary_activity Var                  0.909    0.216
# Primary_activity x Year_centered Cov  0.011    0.111
# Year_centered Var                     0.183
# account_id Var                        2.276    0.205
# ===============================================================================
#
# R²(log):    35.26%
# R²(orig):   -3.44%
# MAPE:       1248.57%
# MAPE(log):  31.54%
# MAE(log):   1.57
# RMSLE:      1.93
# RMSE:       83309.39
# MAE:        24848.71

# %% [markdown]
# ## Waste Full Mixed-Effects Model
#
# A full mixed-effects model is used to predict company Scope 3 emissions, using financial and emissions data, along with information about country, industry, and year. The model is trained on data from 2018 to 2022, and tested on data from 2023. This full model helps provides insights into how a company’s finances, emissions, primary activity, country and the year influence emissions.<br>
#
# Model Structure:<br>
#
# - Random Effects:<br>
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:<br>
#     - Signed log-transformed financial and emissions features:<br>
#         - Market Cap ('slog_Market_Cap_USD')<br>
#         - Revenue ('slog_Revenue_USD')<br>
#         - EBITDA ('slog_ebitda_USD')<br>
#         - Gross Profit ('slog_grossProfit_USD')<br>
#         - Net Income ('slog_netIncome_USD')<br>
#         - Short-Term Investments ('slog_shortTermInvestments_USD')<br>
#         - Total Assets ('slog_totalAssets_USD')<br>
#         - Total Equity ('slog_totalEquity_USD')<br>
#         - Scope 1&2 Emissions ('slog_scope_1_2_emissions_amount')<br>
#     - Country ('Countries', as a categorical variable)<br>
#     - Primary Activity ('Primary_activity', as a categorical variable)<br>
#     - Year (numeric)<br>

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3282 entries, 0 to 3882
# Data columns (total 32 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       3282 non-null   object
#  1   Year                             3282 non-null   int64
#  2   Year_sq                          3282 non-null   int64
#  3   Countries                        3282 non-null   object
#  4   Primary_activity                 3282 non-null   object
#  5   Primary_sector                   3282 non-null   object
#  6   Market_Cap_USD                   3282 non-null   float64
#  7   totalInvestments_USD             3282 non-null   float64
#  8   Revenue_USD                      3282 non-null   float64
#  9   ebitda_USD                       3282 non-null   float64
#  10  grossProfit_USD                  3282 non-null   float64
#  11  netIncome_USD                    3282 non-null   float64
#  12  totalDebt_USD                    3282 non-null   float64
#  13  shortTermInvestments_USD         3282 non-null   float64
#  14  totalAssets_USD                  3282 non-null   float64
#  15  totalEquity_USD                  3282 non-null   float64
#  16  scope_1_2_emissions_amount       3282 non-null   float64
#  17  Scope_3_emissions_amount         3282 non-null   float64
#  18  slog_Market_Cap_USD              3282 non-null   float64
#  19  slog_totalInvestments_USD        3282 non-null   float64
#  20  slog_Revenue_USD                 3282 non-null   float64
#  21  slog_ebitda_USD                  3282 non-null   float64
#  22  slog_grossProfit_USD             3282 non-null   float64
#  23  slog_netIncome_USD               3282 non-null   float64
#  24  slog_totalDebt_USD               3282 non-null   float64
#  25  slog_shortTermInvestments_USD    3282 non-null   float64
#  26  slog_totalAssets_USD             3282 non-null   float64
#  27  slog_totalEquity_USD             3282 non-null   float64
#  28  slog_scope_1_2_emissions_amount  3282 non-null   float64
#  29  slog_Scope_3_emissions_amount    3282 non-null   float64
#  30  log_Scope_3_emissions_amount     3282 non-null   float64
#  31  Year_centered                    3282 non-null   float64
# dtypes: float64(26), int64(2), object(4)
# memory usage: 975.2+ KB

# %%
# --- Feature and target columns ---
numeric_cols = [
    'Market_Cap_USD', 'totalInvestments_USD', 'Revenue_USD', 'ebitda_USD', 'grossProfit_USD',
    'netIncome_USD', 'totalDebt_USD', 'shortTermInvestments_USD', 'totalAssets_USD',
    'totalEquity_USD', 'scope_1_2_emissions_amount', 'Scope_3_emissions_amount'
]
feature_cols_slog = [f'slog_{col}' for col in numeric_cols if col != 'Scope_3_emissions_amount']
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
required_cols = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_full = train_df.dropna(subset=required_cols).copy()
test_df_full = test_df.dropna(subset=required_cols).copy()

if test_df_full.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the full mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_full, groups=train_df_full['account_id'])
        mdf = md.fit(reml=False)
    print(mdf.summary())

    # --- Predict on test set ---
    test_df_full['predicted_log'] = mdf.predict(test_df_full)
    test_df_full['predicted'] = np.sign(test_df_full['predicted_log']) * (np.expm1(np.abs(test_df_full['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_full[target_col_slog]
    y_pred_log = test_df_full['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_full['predicted']

    # Mask for finite values
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nFull Mixed-Effects Model (Full Model) Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf.params,
        'pvalue': mdf.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Full Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Full Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Full Model Predicted")
    plt.xscale("log")
    plt.title("Full Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    full_model_metrics = {
        "Model": "Full Model",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                         Mixed Linear Model Regression Results
# =====================================================================================================================
# Model:                          MixedLM               Dependent Variable:               slog_Scope_3_emissions_amount
# No. Observations:               3282                  Method:                           ML
# No. Groups:                     769                   Scale:                            0.8031
# Min. group size:                1                     Log-Likelihood:                   -5122.8383
# Max. group size:                5                     Converged:                        Yes
# Mean group size:                4.3
# ---------------------------------------------------------------------------------------------------------------------
#                                                                           Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 22.636   23.688  0.956 0.339 -23.792 69.064
# C(Countries)[T.Austria]                                                    2.769    1.192  2.323 0.020   0.433  5.104
# C(Countries)[T.Belgium]                                                   -1.095    0.669 -1.638 0.102  -2.406  0.216
# C(Countries)[T.Bermuda]                                                   -1.422    1.032 -1.378 0.168  -3.445  0.601
# C(Countries)[T.Brazil]                                                    -1.143    0.521 -2.194 0.028  -2.163 -0.122
# C(Countries)[T.Canada]                                                    -0.252    0.459 -0.550 0.582  -1.151  0.646
# C(Countries)[T.Chile]                                                     -1.879    1.592 -1.180 0.238  -5.000  1.242
# C(Countries)[T.China]                                                     -0.582    0.548 -1.063 0.288  -1.655  0.491
# C(Countries)[T.Denmark]                                                   -1.338    0.772 -1.733 0.083  -2.852  0.175
# C(Countries)[T.Finland]                                                   -0.534    0.550 -0.971 0.331  -1.613  0.544
# C(Countries)[T.France]                                                    -0.310    0.452 -0.685 0.493  -1.195  0.576
# C(Countries)[T.Germany]                                                   -0.405    0.466 -0.869 0.385  -1.317  0.508
# C(Countries)[T.Greece]                                                    -1.031    0.886 -1.163 0.245  -2.768  0.706
# C(Countries)[T.Hungary]                                                   -0.327    1.384 -0.236 0.813  -3.038  2.385
# C(Countries)[T.India]                                                     -2.355    1.038 -2.269 0.023  -4.388 -0.321
# C(Countries)[T.Ireland]                                                   -0.106    0.643 -0.165 0.869  -1.367  1.154
# C(Countries)[T.Israel]                                                    -0.461    1.124 -0.410 0.682  -2.664  1.742
# C(Countries)[T.Italy]                                                     -0.884    0.562 -1.572 0.116  -1.986  0.218
# C(Countries)[T.Japan]                                                     -0.452    0.392 -1.152 0.249  -1.221  0.317
# C(Countries)[T.Mexico]                                                    -1.659    1.164 -1.424 0.154  -3.941  0.624
# C(Countries)[T.Netherlands]                                               -0.228    0.575 -0.397 0.691  -1.355  0.898
# C(Countries)[T.New Zealand]                                                0.199    0.787  0.253 0.801  -1.343  1.740
# C(Countries)[T.Norway]                                                    -2.157    0.554 -3.891 0.000  -3.243 -1.070
# C(Countries)[T.Peru]                                                       1.194    1.356  0.880 0.379  -1.465  3.852
# C(Countries)[T.Portugal]                                                  -1.712    0.765 -2.236 0.025  -3.212 -0.211
# C(Countries)[T.Singapore]                                                 -1.364    1.169 -1.167 0.243  -3.655  0.926
# C(Countries)[T.South Africa]                                              -1.071    0.442 -2.425 0.015  -1.937 -0.206
# C(Countries)[T.South Korea]                                               -1.323    0.486 -2.720 0.007  -2.277 -0.370
# C(Countries)[T.Spain]                                                     -1.320    0.480 -2.751 0.006  -2.261 -0.380
# C(Countries)[T.Sweden]                                                    -1.524    0.825 -1.846 0.065  -3.141  0.094
# C(Countries)[T.Switzerland]                                               -0.609    0.485 -1.256 0.209  -1.558  0.341
# C(Countries)[T.Thailand]                                                  -0.620    0.786 -0.789 0.430  -2.162  0.921
# C(Countries)[T.Turkey]                                                    -3.962    1.632 -2.428 0.015  -7.160 -0.763
# C(Countries)[T.USA]                                                       -0.654    0.387 -1.690 0.091  -1.413  0.104
# C(Countries)[T.United Kingdom]                                            -1.503    0.406 -3.700 0.000  -2.299 -0.707
# C(Primary_activity)[T.Accessories manufacture]                            -0.966    1.134 -0.852 0.394  -3.188  1.256
# C(Primary_activity)[T.Aerospace]                                           1.592    1.478  1.077 0.281  -1.304  4.488
# C(Primary_activity)[T.Agricultural chemicals]                              2.482    1.477  1.680 0.093  -0.413  5.377
# C(Primary_activity)[T.Agriculture, construction & mining machinery]        0.453    0.853  0.530 0.596  -1.220  2.125
# C(Primary_activity)[T.Alcoholic beverages]                                 0.460    0.765  0.601 0.548  -1.040  1.959
# C(Primary_activity)[T.Animal processing]                                   2.942    0.908  3.240 0.001   1.162  4.722
# C(Primary_activity)[T.Apparel & footwear design]                           0.308    0.916  0.336 0.737  -1.487  2.103
# C(Primary_activity)[T.Apparel stores]                                      0.666    0.737  0.904 0.366  -0.779  2.112
# C(Primary_activity)[T.Aquaculture]                                         1.850    1.060  1.745 0.081  -0.228  3.928
# C(Primary_activity)[T.Asset managers]                                     -1.646    0.739 -2.228 0.026  -3.093 -0.198
# C(Primary_activity)[T.Automobiles]                                         1.472    0.802  1.835 0.066  -0.100  3.044
# C(Primary_activity)[T.Baked goods & cereals]                               1.072    1.441  0.744 0.457  -1.752  3.895
# C(Primary_activity)[T.Banks]                                              -1.298    0.638 -2.033 0.042  -2.549 -0.046
# C(Primary_activity)[T.Batteries]                                           1.065    1.015  1.049 0.294  -0.924  3.055
# C(Primary_activity)[T.Biotechnology]                                       0.001    0.794  0.001 0.999  -1.557  1.558
# C(Primary_activity)[T.Building sub-contractors]                            2.573    0.983  2.616 0.009   0.646  4.501
# C(Primary_activity)[T.Bus & taxi]                                          1.522    1.443  1.055 0.291  -1.305  4.349
# C(Primary_activity)[T.CCGT generation]                                     0.146    0.802  0.182 0.856  -1.426  1.718
# C(Primary_activity)[T.Cattle farming]                                      3.839    1.482  2.590 0.010   0.934  6.744
# C(Primary_activity)[T.Cement]                                              0.568    1.317  0.431 0.666  -2.013  3.149
# C(Primary_activity)[T.Clothing manufacture]                                1.362    0.876  1.555 0.120  -0.354  3.078
# C(Primary_activity)[T.Coal generation]                                    -2.509    1.697 -1.479 0.139  -5.835  0.817
# C(Primary_activity)[T.Commercial services]                                 0.273    0.918  0.298 0.766  -1.526  2.073
# C(Primary_activity)[T.Communications equipment]                           -1.169    0.811 -1.442 0.149  -2.758  0.420
# C(Primary_activity)[T.Computer hardware]                                  -0.895    0.875 -1.024 0.306  -2.609  0.819
# C(Primary_activity)[T.Consumer services]                                   0.938    1.472  0.638 0.524  -1.946  3.823
# C(Primary_activity)[T.Dairy & egg products]                                2.549    1.114  2.288 0.022   0.366  4.733
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                 1.222    0.800  1.527 0.127  -0.346  2.791
# C(Primary_activity)[T.Department stores]                                   0.648    0.976  0.663 0.507  -1.266  2.561
# C(Primary_activity)[T.Discretionary delivery retail]                       0.760    0.981  0.774 0.439  -1.164  2.684
# C(Primary_activity)[T.Education services]                                 -0.029    1.442 -0.020 0.984  -2.855  2.796
# C(Primary_activity)[T.Electrical equipment]                                0.868    0.702  1.237 0.216  -0.508  2.244
# C(Primary_activity)[T.Electricity networks]                               -0.064    0.750 -0.086 0.932  -1.534  1.406
# C(Primary_activity)[T.Electronic components]                               0.100    0.670  0.149 0.881  -1.213  1.413
# C(Primary_activity)[T.Electronic equipment]                                0.207    0.710  0.292 0.770  -1.184  1.599
# C(Primary_activity)[T.Energy infrastructure construction]                  2.559    1.150  2.224 0.026   0.304  4.813
# C(Primary_activity)[T.Energy services & equipment]                         1.659    0.945  1.755 0.079  -0.194  3.511
# C(Primary_activity)[T.Engineering services]                               -0.005    1.221 -0.004 0.997  -2.398  2.388
# C(Primary_activity)[T.Engines & motors]                                    1.246    0.819  1.521 0.128  -0.360  2.851
# C(Primary_activity)[T.Fabricated metal components]                         1.238    0.769  1.609 0.108  -0.270  2.745
# C(Primary_activity)[T.Fast food]                                           4.347    1.005  4.326 0.000   2.378  6.317
# C(Primary_activity)[T.Finished wood products]                              1.236    1.481  0.835 0.404  -1.667  4.139
# C(Primary_activity)[T.Fishing]                                             1.546    1.464  1.056 0.291  -1.323  4.415
# C(Primary_activity)[T.Food & beverage amenities]                           5.474    1.456  3.759 0.000   2.620  8.329
# C(Primary_activity)[T.Food & beverage wholesale]                           1.563    1.122  1.393 0.164  -0.636  3.763
# C(Primary_activity)[T.Furniture]                                           1.492    0.860  1.735 0.083  -0.193  3.177
# C(Primary_activity)[T.Gambling]                                            2.278    0.906  2.515 0.012   0.502  4.053
# C(Primary_activity)[T.Gas utilities]                                      -0.659    0.931 -0.707 0.480  -2.484  1.167
# C(Primary_activity)[T.Glass products]                                      1.064    1.144  0.930 0.353  -1.179  3.306
# C(Primary_activity)[T.Grain & corn milling]                                3.387    1.653  2.049 0.040   0.147  6.628
# C(Primary_activity)[T.Health care facilities]                              1.827    0.989  1.847 0.065  -0.112  3.766
# C(Primary_activity)[T.Health care services]                                0.495    0.800  0.618 0.536  -1.074  2.063
# C(Primary_activity)[T.Health care supplies]                                0.374    0.852  0.440 0.660  -1.295  2.043
# C(Primary_activity)[T.Homeware]                                            1.712    1.461  1.172 0.241  -1.152  4.575
# C(Primary_activity)[T.Hotels & lodging]                                    2.163    0.784  2.760 0.006   0.627  3.699
# C(Primary_activity)[T.Hydro generation]                                   -2.729    1.684 -1.621 0.105  -6.029  0.571
# C(Primary_activity)[T.Industrial machinery]                               -0.223    0.757 -0.295 0.768  -1.707  1.261
# C(Primary_activity)[T.Inorganic base chemicals]                            1.283    0.925  1.388 0.165  -0.529  3.096
# C(Primary_activity)[T.Insurance]                                          -1.564    0.646 -2.420 0.016  -2.831 -0.297
# C(Primary_activity)[T.Intermodal transport]                                0.108    1.442  0.075 0.940  -2.718  2.933
# C(Primary_activity)[T.Iron & steel]                                        1.336    1.041  1.283 0.199  -0.705  3.377
# C(Primary_activity)[T.Logging]                                             1.222    1.440  0.849 0.396  -1.601  4.044
# C(Primary_activity)[T.Logistics - 3rd party]                              -0.666    0.983 -0.678 0.498  -2.594  1.261
# C(Primary_activity)[T.Logistics - transport]                               0.551    1.455  0.379 0.705  -2.301  3.402
# C(Primary_activity)[T.Marine freight]                                     -0.356    0.922 -0.386 0.700  -2.164  1.452
# C(Primary_activity)[T.Marketing]                                          -0.451    0.778 -0.579 0.562  -1.976  1.074
# C(Primary_activity)[T.Medical equipment]                                  -0.535    0.731 -0.731 0.465  -1.968  0.899
# C(Primary_activity)[T.Metal containers & packaging]                        2.272    0.865  2.625 0.009   0.576  3.968
# C(Primary_activity)[T.Metal processing]                                    1.879    1.120  1.678 0.093  -0.315  4.074
# C(Primary_activity)[T.Nitrogenous fertilizers]                             0.335    1.158  0.290 0.772  -1.933  2.604
# C(Primary_activity)[T.Non-CCGT generation]                                -0.477    1.446 -0.330 0.741  -3.312  2.358
# C(Primary_activity)[T.Non-alcoholic beverages]                             1.278    0.896  1.425 0.154  -0.479  3.034
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                         0.062    1.233  0.050 0.960  -2.356  2.479
# C(Primary_activity)[T.Non-residential building construction]               3.005    0.739  4.066 0.000   1.556  4.453
# C(Primary_activity)[T.Oil & gas extraction]                               -0.412    0.960 -0.430 0.667  -2.294  1.469
# C(Primary_activity)[T.Oil & gas marketing & retailing]                     2.021    1.164  1.735 0.083  -0.261  4.303
# C(Primary_activity)[T.Oil & gas pipelines & storage]                       0.253    0.922  0.274 0.784  -1.553  2.059
# C(Primary_activity)[T.Oil & gas refining]                                  3.083    1.495  2.061 0.039   0.152  6.013
# C(Primary_activity)[T.Other base chemicals]                                1.888    0.700  2.698 0.007   0.516  3.259
# C(Primary_activity)[T.Other containers & packaging]                        2.387    0.985  2.424 0.015   0.457  4.317
# C(Primary_activity)[T.Other food processing]                               2.312    0.749  3.087 0.002   0.844  3.781
# C(Primary_activity)[T.Other non-ferrous ore mining]                        0.181    0.982  0.185 0.854  -1.744  2.106
# C(Primary_activity)[T.Other non-metallic minerals]                         2.171    1.454  1.493 0.136  -0.680  5.021
# C(Primary_activity)[T.Other professional services]                        -0.410    0.692 -0.592 0.554  -1.766  0.946
# C(Primary_activity)[T.Other renewable energy equipment]                    2.325    1.624  1.431 0.152  -0.859  5.508
# C(Primary_activity)[T.Other renewable generation]                          1.820    1.593  1.142 0.253  -1.303  4.942
# C(Primary_activity)[T.Paper products]                                      1.874    0.822  2.280 0.023   0.263  3.485
# C(Primary_activity)[T.Passenger airlines]                                  0.014    0.799  0.018 0.986  -1.551  1.580
# C(Primary_activity)[T.Passenger rail]                                      0.465    1.126  0.413 0.680  -1.741  2.671
# C(Primary_activity)[T.Personal care & household products]                  1.483    0.709  2.094 0.036   0.095  2.872
# C(Primary_activity)[T.Pharmaceuticals]                                     1.043    0.673  1.550 0.121  -0.276  2.363
# C(Primary_activity)[T.Plastic products]                                    1.328    0.787  1.687 0.092  -0.215  2.871
# C(Primary_activity)[T.Precious metals & minerals mining]                  -0.162    0.923 -0.176 0.861  -1.971  1.647
# C(Primary_activity)[T.Print publishing]                                    2.537    1.025  2.475 0.013   0.528  4.547
# C(Primary_activity)[T.Printing services]                                   1.040    1.111  0.936 0.349  -1.138  3.218
# C(Primary_activity)[T.Pulp & paper mills]                                  2.718    1.043  2.605 0.009   0.673  4.763
# C(Primary_activity)[T.REIT]                                                1.508    0.686  2.199 0.028   0.164  2.852
# C(Primary_activity)[T.Rail freight]                                        1.792    0.867  2.067 0.039   0.092  3.492
# C(Primary_activity)[T.Railroad rolling stock]                             -0.196    1.469 -0.133 0.894  -3.076  2.684
# C(Primary_activity)[T.Real estate owners & developers]                    -0.582    0.880 -0.662 0.508  -2.306  1.142
# C(Primary_activity)[T.Real estate services]                                1.727    0.916  1.885 0.059  -0.069  3.523
# C(Primary_activity)[T.Residential building construction]                   1.756    0.740  2.372 0.018   0.305  3.207
# C(Primary_activity)[T.Rubber products]                                     0.833    0.908  0.917 0.359  -0.946  2.611
# C(Primary_activity)[T.Semiconductors]                                      0.277    0.890  0.311 0.756  -1.468  2.022
# C(Primary_activity)[T.Servers & data centers]                              0.647    1.114  0.580 0.562  -1.537  2.831
# C(Primary_activity)[T.Software]                                           -1.610    0.760 -2.118 0.034  -3.100 -0.120
# C(Primary_activity)[T.Solar energy equipment]                              0.763    1.442  0.529 0.597  -2.063  3.588
# C(Primary_activity)[T.Specialist retail]                                   1.926    0.869  2.217 0.027   0.223  3.629
# C(Primary_activity)[T.Specialty chemicals]                                 2.608    0.700  3.727 0.000   1.236  3.979
# C(Primary_activity)[T.Supermarkets, food & drugstores]                     2.290    0.691  3.312 0.001   0.935  3.645
# C(Primary_activity)[T.Telecommunications services]                        -0.136    0.671 -0.203 0.839  -1.451  1.178
# C(Primary_activity)[T.Textiles]                                           -0.581    1.494 -0.389 0.697  -3.510  2.348
# C(Primary_activity)[T.Tobacco products]                                    1.171    0.901  1.301 0.193  -0.594  2.936
# C(Primary_activity)[T.Transportation infrastructure & other construction]  1.979    0.769  2.575 0.010   0.473  3.486
# C(Primary_activity)[T.Transportation support services]                     2.959    1.455  2.035 0.042   0.109  5.810
# C(Primary_activity)[T.Travel services]                                     0.518    1.440  0.360 0.719  -2.304  3.340
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]              -0.265    0.904 -0.293 0.769  -2.037  1.506
# C(Primary_activity)[T.Waste management]                                    1.837    1.445  1.271 0.204  -0.995  4.669
# C(Primary_activity)[T.Water supply networks]                               3.488    0.923  3.779 0.000   1.679  5.297
# C(Primary_activity)[T.Wind generation]                                    -1.568    1.514 -1.036 0.300  -4.534  1.399
# C(Primary_activity)[T.Wood furniture]                                      1.716    1.460  1.175 0.240  -1.145  4.577
# slog_Market_Cap_USD                                                        0.152    0.039  3.915 0.000   0.076  0.229
# slog_totalInvestments_USD                                                 -0.008    0.005 -1.539 0.124  -0.018  0.002
# slog_Revenue_USD                                                           0.025    0.013  1.995 0.046   0.000  0.050
# slog_ebitda_USD                                                            0.000    0.003  0.115 0.908  -0.006  0.007
# slog_grossProfit_USD                                                      -0.007    0.007 -0.889 0.374  -0.021  0.008
# slog_netIncome_USD                                                         0.002    0.002  0.845 0.398  -0.002  0.005
# slog_totalDebt_USD                                                         0.022    0.019  1.162 0.245  -0.015  0.058
# slog_shortTermInvestments_USD                                              0.004    0.002  1.529 0.126  -0.001  0.009
# slog_totalAssets_USD                                                       0.136    0.040  3.376 0.001   0.057  0.215
# slog_totalEquity_USD                                                       0.010    0.006  1.686 0.092  -0.002  0.022
# slog_scope_1_2_emissions_amount                                            0.301    0.026 11.566 0.000   0.250  0.352
# Year                                                                      -0.013    0.012 -1.085 0.278  -0.036  0.010
# Group Var                                                                  1.513    0.121
# =====================================================================================================================
#
#
# Full Mixed-Effects Model (Full Model) Test Set Performance Metrics:
# R²(log):    64.54%
# R²(orig):   26.55%
# MAPE:       321.92%
# MAPE(log):  20.52%
# MAE(log):   1.13
# RMSLE:      1.43
# RMSE:       70202.55
# MAE:        20430.06
#
# Top Influential Features (by p-value):
#                                                         coef        pvalue
# Group Var                                           1.883921  5.479308e-44
# slog_scope_1_2_emissions_amount                     0.300757  6.156605e-31
# C(Primary_activity)[T.Fast food]                    4.347322  1.516947e-05
# C(Primary_activity)[T.Non-residential building ...  3.004739  4.777053e-05
# slog_Market_Cap_USD                                 0.152294  9.023143e-05
# C(Countries)[T.Norway]                             -2.156825  9.996602e-05
# C(Primary_activity)[T.Water supply networks]        3.488014  1.574314e-04
# C(Primary_activity)[T.Food & beverage amenities]    5.474386  1.706094e-04
# C(Primary_activity)[T.Specialty chemicals]          2.607648  1.937389e-04
# C(Countries)[T.United Kingdom]                     -1.502767  2.153688e-04

# %% [markdown]
# ## Waste Optimized Mixed-Effects Model
#
# An optimized mixed-effects model is used to predict company Scope 3 emissions. The model provides accurate prediction using only the most significant predictive features, while still accounting for primary activity, country and company level effects. The model is trained on data from 2018–2022 and evaluated on test data from 2023.
#
# Model Structure:
#
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:
#     - Signed log-transformed features:
#         - Market Cap ('slog_Market_Cap_USD')
#         - Revenue ('slog_Revenue_USD')
#         - Total Assets ('slog_totalAssets_USD')
#         - Total Equity ('slog_totalEquity_USD')
#         - Scope 1 & 2 Emissions ('slog_scope_1_2_emissions_amount')
#     - Country ('Countries', as a categorical variable)
#     - Primary Activity ('Primary_activity', as a categorical variable)
#     - *(Year is excluded due to lack of significance)*

# %%
feature_cols_slog = [
    'slog_Market_Cap_USD',
    'slog_Revenue_USD',
    'slog_totalDebt_USD',
    'slog_totalAssets_USD',
    'slog_totalEquity_USD',
    'slog_scope_1_2_emissions_amount'
]
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
all_model_vars = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_opt = train_df.dropna(subset=all_model_vars).copy()
test_df_opt = test_df.dropna(subset=all_model_vars).copy()

if test_df_opt.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity)'
        # Year is excluded due to lack of significance in optimized model
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the optimized mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_opt, groups=train_df_opt['account_id'])
        mdf_optimized = md.fit(reml=False)
    print(mdf_optimized.summary())

    # --- Predict on test set ---
    test_df_opt['predicted_log'] = mdf_optimized.predict(test_df_opt)
    test_df_opt['predicted'] = np.sign(test_df_opt['predicted_log']) * (np.expm1(np.abs(test_df_opt['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_opt[target_col_slog]
    y_pred_log = test_df_opt['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_opt['predicted']

    # Mask for valid/finites
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <-- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nOptimized Mixed-Effects Model: Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf_optimized.params,
        'pvalue': mdf_optimized.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Optimized Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Optimized Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Optimized Model Predicted")
    plt.xscale("log")
    plt.title("Optimized Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    optimized_model_metrics = {
        "Model": "Optimized",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                        Mixed Linear Model Regression Results
# ====================================================================================================================
# Model:                           MixedLM              Dependent Variable:              slog_Scope_3_emissions_amount
# No. Observations:                3282                 Method:                          ML
# No. Groups:                      769                  Scale:                           0.8034
# Min. group size:                 1                    Log-Likelihood:                  -5126.3398
# Max. group size:                 5                    Converged:                       Yes
# Mean group size:                 4.3
# --------------------------------------------------------------------------------------------------------------------
#                                                                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 -3.137    1.188 -2.641 0.008 -5.465 -0.809
# C(Countries)[T.Austria]                                                    2.737    1.195  2.290 0.022  0.395  5.079
# C(Countries)[T.Belgium]                                                   -1.103    0.671 -1.643 0.100 -2.418  0.213
# C(Countries)[T.Bermuda]                                                   -1.429    1.036 -1.380 0.168 -3.459  0.601
# C(Countries)[T.Brazil]                                                    -1.091    0.521 -2.092 0.036 -2.113 -0.069
# C(Countries)[T.Canada]                                                    -0.225    0.460 -0.488 0.626 -1.126  0.677
# C(Countries)[T.Chile]                                                     -1.886    1.598 -1.180 0.238 -5.018  1.246
# C(Countries)[T.China]                                                     -0.550    0.549 -1.002 0.316 -1.626  0.526
# C(Countries)[T.Denmark]                                                   -1.340    0.775 -1.729 0.084 -2.859  0.179
# C(Countries)[T.Finland]                                                   -0.569    0.552 -1.032 0.302 -1.651  0.512
# C(Countries)[T.France]                                                    -0.302    0.453 -0.666 0.506 -1.191  0.587
# C(Countries)[T.Germany]                                                   -0.374    0.467 -0.802 0.423 -1.289  0.541
# C(Countries)[T.Greece]                                                    -1.032    0.889 -1.161 0.246 -2.775  0.711
# C(Countries)[T.Hungary]                                                   -0.328    1.389 -0.236 0.813 -3.050  2.393
# C(Countries)[T.India]                                                     -2.310    1.041 -2.218 0.027 -4.351 -0.269
# C(Countries)[T.Ireland]                                                   -0.108    0.645 -0.167 0.867 -1.373  1.157
# C(Countries)[T.Israel]                                                    -0.432    1.129 -0.383 0.702 -2.644  1.780
# C(Countries)[T.Italy]                                                     -0.887    0.564 -1.572 0.116 -1.993  0.219
# C(Countries)[T.Japan]                                                     -0.471    0.393 -1.198 0.231 -1.242  0.300
# C(Countries)[T.Mexico]                                                    -1.674    1.169 -1.432 0.152 -3.965  0.617
# C(Countries)[T.Netherlands]                                               -0.248    0.577 -0.429 0.668 -1.378  0.883
# C(Countries)[T.New Zealand]                                                0.213    0.790  0.270 0.787 -1.334  1.761
# C(Countries)[T.Norway]                                                    -2.176    0.556 -3.911 0.000 -3.266 -1.085
# C(Countries)[T.Peru]                                                       1.262    1.361  0.927 0.354 -1.405  3.929
# C(Countries)[T.Portugal]                                                  -1.720    0.768 -2.239 0.025 -3.225 -0.215
# C(Countries)[T.Singapore]                                                 -1.387    1.172 -1.184 0.237 -3.684  0.910
# C(Countries)[T.South Africa]                                              -1.077    0.443 -2.429 0.015 -1.945 -0.208
# C(Countries)[T.South Korea]                                               -1.293    0.487 -2.653 0.008 -2.248 -0.338
# C(Countries)[T.Spain]                                                     -1.304    0.481 -2.709 0.007 -2.248 -0.360
# C(Countries)[T.Sweden]                                                    -1.517    0.828 -1.832 0.067 -3.140  0.106
# C(Countries)[T.Switzerland]                                               -0.598    0.486 -1.231 0.218 -1.552  0.355
# C(Countries)[T.Thailand]                                                  -0.593    0.789 -0.751 0.453 -2.139  0.954
# C(Countries)[T.Turkey]                                                    -3.882    1.635 -2.374 0.018 -7.087 -0.677
# C(Countries)[T.USA]                                                       -0.613    0.388 -1.581 0.114 -1.374  0.147
# C(Countries)[T.United Kingdom]                                            -1.501    0.408 -3.683 0.000 -2.300 -0.702
# C(Primary_activity)[T.Accessories manufacture]                            -0.989    1.137 -0.870 0.384 -3.218  1.240
# C(Primary_activity)[T.Aerospace]                                           1.525    1.482  1.029 0.304 -1.381  4.430
# C(Primary_activity)[T.Agricultural chemicals]                              2.493    1.482  1.682 0.093 -0.412  5.398
# C(Primary_activity)[T.Agriculture, construction & mining machinery]        0.512    0.856  0.598 0.550 -1.166  2.190
# C(Primary_activity)[T.Alcoholic beverages]                                 0.471    0.768  0.614 0.540 -1.034  1.976
# C(Primary_activity)[T.Animal processing]                                   2.975    0.911  3.266 0.001  1.190  4.761
# C(Primary_activity)[T.Apparel & footwear design]                           0.302    0.919  0.329 0.742 -1.499  2.103
# C(Primary_activity)[T.Apparel stores]                                      0.698    0.739  0.945 0.345 -0.750  2.146
# C(Primary_activity)[T.Aquaculture]                                         1.835    1.064  1.724 0.085 -0.251  3.920
# C(Primary_activity)[T.Asset managers]                                     -1.655    0.741 -2.234 0.025 -3.107 -0.203
# C(Primary_activity)[T.Automobiles]                                         1.474    0.805  1.832 0.067 -0.103  3.050
# C(Primary_activity)[T.Baked goods & cereals]                               1.070    1.446  0.740 0.459 -1.764  3.904
# C(Primary_activity)[T.Banks]                                              -1.333    0.640 -2.082 0.037 -2.588 -0.078
# C(Primary_activity)[T.Batteries]                                           1.020    1.018  1.003 0.316 -0.974  3.015
# C(Primary_activity)[T.Biotechnology]                                       0.012    0.797  0.015 0.988 -1.551  1.574
# C(Primary_activity)[T.Building sub-contractors]                            2.544    0.986  2.579 0.010  0.610  4.477
# C(Primary_activity)[T.Bus & taxi]                                          1.470    1.447  1.015 0.310 -1.367  4.306
# C(Primary_activity)[T.CCGT generation]                                     0.155    0.802  0.193 0.847 -1.417  1.727
# C(Primary_activity)[T.Cattle farming]                                      3.875    1.488  2.604 0.009  0.959  6.791
# C(Primary_activity)[T.Cement]                                              0.552    1.321  0.418 0.676 -2.038  3.141
# C(Primary_activity)[T.Clothing manufacture]                                1.364    0.878  1.553 0.120 -0.358  3.085
# C(Primary_activity)[T.Coal generation]                                    -2.497    1.701 -1.468 0.142 -5.832  0.837
# C(Primary_activity)[T.Commercial services]                                 0.373    0.918  0.406 0.685 -1.426  2.171
# C(Primary_activity)[T.Communications equipment]                           -1.177    0.813 -1.447 0.148 -2.771  0.417
# C(Primary_activity)[T.Computer hardware]                                  -0.894    0.877 -1.019 0.308 -2.614  0.826
# C(Primary_activity)[T.Consumer services]                                   0.844    1.476  0.572 0.568 -2.049  3.737
# C(Primary_activity)[T.Dairy & egg products]                                2.535    1.118  2.268 0.023  0.344  4.726
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                 1.226    0.801  1.531 0.126 -0.344  2.796
# C(Primary_activity)[T.Department stores]                                   0.691    0.978  0.706 0.480 -1.227  2.609
# C(Primary_activity)[T.Discretionary delivery retail]                       0.745    0.985  0.756 0.449 -1.185  2.675
# C(Primary_activity)[T.Education services]                                  0.028    1.447  0.019 0.985 -2.808  2.863
# C(Primary_activity)[T.Electrical equipment]                                0.889    0.704  1.262 0.207 -0.491  2.268
# C(Primary_activity)[T.Electricity networks]                               -0.072    0.752 -0.095 0.924 -1.546  1.403
# C(Primary_activity)[T.Electronic components]                               0.115    0.672  0.171 0.864 -1.202  1.431
# C(Primary_activity)[T.Electronic equipment]                                0.218    0.712  0.305 0.760 -1.178  1.613
# C(Primary_activity)[T.Energy infrastructure construction]                  2.589    1.154  2.243 0.025  0.327  4.852
# C(Primary_activity)[T.Energy services & equipment]                         1.693    0.945  1.791 0.073 -0.160  3.545
# C(Primary_activity)[T.Engineering services]                               -0.024    1.224 -0.019 0.985 -2.424  2.376
# C(Primary_activity)[T.Engines & motors]                                    1.231    0.821  1.499 0.134 -0.379  2.840
# C(Primary_activity)[T.Fabricated metal components]                         1.277    0.771  1.656 0.098 -0.235  2.789
# C(Primary_activity)[T.Fast food]                                           4.311    1.008  4.278 0.000  2.336  6.286
# C(Primary_activity)[T.Finished wood products]                              1.252    1.487  0.842 0.400 -1.661  4.166
# C(Primary_activity)[T.Fishing]                                             1.487    1.468  1.013 0.311 -1.391  4.364
# C(Primary_activity)[T.Food & beverage amenities]                           5.493    1.462  3.758 0.000  2.628  8.358
# C(Primary_activity)[T.Food & beverage wholesale]                           1.580    1.126  1.404 0.160 -0.626  3.786
# C(Primary_activity)[T.Furniture]                                           1.505    0.862  1.746 0.081 -0.185  3.195
# C(Primary_activity)[T.Gambling]                                            2.269    0.908  2.499 0.012  0.489  4.049
# C(Primary_activity)[T.Gas utilities]                                      -0.676    0.934 -0.724 0.469 -2.507  1.154
# C(Primary_activity)[T.Glass products]                                      1.109    1.148  0.966 0.334 -1.141  3.360
# C(Primary_activity)[T.Grain & corn milling]                                3.409    1.658  2.056 0.040  0.159  6.658
# C(Primary_activity)[T.Health care facilities]                              1.819    0.993  1.832 0.067 -0.127  3.765
# C(Primary_activity)[T.Health care services]                                0.490    0.803  0.611 0.541 -1.083  2.064
# C(Primary_activity)[T.Health care supplies]                                0.394    0.855  0.461 0.645 -1.281  2.068
# C(Primary_activity)[T.Homeware]                                            1.767    1.466  1.205 0.228 -1.106  4.640
# C(Primary_activity)[T.Hotels & lodging]                                    2.151    0.786  2.737 0.006  0.611  3.692
# C(Primary_activity)[T.Hydro generation]                                   -2.739    1.688 -1.622 0.105 -6.049  0.570
# C(Primary_activity)[T.Industrial machinery]                               -0.246    0.759 -0.325 0.745 -1.733  1.240
# C(Primary_activity)[T.Inorganic base chemicals]                            1.285    0.928  1.385 0.166 -0.533  3.103
# C(Primary_activity)[T.Insurance]                                          -1.576    0.648 -2.431 0.015 -2.847 -0.305
# C(Primary_activity)[T.Intermodal transport]                                0.044    1.446  0.030 0.976 -2.789  2.877
# C(Primary_activity)[T.Iron & steel]                                        1.399    1.044  1.339 0.180 -0.648  3.446
# C(Primary_activity)[T.Logging]                                             1.282    1.445  0.887 0.375 -1.550  4.115
# C(Primary_activity)[T.Logistics - 3rd party]                              -0.639    0.986 -0.648 0.517 -2.573  1.294
# C(Primary_activity)[T.Logistics - transport]                               0.590    1.460  0.404 0.686 -2.272  3.452
# C(Primary_activity)[T.Marine freight]                                     -0.349    0.925 -0.377 0.706 -2.163  1.464
# C(Primary_activity)[T.Marketing]                                          -0.443    0.780 -0.568 0.570 -1.973  1.086
# C(Primary_activity)[T.Medical equipment]                                  -0.506    0.733 -0.690 0.490 -1.943  0.931
# C(Primary_activity)[T.Metal containers & packaging]                        2.297    0.866  2.653 0.008  0.600  3.995
# C(Primary_activity)[T.Metal processing]                                    1.915    1.123  1.705 0.088 -0.287  4.116
# C(Primary_activity)[T.Nitrogenous fertilizers]                             0.358    1.161  0.308 0.758 -1.918  2.634
# C(Primary_activity)[T.Non-CCGT generation]                                -0.540    1.450 -0.372 0.710 -3.381  2.302
# C(Primary_activity)[T.Non-alcoholic beverages]                             1.302    0.899  1.447 0.148 -0.461  3.064
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                         0.049    1.238  0.039 0.969 -2.378  2.475
# C(Primary_activity)[T.Non-residential building construction]               3.025    0.741  4.081 0.000  1.572  4.478
# C(Primary_activity)[T.Oil & gas extraction]                               -0.412    0.963 -0.428 0.669 -2.299  1.476
# C(Primary_activity)[T.Oil & gas marketing & retailing]                     2.034    1.168  1.741 0.082 -0.256  4.324
# C(Primary_activity)[T.Oil & gas pipelines & storage]                       0.252    0.925  0.273 0.785 -1.560  2.065
# C(Primary_activity)[T.Oil & gas refining]                                  3.161    1.501  2.106 0.035  0.219  6.102
# C(Primary_activity)[T.Other base chemicals]                                1.902    0.702  2.711 0.007  0.527  3.277
# C(Primary_activity)[T.Other containers & packaging]                        2.495    0.986  2.531 0.011  0.563  4.427
# C(Primary_activity)[T.Other food processing]                               2.316    0.751  3.084 0.002  0.844  3.789
# C(Primary_activity)[T.Other non-ferrous ore mining]                        0.184    0.985  0.186 0.852 -1.748  2.115
# C(Primary_activity)[T.Other non-metallic minerals]                         2.316    1.456  1.591 0.112 -0.537  5.169
# C(Primary_activity)[T.Other professional services]                        -0.393    0.694 -0.567 0.571 -1.753  0.967
# C(Primary_activity)[T.Other renewable energy equipment]                    2.315    1.630  1.421 0.155 -0.879  5.510
# C(Primary_activity)[T.Other renewable generation]                          1.893    1.599  1.184 0.236 -1.241  5.027
# C(Primary_activity)[T.Paper products]                                      1.863    0.824  2.260 0.024  0.248  3.479
# C(Primary_activity)[T.Passenger airlines]                                  0.102    0.798  0.128 0.898 -1.461  1.665
# C(Primary_activity)[T.Passenger rail]                                      0.515    1.129  0.456 0.648 -1.697  2.728
# C(Primary_activity)[T.Personal care & household products]                  1.511    0.710  2.127 0.033  0.119  2.903
# C(Primary_activity)[T.Pharmaceuticals]                                     1.069    0.676  1.583 0.114 -0.255  2.393
# C(Primary_activity)[T.Plastic products]                                    1.328    0.789  1.683 0.092 -0.218  2.875
# C(Primary_activity)[T.Precious metals & minerals mining]                  -0.153    0.926 -0.165 0.869 -1.968  1.662
# C(Primary_activity)[T.Print publishing]                                    2.537    1.028  2.468 0.014  0.522  4.552
# C(Primary_activity)[T.Printing services]                                   1.083    1.115  0.971 0.331 -1.102  3.269
# C(Primary_activity)[T.Pulp & paper mills]                                  2.702    1.046  2.582 0.010  0.651  4.752
# C(Primary_activity)[T.REIT]                                                1.463    0.688  2.128 0.033  0.115  2.812
# C(Primary_activity)[T.Rail freight]                                        1.769    0.870  2.033 0.042  0.064  3.474
# C(Primary_activity)[T.Railroad rolling stock]                             -0.196    1.474 -0.133 0.894 -3.086  2.693
# C(Primary_activity)[T.Real estate owners & developers]                    -0.634    0.882 -0.719 0.472 -2.363  1.095
# C(Primary_activity)[T.Real estate services]                                1.717    0.919  1.867 0.062 -0.086  3.519
# C(Primary_activity)[T.Residential building construction]                   1.747    0.742  2.355 0.019  0.293  3.202
# C(Primary_activity)[T.Rubber products]                                     0.860    0.911  0.944 0.345 -0.925  2.644
# C(Primary_activity)[T.Semiconductors]                                      0.283    0.893  0.317 0.751 -1.467  2.033
# C(Primary_activity)[T.Servers & data centers]                              0.621    1.118  0.556 0.579 -1.571  2.813
# C(Primary_activity)[T.Software]                                           -1.601    0.763 -2.098 0.036 -3.096 -0.106
# C(Primary_activity)[T.Solar energy equipment]                              0.749    1.447  0.518 0.604 -2.086  3.585
# C(Primary_activity)[T.Specialist retail]                                   1.911    0.871  2.193 0.028  0.203  3.618
# C(Primary_activity)[T.Specialty chemicals]                                 2.612    0.702  3.724 0.000  1.237  3.987
# C(Primary_activity)[T.Supermarkets, food & drugstores]                     2.305    0.693  3.325 0.001  0.946  3.664
# C(Primary_activity)[T.Telecommunications services]                        -0.109    0.673 -0.161 0.872 -1.427  1.210
# C(Primary_activity)[T.Textiles]                                           -0.574    1.500 -0.383 0.702 -3.514  2.366
# C(Primary_activity)[T.Tobacco products]                                    1.159    0.903  1.282 0.200 -0.612  2.929
# C(Primary_activity)[T.Transportation infrastructure & other construction]  1.956    0.771  2.536 0.011  0.444  3.467
# C(Primary_activity)[T.Transportation support services]                     2.874    1.459  1.970 0.049  0.015  5.733
# C(Primary_activity)[T.Travel services]                                     0.464    1.444  0.321 0.748 -2.366  3.295
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]              -0.234    0.905 -0.258 0.796 -2.008  1.540
# C(Primary_activity)[T.Waste management]                                    1.876    1.450  1.294 0.196 -0.967  4.718
# C(Primary_activity)[T.Water supply networks]                               3.514    0.926  3.795 0.000  1.699  5.329
# C(Primary_activity)[T.Wind generation]                                    -1.503    1.519 -0.990 0.322 -4.480  1.474
# C(Primary_activity)[T.Wood furniture]                                      1.645    1.464  1.123 0.261 -1.225  4.514
# slog_Market_Cap_USD                                                        0.155    0.038  4.036 0.000  0.079  0.230
# slog_Revenue_USD                                                           0.020    0.010  1.938 0.053 -0.000  0.040
# slog_totalDebt_USD                                                         0.018    0.019  0.984 0.325 -0.018  0.055
# slog_totalAssets_USD                                                       0.132    0.040  3.295 0.001  0.054  0.211
# slog_totalEquity_USD                                                       0.010    0.006  1.692 0.091 -0.002  0.022
# slog_scope_1_2_emissions_amount                                            0.298    0.026 11.470 0.000  0.247  0.349
# Group Var                                                                  1.526    0.122
# ====================================================================================================================
#
#
# Optimized Mixed-Effects Model: Test Set Performance Metrics:
# R²(log):    64.40%
# R²(orig):   26.22%
# MAPE:       333.04%
# MAPE(log):  20.68%
# MAE(log):   1.13
# RMSLE:      1.43
# RMSE:       70358.03
# MAE:        20434.43
#
# Top Influential Features (by p-value):
#                                                         coef        pvalue
# Group Var                                           1.899888  4.632640e-44
# slog_scope_1_2_emissions_amount                     0.297667  1.858844e-30
# C(Primary_activity)[T.Fast food]                    4.311236  1.886169e-05
# C(Primary_activity)[T.Non-residential building ...  3.025102  4.484641e-05
# slog_Market_Cap_USD                                 0.154528  5.432463e-05
# C(Countries)[T.Norway]                             -2.175578  9.196157e-05
# C(Primary_activity)[T.Water supply networks]        3.514228  1.476005e-04
# C(Primary_activity)[T.Food & beverage amenities]    5.492710  1.714866e-04
# C(Primary_activity)[T.Specialty chemicals]          2.612407  1.962101e-04
# C(Countries)[T.United Kingdom]                     -1.500929  2.309514e-04
#
# All feature coefficients sorted by absolute value:
#                                                       coef    pvalue
# C(Primary_activity)[T.Food & beverage amenities]  5.492710  0.000171
# C(Primary_activity)[T.Fast food]                  4.311236  0.000019
# C(Countries)[T.Turkey]                           -3.882284  0.017585
# C(Primary_activity)[T.Cattle farming]             3.874903  0.009203
# C(Primary_activity)[T.Water supply networks]      3.514228  0.000148
# ...                                                    ...       ...
# C(Primary_activity)[T.Engineering services]      -0.023704  0.984555
# slog_Revenue_USD                                  0.019741  0.052598
# slog_totalDebt_USD                                0.018289  0.325298
# C(Primary_activity)[T.Biotechnology]              0.011783  0.988208
# slog_totalEquity_USD                              0.010060  0.090625
#
# [162 rows x 2 columns]

# %%
metrics_text_log = (
    f"R²(log):   {r2_log_pct:.2f}%\n"
    f"R²(orig):  {r2_pct:.2f}%\n"
    f"MAPE:      {mape_orig:.2f}%\n"
    f"MAPE(log): {mape_log:.2f}%\n"
    f"MAE(log):  {mae_log:.2f}\n"
    f"RMSLE:     {rmsle:.2f}\n"
    f"RMSE:      {rmse_orig:.2f}\n"
    f"MAE:       {mae_orig:.2f}"
)

fig, ax = plt.subplots(figsize=(9.5, 6))  # Wider to make room for the box

if hasattr(y_pred_log, "nunique"):
    multiple_vals = y_pred_log.nunique() > 1
else:
    multiple_vals = len(set(y_pred_log)) > 1

if multiple_vals:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=ax, color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    ax.plot([], [], ' ', label="Predicted: constant value (no KDE)")

ax.set_title("Waste Optimized Model: signed log(Scope 3 Emissions)")
ax.set_xlabel("signed log(metric tons + 1)")
ax.set_ylabel("Density")
ax.legend()

# Place metrics box outside plot to the right
fig.text(
    0.82, 0.75, metrics_text_log,
    va='top', ha='left',
    fontsize=12, bbox=dict(boxstyle='round', alpha=0.15)
)

plt.subplots_adjust(right=0.8)  # Make sure there's room for the box
fig.savefig("waste_scope3_log_density.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Metrics Table for Waste

# %%
metrics_dicts = [
    null_model_metrics,
    two_level_model_metrics,
    three_level_model_metrics,
    full_model_metrics,
    optimized_model_metrics
]

for metrics, train, test in zip(
        metrics_dicts,
        [train_df, train_df, train_df, train_df, train_df],
        [test_df, test_df, test_df, test_df, test_df]):
    
    metrics["# Obs (train)"] = len(train)
    metrics["# Obs (test)"] = len(test)
    metrics["# Obs (train/test)"] = f"{len(train)}/{len(test)}"

metrics_df = pd.DataFrame(metrics_dicts)

# Ensure all relevant columns are ordered and present
desired_order = [
    "Model", "R2_log", "R2_orig", "RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "# Obs (train/test)"
]


# Ensure MAE_log is present, fill with NaN if missing
if "MAE_log" not in metrics_df.columns:
    metrics_df["MAE_log"] = np.nan

metrics_df = metrics_df[[col for col in desired_order if col in metrics_df.columns]]

metrics_df_display = metrics_df.copy()
if "R2_log" in metrics_df_display.columns:
    metrics_df_display["R2_log"] = (metrics_df_display["R2_log"] * 100).map("{:.2f}%".format)
if "R2_orig" in metrics_df_display.columns:
    metrics_df_display["R2_orig"] = (metrics_df_display["R2_orig"] * 100).map("{:.2f}%".format)
for col in ["RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "MAPE(log)"]:
    if col in metrics_df_display.columns:
        metrics_df_display[col] = metrics_df_display[col].map("{:.2f}".format)

from IPython.display import display
display(metrics_df_display)
# Out:
#                                      Model  R2_log R2_orig      RMSE  \
# 0                                Null (RI)  -0.62%  -9.20%  85600.06
# 1                           2-level (RI+S)  -0.34%  -9.10%  85558.41
# 2  3-level (Primary Activity/Account/Year)  35.26%  -3.44%  83309.39
# 3                               Full Model  64.54%  26.55%  70202.55
# 4                                Optimized  64.40%  26.22%  70358.03
#
#         MAE MAE_log RMSLE     MAPE # Obs (train/test)
# 0  26617.98    1.98  2.41  4000.78           3282/678
# 1  26597.18    1.97  2.41  4201.89           3282/678
# 2  24848.71    1.57  1.93  1248.57           3282/678
# 3  20430.06    1.13  1.43   321.92           3282/678
# 4  20434.43    1.13  1.43   333.04           3282/678
