# %% [markdown]
# # GHG HLM on Scope 3 source Franchises

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_log_error, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GroupShuffleSplit
from scipy.stats import zscore
import scipy.stats as stats
from sklearn.feature_selection import mutual_info_regression
from sklearn.impute import SimpleImputer
import warnings
from statsmodels.regression.mixed_linear_model import MixedLM


#read in dataset from GHG_post_outliers data set
franchises=pd.read_csv('/Users/amberjensen/Desktop/GHG_Emissions_Project/franchises.csv')

# %%
#check for info
franchises.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_name                382 non-null    object
#  1   account_id                  382 non-null    int64
#  2   Year                        382 non-null    int64
#  3   incorporated_country        382 non-null    object
#  4   Primary activity            382 non-null    object
#  5   Primary sector              382 non-null    object
#  6   Market_Cap_USD              331 non-null    float64
#  7   Third_party_verification    382 non-null    object
#  8   Revenue_USD                 331 non-null    float64
#  9   ebitda_USD                  331 non-null    float64
#  10  grossProfit_USD             331 non-null    float64
#  11  netIncome_USD               331 non-null    float64
#  12  cashAndCashEquivalents_USD  331 non-null    float64
#  13  shortTermInvestments_USD    331 non-null    float64
#  14  longTermInvestments_USD     331 non-null    float64
#  15  totalAssets_USD             331 non-null    float64
#  16  totalLiabilities_USD        331 non-null    float64
#  17  totalInvestments_USD        331 non-null    float64
#  18  totalDebt_USD               331 non-null    float64
#  19  totalEquity_USD             331 non-null    float64
#  20  Scope_3_emissions_type      382 non-null    object
#  21  Scope_3_emissions_amount    382 non-null    float64
#  22  scope_1_2_emissions_amount  382 non-null    float64
#  23  Year_sq                     382 non-null    int64
# dtypes: float64(15), int64(3), object(6)
# memory usage: 71.8+ KB

# %%
#show a df for franchises
franchises.head()
# Out:
#                     account_name  account_id  Year incorporated_country  \
# 0  Intercontinental Hotels Group       22499  2018       United Kingdom
# 1    Marks and Spencer Group plc       11328  2018       United Kingdom
# 2                       Gap Inc.        7060  2018                  USA
# 3             General Mills Inc.        7156  2018                  USA
# 4         Hilton Worldwide, Inc.        8348  2018                  USA
#
#                   Primary activity              Primary sector  \
# 0                 Hotels & lodging  Bars, hotels & restaurants
# 1  Supermarkets, food & drugstores          Convenience retail
# 2                   Apparel stores        Discretionary retail
# 3            Other food processing  Food & beverage processing
# 4                 Hotels & lodging  Bars, hotels & restaurants
#
#    Market_Cap_USD                           Third_party_verification  \
# 0    7.765812e+09  Third-party verification or assurance process ...
# 1    4.877304e+09  Third-party verification or assurance process ...
# 2    9.814560e+09  Third-party verification or assurance process ...
# 3    2.337958e+10  Third-party verification or assurance process ...
# 4    2.103740e+10  Third-party verification or assurance process ...
#
#     Revenue_USD    ebitda_USD  ...  longTermInvestments_USD  totalAssets_USD  \
# 0  4.337000e+09  8.000000e+08  ...              363000000.0     3.753000e+09
# 1  1.317917e+10  1.089406e+09  ...               36195000.0     1.124077e+10
# 2  1.658000e+10  1.879000e+09  ...              338000000.0     8.049000e+09
# 3  1.574040e+10  3.459300e+09  ...              499600000.0     3.062400e+10
# 4  8.906000e+09  1.785000e+09  ...                      0.0     1.399500e+10
#
#    totalLiabilities_USD  totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0          4.830000e+09           364000000.0   2.249000e+09    -1.077000e+09
# 1          8.104886e+09           209931000.0   5.443093e+09     3.135884e+09
# 2          4.496000e+09           288000000.0   1.249000e+09     3.553000e+09
# 3          2.335540e+10           499600000.0   1.581860e+10     7.268600e+09
# 4          1.343700e+10                   0.0   7.282000e+09     5.580000e+08
#
#    Scope_3_emissions_type  Scope_3_emissions_amount  \
# 0              Franchises                2631574.96
# 1              Franchises                 150000.00
# 2              Franchises                  40652.00
# 3              Franchises                   9086.00
# 4              Franchises                3473170.00
#
#    scope_1_2_emissions_amount  Year_sq
# 0                  1466765.00  4072324
# 1                   218956.75  4072324
# 2                   216821.25  4072324
# 3                   645194.75  4072324
# 4                  1390431.75  4072324
#
# [5 rows x 24 columns]

# %%
#define a list of numeric columns
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD',
       'grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD',
       'shortTermInvestments_USD', 'longTermInvestments_USD',
       'totalAssets_USD', 'totalLiabilities_USD', 'totalInvestments_USD',
       'totalDebt_USD', 'totalEquity_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount']

# %%
#plot the heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(franchises[numeric_cols].corr(), annot=True, annot_kws={"size": 8})
plt.show()

# %%
#correlation matrix
franchises[numeric_cols].corr()
# Out:
#                             Market_Cap_USD  Revenue_USD  ebitda_USD  \
# Market_Cap_USD                    1.000000     0.639906    0.745096
# Revenue_USD                       0.639906     1.000000    0.848261
# ebitda_USD                        0.745096     0.848261    1.000000
# grossProfit_USD                   0.561633     0.775600    0.796318
# netIncome_USD                     0.794612     0.725868    0.875009
# cashAndCashEquivalents_USD        0.510409     0.614625    0.565706
# shortTermInvestments_USD          0.107092     0.179875    0.110115
# longTermInvestments_USD           0.077269     0.222459    0.127696
# totalAssets_USD                   0.522586     0.786122    0.786385
# totalLiabilities_USD              0.569379     0.768697    0.716568
# totalInvestments_USD              0.090457     0.223625    0.119685
# totalDebt_USD                     0.723242     0.730943    0.836831
# totalEquity_USD                   0.274708     0.595745    0.704549
# Scope_3_emissions_amount          0.500216     0.071695    0.235364
# scope_1_2_emissions_amount        0.059129     0.205625    0.105645
#
#                             grossProfit_USD  netIncome_USD  \
# Market_Cap_USD                     0.561633       0.794612
# Revenue_USD                        0.775600       0.725868
# ebitda_USD                         0.796318       0.875009
# grossProfit_USD                    1.000000       0.643077
# netIncome_USD                      0.643077       1.000000
# cashAndCashEquivalents_USD         0.580015       0.533874
# shortTermInvestments_USD           0.272092       0.158550
# longTermInvestments_USD            0.458230       0.145563
# totalAssets_USD                    0.830835       0.674978
# totalLiabilities_USD               0.785370       0.639436
# totalInvestments_USD               0.443950       0.155112
# totalDebt_USD                      0.630362       0.755892
# totalEquity_USD                    0.685690       0.554143
# Scope_3_emissions_amount           0.094051       0.311142
# scope_1_2_emissions_amount         0.074320       0.031892
#
#                             cashAndCashEquivalents_USD  \
# Market_Cap_USD                                0.510409
# Revenue_USD                                   0.614625
# ebitda_USD                                    0.565706
# grossProfit_USD                               0.580015
# netIncome_USD                                 0.533874
# cashAndCashEquivalents_USD                    1.000000
# shortTermInvestments_USD                      0.313797
# longTermInvestments_USD                       0.426752
# totalAssets_USD                               0.745604
# totalLiabilities_USD                          0.734427
# totalInvestments_USD                          0.445231
# totalDebt_USD                                 0.604296
# totalEquity_USD                               0.553895
# Scope_3_emissions_amount                      0.064592
# scope_1_2_emissions_amount                    0.160582
#
#                             shortTermInvestments_USD  longTermInvestments_USD  \
# Market_Cap_USD                              0.107092                 0.077269
# Revenue_USD                                 0.179875                 0.222459
# ebitda_USD                                  0.110115                 0.127696
# grossProfit_USD                             0.272092                 0.458230
# netIncome_USD                               0.158550                 0.145563
# cashAndCashEquivalents_USD                  0.313797                 0.426752
# shortTermInvestments_USD                    1.000000                 0.421322
# longTermInvestments_USD                     0.421322                 1.000000
# totalAssets_USD                             0.350031                 0.604122
# totalLiabilities_USD                        0.363120                 0.665213
# totalInvestments_USD                        0.610868                 0.971298
# totalDebt_USD                               0.144787                 0.134168
# totalEquity_USD                             0.221900                 0.303413
# Scope_3_emissions_amount                   -0.024571                 0.013137
# scope_1_2_emissions_amount                  0.011211                -0.038734
#
#                             totalAssets_USD  totalLiabilities_USD  \
# Market_Cap_USD                     0.522586              0.569379
# Revenue_USD                        0.786122              0.768697
# ebitda_USD                         0.786385              0.716568
# grossProfit_USD                    0.830835              0.785370
# netIncome_USD                      0.674978              0.639436
# cashAndCashEquivalents_USD         0.745604              0.734427
# shortTermInvestments_USD           0.350031              0.363120
# longTermInvestments_USD            0.604122              0.665213
# totalAssets_USD                    1.000000              0.957233
# totalLiabilities_USD               0.957233              1.000000
# totalInvestments_USD               0.597418              0.657689
# totalDebt_USD                      0.784297              0.788983
# totalEquity_USD                    0.800438              0.592783
# Scope_3_emissions_amount           0.110660              0.244715
# scope_1_2_emissions_amount         0.143772              0.131408
#
#                             totalInvestments_USD  totalDebt_USD  \
# Market_Cap_USD                          0.090457       0.723242
# Revenue_USD                             0.223625       0.730943
# ebitda_USD                              0.119685       0.836831
# grossProfit_USD                         0.443950       0.630362
# netIncome_USD                           0.155112       0.755892
# cashAndCashEquivalents_USD              0.445231       0.604296
# shortTermInvestments_USD                0.610868       0.144787
# longTermInvestments_USD                 0.971298       0.134168
# totalAssets_USD                         0.597418       0.784297
# totalLiabilities_USD                    0.657689       0.788983
# totalInvestments_USD                    1.000000       0.136993
# totalDebt_USD                           0.136993       1.000000
# totalEquity_USD                         0.300337       0.548650
# Scope_3_emissions_amount                0.009270       0.405565
# scope_1_2_emissions_amount             -0.033028       0.147392
#
#                             totalEquity_USD  Scope_3_emissions_amount  \
# Market_Cap_USD                     0.274708                  0.500216
# Revenue_USD                        0.595745                  0.071695
# ebitda_USD                         0.704549                  0.235364
# grossProfit_USD                    0.685690                  0.094051
# netIncome_USD                      0.554143                  0.311142
# cashAndCashEquivalents_USD         0.553895                  0.064592
# shortTermInvestments_USD           0.221900                 -0.024571
# longTermInvestments_USD            0.303413                  0.013137
# totalAssets_USD                    0.800438                  0.110660
# totalLiabilities_USD               0.592783                  0.244715
# totalInvestments_USD               0.300337                  0.009270
# totalDebt_USD                      0.548650                  0.405565
# totalEquity_USD                    1.000000                 -0.199077
# Scope_3_emissions_amount          -0.199077                  1.000000
# scope_1_2_emissions_amount         0.128272                 -0.043732
#
#                             scope_1_2_emissions_amount
# Market_Cap_USD                                0.059129
# Revenue_USD                                   0.205625
# ebitda_USD                                    0.105645
# grossProfit_USD                               0.074320
# netIncome_USD                                 0.031892
# cashAndCashEquivalents_USD                    0.160582
# shortTermInvestments_USD                      0.011211
# longTermInvestments_USD                      -0.038734
# totalAssets_USD                               0.143772
# totalLiabilities_USD                          0.131408
# totalInvestments_USD                         -0.033028
# totalDebt_USD                                 0.147392
# totalEquity_USD                               0.128272
# Scope_3_emissions_amount                     -0.043732
# scope_1_2_emissions_amount                    1.000000

# %%
#drop columns due to collinearity
franchises=franchises.drop(columns=['ebitda_USD', 'netIncome_USD', 'totalLiabilities_USD', 'totalEquity_USD', 'totalDebt_USD', 'cashAndCashEquivalents_USD',
                                    'grossProfit_USD', 'longTermInvestments_USD', "account_name", "Third_party_verification",
                                    "Scope_3_emissions_type"])

# %%
franchises.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  382 non-null    int64
#  1   Year                        382 non-null    int64
#  2   incorporated_country        382 non-null    object
#  3   Primary activity            382 non-null    object
#  4   Primary sector              382 non-null    object
#  5   Market_Cap_USD              331 non-null    float64
#  6   Revenue_USD                 331 non-null    float64
#  7   shortTermInvestments_USD    331 non-null    float64
#  8   totalAssets_USD             331 non-null    float64
#  9   totalInvestments_USD        331 non-null    float64
#  10  Scope_3_emissions_amount    382 non-null    float64
#  11  scope_1_2_emissions_amount  382 non-null    float64
#  12  Year_sq                     382 non-null    int64
# dtypes: float64(7), int64(3), object(3)
# memory usage: 38.9+ KB

# %%
sns.boxplot(franchises)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#plot a scatter plot of scope year emissions and scope 1_2 emissions

sns.scatterplot(x='Year', y='Market_Cap_USD', data=franchises)
# Out:
# <Axes: xlabel='Year', ylabel='Market_Cap_USD'>

# %%
# copy dataframe
franchises_no_transform = franchises.copy()
# Change 'incorporated_country' to 'Countries' in franchises dataframe
franchises_no_transform = franchises_no_transform.rename(columns={'incorporated_country': 'Countries',
                                                       'Primary activity': 'Primary_activity',
                                                        'Primary sector': 'Primary_sector'})

print(franchises_no_transform.info())
franchises_no_transform.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  382 non-null    int64
#  1   Year                        382 non-null    int64
#  2   Countries                   382 non-null    object
#  3   Primary_activity            382 non-null    object
#  4   Primary_sector              382 non-null    object
#  5   Market_Cap_USD              331 non-null    float64
#  6   Revenue_USD                 331 non-null    float64
#  7   shortTermInvestments_USD    331 non-null    float64
#  8   totalAssets_USD             331 non-null    float64
#  9   totalInvestments_USD        331 non-null    float64
#  10  Scope_3_emissions_amount    382 non-null    float64
#  11  scope_1_2_emissions_amount  382 non-null    float64
#  12  Year_sq                     382 non-null    int64
# dtypes: float64(7), int64(3), object(3)
# memory usage: 38.9+ KB
# None
#    account_id  Year       Countries                 Primary_activity  \
# 0       22499  2018  United Kingdom                 Hotels & lodging
# 1       11328  2018  United Kingdom  Supermarkets, food & drugstores
# 2        7060  2018             USA                   Apparel stores
# 3        7156  2018             USA            Other food processing
# 4        8348  2018             USA                 Hotels & lodging
#
#                Primary_sector  Market_Cap_USD   Revenue_USD  \
# 0  Bars, hotels & restaurants    7.765812e+09  4.337000e+09
# 1          Convenience retail    4.877304e+09  1.317917e+10
# 2        Discretionary retail    9.814560e+09  1.658000e+10
# 3  Food & beverage processing    2.337958e+10  1.574040e+10
# 4  Bars, hotels & restaurants    2.103740e+10  8.906000e+09
#
#    shortTermInvestments_USD  totalAssets_USD  totalInvestments_USD  \
# 0                 1000000.0     3.753000e+09           364000000.0
# 1               173736000.0     1.124077e+10           209931000.0
# 2               288000000.0     8.049000e+09           288000000.0
# 3                 7100000.0     3.062400e+10           499600000.0
# 4                       0.0     1.399500e+10                   0.0
#
#    Scope_3_emissions_amount  scope_1_2_emissions_amount  Year_sq
# 0                2631574.96                  1466765.00  4072324
# 1                 150000.00                   218956.75  4072324
# 2                  40652.00                   216821.25  4072324
# 3                   9086.00                   645194.75  4072324
# 4                3473170.00                  1390431.75  4072324

# %%
franchises_no_transform['Primary_sector'].value_counts()
# Out:
# Primary_sector
# Bars, hotels & restaurants                            54
# Discretionary retail                                  45
# Media, telecommunications & data center services      41
# Convenience retail                                    32
# Food & beverage processing                            30
# Apparel design                                        16
# Chemicals                                             16
# Trading, wholesale, distribution, rental & leasing    14
# Financial services                                    13
# Transportation equipment                              13
# Intermodal transport & logistics                      12
# Air transport                                         11
# Electrical & electronic equipment                     10
# Accessories                                            9
# Textiles & fabric goods                                7
# Wood & rubber products                                 6
# Energy utility networks                                6
# Tobacco                                                6
# Other services                                         6
# Metal products manufacturing                           6
# Rail transport                                         5
# Specialized professional services                      4
# Construction                                           4
# Powered machinery                                      3
# Medical equipment & supplies                           2
# Print & publishing services                            2
# Metal smelting, refining & forming                     2
# Leisure & home manufacturing                           2
# Thermal power generation                               1
# Road transport                                         1
# Plastic product manufacturing                          1
# Cement & concrete                                      1
# 0                                                      1
# Name: count, dtype: int64

# %%
franchises_no_transform['Primary_activity'].value_counts().head(20)
# Out:
# Primary_activity
# Telecommunications services            41
# Hotels & lodging                       35
# Supermarkets, food & drugstores        32
# Apparel stores                         28
# Fast food                              17
# Apparel & footwear design              16
# Specialist retail                      16
# Other food processing                  14
# Automobiles                            13
# Logistics - 3rd party                  12
# Passenger airlines                     11
# Insurance                              11
# Accessories manufacture                 9
# Non-alcoholic beverages                 9
# Dealers, wholesalers & distributors     9
# Electronic equipment                    8
# Alcoholic beverages                     7
# Clothing manufacture                    7
# Fabricated metal components             6
# Tobacco products                        6
# Name: count, dtype: int64

# %%
# Looking at missing data
print(franchises_no_transform.isnull().mean().sort_values(ascending=False).round(3) * 100)
# Out:
# Market_Cap_USD                13.4
# Revenue_USD                   13.4
# shortTermInvestments_USD      13.4
# totalAssets_USD               13.4
# totalInvestments_USD          13.4
# account_id                     0.0
# Year                           0.0
# Countries                      0.0
# Primary_activity               0.0
# Primary_sector                 0.0
# Scope_3_emissions_amount       0.0
# scope_1_2_emissions_amount     0.0
# Year_sq                        0.0
# dtype: float64

# %% [markdown]
# Apply signed log transformation and split data by company and year into train_df (2018-2022) and test_df (2023):

# %%
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'shortTermInvestments_USD', 'totalInvestments_USD', 'totalAssets_USD',
                'Scope_3_emissions_amount', 'scope_1_2_emissions_amount'
]
required_cols = [
    'account_id', 'Year', 'Year_sq', 'Countries', 'Primary_activity', 'Primary_sector'
] + numeric_cols

# --- Prepare Data ---
df = franchises_no_transform[required_cols].dropna()

# --- Signed log transform ---
def signed_log(x):
    return np.sign(x) * np.log(np.abs(x) + 1)

for col in numeric_cols:
    df[f'slog_{col}'] = signed_log(df[col])

# --- Company-level split by year ---
train_df = df[df['Year'].between(2018, 2022)].copy()
test_df  = df[df['Year'] == 2023].copy()

# Keep only companies present in training
valid_companies = set(train_df['account_id'].unique())
test_df = test_df[test_df['account_id'].isin(valid_companies)].copy()

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (259, 20)
# Test shape: (56, 20)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 259 entries, 0 to 298
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       259 non-null    int64
#  1   Year                             259 non-null    int64
#  2   Year_sq                          259 non-null    int64
#  3   Countries                        259 non-null    object
#  4   Primary_activity                 259 non-null    object
#  5   Primary_sector                   259 non-null    object
#  6   Market_Cap_USD                   259 non-null    float64
#  7   Revenue_USD                      259 non-null    float64
#  8   shortTermInvestments_USD         259 non-null    float64
#  9   totalInvestments_USD             259 non-null    float64
#  10  totalAssets_USD                  259 non-null    float64
#  11  Scope_3_emissions_amount         259 non-null    float64
#  12  scope_1_2_emissions_amount       259 non-null    float64
#  13  slog_Market_Cap_USD              259 non-null    float64
#  14  slog_Revenue_USD                 259 non-null    float64
#  15  slog_shortTermInvestments_USD    259 non-null    float64
#  16  slog_totalInvestments_USD        259 non-null    float64
#  17  slog_totalAssets_USD             259 non-null    float64
#  18  slog_Scope_3_emissions_amount    259 non-null    float64
#  19  slog_scope_1_2_emissions_amount  259 non-null    float64
# dtypes: float64(14), int64(3), object(3)
# memory usage: 42.5+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, 299 to 381
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       56 non-null     int64
#  1   Year                             56 non-null     int64
#  2   Year_sq                          56 non-null     int64
#  3   Countries                        56 non-null     object
#  4   Primary_activity                 56 non-null     object
#  5   Primary_sector                   56 non-null     object
#  6   Market_Cap_USD                   56 non-null     float64
#  7   Revenue_USD                      56 non-null     float64
#  8   shortTermInvestments_USD         56 non-null     float64
#  9   totalInvestments_USD             56 non-null     float64
#  10  totalAssets_USD                  56 non-null     float64
#  11  Scope_3_emissions_amount         56 non-null     float64
#  12  scope_1_2_emissions_amount       56 non-null     float64
#  13  slog_Market_Cap_USD              56 non-null     float64
#  14  slog_Revenue_USD                 56 non-null     float64
#  15  slog_shortTermInvestments_USD    56 non-null     float64
#  16  slog_totalInvestments_USD        56 non-null     float64
#  17  slog_totalAssets_USD             56 non-null     float64
#  18  slog_Scope_3_emissions_amount    56 non-null     float64
#  19  slog_scope_1_2_emissions_amount  56 non-null     float64
# dtypes: float64(14), int64(3), object(3)
# memory usage: 9.2+ KB

# %%
# Check number of 0's in train and test df's
print((train_df == 0).sum().sum())
print((test_df == 0).sum().sum())
# Out:
# 108
# 40

# %% [markdown]
# ## Franchises Null Mixed-Effects Model
#
# Null mixed-effects model (random intercept only) to predict log-transformed Scope 3 emissions. The model serves as a baseline, capturing only the average emission level for each company, without incorporating any explanatory variables, and quantifies the improvement gained by including additional features and structure. The model is trained on 2018–2022 data and evaluated on a test set from 2023.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies
# - Fixed Effects:
#     - Intercept only (no predictors)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE NULL MODEL (random intercept only) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    null_model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ 1",
        train_df,
        groups=train_df["account_id"]
    )
    null_result = null_model.fit(method="lbfgs")

if not null_result.converged:
    print("WARNING: Null model did not fully converge.")

print(null_result.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_null'] = null_result.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_null']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_null'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics text
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[0], color='gray')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Null Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[1], color='gray')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Null Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Null Model Predicted")
plt.xscale("log")
plt.title("Null Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
null_model_metrics = {
    "Model": "Null (RI)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "Random intercept only"
}
# Out:
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 259     Method:             REML
# No. Groups:       76      Scale:              0.6352
# Min. group size:  1       Log-Likelihood:     -454.3271
# Max. group size:  5       Converged:          Yes
# Mean group size:  3.4
# ------------------------------------------------------------------------------
#                 Coef.      Std.Err.       z        P>|z|     [0.025     0.975]
# ------------------------------------------------------------------------------
# Intercept        9.945        0.372     26.756     0.000      9.217     10.674
# Group Var       10.214        2.547
# ==========================================================================
#
# R²(log):    -2.71%
# R²(orig):   -19.72%
# MAPE:       4607.41%
# MAPE(log):  28.08%
# MAE(log):   2.41
# RMSLE:      3.02
# RMSE:       1750377.80
# MAE:        723890.41

# %% [markdown]
# ## Franchises Two-Level Mixed-Effects Model
#
# Two-level hierarchical linear mixed-effects model to predict log-transformed Scope 3 emissions at the company level. The model is fit to training data (from 2018–2022), and predictions are evaluated on a test set (from 2023).  This model provides a baseline for including time trends and company-level variability.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies.<br>
# - Fixed Effects:
#     - Year (numeric)
#     - Year squared ('Year_sq', quadratic time trend)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- Check group sizes ---
group_sizes = train_df.groupby('account_id').size()
print("Two-Level Model: Company/year group size summary:")
print(group_sizes.describe())

# --- FIT THE TWO-LEVEL MODEL (random intercept, +Year, +Year_sq) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ Year + Year_sq",
        train_df,
        groups=train_df["account_id"],
        re_formula="1"
    )
    result_twolevel = model.fit(method="lbfgs")

if not result_twolevel.converged:
    print("WARNING: Two-level mixed model did not fully converge.")

print(result_twolevel.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_twolevel.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_mixed']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='orange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Two-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='orange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Two-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="orange", alpha=0.5, label="Two-Level Model Predicted")
plt.xscale("log")
plt.title("Two-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
two_level_model_metrics = {
    "Model": "2-level (RI+S)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "+Year, Year_sq"
}
# Out:
# Two-Level Model: Company/year group size summary:
# count    76.000000
# mean      3.407895
# std       1.706284
# min       1.000000
# 25%       1.000000
# 50%       4.000000
# 75%       5.000000
# max       5.000000
# dtype: float64
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 259     Method:             REML
# No. Groups:       76      Scale:              0.6410
# Min. group size:  1       Log-Likelihood:     -459.0196
# Max. group size:  5       Converged:          Yes
# Mean group size:  3.4
# ---------------------------------------------------------------------------
#                 Coef.     Std.Err.     z     P>|z|     [0.025      0.975]
# ---------------------------------------------------------------------------
# Intercept      6075.043  129726.378   0.047  0.963  -248183.986  260334.072
# Year             -6.027     128.438  -0.047  0.963     -257.761     245.708
# Year_sq           0.001       0.032   0.047  0.962       -0.061       0.064
# Group Var        10.219       2.541
# ==========================================================================
#
# R²(log):    -2.03%
# R²(orig):   -19.64%
# MAPE:       4920.27%
# MAPE(log):  28.19%
# MAE(log):   2.40
# RMSLE:      3.01
# RMSE:       1749802.24
# MAE:        723732.38

# %% [markdown]
# ## Franchises Three-Level Mixed-Effects Model
#
# A three-level hierarchical linear mixed-effects model is used to predict log-transformed Scope 3 emissions. It takes into account differences between primary activity, differences between companies, and changes over time. The model is trained using data from 2018 to 2022, and then tested on new data from 2023. This model provides insight on how emissions are influenced by primary activity, by individual companies, by financial and emissions factors, and by trends over time.
#
# Model Structure:
#
# - Level 3 (Primary Activity):<br>
#     - Random intercept and random slope for Year for each primary activity ('Primary_activity'), capturing baseline primary activity and primary activity-specific time trends.<br>
# - Level 2 (Account/Company):
#     - Random intercept for each company ('account_id'), capturing company-level deviations within each primary activity.
# - Level 1 (Yearly Observations):
#     - Repeated annual observations within each company.
#
# - Fixed Effects:
#     - Signed log-transformed market cap ('slog_Market_Cap_USD')
#     - Signed log-transformed revenue ('slog_Revenue_USD')
#     - *Removed: Signed log-transformed EBITDA ('slog_ebitda_USD') due to collinearity*
#     - Signed log-transformed Scope 1 & 2 emissions ('slog_scope_1_2_emissions_amount')

# %%
# --- Ensure grouping/categorical variables are string ---
for col in ['Countries', 'account_id', 'Primary_activity', 'Primary_sector']:
    train_df[col] = train_df[col].astype(str)
    test_df[col] = test_df[col].astype(str)

# --- Center the Year variable ---
year_mean = train_df['Year'].mean()
train_df['Year_centered'] = train_df['Year'] - year_mean
test_df['Year_centered'] = test_df['Year'] - year_mean

# --- Ensure log-transformed target exists ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE 3-LEVEL MIXED MODEL with Primary_activity as Level 3 group ---
vc = {'account_id': '0 + C(account_id)'}  # Level 2: account_id random intercept

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model_3level = MixedLM.from_formula(
        'log_Scope_3_emissions_amount ~ slog_Market_Cap_USD + slog_Revenue_USD + slog_scope_1_2_emissions_amount',
        groups='Primary_activity',
        re_formula='~Year_centered',
        vc_formula=vc,
        data=train_df
    )
    result_3level = model_3level.fit(method="lbfgs", maxiter=1000)

if not result_3level.converged:
    print("WARNING: Three-level mixed model did not fully converge.")

print(result_3level.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_3level.predict(test_df)

# --- Compute back-transformed values ---
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])

# --- Robust Mask for finite values everywhere ---
mask = (
    np.isfinite(test_df['log_Scope_3_emissions_amount']) &
    np.isfinite(test_df['predicted_mixed']) &
    np.isfinite(test_df['Reported_Scope_3']) &
    np.isfinite(test_df['Predicted_Scope_3'])
)
test_df = test_df.loc[mask].copy()

y_true_log = test_df['log_Scope_3_emissions_amount'].values
y_pred_log = test_df['predicted_mixed'].values
y_true = test_df['Reported_Scope_3'].values
y_pred = test_df['Predicted_Scope_3'].values

# Final defensive check and diagnostics
arrays = {
    "y_true_log": y_true_log,
    "y_pred_log": y_pred_log,
    "y_true": y_true,
    "y_pred": y_pred,
}
for arr_name, arr in arrays.items():
    if not np.all(np.isfinite(arr)):
        print(f"ERROR: {arr_name} contains non-finite values!")
        print(f"Non-finite indices: {np.where(~np.isfinite(arr))[0]}")
        print(f"Values: {arr[~np.isfinite(arr)]}")
        raise ValueError(f"{arr_name} contains infs or NaNs after masking!")

# --- METRICS ---
mae_log = mean_absolute_error(y_true_log, y_pred_log)
nonzero_mask = y_true_log != 0
if np.any(nonzero_mask):
    mape_log = np.mean(np.abs((y_true_log[nonzero_mask] - y_pred_log[nonzero_mask]) / y_true_log[nonzero_mask])) * 100
else:
    mape_log = np.nan

r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)

metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
if len(np.unique(y_pred_log)) > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Three-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()
axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

if len(np.unique(y_pred)) > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Three-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()
axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Filter strictly positive values for histogram (log x-axis requires >0)
y_true_pos = y_true[y_true > 0]
y_pred_pos = y_pred[y_pred > 0]

if y_true_pos.size > 0 and y_pred_pos.size > 0:
    min_val = min(y_true_pos.min(), y_pred_pos.min())
    max_val = max(y_true_pos.max(), y_pred_pos.max())
    if min_val == max_val:
        print("Skipping histogram: Only one unique positive value present.")
    else:
        log_bins = np.logspace(np.log10(min_val), np.log10(max_val), 100)

        plt.figure(figsize=(8, 5))
        sns.histplot(y_true_pos, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
        sns.histplot(y_pred_pos, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Three-Level Model Predicted")
        plt.xscale("log")
        plt.title("Three-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
        plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
        plt.ylabel("Density")
        plt.legend()
        plt.tight_layout()
        plt.show()
else:
    print("Skipping histogram: Not enough positive values in y_true or y_pred for log-scale histogram.")

# --- RETURN METRICS FOR SUMMARY TABLE ---
three_level_model_metrics = {
    "Model": "3-level (Primary Activity/Account/Year)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,
    "MAPE(log)": mape_log,
}
# Out:
#                       Mixed Linear Model Regression Results
# =================================================================================
# Model:               MixedLM   Dependent Variable:   log_Scope_3_emissions_amount
# No. Observations:    259       Method:               REML
# No. Groups:          34        Scale:                0.4594
# Min. group size:     1         Log-Likelihood:       -431.4911
# Max. group size:     28        Converged:            Yes
# Mean group size:     7.6
# ---------------------------------------------------------------------------------
#                                       Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# ---------------------------------------------------------------------------------
# Intercept                            -10.719    4.822 -2.223 0.026 -20.171 -1.268
# slog_Market_Cap_USD                    0.194    0.136  1.431 0.153  -0.072  0.461
# slog_Revenue_USD                       0.493    0.221  2.228 0.026   0.059  0.927
# slog_scope_1_2_emissions_amount        0.376    0.108  3.490 0.000   0.165  0.587
# Primary_activity Var                   3.927    2.904
# Primary_activity x Year_centered Cov  -0.259    0.352
# Year_centered Var                      0.121    0.083
# account_id Var                         4.637    1.868
# =================================================================================
#
# R²(log):    23.53%
# R²(orig):   -16.86%
# MAPE:       1982.32%
# MAPE(log):  23.70%
# MAE(log):   2.09
# RMSLE:      2.60
# RMSE:       1729360.79
# MAE:        709750.62

# %% [markdown]
# ## Franchises Full Mixed-Effects Model
#
# A full mixed-effects model is used to predict company Scope 3 emissions, using financial and emissions data, along with information about country, industry, and year. The model is trained on data from 2018 to 2022, and tested on data from 2023. This full model helps provides insights into how a company’s finances, emissions, primary activity, country and the year influence emissions.<br>
#
# Model Structure:<br>
#
# - Random Effects:<br>
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:<br>
#     - Signed log-transformed financial and emissions features:<br>
#         - Market Cap ('slog_Market_Cap_USD')<br>
#         - Revenue ('slog_Revenue_USD')<br>
#         - Short Term Investments ('slog_shortTermInvestments_USD')
#         - Total Assets ('slog_totalAssets_USD')<br>
#         - Scope 1&2 Emissions ('slog_scope_1_2_emissions_amount')<br>
#     - Country ('Countries', as a categorical variable)<br>
#     - Primary Activity ('Primary_activity', as a categorical variable)<br>
#     - *Does **Not** include Year due to singular matrix error message*<br>

# %%
# --- Feature and target columns ---
numeric_cols = ['Market_Cap_USD',
 'Revenue_USD',
 'shortTermInvestments_USD',
 'totalInvestments_USD',
 'totalAssets_USD',
 'Scope_3_emissions_amount',
 'scope_1_2_emissions_amount'
]
feature_cols_slog = [f'slog_{col}' for col in numeric_cols if col != 'Scope_3_emissions_amount']
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
required_cols = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_full = train_df.dropna(subset=required_cols).copy()
test_df_full = test_df.dropna(subset=required_cols).copy()

if test_df_full.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity)'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the full mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_full, groups=train_df_full['account_id'])
        mdf = md.fit(reml=False)
    print(mdf.summary())

    # --- Predict on test set ---
    test_df_full['predicted_log'] = mdf.predict(test_df_full)
    test_df_full['predicted'] = np.sign(test_df_full['predicted_log']) * (np.expm1(np.abs(test_df_full['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_full[target_col_slog]
    y_pred_log = test_df_full['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_full['predicted']

    # Mask for finite values
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nFull Mixed-Effects Model (Full Model) Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf.params,
        'pvalue': mdf.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Full Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Full Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Full Model Predicted")
    plt.xscale("log")
    plt.title("Full Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    full_model_metrics = {
        "Model": "Full Model",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                                   Mixed Linear Model Regression Results
# =========================================================================================================================================
# Model:                                  MixedLM                     Dependent Variable:                     slog_Scope_3_emissions_amount
# No. Observations:                       259                         Method:                                 ML
# No. Groups:                             76                          Scale:                                  0.6675
# Min. group size:                        1                           Log-Likelihood:                         -368.3164
# Max. group size:                        5                           Converged:                              Yes
# Mean group size:                        3.4
# -----------------------------------------------------------------------------------------------------------------------------------------
#                                                                   Coef.           Std.Err.      z    P>|z|      [0.025         0.975]
# -----------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                              -34.119          5.049 -6.758 0.000         -44.015        -24.224
# C(Countries)[T.Canada]                                                   4.937          1.845  2.676 0.007           1.321          8.553
# C(Countries)[T.China]                                                    7.298          2.129  3.428 0.001           3.126         11.471
# C(Countries)[T.Denmark]                                     53988679179088.914
# C(Countries)[T.Finland]                                                  6.229          1.706  3.650 0.000           2.884          9.573
# C(Countries)[T.France]                                                   4.686          1.322  3.545 0.000           2.096          7.277
# C(Countries)[T.Germany]                                                  7.600          2.098  3.623 0.000           3.488         11.713
# C(Countries)[T.Italy]                                                    4.091          1.935  2.114 0.034           0.299          7.883
# C(Countries)[T.Japan]                                                    4.763          0.762  6.253 0.000           3.270          6.256
# C(Countries)[T.Netherlands]                                              7.550          2.310  3.268 0.001           3.021         12.078
# C(Countries)[T.Norway]                                                   9.319          2.158  4.319 0.000           5.090         13.548
# C(Countries)[T.Portugal]                                                 3.087          1.674  1.844 0.065          -0.194          6.368
# C(Countries)[T.Singapore]                                                3.870          1.842  2.101 0.036           0.260          7.479
# C(Countries)[T.South Africa]                                             7.633          1.555  4.908 0.000           4.585         10.681
# C(Countries)[T.South Korea]                                              7.396          1.610  4.593 0.000           4.240         10.552
# C(Countries)[T.Spain]                                                    3.879          1.444  2.687 0.007           1.049          6.708
# C(Countries)[T.Sweden]                                                   1.179          1.828  0.645 0.519          -2.403          4.761
# C(Countries)[T.Switzerland]                                              9.181
# C(Countries)[T.Turkey]                                                  46.385 2027992721.060  0.000 1.000 -3974792647.802 3974792740.572
# C(Countries)[T.USA]                                                      5.167          1.390  3.716 0.000           2.442          7.892
# C(Countries)[T.United Kingdom]                                           5.923          1.457  4.065 0.000           3.067          8.779
# C(Primary_activity)[T.Alcoholic beverages]                 -53988679179077.156
# C(Primary_activity)[T.Apparel & footwear design]                         5.785          0.428 13.503 0.000           4.946          6.625
# C(Primary_activity)[T.Apparel stores]                                    4.474
# C(Primary_activity)[T.Automobiles]                                       3.813          0.801  4.759 0.000           2.243          5.383
# C(Primary_activity)[T.CCGT generation]                                 -42.664 2292762268.283 -0.000 1.000 -4493731513.611 4493731428.282
# C(Primary_activity)[T.Clothing manufacture]                              4.584          1.051  4.362 0.000           2.524          6.644
# C(Primary_activity)[T.Communications equipment]                         -2.851          1.009 -2.826 0.005          -4.829         -0.874
# C(Primary_activity)[T.Dealers, wholesalers & distributors]               6.441
# C(Primary_activity)[T.Electronic equipment]                              0.875          0.711  1.230 0.219          -0.519          2.268
# C(Primary_activity)[T.Engines & motors]                                  3.024          0.952  3.177 0.001           1.158          4.889
# C(Primary_activity)[T.Fabricated metal components]                       5.333          0.705  7.563 0.000           3.951          6.714
# C(Primary_activity)[T.Fast food]                                         9.112          0.730 12.491 0.000           7.682         10.542
# C(Primary_activity)[T.Food & beverage amenities]                         6.574          1.256  5.235 0.000           4.112          9.035
# C(Primary_activity)[T.Food & beverage wholesale]                         3.749          0.751  4.992 0.000           2.277          5.221
# C(Primary_activity)[T.Gas utilities]                                     3.920          1.237  3.169 0.002           1.495          6.344
# C(Primary_activity)[T.Hotels & lodging]                                  6.883          0.947  7.266 0.000           5.026          8.740
# C(Primary_activity)[T.Insurance]                                         5.133          0.664  7.727 0.000           3.831          6.435
# C(Primary_activity)[T.Logistics - 3rd party]                             0.303          1.104  0.275 0.784          -1.860          2.467
# C(Primary_activity)[T.Non-alcoholic beverages]                           4.552          0.906  5.024 0.000           2.776          6.328
# C(Primary_activity)[T.Other base chemicals]                             -2.325          1.624 -1.431 0.152          -5.508          0.858
# C(Primary_activity)[T.Other food processing]                             2.711          0.839  3.229 0.001           1.065          4.356
# C(Primary_activity)[T.Other professional services]                       3.036          1.075  2.825 0.005           0.930          5.143
# C(Primary_activity)[T.Passenger airlines]                                2.647          1.224  2.163 0.031           0.249          5.046
# C(Primary_activity)[T.Passenger rail]                                    2.908          2.095  1.388 0.165          -1.197          7.014
# C(Primary_activity)[T.Personal care & household products]                9.792          1.039  9.421 0.000           7.755         11.829
# C(Primary_activity)[T.Plastic products]                                  1.683          1.302  1.293 0.196          -0.868          4.234
# C(Primary_activity)[T.Print publishing]                                 -0.193          1.147 -0.168 0.867          -2.440          2.055
# C(Primary_activity)[T.Real estate services]                             -2.348          0.768 -3.058 0.002          -3.853         -0.843
# C(Primary_activity)[T.Rubber products]                                   2.080          1.391  1.495 0.135          -0.646          4.806
# C(Primary_activity)[T.Specialist retail]                                 4.365
# C(Primary_activity)[T.Supermarkets, food & drugstores]                   4.726
# C(Primary_activity)[T.Telecommunications services]                       1.615          0.983  1.643 0.100          -0.311          3.541
# C(Primary_activity)[T.Tobacco products]                                  0.928          1.109  0.837 0.403          -1.246          3.102
# slog_Market_Cap_USD                                                      0.135          0.135  0.994 0.320          -0.131          0.400
# slog_Revenue_USD                                                         0.536          0.281  1.910 0.056          -0.014          1.086
# slog_shortTermInvestments_USD                                           -0.003          0.009 -0.374 0.708          -0.021          0.014
# slog_totalInvestments_USD                                               -0.028          0.017 -1.626 0.104          -0.062          0.006
# slog_totalAssets_USD                                                     0.578          0.298  1.939 0.052          -0.006          1.162
# slog_scope_1_2_emissions_amount                                          0.541          0.136  3.985 0.000           0.275          0.807
# Group Var                                                                0.677          0.224
# =========================================================================================================================================
#
#
# Full Mixed-Effects Model (Full Model) Test Set Performance Metrics:
# R²(log):    78.01%
# R²(orig):   -201.25%
# MAPE:       254.02%
# MAPE(log):  11.23%
# MAE(log):   1.03
# RMSLE:      1.40
# RMSE:       2776583.31
# MAE:        724851.92
#
# Top Influential Features (by p-value):
#                                                         coef        pvalue
# C(Primary_activity)[T.Apparel & footwear design]    5.785273  1.511087e-41
# C(Primary_activity)[T.Fast food]                    9.112197  8.400302e-36
# C(Primary_activity)[T.Personal care & household...  9.792072  4.447165e-21
# C(Primary_activity)[T.Insurance]                    5.133285  1.104681e-14
# C(Primary_activity)[T.Fabricated metal components]  5.332544  3.934563e-14
# C(Primary_activity)[T.Hotels & lodging]             6.883066  3.716168e-13
# C(Countries)[T.Japan]                               4.763259  4.037028e-10
# C(Primary_activity)[T.Food & beverage amenities]    6.573507  1.653086e-07
# C(Primary_activity)[T.Non-alcoholic beverages]      4.552095  5.060132e-07
# C(Primary_activity)[T.Food & beverage wholesale]    3.749020  5.987095e-07
# /Users/amberjensen/anaconda3/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2704: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))

# %% [markdown]
# ## Franchises Optimized Mixed-Effects Model
#
# An optimized mixed-effects model is used to predict company Scope 3 emissions. The model provides accurate prediction using only the most significant predictive features, while still accounting for primary activity, country and company level effects. The model is trained on data from 2018–2022 and evaluated on test data from 2023.
#
# Model Structure:
#
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:
#     - Signed log-transformed features:
#         - Market Cap ('slog_Market_Cap_USD')
#         - Revenue ('slog_Revenue_USD')
#         - Total Investments ('slog_totalInvestments_USD') *Note: This had a slightly negative coefficient, but the model required this to run*
#         - Total Assets ('slog_totalAssets_USD')
#         - Scope 1 & 2 Emissions ('slog_scope_1_2_emissions_amount')
#     - Country ('Countries', as a categorical variable)
#     - Primary Activity ('Primary_activity', as a categorical variable)
#     - *Year is not included due to causing a single matrix, and thus preventing the model from running*

# %%
feature_cols_slog = [
    'slog_Market_Cap_USD',
    'slog_Revenue_USD',
    'slog_totalInvestments_USD',
    'slog_totalAssets_USD',
    'slog_scope_1_2_emissions_amount'
]
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
all_model_vars = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_opt = train_df.dropna(subset=all_model_vars).copy()
test_df_opt = test_df.dropna(subset=all_model_vars).copy()

if test_df_opt.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity)'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the optimized mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_opt, groups=train_df_opt['account_id'])
        mdf_optimized = md.fit(reml=False)
    print(mdf_optimized.summary())

    # --- Predict on test set ---
    test_df_opt['predicted_log'] = mdf_optimized.predict(test_df_opt)
    test_df_opt['predicted'] = np.sign(test_df_opt['predicted_log']) * (np.expm1(np.abs(test_df_opt['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_opt[target_col_slog]
    y_pred_log = test_df_opt['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_opt['predicted']

    # Mask for valid/finites
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <-- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nOptimized Mixed-Effects Model: Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf_optimized.params,
        'pvalue': mdf_optimized.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Optimized Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Optimized Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Optimized Model Predicted")
    plt.xscale("log")
    plt.title("Optimized Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    optimized_model_metrics = {
        "Model": "Optimized",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                           Mixed Linear Model Regression Results
# ==========================================================================================================================
# Model:                             MixedLM                Dependent Variable:                slog_Scope_3_emissions_amount
# No. Observations:                  259                    Method:                            ML
# No. Groups:                        76                     Scale:                             0.6659
# Min. group size:                   1                      Log-Likelihood:                    -368.3482
# Max. group size:                   5                      Converged:                         Yes
# Mean group size:                   3.4
# --------------------------------------------------------------------------------------------------------------------------
#                                                             Coef.     Std.Err.     z    P>|z|     [0.025         0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                  -33.936         5.003 -6.783 0.000        -43.742       -24.130
# C(Countries)[T.Canada]                                       4.894         1.525  3.209 0.001          1.905         7.883
# C(Countries)[T.China]                                        7.232         1.822  3.969 0.000          3.661        10.803
# C(Countries)[T.Denmark]                                     -0.484 306284024.830 -0.000 1.000 -600305658.191 600305657.222
# C(Countries)[T.Finland]                                      6.131         1.540  3.982 0.000          3.113         9.148
# C(Countries)[T.France]                                       4.578         1.349  3.392 0.001          1.933         7.223
# C(Countries)[T.Germany]                                      7.430         1.837  4.045 0.000          3.830        11.029
# C(Countries)[T.Italy]                                        4.008         1.857  2.158 0.031          0.368         7.648
# C(Countries)[T.Japan]                                        4.696         1.519  3.091 0.002          1.718         7.673
# C(Countries)[T.Netherlands]                                  7.551         1.969  3.835 0.000          3.691        11.410
# C(Countries)[T.Norway]                                       9.348         1.875  4.985 0.000          5.672        13.023
# C(Countries)[T.Portugal]                                     3.031         1.479  2.049 0.040          0.132         5.931
# C(Countries)[T.Singapore]                                    3.851         1.800  2.140 0.032          0.323         7.378
# C(Countries)[T.South Africa]                                 7.610         1.378  5.525 0.000          4.910        10.310
# C(Countries)[T.South Korea]                                  7.299         1.461  4.997 0.000          4.436        10.162
# C(Countries)[T.Spain]                                        3.826         1.500  2.550 0.011          0.885         6.767
# C(Countries)[T.Sweden]                                       1.089         1.807  0.602 0.547         -2.453         4.630
# C(Countries)[T.Switzerland]                                  9.034         2.174  4.156 0.000          4.774        13.295
# C(Countries)[T.Turkey]                                      -7.434
# C(Countries)[T.USA]                                          5.097         1.414  3.605 0.000          2.326         7.868
# C(Countries)[T.United Kingdom]                               5.835         1.274  4.579 0.000          3.337         8.333
# C(Primary_activity)[T.Alcoholic beverages]                  12.210 304304918.239  0.000 1.000 -596426667.858 596426692.277
# C(Primary_activity)[T.Apparel & footwear design]             5.726         1.346  4.255 0.000          3.088         8.363
# C(Primary_activity)[T.Apparel stores]                        4.395         1.224  3.590 0.000          1.995         6.794
# C(Primary_activity)[T.Automobiles]                           3.790         1.236  3.066 0.002          1.367         6.212
# C(Primary_activity)[T.CCGT generation]                      11.034
# C(Primary_activity)[T.Clothing manufacture]                  4.585         1.497  3.064 0.002          1.652         7.518
# C(Primary_activity)[T.Communications equipment]             -2.818         1.652 -1.706 0.088         -6.055         0.419
# C(Primary_activity)[T.Dealers, wholesalers & distributors]   6.365         1.513  4.208 0.000          3.400         9.330
# C(Primary_activity)[T.Electronic equipment]                  0.785         1.231  0.638 0.523         -1.627         3.198
# C(Primary_activity)[T.Engines & motors]                      2.963         1.590  1.863 0.062         -0.154         6.080
# C(Primary_activity)[T.Fabricated metal components]           5.311         1.544  3.439 0.001          2.284         8.337
# C(Primary_activity)[T.Fast food]                             9.105         1.181  7.707 0.000          6.789        11.421
# C(Primary_activity)[T.Food & beverage amenities]             6.512         1.700  3.832 0.000          3.181         9.843
# C(Primary_activity)[T.Food & beverage wholesale]             3.693         1.591  2.321 0.020          0.574         6.812
# C(Primary_activity)[T.Gas utilities]                         3.986         1.665  2.394 0.017          0.723         7.249
# C(Primary_activity)[T.Hotels & lodging]                      6.883         1.361  5.059 0.000          4.217         9.550
# C(Primary_activity)[T.Insurance]                             5.027         1.512  3.325 0.001          2.064         7.991
# C(Primary_activity)[T.Logistics - 3rd party]                 0.243         1.746  0.139 0.889         -3.180         3.666
# C(Primary_activity)[T.Non-alcoholic beverages]               4.499         1.369  3.287 0.001          1.816         7.181
# C(Primary_activity)[T.Other base chemicals]                 -2.413         2.564 -0.941 0.347         -7.437         2.612
# C(Primary_activity)[T.Other food processing]                 2.659         1.468  1.811 0.070         -0.219         5.537
# C(Primary_activity)[T.Other professional services]           2.968         1.629  1.822 0.068         -0.225         6.161
# C(Primary_activity)[T.Passenger airlines]                    2.578         1.993  1.293 0.196         -1.329         6.484
# C(Primary_activity)[T.Passenger rail]                        2.880         2.406  1.197 0.231         -1.836         7.597
# C(Primary_activity)[T.Personal care & household products]    9.704         1.265  7.669 0.000          7.224        12.184
# C(Primary_activity)[T.Plastic products]                      1.732         1.531  1.131 0.258         -1.269         4.733
# C(Primary_activity)[T.Print publishing]                     -0.268         1.742 -0.154 0.878         -3.681         3.146
# C(Primary_activity)[T.Real estate services]                 -2.446         1.300 -1.882 0.060         -4.993         0.102
# C(Primary_activity)[T.Rubber products]                       2.030         1.935  1.049 0.294         -1.762         5.823
# C(Primary_activity)[T.Specialist retail]                     4.324         1.423  3.039 0.002          1.535         7.112
# C(Primary_activity)[T.Supermarkets, food & drugstores]       4.659         1.584  2.941 0.003          1.554         7.763
# C(Primary_activity)[T.Telecommunications services]           1.561         1.652  0.945 0.345         -1.677         4.799
# C(Primary_activity)[T.Tobacco products]                      0.860         1.502  0.573 0.567         -2.084         3.804
# slog_Market_Cap_USD                                          0.122
# slog_Revenue_USD                                             0.559
# slog_totalInvestments_USD                                   -0.029         0.016 -1.792 0.073         -0.060         0.003
# slog_totalAssets_USD                                         0.566         0.472  1.199 0.230         -0.359         1.492
# slog_scope_1_2_emissions_amount                              0.535         0.189  2.836 0.005          0.165         0.905
# Group Var                                                    0.684         0.198
# ==========================================================================================================================
#
#
# Optimized Mixed-Effects Model: Test Set Performance Metrics:
# R²(log):    78.04%
# R²(orig):   -216.34%
# MAPE:       257.29%
# MAPE(log):  11.23%
# MAE(log):   1.03
# RMSLE:      1.40
# RMSE:       2845271.54
# MAE:        732099.35
#
# Top Influential Features (by p-value):
#                                                         coef        pvalue
# C(Primary_activity)[T.Fast food]                    9.105046  1.289735e-14
# C(Primary_activity)[T.Personal care & household...  9.704209  1.729539e-14
# C(Countries)[T.South Africa]                        7.610306  3.303684e-08
# C(Primary_activity)[T.Hotels & lodging]             6.883401  4.214160e-07
# C(Countries)[T.South Korea]                         7.298988  5.818854e-07
# C(Countries)[T.Norway]                              9.347575  6.208880e-07
# C(Countries)[T.United Kingdom]                      5.835268  4.676053e-06
# C(Primary_activity)[T.Apparel & footwear design]    5.725798  2.091075e-05
# Group Var                                           1.027766  2.269676e-05
# C(Primary_activity)[T.Dealers, wholesalers & di...  6.365173  2.576515e-05
#
# All feature coefficients sorted by absolute value:
#                                                          coef        pvalue
# C(Primary_activity)[T.Alcoholic beverages]          12.209765  1.000000e+00
# C(Primary_activity)[T.CCGT generation]              11.033614           NaN
# C(Primary_activity)[T.Personal care & household...   9.704209  1.729539e-14
# C(Countries)[T.Norway]                               9.347575  6.208880e-07
# C(Primary_activity)[T.Fast food]                     9.105046  1.289735e-14
# C(Countries)[T.Switzerland]                          9.034226  3.240745e-05
# C(Countries)[T.South Africa]                         7.610306  3.303684e-08
# C(Countries)[T.Netherlands]                          7.550576  1.256648e-04
# C(Countries)[T.Turkey]                              -7.433653           NaN
# C(Countries)[T.Germany]                              7.429633  5.225769e-05
# C(Countries)[T.South Korea]                          7.298988  5.818854e-07
# C(Countries)[T.China]                                7.232049  7.215112e-05
# C(Primary_activity)[T.Hotels & lodging]              6.883401  4.214160e-07
# C(Primary_activity)[T.Food & beverage amenities]     6.512303  1.272923e-04
# C(Primary_activity)[T.Dealers, wholesalers & di...   6.365173  2.576515e-05
# C(Countries)[T.Finland]                              6.130857  6.832381e-05
# C(Countries)[T.United Kingdom]                       5.835268  4.676053e-06
# C(Primary_activity)[T.Apparel & footwear design]     5.725798  2.091075e-05
# C(Primary_activity)[T.Fabricated metal components]   5.310574  5.841193e-04
# C(Countries)[T.USA]                                  5.096791  3.120294e-04
# C(Primary_activity)[T.Insurance]                     5.027394  8.830273e-04
# C(Countries)[T.Canada]                               4.894378  1.330679e-03
# C(Countries)[T.Japan]                                4.695702  1.993303e-03
# C(Primary_activity)[T.Supermarkets, food & drug...   4.658506  3.271025e-03
# C(Primary_activity)[T.Clothing manufacture]          4.584884  2.186414e-03
# C(Countries)[T.France]                               4.578004  6.928073e-04
# C(Primary_activity)[T.Non-alcoholic beverages]       4.498613  1.013543e-03
# C(Primary_activity)[T.Apparel stores]                4.394868  3.308422e-04
# C(Primary_activity)[T.Specialist retail]             4.323608  2.375405e-03
# C(Countries)[T.Italy]                                4.008054  3.089865e-02
# C(Primary_activity)[T.Gas utilities]                 3.986376  1.664399e-02
# C(Countries)[T.Singapore]                            3.850780  3.238529e-02
# C(Countries)[T.Spain]                                3.825997  1.076856e-02
# C(Primary_activity)[T.Automobiles]                   3.789857  2.167647e-03
# C(Primary_activity)[T.Food & beverage wholesale]     3.692943  2.030737e-02
# C(Countries)[T.Portugal]                             3.031403  4.045808e-02
# C(Primary_activity)[T.Other professional services]   2.968247  6.843801e-02
# C(Primary_activity)[T.Engines & motors]              2.963337  6.240399e-02
# C(Primary_activity)[T.Passenger rail]                2.880485  2.313145e-01
# C(Primary_activity)[T.Communications equipment]     -2.818097  8.795751e-02
# C(Primary_activity)[T.Other food processing]         2.658668  7.020819e-02
# C(Primary_activity)[T.Passenger airlines]            2.577795  1.958806e-01
# C(Primary_activity)[T.Real estate services]         -2.445544  5.985901e-02
# C(Primary_activity)[T.Other base chemicals]         -2.412513  3.466936e-01
# C(Primary_activity)[T.Rubber products]               2.030492  2.939881e-01
# C(Primary_activity)[T.Plastic products]              1.732222  2.579212e-01
# C(Primary_activity)[T.Telecommunications services]   1.560832  3.448059e-01
# C(Countries)[T.Sweden]                               1.088515  5.468709e-01
# Group Var                                            1.027766  2.269676e-05
# C(Primary_activity)[T.Tobacco products]              0.859894  5.669759e-01
# C(Primary_activity)[T.Electronic equipment]          0.785315  5.234313e-01
# slog_totalAssets_USD                                 0.566186  2.304802e-01
# slog_Revenue_USD                                     0.559483           NaN
# slog_scope_1_2_emissions_amount                      0.535219  4.566598e-03
# C(Countries)[T.Denmark]                             -0.484398  1.000000e+00
# C(Primary_activity)[T.Print publishing]             -0.267613  8.778926e-01
# C(Primary_activity)[T.Logistics - 3rd party]         0.242819  8.894195e-01
# slog_Market_Cap_USD                                  0.122243           NaN
# slog_totalInvestments_USD                           -0.028823  7.319438e-02
# /Users/amberjensen/anaconda3/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2704: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))

# %%
metrics_text_log = (
    f"R²(log):   {r2_log_pct:.2f}%\n"
    f"R²(orig):  {r2_pct:.2f}%\n"
    f"MAPE:      {mape_orig:.2f}%\n"
    f"MAPE(log): {mape_log:.2f}%\n"
    f"MAE(log):  {mae_log:.2f}\n"
    f"RMSLE:     {rmsle:.2f}\n"
    f"RMSE:      {rmse_orig:.2f}\n"
    f"MAE:       {mae_orig:.2f}"
)

fig, ax = plt.subplots(figsize=(9.5, 6))  # Wider to make room for the box

if hasattr(y_pred_log, "nunique"):
    multiple_vals = y_pred_log.nunique() > 1
else:
    multiple_vals = len(set(y_pred_log)) > 1

if multiple_vals:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=ax, color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    ax.plot([], [], ' ', label="Predicted: constant value (no KDE)")

ax.set_title("Franchises Optimized Model: signed log(Scope 3 Emissions)")
ax.set_xlabel("signed log(metric tons + 1)")
ax.set_ylabel("Density")
ax.legend()

# Place metrics box outside plot to the right
fig.text(
    0.82, 0.75, metrics_text_log,
    va='top', ha='left',
    fontsize=12, bbox=dict(boxstyle='round', alpha=0.15)
)

plt.subplots_adjust(right=0.8)  # Make sure there's room for the box
fig.savefig("franchises_scope3_log_density.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Metrics Table for Franchises

# %%
metrics_dicts = [
    null_model_metrics,
    two_level_model_metrics,
    three_level_model_metrics,
    full_model_metrics,
    optimized_model_metrics
]

for metrics, train, test in zip(
        metrics_dicts,
        [train_df, train_df, train_df, train_df, train_df],
        [test_df, test_df, test_df, test_df, test_df]):
    
    metrics["# Obs (train)"] = len(train)
    metrics["# Obs (test)"] = len(test)
    metrics["# Obs (train/test)"] = f"{len(train)}/{len(test)}"

metrics_df = pd.DataFrame(metrics_dicts)

# Ensure all relevant columns are ordered and present
desired_order = [
    "Model", "R2_log", "R2_orig", "RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "# Obs (train/test)"
]


# Ensure MAE_log is present, fill with NaN if missing
if "MAE_log" not in metrics_df.columns:
    metrics_df["MAE_log"] = np.nan

metrics_df = metrics_df[[col for col in desired_order if col in metrics_df.columns]]

metrics_df_display = metrics_df.copy()
if "R2_log" in metrics_df_display.columns:
    metrics_df_display["R2_log"] = (metrics_df_display["R2_log"] * 100).map("{:.2f}%".format)
if "R2_orig" in metrics_df_display.columns:
    metrics_df_display["R2_orig"] = (metrics_df_display["R2_orig"] * 100).map("{:.2f}%".format)
for col in ["RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "MAPE(log)"]:
    if col in metrics_df_display.columns:
        metrics_df_display[col] = metrics_df_display[col].map("{:.2f}".format)

from IPython.display import display
display(metrics_df_display)
# Out:
#                                      Model  R2_log   R2_orig        RMSE  \
# 0                                Null (RI)  -2.71%   -19.72%  1750377.80
# 1                           2-level (RI+S)  -2.03%   -19.64%  1749802.24
# 2  3-level (Primary Activity/Account/Year)  23.53%   -16.86%  1729360.79
# 3                               Full Model  78.01%  -201.25%  2776583.31
# 4                                Optimized  78.04%  -216.34%  2845271.54
#
#          MAE MAE_log RMSLE     MAPE # Obs (train/test)
# 0  723890.41    2.41  3.02  4607.41             259/56
# 1  723732.38    2.40  3.01  4920.27             259/56
# 2  709750.62    2.09  2.60  1982.32             259/56
# 3  724851.92    1.03  1.40   254.02             259/56
# 4  732099.35    1.03  1.40   257.29             259/56
