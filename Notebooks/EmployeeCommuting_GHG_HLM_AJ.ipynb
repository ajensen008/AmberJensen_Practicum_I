# %% [markdown]
# # GHG HLM on Scope 3 source Employee Commuting

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_log_error, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GroupShuffleSplit
from scipy.stats import zscore
import scipy.stats as stats
from sklearn.feature_selection import mutual_info_regression
from sklearn.impute import SimpleImputer
import warnings
from statsmodels.regression.mixed_linear_model import MixedLM


#read in dataset GHG_post_outliers data set
employee_commuting=pd.read_csv('/Users/amberjensen/Desktop/GHG_Emissions_Project/employee_commuting.csv')

# %%
#check for info
employee_commuting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4661 entries, 0 to 4660
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_name                4661 non-null   object
#  1   account_id                  4661 non-null   int64
#  2   Year                        4661 non-null   int64
#  3   incorporated_country        4661 non-null   object
#  4   Primary activity            4661 non-null   object
#  5   Primary sector              4661 non-null   object
#  6   Market_Cap_USD              3874 non-null   float64
#  7   Third_party_verification    4659 non-null   object
#  8   Revenue_USD                 3887 non-null   float64
#  9   ebitda_USD                  3887 non-null   float64
#  10  grossProfit_USD             3887 non-null   float64
#  11  netIncome_USD               3887 non-null   float64
#  12  cashAndCashEquivalents_USD  3887 non-null   float64
#  13  shortTermInvestments_USD    3887 non-null   float64
#  14  longTermInvestments_USD     3887 non-null   float64
#  15  totalAssets_USD             3887 non-null   float64
#  16  totalLiabilities_USD        3887 non-null   float64
#  17  totalInvestments_USD        3887 non-null   float64
#  18  totalDebt_USD               3887 non-null   float64
#  19  totalEquity_USD             3887 non-null   float64
#  20  Scope_3_emissions_type      4661 non-null   object
#  21  Scope_3_emissions_amount    4661 non-null   float64
#  22  scope_1_2_emissions_amount  4651 non-null   float64
#  23  Year_sq                     4661 non-null   int64
# dtypes: float64(15), int64(3), object(6)
# memory usage: 874.1+ KB

# %%
#show a df for employee_commuting
employee_commuting.head()
# Out:
#                account_name  account_id  Year incorporated_country  \
# 0                  3i Group          44  2018       United Kingdom
# 1               Antofagasta         820  2018       United Kingdom
# 2                     Aptiv        4407  2018       United Kingdom
# 3                  Arm Ltd.         950  2018       United Kingdom
# 4  Associated British Foods        1085  2018       United Kingdom
#
#                Primary activity                     Primary sector  \
# 0                Asset managers                 Financial services
# 1  Other non-ferrous ore mining            Metallic mineral mining
# 2          Electrical equipment  Electrical & electronic equipment
# 3         Electronic components  Electrical & electronic equipment
# 4                Apparel stores               Discretionary retail
#
#    Market_Cap_USD                           Third_party_verification  \
# 0    9.548124e+09  Third-party verification or assurance process ...
# 1    7.721230e+09  Third-party verification or assurance process ...
# 2    1.595156e+10           No third-party verification or assurance
# 3             NaN           No third-party verification or assurance
# 4    2.051429e+10  Third-party verification or assurance process ...
#
#     Revenue_USD    ebitda_USD  ...  longTermInvestments_USD  totalAssets_USD  \
# 0  1.728470e+09  1.565910e+09  ...             8.544560e+09     1.107567e+10
# 1  4.733100e+09  2.092800e+09  ...             1.060800e+09     1.410250e+10
# 2  1.443500e+10  2.260000e+09  ...             9.900000e+07     1.248000e+10
# 3           NaN           NaN  ...                      NaN              NaN
# 4  1.977898e+10  2.363470e+09  ...             3.429000e+08     1.738884e+10
#
#    totalLiabilities_USD  totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0          1.031240e+09          8.544560e+09   7.302500e+08     1.004443e+10
# 1          4.664400e+09          1.924000e+09   2.493900e+09     9.438100e+09
# 2          8.810000e+09          1.710000e+08   4.344000e+09     3.670000e+09
# 3                   NaN                   NaN            NaN              NaN
# 4          5.582920e+09          3.810000e+08   9.880600e+08     1.180592e+10
#
#    Scope_3_emissions_type  Scope_3_emissions_amount  \
# 0      Employee commuting                      3.90
# 1      Employee commuting                   6213.00
# 2      Employee commuting                 237000.00
# 3      Employee commuting                   4190.96
# 4      Employee commuting                  57722.00
#
#    scope_1_2_emissions_amount  Year_sq
# 0                3.389500e+02  4072324
# 1                3.292186e+06  4072324
# 2                3.804718e+05  4072324
# 3                7.728538e+03  4072324
# 4                2.801746e+06  4072324
#
# [5 rows x 24 columns]

# %%
#define a list of numeric columns
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD',
       'grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD',
       'shortTermInvestments_USD', 'longTermInvestments_USD',
       'totalAssets_USD', 'totalLiabilities_USD', 'totalInvestments_USD',
       'totalDebt_USD', 'totalEquity_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount']

# %%
#plot the heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(employee_commuting[numeric_cols].corr(), annot=True, annot_kws={"size": 8})
plt.show()

# %%
#correlation matrix
employee_commuting[numeric_cols].corr()
# Out:
#                             Market_Cap_USD  Revenue_USD  ebitda_USD  \
# Market_Cap_USD                    1.000000     0.349139    0.458443
# Revenue_USD                       0.349139     1.000000    0.744201
# ebitda_USD                        0.458443     0.744201    1.000000
# grossProfit_USD                   0.348759     0.810433    0.746732
# netIncome_USD                     0.491785     0.712395    0.926902
# cashAndCashEquivalents_USD        0.058298     0.181288    0.261714
# shortTermInvestments_USD          0.090298     0.193507    0.259394
# longTermInvestments_USD           0.062880     0.234185    0.301213
# totalAssets_USD                   0.095794     0.310234    0.394829
# totalLiabilities_USD              0.074126     0.275611    0.350381
# totalInvestments_USD              0.088254     0.256971    0.333141
# totalDebt_USD                     0.128742     0.387544    0.476684
# totalEquity_USD                   0.272807     0.593799    0.715090
# Scope_3_emissions_amount          0.082609     0.359702    0.247635
# scope_1_2_emissions_amount       -0.006525     0.084342    0.047790
#
#                             grossProfit_USD  netIncome_USD  \
# Market_Cap_USD                     0.348759       0.491785
# Revenue_USD                        0.810433       0.712395
# ebitda_USD                         0.746732       0.926902
# grossProfit_USD                    1.000000       0.737502
# netIncome_USD                      0.737502       1.000000
# cashAndCashEquivalents_USD         0.327859       0.249593
# shortTermInvestments_USD           0.323920       0.232104
# longTermInvestments_USD            0.436533       0.297462
# totalAssets_USD                    0.516788       0.363321
# totalLiabilities_USD               0.476121       0.322399
# totalInvestments_USD               0.462318       0.323775
# totalDebt_USD                      0.512263       0.399090
# totalEquity_USD                    0.730756       0.660342
# Scope_3_emissions_amount           0.229625       0.200553
# scope_1_2_emissions_amount        -0.006176       0.003068
#
#                             cashAndCashEquivalents_USD  \
# Market_Cap_USD                                0.058298
# Revenue_USD                                   0.181288
# ebitda_USD                                    0.261714
# grossProfit_USD                               0.327859
# netIncome_USD                                 0.249593
# cashAndCashEquivalents_USD                    1.000000
# shortTermInvestments_USD                      0.063560
# longTermInvestments_USD                       0.700255
# totalAssets_USD                               0.848102
# totalLiabilities_USD                          0.820321
# totalInvestments_USD                          0.644149
# totalDebt_USD                                 0.771750
# totalEquity_USD                               0.583860
# Scope_3_emissions_amount                      0.068310
# scope_1_2_emissions_amount                   -0.028488
#
#                             shortTermInvestments_USD  longTermInvestments_USD  \
# Market_Cap_USD                              0.090298                 0.062880
# Revenue_USD                                 0.193507                 0.234185
# ebitda_USD                                  0.259394                 0.301213
# grossProfit_USD                             0.323920                 0.436533
# netIncome_USD                               0.232104                 0.297462
# cashAndCashEquivalents_USD                  0.063560                 0.700255
# shortTermInvestments_USD                    1.000000                 0.540021
# longTermInvestments_USD                     0.540021                 1.000000
# totalAssets_USD                             0.347622                 0.884511
# totalLiabilities_USD                        0.335513                 0.852822
# totalInvestments_USD                        0.623095                 0.954581
# totalDebt_USD                               0.151700                 0.679454
# totalEquity_USD                             0.381863                 0.670558
# Scope_3_emissions_amount                    0.074962                 0.081317
# scope_1_2_emissions_amount                 -0.019479                -0.043540
#
#                             totalAssets_USD  totalLiabilities_USD  \
# Market_Cap_USD                     0.095794              0.074126
# Revenue_USD                        0.310234              0.275611
# ebitda_USD                         0.394829              0.350381
# grossProfit_USD                    0.516788              0.476121
# netIncome_USD                      0.363321              0.322399
# cashAndCashEquivalents_USD         0.848102              0.820321
# shortTermInvestments_USD           0.347622              0.335513
# longTermInvestments_USD            0.884511              0.852822
# totalAssets_USD                    1.000000              0.961960
# totalLiabilities_USD               0.961960              1.000000
# totalInvestments_USD               0.844361              0.816753
# totalDebt_USD                      0.858442              0.839315
# totalEquity_USD                    0.776862              0.722415
# Scope_3_emissions_amount           0.120163              0.114501
# scope_1_2_emissions_amount        -0.020063             -0.023824
#
#                             totalInvestments_USD  totalDebt_USD  \
# Market_Cap_USD                          0.088254       0.128742
# Revenue_USD                             0.256971       0.387544
# ebitda_USD                              0.333141       0.476684
# grossProfit_USD                         0.462318       0.512263
# netIncome_USD                           0.323775       0.399090
# cashAndCashEquivalents_USD              0.644149       0.771750
# shortTermInvestments_USD                0.623095       0.151700
# longTermInvestments_USD                 0.954581       0.679454
# totalAssets_USD                         0.844361       0.858442
# totalLiabilities_USD                    0.816753       0.839315
# totalInvestments_USD                    1.000000       0.645811
# totalDebt_USD                           0.645811       1.000000
# totalEquity_USD                         0.671019       0.723432
# Scope_3_emissions_amount                0.087248       0.170094
# scope_1_2_emissions_amount             -0.041017       0.033871
#
#                             totalEquity_USD  Scope_3_emissions_amount  \
# Market_Cap_USD                     0.272807                  0.082609
# Revenue_USD                        0.593799                  0.359702
# ebitda_USD                         0.715090                  0.247635
# grossProfit_USD                    0.730756                  0.229625
# netIncome_USD                      0.660342                  0.200553
# cashAndCashEquivalents_USD         0.583860                  0.068310
# shortTermInvestments_USD           0.381863                  0.074962
# longTermInvestments_USD            0.670558                  0.081317
# totalAssets_USD                    0.776862                  0.120163
# totalLiabilities_USD               0.722415                  0.114501
# totalInvestments_USD               0.671019                  0.087248
# totalDebt_USD                      0.723432                  0.170094
# totalEquity_USD                    1.000000                  0.195794
# Scope_3_emissions_amount           0.195794                  1.000000
# scope_1_2_emissions_amount         0.062808                  0.079360
#
#                             scope_1_2_emissions_amount
# Market_Cap_USD                               -0.006525
# Revenue_USD                                   0.084342
# ebitda_USD                                    0.047790
# grossProfit_USD                              -0.006176
# netIncome_USD                                 0.003068
# cashAndCashEquivalents_USD                   -0.028488
# shortTermInvestments_USD                     -0.019479
# longTermInvestments_USD                      -0.043540
# totalAssets_USD                              -0.020063
# totalLiabilities_USD                         -0.023824
# totalInvestments_USD                         -0.041017
# totalDebt_USD                                 0.033871
# totalEquity_USD                               0.062808
# Scope_3_emissions_amount                      0.079360
# scope_1_2_emissions_amount                    1.000000

# %%
#drop columns due to collinearity, keeping total
employee_commuting=employee_commuting.drop(columns=['grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD',
                                                    "account_name", "Third_party_verification", "Scope_3_emissions_type"])

# %%
employee_commuting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4661 entries, 0 to 4660
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  4661 non-null   int64
#  1   Year                        4661 non-null   int64
#  2   incorporated_country        4661 non-null   object
#  3   Primary activity            4661 non-null   object
#  4   Primary sector              4661 non-null   object
#  5   Market_Cap_USD              3874 non-null   float64
#  6   Revenue_USD                 3887 non-null   float64
#  7   ebitda_USD                  3887 non-null   float64
#  8   shortTermInvestments_USD    3887 non-null   float64
#  9   longTermInvestments_USD     3887 non-null   float64
#  10  totalAssets_USD             3887 non-null   float64
#  11  totalLiabilities_USD        3887 non-null   float64
#  12  totalInvestments_USD        3887 non-null   float64
#  13  totalDebt_USD               3887 non-null   float64
#  14  totalEquity_USD             3887 non-null   float64
#  15  Scope_3_emissions_amount    4661 non-null   float64
#  16  scope_1_2_emissions_amount  4651 non-null   float64
#  17  Year_sq                     4661 non-null   int64
# dtypes: float64(12), int64(3), object(3)
# memory usage: 655.6+ KB

# %%
sns.boxplot(employee_commuting)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# copy dataframe
employee_commuting_no_transform = employee_commuting.copy()
# Change 'incorporated_country' to 'Countries' in employee_commuting dataframe
employee_commuting_no_transform = employee_commuting_no_transform.rename(columns={'incorporated_country': 'Countries',
                                                       'Primary activity': 'Primary_activity',
                                                        'Primary sector': 'Primary_sector'})

print(employee_commuting_no_transform.info())
employee_commuting_no_transform.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4661 entries, 0 to 4660
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  4661 non-null   int64
#  1   Year                        4661 non-null   int64
#  2   Countries                   4661 non-null   object
#  3   Primary_activity            4661 non-null   object
#  4   Primary_sector              4661 non-null   object
#  5   Market_Cap_USD              3874 non-null   float64
#  6   Revenue_USD                 3887 non-null   float64
#  7   ebitda_USD                  3887 non-null   float64
#  8   shortTermInvestments_USD    3887 non-null   float64
#  9   longTermInvestments_USD     3887 non-null   float64
#  10  totalAssets_USD             3887 non-null   float64
#  11  totalLiabilities_USD        3887 non-null   float64
#  12  totalInvestments_USD        3887 non-null   float64
#  13  totalDebt_USD               3887 non-null   float64
#  14  totalEquity_USD             3887 non-null   float64
#  15  Scope_3_emissions_amount    4661 non-null   float64
#  16  scope_1_2_emissions_amount  4651 non-null   float64
#  17  Year_sq                     4661 non-null   int64
# dtypes: float64(12), int64(3), object(3)
# memory usage: 655.6+ KB
# None
#    account_id  Year       Countries              Primary_activity  \
# 0          44  2018  United Kingdom                Asset managers
# 1         820  2018  United Kingdom  Other non-ferrous ore mining
# 2        4407  2018  United Kingdom          Electrical equipment
# 3         950  2018  United Kingdom         Electronic components
# 4        1085  2018  United Kingdom                Apparel stores
#
#                       Primary_sector  Market_Cap_USD   Revenue_USD  \
# 0                 Financial services    9.548124e+09  1.728470e+09
# 1            Metallic mineral mining    7.721230e+09  4.733100e+09
# 2  Electrical & electronic equipment    1.595156e+10  1.443500e+10
# 3  Electrical & electronic equipment             NaN           NaN
# 4               Discretionary retail    2.051429e+10  1.977898e+10
#
#      ebitda_USD  shortTermInvestments_USD  longTermInvestments_USD  \
# 0  1.565910e+09                       0.0             8.544560e+09
# 1  2.092800e+09               863200000.0             1.060800e+09
# 2  2.260000e+09                72000000.0             9.900000e+07
# 3           NaN                       NaN                      NaN
# 4  2.363470e+09                38100000.0             3.429000e+08
#
#    totalAssets_USD  totalLiabilities_USD  totalInvestments_USD  totalDebt_USD  \
# 0     1.107567e+10          1.031240e+09          8.544560e+09   7.302500e+08
# 1     1.410250e+10          4.664400e+09          1.924000e+09   2.493900e+09
# 2     1.248000e+10          8.810000e+09          1.710000e+08   4.344000e+09
# 3              NaN                   NaN                   NaN            NaN
# 4     1.738884e+10          5.582920e+09          3.810000e+08   9.880600e+08
#
#    totalEquity_USD  Scope_3_emissions_amount  scope_1_2_emissions_amount  \
# 0     1.004443e+10                      3.90                3.389500e+02
# 1     9.438100e+09                   6213.00                3.292186e+06
# 2     3.670000e+09                 237000.00                3.804718e+05
# 3              NaN                   4190.96                7.728538e+03
# 4     1.180592e+10                  57722.00                2.801746e+06
#
#    Year_sq
# 0  4072324
# 1  4072324
# 2  4072324
# 3  4072324
# 4  4072324

# %%
employee_commuting_no_transform['Primary_sector'].value_counts()
# Out:
# Primary_sector
# Financial services                                    690
# Electrical & electronic equipment                     514
# Chemicals                                             365
# Construction                                          198
# Media, telecommunications & data center services      190
# Biotech & pharma                                      189
# Food & beverage processing                            189
# Specialized professional services                     187
# Powered machinery                                     130
# Discretionary retail                                  118
# Energy utility networks                               107
# Medical equipment & supplies                           96
# Thermal power generation                               94
# Trading, wholesale, distribution, rental & leasing     93
# Convenience retail                                     91
# Other services                                         67
# Leisure & home manufacturing                           66
# Metal products manufacturing                           64
# Paper products & packaging                             63
# Plastic product manufacturing                          61
# Transportation equipment                               60
# IT & software development                              58
# Intermodal transport & logistics                       53
# Bars, hotels & restaurants                             53
# Web & marketing services                               49
# Metal smelting, refining & forming                     48
# 0                                                      48
# Air transport                                          46
# Commercial & consumer services                         42
# Light manufacturing                                    42
# Wood & rubber products                                 40
# Print & publishing services                            40
# Textiles & fabric goods                                39
# Rail transport                                         39
# Metallic mineral mining                                39
# Land & property ownership & development                37
# Marine transport                                       30
# Non-energy utilities                                   29
# Industrial support services                            28
# Cement & concrete                                      27
# Wood & paper materials                                 26
# Other materials                                        26
# Tobacco                                                23
# Apparel design                                         23
# Entertainment facilities                               21
# Health care provision                                  17
# Renewable power generation                             16
# Oil & gas storage & transportation                     15
# Fish & animal farming                                  15
# Oil & gas extraction & production                      12
# Renewable energy equipment                             10
# Accessories                                            10
# Oil & gas retailing                                    10
# Road transport                                          7
# Logging & rubber tapping                                6
# Other mineral mining                                    5
# Name: count, dtype: int64

# %%
employee_commuting_no_transform['Primary_activity'].value_counts().head(20)
# Out:
# Primary_activity
# Banks                                 370
# Electronic components                 190
# Telecommunications services           172
# Other professional services           166
# Pharmaceuticals                       149
# Insurance                             141
# REIT                                  130
# Other base chemicals                  117
# Specialty chemicals                   114
# Electrical equipment                   97
# Electricity networks                   92
# Supermarkets, food & drugstores        91
# Electronic equipment                   80
# Personal care & household products     78
# CCGT generation                        74
# Communications equipment               73
# Other food processing                  72
# Industrial machinery                   66
# Paper products                         63
# Medical equipment                      62
# Name: count, dtype: int64

# %%
# Looking at missing data
print(employee_commuting_no_transform.isnull().mean().sort_values(ascending=False).round(3) * 100)
# Out:
# Market_Cap_USD                16.9
# longTermInvestments_USD       16.6
# totalInvestments_USD          16.6
# totalEquity_USD               16.6
# Revenue_USD                   16.6
# ebitda_USD                    16.6
# shortTermInvestments_USD      16.6
# totalDebt_USD                 16.6
# totalAssets_USD               16.6
# totalLiabilities_USD          16.6
# scope_1_2_emissions_amount     0.2
# Scope_3_emissions_amount       0.0
# account_id                     0.0
# Year                           0.0
# Primary_sector                 0.0
# Primary_activity               0.0
# Countries                      0.0
# Year_sq                        0.0
# dtype: float64

# %% [markdown]
# Apply signed log transformation and split data by company and year into train_df (2018-2022) and test_df (2023):

# %%
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD',
       'shortTermInvestments_USD', 'longTermInvestments_USD',
       'totalAssets_USD', 'totalLiabilities_USD', 'totalInvestments_USD',
       'totalDebt_USD', 'totalEquity_USD', 'Scope_3_emissions_amount',
       'scope_1_2_emissions_amount'
]
required_cols = [
    'account_id', 'Year', 'Year_sq', 'Countries', 'Primary_activity', 'Primary_sector'
] + numeric_cols

# --- Prepare Data ---
df = employee_commuting_no_transform[required_cols].dropna()

# --- Signed log transform ---
def signed_log(x):
    return np.sign(x) * np.log(np.abs(x) + 1)

for col in numeric_cols:
    df[f'slog_{col}'] = signed_log(df[col])

# --- Company-level split by year ---
train_df = df[df['Year'].between(2018, 2022)].copy()
test_df  = df[df['Year'] == 2023].copy()

# Keep only companies present in training
valid_companies = set(train_df['account_id'].unique())
test_df = test_df[test_df['account_id'].isin(valid_companies)].copy()

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (3092, 30)
# Test shape: (653, 30)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3092 entries, 0 to 3757
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       3092 non-null   int64
#  1   Year                             3092 non-null   int64
#  2   Year_sq                          3092 non-null   int64
#  3   Countries                        3092 non-null   object
#  4   Primary_activity                 3092 non-null   object
#  5   Primary_sector                   3092 non-null   object
#  6   Market_Cap_USD                   3092 non-null   float64
#  7   Revenue_USD                      3092 non-null   float64
#  8   ebitda_USD                       3092 non-null   float64
#  9   shortTermInvestments_USD         3092 non-null   float64
#  10  longTermInvestments_USD          3092 non-null   float64
#  11  totalAssets_USD                  3092 non-null   float64
#  12  totalLiabilities_USD             3092 non-null   float64
#  13  totalInvestments_USD             3092 non-null   float64
#  14  totalDebt_USD                    3092 non-null   float64
#  15  totalEquity_USD                  3092 non-null   float64
#  16  Scope_3_emissions_amount         3092 non-null   float64
#  17  scope_1_2_emissions_amount       3092 non-null   float64
#  18  slog_Market_Cap_USD              3092 non-null   float64
#  19  slog_Revenue_USD                 3092 non-null   float64
#  20  slog_ebitda_USD                  3092 non-null   float64
#  21  slog_shortTermInvestments_USD    3092 non-null   float64
#  22  slog_longTermInvestments_USD     3092 non-null   float64
#  23  slog_totalAssets_USD             3092 non-null   float64
#  24  slog_totalLiabilities_USD        3092 non-null   float64
#  25  slog_totalInvestments_USD        3092 non-null   float64
#  26  slog_totalDebt_USD               3092 non-null   float64
#  27  slog_totalEquity_USD             3092 non-null   float64
#  28  slog_Scope_3_emissions_amount    3092 non-null   float64
#  29  slog_scope_1_2_emissions_amount  3092 non-null   float64
# dtypes: float64(24), int64(3), object(3)
# memory usage: 748.8+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 653 entries, 3760 to 4658
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       653 non-null    int64
#  1   Year                             653 non-null    int64
#  2   Year_sq                          653 non-null    int64
#  3   Countries                        653 non-null    object
#  4   Primary_activity                 653 non-null    object
#  5   Primary_sector                   653 non-null    object
#  6   Market_Cap_USD                   653 non-null    float64
#  7   Revenue_USD                      653 non-null    float64
#  8   ebitda_USD                       653 non-null    float64
#  9   shortTermInvestments_USD         653 non-null    float64
#  10  longTermInvestments_USD          653 non-null    float64
#  11  totalAssets_USD                  653 non-null    float64
#  12  totalLiabilities_USD             653 non-null    float64
#  13  totalInvestments_USD             653 non-null    float64
#  14  totalDebt_USD                    653 non-null    float64
#  15  totalEquity_USD                  653 non-null    float64
#  16  Scope_3_emissions_amount         653 non-null    float64
#  17  scope_1_2_emissions_amount       653 non-null    float64
#  18  slog_Market_Cap_USD              653 non-null    float64
#  19  slog_Revenue_USD                 653 non-null    float64
#  20  slog_ebitda_USD                  653 non-null    float64
#  21  slog_shortTermInvestments_USD    653 non-null    float64
#  22  slog_longTermInvestments_USD     653 non-null    float64
#  23  slog_totalAssets_USD             653 non-null    float64
#  24  slog_totalLiabilities_USD        653 non-null    float64
#  25  slog_totalInvestments_USD        653 non-null    float64
#  26  slog_totalDebt_USD               653 non-null    float64
#  27  slog_totalEquity_USD             653 non-null    float64
#  28  slog_Scope_3_emissions_amount    653 non-null    float64
#  29  slog_scope_1_2_emissions_amount  653 non-null    float64
# dtypes: float64(24), int64(3), object(3)
# memory usage: 158.1+ KB

# %%
print((train_df == 0).sum().sum())
print((test_df == 0).sum().sum())
# Out:
# 1524
# 452

# %% [markdown]
# ## Employee Commuting Null Mixed-Effects Model
#
# Null mixed-effects model (random intercept only) to predict log-transformed Scope 3 emissions. The model serves as a baseline, capturing only the average emission level for each company, without incorporating any explanatory variables, and quantifies the improvement gained by including additional features and structure. The model is trained on 2018–2022 data and evaluated on a test set from 2023.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies
# - Fixed Effects:
#     - Intercept only (no predictors)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE NULL MODEL (random intercept only) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    null_model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ 1",
        train_df,
        groups=train_df["account_id"]
    )
    null_result = null_model.fit(method="lbfgs")

if not null_result.converged:
    print("WARNING: Null model did not fully converge.")

print(null_result.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_null'] = null_result.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_null']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_null'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics text
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[0], color='gray')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Null Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[1], color='gray')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Null Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Null Model Predicted")
plt.xscale("log")
plt.title("Null Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
null_model_metrics = {
    "Model": "Null (RI)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "Random intercept only"
}
# Out:
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 3092    Method:             REML
# No. Groups:       741     Scale:              0.5021
# Min. group size:  1       Log-Likelihood:     -4593.4380
# Max. group size:  5       Converged:          Yes
# Mean group size:  4.2
# ------------------------------------------------------------------------------
#                 Coef.     Std.Err.        z        P>|z|     [0.025     0.975]
# ------------------------------------------------------------------------------
# Intercept       8.945        0.074     121.161     0.000      8.801      9.090
# Group Var       3.889        0.341
# ==========================================================================
#
# R²(log):    -1.18%
# R²(orig):   -9.21%
# MAPE:       2188.38%
# MAPE(log):  20.69%
# MAE(log):   1.49
# RMSLE:      1.88
# RMSE:       105269.70
# MAE:        34697.26

# %% [markdown]
# ## Employee Commuting Two-Level Mixed-Effects Model
#
# Two-level hierarchical linear mixed-effects model to predict log-transformed Scope 3 emissions at the company level. The model is fit to training data (from 2018–2022), and predictions are evaluated on a test set (from 2023).  This model provides a baseline for including time trends and company-level variability.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies.<br>
# - Fixed Effects:
#     - Year (numeric)
#     - Year squared ('Year_sq', quadratic time trend)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- Check group sizes ---
group_sizes = train_df.groupby('account_id').size()
print("Two-Level Model: Company/year group size summary:")
print(group_sizes.describe())

# --- FIT THE TWO-LEVEL MODEL (random intercept, +Year, +Year_sq) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ Year + Year_sq",
        train_df,
        groups=train_df["account_id"],
        re_formula="1"
    )
    result_twolevel = model.fit(method="lbfgs")

if not result_twolevel.converged:
    print("WARNING: Two-level mixed model did not fully converge.")

print(result_twolevel.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_twolevel.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_mixed']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='orange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Two-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='orange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Two-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="orange", alpha=0.5, label="Two-Level Model Predicted")
plt.xscale("log")
plt.title("Two-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
two_level_model_metrics = {
    "Model": "2-level (RI+S)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "+Year, Year_sq"
}
# Out:
# Two-Level Model: Company/year group size summary:
# count    741.000000
# mean       4.172740
# std        1.315135
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000
# dtype: float64
# WARNING: Two-level mixed model did not fully converge.
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 3092    Method:             REML
# No. Groups:       741     Scale:              0.4952
# Min. group size:  1       Log-Likelihood:     -4583.3507
# Max. group size:  5       Converged:          No
# Mean group size:  4.2
# ---------------------------------------------------------------------------
#                 Coef.      Std.Err.    z     P>|z|     [0.025      0.975]
# ---------------------------------------------------------------------------
# Intercept    -139203.355  31888.719  -4.365  0.000  -201704.095  -76702.615
# Year             137.870     31.572   4.367  0.000       75.989     199.750
# Year_sq           -0.034      0.008  -4.368  0.000       -0.049      -0.019
# Group Var          3.884      0.343
# ==========================================================================
#
# R²(log):    -8.17%
# R²(orig):   -10.57%
# MAPE:       1575.23%
# MAPE(log):  20.71%
# MAE(log):   1.56
# RMSLE:      1.95
# RMSE:       105920.50
# MAE:        35147.05

# %% [markdown]
# ## Employee Commuting Three-Level Mixed-Effects Model
#
# A three-level hierarchical linear mixed-effects model is used to predict log-transformed Scope 3 emissions. It takes into account differences between primary activity, differences between companies, and changes over time. The model is trained using data from 2018 to 2022, and then tested on new data from 2023. This model provides insight on how emissions are influenced by primary activity, by individual companies, by financial and emissions factors, and by trends over time.
#
# Model Structure:
#
# - Level 3 (Primary Activity):<br>
#     - Random intercept and random slope for Year for each primary activity ('Primary_activity'), capturing baseline primary activity and primary activity-specific time trends.<br>
# - Level 2 (Account/Company):
#     - Random intercept for each company ('account_id'), capturing company-level deviations within each primary activity.
# - Level 1 (Yearly Observations):
#     - Repeated annual observations within each company.
#
# - Fixed Effects:
#     - Signed log-transformed market cap ('slog_Market_Cap_USD')
#     - Signed log-transformed revenue ('slog_Revenue_USD')
#     - Signed log-transformed EBITDA ('slog_ebitda_USD')
#     - Signed log-transformed Scope 1 & 2 emissions ('slog_scope_1_2_emissions_amount')

# %%
# --- Ensure grouping/categorical variables are string ---
for col in ['Countries', 'account_id', 'Primary_activity', 'Primary_sector']:
    train_df[col] = train_df[col].astype(str)
    test_df[col] = test_df[col].astype(str)

# --- Center the Year variable ---
year_mean = train_df['Year'].mean()
train_df['Year_centered'] = train_df['Year'] - year_mean
test_df['Year_centered'] = test_df['Year'] - year_mean

# --- Ensure log-transformed target exists ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE 3-LEVEL MIXED MODEL with Primary_activity as Level 3 group ---
vc = {'account_id': '0 + C(account_id)'}  # Level 2: account_id random intercept

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model_3level = MixedLM.from_formula(
        'log_Scope_3_emissions_amount ~ slog_Market_Cap_USD + slog_Revenue_USD + slog_ebitda_USD + slog_scope_1_2_emissions_amount',
        groups='Primary_activity',
        re_formula='~Year_centered',
        vc_formula=vc,
        data=train_df
    )
    result_3level = model_3level.fit(method="lbfgs", maxiter=1000)

if not result_3level.converged:
    print("WARNING: Three-level mixed model did not fully converge.")

print(result_3level.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_3level.predict(test_df)

# --- Compute back-transformed values ---
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])

# --- Robust Mask for finite values everywhere ---
mask = (
    np.isfinite(test_df['log_Scope_3_emissions_amount']) &
    np.isfinite(test_df['predicted_mixed']) &
    np.isfinite(test_df['Reported_Scope_3']) &
    np.isfinite(test_df['Predicted_Scope_3'])
)
test_df = test_df.loc[mask].copy()

y_true_log = test_df['log_Scope_3_emissions_amount'].values
y_pred_log = test_df['predicted_mixed'].values
y_true = test_df['Reported_Scope_3'].values
y_pred = test_df['Predicted_Scope_3'].values

# Final defensive check and diagnostics
arrays = {
    "y_true_log": y_true_log,
    "y_pred_log": y_pred_log,
    "y_true": y_true,
    "y_pred": y_pred,
}
for arr_name, arr in arrays.items():
    if not np.all(np.isfinite(arr)):
        print(f"ERROR: {arr_name} contains non-finite values!")
        print(f"Non-finite indices: {np.where(~np.isfinite(arr))[0]}")
        print(f"Values: {arr[~np.isfinite(arr)]}")
        raise ValueError(f"{arr_name} contains infs or NaNs after masking!")

# --- METRICS ---
mae_log = mean_absolute_error(y_true_log, y_pred_log)
nonzero_mask = y_true_log != 0
if np.any(nonzero_mask):
    mape_log = np.mean(np.abs((y_true_log[nonzero_mask] - y_pred_log[nonzero_mask]) / y_true_log[nonzero_mask])) * 100
else:
    mape_log = np.nan

r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)

metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
if len(np.unique(y_pred_log)) > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Three-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()
axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

if len(np.unique(y_pred)) > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Three-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()
axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Filter strictly positive values for histogram (log x-axis requires >0)
y_true_pos = y_true[y_true > 0]
y_pred_pos = y_pred[y_pred > 0]

if y_true_pos.size > 0 and y_pred_pos.size > 0:
    min_val = min(y_true_pos.min(), y_pred_pos.min())
    max_val = max(y_true_pos.max(), y_pred_pos.max())
    if min_val == max_val:
        print("Skipping histogram: Only one unique positive value present.")
    else:
        log_bins = np.logspace(np.log10(min_val), np.log10(max_val), 100)

        plt.figure(figsize=(8, 5))
        sns.histplot(y_true_pos, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
        sns.histplot(y_pred_pos, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Three-Level Model Predicted")
        plt.xscale("log")
        plt.title("Three-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
        plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
        plt.ylabel("Density")
        plt.legend()
        plt.tight_layout()
        plt.show()
else:
    print("Skipping histogram: Not enough positive values in y_true or y_pred for log-scale histogram.")

# --- RETURN METRICS FOR SUMMARY TABLE ---
three_level_model_metrics = {
    "Model": "3-level (Primary Activity/Account/Year)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,
    "MAPE(log)": mape_log,
}
# Out:
# WARNING: Three-level mixed model did not fully converge.
#                      Mixed Linear Model Regression Results
# ===============================================================================
# Model:               MixedLM  Dependent Variable:  log_Scope_3_emissions_amount
# No. Observations:    3092     Method:              REML
# No. Groups:          122      Scale:               0.4320
# Min. group size:     1        Log-Likelihood:      -4413.5713
# Max. group size:     224      Converged:           No
# Mean group size:     25.3
# -------------------------------------------------------------------------------
#                                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------------
# Intercept                             0.021    0.772  0.027 0.978 -1.491  1.533
# slog_Market_Cap_USD                   0.264    0.032  8.197 0.000  0.201  0.328
# slog_Revenue_USD                      0.030    0.010  2.881 0.004  0.010  0.050
# slog_ebitda_USD                      -0.008    0.003 -3.107 0.002 -0.013 -0.003
# slog_scope_1_2_emissions_amount       0.192    0.021  9.251 0.000  0.151  0.233
# Primary_activity Var                  0.563    0.233
# Primary_activity x Year_centered Cov -0.027    0.050
# Year_centered Var                     0.042    0.031
# account_id Var                        2.671    0.378
# ===============================================================================
#
# R²(log):    27.78%
# R²(orig):   -2.40%
# MAPE:       1091.66%
# MAPE(log):  17.25%
# MAE(log):   1.24
# RMSLE:      1.59
# RMSE:       101933.20
# MAE:        32227.21

# %% [markdown]
# ## Employee Commuting Full Mixed-Effects Model
#
# A full mixed-effects model is used to predict company Scope 3 emissions, using financial and emissions data, along with information about country, industry, and year. The model is trained on data from 2018 to 2022, and tested on data from 2023. This full model helps provides insights into how a company’s finances, emissions, primary activity, country and the year influence emissions.<br>
#
# Model Structure:<br>
#
# - Random Effects:<br>
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:<br>
#     - Signed log-transformed financial and emissions features:<br>
#         - Market Cap ('slog_Market_Cap_USD')<br>
#         - Revenue ('slog_Revenue_USD')<br>
#         - EBITDA ('slog_ebitda_USD')<br>
#         - Short Term Investments ('slog_shortTermInvestments_USD')
#         - Long Term Investments ('slog_longTermInvestments_USD')
#         - Total Investments ('slog_totalInvestments_USD')<br>
#         - Total Debt ('slog_totalDebt_USD')<br>
#         - Total Liabilities ('slog_totalLiabilities_USD')<br>
#         - Total Assets ('slog_totalAssets_USD')<br>
#         - Total Equity ('slog_totalEquity_USD')<br>
#         - Scope 1&2 Emissions ('slog_scope_1_2_emissions_amount')<br>
#     - Country ('Countries', as a categorical variable)<br>
#     - Primary Activity ('Primary_activity', as a categorical variable)<br>
#     - Year (numeric)<br>

# %%
# --- Feature and target columns ---
numeric_cols = ['Market_Cap_USD',
 'Revenue_USD',
 'ebitda_USD',
 'shortTermInvestments_USD',
 'longTermInvestments_USD',
 'totalAssets_USD',
 'totalLiabilities_USD',
 'totalInvestments_USD',
 'totalDebt_USD',
 'totalEquity_USD',
 'Scope_3_emissions_amount',
 'scope_1_2_emissions_amount'
]
feature_cols_slog = [f'slog_{col}' for col in numeric_cols if col != 'Scope_3_emissions_amount']
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
required_cols = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_full = train_df.dropna(subset=required_cols).copy()
test_df_full = test_df.dropna(subset=required_cols).copy()

if test_df_full.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the full mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_full, groups=train_df_full['account_id'])
        mdf = md.fit(reml=False)
    print(mdf.summary())

    # --- Predict on test set ---
    test_df_full['predicted_log'] = mdf.predict(test_df_full)
    test_df_full['predicted'] = np.sign(test_df_full['predicted_log']) * (np.expm1(np.abs(test_df_full['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_full[target_col_slog]
    y_pred_log = test_df_full['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_full['predicted']

    # Mask for finite values
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nFull Mixed-Effects Model (Full Model) Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf.params,
        'pvalue': mdf.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Full Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Full Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Full Model Predicted")
    plt.xscale("log")
    plt.title("Full Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    full_model_metrics = {
        "Model": "Full Model",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                         Mixed Linear Model Regression Results
# ======================================================================================================================
# Model:                           MixedLM               Dependent Variable:               slog_Scope_3_emissions_amount
# No. Observations:                3092                  Method:                           ML
# No. Groups:                      741                   Scale:                            0.5046
# Min. group size:                 1                     Log-Likelihood:                   -4178.5302
# Max. group size:                 5                     Converged:                        Yes
# Mean group size:                 4.2
# ----------------------------------------------------------------------------------------------------------------------
#                                                                            Coef.  Std.Err.   z    P>|z| [0.025  0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 131.457   19.620  6.700 0.000 93.003 169.912
# C(Countries)[T.Austria]                                                    -0.624    0.848 -0.736 0.462 -2.287   1.039
# C(Countries)[T.Belgium]                                                    -0.715    0.591 -1.211 0.226 -1.873   0.442
# C(Countries)[T.Bermuda]                                                     0.041    1.252  0.033 0.974 -2.412   2.494
# C(Countries)[T.Brazil]                                                     -0.950    0.494 -1.923 0.054 -1.919   0.018
# C(Countries)[T.Canada]                                                     -0.628    0.464 -1.355 0.175 -1.537   0.280
# C(Countries)[T.Chile]                                                      -1.757    1.395 -1.260 0.208 -4.491   0.977
# C(Countries)[T.China]                                                      -2.546    0.503 -5.057 0.000 -3.533  -1.559
# C(Countries)[T.Denmark]                                                    -0.194    0.768 -0.253 0.800 -1.699   1.310
# C(Countries)[T.Finland]                                                    -1.031    0.517 -1.994 0.046 -2.045  -0.018
# C(Countries)[T.France]                                                      0.222    0.424  0.525 0.600 -0.608   1.053
# C(Countries)[T.Germany]                                                    -0.023    0.432 -0.053 0.958 -0.870   0.824
# C(Countries)[T.Greece]                                                     -2.381    0.762 -3.122 0.002 -3.875  -0.886
# C(Countries)[T.Hungary]                                                    -2.175    1.206 -1.804 0.071 -4.538   0.188
# C(Countries)[T.India]                                                       0.445    0.906  0.491 0.624 -1.331   2.220
# C(Countries)[T.Ireland]                                                    -0.420    0.595 -0.707 0.480 -1.586   0.745
# C(Countries)[T.Israel]                                                     -2.581    1.656 -1.559 0.119 -5.826   0.664
# C(Countries)[T.Italy]                                                      -0.701    0.509 -1.378 0.168 -1.698   0.296
# C(Countries)[T.Japan]                                                      -1.204    0.373 -3.225 0.001 -1.935  -0.472
# C(Countries)[T.Luxembourg]                                                 -0.196    1.504 -0.130 0.896 -3.144   2.752
# C(Countries)[T.Mexico]                                                     -4.573    1.007 -4.540 0.000 -6.548  -2.599
# C(Countries)[T.Netherlands]                                                -0.631    0.485 -1.303 0.192 -1.581   0.318
# C(Countries)[T.New Zealand]                                                -1.589    0.708 -2.243 0.025 -2.977  -0.200
# C(Countries)[T.Norway]                                                     -1.014    0.529 -1.918 0.055 -2.049   0.022
# C(Countries)[T.Peru]                                                        0.086    1.183  0.073 0.942 -2.233   2.406
# C(Countries)[T.Portugal]                                                   -3.184    0.822 -3.873 0.000 -4.794  -1.573
# C(Countries)[T.Singapore]                                                  -1.312    0.943 -1.392 0.164 -3.159   0.535
# C(Countries)[T.South Africa]                                                0.044    0.437  0.101 0.920 -0.813   0.901
# C(Countries)[T.South Korea]                                                -1.537    0.460 -3.340 0.001 -2.439  -0.635
# C(Countries)[T.Spain]                                                      -0.834    0.434 -1.923 0.054 -1.684   0.016
# C(Countries)[T.Sweden]                                                     -1.141    0.601 -1.899 0.058 -2.319   0.036
# C(Countries)[T.Switzerland]                                                -0.337    0.459 -0.733 0.463 -1.236   0.563
# C(Countries)[T.Thailand]                                                   -0.584    0.768 -0.760 0.447 -2.089   0.922
# C(Countries)[T.Turkey]                                                     -4.431    1.380 -3.212 0.001 -7.135  -1.727
# C(Countries)[T.USA]                                                        -0.098    0.370 -0.264 0.792 -0.824   0.628
# C(Countries)[T.United Kingdom]                                             -0.522    0.388 -1.348 0.178 -1.282   0.237
# C(Primary_activity)[T.Accessories manufacture]                              1.188    0.926  1.283 0.199 -0.627   3.003
# C(Primary_activity)[T.Aerospace]                                           -2.628    1.238 -2.123 0.034 -5.053  -0.202
# C(Primary_activity)[T.Agricultural chemicals]                               1.155    1.237  0.933 0.351 -1.270   3.580
# C(Primary_activity)[T.Agriculture, construction & mining machinery]         2.533    0.651  3.893 0.000  1.258   3.808
# C(Primary_activity)[T.Alcoholic beverages]                                  1.425    0.595  2.394 0.017  0.259   2.592
# C(Primary_activity)[T.Animal processing]                                    3.457    0.816  4.239 0.000  1.858   5.055
# C(Primary_activity)[T.Apparel & footwear design]                            2.372    0.807  2.938 0.003  0.790   3.955
# C(Primary_activity)[T.Apparel stores]                                       2.680    0.591  4.535 0.000  1.522   3.838
# C(Primary_activity)[T.Aquaculture]                                         -0.066    1.296 -0.051 0.959 -2.607   2.474
# C(Primary_activity)[T.Asset managers]                                       0.071    0.580  0.122 0.903 -1.066   1.207
# C(Primary_activity)[T.Automobiles]                                          1.996    0.653  3.057 0.002  0.716   3.276
# C(Primary_activity)[T.Baked goods & cereals]                                2.170    1.220  1.780 0.075 -0.220   4.561
# C(Primary_activity)[T.Banks]                                                0.956    0.469  2.039 0.041  0.037   1.875
# C(Primary_activity)[T.Batteries]                                            1.665    0.931  1.789 0.074 -0.159   3.490
# C(Primary_activity)[T.Biotechnology]                                        1.792    0.623  2.874 0.004  0.570   3.014
# C(Primary_activity)[T.Building sub-contractors]                             1.400    0.803  1.743 0.081 -0.174   2.974
# C(Primary_activity)[T.CCGT generation]                                     -0.069    0.590 -0.118 0.906 -1.227   1.088
# C(Primary_activity)[T.Cattle farming]                                       1.918    1.257  1.526 0.127 -0.546   4.383
# C(Primary_activity)[T.Cement]                                               2.432    0.888  2.740 0.006  0.692   4.171
# C(Primary_activity)[T.Clothing manufacture]                                 1.534    0.702  2.186 0.029  0.159   2.910
# C(Primary_activity)[T.Coal generation]                                     -1.629    1.271 -1.282 0.200 -4.121   0.862
# C(Primary_activity)[T.Commercial services]                                  3.314    0.745  4.449 0.000  1.854   4.774
# C(Primary_activity)[T.Communications equipment]                             1.976    0.578  3.418 0.001  0.843   3.110
# C(Primary_activity)[T.Computer hardware]                                    2.622    0.661  3.969 0.000  1.327   3.917
# C(Primary_activity)[T.Concrete products]                                    0.290    1.327  0.218 0.827 -2.312   2.892
# C(Primary_activity)[T.Consumer services]                                    1.449    1.242  1.167 0.243 -0.985   3.883
# C(Primary_activity)[T.Dairy & egg products]                                 2.048    1.213  1.688 0.091 -0.330   4.425
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                  2.035    0.642  3.169 0.002  0.776   3.294
# C(Primary_activity)[T.Department stores]                                    2.444    0.791  3.092 0.002  0.895   3.994
# C(Primary_activity)[T.Discretionary delivery retail]                        1.786    0.794  2.249 0.024  0.230   3.343
# C(Primary_activity)[T.Education services]                                   0.972    1.213  0.801 0.423 -1.405   3.348
# C(Primary_activity)[T.Electrical equipment]                                 3.004    0.536  5.604 0.000  1.953   4.055
# C(Primary_activity)[T.Electricity networks]                                -0.419    0.570 -0.735 0.462 -1.536   0.698
# C(Primary_activity)[T.Electronic components]                                2.157    0.501  4.303 0.000  1.175   3.140
# C(Primary_activity)[T.Electronic equipment]                                 2.842    0.542  5.239 0.000  1.779   3.905
# C(Primary_activity)[T.Energy infrastructure construction]                   0.394    0.959  0.411 0.681 -1.484   2.273
# C(Primary_activity)[T.Energy services & equipment]                          3.094    0.839  3.689 0.000  1.450   4.738
# C(Primary_activity)[T.Engineering services]                                 2.598    0.731  3.552 0.000  1.165   4.031
# C(Primary_activity)[T.Engines & motors]                                     2.854    0.664  4.296 0.000  1.552   4.156
# C(Primary_activity)[T.Fabricated metal components]                          3.103    0.614  5.055 0.000  1.900   4.306
# C(Primary_activity)[T.Fast food]                                            2.054    0.893  2.301 0.021  0.305   3.804
# C(Primary_activity)[T.Finished wood products]                               0.045    1.316  0.034 0.973 -2.534   2.623
# C(Primary_activity)[T.Fishing]                                              2.244    1.270  1.767 0.077 -0.245   4.732
# C(Primary_activity)[T.Food & beverage amenities]                            4.988    0.924  5.397 0.000  3.176   6.799
# C(Primary_activity)[T.Food & beverage wholesale]                            2.532    0.927  2.732 0.006  0.716   4.349
# C(Primary_activity)[T.Furniture]                                            2.996    0.728  4.114 0.000  1.569   4.423
# C(Primary_activity)[T.Gambling]                                             0.915    0.737  1.241 0.215 -0.530   2.360
# C(Primary_activity)[T.Gas utilities]                                        1.022    0.810  1.262 0.207 -0.565   2.609
# C(Primary_activity)[T.Glass products]                                       1.993    0.810  2.460 0.014  0.405   3.581
# C(Primary_activity)[T.Grain & corn milling]                                 1.241    1.215  1.021 0.307 -1.141   3.623
# C(Primary_activity)[T.Health care facilities]                               1.875    0.923  2.032 0.042  0.066   3.684
# C(Primary_activity)[T.Health care services]                                 2.027    0.641  3.162 0.002  0.770   3.284
# C(Primary_activity)[T.Health care supplies]                                 1.925    0.675  2.851 0.004  0.601   3.248
# C(Primary_activity)[T.Homeware]                                             2.367    1.235  1.916 0.055 -0.055   4.788
# C(Primary_activity)[T.Hotels & lodging]                                     2.850    0.616  4.624 0.000  1.642   4.058
# C(Primary_activity)[T.Hydro generation]                                    -1.406    1.409 -0.998 0.318 -4.167   1.355
# C(Primary_activity)[T.Industrial machinery]                                 2.138    0.575  3.718 0.000  1.011   3.265
# C(Primary_activity)[T.Inorganic base chemicals]                             1.196    0.805  1.486 0.137 -0.382   2.774
# C(Primary_activity)[T.Insurance]                                            0.507    0.490  1.034 0.301 -0.454   1.468
# C(Primary_activity)[T.Intermodal transport]                                 1.232    1.212  1.017 0.309 -1.142   3.607
# C(Primary_activity)[T.Iron & steel]                                         1.077    0.826  1.304 0.192 -0.542   2.696
# C(Primary_activity)[T.Logging]                                              1.953    1.211  1.612 0.107 -0.421   4.326
# C(Primary_activity)[T.Logistics - 3rd party]                                3.597    0.720  4.996 0.000  2.186   5.008
# C(Primary_activity)[T.Logistics - transport]                                2.249    1.226  1.835 0.067 -0.154   4.651
# C(Primary_activity)[T.Marine freight]                                      -1.078    0.737 -1.463 0.143 -2.522   0.366
# C(Primary_activity)[T.Marketing]                                            1.943    0.604  3.219 0.001  0.760   3.127
# C(Primary_activity)[T.Medical equipment]                                    2.334    0.560  4.169 0.000  1.237   3.431
# C(Primary_activity)[T.Metal containers & packaging]                         1.956    0.726  2.695 0.007  0.533   3.378
# C(Primary_activity)[T.Metal processing]                                     1.387    0.924  1.501 0.133 -0.424   3.199
# C(Primary_activity)[T.Nitrogenous fertilizers]                              1.457    0.949  1.535 0.125 -0.403   3.316
# C(Primary_activity)[T.Non-CCGT generation]                                 -0.863    0.929 -0.929 0.353 -2.683   0.957
# C(Primary_activity)[T.Non-alcoholic beverages]                              1.966    0.720  2.730 0.006  0.554   3.377
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                          1.660    1.239  1.339 0.181 -0.770   4.089
# C(Primary_activity)[T.Non-residential building construction]                1.048    0.590  1.775 0.076 -0.109   2.205
# C(Primary_activity)[T.Oil & gas extraction]                                -0.185    0.933 -0.199 0.843 -2.013   1.643
# C(Primary_activity)[T.Oil & gas marketing & retailing]                      2.027    0.968  2.094 0.036  0.130   3.924
# C(Primary_activity)[T.Oil & gas pipelines & storage]                        0.161    0.815  0.197 0.844 -1.437   1.758
# C(Primary_activity)[T.Other base chemicals]                                 1.532    0.535  2.865 0.004  0.484   2.580
# C(Primary_activity)[T.Other containers & packaging]                         0.782    0.916  0.854 0.393 -1.013   2.576
# C(Primary_activity)[T.Other food processing]                                2.341    0.579  4.041 0.000  1.206   3.477
# C(Primary_activity)[T.Other non-ferrous ore mining]                         0.909    0.797  1.142 0.254 -0.652   2.471
# C(Primary_activity)[T.Other non-metallic minerals]                          0.270    1.236  0.218 0.827 -2.153   2.692
# C(Primary_activity)[T.Other non-wood building materials]                    2.710    1.022  2.652 0.008  0.707   4.712
# C(Primary_activity)[T.Other professional services]                          2.337    0.512  4.565 0.000  1.333   3.340
# C(Primary_activity)[T.Other renewable energy equipment]                     2.629    1.411  1.863 0.062 -0.137   5.395
# C(Primary_activity)[T.Other renewable generation]                           2.609    1.421  1.836 0.066 -0.176   5.395
# C(Primary_activity)[T.Paper products]                                       1.701    0.615  2.765 0.006  0.495   2.908
# C(Primary_activity)[T.Passenger airlines]                                   1.395    0.598  2.332 0.020  0.222   2.567
# C(Primary_activity)[T.Passenger rail]                                       1.158    1.210  0.957 0.338 -1.213   3.529
# C(Primary_activity)[T.Personal care & household products]                   2.120    0.564  3.759 0.000  1.015   3.225
# C(Primary_activity)[T.Pharmaceuticals]                                      1.798    0.505  3.561 0.000  0.808   2.788
# C(Primary_activity)[T.Plastic products]                                     1.984    0.658  3.016 0.003  0.695   3.274
# C(Primary_activity)[T.Precious metals & minerals mining]                    1.854    0.765  2.423 0.015  0.354   3.354
# C(Primary_activity)[T.Print publishing]                                     1.436    0.831  1.728 0.084 -0.192   3.064
# C(Primary_activity)[T.Printing services]                                    2.859    0.916  3.120 0.002  1.063   4.655
# C(Primary_activity)[T.Pulp & paper mills]                                   1.870    0.872  2.145 0.032  0.162   3.579
# C(Primary_activity)[T.REIT]                                                -1.353    0.510 -2.653 0.008 -2.353  -0.354
# C(Primary_activity)[T.Rail freight]                                         1.056    0.730  1.447 0.148 -0.374   2.486
# C(Primary_activity)[T.Railroad rolling stock]                               2.337    1.226  1.906 0.057 -0.067   4.740
# C(Primary_activity)[T.Real estate owners & developers]                     -0.704    0.803 -0.876 0.381 -2.278   0.871
# C(Primary_activity)[T.Real estate services]                                 1.418    0.731  1.940 0.052 -0.015   2.851
# C(Primary_activity)[T.Residential building construction]                    1.856    0.593  3.130 0.002  0.694   3.018
# C(Primary_activity)[T.Rubber products]                                      0.397    0.696  0.570 0.569 -0.967   1.760
# C(Primary_activity)[T.Semiconductors]                                       2.980    0.769  3.876 0.000  1.473   4.488
# C(Primary_activity)[T.Servers & data centers]                               2.417    0.911  2.652 0.008  0.631   4.202
# C(Primary_activity)[T.Software]                                             1.281    0.575  2.227 0.026  0.153   2.408
# C(Primary_activity)[T.Solar energy equipment]                               1.433    1.214  1.181 0.238 -0.946   3.812
# C(Primary_activity)[T.Specialist retail]                                    1.392    0.687  2.028 0.043  0.047   2.738
# C(Primary_activity)[T.Specialty chemicals]                                  1.833    0.532  3.443 0.001  0.789   2.876
# C(Primary_activity)[T.Supermarkets, food & drugstores]                      2.858    0.532  5.375 0.000  1.816   3.900
# C(Primary_activity)[T.Telecommunications services]                          1.923    0.504  3.812 0.000  0.934   2.911
# C(Primary_activity)[T.Textiles]                                             2.190    1.264  1.732 0.083 -0.288   4.668
# C(Primary_activity)[T.Tobacco products]                                     2.067    0.718  2.876 0.004  0.658   3.475
# C(Primary_activity)[T.Transportation infrastructure & other construction]   1.282    0.618  2.074 0.038  0.070   2.493
# C(Primary_activity)[T.Transportation support services]                      1.021    1.226  0.833 0.405 -1.382   3.425
# C(Primary_activity)[T.Travel services]                                      0.621    0.931  0.667 0.505 -1.204   2.447
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]                0.483    0.729  0.662 0.508 -0.947   1.913
# C(Primary_activity)[T.Waste management]                                     1.835    0.919  1.997 0.046  0.034   3.635
# C(Primary_activity)[T.Water supply networks]                                1.234    0.813  1.517 0.129 -0.360   2.828
# C(Primary_activity)[T.Wind generation]                                     -0.721    1.275 -0.565 0.572 -3.221   1.779
# C(Primary_activity)[T.Wood furniture]                                       1.550    1.245  1.245 0.213 -0.890   3.990
# slog_Market_Cap_USD                                                         0.095    0.033  2.874 0.004  0.030   0.159
# slog_Revenue_USD                                                            0.016    0.011  1.491 0.136 -0.005   0.038
# slog_ebitda_USD                                                            -0.007    0.003 -2.643 0.008 -0.012  -0.002
# slog_shortTermInvestments_USD                                               0.000    0.002  0.069 0.945 -0.004   0.004
# slog_longTermInvestments_USD                                               -0.003    0.002 -1.146 0.252 -0.008   0.002
# slog_totalAssets_USD                                                        0.044    0.034  1.274 0.203 -0.023   0.111
# slog_totalLiabilities_USD                                                   0.289    0.039  7.506 0.000  0.214   0.365
# slog_totalInvestments_USD                                                  -0.001    0.004 -0.218 0.827 -0.010   0.008
# slog_totalDebt_USD                                                          0.031    0.015  2.064 0.039  0.002   0.060
# slog_totalEquity_USD                                                        0.007    0.004  1.538 0.124 -0.002   0.016
# slog_scope_1_2_emissions_amount                                             0.194    0.021  9.051 0.000  0.152   0.236
# Year                                                                       -0.068    0.010 -6.917 0.000 -0.087  -0.048
# Group Var                                                                   1.152    0.114
# ======================================================================================================================
#
#
# Full Mixed-Effects Model (Full Model) Test Set Performance Metrics:
# R²(log):    59.77%
# R²(orig):   51.89%
# MAPE:       213.81%
# MAPE(log):  11.48%
# MAE(log):   0.88
# RMSLE:      1.19
# RMSE:       69866.20
# MAE:        23041.37
#
# Top Influential Features (by p-value):
#                                                         coef        pvalue
# Group Var                                           2.283366  2.684640e-46
# slog_scope_1_2_emissions_amount                     0.194352  1.418877e-19
# slog_totalLiabilities_USD                           0.289117  6.113981e-14
# Year                                               -0.067588  4.600830e-12
# C(Primary_activity)[T.Electrical equipment]         3.003938  2.098850e-08
# C(Primary_activity)[T.Food & beverage amenities]    4.987640  6.780100e-08
# C(Primary_activity)[T.Supermarkets, food & drug...  2.858112  7.669563e-08
# C(Primary_activity)[T.Electronic equipment]         2.841809  1.613514e-07
# C(Countries)[T.China]                              -2.545889  4.254877e-07
# C(Primary_activity)[T.Fabricated metal components]  3.102589  4.302880e-07

# %% [markdown]
# ## Employee Commuting Optimized Mixed-Effects Model
#
# An optimized mixed-effects model is used to predict company Scope 3 emissions. The model provides accurate prediction using only the most significant predictive features, while still accounting for primary activity, country and company level effects. The model is trained on data from 2018–2022 and evaluated on test data from 2023.
#
# Model Structure:
#
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:
#     - Signed log-transformed features:
#         - Market Cap ('slog_Market_Cap_USD')
#         - Revenue ('slog_Revenue_USD')
#         - Total Assets ('slog_totalAssets_USD')
#         - Total Liabilities ('slog_totalLiabilities_USD')
#         - Total Debt ('slog_totalDebt_USD')
#         - Scope 1 & 2 Emissions ('slog_scope_1_2_emissions_amount')
#     - Country ('Countries', as a categorical variable)
#     - Primary Activity ('Primary_activity', as a categorical variable)

# %%
feature_cols_slog = [
    'slog_Market_Cap_USD',
    'slog_Revenue_USD',
    'slog_totalAssets_USD',
    'slog_totalLiabilities_USD',
    'slog_totalDebt_USD',
    'slog_scope_1_2_emissions_amount'
]
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
all_model_vars = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_opt = train_df.dropna(subset=all_model_vars).copy()
test_df_opt = test_df.dropna(subset=all_model_vars).copy()

if test_df_opt.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity)'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the optimized mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_opt, groups=train_df_opt['account_id'])
        mdf_optimized = md.fit(reml=False)
    print(mdf_optimized.summary())

    # --- Predict on test set ---
    test_df_opt['predicted_log'] = mdf_optimized.predict(test_df_opt)
    test_df_opt['predicted'] = np.sign(test_df_opt['predicted_log']) * (np.expm1(np.abs(test_df_opt['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_opt[target_col_slog]
    y_pred_log = test_df_opt['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_opt['predicted']

    # Mask for valid/finites
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <-- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nOptimized Mixed-Effects Model: Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf_optimized.params,
        'pvalue': mdf_optimized.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Optimized Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Optimized Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Optimized Model Predicted")
    plt.xscale("log")
    plt.title("Optimized Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    optimized_model_metrics = {
        "Model": "Optimized",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                        Mixed Linear Model Regression Results
# ====================================================================================================================
# Model:                           MixedLM              Dependent Variable:              slog_Scope_3_emissions_amount
# No. Observations:                3092                 Method:                          ML
# No. Groups:                      741                  Scale:                           0.5159
# Min. group size:                 1                    Log-Likelihood:                  -4208.9716
# Max. group size:                 5                    Converged:                       Yes
# Mean group size:                 4.2
# --------------------------------------------------------------------------------------------------------------------
#                                                                           Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 -3.884    1.049 -3.702 0.000 -5.941 -1.828
# C(Countries)[T.Austria]                                                   -0.763    0.854 -0.893 0.372 -2.437  0.911
# C(Countries)[T.Belgium]                                                   -0.696    0.594 -1.171 0.241 -1.861  0.469
# C(Countries)[T.Bermuda]                                                   -0.104    1.260 -0.083 0.934 -2.573  2.364
# C(Countries)[T.Brazil]                                                    -0.916    0.496 -1.848 0.065 -1.887  0.056
# C(Countries)[T.Canada]                                                    -0.603    0.466 -1.293 0.196 -1.517  0.311
# C(Countries)[T.Chile]                                                     -1.572    1.403 -1.120 0.263 -4.322  1.178
# C(Countries)[T.China]                                                     -2.477    0.506 -4.899 0.000 -3.468 -1.486
# C(Countries)[T.Denmark]                                                   -0.117    0.771 -0.152 0.879 -1.628  1.394
# C(Countries)[T.Finland]                                                   -1.031    0.520 -1.982 0.047 -2.050 -0.011
# C(Countries)[T.France]                                                     0.316    0.426  0.742 0.458 -0.519  1.151
# C(Countries)[T.Germany]                                                    0.058    0.434  0.135 0.893 -0.792  0.909
# C(Countries)[T.Greece]                                                    -2.410    0.767 -3.143 0.002 -3.913 -0.907
# C(Countries)[T.Hungary]                                                   -2.215    1.213 -1.827 0.068 -4.591  0.162
# C(Countries)[T.India]                                                      0.485    0.911  0.533 0.594 -1.300  2.270
# C(Countries)[T.Ireland]                                                   -0.363    0.598 -0.606 0.544 -1.535  0.810
# C(Countries)[T.Israel]                                                    -2.463    1.665 -1.479 0.139 -5.726  0.800
# C(Countries)[T.Italy]                                                     -0.671    0.512 -1.311 0.190 -1.673  0.332
# C(Countries)[T.Japan]                                                     -1.173    0.375 -3.126 0.002 -1.909 -0.438
# C(Countries)[T.Luxembourg]                                                -0.258    1.514 -0.171 0.864 -3.226  2.709
# C(Countries)[T.Mexico]                                                    -4.522    1.014 -4.460 0.000 -6.509 -2.535
# C(Countries)[T.Netherlands]                                               -0.595    0.487 -1.222 0.222 -1.550  0.360
# C(Countries)[T.New Zealand]                                               -1.631    0.713 -2.289 0.022 -3.028 -0.235
# C(Countries)[T.Norway]                                                    -1.013    0.532 -1.906 0.057 -2.055  0.029
# C(Countries)[T.Peru]                                                       0.081    1.190  0.068 0.946 -2.251  2.412
# C(Countries)[T.Portugal]                                                  -3.232    0.826 -3.911 0.000 -4.852 -1.612
# C(Countries)[T.Singapore]                                                 -1.386    0.949 -1.461 0.144 -3.245  0.473
# C(Countries)[T.South Africa]                                               0.041    0.440  0.094 0.925 -0.821  0.903
# C(Countries)[T.South Korea]                                               -1.493    0.462 -3.227 0.001 -2.399 -0.586
# C(Countries)[T.Spain]                                                     -0.744    0.436 -1.707 0.088 -1.598  0.110
# C(Countries)[T.Sweden]                                                    -1.080    0.604 -1.788 0.074 -2.264  0.104
# C(Countries)[T.Switzerland]                                               -0.276    0.462 -0.598 0.550 -1.181  0.629
# C(Countries)[T.Thailand]                                                  -0.567    0.772 -0.734 0.463 -2.080  0.947
# C(Countries)[T.Turkey]                                                    -4.221    1.388 -3.041 0.002 -6.942 -1.500
# C(Countries)[T.USA]                                                        0.002    0.372  0.004 0.997 -0.728  0.731
# C(Countries)[T.United Kingdom]                                            -0.480    0.390 -1.233 0.218 -1.244  0.284
# C(Primary_activity)[T.Accessories manufacture]                             1.069    0.932  1.148 0.251 -0.756  2.895
# C(Primary_activity)[T.Aerospace]                                          -2.828    1.245 -2.272 0.023 -5.267 -0.388
# C(Primary_activity)[T.Agricultural chemicals]                              0.965    1.244  0.776 0.438 -1.474  3.404
# C(Primary_activity)[T.Agriculture, construction & mining machinery]        2.453    0.654  3.751 0.000  1.171  3.734
# C(Primary_activity)[T.Alcoholic beverages]                                 1.329    0.598  2.221 0.026  0.156  2.502
# C(Primary_activity)[T.Animal processing]                                   3.271    0.820  3.989 0.000  1.664  4.878
# C(Primary_activity)[T.Apparel & footwear design]                           2.218    0.812  2.731 0.006  0.626  3.810
# C(Primary_activity)[T.Apparel stores]                                      2.561    0.594  4.312 0.000  1.397  3.725
# C(Primary_activity)[T.Aquaculture]                                        -0.147    1.304 -0.113 0.910 -2.703  2.409
# C(Primary_activity)[T.Asset managers]                                     -0.039    0.583 -0.067 0.947 -1.182  1.104
# C(Primary_activity)[T.Automobiles]                                         1.915    0.657  2.916 0.004  0.628  3.202
# C(Primary_activity)[T.Baked goods & cereals]                               2.038    1.227  1.661 0.097 -0.366  4.442
# C(Primary_activity)[T.Banks]                                               0.978    0.471  2.075 0.038  0.054  1.901
# C(Primary_activity)[T.Batteries]                                           1.464    0.935  1.566 0.117 -0.368  3.297
# C(Primary_activity)[T.Biotechnology]                                       1.679    0.627  2.679 0.007  0.450  2.907
# C(Primary_activity)[T.Building sub-contractors]                            1.258    0.807  1.559 0.119 -0.324  2.841
# C(Primary_activity)[T.CCGT generation]                                    -0.181    0.593 -0.305 0.761 -1.343  0.982
# C(Primary_activity)[T.Cattle farming]                                      1.982    1.264  1.568 0.117 -0.495  4.458
# C(Primary_activity)[T.Cement]                                              2.339    0.893  2.620 0.009  0.589  4.088
# C(Primary_activity)[T.Clothing manufacture]                                1.410    0.706  1.998 0.046  0.027  2.793
# C(Primary_activity)[T.Coal generation]                                    -1.785    1.278 -1.397 0.162 -4.290  0.720
# C(Primary_activity)[T.Commercial services]                                 3.206    0.743  4.313 0.000  1.749  4.662
# C(Primary_activity)[T.Communications equipment]                            1.863    0.581  3.205 0.001  0.724  3.002
# C(Primary_activity)[T.Computer hardware]                                   2.433    0.663  3.668 0.000  1.133  3.732
# C(Primary_activity)[T.Concrete products]                                   0.079    1.335  0.059 0.953 -2.537  2.696
# C(Primary_activity)[T.Consumer services]                                   1.174    1.248  0.941 0.347 -1.272  3.620
# C(Primary_activity)[T.Dairy & egg products]                                1.913    1.219  1.570 0.117 -0.476  4.302
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                 1.893    0.643  2.943 0.003  0.632  3.153
# C(Primary_activity)[T.Department stores]                                   2.358    0.794  2.969 0.003  0.801  3.915
# C(Primary_activity)[T.Discretionary delivery retail]                       1.671    0.799  2.092 0.036  0.105  3.237
# C(Primary_activity)[T.Education services]                                  0.848    1.219  0.695 0.487 -1.542  3.237
# C(Primary_activity)[T.Electrical equipment]                                2.899    0.539  5.381 0.000  1.843  3.956
# C(Primary_activity)[T.Electricity networks]                               -0.525    0.573 -0.917 0.359 -1.649  0.598
# C(Primary_activity)[T.Electronic components]                               2.033    0.504  4.034 0.000  1.045  3.021
# C(Primary_activity)[T.Electronic equipment]                                2.706    0.545  4.962 0.000  1.637  3.775
# C(Primary_activity)[T.Energy infrastructure construction]                  0.354    0.963  0.368 0.713 -1.533  2.241
# C(Primary_activity)[T.Energy services & equipment]                         2.982    0.843  3.537 0.000  1.329  4.634
# C(Primary_activity)[T.Engineering services]                                2.413    0.735  3.282 0.001  0.972  3.855
# C(Primary_activity)[T.Engines & motors]                                    2.683    0.668  4.017 0.000  1.374  3.993
# C(Primary_activity)[T.Fabricated metal components]                         2.965    0.617  4.806 0.000  1.756  4.174
# C(Primary_activity)[T.Fast food]                                           1.597    0.877  1.821 0.069 -0.122  3.316
# C(Primary_activity)[T.Finished wood products]                             -0.098    1.324 -0.074 0.941 -2.692  2.496
# C(Primary_activity)[T.Fishing]                                             1.973    1.276  1.546 0.122 -0.528  4.474
# C(Primary_activity)[T.Food & beverage amenities]                           4.760    0.925  5.143 0.000  2.946  6.573
# C(Primary_activity)[T.Food & beverage wholesale]                           2.438    0.932  2.616 0.009  0.611  4.264
# C(Primary_activity)[T.Furniture]                                           2.809    0.732  3.837 0.000  1.374  4.244
# C(Primary_activity)[T.Gambling]                                            0.896    0.741  1.208 0.227 -0.557  2.349
# C(Primary_activity)[T.Gas utilities]                                       0.906    0.814  1.113 0.266 -0.689  2.502
# C(Primary_activity)[T.Glass products]                                      1.814    0.815  2.227 0.026  0.217  3.411
# C(Primary_activity)[T.Grain & corn milling]                                1.091    1.222  0.893 0.372 -1.305  3.487
# C(Primary_activity)[T.Health care facilities]                              1.800    0.928  1.939 0.053 -0.020  3.619
# C(Primary_activity)[T.Health care services]                                1.951    0.645  3.027 0.002  0.688  3.215
# C(Primary_activity)[T.Health care supplies]                                1.857    0.679  2.734 0.006  0.526  3.188
# C(Primary_activity)[T.Homeware]                                            2.181    1.242  1.756 0.079 -0.254  4.615
# C(Primary_activity)[T.Hotels & lodging]                                    2.614    0.617  4.239 0.000  1.405  3.822
# C(Primary_activity)[T.Hydro generation]                                   -1.549    1.417 -1.093 0.274 -4.327  1.229
# C(Primary_activity)[T.Industrial machinery]                                1.970    0.578  3.411 0.001  0.838  3.103
# C(Primary_activity)[T.Inorganic base chemicals]                            1.071    0.810  1.324 0.186 -0.515  2.658
# C(Primary_activity)[T.Insurance]                                           0.521    0.492  1.058 0.290 -0.444  1.486
# C(Primary_activity)[T.Intermodal transport]                                1.112    1.218  0.913 0.361 -1.275  3.498
# C(Primary_activity)[T.Iron & steel]                                        1.002    0.831  1.206 0.228 -0.626  2.630
# C(Primary_activity)[T.Logging]                                             1.840    1.218  1.511 0.131 -0.546  4.227
# C(Primary_activity)[T.Logistics - 3rd party]                               3.555    0.724  4.908 0.000  2.135  4.974
# C(Primary_activity)[T.Logistics - transport]                               2.170    1.233  1.761 0.078 -0.246  4.587
# C(Primary_activity)[T.Marine freight]                                     -1.185    0.741 -1.600 0.110 -2.638  0.267
# C(Primary_activity)[T.Marketing]                                           1.794    0.607  2.955 0.003  0.604  2.983
# C(Primary_activity)[T.Medical equipment]                                   2.184    0.562  3.882 0.000  1.081  3.286
# C(Primary_activity)[T.Metal containers & packaging]                        1.852    0.729  2.542 0.011  0.424  3.280
# C(Primary_activity)[T.Metal processing]                                    1.244    0.929  1.339 0.181 -0.577  3.066
# C(Primary_activity)[T.Nitrogenous fertilizers]                             1.354    0.954  1.419 0.156 -0.515  3.223
# C(Primary_activity)[T.Non-CCGT generation]                                -1.007    0.933 -1.079 0.281 -2.836  0.823
# C(Primary_activity)[T.Non-alcoholic beverages]                             1.858    0.724  2.567 0.010  0.439  3.277
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                         1.524    1.247  1.223 0.222 -0.919  3.967
# C(Primary_activity)[T.Non-residential building construction]               0.953    0.593  1.606 0.108 -0.210  2.116
# C(Primary_activity)[T.Oil & gas extraction]                               -0.308    0.938 -0.329 0.742 -2.147  1.530
# C(Primary_activity)[T.Oil & gas marketing & retailing]                     1.899    0.973  1.951 0.051 -0.008  3.806
# C(Primary_activity)[T.Oil & gas pipelines & storage]                       0.047    0.820  0.057 0.955 -1.560  1.653
# C(Primary_activity)[T.Other base chemicals]                                1.413    0.537  2.630 0.009  0.360  2.467
# C(Primary_activity)[T.Other containers & packaging]                        0.726    0.919  0.790 0.430 -1.075  2.526
# C(Primary_activity)[T.Other food processing]                               2.229    0.582  3.828 0.000  1.088  3.371
# C(Primary_activity)[T.Other non-ferrous ore mining]                        0.785    0.801  0.980 0.327 -0.785  2.355
# C(Primary_activity)[T.Other non-metallic minerals]                         0.117    1.241  0.095 0.925 -2.316  2.550
# C(Primary_activity)[T.Other non-wood building materials]                   2.414    1.027  2.350 0.019  0.401  4.427
# C(Primary_activity)[T.Other professional services]                         2.236    0.515  4.346 0.000  1.228  3.245
# C(Primary_activity)[T.Other renewable energy equipment]                    2.601    1.418  1.834 0.067 -0.179  5.381
# C(Primary_activity)[T.Other renewable generation]                          2.663    1.429  1.863 0.062 -0.139  5.465
# C(Primary_activity)[T.Paper products]                                      1.603    0.618  2.593 0.010  0.391  2.814
# C(Primary_activity)[T.Passenger airlines]                                  1.406    0.600  2.345 0.019  0.231  2.582
# C(Primary_activity)[T.Passenger rail]                                      1.156    1.216  0.950 0.342 -1.228  3.540
# C(Primary_activity)[T.Personal care & household products]                  2.009    0.567  3.545 0.000  0.898  3.120
# C(Primary_activity)[T.Pharmaceuticals]                                     1.724    0.508  3.396 0.001  0.729  2.719
# C(Primary_activity)[T.Plastic products]                                    1.831    0.661  2.769 0.006  0.535  3.127
# C(Primary_activity)[T.Precious metals & minerals mining]                   1.697    0.769  2.206 0.027  0.189  3.205
# C(Primary_activity)[T.Print publishing]                                    1.252    0.835  1.499 0.134 -0.385  2.889
# C(Primary_activity)[T.Printing services]                                   2.753    0.921  2.988 0.003  0.947  4.559
# C(Primary_activity)[T.Pulp & paper mills]                                  1.728    0.876  1.973 0.048  0.012  3.445
# C(Primary_activity)[T.REIT]                                               -1.466    0.513 -2.859 0.004 -2.471 -0.461
# C(Primary_activity)[T.Rail freight]                                        0.959    0.734  1.307 0.191 -0.479  2.397
# C(Primary_activity)[T.Railroad rolling stock]                              2.237    1.233  1.814 0.070 -0.180  4.655
# C(Primary_activity)[T.Real estate owners & developers]                    -0.805    0.808 -0.997 0.319 -2.388  0.778
# C(Primary_activity)[T.Real estate services]                                1.301    0.735  1.769 0.077 -0.140  2.742
# C(Primary_activity)[T.Residential building construction]                   1.716    0.596  2.879 0.004  0.548  2.884
# C(Primary_activity)[T.Rubber products]                                     0.260    0.700  0.371 0.710 -1.111  1.631
# C(Primary_activity)[T.Semiconductors]                                      2.851    0.773  3.688 0.000  1.336  4.366
# C(Primary_activity)[T.Servers & data centers]                              2.345    0.916  2.558 0.011  0.548  4.141
# C(Primary_activity)[T.Software]                                            1.203    0.578  2.082 0.037  0.070  2.336
# C(Primary_activity)[T.Solar energy equipment]                              1.249    1.221  1.023 0.306 -1.144  3.641
# C(Primary_activity)[T.Specialist retail]                                   1.238    0.690  1.794 0.073 -0.115  2.592
# C(Primary_activity)[T.Specialty chemicals]                                 1.695    0.535  3.169 0.002  0.647  2.743
# C(Primary_activity)[T.Supermarkets, food & drugstores]                     2.772    0.535  5.184 0.000  1.724  3.820
# C(Primary_activity)[T.Telecommunications services]                         1.894    0.507  3.735 0.000  0.900  2.887
# C(Primary_activity)[T.Textiles]                                            1.955    1.271  1.538 0.124 -0.537  4.447
# C(Primary_activity)[T.Tobacco products]                                    1.903    0.719  2.647 0.008  0.494  3.312
# C(Primary_activity)[T.Transportation infrastructure & other construction]  1.160    0.622  1.865 0.062 -0.059  2.378
# C(Primary_activity)[T.Transportation support services]                     0.931    1.233  0.755 0.450 -1.485  3.346
# C(Primary_activity)[T.Travel services]                                     0.454    0.937  0.485 0.628 -1.382  2.290
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]               0.406    0.733  0.554 0.580 -1.030  1.842
# C(Primary_activity)[T.Waste management]                                    1.726    0.924  1.868 0.062 -0.085  3.536
# C(Primary_activity)[T.Water supply networks]                               1.091    0.818  1.334 0.182 -0.512  2.694
# C(Primary_activity)[T.Wind generation]                                    -0.822    1.283 -0.641 0.522 -3.335  1.692
# C(Primary_activity)[T.Wood furniture]                                      1.268    1.251  1.013 0.311 -1.185  3.721
# slog_Market_Cap_USD                                                        0.083    0.033  2.526 0.012  0.019  0.148
# slog_Revenue_USD                                                           0.011    0.011  1.002 0.316 -0.010  0.032
# slog_totalAssets_USD                                                       0.041    0.034  1.180 0.238 -0.027  0.108
# slog_totalLiabilities_USD                                                  0.259    0.039  6.681 0.000  0.183  0.334
# slog_totalDebt_USD                                                         0.025    0.015  1.678 0.093 -0.004  0.054
# slog_scope_1_2_emissions_amount                                            0.199    0.022  9.212 0.000  0.157  0.242
# Group Var                                                                  1.165    0.115
# ====================================================================================================================
#
#
# Optimized Mixed-Effects Model: Test Set Performance Metrics:
# R²(log):    61.89%
# R²(orig):   57.81%
# MAPE:       243.28%
# MAPE(log):  11.31%
# MAE(log):   0.84
# RMSLE:      1.15
# RMSE:       65426.33
# MAE:        22518.98
#
# Top Influential Features (by p-value):
#                                                         coef        pvalue
# Group Var                                           2.257722  4.489673e-45
# slog_scope_1_2_emissions_amount                     0.199279  3.197720e-20
# slog_totalLiabilities_USD                           0.258575  2.378720e-11
# C(Primary_activity)[T.Electrical equipment]         2.899440  7.420268e-08
# C(Primary_activity)[T.Supermarkets, food & drug...  2.772168  2.168156e-07
# C(Primary_activity)[T.Food & beverage amenities]    4.759752  2.696973e-07
# C(Primary_activity)[T.Electronic equipment]         2.706137  6.960533e-07
# C(Primary_activity)[T.Logistics - 3rd party]        3.554799  9.193018e-07
# C(Countries)[T.China]                              -2.477052  9.637286e-07
# C(Primary_activity)[T.Fabricated metal components]  2.965210  1.539708e-06
#
# All feature coefficients sorted by absolute value:
#                                                       coef        pvalue
# C(Primary_activity)[T.Food & beverage amenities]  4.759752  2.696973e-07
# C(Countries)[T.Mexico]                           -4.521709  8.203229e-06
# C(Countries)[T.Turkey]                           -4.221067  2.361696e-03
# C(Primary_activity)[T.Logistics - 3rd party]      3.554799  9.193018e-07
# C(Primary_activity)[T.Animal processing]          3.270745  6.627533e-05
# ...                                                    ...           ...
# slog_totalAssets_USD                              0.040615  2.381220e-01
# C(Primary_activity)[T.Asset managers]            -0.038847  9.468783e-01
# slog_totalDebt_USD                                0.024987  9.341843e-02
# slog_Revenue_USD                                  0.010984  3.161727e-01
# C(Countries)[T.USA]                               0.001583  9.966047e-01
#
# [163 rows x 2 columns]

# %%
metrics_text_log = (
    f"R²(log):   {r2_log_pct:.2f}%\n"
    f"R²(orig):  {r2_pct:.2f}%\n"
    f"MAPE:      {mape_orig:.2f}%\n"
    f"MAPE(log): {mape_log:.2f}%\n"
    f"MAE(log):  {mae_log:.2f}\n"
    f"RMSLE:     {rmsle:.2f}\n"
    f"RMSE:      {rmse_orig:.2f}\n"
    f"MAE:       {mae_orig:.2f}"
)

fig, ax = plt.subplots(figsize=(9.5, 6))  # Wider to make room for the box

if hasattr(y_pred_log, "nunique"):
    multiple_vals = y_pred_log.nunique() > 1
else:
    multiple_vals = len(set(y_pred_log)) > 1

if multiple_vals:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=ax, color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    ax.plot([], [], ' ', label="Predicted: constant value (no KDE)")

ax.set_title("Employee Commuting Optimized Model: signed log(Scope 3 Emissions)")
ax.set_xlabel("signed log(metric tons + 1)")
ax.set_ylabel("Density")
ax.legend()

# Place metrics box outside plot to the right
fig.text(
    0.82, 0.75, metrics_text_log,
    va='top', ha='left',
    fontsize=12, bbox=dict(boxstyle='round', alpha=0.15)
)

plt.subplots_adjust(right=0.8)  # Make sure there's room for the box
fig.savefig("employee_commuting_scope3_log_density.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Metrics Table for Employee Commuting

# %%
metrics_dicts = [
    null_model_metrics,
    two_level_model_metrics,
    three_level_model_metrics,
    full_model_metrics,
    optimized_model_metrics
]

for metrics, train, test in zip(
        metrics_dicts,
        [train_df, train_df, train_df, train_df, train_df],
        [test_df, test_df, test_df, test_df, test_df]):
    
    metrics["# Obs (train)"] = len(train)
    metrics["# Obs (test)"] = len(test)
    metrics["# Obs (train/test)"] = f"{len(train)}/{len(test)}"

metrics_df = pd.DataFrame(metrics_dicts)

# Ensure all relevant columns are ordered and present
desired_order = [
    "Model", "R2_log", "R2_orig", "RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "# Obs (train/test)"
]


# Ensure MAE_log is present, fill with NaN if missing
if "MAE_log" not in metrics_df.columns:
    metrics_df["MAE_log"] = np.nan

metrics_df = metrics_df[[col for col in desired_order if col in metrics_df.columns]]

metrics_df_display = metrics_df.copy()
if "R2_log" in metrics_df_display.columns:
    metrics_df_display["R2_log"] = (metrics_df_display["R2_log"] * 100).map("{:.2f}%".format)
if "R2_orig" in metrics_df_display.columns:
    metrics_df_display["R2_orig"] = (metrics_df_display["R2_orig"] * 100).map("{:.2f}%".format)
for col in ["RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "MAPE(log)"]:
    if col in metrics_df_display.columns:
        metrics_df_display[col] = metrics_df_display[col].map("{:.2f}".format)

from IPython.display import display
display(metrics_df_display)
# Out:
#                                      Model  R2_log  R2_orig       RMSE  \
# 0                                Null (RI)  -1.18%   -9.21%  105269.70
# 1                           2-level (RI+S)  -8.17%  -10.57%  105920.50
# 2  3-level (Primary Activity/Account/Year)  27.78%   -2.40%  101933.20
# 3                               Full Model  59.77%   51.89%   69866.20
# 4                                Optimized  61.89%   57.81%   65426.33
#
#         MAE MAE_log RMSLE     MAPE # Obs (train/test)
# 0  34697.26    1.49  1.88  2188.38           3092/653
# 1  35147.05    1.56  1.95  1575.23           3092/653
# 2  32227.21    1.24  1.59  1091.66           3092/653
# 3  23041.37    0.88  1.19   213.81           3092/653
# 4  22518.98    0.84  1.15   243.28           3092/653
