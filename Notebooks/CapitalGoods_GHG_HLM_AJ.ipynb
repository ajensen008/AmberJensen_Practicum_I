# %% [markdown]
# # GHG HLM on Scope 3 source Capital Goods

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_log_error, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GroupShuffleSplit
from scipy.stats import zscore
import scipy.stats as stats
from sklearn.feature_selection import mutual_info_regression
from sklearn.impute import SimpleImputer
import warnings
from statsmodels.regression.mixed_linear_model import MixedLM


#read in dataset from GHG_post_outliers data set
capital_goods=pd.read_csv('/Users/amberjensen/Desktop/GHG_Emissions_Project/capital_goods.csv')

# %%
#check for info
capital_goods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3165 entries, 0 to 3164
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_name                3165 non-null   object
#  1   account_id                  3165 non-null   int64
#  2   Year                        3165 non-null   int64
#  3   incorporated_country        3165 non-null   object
#  4   Primary activity            3165 non-null   object
#  5   Primary sector              3165 non-null   object
#  6   Market_Cap_USD              2821 non-null   float64
#  7   Third_party_verification    3164 non-null   object
#  8   Revenue_USD                 2839 non-null   float64
#  9   ebitda_USD                  2839 non-null   float64
#  10  grossProfit_USD             2839 non-null   float64
#  11  netIncome_USD               2839 non-null   float64
#  12  cashAndCashEquivalents_USD  2839 non-null   float64
#  13  shortTermInvestments_USD    2839 non-null   float64
#  14  longTermInvestments_USD     2839 non-null   float64
#  15  totalAssets_USD             2839 non-null   float64
#  16  totalLiabilities_USD        2839 non-null   float64
#  17  totalInvestments_USD        2839 non-null   float64
#  18  totalDebt_USD               2839 non-null   float64
#  19  totalEquity_USD             2839 non-null   float64
#  20  Scope_3_emissions_type      3165 non-null   object
#  21  Scope_3_emissions_amount    3165 non-null   float64
#  22  scope_1_2_emissions_amount  3161 non-null   float64
#  23  Year_sq                     3165 non-null   int64
# dtypes: float64(15), int64(3), object(6)
# memory usage: 593.6+ KB

# %%
#show a df for capital_goods
capital_goods.head()
# Out:
#                         account_name  account_id  Year incorporated_country  \
# 0                              Aptiv        4407  2018       United Kingdom
# 1                        AstraZeneca        1104  2018       United Kingdom
# 2               British Land Company        2297  2018       United Kingdom
# 3                           BT Group        2377  2018       United Kingdom
# 4  Capital & Counties Properties PLC       31426  2018       United Kingdom
#
#                   Primary activity  \
# 0             Electrical equipment
# 1                  Pharmaceuticals
# 2                             REIT
# 3      Telecommunications services
# 4  Real estate owners & developers
#
#                                      Primary sector  Market_Cap_USD  \
# 0                 Electrical & electronic equipment    1.595156e+10
# 1                                  Biotech & pharma    7.441091e+10
# 2                                Financial services    6.501391e+09
# 3  Media, telecommunications & data center services    2.997109e+10
# 4           Land & property ownership & development             NaN
#
#                             Third_party_verification   Revenue_USD  \
# 0           No third-party verification or assurance  1.443500e+10
# 1  Third-party verification or assurance process ...  2.209000e+10
# 2  Third-party verification or assurance process ...  1.148080e+09
# 3  Third-party verification or assurance process ...  2.975356e+10
# 4  Third-party verification or assurance process ...  1.017270e+08
#
#      ebitda_USD  ...  longTermInvestments_USD  totalAssets_USD  \
# 0  2.260000e+09  ...             9.900000e+07     1.248000e+10
# 1  7.165000e+09  ...             1.130000e+08     6.065100e+10
# 2 -3.022600e+08  ...             3.597910e+09     1.556512e+10
# 3  9.392920e+09  ...             1.282700e+08     5.878449e+10
# 4 -1.353820e+08  ...             0.000000e+00     4.653407e+09
#
#    totalLiabilities_USD  totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0          8.810000e+09          1.710000e+08   4.344000e+09     3.670000e+09
# 1          4.660700e+10          9.220000e+08   1.911300e+10     1.404400e+10
# 2          4.530090e+09          3.402330e+09   3.966210e+09     1.103503e+10
# 3          4.587240e+10          1.282700e+08   2.143252e+10     1.291209e+10
# 4          8.642350e+08          2.197100e+07   7.838440e+08     3.789172e+09
#
#    Scope_3_emissions_type  Scope_3_emissions_amount  \
# 0           Capital goods                  337000.0
# 1           Capital goods                   88314.0
# 2           Capital goods                  106395.0
# 3           Capital goods                  448000.0
# 4           Capital goods                   32356.0
#
#    scope_1_2_emissions_amount  Year_sq
# 0               380471.810000  4072324
# 1               707252.916667  4072324
# 2                14261.000000  4072324
# 3               457281.895000  4072324
# 4                 1407.000000  4072324
#
# [5 rows x 24 columns]

# %%
#define a list of numeric columns
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD',
       'grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD',
       'shortTermInvestments_USD', 'longTermInvestments_USD',
       'totalAssets_USD', 'totalLiabilities_USD', 'totalInvestments_USD',
       'totalDebt_USD', 'totalEquity_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount']

# %%
#plot the heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(capital_goods[numeric_cols].corr(), annot=True, annot_kws={"size": 8})
plt.show()

# %%
#correlation matrix
capital_goods[numeric_cols].corr()
# Out:
#                             Market_Cap_USD  Revenue_USD  ebitda_USD  \
# Market_Cap_USD                    1.000000     0.296429    0.410491
# Revenue_USD                       0.296429     1.000000    0.745473
# ebitda_USD                        0.410491     0.745473    1.000000
# grossProfit_USD                   0.335405     0.806059    0.796477
# netIncome_USD                     0.453245     0.655351    0.889489
# cashAndCashEquivalents_USD        0.075027     0.216994    0.317913
# shortTermInvestments_USD          0.154932     0.304338    0.368063
# longTermInvestments_USD           0.057990     0.230707    0.303351
# totalAssets_USD                   0.111281     0.346386    0.452461
# totalLiabilities_USD              0.085179     0.303395    0.397279
# totalInvestments_USD              0.091600     0.256227    0.338735
# totalDebt_USD                     0.133449     0.473413    0.587877
# totalEquity_USD                   0.305803     0.663040    0.813332
# Scope_3_emissions_amount          0.150445     0.357955    0.363181
# scope_1_2_emissions_amount       -0.001929     0.100887    0.049167
#
#                             grossProfit_USD  netIncome_USD  \
# Market_Cap_USD                     0.335405       0.453245
# Revenue_USD                        0.806059       0.655351
# ebitda_USD                         0.796477       0.889489
# grossProfit_USD                    1.000000       0.754018
# netIncome_USD                      0.754018       1.000000
# cashAndCashEquivalents_USD         0.373643       0.331973
# shortTermInvestments_USD           0.499870       0.393719
# longTermInvestments_USD            0.440473       0.325289
# totalAssets_USD                    0.545727       0.438341
# totalLiabilities_USD               0.502275       0.389295
# totalInvestments_USD               0.464704       0.360950
# totalDebt_USD                      0.591527       0.462843
# totalEquity_USD                    0.785228       0.753326
# Scope_3_emissions_amount           0.266646       0.284311
# scope_1_2_emissions_amount        -0.012773       0.007166
#
#                             cashAndCashEquivalents_USD  \
# Market_Cap_USD                                0.075027
# Revenue_USD                                   0.216994
# ebitda_USD                                    0.317913
# grossProfit_USD                               0.373643
# netIncome_USD                                 0.331973
# cashAndCashEquivalents_USD                    1.000000
# shortTermInvestments_USD                      0.467351
# longTermInvestments_USD                       0.796148
# totalAssets_USD                               0.875479
# totalLiabilities_USD                          0.852637
# totalInvestments_USD                          0.735177
# totalDebt_USD                                 0.720505
# totalEquity_USD                               0.622042
# Scope_3_emissions_amount                      0.008570
# scope_1_2_emissions_amount                   -0.024615
#
#                             shortTermInvestments_USD  longTermInvestments_USD  \
# Market_Cap_USD                              0.154932                 0.057990
# Revenue_USD                                 0.304338                 0.230707
# ebitda_USD                                  0.368063                 0.303351
# grossProfit_USD                             0.499870                 0.440473
# netIncome_USD                               0.393719                 0.325289
# cashAndCashEquivalents_USD                  0.467351                 0.796148
# shortTermInvestments_USD                    1.000000                 0.751969
# longTermInvestments_USD                     0.751969                 1.000000
# totalAssets_USD                             0.643494                 0.926275
# totalLiabilities_USD                        0.652294                 0.904324
# totalInvestments_USD                        0.828297                 0.961875
# totalDebt_USD                               0.498851                 0.734237
# totalEquity_USD                             0.562117                 0.649003
# Scope_3_emissions_amount                    0.031848                -0.012390
# scope_1_2_emissions_amount                 -0.026872                -0.041461
#
#                             totalAssets_USD  totalLiabilities_USD  \
# Market_Cap_USD                     0.111281              0.085179
# Revenue_USD                        0.346386              0.303395
# ebitda_USD                         0.452461              0.397279
# grossProfit_USD                    0.545727              0.502275
# netIncome_USD                      0.438341              0.389295
# cashAndCashEquivalents_USD         0.875479              0.852637
# shortTermInvestments_USD           0.643494              0.652294
# longTermInvestments_USD            0.926275              0.904324
# totalAssets_USD                    1.000000              0.970026
# totalLiabilities_USD               0.970026              1.000000
# totalInvestments_USD               0.878076              0.860914
# totalDebt_USD                      0.864526              0.844809
# totalEquity_USD                    0.773867              0.719076
# Scope_3_emissions_amount           0.050440              0.028141
# scope_1_2_emissions_amount        -0.018006             -0.020654
#
#                             totalInvestments_USD  totalDebt_USD  \
# Market_Cap_USD                          0.091600       0.133449
# Revenue_USD                             0.256227       0.473413
# ebitda_USD                              0.338735       0.587877
# grossProfit_USD                         0.464704       0.591527
# netIncome_USD                           0.360950       0.462843
# cashAndCashEquivalents_USD              0.735177       0.720505
# shortTermInvestments_USD                0.828297       0.498851
# longTermInvestments_USD                 0.961875       0.734237
# totalAssets_USD                         0.878076       0.864526
# totalLiabilities_USD                    0.860914       0.844809
# totalInvestments_USD                    1.000000       0.693579
# totalDebt_USD                           0.693579       1.000000
# totalEquity_USD                         0.646621       0.776508
# Scope_3_emissions_amount                0.002245       0.170120
# scope_1_2_emissions_amount             -0.038668       0.043527
#
#                             totalEquity_USD  Scope_3_emissions_amount  \
# Market_Cap_USD                     0.305803                  0.150445
# Revenue_USD                        0.663040                  0.357955
# ebitda_USD                         0.813332                  0.363181
# grossProfit_USD                    0.785228                  0.266646
# netIncome_USD                      0.753326                  0.284311
# cashAndCashEquivalents_USD         0.622042                  0.008570
# shortTermInvestments_USD           0.562117                  0.031848
# longTermInvestments_USD            0.649003                 -0.012390
# totalAssets_USD                    0.773867                  0.050440
# totalLiabilities_USD               0.719076                  0.028141
# totalInvestments_USD               0.646621                  0.002245
# totalDebt_USD                      0.776508                  0.170120
# totalEquity_USD                    1.000000                  0.249326
# Scope_3_emissions_amount           0.249326                  1.000000
# scope_1_2_emissions_amount         0.041079                  0.245182
#
#                             scope_1_2_emissions_amount
# Market_Cap_USD                               -0.001929
# Revenue_USD                                   0.100887
# ebitda_USD                                    0.049167
# grossProfit_USD                              -0.012773
# netIncome_USD                                 0.007166
# cashAndCashEquivalents_USD                   -0.024615
# shortTermInvestments_USD                     -0.026872
# longTermInvestments_USD                      -0.041461
# totalAssets_USD                              -0.018006
# totalLiabilities_USD                         -0.020654
# totalInvestments_USD                         -0.038668
# totalDebt_USD                                 0.043527
# totalEquity_USD                               0.041079
# Scope_3_emissions_amount                      0.245182
# scope_1_2_emissions_amount                    1.000000

# %%
#drop columns due to collinearity, keeping total
capital_goods=capital_goods.drop(columns=['grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD', 'totalLiabilities_USD',
    'shortTermInvestments_USD', 'longTermInvestments_USD', "account_name", "Third_party_verification", "Scope_3_emissions_type"])

# %%
capital_goods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3165 entries, 0 to 3164
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  3165 non-null   int64
#  1   Year                        3165 non-null   int64
#  2   incorporated_country        3165 non-null   object
#  3   Primary activity            3165 non-null   object
#  4   Primary sector              3165 non-null   object
#  5   Market_Cap_USD              2821 non-null   float64
#  6   Revenue_USD                 2839 non-null   float64
#  7   ebitda_USD                  2839 non-null   float64
#  8   totalAssets_USD             2839 non-null   float64
#  9   totalInvestments_USD        2839 non-null   float64
#  10  totalDebt_USD               2839 non-null   float64
#  11  totalEquity_USD             2839 non-null   float64
#  12  Scope_3_emissions_amount    3165 non-null   float64
#  13  scope_1_2_emissions_amount  3161 non-null   float64
#  14  Year_sq                     3165 non-null   int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 371.0+ KB

# %%
sns.boxplot(capital_goods)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# copy dataframe
capital_goods_no_transform = capital_goods.copy()
# Change 'incorporated_country' to 'Countries' in capital_goods dataframe
capital_goods_no_transform = capital_goods_no_transform.rename(columns={'incorporated_country': 'Countries',
                                                       'Primary activity': 'Primary_activity',
                                                        'Primary sector': 'Primary_sector'})

print(capital_goods_no_transform.info())
capital_goods_no_transform.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3165 entries, 0 to 3164
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  3165 non-null   int64
#  1   Year                        3165 non-null   int64
#  2   Countries                   3165 non-null   object
#  3   Primary_activity            3165 non-null   object
#  4   Primary_sector              3165 non-null   object
#  5   Market_Cap_USD              2821 non-null   float64
#  6   Revenue_USD                 2839 non-null   float64
#  7   ebitda_USD                  2839 non-null   float64
#  8   totalAssets_USD             2839 non-null   float64
#  9   totalInvestments_USD        2839 non-null   float64
#  10  totalDebt_USD               2839 non-null   float64
#  11  totalEquity_USD             2839 non-null   float64
#  12  Scope_3_emissions_amount    3165 non-null   float64
#  13  scope_1_2_emissions_amount  3161 non-null   float64
#  14  Year_sq                     3165 non-null   int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 371.0+ KB
# None
#    account_id  Year       Countries                 Primary_activity  \
# 0        4407  2018  United Kingdom             Electrical equipment
# 1        1104  2018  United Kingdom                  Pharmaceuticals
# 2        2297  2018  United Kingdom                             REIT
# 3        2377  2018  United Kingdom      Telecommunications services
# 4       31426  2018  United Kingdom  Real estate owners & developers
#
#                                      Primary_sector  Market_Cap_USD  \
# 0                 Electrical & electronic equipment    1.595156e+10
# 1                                  Biotech & pharma    7.441091e+10
# 2                                Financial services    6.501391e+09
# 3  Media, telecommunications & data center services    2.997109e+10
# 4           Land & property ownership & development             NaN
#
#     Revenue_USD    ebitda_USD  totalAssets_USD  totalInvestments_USD  \
# 0  1.443500e+10  2.260000e+09     1.248000e+10          1.710000e+08
# 1  2.209000e+10  7.165000e+09     6.065100e+10          9.220000e+08
# 2  1.148080e+09 -3.022600e+08     1.556512e+10          3.402330e+09
# 3  2.975356e+10  9.392920e+09     5.878449e+10          1.282700e+08
# 4  1.017270e+08 -1.353820e+08     4.653407e+09          2.197100e+07
#
#    totalDebt_USD  totalEquity_USD  Scope_3_emissions_amount  \
# 0   4.344000e+09     3.670000e+09                  337000.0
# 1   1.911300e+10     1.404400e+10                   88314.0
# 2   3.966210e+09     1.103503e+10                  106395.0
# 3   2.143252e+10     1.291209e+10                  448000.0
# 4   7.838440e+08     3.789172e+09                   32356.0
#
#    scope_1_2_emissions_amount  Year_sq
# 0               380471.810000  4072324
# 1               707252.916667  4072324
# 2                14261.000000  4072324
# 3               457281.895000  4072324
# 4                 1407.000000  4072324

# %%
capital_goods_no_transform['Primary_sector'].value_counts()
# Out:
# Primary_sector
# Electrical & electronic equipment                     388
# Chemicals                                             318
# Financial services                                    291
# Biotech & pharma                                      163
# Media, telecommunications & data center services      161
# Food & beverage processing                            151
# Construction                                          133
# Powered machinery                                     112
# Specialized professional services                     101
# Medical equipment & supplies                           73
# Discretionary retail                                   65
# Thermal power generation                               62
# Trading, wholesale, distribution, rental & leasing     62
# Metal products manufacturing                           60
# Convenience retail                                     59
# Energy utility networks                                53
# Leisure & home manufacturing                           50
# IT & software development                              46
# Web & marketing services                               44
# Bars, hotels & restaurants                             43
# Air transport                                          43
# Intermodal transport & logistics                       41
# Plastic product manufacturing                          41
# Transportation equipment                               39
# Paper products & packaging                             35
# Rail transport                                         35
# Wood & rubber products                                 33
# Other services                                         32
# Metallic mineral mining                                31
# Commercial & consumer services                         29
# Land & property ownership & development                28
# Non-energy utilities                                   28
# Marine transport                                       26
# Print & publishing services                            26
# Tobacco                                                23
# Metal smelting, refining & forming                     22
# Industrial support services                            21
# Other materials                                        19
# Light manufacturing                                    18
# Apparel design                                         17
# Textiles & fabric goods                                16
# Renewable power generation                             15
# Oil & gas storage & transportation                     14
# Wood & paper materials                                 14
# 0                                                      14
# Entertainment facilities                               11
# Renewable energy equipment                             10
# Accessories                                             9
# Oil & gas extraction & production                       8
# Oil & gas retailing                                     7
# Fish & animal farming                                   6
# Logging & rubber tapping                                6
# Cement & concrete                                       5
# Road transport                                          4
# Health care provision                                   4
# Name: count, dtype: int64

# %%
capital_goods_no_transform['Primary_activity'].value_counts().head(20)
# Out:
# Primary_activity
# Telecommunications services              148
# Banks                                    148
# Electronic components                    142
# Pharmaceuticals                          134
# Other base chemicals                     111
# Specialty chemicals                      102
# Other professional services               95
# Electronic equipment                      75
# Personal care & household products        67
# Electrical equipment                      66
# REIT                                      61
# Other food processing                     61
# Supermarkets, food & drugstores           59
# Insurance                                 58
# Non-residential building construction     56
# Industrial machinery                      55
# CCGT generation                           53
# Software                                  46
# Marketing                                 44
# Passenger airlines                        43
# Name: count, dtype: int64

# %%
# Looking at missing data
print(capital_goods_no_transform.isnull().mean().sort_values(ascending=False).round(3) * 100)
# Out:
# Market_Cap_USD                10.9
# Revenue_USD                   10.3
# ebitda_USD                    10.3
# totalAssets_USD               10.3
# totalInvestments_USD          10.3
# totalDebt_USD                 10.3
# totalEquity_USD               10.3
# scope_1_2_emissions_amount     0.1
# account_id                     0.0
# Year                           0.0
# Countries                      0.0
# Primary_activity               0.0
# Primary_sector                 0.0
# Scope_3_emissions_amount       0.0
# Year_sq                        0.0
# dtype: float64

# %% [markdown]
# Apply signed log transformation and split data by company and year into train_df (2018-2022) and test_df (2023):

# %%
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD',
       'totalAssets_USD', 'totalInvestments_USD',
       'totalDebt_USD', 'totalEquity_USD', 'Scope_3_emissions_amount',
       'scope_1_2_emissions_amount'
]
required_cols = [
    'account_id', 'Year', 'Year_sq', 'Countries', 'Primary_activity', 'Primary_sector'
] + numeric_cols

# --- Prepare Data ---
df = capital_goods_no_transform[required_cols].dropna()

# --- Signed log transform ---
def signed_log(x):
    return np.sign(x) * np.log(np.abs(x) + 1)

for col in numeric_cols:
    df[f'slog_{col}'] = signed_log(df[col])

# --- Company-level split by year ---
train_df = df[df['Year'].between(2018, 2022)].copy()
test_df  = df[df['Year'] == 2023].copy()

# Keep only companies present in training
valid_companies = set(train_df['account_id'].unique())
test_df = test_df[test_df['account_id'].isin(valid_companies)].copy()

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (2218, 24)
# Test shape: (505, 24)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2218 entries, 0 to 2490
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       2218 non-null   int64
#  1   Year                             2218 non-null   int64
#  2   Year_sq                          2218 non-null   int64
#  3   Countries                        2218 non-null   object
#  4   Primary_activity                 2218 non-null   object
#  5   Primary_sector                   2218 non-null   object
#  6   Market_Cap_USD                   2218 non-null   float64
#  7   Revenue_USD                      2218 non-null   float64
#  8   ebitda_USD                       2218 non-null   float64
#  9   totalAssets_USD                  2218 non-null   float64
#  10  totalInvestments_USD             2218 non-null   float64
#  11  totalDebt_USD                    2218 non-null   float64
#  12  totalEquity_USD                  2218 non-null   float64
#  13  Scope_3_emissions_amount         2218 non-null   float64
#  14  scope_1_2_emissions_amount       2218 non-null   float64
#  15  slog_Market_Cap_USD              2218 non-null   float64
#  16  slog_Revenue_USD                 2218 non-null   float64
#  17  slog_ebitda_USD                  2218 non-null   float64
#  18  slog_totalAssets_USD             2218 non-null   float64
#  19  slog_totalInvestments_USD        2218 non-null   float64
#  20  slog_totalDebt_USD               2218 non-null   float64
#  21  slog_totalEquity_USD             2218 non-null   float64
#  22  slog_Scope_3_emissions_amount    2218 non-null   float64
#  23  slog_scope_1_2_emissions_amount  2218 non-null   float64
# dtypes: float64(18), int64(3), object(3)
# memory usage: 433.2+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 505 entries, 2491 to 3161
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       505 non-null    int64
#  1   Year                             505 non-null    int64
#  2   Year_sq                          505 non-null    int64
#  3   Countries                        505 non-null    object
#  4   Primary_activity                 505 non-null    object
#  5   Primary_sector                   505 non-null    object
#  6   Market_Cap_USD                   505 non-null    float64
#  7   Revenue_USD                      505 non-null    float64
#  8   ebitda_USD                       505 non-null    float64
#  9   totalAssets_USD                  505 non-null    float64
#  10  totalInvestments_USD             505 non-null    float64
#  11  totalDebt_USD                    505 non-null    float64
#  12  totalEquity_USD                  505 non-null    float64
#  13  Scope_3_emissions_amount         505 non-null    float64
#  14  scope_1_2_emissions_amount       505 non-null    float64
#  15  slog_Market_Cap_USD              505 non-null    float64
#  16  slog_Revenue_USD                 505 non-null    float64
#  17  slog_ebitda_USD                  505 non-null    float64
#  18  slog_totalAssets_USD             505 non-null    float64
#  19  slog_totalInvestments_USD        505 non-null    float64
#  20  slog_totalDebt_USD               505 non-null    float64
#  21  slog_totalEquity_USD             505 non-null    float64
#  22  slog_Scope_3_emissions_amount    505 non-null    float64
#  23  slog_scope_1_2_emissions_amount  505 non-null    float64
# dtypes: float64(18), int64(3), object(3)
# memory usage: 98.6+ KB

# %%
# Check number of 0's in train and test df's
print((train_df == 0).sum().sum())
print((test_df == 0).sum().sum())
# Out:
# 70
# 18

# %% [markdown]
# ## Capital Goods Null Mixed-Effects Model
#
# Null mixed-effects model (random intercept only) to predict log-transformed Scope 3 emissions. The model serves as a baseline, capturing only the average emission level for each company, without incorporating any explanatory variables, and quantifies the improvement gained by including additional features and structure. The model is trained on 2018–2022 data and evaluated on a test set from 2023.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies
# - Fixed Effects:
#     - Intercept only (no predictors)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE NULL MODEL (random intercept only) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    null_model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ 1",
        train_df,
        groups=train_df["account_id"]
    )
    null_result = null_model.fit(method="lbfgs")

if not null_result.converged:
    print("WARNING: Null model did not fully converge.")

print(null_result.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_null'] = null_result.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_null']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_null'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics text
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[0], color='gray')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Null Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[1], color='gray')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Null Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Null Model Predicted")
plt.xscale("log")
plt.title("Null Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
null_model_metrics = {
    "Model": "Null (RI)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "Random intercept only"
}
# Out:
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 2218    Method:             REML
# No. Groups:       576     Scale:              0.8182
# Min. group size:  1       Log-Likelihood:     -3781.9382
# Max. group size:  5       Converged:          Yes
# Mean group size:  3.9
# ------------------------------------------------------------------------------
#                Coef.      Std.Err.        z        P>|z|     [0.025     0.975]
# ------------------------------------------------------------------------------
# Intercept      10.844        0.091     119.662     0.000     10.667     11.022
# Group Var       4.442        0.362
# ==========================================================================
#
# R²(log):    -2.27%
# R²(orig):   -18.07%
# MAPE:       2733.76%
# MAPE(log):  17.15%
# MAE(log):   1.63
# RMSLE:      2.06
# RMSE:       583922.63
# MAE:        253972.60

# %% [markdown]
# ## Capital Goods Two-Level Mixed-Effects Model
#
# Two-level hierarchical linear mixed-effects model to predict log-transformed Scope 3 emissions at the company level. The model is fit to training data (from 2018–2022), and predictions are evaluated on a test set (from 2023).  This model provides a baseline for including time trends and company-level variability.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies.<br>
# - Fixed Effects:
#     - Year (numeric)
#     - Year squared ('Year_sq', quadratic time trend)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- Check group sizes ---
group_sizes = train_df.groupby('account_id').size()
print("Two-Level Model: Company/year group size summary:")
print(group_sizes.describe())

# --- FIT THE TWO-LEVEL MODEL (random intercept, +Year, +Year_sq) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ Year + Year_sq",
        train_df,
        groups=train_df["account_id"],
        re_formula="1"
    )
    result_twolevel = model.fit(method="lbfgs")

if not result_twolevel.converged:
    print("WARNING: Two-level mixed model did not fully converge.")

print(result_twolevel.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_twolevel.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_mixed']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='orange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Two-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='orange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Two-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="orange", alpha=0.5, label="Two-Level Model Predicted")
plt.xscale("log")
plt.title("Two-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
two_level_model_metrics = {
    "Model": "2-level (RI+S)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "+Year, Year_sq"
}
# Out:
# Two-Level Model: Company/year group size summary:
# count    576.000000
# mean       3.850694
# std        1.528375
# min        1.000000
# 25%        3.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000
# dtype: float64
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 2218    Method:             REML
# No. Groups:       576     Scale:              0.8165
# Min. group size:  1       Log-Likelihood:     -3786.4084
# Max. group size:  5       Converged:          Yes
# Mean group size:  3.9
# ---------------------------------------------------------------------------
#                  Coef.      Std.Err.    z     P>|z|     [0.025      0.975]
# ---------------------------------------------------------------------------
# Intercept      -52690.776  48611.317  -1.084  0.278  -147967.206  42585.654
# Year               52.151     48.129   1.084  0.279      -42.180    146.482
# Year_sq            -0.013      0.012  -1.083  0.279       -0.036      0.010
# Group Var           4.449      0.363
# ==========================================================================
#
# R²(log):    -2.47%
# R²(orig):   -18.18%
# MAPE:       2697.38%
# MAPE(log):  17.16%
# MAE(log):   1.63
# RMSLE:      2.06
# RMSE:       584192.27
# MAE:        254150.72

# %% [markdown]
# ## Capital Goods Three-Level Mixed-Effects Model
#
# A three-level hierarchical linear mixed-effects model is used to predict log-transformed Scope 3 emissions. It takes into account differences between primary activity, differences between companies, and changes over time. The model is trained using data from 2018 to 2022, and then tested on new data from 2023. This model provides insight on how emissions are influenced by primary activity, by individual companies, by financial and emissions factors, and by trends over time.
#
# Model Structure:
#
# - Level 3 (Primary Activity):<br>
#     - Random intercept and random slope for Year for each primary activity ('Primary_activity'), capturing baseline primary activity and primary activity-specific time trends.<br>
# - Level 2 (Account/Company):
#     - Random intercept for each company ('account_id'), capturing company-level deviations within each primary activity.
# - Level 1 (Yearly Observations):
#     - Repeated annual observations within each company.
#
# - Fixed Effects:
#     - Signed log-transformed market cap ('slog_Market_Cap_USD')
#     - Signed log-transformed revenue ('slog_Revenue_USD')
#     - Signed log-transformed EBITDA ('slog_ebitda_USD')
#     - Signed log-transformed Scope 1 & 2 emissions ('slog_scope_1_2_emissions_amount')

# %%
# --- Ensure grouping/categorical variables are string ---
for col in ['Countries', 'account_id', 'Primary_activity', 'Primary_sector']:
    train_df[col] = train_df[col].astype(str)
    test_df[col] = test_df[col].astype(str)

# --- Center the Year variable ---
year_mean = train_df['Year'].mean()
train_df['Year_centered'] = train_df['Year'] - year_mean
test_df['Year_centered'] = test_df['Year'] - year_mean

# --- Ensure log-transformed target exists ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE 3-LEVEL MIXED MODEL with Primary_activity as Level 3 group ---
vc = {'account_id': '0 + C(account_id)'}  # Level 2: account_id random intercept

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model_3level = MixedLM.from_formula(
        'log_Scope_3_emissions_amount ~ slog_Market_Cap_USD + slog_Revenue_USD + slog_ebitda_USD + slog_scope_1_2_emissions_amount',
        groups='Primary_activity',
        re_formula='~Year_centered',
        vc_formula=vc,
        data=train_df
    )
    result_3level = model_3level.fit(method="lbfgs", maxiter=1000)

if not result_3level.converged:
    print("WARNING: Three-level mixed model did not fully converge.")

print(result_3level.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_3level.predict(test_df)

# --- Compute back-transformed values ---
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])

# --- Robust Mask for finite values everywhere ---
mask = (
    np.isfinite(test_df['log_Scope_3_emissions_amount']) &
    np.isfinite(test_df['predicted_mixed']) &
    np.isfinite(test_df['Reported_Scope_3']) &
    np.isfinite(test_df['Predicted_Scope_3'])
)
test_df = test_df.loc[mask].copy()

y_true_log = test_df['log_Scope_3_emissions_amount'].values
y_pred_log = test_df['predicted_mixed'].values
y_true = test_df['Reported_Scope_3'].values
y_pred = test_df['Predicted_Scope_3'].values

# Final defensive check and diagnostics
arrays = {
    "y_true_log": y_true_log,
    "y_pred_log": y_pred_log,
    "y_true": y_true,
    "y_pred": y_pred,
}
for arr_name, arr in arrays.items():
    if not np.all(np.isfinite(arr)):
        print(f"ERROR: {arr_name} contains non-finite values!")
        print(f"Non-finite indices: {np.where(~np.isfinite(arr))[0]}")
        print(f"Values: {arr[~np.isfinite(arr)]}")
        raise ValueError(f"{arr_name} contains infs or NaNs after masking!")

# --- METRICS ---
mae_log = mean_absolute_error(y_true_log, y_pred_log)
nonzero_mask = y_true_log != 0
if np.any(nonzero_mask):
    mape_log = np.mean(np.abs((y_true_log[nonzero_mask] - y_pred_log[nonzero_mask]) / y_true_log[nonzero_mask])) * 100
else:
    mape_log = np.nan

r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)

metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
if len(np.unique(y_pred_log)) > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Three-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()
axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

if len(np.unique(y_pred)) > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Three-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()
axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Filter strictly positive values for histogram (log x-axis requires >0)
y_true_pos = y_true[y_true > 0]
y_pred_pos = y_pred[y_pred > 0]

if y_true_pos.size > 0 and y_pred_pos.size > 0:
    min_val = min(y_true_pos.min(), y_pred_pos.min())
    max_val = max(y_true_pos.max(), y_pred_pos.max())
    if min_val == max_val:
        print("Skipping histogram: Only one unique positive value present.")
    else:
        log_bins = np.logspace(np.log10(min_val), np.log10(max_val), 100)

        plt.figure(figsize=(8, 5))
        sns.histplot(y_true_pos, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
        sns.histplot(y_pred_pos, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Three-Level Model Predicted")
        plt.xscale("log")
        plt.title("Three-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
        plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
        plt.ylabel("Density")
        plt.legend()
        plt.tight_layout()
        plt.show()
else:
    print("Skipping histogram: Not enough positive values in y_true or y_pred for log-scale histogram.")

# --- RETURN METRICS FOR SUMMARY TABLE ---
three_level_model_metrics = {
    "Model": "3-level (Primary Activity/Account/Year)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,
    "MAPE(log)": mape_log,
}
# Out:
#                      Mixed Linear Model Regression Results
# ===============================================================================
# Model:               MixedLM  Dependent Variable:  log_Scope_3_emissions_amount
# No. Observations:    2218     Method:              REML
# No. Groups:          114      Scale:               0.8085
# Min. group size:     1        Log-Likelihood:      -3702.3325
# Max. group size:     108      Converged:           Yes
# Mean group size:     19.5
# -------------------------------------------------------------------------------
#                                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------------
# Intercept                            -0.292    1.044 -0.280 0.780 -2.339  1.755
# slog_Market_Cap_USD                   0.223    0.045  4.948 0.000  0.135  0.312
# slog_Revenue_USD                      0.132    0.042  3.174 0.002  0.050  0.213
# slog_ebitda_USD                       0.006    0.004  1.297 0.195 -0.003  0.014
# slog_scope_1_2_emissions_amount       0.239    0.030  7.900 0.000  0.180  0.298
# Primary_activity Var                  0.358    0.158
# Primary_activity x Year_centered Cov -0.042    0.026
# Year_centered Var                     0.017    0.008
# account_id Var                        2.775    0.260
# ===============================================================================
#
# R²(log):    31.33%
# R²(orig):   -1.31%
# MAPE:       2288.51%
# MAPE(log):  13.80%
# MAE(log):   1.28
# RMSLE:      1.69
# RMSE:       540886.84
# MAE:        225163.02

# %% [markdown]
# ## Capital Goods Full Mixed-Effects Model
#
# A full mixed-effects model is used to predict company Scope 3 emissions, using financial and emissions data, along with information about country, industry, and year. The model is trained on data from 2018 to 2022, and tested on data from 2023. This full model helps provides insights into how a company’s finances, emissions, primary activity, country and the year influence emissions.<br>
#
# Model Structure:<br>
#
# - Random Effects:<br>
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:<br>
#     - Signed log-transformed financial and emissions features:<br>
#         - Market Cap ('slog_Market_Cap_USD')<br>
#         - Revenue ('slog_Revenue_USD')<br>
#         - EBITDA ('slog_ebitda_USD')<br>
#         - Total Investments ('slog_totalInvestments_USD')<br>
#         - Total Debt ('slog_totalDebt_USD')<br>
#         - Total Assets ('slog_totalAssets_USD')<br>
#         - Total Equity ('slog_totalEquity_USD')<br>
#         - Scope 1&2 Emissions ('slog_scope_1_2_emissions_amount')<br>
#     - Country ('Countries', as a categorical variable)<br>
#     - Primary Activity ('Primary_activity', as a categorical variable)<br>
#     - Year (numeric)<br>

# %%
# --- Feature and target columns ---
numeric_cols = ['Market_Cap_USD',
 'Revenue_USD',
 #'ebitda_USD',
 'totalAssets_USD',
 #'totalInvestments_USD',
 'totalDebt_USD',
 'totalEquity_USD',
 'Scope_3_emissions_amount',
 'scope_1_2_emissions_amount'
]
feature_cols_slog = [f'slog_{col}' for col in numeric_cols if col != 'Scope_3_emissions_amount']
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
required_cols = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_full = train_df.dropna(subset=required_cols).copy()
test_df_full = test_df.dropna(subset=required_cols).copy()

if test_df_full.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the full mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_full, groups=train_df_full['account_id'])
        mdf = md.fit(reml=False)
    print(mdf.summary())

    # --- Predict on test set ---
    test_df_full['predicted_log'] = mdf.predict(test_df_full)
    test_df_full['predicted'] = np.sign(test_df_full['predicted_log']) * (np.expm1(np.abs(test_df_full['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_full[target_col_slog]
    y_pred_log = test_df_full['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_full['predicted']

    # Mask for finite values
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nFull Mixed-Effects Model (Full Model) Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf.params,
        'pvalue': mdf.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Full Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Full Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Full Model Predicted")
    plt.xscale("log")
    plt.title("Full Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    full_model_metrics = {
        "Model": "Full Model",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
# /Users/amberjensen/anaconda3/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2704: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))
#                                                                    Mixed Linear Model Regression Results
# ===========================================================================================================================================================================
# Model:                                            MixedLM                                 Dependent Variable:                                 slog_Scope_3_emissions_amount
# No. Observations:                                 2218                                    Method:                                             ML
# No. Groups:                                       576                                     Scale:                                              0.9632
# Min. group size:                                  1                                       Log-Likelihood:                                     -3544.9309
# Max. group size:                                  5                                       Converged:                                          No
# Mean group size:                                  3.9
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                                  Coef.               Std.Err.         z    P>|z|         [0.025               0.975]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                              -35.648               31.892 -1.118 0.264               -98.154               26.858
# C(Countries)[T.Austria]                                                                  3.364                1.023  3.289 0.001                 1.359                5.368
# C(Countries)[T.Belgium]                                                                  1.826                0.844  2.164 0.030                 0.172                3.480
# C(Countries)[T.Bermuda]                                                                  0.891                1.286  0.693 0.488                -1.630                3.412
# C(Countries)[T.Brazil]                                                                   0.759                0.829  0.916 0.360                -0.865                2.383
# C(Countries)[T.Canada]                                                                   0.548                0.598  0.917 0.359                -0.623                1.719
# C(Countries)[T.Chile]                                                                    0.048                1.591  0.030 0.976                -3.071                3.167
# C(Countries)[T.China]                                                                   -0.185                0.627 -0.296 0.768                -1.414                1.044
# C(Countries)[T.Denmark]                                                                  0.817                0.977  0.836 0.403                -1.098                2.731
# C(Countries)[T.Finland]                                                                 -0.339                0.605 -0.560 0.575                -1.525                0.847
# C(Countries)[T.France]                                                                   0.529                0.520  1.018 0.309                -0.489                1.547
# C(Countries)[T.Germany]                                                                  1.417                0.544  2.605 0.009                 0.351                2.482
# C(Countries)[T.Greece]                                                                   0.452                1.194  0.379 0.705                -1.889                2.793
# C(Countries)[T.Hungary]                                                                 -1.216                1.224 -0.993 0.320                -3.614                1.183
# C(Countries)[T.India]                                                                    0.506                1.213  0.417 0.677                -1.871                2.883
# C(Countries)[T.Ireland]                                                                 -0.134                0.774 -0.173 0.863                -1.651                1.384
# C(Countries)[T.Italy]                                                                    0.186                0.614  0.302 0.762                -1.018                1.389
# C(Countries)[T.Japan]                                                                    1.158                0.484  2.395 0.017                 0.210                2.106
# C(Countries)[T.Luxembourg]                                                 458822293578024.750 1655692126242365.250  0.277 0.782 -2786274643343556.000 3703919230499606.000
# C(Countries)[T.Mexico]                                                                  -2.047                1.195 -1.713 0.087                -4.390                0.295
# C(Countries)[T.Netherlands]                                                              1.013                0.619  1.638 0.101                -0.199                2.226
# C(Countries)[T.New Zealand]                                                              0.470                0.815  0.577 0.564                -1.127                2.068
# C(Countries)[T.Norway]                                                                  -0.118                0.895 -0.132 0.895                -1.873                1.636
# C(Countries)[T.Portugal]                                                                -0.812                1.776 -0.457 0.648                -4.293                2.669
# C(Countries)[T.Singapore]                                                                3.062                1.483  2.065 0.039                 0.156                5.968
# C(Countries)[T.South Africa]                                                            -1.100                0.674 -1.634 0.102                -2.420                0.220
# C(Countries)[T.South Korea]                                                             -3.169                0.548 -5.785 0.000                -4.242               -2.095
# C(Countries)[T.Spain]                                                                    0.180                0.549  0.327 0.743                -0.897                1.256
# C(Countries)[T.Sweden]                                                                   0.530                0.948  0.559 0.576                -1.327                2.387
# C(Countries)[T.Switzerland]                                                             -0.043                0.587 -0.073 0.942                -1.193                1.108
# C(Countries)[T.Thailand]                                                                 0.503                0.837  0.601 0.548                -1.138                2.144
# C(Countries)[T.USA]                                                                      0.390                0.477  0.818 0.413                -0.545                1.326
# C(Countries)[T.United Kingdom]                                                           0.828                0.503  1.647 0.100                -0.157                1.814
# C(Primary_activity)[T.Accessories manufacture]                                          -0.169                0.730 -0.231 0.817                -1.600                1.262
# C(Primary_activity)[T.Agricultural chemicals]                                           -1.373                1.108 -1.239 0.215                -3.545                0.799
# C(Primary_activity)[T.Agriculture, construction & mining machinery]                     -0.268                0.360 -0.745 0.456                -0.975                0.438
# C(Primary_activity)[T.Alcoholic beverages]                                              -0.333                0.299 -1.112 0.266                -0.919                0.254
# C(Primary_activity)[T.Animal processing]                                                 0.305                0.736  0.414 0.679                -1.138                1.747
# C(Primary_activity)[T.Apparel & footwear design]                                         0.695                0.586  1.186 0.236                -0.454                1.844
# C(Primary_activity)[T.Apparel stores]                                                    0.044                0.414  0.105 0.916                -0.768                0.855
# C(Primary_activity)[T.Aquaculture]                                                       0.694                1.287  0.539 0.590                -1.828                3.215
# C(Primary_activity)[T.Asset managers]                                                   -1.922                0.517 -3.716 0.000                -2.936               -0.908
# C(Primary_activity)[T.Automobiles]                                                       0.602                0.336  1.792 0.073                -0.057                1.261
# C(Primary_activity)[T.Baked goods & cereals]                                            -0.374                1.036 -0.361 0.718                -2.404                1.657
# C(Primary_activity)[T.Banks]                                                            -1.438                0.324 -4.435 0.000                -2.073               -0.802
# C(Primary_activity)[T.Batteries]                                                        -0.873                0.699 -1.249 0.212                -2.244                0.497
# C(Primary_activity)[T.Biotechnology]                                                    -0.368                0.376 -0.979 0.328                -1.105                0.369
# C(Primary_activity)[T.Building sub-contractors]                                         -0.670                0.679 -0.987 0.324                -2.001                0.661
# C(Primary_activity)[T.CCGT generation]                                                  -0.322                0.225 -1.431 0.152                -0.763                0.119
# C(Primary_activity)[T.Cement]                                                            1.804                1.757  1.027 0.304                -1.640                5.249
# C(Primary_activity)[T.Clothing manufacture]                                             -0.409                0.658 -0.622 0.534                -1.699                0.881
# C(Primary_activity)[T.Coal generation]                                                   1.349                1.427  0.946 0.344                -1.447                4.145
# C(Primary_activity)[T.Commercial services]                                              -0.886                0.473 -1.872 0.061                -1.813                0.041
# C(Primary_activity)[T.Communications equipment]                                         -0.279                0.400 -0.699 0.485                -1.063                0.504
# C(Primary_activity)[T.Computer hardware]                                                 0.416                0.436  0.953 0.340                -0.439                1.271
# C(Primary_activity)[T.Consumer services]                                                -1.027                1.096 -0.938 0.348                -3.174                1.120
# C(Primary_activity)[T.Dairy & egg products]                                              0.809                1.037  0.780 0.435                -1.223                2.840
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                               0.383                0.422  0.907 0.364                -0.444                1.211
# C(Primary_activity)[T.Department stores]                                                -0.153                0.683 -0.224 0.823                -1.493                1.186
# C(Primary_activity)[T.Discretionary delivery retail]                                    -0.465                0.544 -0.855 0.393                -1.531                0.601
# C(Primary_activity)[T.Education services]                                               -0.834                1.097 -0.760 0.447                -2.984                1.317
# C(Primary_activity)[T.Electrical equipment]                                              0.446                0.163  2.733 0.006                 0.126                0.765
# C(Primary_activity)[T.Electricity networks]                                             -1.350                0.532 -2.540 0.011                -2.392               -0.308
# C(Primary_activity)[T.Electronic components]                                            -0.244
# C(Primary_activity)[T.Electronic equipment]                                              0.145
# C(Primary_activity)[T.Energy infrastructure construction]                               -3.846                0.873 -4.407 0.000                -5.557               -2.136
# C(Primary_activity)[T.Energy services & equipment]                                      -0.516                0.783 -0.659 0.510                -2.051                1.019
# C(Primary_activity)[T.Engineering services]                                             -0.364                0.899 -0.405 0.686                -2.126                1.398
# C(Primary_activity)[T.Engines & motors]                                                  0.985                0.359  2.746 0.006                 0.282                1.688
# C(Primary_activity)[T.Fabricated metal components]                                       0.635                0.246  2.582 0.010                 0.153                1.117
# C(Primary_activity)[T.Fast food]                                                        -0.423                0.971 -0.435 0.663                -2.327                1.481
# C(Primary_activity)[T.Finished wood products]                                            2.607                1.215  2.146 0.032                 0.226                4.987
# C(Primary_activity)[T.Food & beverage amenities]                                         1.839                0.956  1.923 0.054                -0.035                3.712
# C(Primary_activity)[T.Food & beverage wholesale]                                        -0.131                0.803 -0.163 0.871                -1.704                1.443
# C(Primary_activity)[T.Furniture]                                                        -0.081                0.446 -0.182 0.855                -0.956                0.793
# C(Primary_activity)[T.Gambling]                                                         -1.973                0.711 -2.775 0.006                -3.366               -0.579
# C(Primary_activity)[T.Gas utilities]                                                    -0.141                0.531 -0.265 0.791                -1.181                0.900
# C(Primary_activity)[T.Glass products]                                                    0.492                0.700  0.703 0.482                -0.879                1.864
# C(Primary_activity)[T.Grain & corn milling]                                             -1.491                1.366 -1.092 0.275                -4.169                1.187
# C(Primary_activity)[T.Health care services]                                             -1.675                0.564 -2.969 0.003                -2.782               -0.569
# C(Primary_activity)[T.Health care supplies]                                             -0.368                0.397 -0.926 0.355                -1.146                0.411
# C(Primary_activity)[T.Homeware]                                                          0.314                1.102  0.285 0.776                -1.845                2.473
# C(Primary_activity)[T.Hotels & lodging]                                                  0.580                0.215  2.700 0.007                 0.159                1.001
# C(Primary_activity)[T.Hydro generation]                                                 -5.823                1.554 -3.747 0.000                -8.870               -2.777
# C(Primary_activity)[T.Industrial machinery]                                             -0.534                0.387 -1.378 0.168                -1.293                0.225
# C(Primary_activity)[T.Inorganic base chemicals]                                          0.013                0.464  0.029 0.977                -0.897                0.923
# C(Primary_activity)[T.Insurance]                                                        -2.173                0.342 -6.350 0.000                -2.844               -1.502
# C(Primary_activity)[T.Intermodal transport]                                             -0.189                1.016 -0.186 0.852                -2.180                1.802
# C(Primary_activity)[T.Iron & steel]                                       -458822293578022.562 1655692126242361.750 -0.277 0.782 -3703919230499597.000 2786274643343552.000
# C(Primary_activity)[T.Logging]                                                          -0.349                1.024 -0.340 0.734                -2.356                1.659
# C(Primary_activity)[T.Logistics - 3rd party]                                            -0.608                0.433 -1.406 0.160                -1.456                0.240
# C(Primary_activity)[T.Logistics - transport]                                            -0.526                1.091 -0.482 0.630                -2.664                1.612
# C(Primary_activity)[T.Marine freight]                                                   -0.756                0.518 -1.461 0.144                -1.771                0.258
# C(Primary_activity)[T.Marketing]                                                        -0.651                0.397 -1.639 0.101                -1.428                0.127
# C(Primary_activity)[T.Medical equipment]                                                -0.415                0.264 -1.570 0.116                -0.932                0.103
# C(Primary_activity)[T.Metal containers & packaging]                                      1.058                0.452  2.342 0.019                 0.172                1.944
# C(Primary_activity)[T.Metal processing]                                                  0.453                0.704  0.643 0.520                -0.927                1.832
# C(Primary_activity)[T.Non-CCGT generation]                                               0.611                1.105  0.553 0.580                -1.555                2.776
# C(Primary_activity)[T.Non-alcoholic beverages]                                           0.428                0.361  1.183 0.237                -0.281                1.136
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                                       0.918                1.047  0.877 0.381                -1.134                2.971
# C(Primary_activity)[T.Non-residential building construction]                            -1.280                0.223 -5.747 0.000                -1.717               -0.844
# C(Primary_activity)[T.Oil & gas extraction]                                             -0.662                0.861 -0.769 0.442                -2.350                1.025
# C(Primary_activity)[T.Oil & gas marketing & retailing]                                   0.472                0.933  0.505 0.613                -1.357                2.301
# C(Primary_activity)[T.Oil & gas pipelines & storage]                                    -0.593                0.629 -0.944 0.345                -1.825                0.639
# C(Primary_activity)[T.Other base chemicals]                                             -0.132
# C(Primary_activity)[T.Other containers & packaging]                                      0.800                0.789  1.014 0.311                -0.747                2.347
# C(Primary_activity)[T.Other food processing]                                             0.485                0.106  4.556 0.000                 0.276                0.694
# C(Primary_activity)[T.Other non-ferrous ore mining]                                     -0.052                0.710 -0.073 0.942                -1.443                1.339
# C(Primary_activity)[T.Other professional services]                                      -0.636
# C(Primary_activity)[T.Other renewable energy equipment]                                 -0.689                1.414 -0.488 0.626                -3.460                2.081
# C(Primary_activity)[T.Other renewable generation]                                        1.947                1.929  1.009 0.313                -1.834                5.729
# C(Primary_activity)[T.Paper products]                                                    0.458                0.309  1.482 0.138                -0.148                1.065
# C(Primary_activity)[T.Passenger airlines]                                                0.009                0.256  0.036 0.971                -0.492                0.510
# C(Primary_activity)[T.Passenger rail]                                                    1.201                1.044  1.150 0.250                -0.846                3.247
# C(Primary_activity)[T.Personal care & household products]                                0.052                0.179  0.290 0.772                -0.298                0.402
# C(Primary_activity)[T.Pharmaceuticals]                                                  -0.600
# C(Primary_activity)[T.Plastic products]                                                 -0.528                0.340 -1.553 0.120                -1.194                0.138
# C(Primary_activity)[T.Precious metals & minerals mining]                                -1.780                0.681 -2.615 0.009                -3.115               -0.446
# C(Primary_activity)[T.Print publishing]                                                 -2.396                1.078 -2.224 0.026                -4.509               -0.284
# C(Primary_activity)[T.Printing services]                                                -0.005                0.714 -0.008 0.994                -1.406                1.395
# C(Primary_activity)[T.Pulp & paper mills]                                                0.244                0.899  0.272 0.786                -1.518                2.006
# C(Primary_activity)[T.REIT]                                                             -0.080                0.216 -0.370 0.712                -0.504                0.344
# C(Primary_activity)[T.Rail freight]                                                      0.807                0.442  1.824 0.068                -0.060                1.673
# C(Primary_activity)[T.Railroad rolling stock]                                           -0.814                1.115 -0.730 0.466                -2.999                1.372
# C(Primary_activity)[T.Real estate owners & developers]                                   0.528                0.621  0.850 0.395                -0.689                1.745
# C(Primary_activity)[T.Real estate services]                                             -4.179                0.711 -5.881 0.000                -5.571               -2.786
# C(Primary_activity)[T.Residential building construction]                                -0.859                0.393 -2.187 0.029                -1.628               -0.089
# C(Primary_activity)[T.Rubber products]                                                   0.573                0.418  1.370 0.171                -0.247                1.393
# C(Primary_activity)[T.Semiconductors]                                                   -0.082                0.553 -0.148 0.882                -1.166                1.002
# C(Primary_activity)[T.Servers & data centers]                                            0.757                0.757  0.999 0.318                -0.728                2.241
# C(Primary_activity)[T.Software]                                                         -0.323                0.225 -1.433 0.152                -0.764                0.119
# C(Primary_activity)[T.Solar energy equipment]                                            2.145                1.090  1.968 0.049                 0.009                4.280
# C(Primary_activity)[T.Specialist retail]                                                -0.031                0.681 -0.045 0.964                -1.365                1.304
# C(Primary_activity)[T.Specialty chemicals]                                              -0.376
# C(Primary_activity)[T.Supermarkets, food & drugstores]                                   0.689                0.078  8.854 0.000                 0.536                0.841
# C(Primary_activity)[T.Telecommunications services]                                       0.827
# C(Primary_activity)[T.Textiles]                                                         -0.432                1.242 -0.348 0.728                -2.867                2.002
# C(Primary_activity)[T.Tobacco products]                                                 -0.939
# C(Primary_activity)[T.Transportation infrastructure & other construction]                1.316                0.399  3.298 0.001                 0.534                2.099
# C(Primary_activity)[T.Transportation support services]                                   2.457                1.068  2.300 0.021                 0.364                4.550
# C(Primary_activity)[T.Travel services]                                                  -0.897                1.072 -0.837 0.403                -2.998                1.204
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]                            -0.914                0.505 -1.809 0.070                -1.904                0.076
# C(Primary_activity)[T.Waste management]                                                  1.484                0.687  2.159 0.031                 0.137                2.831
# C(Primary_activity)[T.Water supply networks]                                             0.203                0.613  0.331 0.740                -0.998                1.405
# C(Primary_activity)[T.Wind generation]                                                   0.014                1.114  0.012 0.990                -2.169                2.197
# C(Primary_activity)[T.Wood furniture]                                                   -0.677                1.094 -0.619 0.536                -2.822                1.468
# slog_Market_Cap_USD                                                                      0.257                0.048  5.329 0.000                 0.162                0.351
# slog_Revenue_USD                                                                         0.094                0.039  2.386 0.017                 0.017                0.171
# slog_totalAssets_USD                                                                     0.151                0.049  3.074 0.002                 0.055                0.247
# slog_totalDebt_USD                                                                       0.024                0.028  0.882 0.378                -0.030                0.078
# slog_totalEquity_USD                                                                     0.003                0.007  0.503 0.615                -0.010                0.016
# slog_scope_1_2_emissions_amount                                                          0.232                0.031  7.512 0.000                 0.171                0.292
# Year                                                                                     0.015                0.016  0.975 0.329                -0.016                0.046
# Group Var                                                                                0.983                0.074
# ===========================================================================================================================================================================
#
#
# Full Mixed-Effects Model (Full Model) Test Set Performance Metrics:
# R²(log):    54.54%
# R²(orig):   29.16%
# MAPE:       260.93%
# MAPE(log):  10.25%
# MAE(log):   1.00
# RMSLE:      1.37
# RMSE:       452287.59
# MAE:        189927.15
#
# Top Influential Features (by p-value):
#                                                         coef        pvalue
# Group Var                                           1.020058  6.783786e-42
# C(Primary_activity)[T.Supermarkets, food & drug...  0.688678  8.465455e-19
# slog_scope_1_2_emissions_amount                     0.231925  5.821269e-14
# C(Primary_activity)[T.Insurance]                   -2.172984  2.156361e-10
# C(Primary_activity)[T.Real estate services]        -4.178614  4.087107e-09
# C(Countries)[T.South Korea]                        -3.168592  7.266392e-09
# C(Primary_activity)[T.Non-residential building ... -1.280263  9.102386e-09
# slog_Market_Cap_USD                                 0.256916  9.866162e-08
# C(Primary_activity)[T.Other food processing]        0.485066  5.224487e-06
# C(Primary_activity)[T.Banks]                       -1.437901  9.205396e-06

# %% [markdown]
# ## Capital Goods Optimized Mixed-Effects Model
#
# An optimized mixed-effects model is used to predict company Scope 3 emissions. The model provides accurate prediction using only the most significant predictive features, while still accounting for primary activity, country and company level effects. The model is trained on data from 2018–2022 and evaluated on test data from 2023.
#
# Model Structure:
#
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:
#     - Signed log-transformed features:
#         - Market Cap ('slog_Market_Cap_USD')
#         - Revenue ('slog_Revenue_USD')
#         - Total Assets ('slog_totalAssets_USD')
#         - Scope 1 & 2 Emissions ('slog_scope_1_2_emissions_amount')
#     - Country ('Countries', as a categorical variable)
#     - Primary Activity ('Primary_activity', as a categorical variable)
#     - Year ('Year', as numeric)

# %%
feature_cols_slog = [
    'slog_Market_Cap_USD',
    'slog_Revenue_USD',
    'slog_totalAssets_USD',
    'slog_scope_1_2_emissions_amount'
]
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
all_model_vars = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_opt = train_df.dropna(subset=all_model_vars).copy()
test_df_opt = test_df.dropna(subset=all_model_vars).copy()

if test_df_opt.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the optimized mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_opt, groups=train_df_opt['account_id'])
        mdf_optimized = md.fit(reml=False)
    print(mdf_optimized.summary())

    # --- Predict on test set ---
    test_df_opt['predicted_log'] = mdf_optimized.predict(test_df_opt)
    test_df_opt['predicted'] = np.sign(test_df_opt['predicted_log']) * (np.expm1(np.abs(test_df_opt['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_opt[target_col_slog]
    y_pred_log = test_df_opt['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_opt['predicted']

    # Mask for valid/finites
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <-- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nOptimized Mixed-Effects Model: Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf_optimized.params,
        'pvalue': mdf_optimized.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Optimized Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Optimized Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Optimized Model Predicted")
    plt.xscale("log")
    plt.title("Optimized Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    optimized_model_metrics = {
        "Model": "Optimized",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                                                    Mixed Linear Model Regression Results
# ============================================================================================================================================================================
# Model:                                             MixedLM                                 Dependent Variable:                                 slog_Scope_3_emissions_amount
# No. Observations:                                  2218                                    Method:                                             ML
# No. Groups:                                        576                                     Scale:                                              0.8235
# Min. group size:                                   1                                       Log-Likelihood:                                     -3532.6803
# Max. group size:                                   5                                       Converged:                                          Yes
# Mean group size:                                   3.9
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                                                                   Coef.               Std.Err.         z    P>|z|         [0.025               0.975]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                              -129.849               29.897 -4.343 0.000              -188.447              -71.251
# C(Countries)[T.Austria]                                                                   3.894                1.217  3.200 0.001                 1.509                6.279
# C(Countries)[T.Belgium]                                                                   1.876                1.025  1.831 0.067                -0.133                3.885
# C(Countries)[T.Bermuda]                                                                  -1.001                2.034 -0.492 0.623                -4.987                2.985
# C(Countries)[T.Brazil]                                                                    0.632                1.009  0.627 0.531                -1.344                2.609
# C(Countries)[T.Canada]                                                                    0.589                0.719  0.819 0.413                -0.821                1.998
# C(Countries)[T.Chile]                                                                    -0.074                1.998 -0.037 0.971                -3.990                3.843
# C(Countries)[T.China]                                                                    -0.177                0.748 -0.237 0.813                -1.642                1.289
# C(Countries)[T.Denmark]                                                                   0.803                1.198  0.670 0.503                -1.545                3.152
# C(Countries)[T.Finland]                                                                  -0.348                0.717 -0.485 0.628                -1.752                1.057
# C(Countries)[T.France]                                                                    0.580                0.614  0.945 0.344                -0.623                1.784
# C(Countries)[T.Germany]                                                                   1.441                0.644  2.239 0.025                 0.179                2.702
# C(Countries)[T.Greece]                                                                    0.323                1.474  0.219 0.827                -2.566                3.211
# C(Countries)[T.Hungary]                                                                  -1.449                1.493 -0.971 0.332                -4.375                1.477
# C(Countries)[T.India]                                                                     0.754                1.501  0.503 0.615                -2.187                3.696
# C(Countries)[T.Ireland]                                                                  -0.052                0.950 -0.054 0.957                -1.913                1.810
# C(Countries)[T.Italy]                                                                     0.137                0.732  0.188 0.851                -1.298                1.572
# C(Countries)[T.Japan]                                                                     1.165                0.550  2.120 0.034                 0.088                2.242
# C(Countries)[T.Luxembourg]                                                 1932815475413182.250 2327977221288731.000  0.830 0.406 -2629936035142363.000 6495566985968727.000
# C(Countries)[T.Mexico]                                                                   -2.051                1.485 -1.381 0.167                -4.961                0.860
# C(Countries)[T.Netherlands]                                                               0.923                0.735  1.255 0.210                -0.518                2.364
# C(Countries)[T.New Zealand]                                                               0.352                0.960  0.367 0.714                -1.529                2.232
# C(Countries)[T.Norway]                                                                   -0.050                1.063 -0.047 0.963                -2.133                2.034
# C(Countries)[T.Portugal]                                                                 -0.809                2.063 -0.392 0.695                -4.853                3.235
# C(Countries)[T.Singapore]                                                                 2.966                1.682  1.763 0.078                -0.332                6.263
# C(Countries)[T.South Africa]                                                             -0.995                0.800 -1.244 0.214                -2.563                0.573
# C(Countries)[T.South Korea]                                                              -3.140                0.661 -4.751 0.000                -4.436               -1.845
# C(Countries)[T.Spain]                                                                     0.245                0.659  0.372 0.710                -1.046                1.536
# C(Countries)[T.Sweden]                                                                    0.539                1.117  0.483 0.629                -1.649                2.728
# C(Countries)[T.Switzerland]                                                              -0.096                0.687 -0.139 0.889                -1.442                1.251
# C(Countries)[T.Thailand]                                                                  0.614                1.012  0.607 0.544                -1.368                2.597
# C(Countries)[T.USA]                                                                       0.510                0.561  0.908 0.364                -0.590                1.610
# C(Countries)[T.United Kingdom]                                                            0.767                0.587  1.307 0.191                -0.383                1.918
# C(Primary_activity)[T.Accessories manufacture]                                            0.205                1.031  0.199 0.843                -1.815                2.225
# C(Primary_activity)[T.Agricultural chemicals]                                            -1.058                1.396 -0.758 0.448                -3.795                1.678
# C(Primary_activity)[T.Agriculture, construction & mining machinery]                       0.192                0.691  0.278 0.781                -1.162                1.546
# C(Primary_activity)[T.Alcoholic beverages]                                                0.195                0.608  0.320 0.749                -0.997                1.387
# C(Primary_activity)[T.Animal processing]                                                  0.685                1.007  0.680 0.496                -1.289                2.660
# C(Primary_activity)[T.Apparel & footwear design]                                          0.960                0.903  1.063 0.288                -0.810                2.729
# C(Primary_activity)[T.Apparel stores]                                                     0.278                0.659  0.422 0.673                -1.014                1.570
# C(Primary_activity)[T.Aquaculture]                                                        0.952                1.631  0.584 0.559                -2.245                4.150
# C(Primary_activity)[T.Asset managers]                                                    -1.702                0.792 -2.149 0.032                -3.254               -0.150
# C(Primary_activity)[T.Automobiles]                                                        1.065                0.654  1.629 0.103                -0.216                2.347
# C(Primary_activity)[T.Baked goods & cereals]                                              0.092                1.349  0.069 0.945                -2.551                2.736
# C(Primary_activity)[T.Banks]                                                             -1.001                0.432 -2.314 0.021                -1.848               -0.153
# C(Primary_activity)[T.Batteries]                                                         -0.469                0.975 -0.482 0.630                -2.380                1.441
# C(Primary_activity)[T.Biotechnology]                                                      0.021                0.615  0.034 0.973                -1.184                1.226
# C(Primary_activity)[T.Building sub-contractors]                                          -0.591                0.861 -0.686 0.492                -2.279                1.097
# C(Primary_activity)[T.CCGT generation]                                                    0.418                0.643  0.651 0.515                -0.842                1.678
# C(Primary_activity)[T.Cement]                                                             2.582                2.129  1.213 0.225                -1.592                6.756
# C(Primary_activity)[T.Clothing manufacture]                                              -0.095                0.870 -0.109 0.913                -1.800                1.610
# C(Primary_activity)[T.Coal generation]                                                    2.002                1.694  1.181 0.237                -1.319                5.322
# C(Primary_activity)[T.Commercial services]                                               -0.610                0.684 -0.892 0.372                -1.950                0.730
# C(Primary_activity)[T.Communications equipment]                                           0.055                0.529  0.105 0.917                -0.981                1.092
# C(Primary_activity)[T.Computer hardware]                                                  0.645                0.560  1.153 0.249                -0.452                1.742
# C(Primary_activity)[T.Consumer services]                                                 -0.909                1.357 -0.669 0.503                -3.569                1.752
# C(Primary_activity)[T.Dairy & egg products]                                               1.245                1.380  0.902 0.367                -1.461                3.950
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                                0.744                0.654  1.139 0.255                -0.537                2.025
# C(Primary_activity)[T.Department stores]                                                  0.264                0.996  0.265 0.791                -1.687                2.216
# C(Primary_activity)[T.Discretionary delivery retail]                                     -0.188                0.826 -0.228 0.820                -1.806                1.430
# C(Primary_activity)[T.Education services]                                                -0.703                1.402 -0.502 0.616                -3.451                2.045
# C(Primary_activity)[T.Electrical equipment]                                               0.878                0.454  1.934 0.053                -0.012                1.768
# C(Primary_activity)[T.Electricity networks]                                              -0.622                0.662 -0.939 0.348                -1.920                0.676
# C(Primary_activity)[T.Electronic components]                                              0.137                0.471  0.291 0.771                -0.787                1.061
# C(Primary_activity)[T.Electronic equipment]                                               0.505                0.420  1.200 0.230                -0.319                1.329
# C(Primary_activity)[T.Energy infrastructure construction]                                -3.422                1.136 -3.011 0.003                -5.650               -1.195
# C(Primary_activity)[T.Energy services & equipment]                                       -0.064                1.023 -0.063 0.950                -2.069                1.940
# C(Primary_activity)[T.Engineering services]                                              -0.056                1.073 -0.052 0.958                -2.160                2.047
# C(Primary_activity)[T.Engines & motors]                                                   1.339                0.522  2.564 0.010                 0.315                2.362
# C(Primary_activity)[T.Fabricated metal components]                                        1.047                0.540  1.939 0.053                -0.011                2.106
# C(Primary_activity)[T.Fast food]                                                         -0.266                1.149 -0.232 0.817                -2.519                1.986
# C(Primary_activity)[T.Finished wood products]                                             2.949                1.509  1.954 0.051                -0.008                5.906
# C(Primary_activity)[T.Food & beverage amenities]                                          2.219                1.390  1.596 0.110                -0.505                4.944
# C(Primary_activity)[T.Food & beverage wholesale]                                          0.242                1.064  0.227 0.820                -1.844                2.328
# C(Primary_activity)[T.Furniture]                                                          0.131                0.587  0.223 0.824                -1.019                1.281
# C(Primary_activity)[T.Gambling]                                                          -1.461                1.071 -1.364 0.173                -3.560                0.638
# C(Primary_activity)[T.Gas utilities]                                                      0.465                0.895  0.520 0.603                -1.288                2.219
# C(Primary_activity)[T.Glass products]                                                     1.089                0.999  1.089 0.276                -0.870                3.047
# C(Primary_activity)[T.Grain & corn milling]                                              -1.096                1.593 -0.688 0.492                -4.219                2.027
# C(Primary_activity)[T.Health care services]                                              -1.543                0.791 -1.951 0.051                -3.092                0.007
# C(Primary_activity)[T.Health care supplies]                                               0.077                0.680  0.114 0.910                -1.256                1.411
# C(Primary_activity)[T.Homeware]                                                           0.565                1.351  0.418 0.676                -2.082                3.212
# C(Primary_activity)[T.Hotels & lodging]                                                   1.000                0.580  1.726 0.084                -0.135                2.136
# C(Primary_activity)[T.Hydro generation]                                                  -5.608                1.813 -3.094 0.002                -9.161               -2.056
# C(Primary_activity)[T.Industrial machinery]                                              -0.313                0.429 -0.731 0.465                -1.153                0.527
# C(Primary_activity)[T.Inorganic base chemicals]                                           0.674                0.832  0.811 0.417                -0.956                2.305
# C(Primary_activity)[T.Insurance]                                                         -1.922                0.590 -3.257 0.001                -3.079               -0.765
# C(Primary_activity)[T.Intermodal transport]                                               0.303                1.400  0.216 0.829                -2.441                3.046
# C(Primary_activity)[T.Iron & steel]                                       -1932815475413180.750 2327977221288730.500 -0.830 0.406 -6495566985968725.000 2629936035142363.000
# C(Primary_activity)[T.Logging]                                                            0.071                1.412  0.050 0.960                -2.697                2.839
# C(Primary_activity)[T.Logistics - 3rd party]                                             -0.058                0.632 -0.091 0.927                -1.297                1.182
# C(Primary_activity)[T.Logistics - transport]                                             -0.061                1.421 -0.043 0.966                -2.847                2.724
# C(Primary_activity)[T.Marine freight]                                                    -0.112                0.809 -0.139 0.890                -1.698                1.473
# C(Primary_activity)[T.Marketing]                                                         -0.393                0.524 -0.750 0.453                -1.419                0.633
# C(Primary_activity)[T.Medical equipment]                                                 -0.088                0.607 -0.145 0.884                -1.277                1.101
# C(Primary_activity)[T.Metal containers & packaging]                                       1.542                0.704  2.188 0.029                 0.161                2.922
# C(Primary_activity)[T.Metal processing]                                                   0.999                1.033  0.967 0.334                -1.026                3.023
# C(Primary_activity)[T.Non-CCGT generation]                                                1.177                1.425  0.826 0.409                -1.617                3.971
# C(Primary_activity)[T.Non-alcoholic beverages]                                            0.908                0.759  1.197 0.231                -0.579                2.396
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                                        1.457                1.277  1.141 0.254                -1.046                3.961
# C(Primary_activity)[T.Non-residential building construction]                             -0.878                0.490 -1.794 0.073                -1.838                0.081
# C(Primary_activity)[T.Oil & gas extraction]                                              -0.276                1.150 -0.240 0.810                -2.530                1.978
# C(Primary_activity)[T.Oil & gas marketing & retailing]                                    0.777                1.201  0.647 0.517                -1.576                3.131
# C(Primary_activity)[T.Oil & gas pipelines & storage]                                      0.039                0.905  0.043 0.965                -1.735                1.814
# C(Primary_activity)[T.Other base chemicals]                                               0.419                0.404  1.037 0.300                -0.373                1.212
# C(Primary_activity)[T.Other containers & packaging]                                       1.204                1.057  1.140 0.254                -0.867                3.275
# C(Primary_activity)[T.Other food processing]                                              0.939                0.560  1.677 0.094                -0.158                2.037
# C(Primary_activity)[T.Other non-ferrous ore mining]                                       0.469                0.943  0.497 0.619                -1.380                2.318
# C(Primary_activity)[T.Other professional services]                                       -0.261                0.432 -0.605 0.545                -1.108                0.585
# C(Primary_activity)[T.Other renewable energy equipment]                                  -0.238                1.776 -0.134 0.893                -3.719                3.242
# C(Primary_activity)[T.Other renewable generation]                                         2.719                2.442  1.114 0.265                -2.066                7.504
# C(Primary_activity)[T.Paper products]                                                     0.899                0.602  1.495 0.135                -0.280                2.078
# C(Primary_activity)[T.Passenger airlines]                                                 0.668                0.624  1.071 0.284                -0.555                1.892
# C(Primary_activity)[T.Passenger rail]                                                     1.784                1.407  1.268 0.205                -0.974                4.542
# C(Primary_activity)[T.Personal care & household products]                                 0.396                0.437  0.906 0.365                -0.461                1.254
# C(Primary_activity)[T.Pharmaceuticals]                                                   -0.123                0.415 -0.296 0.767                -0.937                0.691
# C(Primary_activity)[T.Plastic products]                                                  -0.124                0.579 -0.215 0.830                -1.258                1.010
# C(Primary_activity)[T.Precious metals & minerals mining]                                 -1.252                0.883 -1.417 0.156                -2.983                0.479
# C(Primary_activity)[T.Print publishing]                                                  -2.081                1.412 -1.474 0.141                -4.848                0.687
# C(Primary_activity)[T.Printing services]                                                  0.485                0.986  0.492 0.623                -1.448                2.418
# C(Primary_activity)[T.Pulp & paper mills]                                                 0.671                1.102  0.609 0.543                -1.489                2.831
# C(Primary_activity)[T.REIT]                                                               0.361                0.613  0.589 0.556                -0.841                1.563
# C(Primary_activity)[T.Rail freight]                                                       1.475                0.689  2.140 0.032                 0.124                2.827
# C(Primary_activity)[T.Railroad rolling stock]                                            -0.458                1.457 -0.314 0.753                -3.313                2.397
# C(Primary_activity)[T.Real estate owners & developers]                                    0.797                0.913  0.872 0.383                -0.993                2.586
# C(Primary_activity)[T.Real estate services]                                              -3.742                1.047 -3.573 0.000                -5.795               -1.689
# C(Primary_activity)[T.Residential building construction]                                 -0.525                0.691 -0.759 0.448                -1.880                0.830
# C(Primary_activity)[T.Rubber products]                                                    1.040                0.788  1.321 0.187                -0.504                2.584
# C(Primary_activity)[T.Semiconductors]                                                     0.393                0.846  0.465 0.642                -1.264                2.051
# C(Primary_activity)[T.Servers & data centers]                                             1.223                1.030  1.188 0.235                -0.796                3.242
# C(Primary_activity)[T.Software]                                                           0.063                0.607  0.104 0.917                -1.126                1.252
# C(Primary_activity)[T.Solar energy equipment]                                             2.502                1.414  1.769 0.077                -0.270                5.273
# C(Primary_activity)[T.Specialist retail]                                                  0.409                0.910  0.449 0.654                -1.376                2.193
# C(Primary_activity)[T.Specialty chemicals]                                                0.095                0.160  0.593 0.553                -0.219                0.408
# C(Primary_activity)[T.Supermarkets, food & drugstores]                                    1.170                0.455  2.569 0.010                 0.277                2.062
# C(Primary_activity)[T.Telecommunications services]                                        1.379                0.372  3.704 0.000                 0.649                2.108
# C(Primary_activity)[T.Textiles]                                                          -0.056                1.525 -0.037 0.971                -3.046                2.933
# C(Primary_activity)[T.Tobacco products]                                                  -0.480                0.768 -0.625 0.532                -1.984                1.025
# C(Primary_activity)[T.Transportation infrastructure & other construction]                 1.730                0.659  2.625 0.009                 0.438                3.021
# C(Primary_activity)[T.Transportation support services]                                    2.839                1.444  1.966 0.049                 0.009                5.669
# C(Primary_activity)[T.Travel services]                                                   -0.403                1.450 -0.278 0.781                -3.246                2.440
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]                             -0.621                0.802 -0.774 0.439                -2.192                0.950
# C(Primary_activity)[T.Waste management]                                                   2.154                1.033  2.084 0.037                 0.128                4.179
# C(Primary_activity)[T.Water supply networks]                                              0.842                0.863  0.976 0.329                -0.849                2.533
# C(Primary_activity)[T.Wind generation]                                                    0.667                1.492  0.447 0.655                -2.256                3.591
# C(Primary_activity)[T.Wood furniture]                                                    -0.449                1.408 -0.319 0.750                -3.208                2.310
# slog_Market_Cap_USD                                                                       0.226                0.050  4.520 0.000                 0.128                0.324
# slog_Revenue_USD                                                                          0.138                0.044  3.126 0.002                 0.052                0.225
# slog_totalAssets_USD                                                                      0.137                0.036  3.811 0.000                 0.067                0.208
# slog_scope_1_2_emissions_amount                                                           0.175                0.034  5.135 0.000                 0.108                0.242
# Year                                                                                      0.062                0.015  4.221 0.000                 0.033                0.092
# Group Var                                                                                 1.675                0.173
# ============================================================================================================================================================================
#
#
# Optimized Mixed-Effects Model: Test Set Performance Metrics:
# R²(log):    53.96%
# R²(orig):   26.94%
# MAPE:       300.85%
# MAPE(log):  10.57%
# MAE(log):   1.01
# RMSLE:      1.38
# RMSE:       459329.58
# MAE:        194926.26
#
# Top Influential Features (by p-value):
#                                                         coef        pvalue
# Group Var                                           2.034110  1.133075e-26
# slog_scope_1_2_emissions_amount                     0.175154  2.822501e-07
# C(Countries)[T.South Korea]                        -3.140194  2.021648e-06
# slog_Market_Cap_USD                                 0.225967  6.198484e-06
# Year                                                0.062500  2.435660e-05
# slog_totalAssets_USD                                0.137399  1.381947e-04
# C(Primary_activity)[T.Telecommunications services]  1.378853  2.120677e-04
# C(Primary_activity)[T.Real estate services]        -3.742397  3.530468e-04
# C(Primary_activity)[T.Insurance]                   -1.922331  1.126884e-03
# C(Countries)[T.Austria]                             3.894103  1.372835e-03
#
# All feature coefficients sorted by absolute value:
#                                                             coef    pvalue
# C(Countries)[T.Luxembourg]                          1.932815e+15  0.406394
# C(Primary_activity)[T.Iron & steel]                -1.932815e+15  0.406394
# C(Primary_activity)[T.Hydro generation]            -5.608214e+00  0.001974
# C(Countries)[T.Austria]                             3.894103e+00  0.001373
# C(Primary_activity)[T.Real estate services]        -3.742397e+00  0.000353
# ...                                                          ...       ...
# C(Primary_activity)[T.Communications equipment]     5.538442e-02  0.916597
# C(Countries)[T.Ireland]                            -5.162360e-02  0.956660
# C(Countries)[T.Norway]                             -4.994407e-02  0.962527
# C(Primary_activity)[T.Oil & gas pipelines & sto...  3.924398e-02  0.965422
# C(Primary_activity)[T.Biotechnology]                2.076159e-02  0.973061
#
# [151 rows x 2 columns]

# %%
metrics_text_log = (
    f"R²(log):   {r2_log_pct:.2f}%\n"
    f"R²(orig):  {r2_pct:.2f}%\n"
    f"MAPE:      {mape_orig:.2f}%\n"
    f"MAPE(log): {mape_log:.2f}%\n"
    f"MAE(log):  {mae_log:.2f}\n"
    f"RMSLE:     {rmsle:.2f}\n"
    f"RMSE:      {rmse_orig:.2f}\n"
    f"MAE:       {mae_orig:.2f}"
)

fig, ax = plt.subplots(figsize=(9.5, 6))  # Wider to make room for the box

if hasattr(y_pred_log, "nunique"):
    multiple_vals = y_pred_log.nunique() > 1
else:
    multiple_vals = len(set(y_pred_log)) > 1

if multiple_vals:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=ax, color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    ax.plot([], [], ' ', label="Predicted: constant value (no KDE)")

ax.set_title("Capital Goods Optimized Model: signed log(Scope 3 Emissions)")
ax.set_xlabel("signed log(metric tons + 1)")
ax.set_ylabel("Density")
ax.legend()

# Place metrics box outside plot to the right
fig.text(
    0.82, 0.75, metrics_text_log,
    va='top', ha='left',
    fontsize=12, bbox=dict(boxstyle='round', alpha=0.15)
)

plt.subplots_adjust(right=0.8)  # Make sure there's room for the box
fig.savefig("capital_goods_scope3_log_density.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Metrics Table for Capital Goods

# %%
metrics_dicts = [
    null_model_metrics,
    two_level_model_metrics,
    three_level_model_metrics,
    full_model_metrics,
    optimized_model_metrics
]

for metrics, train, test in zip(
        metrics_dicts,
        [train_df, train_df, train_df, train_df, train_df],
        [test_df, test_df, test_df, test_df, test_df]):
    
    metrics["# Obs (train)"] = len(train)
    metrics["# Obs (test)"] = len(test)
    metrics["# Obs (train/test)"] = f"{len(train)}/{len(test)}"

metrics_df = pd.DataFrame(metrics_dicts)

# Ensure all relevant columns are ordered and present
desired_order = [
    "Model", "R2_log", "R2_orig", "RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "# Obs (train/test)"
]


# Ensure MAE_log is present, fill with NaN if missing
if "MAE_log" not in metrics_df.columns:
    metrics_df["MAE_log"] = np.nan

metrics_df = metrics_df[[col for col in desired_order if col in metrics_df.columns]]

metrics_df_display = metrics_df.copy()
if "R2_log" in metrics_df_display.columns:
    metrics_df_display["R2_log"] = (metrics_df_display["R2_log"] * 100).map("{:.2f}%".format)
if "R2_orig" in metrics_df_display.columns:
    metrics_df_display["R2_orig"] = (metrics_df_display["R2_orig"] * 100).map("{:.2f}%".format)
for col in ["RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "MAPE(log)"]:
    if col in metrics_df_display.columns:
        metrics_df_display[col] = metrics_df_display[col].map("{:.2f}".format)

from IPython.display import display
display(metrics_df_display)
# Out:
#                                      Model  R2_log  R2_orig       RMSE  \
# 0                                Null (RI)  -2.27%  -18.07%  583922.63
# 1                           2-level (RI+S)  -2.47%  -18.18%  584192.27
# 2  3-level (Primary Activity/Account/Year)  31.33%   -1.31%  540886.84
# 3                               Full Model  54.54%   29.16%  452287.59
# 4                                Optimized  53.96%   26.94%  459329.58
#
#          MAE MAE_log RMSLE     MAPE # Obs (train/test)
# 0  253972.60    1.63  2.06  2733.76           2218/505
# 1  254150.72    1.63  2.06  2697.38           2218/505
# 2  225163.02    1.28  1.69  2288.51           2218/505
# 3  189927.15    1.00  1.37   260.93           2218/505
# 4  194926.26    1.01  1.38   300.85           2218/505
