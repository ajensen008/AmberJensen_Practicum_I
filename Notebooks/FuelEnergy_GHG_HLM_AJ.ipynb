# %% [markdown]
# # GHG HLM on Scope 3 source Fuel Energy

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_log_error, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GroupShuffleSplit
from scipy.stats import zscore
import scipy.stats as stats
from sklearn.feature_selection import mutual_info_regression
from sklearn.impute import SimpleImputer
import warnings
from statsmodels.regression.mixed_linear_model import MixedLM


#read in dataset GHG_post_outliers data set
fuel_energy=pd.read_csv('/Users/amberjensen/Desktop/GHG_Emissions_Project/fuel_energy.csv')

# %%
#check for info
fuel_energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4703 entries, 0 to 4702
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_name                4703 non-null   object
#  1   account_id                  4703 non-null   int64
#  2   Year                        4703 non-null   int64
#  3   incorporated_country        4703 non-null   object
#  4   Primary activity            4703 non-null   object
#  5   Primary sector              4703 non-null   object
#  6   Market_Cap_USD              4038 non-null   float64
#  7   Third_party_verification    4700 non-null   object
#  8   Revenue_USD                 4060 non-null   float64
#  9   ebitda_USD                  4060 non-null   float64
#  10  grossProfit_USD             4060 non-null   float64
#  11  netIncome_USD               4060 non-null   float64
#  12  cashAndCashEquivalents_USD  4060 non-null   float64
#  13  shortTermInvestments_USD    4060 non-null   float64
#  14  longTermInvestments_USD     4060 non-null   float64
#  15  totalAssets_USD             4060 non-null   float64
#  16  totalLiabilities_USD        4060 non-null   float64
#  17  totalInvestments_USD        4060 non-null   float64
#  18  totalDebt_USD               4060 non-null   float64
#  19  totalEquity_USD             4060 non-null   float64
#  20  Scope_3_emissions_type      4703 non-null   object
#  21  Scope_3_emissions_amount    4703 non-null   float64
#  22  scope_1_2_emissions_amount  4694 non-null   float64
#  23  Year_sq                     4703 non-null   int64
# dtypes: float64(15), int64(3), object(6)
# memory usage: 881.9+ KB

# %%
#show a df for fuel_energy
fuel_energy.head()
# Out:
#                account_name  account_id  Year incorporated_country  \
# 0                  3i Group          44  2018       United Kingdom
# 1                     abrdn       17604  2018       United Kingdom
# 2                     Aptiv        4407  2018       United Kingdom
# 3                  Arm Ltd.         950  2018       United Kingdom
# 4  Associated British Foods        1085  2018       United Kingdom
#
#         Primary activity                     Primary sector  Market_Cap_USD  \
# 0         Asset managers                 Financial services    9.548124e+09
# 1              Insurance                 Financial services    1.019344e+10
# 2   Electrical equipment  Electrical & electronic equipment    1.595156e+10
# 3  Electronic components  Electrical & electronic equipment             NaN
# 4         Apparel stores               Discretionary retail    2.051429e+10
#
#                             Third_party_verification   Revenue_USD  \
# 0  Third-party verification or assurance process ...  1.728470e+09
# 1  Third-party verification or assurance process ...  2.912110e+09
# 2           No third-party verification or assurance  1.443500e+10
# 3           No third-party verification or assurance           NaN
# 4  Third-party verification or assurance process ...  1.977898e+10
#
#      ebitda_USD  ...  longTermInvestments_USD  totalAssets_USD  \
# 0  1.565910e+09  ...             8.544560e+09     1.107567e+10
# 1  1.482090e+09  ...             6.626860e+09     1.589659e+10
# 2  2.260000e+09  ...             9.900000e+07     1.248000e+10
# 3           NaN  ...                      NaN              NaN
# 4  2.363470e+09  ...             3.429000e+08     1.738884e+10
#
#    totalLiabilities_USD  totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0          1.031240e+09          8.544560e+09   7.302500e+08     1.004443e+10
# 1          6.322060e+09          6.626860e+09   1.647190e+09     9.574530e+09
# 2          8.810000e+09          1.710000e+08   4.344000e+09     3.670000e+09
# 3                   NaN                   NaN            NaN              NaN
# 4          5.582920e+09          3.810000e+08   9.880600e+08     1.180592e+10
#
#                               Scope_3_emissions_type  \
# 0  Fuel-and-energy-related activities (not includ...
# 1  Fuel-and-energy-related activities (not includ...
# 2  Fuel-and-energy-related activities (not includ...
# 3  Fuel-and-energy-related activities (not includ...
# 4  Fuel-and-energy-related activities (not includ...
#
#    Scope_3_emissions_amount  scope_1_2_emissions_amount  Year_sq
# 0                     61.42                3.389500e+02  4072324
# 1                   1373.00                7.197250e+03  4072324
# 2                 103000.00                3.804718e+05  4072324
# 3                   2078.37                7.728538e+03  4072324
# 4                 452806.00                2.801746e+06  4072324
#
# [5 rows x 24 columns]

# %%
#define a list of numeric columns
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD',
       'grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD',
       'shortTermInvestments_USD', 'longTermInvestments_USD',
       'totalAssets_USD', 'totalLiabilities_USD', 'totalInvestments_USD',
       'totalDebt_USD', 'totalEquity_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount']

# %%
#plot the heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(fuel_energy[numeric_cols].corr(), annot=True, annot_kws={"size": 8})
plt.show()

# %%
#correlation matrix
fuel_energy[numeric_cols].corr()
# Out:
#                             Market_Cap_USD  Revenue_USD  ebitda_USD  \
# Market_Cap_USD                    1.000000     0.227229    0.339798
# Revenue_USD                       0.227229     1.000000    0.674444
# ebitda_USD                        0.339798     0.674444    1.000000
# grossProfit_USD                   0.247327     0.782438    0.681668
# netIncome_USD                     0.373637     0.614255    0.862071
# cashAndCashEquivalents_USD        0.064678     0.226995    0.292809
# shortTermInvestments_USD          0.090538     0.297599    0.264763
# longTermInvestments_USD           0.059017     0.286328    0.300011
# totalAssets_USD                   0.090467     0.350800    0.403012
# totalLiabilities_USD              0.078677     0.328318    0.367692
# totalInvestments_USD              0.076098     0.298434    0.314450
# totalDebt_USD                     0.115267     0.422785    0.498604
# totalEquity_USD                   0.201390     0.562751    0.680764
# Scope_3_emissions_amount         -0.000468     0.080817    0.074901
# scope_1_2_emissions_amount        0.000086     0.102783    0.084367
#
#                             grossProfit_USD  netIncome_USD  \
# Market_Cap_USD                     0.247327       0.373637
# Revenue_USD                        0.782438       0.614255
# ebitda_USD                         0.681668       0.862071
# grossProfit_USD                    1.000000       0.698176
# netIncome_USD                      0.698176       1.000000
# cashAndCashEquivalents_USD         0.391315       0.365567
# shortTermInvestments_USD           0.524176       0.355657
# longTermInvestments_USD            0.532961       0.386811
# totalAssets_USD                    0.570266       0.468479
# totalLiabilities_USD               0.544762       0.442734
# totalInvestments_USD               0.541939       0.405623
# totalDebt_USD                      0.540686       0.491227
# totalEquity_USD                    0.714150       0.678286
# Scope_3_emissions_amount           0.003976       0.011396
# scope_1_2_emissions_amount         0.005762       0.025675
#
#                             cashAndCashEquivalents_USD  \
# Market_Cap_USD                                0.064678
# Revenue_USD                                   0.226995
# ebitda_USD                                    0.292809
# grossProfit_USD                               0.391315
# netIncome_USD                                 0.365567
# cashAndCashEquivalents_USD                    1.000000
# shortTermInvestments_USD                      0.423169
# longTermInvestments_USD                       0.755971
# totalAssets_USD                               0.856585
# totalLiabilities_USD                          0.822124
# totalInvestments_USD                          0.717829
# totalDebt_USD                                 0.758641
# totalEquity_USD                               0.675081
# Scope_3_emissions_amount                     -0.028478
# scope_1_2_emissions_amount                   -0.030523
#
#                             shortTermInvestments_USD  longTermInvestments_USD  \
# Market_Cap_USD                              0.090538                 0.059017
# Revenue_USD                                 0.297599                 0.286328
# ebitda_USD                                  0.264763                 0.300011
# grossProfit_USD                             0.524176                 0.532961
# netIncome_USD                               0.355657                 0.386811
# cashAndCashEquivalents_USD                  0.423169                 0.755971
# shortTermInvestments_USD                    1.000000                 0.723703
# longTermInvestments_USD                     0.723703                 1.000000
# totalAssets_USD                             0.629940                 0.912843
# totalLiabilities_USD                        0.642006                 0.881291
# totalInvestments_USD                        0.797375                 0.965113
# totalDebt_USD                               0.433356                 0.705808
# totalEquity_USD                             0.568023                 0.731172
# Scope_3_emissions_amount                   -0.028162                -0.037553
# scope_1_2_emissions_amount                 -0.033879                -0.043101
#
#                             totalAssets_USD  totalLiabilities_USD  \
# Market_Cap_USD                     0.090467              0.078677
# Revenue_USD                        0.350800              0.328318
# ebitda_USD                         0.403012              0.367692
# grossProfit_USD                    0.570266              0.544762
# netIncome_USD                      0.468479              0.442734
# cashAndCashEquivalents_USD         0.856585              0.822124
# shortTermInvestments_USD           0.629940              0.642006
# longTermInvestments_USD            0.912843              0.881291
# totalAssets_USD                    1.000000              0.967376
# totalLiabilities_USD               0.967376              1.000000
# totalInvestments_USD               0.881087              0.857381
# totalDebt_USD                      0.844064              0.824789
# totalEquity_USD                    0.826443              0.786268
# Scope_3_emissions_amount          -0.007033             -0.010268
# scope_1_2_emissions_amount        -0.014051             -0.020219
#
#                             totalInvestments_USD  totalDebt_USD  \
# Market_Cap_USD                          0.076098       0.115267
# Revenue_USD                             0.298434       0.422785
# ebitda_USD                              0.314450       0.498604
# grossProfit_USD                         0.541939       0.540686
# netIncome_USD                           0.405623       0.491227
# cashAndCashEquivalents_USD              0.717829       0.758641
# shortTermInvestments_USD                0.797375       0.433356
# longTermInvestments_USD                 0.965113       0.705808
# totalAssets_USD                         0.881087       0.844064
# totalLiabilities_USD                    0.857381       0.824789
# totalInvestments_USD                    1.000000       0.679061
# totalDebt_USD                           0.679061       1.000000
# totalEquity_USD                         0.724252       0.792225
# Scope_3_emissions_amount               -0.035833       0.071386
# scope_1_2_emissions_amount             -0.042116       0.054703
#
#                             totalEquity_USD  Scope_3_emissions_amount  \
# Market_Cap_USD                     0.201390                 -0.000468
# Revenue_USD                        0.562751                  0.080817
# ebitda_USD                         0.680764                  0.074901
# grossProfit_USD                    0.714150                  0.003976
# netIncome_USD                      0.678286                  0.011396
# cashAndCashEquivalents_USD         0.675081                 -0.028478
# shortTermInvestments_USD           0.568023                 -0.028162
# longTermInvestments_USD            0.731172                 -0.037553
# totalAssets_USD                    0.826443                 -0.007033
# totalLiabilities_USD               0.786268                 -0.010268
# totalInvestments_USD               0.724252                 -0.035833
# totalDebt_USD                      0.792225                  0.071386
# totalEquity_USD                    1.000000                  0.062560
# Scope_3_emissions_amount           0.062560                  1.000000
# scope_1_2_emissions_amount         0.088879                  0.507761
#
#                             scope_1_2_emissions_amount
# Market_Cap_USD                                0.000086
# Revenue_USD                                   0.102783
# ebitda_USD                                    0.084367
# grossProfit_USD                               0.005762
# netIncome_USD                                 0.025675
# cashAndCashEquivalents_USD                   -0.030523
# shortTermInvestments_USD                     -0.033879
# longTermInvestments_USD                      -0.043101
# totalAssets_USD                              -0.014051
# totalLiabilities_USD                         -0.020219
# totalInvestments_USD                         -0.042116
# totalDebt_USD                                 0.054703
# totalEquity_USD                               0.088879
# Scope_3_emissions_amount                      0.507761
# scope_1_2_emissions_amount                    1.000000

# %%
#drop columns due to collinearity, keeping total
fuel_energy=fuel_energy.drop(columns=['grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD',
                                      'longTermInvestments_USD', 'shortTermInvestments_USD', "account_name", "Third_party_verification", "Scope_3_emissions_type"])

# %%
fuel_energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4703 entries, 0 to 4702
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  4703 non-null   int64
#  1   Year                        4703 non-null   int64
#  2   incorporated_country        4703 non-null   object
#  3   Primary activity            4703 non-null   object
#  4   Primary sector              4703 non-null   object
#  5   Market_Cap_USD              4038 non-null   float64
#  6   Revenue_USD                 4060 non-null   float64
#  7   ebitda_USD                  4060 non-null   float64
#  8   totalAssets_USD             4060 non-null   float64
#  9   totalLiabilities_USD        4060 non-null   float64
#  10  totalInvestments_USD        4060 non-null   float64
#  11  totalDebt_USD               4060 non-null   float64
#  12  totalEquity_USD             4060 non-null   float64
#  13  Scope_3_emissions_amount    4703 non-null   float64
#  14  scope_1_2_emissions_amount  4694 non-null   float64
#  15  Year_sq                     4703 non-null   int64
# dtypes: float64(10), int64(3), object(3)
# memory usage: 588.0+ KB

# %%
sns.boxplot(fuel_energy)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# copy dataframe
fuel_energy_no_transform = fuel_energy.copy()
# Change 'incorporated_country' to 'Countries' in fuel_energy dataframe
fuel_energy_no_transform = fuel_energy_no_transform.rename(columns={'incorporated_country': 'Countries',
                                                       'Primary activity': 'Primary_activity',
                                                        'Primary sector': 'Primary_sector'})

print(fuel_energy_no_transform.info())
fuel_energy_no_transform.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4703 entries, 0 to 4702
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  4703 non-null   int64
#  1   Year                        4703 non-null   int64
#  2   Countries                   4703 non-null   object
#  3   Primary_activity            4703 non-null   object
#  4   Primary_sector              4703 non-null   object
#  5   Market_Cap_USD              4038 non-null   float64
#  6   Revenue_USD                 4060 non-null   float64
#  7   ebitda_USD                  4060 non-null   float64
#  8   totalAssets_USD             4060 non-null   float64
#  9   totalLiabilities_USD        4060 non-null   float64
#  10  totalInvestments_USD        4060 non-null   float64
#  11  totalDebt_USD               4060 non-null   float64
#  12  totalEquity_USD             4060 non-null   float64
#  13  Scope_3_emissions_amount    4703 non-null   float64
#  14  scope_1_2_emissions_amount  4694 non-null   float64
#  15  Year_sq                     4703 non-null   int64
# dtypes: float64(10), int64(3), object(3)
# memory usage: 588.0+ KB
# None
#    account_id  Year       Countries       Primary_activity  \
# 0          44  2018  United Kingdom         Asset managers
# 1       17604  2018  United Kingdom              Insurance
# 2        4407  2018  United Kingdom   Electrical equipment
# 3         950  2018  United Kingdom  Electronic components
# 4        1085  2018  United Kingdom         Apparel stores
#
#                       Primary_sector  Market_Cap_USD   Revenue_USD  \
# 0                 Financial services    9.548124e+09  1.728470e+09
# 1                 Financial services    1.019344e+10  2.912110e+09
# 2  Electrical & electronic equipment    1.595156e+10  1.443500e+10
# 3  Electrical & electronic equipment             NaN           NaN
# 4               Discretionary retail    2.051429e+10  1.977898e+10
#
#      ebitda_USD  totalAssets_USD  totalLiabilities_USD  totalInvestments_USD  \
# 0  1.565910e+09     1.107567e+10          1.031240e+09          8.544560e+09
# 1  1.482090e+09     1.589659e+10          6.322060e+09          6.626860e+09
# 2  2.260000e+09     1.248000e+10          8.810000e+09          1.710000e+08
# 3           NaN              NaN                   NaN                   NaN
# 4  2.363470e+09     1.738884e+10          5.582920e+09          3.810000e+08
#
#    totalDebt_USD  totalEquity_USD  Scope_3_emissions_amount  \
# 0   7.302500e+08     1.004443e+10                     61.42
# 1   1.647190e+09     9.574530e+09                   1373.00
# 2   4.344000e+09     3.670000e+09                 103000.00
# 3            NaN              NaN                   2078.37
# 4   9.880600e+08     1.180592e+10                 452806.00
#
#    scope_1_2_emissions_amount  Year_sq
# 0                3.389500e+02  4072324
# 1                7.197250e+03  4072324
# 2                3.804718e+05  4072324
# 3                7.728538e+03  4072324
# 4                2.801746e+06  4072324

# %%
fuel_energy_no_transform['Primary_sector'].value_counts()
# Out:
# Primary_sector
# Financial services                                    609
# Electrical & electronic equipment                     460
# Chemicals                                             395
# Food & beverage processing                            227
# Construction                                          219
# Media, telecommunications & data center services      185
# Specialized professional services                     179
# Biotech & pharma                                      171
# Powered machinery                                     132
# Thermal power generation                              121
# Discretionary retail                                  120
# Energy utility networks                               115
# Convenience retail                                    103
# Trading, wholesale, distribution, rental & leasing     94
# Medical equipment & supplies                           93
# Metal products manufacturing                           72
# Bars, hotels & restaurants                             67
# Paper products & packaging                             65
# IT & software development                              60
# Air transport                                          58
# Commercial & consumer services                         58
# Other services                                         56
# Leisure & home manufacturing                           54
# Intermodal transport & logistics                       54
# Plastic product manufacturing                          51
# Metal smelting, refining & forming                     49
# Transportation equipment                               49
# 0                                                      48
# Web & marketing services                               46
# Land & property ownership & development                46
# Print & publishing services                            45
# Cement & concrete                                      45
# Metallic mineral mining                                44
# Wood & paper materials                                 38
# Wood & rubber products                                 35
# Rail transport                                         35
# Textiles & fabric goods                                34
# Light manufacturing                                    32
# Industrial support services                            31
# Non-energy utilities                                   31
# Other materials                                        30
# Marine transport                                       30
# Fish & animal farming                                  26
# Tobacco                                                25
# Oil & gas extraction & production                      20
# Apparel design                                         20
# Health care provision                                  20
# Entertainment facilities                               19
# Oil & gas storage & transportation                     19
# Renewable power generation                             15
# Road transport                                         12
# Oil & gas retailing                                    10
# Accessories                                            10
# Renewable energy equipment                             10
# Logging & rubber tapping                                6
# Oil & gas processing                                    5
# Name: count, dtype: int64

# %%
fuel_energy_no_transform['Primary_activity'].value_counts().head(20)
# Out:
# Primary_activity
# Banks                                                 267
# Electronic components                                 172
# Insurance                                             172
# Telecommunications services                           171
# Other professional services                           161
# Pharmaceuticals                                       135
# Other base chemicals                                  122
# Specialty chemicals                                   120
# CCGT generation                                       108
# REIT                                                  105
# Supermarkets, food & drugstores                       103
# Electrical equipment                                  100
# Electricity networks                                   86
# Personal care & household products                     85
# Electronic equipment                                   77
# Other food processing                                  76
# Transportation infrastructure & other construction     71
# Asset managers                                         65
# Paper products                                         65
# Alcoholic beverages                                    64
# Name: count, dtype: int64

# %%
# Looking at missing data
print(fuel_energy_no_transform.isnull().mean().sort_values(ascending=False).round(3) * 100)
# Out:
# Market_Cap_USD                14.1
# Revenue_USD                   13.7
# ebitda_USD                    13.7
# totalAssets_USD               13.7
# totalLiabilities_USD          13.7
# totalInvestments_USD          13.7
# totalDebt_USD                 13.7
# totalEquity_USD               13.7
# scope_1_2_emissions_amount     0.2
# account_id                     0.0
# Year                           0.0
# Countries                      0.0
# Primary_activity               0.0
# Primary_sector                 0.0
# Scope_3_emissions_amount       0.0
# Year_sq                        0.0
# dtype: float64

# %% [markdown]
# Apply signed log transformation and split data by company and year into train_df (2018-2022) and test_df (2023):

# %%
numeric_cols = ['Market_Cap_USD',
    'Revenue_USD',
    'totalAssets_USD',
    'totalLiabilities_USD',
    'totalInvestments_USD',
    'totalDebt_USD',
    'totalEquity_USD',
    'ebitda_USD',
    'Scope_3_emissions_amount',
    'scope_1_2_emissions_amount'
]
required_cols = [
    'account_id', 'Year', 'Year_sq', 'Countries', 'Primary_activity', 'Primary_sector'
] + numeric_cols

# --- Prepare Data ---
df = fuel_energy_no_transform[required_cols].dropna()

# --- Signed log transform ---
def signed_log(x):
    return np.sign(x) * np.log(np.abs(x) + 1)

for col in numeric_cols:
    df[f'slog_{col}'] = signed_log(df[col])

# --- Company-level split by year ---
train_df = df[df['Year'].between(2018, 2022)].copy()
test_df  = df[df['Year'] == 2023].copy()

# Keep only companies present in training
valid_companies = set(train_df['account_id'].unique())
test_df = test_df[test_df['account_id'].isin(valid_companies)].copy()

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (3242, 26)
# Test shape: (679, 26)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3242 entries, 0 to 3793
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       3242 non-null   int64
#  1   Year                             3242 non-null   int64
#  2   Year_sq                          3242 non-null   int64
#  3   Countries                        3242 non-null   object
#  4   Primary_activity                 3242 non-null   object
#  5   Primary_sector                   3242 non-null   object
#  6   Market_Cap_USD                   3242 non-null   float64
#  7   Revenue_USD                      3242 non-null   float64
#  8   totalAssets_USD                  3242 non-null   float64
#  9   totalLiabilities_USD             3242 non-null   float64
#  10  totalInvestments_USD             3242 non-null   float64
#  11  totalDebt_USD                    3242 non-null   float64
#  12  totalEquity_USD                  3242 non-null   float64
#  13  ebitda_USD                       3242 non-null   float64
#  14  Scope_3_emissions_amount         3242 non-null   float64
#  15  scope_1_2_emissions_amount       3242 non-null   float64
#  16  slog_Market_Cap_USD              3242 non-null   float64
#  17  slog_Revenue_USD                 3242 non-null   float64
#  18  slog_totalAssets_USD             3242 non-null   float64
#  19  slog_totalLiabilities_USD        3242 non-null   float64
#  20  slog_totalInvestments_USD        3242 non-null   float64
#  21  slog_totalDebt_USD               3242 non-null   float64
#  22  slog_totalEquity_USD             3242 non-null   float64
#  23  slog_ebitda_USD                  3242 non-null   float64
#  24  slog_Scope_3_emissions_amount    3242 non-null   float64
#  25  slog_scope_1_2_emissions_amount  3242 non-null   float64
# dtypes: float64(20), int64(3), object(3)
# memory usage: 683.9+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 679 entries, 3797 to 4700
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       679 non-null    int64
#  1   Year                             679 non-null    int64
#  2   Year_sq                          679 non-null    int64
#  3   Countries                        679 non-null    object
#  4   Primary_activity                 679 non-null    object
#  5   Primary_sector                   679 non-null    object
#  6   Market_Cap_USD                   679 non-null    float64
#  7   Revenue_USD                      679 non-null    float64
#  8   totalAssets_USD                  679 non-null    float64
#  9   totalLiabilities_USD             679 non-null    float64
#  10  totalInvestments_USD             679 non-null    float64
#  11  totalDebt_USD                    679 non-null    float64
#  12  totalEquity_USD                  679 non-null    float64
#  13  ebitda_USD                       679 non-null    float64
#  14  Scope_3_emissions_amount         679 non-null    float64
#  15  scope_1_2_emissions_amount       679 non-null    float64
#  16  slog_Market_Cap_USD              679 non-null    float64
#  17  slog_Revenue_USD                 679 non-null    float64
#  18  slog_totalAssets_USD             679 non-null    float64
#  19  slog_totalLiabilities_USD        679 non-null    float64
#  20  slog_totalInvestments_USD        679 non-null    float64
#  21  slog_totalDebt_USD               679 non-null    float64
#  22  slog_totalEquity_USD             679 non-null    float64
#  23  slog_ebitda_USD                  679 non-null    float64
#  24  slog_Scope_3_emissions_amount    679 non-null    float64
#  25  slog_scope_1_2_emissions_amount  679 non-null    float64
# dtypes: float64(20), int64(3), object(3)
# memory usage: 143.2+ KB

# %%
print((train_df == 0).sum().sum())
print((test_df == 0).sum().sum())
# Out:
# 134
# 30

# %% [markdown]
# ## Fuel Energy Null Mixed-Effects Model
#
# Null mixed-effects model (random intercept only) to predict log-transformed Scope 3 emissions. The model serves as a baseline, capturing only the average emission level for each company, without incorporating any explanatory variables, and quantifies the improvement gained by including additional features and structure. The model is trained on 2018–2022 data and evaluated on a test set from 2023.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies
# - Fixed Effects:
#     - Intercept only (no predictors)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE NULL MODEL (random intercept only) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    null_model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ 1",
        train_df,
        groups=train_df["account_id"]
    )
    null_result = null_model.fit(method="lbfgs")

if not null_result.converged:
    print("WARNING: Null model did not fully converge.")

print(null_result.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_null'] = null_result.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_null']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_null'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics text
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[0], color='gray')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Null Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[1], color='gray')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Null Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Null Model Predicted")
plt.xscale("log")
plt.title("Null Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
null_model_metrics = {
    "Model": "Null (RI)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "Random intercept only"
}
# Out:
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 3242    Method:             REML
# No. Groups:       771     Scale:              0.9073
# Min. group size:  1       Log-Likelihood:     -5705.5403
# Max. group size:  5       Converged:          Yes
# Mean group size:  4.2
# ------------------------------------------------------------------------------
#                Coef.      Std.Err.        z        P>|z|     [0.025     0.975]
# ------------------------------------------------------------------------------
# Intercept      10.334        0.090     115.460     0.000     10.159     10.510
# Group Var       5.911        0.378
# ==========================================================================
#
# R²(log):    -1.76%
# R²(orig):   -5.18%
# MAPE:       2071.13%
# MAPE(log):  20.92%
# MAE(log):   1.98
# RMSLE:      2.51
# RMSE:       3124261.59
# MAE:        711942.76

# %% [markdown]
# ## Fuel Energy Two-Level Mixed-Effects Model
#
# Two-level hierarchical linear mixed-effects model to predict log-transformed Scope 3 emissions at the company level. The model is fit to training data (from 2018–2022), and predictions are evaluated on a test set (from 2023).  This model provides a baseline for including time trends and company-level variability.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies.<br>
# - Fixed Effects:
#     - Year (numeric)
#     - Year squared ('Year_sq', quadratic time trend)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- Check group sizes ---
group_sizes = train_df.groupby('account_id').size()
print("Two-Level Model: Company/year group size summary:")
print(group_sizes.describe())

# --- FIT THE TWO-LEVEL MODEL (random intercept, +Year, +Year_sq) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')a
    model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ Year + Year_sq",
        train_df,
        groups=train_df["account_id"],
        re_formula="1"
    )
    result_twolevel = model.fit(method="lbfgs")

if not result_twolevel.converged:
    print("WARNING: Two-level mixed model did not fully converge.")

print(result_twolevel.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_twolevel.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_mixed']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='orange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Two-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='orange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Two-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="orange", alpha=0.5, label="Two-Level Model Predicted")
plt.xscale("log")
plt.title("Two-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
two_level_model_metrics = {
    "Model": "2-level (RI+S)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "+Year, Year_sq"
}
# Out:
# Two-Level Model: Company/year group size summary:
# count    771.000000
# mean       4.204929
# std        1.284079
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000
# dtype: float64
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 3242    Method:             REML
# No. Groups:       771     Scale:              0.9011
# Min. group size:  1       Log-Likelihood:     -5703.8409
# Max. group size:  5       Converged:          Yes
# Mean group size:  4.2
# ----------------------------------------------------------------------------
#               Coef.      Std.Err.     z      P>|z|     [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept   63022.200   41701.581    1.511   0.131   -18711.396   144755.796
# Year          -62.436      41.288   -1.512   0.130     -143.358       18.487
# Year_sq         0.015       0.010    1.513   0.130       -0.005        0.035
# Group Var       5.924       0.380
# ==========================================================================
#
# R²(log):    -0.14%
# R²(orig):   -5.05%
# MAPE:       2624.15%
# MAPE(log):  21.28%
# MAE(log):   1.96
# RMSLE:      2.49
# RMSE:       3122444.86
# MAE:        711509.03

# %% [markdown]
# ## Fuel Energy Three-Level Mixed-Effects Model
#
# A three-level hierarchical linear mixed-effects model is used to predict log-transformed Scope 3 emissions. It takes into account differences between primary activity, differences between companies, and changes over time. The model is trained using data from 2018 to 2022, and then tested on new data from 2023. This model provides insight on how emissions are influenced by primary activity, by individual companies, by financial and emissions factors, and by trends over time.
#
# Model Structure:
#
# - Level 3 (Primary Activity):<br>
#     - Random intercept and random slope for Year for each primary activity ('Primary_activity'), capturing baseline primary activity and primary activity-specific time trends.<br>
# - Level 2 (Account/Company):
#     - Random intercept for each company ('account_id'), capturing company-level deviations within each primary activity.
# - Level 1 (Yearly Observations):
#     - Repeated annual observations within each company.
#
# - Fixed Effects:
#     - Signed log-transformed market cap ('slog_Market_Cap_USD')
#     - Signed log-transformed revenue ('slog_Revenue_USD')
#     - Signed log-transformed EBITDA ('slog_ebitda_USD')
#     - Signed log-transformed Scope 1 & 2 emissions ('slog_scope_1_2_emissions_amount')

# %%
# --- Ensure grouping/categorical variables are string ---
for col in ['Countries', 'account_id', 'Primary_activity', 'Primary_sector']:
    train_df[col] = train_df[col].astype(str)
    test_df[col] = test_df[col].astype(str)

# --- Center the Year variable ---
year_mean = train_df['Year'].mean()
train_df['Year_centered'] = train_df['Year'] - year_mean
test_df['Year_centered'] = test_df['Year'] - year_mean

# --- Ensure log-transformed target exists ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE 3-LEVEL MIXED MODEL with Primary_activity as Level 3 group ---
vc = {'account_id': '0 + C(account_id)'}  # Level 2: account_id random intercept

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model_3level = MixedLM.from_formula(
        'log_Scope_3_emissions_amount ~ slog_Market_Cap_USD + slog_Revenue_USD + slog_ebitda_USD + slog_scope_1_2_emissions_amount',
        groups='Primary_activity',
        re_formula='~Year_centered',
        vc_formula=vc,
        data=train_df
    )
    result_3level = model_3level.fit(method="lbfgs", maxiter=1000)

if not result_3level.converged:
    print("WARNING: Three-level mixed model did not fully converge.")

print(result_3level.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_3level.predict(test_df)

# --- Compute back-transformed values ---
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])

# --- Robust Mask for finite values everywhere ---
mask = (
    np.isfinite(test_df['log_Scope_3_emissions_amount']) &
    np.isfinite(test_df['predicted_mixed']) &
    np.isfinite(test_df['Reported_Scope_3']) &
    np.isfinite(test_df['Predicted_Scope_3'])
)
test_df = test_df.loc[mask].copy()

y_true_log = test_df['log_Scope_3_emissions_amount'].values
y_pred_log = test_df['predicted_mixed'].values
y_true = test_df['Reported_Scope_3'].values
y_pred = test_df['Predicted_Scope_3'].values

# Final defensive check and diagnostics
arrays = {
    "y_true_log": y_true_log,
    "y_pred_log": y_pred_log,
    "y_true": y_true,
    "y_pred": y_pred,
}
for arr_name, arr in arrays.items():
    if not np.all(np.isfinite(arr)):
        print(f"ERROR: {arr_name} contains non-finite values!")
        print(f"Non-finite indices: {np.where(~np.isfinite(arr))[0]}")
        print(f"Values: {arr[~np.isfinite(arr)]}")
        raise ValueError(f"{arr_name} contains infs or NaNs after masking!")

# --- METRICS ---
mae_log = mean_absolute_error(y_true_log, y_pred_log)
nonzero_mask = y_true_log != 0
if np.any(nonzero_mask):
    mape_log = np.mean(np.abs((y_true_log[nonzero_mask] - y_pred_log[nonzero_mask]) / y_true_log[nonzero_mask])) * 100
else:
    mape_log = np.nan

r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)

metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
if len(np.unique(y_pred_log)) > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Three-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()
axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

if len(np.unique(y_pred)) > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Three-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()
axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Filter strictly positive values for histogram (log x-axis requires >0)
y_true_pos = y_true[y_true > 0]
y_pred_pos = y_pred[y_pred > 0]

if y_true_pos.size > 0 and y_pred_pos.size > 0:
    min_val = min(y_true_pos.min(), y_pred_pos.min())
    max_val = max(y_true_pos.max(), y_pred_pos.max())
    if min_val == max_val:
        print("Skipping histogram: Only one unique positive value present.")
    else:
        log_bins = np.logspace(np.log10(min_val), np.log10(max_val), 100)

        plt.figure(figsize=(8, 5))
        sns.histplot(y_true_pos, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
        sns.histplot(y_pred_pos, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Three-Level Model Predicted")
        plt.xscale("log")
        plt.title("Three-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
        plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
        plt.ylabel("Density")
        plt.legend()
        plt.tight_layout()
        plt.show()
else:
    print("Skipping histogram: Not enough positive values in y_true or y_pred for log-scale histogram.")

# --- RETURN METRICS FOR SUMMARY TABLE ---
three_level_model_metrics = {
    "Model": "3-level (Primary Activity/Account/Year)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,
    "MAPE(log)": mape_log,
}
# Out:
#                      Mixed Linear Model Regression Results
# ===============================================================================
# Model:               MixedLM  Dependent Variable:  log_Scope_3_emissions_amount
# No. Observations:    3242     Method:              REML
# No. Groups:          124      Scale:               0.8935
# Min. group size:     1        Log-Likelihood:      -5261.1266
# Max. group size:     172      Converged:           Yes
# Mean group size:     26.1
# -------------------------------------------------------------------------------
#                                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------------
# Intercept                            -2.521    0.652 -3.866 0.000 -3.799 -1.243
# slog_Market_Cap_USD                   0.230    0.030  7.617 0.000  0.171  0.289
# slog_Revenue_USD                      0.012    0.010  1.134 0.257 -0.009  0.032
# slog_ebitda_USD                      -0.003    0.003 -0.888 0.374 -0.009  0.004
# slog_scope_1_2_emissions_amount       0.613    0.026 23.997 0.000  0.563  0.663
# Primary_activity Var                  0.337    0.100
# Primary_activity x Year_centered Cov -0.014    0.023
# Year_centered Var                     0.041    0.012
# account_id Var                        1.260    0.103
# ===============================================================================
#
# R²(log):    73.19%
# R²(orig):   6.64%
# MAPE:       261.81%
# MAPE(log):  9.91%
# MAE(log):   0.94
# RMSLE:      1.29
# RMSE:       2943582.06
# MAE:        615457.57

# %% [markdown]
# ## Fuel Energy Full Mixed-Effects Model
#
# A full mixed-effects model is used to predict company Scope 3 emissions, using financial and emissions data, along with information about country, industry, and year. The model is trained on data from 2018 to 2022, and tested on data from 2023. This full model helps provides insights into how a company’s finances, emissions, primary activity, country and the year influence emissions.<br>
#
# Model Structure:<br>
#
# - Random Effects:<br>
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:<br>
#     - Signed log-transformed financial and emissions features:<br>
#         - Market Cap ('slog_Market_Cap_USD')<br>
#         - Revenue ('slog_Revenue_USD')<br>
#         - EBITDA ('slog_ebitda_USD')<br>
#         - Total Investments ('slog_totalInvestments_USD')<br>
#         - Total Debt ('slog_totalDebt_USD')<br>
#         - Total Liabilities ('slog_totalLiabilities_USD')<br>
#         - Total Assets ('slog_totalAssets_USD')<br>
#         - Total Equity ('slog_totalEquity_USD')<br>
#         - Scope 1&2 Emissions ('slog_scope_1_2_emissions_amount')<br>
#     - Country ('Countries', as a categorical variable)<br>
#     - Primary Activity ('Primary_activity', as a categorical variable)<br>
#     - Year (numeric)<br>

# %%
# --- Feature and target columns ---
numeric_cols = [
    'Market_Cap_USD', 'Revenue_USD', 'totalAssets_USD', 'totalLiabilities_USD', 'totalInvestments_USD', 'totalDebt_USD',
    'totalEquity_USD', 'ebitda_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount'
]
feature_cols_slog = [f'slog_{col}' for col in numeric_cols if col != 'Scope_3_emissions_amount']
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
required_cols = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_full = train_df.dropna(subset=required_cols).copy()
test_df_full = test_df.dropna(subset=required_cols).copy()

if test_df_full.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the full mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_full, groups=train_df_full['account_id'])
        mdf = md.fit(reml=False)
    print(mdf.summary())

    # --- Predict on test set ---
    test_df_full['predicted_log'] = mdf.predict(test_df_full)
    test_df_full['predicted'] = np.sign(test_df_full['predicted_log']) * (np.expm1(np.abs(test_df_full['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_full[target_col_slog]
    y_pred_log = test_df_full['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_full['predicted']

    # Mask for finite values
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nFull Mixed-Effects Model (Full Model) Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf.params,
        'pvalue': mdf.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Full Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Full Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Full Model Predicted")
    plt.xscale("log")
    plt.title("Full Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    full_model_metrics = {
        "Model": "Full Model",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                          Mixed Linear Model Regression Results
# ========================================================================================================================
# Model:                           MixedLM                Dependent Variable:                slog_Scope_3_emissions_amount
# No. Observations:                3242                   Method:                            ML
# No. Groups:                      771                    Scale:                             0.9324
# Min. group size:                 1                      Log-Likelihood:                    -5084.3033
# Max. group size:                 5                      Converged:                         Yes
# Mean group size:                 4.2
# ------------------------------------------------------------------------------------------------------------------------
#                                                                            Coef.  Std.Err.   z    P>|z|  [0.025   0.975]
# ------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 -65.712   25.545 -2.572 0.010 -115.780 -15.644
# C(Countries)[T.Austria]                                                     0.924    0.707  1.307 0.191   -0.462   2.310
# C(Countries)[T.Belgium]                                                    -0.579    0.497 -1.164 0.244   -1.554   0.396
# C(Countries)[T.Bermuda]                                                     0.072    0.835  0.086 0.931   -1.564   1.708
# C(Countries)[T.Brazil]                                                     -2.487    0.475 -5.233 0.000   -3.419  -1.556
# C(Countries)[T.Canada]                                                      0.069    0.388  0.178 0.859   -0.691   0.830
# C(Countries)[T.Chile]                                                      -1.682    1.218 -1.382 0.167   -4.069   0.704
# C(Countries)[T.China]                                                      -2.142    0.452 -4.738 0.000   -3.028  -1.256
# C(Countries)[T.Denmark]                                                    -0.170    0.614 -0.277 0.782   -1.373   1.033
# C(Countries)[T.Finland]                                                    -0.619    0.417 -1.484 0.138   -1.437   0.199
# C(Countries)[T.France]                                                     -0.413    0.349 -1.183 0.237   -1.098   0.271
# C(Countries)[T.Germany]                                                    -0.303    0.353 -0.859 0.390   -0.995   0.389
# C(Countries)[T.Greece]                                                     -0.533    0.735 -0.726 0.468   -1.973   0.907
# C(Countries)[T.Hungary]                                                    -2.922    1.107 -2.640 0.008   -5.091  -0.753
# C(Countries)[T.India]                                                      -2.055    0.831 -2.474 0.013   -3.683  -0.427
# C(Countries)[T.Ireland]                                                    -0.222    0.521 -0.426 0.670   -1.244   0.800
# C(Countries)[T.Israel]                                                     -2.421    1.483 -1.632 0.103   -5.327   0.486
# C(Countries)[T.Italy]                                                      -0.553    0.433 -1.278 0.201   -1.400   0.295
# C(Countries)[T.Japan]                                                      -0.588    0.299 -1.964 0.049   -1.175  -0.001
# C(Countries)[T.Luxembourg]                                                 -2.231    1.350 -1.653 0.098   -4.877   0.414
# C(Countries)[T.Mexico]                                                     -0.166    0.715 -0.231 0.817   -1.568   1.236
# C(Countries)[T.Netherlands]                                                -0.484    0.428 -1.130 0.258   -1.322   0.355
# C(Countries)[T.New Zealand]                                                -0.870    0.614 -1.417 0.156   -2.074   0.333
# C(Countries)[T.Norway]                                                     -0.570    0.461 -1.235 0.217   -1.474   0.335
# C(Countries)[T.Peru]                                                       -1.122    1.097 -1.023 0.306   -3.271   1.027
# C(Countries)[T.Portugal]                                                   -1.634    1.481 -1.104 0.270   -4.537   1.268
# C(Countries)[T.Singapore]                                                  -1.700    0.883 -1.927 0.054   -3.430   0.029
# C(Countries)[T.South Africa]                                               -0.691    0.350 -1.978 0.048   -1.377  -0.006
# C(Countries)[T.South Korea]                                                -1.435    0.403 -3.564 0.000   -2.225  -0.646
# C(Countries)[T.Spain]                                                      -0.360    0.373 -0.966 0.334   -1.091   0.371
# C(Countries)[T.Sweden]                                                     -0.430    0.580 -0.742 0.458   -1.568   0.707
# C(Countries)[T.Switzerland]                                                -0.423    0.366 -1.156 0.248   -1.141   0.294
# C(Countries)[T.Thailand]                                                   -1.972    0.622 -3.168 0.002   -3.192  -0.752
# C(Countries)[T.Turkey]                                                     -0.636    1.400 -0.454 0.650   -3.380   2.108
# C(Countries)[T.USA]                                                        -0.412    0.294 -1.399 0.162   -0.989   0.165
# C(Countries)[T.United Kingdom]                                             -0.836    0.307 -2.726 0.006   -1.437  -0.235
# C(Primary_activity)[T.Accessories manufacture]                             -0.129    0.858 -0.151 0.880   -1.811   1.553
# C(Primary_activity)[T.Aerospace]                                            1.684    1.230  1.369 0.171   -0.727   4.095
# C(Primary_activity)[T.Agricultural chemicals]                               0.961    1.165  0.825 0.409   -1.322   3.243
# C(Primary_activity)[T.Agriculture, construction & mining machinery]         1.038    0.591  1.755 0.079   -0.121   2.196
# C(Primary_activity)[T.Alcoholic beverages]                                  1.287    0.524  2.455 0.014    0.259   2.314
# C(Primary_activity)[T.Animal processing]                                    1.092    0.687  1.591 0.112   -0.253   2.438
# C(Primary_activity)[T.Apparel & footwear design]                            0.390    0.656  0.594 0.552   -0.895   1.675
# C(Primary_activity)[T.Apparel stores]                                       1.584    0.552  2.872 0.004    0.503   2.665
# C(Primary_activity)[T.Aquaculture]                                          1.192    0.820  1.454 0.146   -0.414   2.798
# C(Primary_activity)[T.Asset managers]                                      -0.578    0.541 -1.068 0.285   -1.639   0.483
# C(Primary_activity)[T.Automobiles]                                          1.441    0.604  2.386 0.017    0.257   2.625
# C(Primary_activity)[T.Baked goods & cereals]                                2.848    1.110  2.565 0.010    0.672   5.024
# C(Primary_activity)[T.Banks]                                               -0.775    0.438 -1.771 0.077   -1.633   0.083
# C(Primary_activity)[T.Batteries]                                            2.638    0.749  3.524 0.000    1.171   4.105
# C(Primary_activity)[T.Biotechnology]                                        0.237    0.577  0.411 0.681   -0.894   1.368
# C(Primary_activity)[T.Building sub-contractors]                             0.058    0.737  0.079 0.937   -1.386   1.502
# C(Primary_activity)[T.Bus & taxi]                                          -0.993    1.117 -0.889 0.374   -3.182   1.196
# C(Primary_activity)[T.CCGT generation]                                      2.620    0.521  5.027 0.000    1.599   3.642
# C(Primary_activity)[T.Cattle farming]                                       2.684    1.459  1.840 0.066   -0.175   5.544
# C(Primary_activity)[T.Cement]                                               1.996    0.715  2.790 0.005    0.594   3.398
# C(Primary_activity)[T.Chocolate confection]                                 1.777    1.129  1.574 0.115   -0.435   3.989
# C(Primary_activity)[T.Clothing manufacture]                                -0.000    0.650 -0.000 1.000   -1.274   1.274
# C(Primary_activity)[T.Coal generation]                                      1.542    1.222  1.262 0.207   -0.852   3.937
# C(Primary_activity)[T.Commercial services]                                  1.124    0.610  1.844 0.065   -0.071   2.318
# C(Primary_activity)[T.Communications equipment]                             0.324    0.584  0.555 0.579   -0.820   1.469
# C(Primary_activity)[T.Computer hardware]                                    1.384    0.635  2.178 0.029    0.139   2.628
# C(Primary_activity)[T.Concrete products]                                    1.291    1.249  1.033 0.301   -1.158   3.740
# C(Primary_activity)[T.Consumer services]                                   -0.382    1.137 -0.336 0.737   -2.609   1.846
# C(Primary_activity)[T.Dairy & egg products]                                 2.040    0.773  2.641 0.008    0.526   3.555
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                  0.663    0.575  1.152 0.249   -0.465   1.791
# C(Primary_activity)[T.Department stores]                                    0.609    0.726  0.839 0.402   -0.815   2.033
# C(Primary_activity)[T.Discretionary delivery retail]                        0.915    0.729  1.255 0.209   -0.513   2.343
# C(Primary_activity)[T.Education services]                                  -0.222    1.113 -0.200 0.842   -2.404   1.959
# C(Primary_activity)[T.Electrical equipment]                                 0.960    0.490  1.958 0.050   -0.001   1.921
# C(Primary_activity)[T.Electricity networks]                                 3.022    0.524  5.766 0.000    1.995   4.049
# C(Primary_activity)[T.Electronic components]                                0.909    0.462  1.967 0.049    0.003   1.814
# C(Primary_activity)[T.Electronic equipment]                                 0.895    0.503  1.779 0.075   -0.091   1.881
# C(Primary_activity)[T.Energy infrastructure construction]                   1.935    0.884  2.190 0.029    0.203   3.668
# C(Primary_activity)[T.Energy services & equipment]                          0.042    0.736  0.057 0.955   -1.401   1.484
# C(Primary_activity)[T.Engineering services]                                -0.846    0.723 -1.170 0.242   -2.263   0.572
# C(Primary_activity)[T.Engines & motors]                                     1.571    0.621  2.530 0.011    0.354   2.788
# C(Primary_activity)[T.Fabricated metal components]                          1.320    0.553  2.388 0.017    0.237   2.403
# C(Primary_activity)[T.Fast food]                                            1.683    0.867  1.940 0.052   -0.017   3.383
# C(Primary_activity)[T.Finished wood products]                              -0.597    1.256 -0.475 0.635   -3.059   1.866
# C(Primary_activity)[T.Fishing]                                              1.717    1.136  1.512 0.131   -0.509   3.943
# C(Primary_activity)[T.Food & beverage amenities]                            1.904    0.855  2.228 0.026    0.229   3.579
# C(Primary_activity)[T.Food & beverage wholesale]                            1.720    0.849  2.027 0.043    0.057   3.384
# C(Primary_activity)[T.Furniture]                                            0.939    0.667  1.408 0.159   -0.368   2.246
# C(Primary_activity)[T.Gambling]                                             1.848    0.702  2.632 0.008    0.472   3.223
# C(Primary_activity)[T.Gas utilities]                                        3.288    0.640  5.140 0.000    2.034   4.541
# C(Primary_activity)[T.Glass products]                                       2.222    0.751  2.957 0.003    0.749   3.694
# C(Primary_activity)[T.Grain & corn milling]                                 2.418    1.413  1.712 0.087   -0.351   5.187
# C(Primary_activity)[T.Health care facilities]                               1.258    0.737  1.706 0.088   -0.187   2.703
# C(Primary_activity)[T.Health care services]                                -0.309    0.607 -0.508 0.611   -1.498   0.881
# C(Primary_activity)[T.Health care supplies]                                 0.502    0.620  0.811 0.418   -0.712   1.717
# C(Primary_activity)[T.Homeware]                                             1.815    1.132  1.604 0.109   -0.403   4.033
# C(Primary_activity)[T.Hotels & lodging]                                     1.762    0.570  3.092 0.002    0.645   2.879
# C(Primary_activity)[T.Hydro generation]                                     0.316    1.458  0.217 0.828   -2.542   3.174
# C(Primary_activity)[T.Industrial machinery]                                 0.791    0.528  1.500 0.134   -0.243   1.825
# C(Primary_activity)[T.Inorganic base chemicals]                             2.360    0.633  3.729 0.000    1.119   3.600
# C(Primary_activity)[T.Insurance]                                           -0.766    0.444 -1.724 0.085   -1.636   0.105
# C(Primary_activity)[T.Intermodal transport]                                 0.751    1.112  0.675 0.500   -1.430   2.931
# C(Primary_activity)[T.Iron & steel]                                         0.820    0.761  1.078 0.281   -0.672   2.312
# C(Primary_activity)[T.Logging]                                              0.911    1.112  0.819 0.413   -1.269   3.090
# C(Primary_activity)[T.Logistics - 3rd party]                                1.575    0.660  2.386 0.017    0.281   2.869
# C(Primary_activity)[T.Logistics - transport]                               -0.064    1.123 -0.057 0.955   -2.265   2.138
# C(Primary_activity)[T.Marine freight]                                       2.572    0.742  3.464 0.001    1.116   4.027
# C(Primary_activity)[T.Marketing]                                            0.394    0.565  0.698 0.485   -0.712   1.501
# C(Primary_activity)[T.Medical equipment]                                    0.361    0.520  0.694 0.488   -0.658   1.380
# C(Primary_activity)[T.Metal containers & packaging]                         1.962    0.628  3.124 0.002    0.731   3.193
# C(Primary_activity)[T.Metal processing]                                     1.330    0.851  1.563 0.118   -0.338   2.999
# C(Primary_activity)[T.Nitrogenous fertilizers]                              1.753    0.773  2.269 0.023    0.238   3.267
# C(Primary_activity)[T.Non-CCGT generation]                                  4.106    1.121  3.664 0.000    1.910   6.303
# C(Primary_activity)[T.Non-alcoholic beverages]                              1.125    0.619  1.817 0.069   -0.089   2.338
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                          2.041    1.114  1.833 0.067   -0.142   4.224
# C(Primary_activity)[T.Non-residential building construction]                0.850    0.549  1.548 0.122   -0.226   1.926
# C(Primary_activity)[T.Oil & gas extraction]                                -0.885    0.729 -1.215 0.224   -2.314   0.543
# C(Primary_activity)[T.Oil & gas marketing & retailing]                      3.266    0.907  3.602 0.000    1.489   5.044
# C(Primary_activity)[T.Oil & gas pipelines & storage]                       -0.424    0.689 -0.616 0.538   -1.774   0.926
# C(Primary_activity)[T.Oil & gas refining]                                   0.534    1.176  0.455 0.649   -1.770   2.839
# C(Primary_activity)[T.Other base chemicals]                                 1.807    0.492  3.669 0.000    0.842   2.772
# C(Primary_activity)[T.Other containers & packaging]                         1.677    0.743  2.258 0.024    0.222   3.133
# C(Primary_activity)[T.Other food processing]                                2.117    0.531  3.989 0.000    1.077   3.158
# C(Primary_activity)[T.Other non-ferrous ore mining]                         1.796    0.852  2.108 0.035    0.126   3.466
# C(Primary_activity)[T.Other non-wood building materials]                    1.366    0.948  1.441 0.149   -0.491   3.224
# C(Primary_activity)[T.Other professional services]                          0.734    0.469  1.563 0.118   -0.186   1.654
# C(Primary_activity)[T.Other renewable energy equipment]                     0.061    1.288  0.047 0.962   -2.464   2.586
# C(Primary_activity)[T.Other renewable generation]                           4.841    1.832  2.642 0.008    1.250   8.433
# C(Primary_activity)[T.Paper products]                                       2.050    0.571  3.589 0.000    0.931   3.170
# C(Primary_activity)[T.Passenger airlines]                                   2.533    0.539  4.697 0.000    1.476   3.590
# C(Primary_activity)[T.Passenger rail]                                       1.632    1.111  1.468 0.142   -0.546   3.810
# C(Primary_activity)[T.Personal care & household products]                   0.919    0.510  1.801 0.072   -0.081   1.920
# C(Primary_activity)[T.Pharmaceuticals]                                      0.670    0.465  1.443 0.149   -0.240   1.581
# C(Primary_activity)[T.Plastic products]                                     1.739    0.581  2.993 0.003    0.600   2.879
# C(Primary_activity)[T.Precious metals & minerals mining]                    1.226    0.656  1.868 0.062   -0.060   2.513
# C(Primary_activity)[T.Print publishing]                                     1.269    0.716  1.772 0.076   -0.135   2.672
# C(Primary_activity)[T.Printing services]                                    1.642    0.842  1.951 0.051   -0.008   3.291
# C(Primary_activity)[T.Pulp & paper mills]                                   2.126    0.701  3.032 0.002    0.752   3.501
# C(Primary_activity)[T.REIT]                                                 1.062    0.484  2.192 0.028    0.113   2.011
# C(Primary_activity)[T.Rail freight]                                         2.181    0.650  3.353 0.001    0.906   3.456
# C(Primary_activity)[T.Railroad rolling stock]                               0.449    1.144  0.393 0.694   -1.793   2.691
# C(Primary_activity)[T.Real estate owners & developers]                      0.318    0.606  0.524 0.600   -0.870   1.505
# C(Primary_activity)[T.Real estate services]                                 0.221    0.687  0.322 0.747   -1.126   1.568
# C(Primary_activity)[T.Residential building construction]                    0.369    0.529  0.698 0.485   -0.667   1.406
# C(Primary_activity)[T.Rubber products]                                      2.015    0.647  3.117 0.002    0.748   3.283
# C(Primary_activity)[T.Semiconductors]                                       3.319    0.715  4.642 0.000    1.918   4.720
# C(Primary_activity)[T.Servers & data centers]                               1.357    0.843  1.611 0.107   -0.294   3.009
# C(Primary_activity)[T.Software]                                             0.319    0.528  0.605 0.545   -0.716   1.355
# C(Primary_activity)[T.Solar energy equipment]                               0.443    1.113  0.399 0.690   -1.737   2.624
# C(Primary_activity)[T.Specialist retail]                                    0.875    0.644  1.360 0.174   -0.386   2.137
# C(Primary_activity)[T.Specialty chemicals]                                  1.275    0.486  2.624 0.009    0.323   2.226
# C(Primary_activity)[T.Supermarkets, food & drugstores]                      1.588    0.486  3.267 0.001    0.635   2.541
# C(Primary_activity)[T.Telecommunications services]                          0.791    0.462  1.711 0.087   -0.115   1.696
# C(Primary_activity)[T.Textiles]                                             4.078    1.170  3.487 0.000    1.786   6.370
# C(Primary_activity)[T.Tobacco products]                                     1.202    0.662  1.816 0.069   -0.095   2.499
# C(Primary_activity)[T.Transportation infrastructure & other construction]   1.151    0.564  2.041 0.041    0.046   2.256
# C(Primary_activity)[T.Transportation support services]                      1.519    1.127  1.348 0.178   -0.690   3.728
# C(Primary_activity)[T.Travel services]                                     -0.602    0.838 -0.718 0.473   -2.244   1.040
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]               -0.221    0.677 -0.327 0.744   -1.549   1.106
# C(Primary_activity)[T.Waste management]                                     1.266    0.855  1.481 0.138   -0.409   2.941
# C(Primary_activity)[T.Water supply networks]                                1.360    0.738  1.842 0.065   -0.087   2.807
# C(Primary_activity)[T.Wind generation]                                      3.128    1.161  2.693 0.007    0.852   5.405
# C(Primary_activity)[T.Wood furniture]                                       1.867    1.138  1.641 0.101   -0.364   4.098
# slog_Market_Cap_USD                                                         0.124    0.037  3.348 0.001    0.052   0.197
# slog_Revenue_USD                                                            0.008    0.011  0.746 0.456   -0.013   0.029
# slog_totalAssets_USD                                                        0.149    0.041  3.616 0.000    0.068   0.229
# slog_totalLiabilities_USD                                                   0.117    0.034  3.431 0.001    0.050   0.183
# slog_totalInvestments_USD                                                  -0.005    0.005 -1.060 0.289   -0.014   0.004
# slog_totalDebt_USD                                                         -0.018    0.019 -0.925 0.355   -0.056   0.020
# slog_totalEquity_USD                                                       -0.004    0.006 -0.699 0.485   -0.015   0.007
# slog_ebitda_USD                                                            -0.003    0.003 -0.770 0.442   -0.009   0.004
# slog_scope_1_2_emissions_amount                                             0.505    0.027 18.804 0.000    0.452   0.558
# Year                                                                        0.030    0.013  2.380 0.017    0.005   0.055
# Group Var                                                                   0.869    0.071
# ========================================================================================================================
#
#
# Full Mixed-Effects Model (Full Model) Test Set Performance Metrics:
# R²(log):    80.18%
# R²(orig):   30.12%
# MAPE:       165.75%
# MAPE(log):  8.38%
# MAE(log):   0.80
# RMSLE:      1.11
# RMSE:       2546657.29
# MAE:        477618.45
#
# Top Influential Features (by p-value):
#                                                   coef        pvalue
# slog_scope_1_2_emissions_amount               0.505088  6.951652e-79
# Group Var                                     0.931795  1.254328e-36
# C(Primary_activity)[T.Electricity networks]   3.021671  8.126578e-09
# C(Countries)[T.Brazil]                       -2.487486  1.665770e-07
# C(Primary_activity)[T.Gas utilities]          3.287697  2.742091e-07
# C(Primary_activity)[T.CCGT generation]        2.620486  4.979364e-07
# C(Countries)[T.China]                        -2.142213  2.158727e-06
# C(Primary_activity)[T.Passenger airlines]     2.532697  2.644336e-06
# C(Primary_activity)[T.Semiconductors]         3.318783  3.447285e-06
# C(Primary_activity)[T.Other food processing]  2.117446  6.644255e-05

# %% [markdown]
# ## Fuel Energy Optimized Mixed-Effects Model
#
# An optimized mixed-effects model is used to predict company Scope 3 emissions. The model provides accurate prediction using only the most significant predictive features, while still accounting for primary activity, country and company level effects. The model is trained on data from 2018–2022 and evaluated on test data from 2023.
#
# Model Structure:
#
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:
#     - Signed log-transformed features:
#         - Market Cap ('slog_Market_Cap_USD')
#         - Total Assets ('slog_totalAssets_USD')
#         - Total Liabilities ('slog_totalLiabilities_USD')
#         - Scope 1 & 2 Emissions ('slog_scope_1_2_emissions_amount')
#     - Country ('Countries', as a categorical variable)
#     - Primary Activity ('Primary_activity', as a categorical variable)
#     - Year

# %%
feature_cols_slog = [
    'slog_Market_Cap_USD',
    'slog_totalAssets_USD',
    'slog_totalLiabilities_USD',
    'slog_scope_1_2_emissions_amount'
]
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
all_model_vars = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_opt = train_df.dropna(subset=all_model_vars).copy()
test_df_opt = test_df.dropna(subset=all_model_vars).copy()

if test_df_opt.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity)  + Year'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the optimized mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_opt, groups=train_df_opt['account_id'])
        mdf_optimized = md.fit(reml=False)
    print(mdf_optimized.summary())

    # --- Predict on test set ---
    test_df_opt['predicted_log'] = mdf_optimized.predict(test_df_opt)
    test_df_opt['predicted'] = np.sign(test_df_opt['predicted_log']) * (np.expm1(np.abs(test_df_opt['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_opt[target_col_slog]
    y_pred_log = test_df_opt['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_opt['predicted']

    # Mask for valid/finites
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <-- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nOptimized Mixed-Effects Model: Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf_optimized.params,
        'pvalue': mdf_optimized.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Optimized Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Optimized Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Optimized Model Predicted")
    plt.xscale("log")
    plt.title("Optimized Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    optimized_model_metrics = {
        "Model": "Optimized",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                          Mixed Linear Model Regression Results
# ========================================================================================================================
# Model:                           MixedLM                Dependent Variable:                slog_Scope_3_emissions_amount
# No. Observations:                3242                   Method:                            ML
# No. Groups:                      771                    Scale:                             0.9340
# Min. group size:                 1                      Log-Likelihood:                    -5086.0567
# Max. group size:                 5                      Converged:                         Yes
# Mean group size:                 4.2
# ------------------------------------------------------------------------------------------------------------------------
#                                                                            Coef.  Std.Err.   z    P>|z|  [0.025   0.975]
# ------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 -63.358   25.451 -2.489 0.013 -113.242 -13.474
# C(Countries)[T.Austria]                                                     0.863    0.705  1.224 0.221   -0.519   2.245
# C(Countries)[T.Belgium]                                                    -0.589    0.497 -1.186 0.236   -1.563   0.384
# C(Countries)[T.Bermuda]                                                     0.054    0.834  0.065 0.948   -1.581   1.689
# C(Countries)[T.Brazil]                                                     -2.500    0.475 -5.266 0.000   -3.431  -1.570
# C(Countries)[T.Canada]                                                      0.068    0.388  0.176 0.860   -0.692   0.828
# C(Countries)[T.Chile]                                                      -1.674    1.216 -1.376 0.169   -4.057   0.710
# C(Countries)[T.China]                                                      -2.167    0.451 -4.804 0.000   -3.051  -1.283
# C(Countries)[T.Denmark]                                                    -0.179    0.613 -0.292 0.770   -1.381   1.023
# C(Countries)[T.Finland]                                                    -0.637    0.417 -1.529 0.126   -1.454   0.180
# C(Countries)[T.France]                                                     -0.418    0.349 -1.199 0.231   -1.102   0.265
# C(Countries)[T.Germany]                                                    -0.313    0.353 -0.887 0.375   -1.004   0.378
# C(Countries)[T.Greece]                                                     -0.562    0.731 -0.769 0.442   -1.994   0.870
# C(Countries)[T.Hungary]                                                    -2.933    1.106 -2.653 0.008   -5.101  -0.766
# C(Countries)[T.India]                                                      -2.034    0.830 -2.452 0.014   -3.661  -0.408
# C(Countries)[T.Ireland]                                                    -0.233    0.521 -0.446 0.655   -1.254   0.789
# C(Countries)[T.Israel]                                                     -2.411    1.482 -1.627 0.104   -5.315   0.494
# C(Countries)[T.Italy]                                                      -0.559    0.432 -1.293 0.196   -1.406   0.288
# C(Countries)[T.Japan]                                                      -0.597    0.298 -2.002 0.045   -1.182  -0.013
# C(Countries)[T.Luxembourg]                                                 -2.233    1.349 -1.655 0.098   -4.878   0.411
# C(Countries)[T.Mexico]                                                     -0.182    0.715 -0.254 0.799   -1.583   1.219
# C(Countries)[T.Netherlands]                                                -0.484    0.427 -1.133 0.257   -1.322   0.353
# C(Countries)[T.New Zealand]                                                -0.906    0.612 -1.480 0.139   -2.106   0.294
# C(Countries)[T.Norway]                                                     -0.585    0.461 -1.270 0.204   -1.489   0.318
# C(Countries)[T.Peru]                                                       -1.136    1.096 -1.037 0.300   -3.284   1.012
# C(Countries)[T.Portugal]                                                   -1.651    1.481 -1.115 0.265   -4.554   1.251
# C(Countries)[T.Singapore]                                                  -1.714    0.882 -1.943 0.052   -3.443   0.015
# C(Countries)[T.South Africa]                                               -0.702    0.349 -2.009 0.044   -1.387  -0.017
# C(Countries)[T.South Korea]                                                -1.458    0.402 -3.625 0.000   -2.246  -0.670
# C(Countries)[T.Spain]                                                      -0.368    0.372 -0.988 0.323   -1.098   0.362
# C(Countries)[T.Sweden]                                                     -0.437    0.580 -0.754 0.451   -1.574   0.699
# C(Countries)[T.Switzerland]                                                -0.412    0.366 -1.127 0.260   -1.128   0.304
# C(Countries)[T.Thailand]                                                   -1.990    0.622 -3.200 0.001   -3.208  -0.771
# C(Countries)[T.Turkey]                                                     -0.579    1.398 -0.414 0.679   -3.319   2.162
# C(Countries)[T.USA]                                                        -0.398    0.294 -1.355 0.176   -0.974   0.178
# C(Countries)[T.United Kingdom]                                             -0.840    0.306 -2.741 0.006   -1.440  -0.239
# C(Primary_activity)[T.Accessories manufacture]                             -0.160    0.855 -0.187 0.852   -1.835   1.515
# C(Primary_activity)[T.Aerospace]                                            1.658    1.229  1.350 0.177   -0.750   4.067
# C(Primary_activity)[T.Agricultural chemicals]                               0.944    1.163  0.812 0.417   -1.335   3.223
# C(Primary_activity)[T.Agriculture, construction & mining machinery]         1.029    0.587  1.753 0.080   -0.122   2.181
# C(Primary_activity)[T.Alcoholic beverages]                                  1.271    0.521  2.440 0.015    0.250   2.292
# C(Primary_activity)[T.Animal processing]                                    1.085    0.684  1.587 0.112   -0.255   2.425
# C(Primary_activity)[T.Apparel & footwear design]                            0.368    0.653  0.564 0.573   -0.911   1.648
# C(Primary_activity)[T.Apparel stores]                                       1.588    0.547  2.901 0.004    0.515   2.661
# C(Primary_activity)[T.Aquaculture]                                          1.174    0.817  1.436 0.151   -0.428   2.776
# C(Primary_activity)[T.Asset managers]                                      -0.588    0.540 -1.089 0.276   -1.646   0.470
# C(Primary_activity)[T.Automobiles]                                          1.440    0.601  2.395 0.017    0.262   2.618
# C(Primary_activity)[T.Baked goods & cereals]                                2.816    1.108  2.541 0.011    0.644   4.989
# C(Primary_activity)[T.Banks]                                               -0.773    0.437 -1.770 0.077   -1.629   0.083
# C(Primary_activity)[T.Batteries]                                            2.619    0.746  3.511 0.000    1.157   4.081
# C(Primary_activity)[T.Biotechnology]                                        0.206    0.575  0.358 0.720   -0.920   1.332
# C(Primary_activity)[T.Building sub-contractors]                             0.059    0.735  0.080 0.936   -1.381   1.499
# C(Primary_activity)[T.Bus & taxi]                                          -1.013    1.115 -0.909 0.364   -3.197   1.172
# C(Primary_activity)[T.CCGT generation]                                      2.598    0.519  5.008 0.000    1.581   3.615
# C(Primary_activity)[T.Cattle farming]                                       2.686    1.458  1.843 0.065   -0.171   5.543
# C(Primary_activity)[T.Cement]                                               1.984    0.713  2.782 0.005    0.586   3.382
# C(Primary_activity)[T.Chocolate confection]                                 1.765    1.125  1.569 0.117   -0.440   3.971
# C(Primary_activity)[T.Clothing manufacture]                                 0.006    0.647  0.009 0.993   -1.261   1.273
# C(Primary_activity)[T.Coal generation]                                      1.534    1.219  1.258 0.208   -0.856   3.924
# C(Primary_activity)[T.Commercial services]                                  1.189    0.601  1.978 0.048    0.011   2.368
# C(Primary_activity)[T.Communications equipment]                             0.306    0.582  0.527 0.598   -0.833   1.446
# C(Primary_activity)[T.Computer hardware]                                    1.441    0.630  2.286 0.022    0.206   2.677
# C(Primary_activity)[T.Concrete products]                                    1.284    1.248  1.029 0.304   -1.162   3.729
# C(Primary_activity)[T.Consumer services]                                   -0.382    1.135 -0.337 0.736   -2.607   1.842
# C(Primary_activity)[T.Dairy & egg products]                                 1.998    0.771  2.591 0.010    0.487   3.510
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                  0.691    0.571  1.210 0.226   -0.429   1.811
# C(Primary_activity)[T.Department stores]                                    0.622    0.722  0.862 0.389   -0.793   2.038
# C(Primary_activity)[T.Discretionary delivery retail]                        0.911    0.726  1.254 0.210   -0.512   2.334
# C(Primary_activity)[T.Education services]                                  -0.237    1.110 -0.213 0.831   -2.413   1.940
# C(Primary_activity)[T.Electrical equipment]                                 0.965    0.487  1.981 0.048    0.010   1.920
# C(Primary_activity)[T.Electricity networks]                                 3.002    0.522  5.749 0.000    1.979   4.025
# C(Primary_activity)[T.Electronic components]                                0.907    0.459  1.977 0.048    0.008   1.806
# C(Primary_activity)[T.Electronic equipment]                                 0.890    0.500  1.780 0.075   -0.090   1.870
# C(Primary_activity)[T.Energy infrastructure construction]                   1.964    0.882  2.227 0.026    0.235   3.693
# C(Primary_activity)[T.Energy services & equipment]                          0.037    0.733  0.050 0.960   -1.400   1.474
# C(Primary_activity)[T.Engineering services]                                -0.864    0.721 -1.198 0.231   -2.276   0.549
# C(Primary_activity)[T.Engines & motors]                                     1.567    0.618  2.536 0.011    0.356   2.779
# C(Primary_activity)[T.Fabricated metal components]                          1.319    0.549  2.403 0.016    0.243   2.395
# C(Primary_activity)[T.Fast food]                                            1.789    0.836  2.141 0.032    0.151   3.428
# C(Primary_activity)[T.Finished wood products]                              -0.614    1.255 -0.490 0.624   -3.074   1.845
# C(Primary_activity)[T.Fishing]                                              1.682    1.133  1.484 0.138   -0.539   3.904
# C(Primary_activity)[T.Food & beverage amenities]                            1.959    0.846  2.316 0.021    0.301   3.616
# C(Primary_activity)[T.Food & beverage wholesale]                            1.730    0.846  2.047 0.041    0.073   3.388
# C(Primary_activity)[T.Furniture]                                            0.934    0.665  1.405 0.160   -0.369   2.238
# C(Primary_activity)[T.Gambling]                                             1.863    0.698  2.667 0.008    0.494   3.231
# C(Primary_activity)[T.Gas utilities]                                        3.265    0.637  5.129 0.000    2.017   4.513
# C(Primary_activity)[T.Glass products]                                       2.189    0.748  2.925 0.003    0.722   3.656
# C(Primary_activity)[T.Grain & corn milling]                                 2.402    1.411  1.702 0.089   -0.365   5.168
# C(Primary_activity)[T.Health care facilities]                               1.238    0.735  1.685 0.092   -0.202   2.678
# C(Primary_activity)[T.Health care services]                                -0.331    0.604 -0.548 0.584   -1.515   0.853
# C(Primary_activity)[T.Health care supplies]                                 0.490    0.617  0.793 0.428   -0.720   1.700
# C(Primary_activity)[T.Homeware]                                             1.843    1.130  1.631 0.103   -0.371   4.058
# C(Primary_activity)[T.Hotels & lodging]                                     1.807    0.561  3.222 0.001    0.708   2.906
# C(Primary_activity)[T.Hydro generation]                                     0.290    1.457  0.199 0.842   -2.567   3.146
# C(Primary_activity)[T.Industrial machinery]                                 0.831    0.526  1.581 0.114   -0.199   1.862
# C(Primary_activity)[T.Inorganic base chemicals]                             2.340    0.631  3.710 0.000    1.104   3.576
# C(Primary_activity)[T.Insurance]                                           -0.737    0.442 -1.667 0.095   -1.604   0.129
# C(Primary_activity)[T.Intermodal transport]                                 0.718    1.110  0.647 0.517   -1.456   2.893
# C(Primary_activity)[T.Iron & steel]                                         0.820    0.759  1.080 0.280   -0.667   2.306
# C(Primary_activity)[T.Logging]                                              0.894    1.109  0.806 0.420   -1.281   3.068
# C(Primary_activity)[T.Logistics - 3rd party]                                1.599    0.656  2.438 0.015    0.314   2.885
# C(Primary_activity)[T.Logistics - transport]                               -0.081    1.122 -0.072 0.942   -2.280   2.118
# C(Primary_activity)[T.Marine freight]                                       2.540    0.739  3.436 0.001    1.091   3.988
# C(Primary_activity)[T.Marketing]                                            0.414    0.563  0.736 0.462   -0.689   1.517
# C(Primary_activity)[T.Medical equipment]                                    0.375    0.516  0.726 0.468   -0.637   1.387
# C(Primary_activity)[T.Metal containers & packaging]                         1.979    0.624  3.174 0.002    0.757   3.202
# C(Primary_activity)[T.Metal processing]                                     1.305    0.849  1.537 0.124   -0.359   2.969
# C(Primary_activity)[T.Nitrogenous fertilizers]                              1.748    0.771  2.268 0.023    0.237   3.258
# C(Primary_activity)[T.Non-CCGT generation]                                  4.113    1.118  3.678 0.000    1.921   6.305
# C(Primary_activity)[T.Non-alcoholic beverages]                              1.104    0.616  1.794 0.073   -0.102   2.311
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                          2.010    1.112  1.808 0.071   -0.170   4.190
# C(Primary_activity)[T.Non-residential building construction]                0.846    0.546  1.549 0.121   -0.225   1.917
# C(Primary_activity)[T.Oil & gas extraction]                                -0.894    0.727 -1.231 0.218   -2.318   0.530
# C(Primary_activity)[T.Oil & gas marketing & retailing]                      3.268    0.904  3.614 0.000    1.496   5.041
# C(Primary_activity)[T.Oil & gas pipelines & storage]                       -0.466    0.686 -0.679 0.497   -1.812   0.879
# C(Primary_activity)[T.Oil & gas refining]                                   0.549    1.174  0.468 0.640   -1.752   2.850
# C(Primary_activity)[T.Other base chemicals]                                 1.796    0.489  3.675 0.000    0.838   2.754
# C(Primary_activity)[T.Other containers & packaging]                         1.708    0.738  2.315 0.021    0.262   3.154
# C(Primary_activity)[T.Other food processing]                                2.105    0.527  3.992 0.000    1.072   3.139
# C(Primary_activity)[T.Other non-ferrous ore mining]                         1.796    0.850  2.114 0.035    0.131   3.462
# C(Primary_activity)[T.Other non-wood building materials]                    1.350    0.945  1.429 0.153   -0.501   3.201
# C(Primary_activity)[T.Other professional services]                          0.724    0.466  1.554 0.120   -0.189   1.636
# C(Primary_activity)[T.Other renewable energy equipment]                     0.120    1.286  0.093 0.926   -2.401   2.641
# C(Primary_activity)[T.Other renewable generation]                           4.837    1.831  2.641 0.008    1.248   8.427
# C(Primary_activity)[T.Paper products]                                       2.052    0.567  3.616 0.000    0.940   3.164
# C(Primary_activity)[T.Passenger airlines]                                   2.579    0.535  4.821 0.000    1.530   3.627
# C(Primary_activity)[T.Passenger rail]                                       1.637    1.109  1.476 0.140   -0.537   3.810
# C(Primary_activity)[T.Personal care & household products]                   0.929    0.507  1.831 0.067   -0.065   1.924
# C(Primary_activity)[T.Pharmaceuticals]                                      0.666    0.462  1.442 0.149   -0.240   1.571
# C(Primary_activity)[T.Plastic products]                                     1.721    0.578  2.979 0.003    0.589   2.853
# C(Primary_activity)[T.Precious metals & minerals mining]                    1.215    0.655  1.856 0.063   -0.068   2.499
# C(Primary_activity)[T.Print publishing]                                     1.286    0.714  1.801 0.072   -0.114   2.687
# C(Primary_activity)[T.Printing services]                                    1.632    0.840  1.943 0.052   -0.014   3.277
# C(Primary_activity)[T.Pulp & paper mills]                                   2.120    0.699  3.033 0.002    0.750   3.491
# C(Primary_activity)[T.REIT]                                                 1.019    0.481  2.118 0.034    0.076   1.963
# C(Primary_activity)[T.Rail freight]                                         2.150    0.648  3.316 0.001    0.879   3.421
# C(Primary_activity)[T.Railroad rolling stock]                               0.456    1.143  0.399 0.690   -1.784   2.695
# C(Primary_activity)[T.Real estate owners & developers]                      0.288    0.603  0.477 0.634   -0.895   1.470
# C(Primary_activity)[T.Real estate services]                                 0.194    0.685  0.283 0.777   -1.149   1.537
# C(Primary_activity)[T.Residential building construction]                    0.367    0.525  0.699 0.485   -0.663   1.397
# C(Primary_activity)[T.Rubber products]                                      1.996    0.643  3.103 0.002    0.735   3.257
# C(Primary_activity)[T.Semiconductors]                                       3.312    0.712  4.649 0.000    1.916   4.709
# C(Primary_activity)[T.Servers & data centers]                               1.325    0.841  1.576 0.115   -0.323   2.973
# C(Primary_activity)[T.Software]                                             0.325    0.525  0.619 0.536   -0.704   1.353
# C(Primary_activity)[T.Solar energy equipment]                               0.419    1.112  0.377 0.706   -1.760   2.598
# C(Primary_activity)[T.Specialist retail]                                    0.861    0.640  1.345 0.179   -0.394   2.116
# C(Primary_activity)[T.Specialty chemicals]                                  1.275    0.483  2.643 0.008    0.329   2.221
# C(Primary_activity)[T.Supermarkets, food & drugstores]                      1.585    0.481  3.291 0.001    0.641   2.528
# C(Primary_activity)[T.Telecommunications services]                          0.788    0.458  1.721 0.085   -0.109   1.685
# C(Primary_activity)[T.Textiles]                                             4.048    1.167  3.468 0.001    1.760   6.336
# C(Primary_activity)[T.Tobacco products]                                     1.241    0.653  1.901 0.057   -0.039   2.520
# C(Primary_activity)[T.Transportation infrastructure & other construction]   1.136    0.561  2.025 0.043    0.036   2.236
# C(Primary_activity)[T.Transportation support services]                      1.494    1.125  1.329 0.184   -0.710   3.699
# C(Primary_activity)[T.Travel services]                                     -0.624    0.835 -0.747 0.455   -2.261   1.013
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]               -0.203    0.673 -0.302 0.763   -1.522   1.116
# C(Primary_activity)[T.Waste management]                                     1.236    0.853  1.449 0.147   -0.435   2.907
# C(Primary_activity)[T.Water supply networks]                                1.341    0.736  1.821 0.069   -0.102   2.784
# C(Primary_activity)[T.Wind generation]                                      3.094    1.159  2.669 0.008    0.822   5.366
# C(Primary_activity)[T.Wood furniture]                                       1.844    1.136  1.623 0.105   -0.383   4.070
# slog_Market_Cap_USD                                                         0.123    0.036  3.380 0.001    0.052   0.195
# slog_totalAssets_USD                                                        0.135    0.038  3.545 0.000    0.060   0.209
# slog_totalLiabilities_USD                                                   0.104    0.031  3.296 0.001    0.042   0.165
# slog_scope_1_2_emissions_amount                                             0.505    0.027 18.876 0.000    0.453   0.558
# Year                                                                        0.029    0.013  2.304 0.021    0.004   0.054
# Group Var                                                                   0.867    0.071
# ========================================================================================================================
#
#
# Optimized Mixed-Effects Model: Test Set Performance Metrics:
# R²(log):    80.19%
# R²(orig):   30.21%
# MAPE:       164.79%
# MAPE(log):  8.40%
# MAE(log):   0.80
# RMSLE:      1.11
# RMSE:       2545061.38
# MAE:        477732.56
#
# Top Influential Features (by p-value):
#                                                   coef        pvalue
# slog_scope_1_2_emissions_amount               0.505167  1.793366e-79
# Group Var                                     0.928626  1.213769e-36
# C(Primary_activity)[T.Electricity networks]   3.001944  8.965375e-09
# C(Countries)[T.Brazil]                       -2.500436  1.391396e-07
# C(Primary_activity)[T.Gas utilities]          3.264908  2.919022e-07
# C(Primary_activity)[T.CCGT generation]        2.597995  5.494161e-07
# C(Primary_activity)[T.Passenger airlines]     2.578735  1.427416e-06
# C(Countries)[T.China]                        -2.167157  1.551757e-06
# C(Primary_activity)[T.Semiconductors]         3.312361  3.335800e-06
# C(Primary_activity)[T.Other food processing]  2.105063  6.547823e-05
#
# All feature coefficients sorted by absolute value:
#                                                         coef    pvalue
# C(Primary_activity)[T.Other renewable generation]   4.837326  0.008255
# C(Primary_activity)[T.Non-CCGT generation]          4.112699  0.000235
# C(Primary_activity)[T.Textiles]                     4.048017  0.000525
# C(Primary_activity)[T.Semiconductors]               3.312361  0.000003
# C(Primary_activity)[T.Oil & gas marketing & ret...  3.268495  0.000302
# ...                                                      ...       ...
# C(Primary_activity)[T.Building sub-contractors]     0.058945  0.936037
# C(Countries)[T.Bermuda]                             0.054136  0.948252
# C(Primary_activity)[T.Energy services & equipment]  0.036885  0.959876
# Year                                                0.029115  0.021205
# C(Primary_activity)[T.Clothing manufacture]         0.005951  0.992656
#
# [164 rows x 2 columns]

# %%
metrics_text_log = (
    f"R²(log):   {r2_log_pct:.2f}%\n"
    f"R²(orig):  {r2_pct:.2f}%\n"
    f"MAPE:      {mape_orig:.2f}%\n"
    f"MAPE(log): {mape_log:.2f}%\n"
    f"MAE(log):  {mae_log:.2f}\n"
    f"RMSLE:     {rmsle:.2f}\n"
    f"RMSE:      {rmse_orig:.2f}\n"
    f"MAE:       {mae_orig:.2f}"
)

fig, ax = plt.subplots(figsize=(9.5, 6))  # Wider to make room for the box

if hasattr(y_pred_log, "nunique"):
    multiple_vals = y_pred_log.nunique() > 1
else:
    multiple_vals = len(set(y_pred_log)) > 1

if multiple_vals:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=ax, color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    ax.plot([], [], ' ', label="Predicted: constant value (no KDE)")

ax.set_title("Fuel Energy Optimized Model: signed log(Scope 3 Emissions)")
ax.set_xlabel("signed log(metric tons + 1)")
ax.set_ylabel("Density")
ax.legend()

# Place metrics box outside plot to the right
fig.text(
    0.82, 0.75, metrics_text_log,
    va='top', ha='left',
    fontsize=12, bbox=dict(boxstyle='round', alpha=0.15)
)

plt.subplots_adjust(right=0.8)  # Make sure there's room for the box
fig.savefig("fuel_energy_scope3_log_density.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Metrics Table for Fuel Energy

# %%
metrics_dicts = [
    null_model_metrics,
    two_level_model_metrics,
    three_level_model_metrics,
    full_model_metrics,
    optimized_model_metrics
]

for metrics, train, test in zip(
        metrics_dicts,
        [train_df, train_df, train_df, train_df, train_df],
        [test_df, test_df, test_df, test_df, test_df]):
    
    metrics["# Obs (train)"] = len(train)
    metrics["# Obs (test)"] = len(test)
    metrics["# Obs (train/test)"] = f"{len(train)}/{len(test)}"

metrics_df = pd.DataFrame(metrics_dicts)

# Ensure all relevant columns are ordered and present
desired_order = [
    "Model", "R2_log", "R2_orig", "RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "# Obs (train/test)"
]


# Ensure MAE_log is present, fill with NaN if missing
if "MAE_log" not in metrics_df.columns:
    metrics_df["MAE_log"] = np.nan

metrics_df = metrics_df[[col for col in desired_order if col in metrics_df.columns]]

metrics_df_display = metrics_df.copy()
if "R2_log" in metrics_df_display.columns:
    metrics_df_display["R2_log"] = (metrics_df_display["R2_log"] * 100).map("{:.2f}%".format)
if "R2_orig" in metrics_df_display.columns:
    metrics_df_display["R2_orig"] = (metrics_df_display["R2_orig"] * 100).map("{:.2f}%".format)
for col in ["RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "MAPE(log)"]:
    if col in metrics_df_display.columns:
        metrics_df_display[col] = metrics_df_display[col].map("{:.2f}".format)

from IPython.display import display
display(metrics_df_display)
# Out:
#                                      Model  R2_log R2_orig        RMSE  \
# 0                                Null (RI)  -1.76%  -5.18%  3124261.59
# 1                           2-level (RI+S)  -0.14%  -5.05%  3122444.86
# 2  3-level (Primary Activity/Account/Year)  73.19%   6.64%  2943582.06
# 3                               Full Model  80.18%  30.12%  2546657.29
# 4                                Optimized  80.19%  30.21%  2545061.38
#
#          MAE MAE_log RMSLE     MAPE # Obs (train/test)
# 0  711942.76    1.98  2.51  2071.13           3242/679
# 1  711509.03    1.96  2.49  2624.15           3242/679
# 2  615457.57    0.94  1.29   261.81           3242/679
# 3  477618.45    0.80  1.11   165.75           3242/679
# 4  477732.56    0.80  1.11   164.79           3242/679
