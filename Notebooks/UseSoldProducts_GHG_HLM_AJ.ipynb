# %% [markdown]
# # GHG HLM on Scope 3 source Use of Sold Products

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_log_error, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GroupShuffleSplit
from scipy.stats import zscore
import scipy.stats as stats
from sklearn.feature_selection import mutual_info_regression
from sklearn.impute import SimpleImputer
import warnings
from statsmodels.regression.mixed_linear_model import MixedLM


#read in dataset from GHG_post_outliers data set
use_sold_products=pd.read_csv('/Users/amberjensen/Desktop/GHG_Emissions_Project/use_sold_products.csv')

# %%
#check for info
use_sold_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_name                2253 non-null   object
#  1   account_id                  2253 non-null   int64
#  2   Year                        2253 non-null   int64
#  3   incorporated_country        2253 non-null   object
#  4   Primary activity            2253 non-null   object
#  5   Primary sector              2253 non-null   object
#  6   Market_Cap_USD              2013 non-null   float64
#  7   Third_party_verification    2252 non-null   object
#  8   Revenue_USD                 2008 non-null   float64
#  9   ebitda_USD                  2008 non-null   float64
#  10  grossProfit_USD             2008 non-null   float64
#  11  netIncome_USD               2008 non-null   float64
#  12  cashAndCashEquivalents_USD  2008 non-null   float64
#  13  shortTermInvestments_USD    2008 non-null   float64
#  14  longTermInvestments_USD     2008 non-null   float64
#  15  totalAssets_USD             2008 non-null   float64
#  16  totalLiabilities_USD        2008 non-null   float64
#  17  totalInvestments_USD        2008 non-null   float64
#  18  totalDebt_USD               2008 non-null   float64
#  19  totalEquity_USD             2008 non-null   float64
#  20  Scope_3_emissions_type      2253 non-null   object
#  21  Scope_3_emissions_amount    2253 non-null   float64
#  22  scope_1_2_emissions_amount  2249 non-null   float64
#  23  Year_sq                     2253 non-null   int64
# dtypes: float64(15), int64(3), object(6)
# memory usage: 422.6+ KB

# %%
#show a df for use_sold_products
use_sold_products.head()
# Out:
#                account_name  account_id  Year incorporated_country  \
# 0                     Aptiv        4407  2018       United Kingdom
# 1               AstraZeneca        1104  2018       United Kingdom
# 2  Barratt Developments plc       23046  2018       United Kingdom
# 3                  BT Group        2377  2018       United Kingdom
# 4            Burberry Group        2414  2018       United Kingdom
#
#                     Primary activity  \
# 0               Electrical equipment
# 1                    Pharmaceuticals
# 2  Residential building construction
# 3        Telecommunications services
# 4               Clothing manufacture
#
#                                      Primary sector  Market_Cap_USD  \
# 0                 Electrical & electronic equipment    1.595156e+10
# 1                                  Biotech & pharma    7.441091e+10
# 2                                      Construction    6.017675e+09
# 3  Media, telecommunications & data center services    2.997109e+10
# 4                           Textiles & fabric goods    9.107209e+09
#
#                             Third_party_verification   Revenue_USD  \
# 0           No third-party verification or assurance  1.443500e+10
# 1  Third-party verification or assurance process ...  2.209000e+10
# 2  Third-party verification or assurance process ...  6.049137e+09
# 3  Third-party verification or assurance process ...  2.975356e+10
# 4  Third-party verification or assurance process ...  3.470656e+09
#
#      ebitda_USD  ...  longTermInvestments_USD  totalAssets_USD  \
# 0  2.260000e+09  ...               99000000.0     1.248000e+10
# 1  7.165000e+09  ...              113000000.0     6.065100e+10
# 2  1.152398e+09  ...              240030000.0     9.353804e+09
# 3  9.392920e+09  ...              128270000.0     5.878449e+10
# 4  7.345680e+08  ...                7366000.0     2.823210e+09
#
#    totalLiabilities_USD  totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0          8.810000e+09           171000000.0   4.344000e+09     3.670000e+09
# 1          4.660700e+10           922000000.0   1.911300e+10     1.404400e+10
# 2          3.170174e+09           240030000.0   1.699768e+09     6.183630e+09
# 3          4.587240e+10           128270000.0   2.143252e+10     1.291209e+10
# 4          1.012952e+09             9398000.0   2.946400e+07     1.810258e+09
#
#    Scope_3_emissions_type  Scope_3_emissions_amount  \
# 0    Use of sold products                3556030.00
# 1    Use of sold products                 778885.00
# 2    Use of sold products                   4703.27
# 3    Use of sold products                1250000.00
# 4    Use of sold products                  32700.00
#
#    scope_1_2_emissions_amount  Year_sq
# 0               380471.810000  4072324
# 1               707252.916667  4072324
# 2                24631.930000  4072324
# 3               457281.895000  4072324
# 4                68188.250000  4072324
#
# [5 rows x 24 columns]

# %%
#define a list of numeric columns
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD',
       'grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD',
       'shortTermInvestments_USD', 'longTermInvestments_USD',
       'totalAssets_USD', 'totalLiabilities_USD', 'totalInvestments_USD',
       'totalDebt_USD', 'totalEquity_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount']

# %%
#plot the heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(use_sold_products[numeric_cols].corr(), annot=True, annot_kws={"size": 8})
plt.show()

# %%
#correlation matrix
use_sold_products[numeric_cols].corr()
# Out:
#                             Market_Cap_USD  Revenue_USD  ebitda_USD  \
# Market_Cap_USD                    1.000000     0.747858    0.871899
# Revenue_USD                       0.747858     1.000000    0.872024
# ebitda_USD                        0.871899     0.872024    1.000000
# grossProfit_USD                   0.788095     0.862193    0.918117
# netIncome_USD                     0.913663     0.811920    0.936238
# cashAndCashEquivalents_USD        0.179452     0.251639    0.284528
# shortTermInvestments_USD          0.377960     0.336283    0.427771
# longTermInvestments_USD           0.150255     0.218485    0.259287
# totalAssets_USD                   0.223439     0.326285    0.377622
# totalLiabilities_USD              0.196711     0.301511    0.340535
# totalInvestments_USD              0.215216     0.252627    0.311181
# totalDebt_USD                     0.374389     0.570636    0.619754
# totalEquity_USD                   0.461069     0.569733    0.667269
# Scope_3_emissions_amount          0.001962     0.115166    0.023443
# scope_1_2_emissions_amount        0.002734     0.025583    0.041658
#
#                             grossProfit_USD  netIncome_USD  \
# Market_Cap_USD                     0.788095       0.913663
# Revenue_USD                        0.862193       0.811920
# ebitda_USD                         0.918117       0.936238
# grossProfit_USD                    1.000000       0.864189
# netIncome_USD                      0.864189       1.000000
# cashAndCashEquivalents_USD         0.428415       0.312569
# shortTermInvestments_USD           0.532245       0.469532
# longTermInvestments_USD            0.389898       0.304284
# totalAssets_USD                    0.526185       0.377228
# totalLiabilities_USD               0.493045       0.351639
# totalInvestments_USD               0.426556       0.353817
# totalDebt_USD                      0.711023       0.517807
# totalEquity_USD                    0.756339       0.589066
# Scope_3_emissions_amount           0.009840      -0.000610
# scope_1_2_emissions_amount        -0.001411      -0.003911
#
#                             cashAndCashEquivalents_USD  \
# Market_Cap_USD                                0.179452
# Revenue_USD                                   0.251639
# ebitda_USD                                    0.284528
# grossProfit_USD                               0.428415
# netIncome_USD                                 0.312569
# cashAndCashEquivalents_USD                    1.000000
# shortTermInvestments_USD                      0.706656
# longTermInvestments_USD                       0.923919
# totalAssets_USD                               0.935647
# totalLiabilities_USD                          0.880555
# totalInvestments_USD                          0.865012
# totalDebt_USD                                 0.688770
# totalEquity_USD                               0.691161
# Scope_3_emissions_amount                     -0.045694
# scope_1_2_emissions_amount                   -0.030102
#
#                             shortTermInvestments_USD  longTermInvestments_USD  \
# Market_Cap_USD                              0.377960                 0.150255
# Revenue_USD                                 0.336283                 0.218485
# ebitda_USD                                  0.427771                 0.259287
# grossProfit_USD                             0.532245                 0.389898
# netIncome_USD                               0.469532                 0.304284
# cashAndCashEquivalents_USD                  0.706656                 0.923919
# shortTermInvestments_USD                    1.000000                 0.769258
# longTermInvestments_USD                     0.769258                 1.000000
# totalAssets_USD                             0.783524                 0.951200
# totalLiabilities_USD                        0.808552                 0.913722
# totalInvestments_USD                        0.801467                 0.950116
# totalDebt_USD                               0.669238                 0.702972
# totalEquity_USD                             0.728406                 0.683188
# Scope_3_emissions_amount                   -0.024631                -0.046911
# scope_1_2_emissions_amount                 -0.017829                -0.020071
#
#                             totalAssets_USD  totalLiabilities_USD  \
# Market_Cap_USD                     0.223439              0.196711
# Revenue_USD                        0.326285              0.301511
# ebitda_USD                         0.377622              0.340535
# grossProfit_USD                    0.526185              0.493045
# netIncome_USD                      0.377228              0.351639
# cashAndCashEquivalents_USD         0.935647              0.880555
# shortTermInvestments_USD           0.783524              0.808552
# longTermInvestments_USD            0.951200              0.913722
# totalAssets_USD                    1.000000              0.951731
# totalLiabilities_USD               0.951731              1.000000
# totalInvestments_USD               0.911123              0.875831
# totalDebt_USD                      0.837308              0.807880
# totalEquity_USD                    0.803725              0.756770
# Scope_3_emissions_amount          -0.037040             -0.032616
# scope_1_2_emissions_amount         0.022160              0.019230
#
#                             totalInvestments_USD  totalDebt_USD  \
# Market_Cap_USD                          0.215216       0.374389
# Revenue_USD                             0.252627       0.570636
# ebitda_USD                              0.311181       0.619754
# grossProfit_USD                         0.426556       0.711023
# netIncome_USD                           0.353817       0.517807
# cashAndCashEquivalents_USD              0.865012       0.688770
# shortTermInvestments_USD                0.801467       0.669238
# longTermInvestments_USD                 0.950116       0.702972
# totalAssets_USD                         0.911123       0.837308
# totalLiabilities_USD                    0.875831       0.807880
# totalInvestments_USD                    1.000000       0.689846
# totalDebt_USD                           0.689846       1.000000
# totalEquity_USD                         0.692019       0.844373
# Scope_3_emissions_amount               -0.043779      -0.002211
# scope_1_2_emissions_amount             -0.020583       0.135311
#
#                             totalEquity_USD  Scope_3_emissions_amount  \
# Market_Cap_USD                     0.461069                  0.001962
# Revenue_USD                        0.569733                  0.115166
# ebitda_USD                         0.667269                  0.023443
# grossProfit_USD                    0.756339                  0.009840
# netIncome_USD                      0.589066                 -0.000610
# cashAndCashEquivalents_USD         0.691161                 -0.045694
# shortTermInvestments_USD           0.728406                 -0.024631
# longTermInvestments_USD            0.683188                 -0.046911
# totalAssets_USD                    0.803725                 -0.037040
# totalLiabilities_USD               0.756770                 -0.032616
# totalInvestments_USD               0.692019                 -0.043779
# totalDebt_USD                      0.844373                 -0.002211
# totalEquity_USD                    1.000000                  0.015753
# Scope_3_emissions_amount           0.015753                  1.000000
# scope_1_2_emissions_amount         0.094391                  0.189488
#
#                             scope_1_2_emissions_amount
# Market_Cap_USD                                0.002734
# Revenue_USD                                   0.025583
# ebitda_USD                                    0.041658
# grossProfit_USD                              -0.001411
# netIncome_USD                                -0.003911
# cashAndCashEquivalents_USD                   -0.030102
# shortTermInvestments_USD                     -0.017829
# longTermInvestments_USD                      -0.020071
# totalAssets_USD                               0.022160
# totalLiabilities_USD                          0.019230
# totalInvestments_USD                         -0.020583
# totalDebt_USD                                 0.135311
# totalEquity_USD                               0.094391
# Scope_3_emissions_amount                      0.189488
# scope_1_2_emissions_amount                    1.000000

# %%
#drop columns due to collinearity, keeping total
use_sold_products=use_sold_products.drop(columns=['grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD',
    'shortTermInvestments_USD', 'longTermInvestments_USD', "account_name", "Third_party_verification", "Scope_3_emissions_type"])

# %%
use_sold_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  2253 non-null   int64
#  1   Year                        2253 non-null   int64
#  2   incorporated_country        2253 non-null   object
#  3   Primary activity            2253 non-null   object
#  4   Primary sector              2253 non-null   object
#  5   Market_Cap_USD              2013 non-null   float64
#  6   Revenue_USD                 2008 non-null   float64
#  7   ebitda_USD                  2008 non-null   float64
#  8   totalAssets_USD             2008 non-null   float64
#  9   totalLiabilities_USD        2008 non-null   float64
#  10  totalInvestments_USD        2008 non-null   float64
#  11  totalDebt_USD               2008 non-null   float64
#  12  totalEquity_USD             2008 non-null   float64
#  13  Scope_3_emissions_amount    2253 non-null   float64
#  14  scope_1_2_emissions_amount  2249 non-null   float64
#  15  Year_sq                     2253 non-null   int64
# dtypes: float64(10), int64(3), object(3)
# memory usage: 281.8+ KB

# %%
sns.boxplot(use_sold_products)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# copy dataframe
use_sold_products_no_transform = use_sold_products.copy()
# Change 'incorporated_country' to 'Countries' in use_sold_products dataframe
use_sold_products_no_transform = use_sold_products_no_transform.rename(columns={'incorporated_country': 'Countries',
                                                       'Primary activity': 'Primary_activity',
                                                        'Primary sector': 'Primary_sector'})

print(use_sold_products_no_transform.info())
use_sold_products_no_transform.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  2253 non-null   int64
#  1   Year                        2253 non-null   int64
#  2   Countries                   2253 non-null   object
#  3   Primary_activity            2253 non-null   object
#  4   Primary_sector              2253 non-null   object
#  5   Market_Cap_USD              2013 non-null   float64
#  6   Revenue_USD                 2008 non-null   float64
#  7   ebitda_USD                  2008 non-null   float64
#  8   totalAssets_USD             2008 non-null   float64
#  9   totalLiabilities_USD        2008 non-null   float64
#  10  totalInvestments_USD        2008 non-null   float64
#  11  totalDebt_USD               2008 non-null   float64
#  12  totalEquity_USD             2008 non-null   float64
#  13  Scope_3_emissions_amount    2253 non-null   float64
#  14  scope_1_2_emissions_amount  2249 non-null   float64
#  15  Year_sq                     2253 non-null   int64
# dtypes: float64(10), int64(3), object(3)
# memory usage: 281.8+ KB
# None
#    account_id  Year       Countries                   Primary_activity  \
# 0        4407  2018  United Kingdom               Electrical equipment
# 1        1104  2018  United Kingdom                    Pharmaceuticals
# 2       23046  2018  United Kingdom  Residential building construction
# 3        2377  2018  United Kingdom        Telecommunications services
# 4        2414  2018  United Kingdom               Clothing manufacture
#
#                                      Primary_sector  Market_Cap_USD  \
# 0                 Electrical & electronic equipment    1.595156e+10
# 1                                  Biotech & pharma    7.441091e+10
# 2                                      Construction    6.017675e+09
# 3  Media, telecommunications & data center services    2.997109e+10
# 4                           Textiles & fabric goods    9.107209e+09
#
#     Revenue_USD    ebitda_USD  totalAssets_USD  totalLiabilities_USD  \
# 0  1.443500e+10  2.260000e+09     1.248000e+10          8.810000e+09
# 1  2.209000e+10  7.165000e+09     6.065100e+10          4.660700e+10
# 2  6.049137e+09  1.152398e+09     9.353804e+09          3.170174e+09
# 3  2.975356e+10  9.392920e+09     5.878449e+10          4.587240e+10
# 4  3.470656e+09  7.345680e+08     2.823210e+09          1.012952e+09
#
#    totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0           171000000.0   4.344000e+09     3.670000e+09
# 1           922000000.0   1.911300e+10     1.404400e+10
# 2           240030000.0   1.699768e+09     6.183630e+09
# 3           128270000.0   2.143252e+10     1.291209e+10
# 4             9398000.0   2.946400e+07     1.810258e+09
#
#    Scope_3_emissions_amount  scope_1_2_emissions_amount  Year_sq
# 0                3556030.00               380471.810000  4072324
# 1                 778885.00               707252.916667  4072324
# 2                   4703.27                24631.930000  4072324
# 3                1250000.00               457281.895000  4072324
# 4                  32700.00                68188.250000  4072324

# %%
use_sold_products_no_transform['Primary_sector'].value_counts()
# Out:
# Primary_sector
# Electrical & electronic equipment                     358
# Chemicals                                             195
# Construction                                          176
# Media, telecommunications & data center services      163
# Food & beverage processing                            138
# Powered machinery                                     108
# Energy utility networks                                90
# Discretionary retail                                   82
# Medical equipment & supplies                           76
# Financial services                                     69
# Thermal power generation                               66
# Transportation equipment                               60
# Convenience retail                                     58
# Biotech & pharma                                       55
# Specialized professional services                      41
# Trading, wholesale, distribution, rental & leasing     38
# Wood & rubber products                                 31
# IT & software development                              26
# Oil & gas extraction & production                      24
# Plastic product manufacturing                          24
# Other services                                         23
# Apparel design                                         21
# Textiles & fabric goods                                21
# Leisure & home manufacturing                           21
# Metal products manufacturing                           20
# Intermodal transport & logistics                       18
# Other materials                                        18
# Industrial support services                            17
# Tobacco                                                17
# Print & publishing services                            15
# Paper products & packaging                             14
# Land & property ownership & development                14
# Bars, hotels & restaurants                             13
# Metal smelting, refining & forming                     13
# Non-energy utilities                                   13
# Marine transport                                       12
# Oil & gas processing                                   12
# 0                                                      11
# Oil & gas retailing                                    11
# Commercial & consumer services                         11
# Web & marketing services                                8
# Renewable power generation                              7
# Accessories                                             6
# Logging & rubber tapping                                6
# Entertainment facilities                                6
# Air transport                                           6
# Road transport                                          5
# Light manufacturing                                     4
# Oil & gas storage & transportation                      3
# Metallic mineral mining                                 2
# Renewable energy equipment                              2
# Health care provision                                   2
# Cement & concrete                                       2
# Rail transport                                          1
# Name: count, dtype: int64

# %%
use_sold_products_no_transform['Primary_activity'].value_counts().head(20)
# Out:
# Primary_activity
# Telecommunications services              157
# Electronic components                    108
# Electronic equipment                      79
# Other base chemicals                      73
# Personal care & household products        70
# Electrical equipment                      67
# Communications equipment                  66
# Electricity networks                      63
# CCGT generation                           63
# Non-residential building construction     60
# Industrial machinery                      59
# Supermarkets, food & drugstores           58
# Pharmaceuticals                           53
# Banks                                     53
# Automobiles                               49
# Alcoholic beverages                       49
# Medical equipment                         47
# Residential building construction         44
# Other food processing                     43
# Other professional services               41
# Name: count, dtype: int64

# %%
# Looking at missing data
print(use_sold_products_no_transform.isnull().mean().sort_values(ascending=False).round(3) * 100)
# Out:
# Revenue_USD                   10.9
# ebitda_USD                    10.9
# totalAssets_USD               10.9
# totalLiabilities_USD          10.9
# totalInvestments_USD          10.9
# totalDebt_USD                 10.9
# totalEquity_USD               10.9
# Market_Cap_USD                10.7
# scope_1_2_emissions_amount     0.2
# account_id                     0.0
# Year                           0.0
# Countries                      0.0
# Primary_activity               0.0
# Primary_sector                 0.0
# Scope_3_emissions_amount       0.0
# Year_sq                        0.0
# dtype: float64

# %% [markdown]
# Apply signed log transformation and split data by company and year into train_df (2018-2022) and test_df (2023):

# %%
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD',
       'totalAssets_USD', 'totalLiabilities_USD', 'totalInvestments_USD',
       'totalDebt_USD', 'totalEquity_USD', 'Scope_3_emissions_amount',
       'scope_1_2_emissions_amount'
]
required_cols = [
    'account_id', 'Year', 'Year_sq', 'Countries', 'Primary_activity', 'Primary_sector'
] + numeric_cols

# --- Prepare Data ---
df = use_sold_products_no_transform[required_cols].dropna()

# --- Signed log transform ---
def signed_log(x):
    return np.sign(x) * np.log(np.abs(x) + 1)

for col in numeric_cols:
    df[f'slog_{col}'] = signed_log(df[col])

# --- Company-level split by year ---
train_df = df[df['Year'].between(2018, 2022)].copy()
test_df  = df[df['Year'] == 2023].copy()

# Keep only companies present in training
valid_companies = set(train_df['account_id'].unique())
test_df = test_df[test_df['account_id'].isin(valid_companies)].copy()

# --- Remove rare categories in Primary_activity and Countries (≤2 rows) to prevent singular matrices ---
for col in ['Primary_activity', 'Countries']:
    value_counts = train_df[col].value_counts()
    allowed = value_counts[value_counts > 2].index
    train_df = train_df[train_df[col].isin(allowed)].copy()
    test_df = test_df[test_df[col].isin(allowed)].copy()

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (1568, 26)
# Test shape: (336, 26)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1568 entries, 0 to 1791
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       1568 non-null   int64
#  1   Year                             1568 non-null   int64
#  2   Year_sq                          1568 non-null   int64
#  3   Countries                        1568 non-null   object
#  4   Primary_activity                 1568 non-null   object
#  5   Primary_sector                   1568 non-null   object
#  6   Market_Cap_USD                   1568 non-null   float64
#  7   Revenue_USD                      1568 non-null   float64
#  8   ebitda_USD                       1568 non-null   float64
#  9   totalAssets_USD                  1568 non-null   float64
#  10  totalLiabilities_USD             1568 non-null   float64
#  11  totalInvestments_USD             1568 non-null   float64
#  12  totalDebt_USD                    1568 non-null   float64
#  13  totalEquity_USD                  1568 non-null   float64
#  14  Scope_3_emissions_amount         1568 non-null   float64
#  15  scope_1_2_emissions_amount       1568 non-null   float64
#  16  slog_Market_Cap_USD              1568 non-null   float64
#  17  slog_Revenue_USD                 1568 non-null   float64
#  18  slog_ebitda_USD                  1568 non-null   float64
#  19  slog_totalAssets_USD             1568 non-null   float64
#  20  slog_totalLiabilities_USD        1568 non-null   float64
#  21  slog_totalInvestments_USD        1568 non-null   float64
#  22  slog_totalDebt_USD               1568 non-null   float64
#  23  slog_totalEquity_USD             1568 non-null   float64
#  24  slog_Scope_3_emissions_amount    1568 non-null   float64
#  25  slog_scope_1_2_emissions_amount  1568 non-null   float64
# dtypes: float64(20), int64(3), object(3)
# memory usage: 330.8+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 336 entries, 1792 to 2249
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       336 non-null    int64
#  1   Year                             336 non-null    int64
#  2   Year_sq                          336 non-null    int64
#  3   Countries                        336 non-null    object
#  4   Primary_activity                 336 non-null    object
#  5   Primary_sector                   336 non-null    object
#  6   Market_Cap_USD                   336 non-null    float64
#  7   Revenue_USD                      336 non-null    float64
#  8   ebitda_USD                       336 non-null    float64
#  9   totalAssets_USD                  336 non-null    float64
#  10  totalLiabilities_USD             336 non-null    float64
#  11  totalInvestments_USD             336 non-null    float64
#  12  totalDebt_USD                    336 non-null    float64
#  13  totalEquity_USD                  336 non-null    float64
#  14  Scope_3_emissions_amount         336 non-null    float64
#  15  scope_1_2_emissions_amount       336 non-null    float64
#  16  slog_Market_Cap_USD              336 non-null    float64
#  17  slog_Revenue_USD                 336 non-null    float64
#  18  slog_ebitda_USD                  336 non-null    float64
#  19  slog_totalAssets_USD             336 non-null    float64
#  20  slog_totalLiabilities_USD        336 non-null    float64
#  21  slog_totalInvestments_USD        336 non-null    float64
#  22  slog_totalDebt_USD               336 non-null    float64
#  23  slog_totalEquity_USD             336 non-null    float64
#  24  slog_Scope_3_emissions_amount    336 non-null    float64
#  25  slog_scope_1_2_emissions_amount  336 non-null    float64
# dtypes: float64(20), int64(3), object(3)
# memory usage: 70.9+ KB

# %%
# Check number of 0's in train and test df's
print((train_df == 0).sum().sum())
print((test_df == 0).sum().sum())
# Out:
# 46
# 12

# %% [markdown]
# ## Use of Sold Products Null Mixed-Effects Model
#
# Null mixed-effects model (random intercept only) to predict log-transformed Scope 3 emissions. The model serves as a baseline, capturing only the average emission level for each company, without incorporating any explanatory variables, and quantifies the improvement gained by including additional features and structure. The model is trained on 2018–2022 data and evaluated on a test set from 2023.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies
# - Fixed Effects:
#     - Intercept only (no predictors)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE NULL MODEL (random intercept only) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    null_model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ 1",
        train_df,
        groups=train_df["account_id"]
    )
    null_result = null_model.fit(method="lbfgs")

if not null_result.converged:
    print("WARNING: Null model did not fully converge.")

print(null_result.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_null'] = null_result.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_null']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_null'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics text
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[0], color='gray')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Null Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[1], color='gray')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Null Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Null Model Predicted")
plt.xscale("log")
plt.title("Null Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
null_model_metrics = {
    "Model": "Null (RI)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "Random intercept only"
}
# Out:
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 1568    Method:             REML
# No. Groups:       392     Scale:              0.5343
# Min. group size:  1       Log-Likelihood:     -2539.4157
# Max. group size:  5       Converged:          Yes
# Mean group size:  4.0
# ------------------------------------------------------------------------------
#                 Coef.      Std.Err.       z        P>|z|     [0.025     0.975]
# ------------------------------------------------------------------------------
# Intercept       13.203        0.152     86.929     0.000     12.905     13.501
# Group Var        8.868        1.022
# ==========================================================================
#
# R²(log):    -2.23%
# R²(orig):   -31.47%
# MAPE:       34938.37%
# MAPE(log):  20.63%
# MAE(log):   2.29
# RMSLE:      2.80
# RMSE:       11439902.77
# MAE:        5909861.15

# %% [markdown]
# ## Use of Sold Products Two-Level Mixed-Effects Model
#
# Two-level hierarchical linear mixed-effects model to predict log-transformed Scope 3 emissions at the company level. The model is fit to training data (from 2018–2022), and predictions are evaluated on a test set (from 2023).  This model provides a baseline for including time trends and company-level variability.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies.<br>
# - Fixed Effects:
#     - Year (numeric)
#     - Year squared ('Year_sq', quadratic time trend)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- Check group sizes ---
group_sizes = train_df.groupby('account_id').size()
print("Two-Level Model: Company/year group size summary:")
print(group_sizes.describe())

# --- FIT THE TWO-LEVEL MODEL (random intercept, +Year, +Year_sq) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ Year + Year_sq",
        train_df,
        groups=train_df["account_id"],
        re_formula="1"
    )
    result_twolevel = model.fit(method="lbfgs")

if not result_twolevel.converged:
    print("WARNING: Two-level mixed model did not fully converge.")

print(result_twolevel.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_twolevel.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_mixed']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='orange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Two-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='orange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Two-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="orange", alpha=0.5, label="Two-Level Model Predicted")
plt.xscale("log")
plt.title("Two-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
two_level_model_metrics = {
    "Model": "2-level (RI+S)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "+Year, Year_sq"
}
# Out:
# Two-Level Model: Company/year group size summary:
# count    392.000000
# mean       4.000000
# std        1.425023
# min        1.000000
# 25%        3.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000
# dtype: float64
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 1568    Method:             REML
# No. Groups:       392     Scale:              0.5350
# Min. group size:  1       Log-Likelihood:     -2545.9801
# Max. group size:  5       Converged:          Yes
# Mean group size:  4.0
# ----------------------------------------------------------------------------
#                Coef.      Std.Err.     z      P>|z|     [0.025       0.975]
# ----------------------------------------------------------------------------
# Intercept     5895.964   46625.709    0.126   0.899   -85488.746   97280.675
# Year            -5.836      46.163   -0.126   0.899      -96.314      84.642
# Year_sq          0.001       0.011    0.127   0.899       -0.021       0.024
# Group Var        8.867       1.021
# ==========================================================================
#
# R²(log):    -1.82%
# R²(orig):   -31.22%
# MAPE:       36364.14%
# MAPE(log):  20.63%
# MAE(log):   2.29
# RMSLE:      2.79
# RMSE:       11429091.04
# MAE:        5905187.77

# %% [markdown]
# ## Use of Sold Products Three-Level Mixed-Effects Model
#
# A three-level hierarchical linear mixed-effects model is used to predict log-transformed Scope 3 emissions. It takes into account differences between primary activity, differences between companies, and changes over time. The model is trained using data from 2018 to 2022, and then tested on new data from 2023. This model provides insight on how emissions are influenced by primary activity, by individual companies, by financial and emissions factors, and by trends over time.
#
# Model Structure:
#
# - Level 3 (Primary Activity):<br>
#     - Random intercept and random slope for Year for each primary activity ('Primary_activity'), capturing baseline primary activity and primary activity-specific time trends.<br>
# - Level 2 (Account/Company):
#     - Random intercept for each company ('account_id'), capturing company-level deviations within each primary activity.
# - Level 1 (Yearly Observations):
#     - Repeated annual observations within each company.
#
# - Fixed Effects:
#     - Signed log-transformed market cap ('slog_Market_Cap_USD')
#     - Signed log-transformed revenue ('slog_Revenue_USD')
#     - Signed log-transformed EBITDA ('slog_ebitda_USD')
#     - Signed log-transformed Scope 1 & 2 emissions ('slog_scope_1_2_emissions_amount')

# %%
# --- Ensure grouping/categorical variables are string ---
for col in ['Countries', 'account_id', 'Primary_activity', 'Primary_sector']:
    train_df[col] = train_df[col].astype(str)
    test_df[col] = test_df[col].astype(str)

# --- Center the Year variable ---
year_mean = train_df['Year'].mean()
train_df['Year_centered'] = train_df['Year'] - year_mean
test_df['Year_centered'] = test_df['Year'] - year_mean

# --- Ensure log-transformed target exists ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE 3-LEVEL MIXED MODEL with Primary_activity as Level 3 group ---
vc = {'account_id': '0 + C(account_id)'}  # Level 2: account_id random intercept

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model_3level = MixedLM.from_formula(
        'log_Scope_3_emissions_amount ~ slog_Market_Cap_USD + slog_Revenue_USD + slog_ebitda_USD + slog_scope_1_2_emissions_amount',
        groups='Primary_activity',
        re_formula='~Year_centered',
        vc_formula=vc,
        data=train_df
    )
    result_3level = model_3level.fit(method="lbfgs", maxiter=1000)

if not result_3level.converged:
    print("WARNING: Three-level mixed model did not fully converge.")

print(result_3level.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_3level.predict(test_df)

# --- Compute back-transformed values ---
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])

# --- Robust Mask for finite values everywhere ---
mask = (
    np.isfinite(test_df['log_Scope_3_emissions_amount']) &
    np.isfinite(test_df['predicted_mixed']) &
    np.isfinite(test_df['Reported_Scope_3']) &
    np.isfinite(test_df['Predicted_Scope_3'])
)
test_df = test_df.loc[mask].copy()

y_true_log = test_df['log_Scope_3_emissions_amount'].values
y_pred_log = test_df['predicted_mixed'].values
y_true = test_df['Reported_Scope_3'].values
y_pred = test_df['Predicted_Scope_3'].values

# Final defensive check and diagnostics
arrays = {
    "y_true_log": y_true_log,
    "y_pred_log": y_pred_log,
    "y_true": y_true,
    "y_pred": y_pred,
}
for arr_name, arr in arrays.items():
    if not np.all(np.isfinite(arr)):
        print(f"ERROR: {arr_name} contains non-finite values!")
        print(f"Non-finite indices: {np.where(~np.isfinite(arr))[0]}")
        print(f"Values: {arr[~np.isfinite(arr)]}")
        raise ValueError(f"{arr_name} contains infs or NaNs after masking!")

# --- METRICS ---
mae_log = mean_absolute_error(y_true_log, y_pred_log)
nonzero_mask = y_true_log != 0
if np.any(nonzero_mask):
    mape_log = np.mean(np.abs((y_true_log[nonzero_mask] - y_pred_log[nonzero_mask]) / y_true_log[nonzero_mask])) * 100
else:
    mape_log = np.nan

r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)

metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
if len(np.unique(y_pred_log)) > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Three-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()
axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

if len(np.unique(y_pred)) > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Three-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()
axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Filter strictly positive values for histogram (log x-axis requires >0)
y_true_pos = y_true[y_true > 0]
y_pred_pos = y_pred[y_pred > 0]

if y_true_pos.size > 0 and y_pred_pos.size > 0:
    min_val = min(y_true_pos.min(), y_pred_pos.min())
    max_val = max(y_true_pos.max(), y_pred_pos.max())
    if min_val == max_val:
        print("Skipping histogram: Only one unique positive value present.")
    else:
        log_bins = np.logspace(np.log10(min_val), np.log10(max_val), 100)

        plt.figure(figsize=(8, 5))
        sns.histplot(y_true_pos, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
        sns.histplot(y_pred_pos, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Three-Level Model Predicted")
        plt.xscale("log")
        plt.title("Three-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
        plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
        plt.ylabel("Density")
        plt.legend()
        plt.tight_layout()
        plt.show()
else:
    print("Skipping histogram: Not enough positive values in y_true or y_pred for log-scale histogram.")

# --- RETURN METRICS FOR SUMMARY TABLE ---
three_level_model_metrics = {
    "Model": "3-level (Primary Activity/Account/Year)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,
    "MAPE(log)": mape_log,
}
# Out:
#                      Mixed Linear Model Regression Results
# ===============================================================================
# Model:               MixedLM  Dependent Variable:  log_Scope_3_emissions_amount
# No. Observations:    1568     Method:              REML
# No. Groups:          85       Scale:               0.5195
# Min. group size:     3        Log-Likelihood:      -2478.1232
# Max. group size:     109      Converged:           Yes
# Mean group size:     18.4
# -------------------------------------------------------------------------------
#                                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------------
# Intercept                             6.298    1.319  4.775 0.000  3.713  8.883
# slog_Market_Cap_USD                   0.137    0.053  2.597 0.009  0.034  0.241
# slog_Revenue_USD                      0.049    0.024  2.069 0.039  0.003  0.095
# slog_ebitda_USD                      -0.007    0.006 -1.055 0.291 -0.019  0.006
# slog_scope_1_2_emissions_amount       0.194    0.041  4.734 0.000  0.114  0.275
# Primary_activity Var                  5.283    1.640
# Primary_activity x Year_centered Cov  0.114    0.098
# Year_centered Var                     0.018    0.012
# account_id Var                        4.123    0.585
# ===============================================================================
#
# R²(log):    4.73%
# R²(orig):   -31.17%
# MAPE:       11181.09%
# MAPE(log):  19.46%
# MAE(log):   2.24
# RMSLE:      2.70
# RMSE:       11427052.05
# MAE:        5868880.03

# %% [markdown]
# ## Use of Sold Products Full Mixed-Effects Model
#
# A full mixed-effects model is used to predict company Scope 3 emissions, using financial and emissions data, along with information about country, industry, and year. The model is trained on data from 2018 to 2022, and tested on data from 2023. This full model helps provides insights into how a company’s finances, emissions, primary activity, country and the year influence emissions.<br>
#
# Model Structure:<br>
#
# - Random Effects:<br>
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:<br>
#     - Signed log-transformed financial and emissions features:<br>
#         - Market Cap ('slog_Market_Cap_USD')<br>
#         - Revenue ('slog_Revenue_USD')<br>
#         - EBITDA ('slog_ebitda_USD')<br>
#         - Total Investments ('slog_totalInvestments_USD')<br>
#         - Total Debt ('slog_totalDebt_USD')<br>
#         - Total Assets ('slog_totalAssets_USD')<br>
#         - Total Liabilities ('slog_totalLiabilities_USD')<br>
#         - Total Equity ('slog_totalEquity_USD')<br>
#         - Scope 1&2 Emissions ('slog_scope_1_2_emissions_amount')<br>
#     - Country ('Countries', as a categorical variable)<br>
#     - Primary Activity ('Primary_activity', as a categorical variable)<br>
#     - Year (numeric)<br>

# %%
# --- Feature and target columns ---
numeric_cols = ['Market_Cap_USD',
 'Revenue_USD',
 'ebitda_USD',
 'totalAssets_USD',
 'totalLiabilities_USD',
 'totalInvestments_USD',
 'totalDebt_USD',
 'totalEquity_USD',
 'Scope_3_emissions_amount',
 'scope_1_2_emissions_amount'
]
feature_cols_slog = [f'slog_{col}' for col in numeric_cols if col != 'Scope_3_emissions_amount']
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
required_cols = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_full = train_df.dropna(subset=required_cols).copy()
test_df_full = test_df.dropna(subset=required_cols).copy()

if test_df_full.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the full mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_full, groups=train_df_full['account_id'])
        mdf = md.fit(reml=False)
    print(mdf.summary())

    # --- Predict on test set ---
    test_df_full['predicted_log'] = mdf.predict(test_df_full)
    test_df_full['predicted'] = np.sign(test_df_full['predicted_log']) * (np.expm1(np.abs(test_df_full['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_full[target_col_slog]
    y_pred_log = test_df_full['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_full['predicted']

    # Mask for finite values
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nFull Mixed-Effects Model (Full Model) Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf.params,
        'pvalue': mdf.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Full Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Full Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Full Model Predicted")
    plt.xscale("log")
    plt.title("Full Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    full_model_metrics = {
        "Model": "Full Model",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                          Mixed Linear Model Regression Results
# =======================================================================================================================
# Model:                            MixedLM               Dependent Variable:               slog_Scope_3_emissions_amount
# No. Observations:                 1568                  Method:                           ML
# No. Groups:                       392                   Scale:                            0.5421
# Min. group size:                  1                     Log-Likelihood:                   -2304.0212
# Max. group size:                  5                     Converged:                        Yes
# Mean group size:                  4.0
# -----------------------------------------------------------------------------------------------------------------------
#                                                                            Coef.  Std.Err.   z    P>|z|  [0.025  0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                                                  57.433   29.974  1.916 0.055  -1.316 116.181
# C(Countries)[T.Austria]                                                     1.067    1.452  0.734 0.463  -1.780   3.913
# C(Countries)[T.Belgium]                                                     0.390    1.044  0.373 0.709  -1.657   2.436
# C(Countries)[T.Brazil]                                                     -0.843    1.321 -0.638 0.523  -3.433   1.746
# C(Countries)[T.Canada]                                                     -1.503    0.981 -1.532 0.125  -3.426   0.420
# C(Countries)[T.China]                                                      -0.646    0.959 -0.674 0.501  -2.525   1.233
# C(Countries)[T.Denmark]                                                     0.857    1.430  0.600 0.549  -1.945   3.660
# C(Countries)[T.Finland]                                                    -0.915    0.960 -0.953 0.340  -2.797   0.966
# C(Countries)[T.France]                                                     -0.572    0.878 -0.651 0.515  -2.294   1.149
# C(Countries)[T.Germany]                                                     0.710    0.887  0.801 0.423  -1.028   2.448
# C(Countries)[T.Greece]                                                      1.869    1.787  1.046 0.296  -1.634   5.371
# C(Countries)[T.Hungary]                                                    -2.919    1.787 -1.633 0.102  -6.423   0.584
# C(Countries)[T.Ireland]                                                     1.449    1.342  1.080 0.280  -1.181   4.080
# C(Countries)[T.Italy]                                                      -1.817    1.002 -1.813 0.070  -3.781   0.147
# C(Countries)[T.Japan]                                                      -0.367    0.785 -0.467 0.640  -1.905   1.172
# C(Countries)[T.Netherlands]                                                 0.157    1.130  0.139 0.890  -2.058   2.372
# C(Countries)[T.Norway]                                                     -1.911    1.183 -1.616 0.106  -4.230   0.407
# C(Countries)[T.Portugal]                                                   -4.206    1.920 -2.190 0.029  -7.969  -0.442
# C(Countries)[T.Singapore]                                                   0.968    1.482  0.653 0.514  -1.936   3.872
# C(Countries)[T.South Africa]                                                0.879    1.001  0.878 0.380  -1.083   2.841
# C(Countries)[T.South Korea]                                                -1.632    0.913 -1.788 0.074  -3.422   0.157
# C(Countries)[T.Spain]                                                      -0.934    0.964 -0.969 0.333  -2.824   0.956
# C(Countries)[T.Sweden]                                                     -1.746    1.228 -1.422 0.155  -4.152   0.660
# C(Countries)[T.Switzerland]                                                -1.351    0.978 -1.381 0.167  -3.268   0.566
# C(Countries)[T.Thailand]                                                   -0.809    1.156 -0.700 0.484  -3.076   1.458
# C(Countries)[T.USA]                                                        -0.543    0.796 -0.682 0.495  -2.102   1.017
# C(Countries)[T.United Kingdom]                                             -0.877    0.810 -1.083 0.279  -2.466   0.711
# C(Primary_activity)[T.Accessories manufacture]                             -2.978    2.383 -1.250 0.211  -7.649   1.692
# C(Primary_activity)[T.Agriculture, construction & mining machinery]         1.856    1.874  0.990 0.322  -1.817   5.528
# C(Primary_activity)[T.Alcoholic beverages]                                 -2.421    1.841 -1.315 0.188  -6.029   1.187
# C(Primary_activity)[T.Animal processing]                                   -4.334    2.114 -2.050 0.040  -8.478  -0.189
# C(Primary_activity)[T.Apparel & footwear design]                           -0.989    1.936 -0.511 0.609  -4.783   2.805
# C(Primary_activity)[T.Apparel stores]                                      -0.254    1.836 -0.138 0.890  -3.853   3.345
# C(Primary_activity)[T.Asset managers]                                     -10.074    2.423 -4.157 0.000 -14.824  -5.324
# C(Primary_activity)[T.Automobiles]                                          2.649    1.875  1.413 0.158  -1.026   6.324
# C(Primary_activity)[T.Banks]                                               -8.769    1.853 -4.733 0.000 -12.400  -5.138
# C(Primary_activity)[T.Batteries]                                            0.734    2.416  0.304 0.761  -4.002   5.470
# C(Primary_activity)[T.Building sub-contractors]                             0.663    2.013  0.330 0.742  -3.282   4.609
# C(Primary_activity)[T.CCGT generation]                                      0.563    1.781  0.316 0.752  -2.928   4.055
# C(Primary_activity)[T.Clothing manufacture]                                -0.666    1.934 -0.344 0.731  -4.457   3.126
# C(Primary_activity)[T.Commercial services]                                 -1.676    2.090 -0.802 0.422  -5.772   2.420
# C(Primary_activity)[T.Communications equipment]                             0.409    1.834  0.223 0.823  -3.184   4.003
# C(Primary_activity)[T.Computer hardware]                                    1.280    1.883  0.680 0.497  -2.411   4.971
# C(Primary_activity)[T.Dairy & egg products]                                -0.921    2.395 -0.385 0.701  -5.616   3.773
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                  0.156    1.904  0.082 0.935  -3.575   3.887
# C(Primary_activity)[T.Department stores]                                   -3.831    2.090 -1.833 0.067  -7.927   0.266
# C(Primary_activity)[T.Discretionary delivery retail]                       -1.096    2.005 -0.547 0.585  -5.025   2.833
# C(Primary_activity)[T.Education services]                                  -6.982    2.390 -2.922 0.003 -11.666  -2.299
# C(Primary_activity)[T.Electrical equipment]                                 0.498    1.814  0.275 0.783  -3.056   4.053
# C(Primary_activity)[T.Electricity networks]                                 0.819    1.835  0.446 0.655  -2.777   4.415
# C(Primary_activity)[T.Electronic components]                                0.248    1.784  0.139 0.890  -3.249   3.744
# C(Primary_activity)[T.Electronic equipment]                                -0.974    1.803 -0.541 0.589  -4.507   2.559
# C(Primary_activity)[T.Energy infrastructure construction]                   0.002    2.135  0.001 0.999  -4.182   4.186
# C(Primary_activity)[T.Energy services & equipment]                         -9.865    2.543 -3.879 0.000 -14.849  -4.881
# C(Primary_activity)[T.Engines & motors]                                     2.198    2.001  1.098 0.272  -1.725   6.121
# C(Primary_activity)[T.Fabricated metal components]                         -0.109    1.953 -0.056 0.956  -3.936   3.718
# C(Primary_activity)[T.Food & beverage amenities]                           -1.059    2.093 -0.506 0.613  -5.161   3.044
# C(Primary_activity)[T.Furniture]                                           -5.516    2.382 -2.316 0.021 -10.184  -0.847
# C(Primary_activity)[T.Gambling]                                            -4.074    2.477 -1.644 0.100  -8.929   0.782
# C(Primary_activity)[T.Gas utilities]                                        2.424    1.886  1.286 0.199  -1.271   6.120
# C(Primary_activity)[T.Glass products]                                      -0.865    2.366 -0.366 0.715  -5.503   3.772
# C(Primary_activity)[T.Health care supplies]                                -2.366    1.895 -1.249 0.212  -6.079   1.347
# C(Primary_activity)[T.Homeware]                                            -1.362    2.410 -0.565 0.572  -6.086   3.361
# C(Primary_activity)[T.Industrial machinery]                                 0.494    1.831  0.270 0.787  -3.094   4.082
# C(Primary_activity)[T.Inorganic base chemicals]                            -0.846    1.931 -0.438 0.662  -4.631   2.940
# C(Primary_activity)[T.Insurance]                                           -3.699    2.148 -1.722 0.085  -7.910   0.512
# C(Primary_activity)[T.Intermodal transport]                                -7.755    2.373 -3.268 0.001 -12.406  -3.104
# C(Primary_activity)[T.Logging]                                              1.670    2.372  0.704 0.481  -2.979   6.319
# C(Primary_activity)[T.Logistics - 3rd party]                                0.015    2.412  0.006 0.995  -4.712   4.743
# C(Primary_activity)[T.Logistics - transport]                                0.533    2.400  0.222 0.824  -4.171   5.236
# C(Primary_activity)[T.Marine freight]                                      -1.751    2.367 -0.740 0.459  -6.391   2.888
# C(Primary_activity)[T.Marketing]                                           -1.928    2.035 -0.948 0.343  -5.917   2.060
# C(Primary_activity)[T.Medical equipment]                                   -1.089    1.849 -0.589 0.556  -4.713   2.536
# C(Primary_activity)[T.Metal processing]                                     1.605    2.404  0.668 0.504  -3.107   6.317
# C(Primary_activity)[T.Nitrogenous fertilizers]                              2.120    2.031  1.044 0.296  -1.860   6.100
# C(Primary_activity)[T.Non-alcoholic beverages]                             -2.590    1.931 -1.341 0.180  -6.375   1.195
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                         -0.562    2.369 -0.237 0.812  -5.205   4.080
# C(Primary_activity)[T.Non-residential building construction]               -0.022    1.833 -0.012 0.990  -3.615   3.570
# C(Primary_activity)[T.Oil & gas extraction]                                 2.944    1.931  1.524 0.127  -0.841   6.728
# C(Primary_activity)[T.Oil & gas marketing & retailing]                     -0.703    2.242 -0.313 0.754  -5.097   3.692
# C(Primary_activity)[T.Oil & gas refining]                                   3.243    2.096  1.548 0.122  -0.864   7.351
# C(Primary_activity)[T.Other base chemicals]                                -1.070    1.802 -0.594 0.553  -4.602   2.462
# C(Primary_activity)[T.Other food processing]                               -3.157    1.851 -1.706 0.088  -6.784   0.470
# C(Primary_activity)[T.Other non-wood building materials]                    2.501    2.445  1.023 0.306  -2.291   7.293
# C(Primary_activity)[T.Other professional services]                         -2.113    1.846 -1.145 0.252  -5.732   1.505
# C(Primary_activity)[T.Other renewable generation]                           3.032    2.954  1.026 0.305  -2.758   8.823
# C(Primary_activity)[T.Paper products]                                      -4.878    2.103 -2.319 0.020  -9.000  -0.755
# C(Primary_activity)[T.Passenger airlines]                                  -4.666    1.937 -2.409 0.016  -8.463  -0.870
# C(Primary_activity)[T.Personal care & household products]                  -0.049    1.809 -0.027 0.979  -3.594   3.497
# C(Primary_activity)[T.Pharmaceuticals]                                     -2.984    1.824 -1.636 0.102  -6.559   0.591
# C(Primary_activity)[T.Plastic products]                                     1.680    2.085  0.806 0.420  -2.405   5.766
# C(Primary_activity)[T.Print publishing]                                    -5.018    2.194 -2.287 0.022  -9.319  -0.717
# C(Primary_activity)[T.Printing services]                                   -5.382    2.369 -2.272 0.023 -10.026  -0.738
# C(Primary_activity)[T.Railroad rolling stock]                               2.331    2.401  0.971 0.332  -2.375   7.038
# C(Primary_activity)[T.Real estate owners & developers]                     -2.914    2.145 -1.358 0.174  -7.118   1.291
# C(Primary_activity)[T.Real estate services]                                 0.354    1.996  0.177 0.859  -3.559   4.267
# C(Primary_activity)[T.Residential building construction]                   -0.173    1.838 -0.094 0.925  -3.775   3.430
# C(Primary_activity)[T.Rubber products]                                      3.312    1.891  1.751 0.080  -0.394   7.019
# C(Primary_activity)[T.Servers & data centers]                               0.315    2.376  0.132 0.895  -4.343   4.972
# C(Primary_activity)[T.Software]                                            -3.138    1.888 -1.663 0.096  -6.838   0.561
# C(Primary_activity)[T.Specialist retail]                                   -0.062    1.936 -0.032 0.975  -3.857   3.734
# C(Primary_activity)[T.Specialty chemicals]                                 -0.446    2.011 -0.222 0.824  -4.387   3.495
# C(Primary_activity)[T.Supermarkets, food & drugstores]                     -0.954    1.808 -0.528 0.598  -4.498   2.590
# C(Primary_activity)[T.Telecommunications services]                         -2.726    1.767 -1.543 0.123  -6.190   0.737
# C(Primary_activity)[T.Tobacco products]                                    -4.717    1.982 -2.380 0.017  -8.602  -0.832
# C(Primary_activity)[T.Transportation infrastructure & other construction]  -2.320    1.830 -1.267 0.205  -5.906   1.267
# C(Primary_activity)[T.Transportation support services]                      0.706    2.272  0.311 0.756  -3.747   5.158
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]               -2.221    2.112 -1.051 0.293  -6.361   1.919
# C(Primary_activity)[T.Waste management]                                   -10.657    2.107 -5.058 0.000 -14.786  -6.528
# C(Primary_activity)[T.Water supply networks]                               -1.352    2.097 -0.645 0.519  -5.463   2.758
# C(Primary_activity)[T.Wood furniture]                                      -2.105    2.396 -0.879 0.380  -6.801   2.591
# slog_Market_Cap_USD                                                        -0.036    0.059 -0.614 0.539  -0.152   0.079
# slog_Revenue_USD                                                            0.019    0.024  0.807 0.420  -0.028   0.067
# slog_ebitda_USD                                                            -0.005    0.006 -0.797 0.425  -0.018   0.008
# slog_totalAssets_USD                                                        0.670    0.160  4.185 0.000   0.356   0.984
# slog_totalLiabilities_USD                                                   0.156    0.110  1.422 0.155  -0.059   0.371
# slog_totalInvestments_USD                                                  -0.003    0.006 -0.454 0.650  -0.015   0.009
# slog_totalDebt_USD                                                         -0.041    0.026 -1.594 0.111  -0.092   0.009
# slog_totalEquity_USD                                                       -0.002    0.008 -0.282 0.778  -0.018   0.013
# slog_scope_1_2_emissions_amount                                             0.090    0.042  2.135 0.033   0.007   0.172
# Year                                                                       -0.030    0.015 -2.022 0.043  -0.060  -0.001
# Group Var                                                                   2.436    0.300
# =======================================================================================================================
#
#
# Full Mixed-Effects Model (Full Model) Test Set Performance Metrics:
# R²(log):    64.60%
# R²(orig):   24.56%
# MAPE:       689.83%
# MAPE(log):  10.40%
# MAE(log):   1.26
# RMSLE:      1.65
# RMSE:       8665713.03
# MAE:        4353723.74
#
# Top Influential Features (by p-value):
#                                                          coef        pvalue
# Group Var                                            4.492976  2.491702e-28
# C(Primary_activity)[T.Waste management]            -10.656995  4.228983e-07
# C(Primary_activity)[T.Banks]                        -8.768917  2.210314e-06
# slog_totalAssets_USD                                 0.670294  2.849709e-05
# C(Primary_activity)[T.Asset managers]              -10.074366  3.224998e-05
# C(Primary_activity)[T.Energy services & equipment]  -9.865041  1.047943e-04
# C(Primary_activity)[T.Intermodal transport]         -7.754690  1.084008e-03
# C(Primary_activity)[T.Education services]           -6.982045  3.479571e-03
# C(Primary_activity)[T.Passenger airlines]           -4.666205  1.600401e-02
# C(Primary_activity)[T.Tobacco products]             -4.716985  1.732251e-02

# %% [markdown]
# ## Use of Sold Products Optimized Mixed-Effects Model
#
# An optimized mixed-effects model is used to predict company Scope 3 emissions. The model provides accurate prediction using only the most significant predictive features, while still accounting for primary activity, country and company level effects. The model is trained on data from 2018–2022 and evaluated on test data from 2023.
#
# Model Structure:
#
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:
#     - Signed log-transformed features:
#         - Revenue ('slog_Revenue_USD')
#         - Total Assets ('slog_totalAssets_USD')
#         - Total Liabilities ('slog_totalLiabilities_USD')
#         - Scope 1 & 2 Emissions ('slog_scope_1_2_emissions_amount')
#     - Country ('Countries', as a categorical variable)
#     - Primary Activity ('Primary_activity', as a categorical variable)

# %%
feature_cols_slog = [
    'slog_Revenue_USD',
    'slog_totalAssets_USD',
    'slog_totalLiabilities_USD',
    'slog_scope_1_2_emissions_amount'
]
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
all_model_vars = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_opt = train_df.dropna(subset=all_model_vars).copy()
test_df_opt = test_df.dropna(subset=all_model_vars).copy()

if test_df_opt.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity)'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the optimized mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_opt, groups=train_df_opt['account_id'])
        mdf_optimized = md.fit(reml=False)
    print(mdf_optimized.summary())

    # --- Predict on test set ---
    test_df_opt['predicted_log'] = mdf_optimized.predict(test_df_opt)
    test_df_opt['predicted'] = np.sign(test_df_opt['predicted_log']) * (np.expm1(np.abs(test_df_opt['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_opt[target_col_slog]
    y_pred_log = test_df_opt['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_opt['predicted']

    # Mask for valid/finites
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <-- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nOptimized Mixed-Effects Model: Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf_optimized.params,
        'pvalue': mdf_optimized.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Optimized Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Optimized Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Optimized Model Predicted")
    plt.xscale("log")
    plt.title("Optimized Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    optimized_model_metrics = {
        "Model": "Optimized",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                         Mixed Linear Model Regression Results
# ======================================================================================================================
# Model:                           MixedLM               Dependent Variable:               slog_Scope_3_emissions_amount
# No. Observations:                1568                  Method:                           ML
# No. Groups:                      392                   Scale:                            0.5437
# Min. group size:                 1                     Log-Likelihood:                   -2307.9434
# Max. group size:                 5                     Converged:                        Yes
# Mean group size:                 4.0
# ----------------------------------------------------------------------------------------------------------------------
#                                                                            Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                                                  -2.662    2.596 -1.026 0.305  -7.749  2.425
# C(Countries)[T.Austria]                                                     1.004    1.459  0.688 0.492  -1.857  3.864
# C(Countries)[T.Belgium]                                                     0.487    1.048  0.464 0.642  -1.568  2.542
# C(Countries)[T.Brazil]                                                     -0.857    1.328 -0.645 0.519  -3.460  1.746
# C(Countries)[T.Canada]                                                     -1.437    0.986 -1.458 0.145  -3.369  0.495
# C(Countries)[T.China]                                                      -0.595    0.963 -0.618 0.536  -2.483  1.292
# C(Countries)[T.Denmark]                                                     0.924    1.437  0.643 0.520  -1.892  3.740
# C(Countries)[T.Finland]                                                    -0.928    0.965 -0.962 0.336  -2.819  0.962
# C(Countries)[T.France]                                                     -0.439    0.881 -0.498 0.618  -2.165  1.288
# C(Countries)[T.Germany]                                                     0.792    0.891  0.889 0.374  -0.954  2.538
# C(Countries)[T.Greece]                                                      1.851    1.797  1.030 0.303  -1.670  5.373
# C(Countries)[T.Hungary]                                                    -2.816    1.797 -1.568 0.117  -6.338  0.705
# C(Countries)[T.Ireland]                                                     1.466    1.348  1.087 0.277  -1.177  4.109
# C(Countries)[T.Italy]                                                      -1.708    1.006 -1.699 0.089  -3.680  0.263
# C(Countries)[T.Japan]                                                      -0.270    0.788 -0.343 0.732  -1.815  1.274
# C(Countries)[T.Netherlands]                                                 0.261    1.136  0.230 0.818  -1.965  2.487
# C(Countries)[T.Norway]                                                     -1.918    1.188 -1.615 0.106  -4.246  0.410
# C(Countries)[T.Portugal]                                                   -4.290    1.930 -2.222 0.026  -8.073 -0.507
# C(Countries)[T.Singapore]                                                   0.884    1.490  0.593 0.553  -2.036  3.803
# C(Countries)[T.South Africa]                                                0.886    1.006  0.880 0.379  -1.087  2.858
# C(Countries)[T.South Korea]                                                -1.543    0.917 -1.684 0.092  -3.340  0.253
# C(Countries)[T.Spain]                                                      -0.836    0.968 -0.864 0.388  -2.734  1.061
# C(Countries)[T.Sweden]                                                     -1.664    1.234 -1.349 0.177  -4.082  0.754
# C(Countries)[T.Switzerland]                                                -1.272    0.982 -1.296 0.195  -3.197  0.653
# C(Countries)[T.Thailand]                                                   -0.748    1.162 -0.643 0.520  -3.025  1.530
# C(Countries)[T.USA]                                                        -0.448    0.798 -0.561 0.575  -2.011  1.116
# C(Countries)[T.United Kingdom]                                             -0.772    0.813 -0.949 0.342  -2.366  0.822
# C(Primary_activity)[T.Accessories manufacture]                             -3.100    2.396 -1.294 0.196  -7.796  1.595
# C(Primary_activity)[T.Agriculture, construction & mining machinery]         1.864    1.884  0.990 0.322  -1.828  5.557
# C(Primary_activity)[T.Alcoholic beverages]                                 -2.424    1.851 -1.310 0.190  -6.052  1.204
# C(Primary_activity)[T.Animal processing]                                   -4.425    2.126 -2.081 0.037  -8.592 -0.258
# C(Primary_activity)[T.Apparel & footwear design]                           -1.049    1.946 -0.539 0.590  -4.862  2.764
# C(Primary_activity)[T.Apparel stores]                                      -0.230    1.846 -0.124 0.901  -3.848  3.389
# C(Primary_activity)[T.Asset managers]                                      -9.630    2.429 -3.964 0.000 -14.390 -4.869
# C(Primary_activity)[T.Automobiles]                                          2.684    1.885  1.424 0.154  -1.010  6.379
# C(Primary_activity)[T.Banks]                                               -8.408    1.855 -4.533 0.000 -12.043 -4.772
# C(Primary_activity)[T.Batteries]                                            0.725    2.429  0.298 0.765  -4.037  5.486
# C(Primary_activity)[T.Building sub-contractors]                             0.625    2.024  0.309 0.757  -3.341  4.592
# C(Primary_activity)[T.CCGT generation]                                      0.556    1.791  0.310 0.756  -2.955  4.066
# C(Primary_activity)[T.Clothing manufacture]                                -0.730    1.944 -0.375 0.707  -4.540  3.081
# C(Primary_activity)[T.Commercial services]                                 -1.667    2.100 -0.794 0.427  -5.783  2.449
# C(Primary_activity)[T.Communications equipment]                             0.426    1.843  0.231 0.817  -3.187  4.039
# C(Primary_activity)[T.Computer hardware]                                    1.297    1.893  0.685 0.493  -2.413  5.006
# C(Primary_activity)[T.Dairy & egg products]                                -0.944    2.408 -0.392 0.695  -5.664  3.776
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                  0.127    1.913  0.066 0.947  -3.623  3.876
# C(Primary_activity)[T.Department stores]                                   -3.870    2.102 -1.842 0.066  -7.989  0.249
# C(Primary_activity)[T.Discretionary delivery retail]                       -1.180    2.016 -0.585 0.558  -5.130  2.770
# C(Primary_activity)[T.Education services]                                  -7.014    2.403 -2.919 0.004 -11.723 -2.304
# C(Primary_activity)[T.Electrical equipment]                                 0.477    1.824  0.261 0.794  -3.098  4.051
# C(Primary_activity)[T.Electricity networks]                                 0.819    1.845  0.444 0.657  -2.797  4.435
# C(Primary_activity)[T.Electronic components]                                0.230    1.794  0.128 0.898  -3.286  3.746
# C(Primary_activity)[T.Electronic equipment]                                -0.992    1.813 -0.547 0.584  -4.544  2.561
# C(Primary_activity)[T.Energy infrastructure construction]                   0.035    2.147  0.017 0.987  -4.172  4.243
# C(Primary_activity)[T.Energy services & equipment]                        -10.141    2.555 -3.968 0.000 -15.149 -5.132
# C(Primary_activity)[T.Engines & motors]                                     2.192    2.012  1.089 0.276  -1.752  6.136
# C(Primary_activity)[T.Fabricated metal components]                         -0.155    1.963 -0.079 0.937  -4.003  3.693
# C(Primary_activity)[T.Food & beverage amenities]                           -1.082    2.101 -0.515 0.607  -5.199  3.036
# C(Primary_activity)[T.Furniture]                                           -5.543    2.395 -2.314 0.021 -10.238 -0.849
# C(Primary_activity)[T.Gambling]                                            -4.068    2.489 -1.634 0.102  -8.945  0.810
# C(Primary_activity)[T.Gas utilities]                                        2.386    1.896  1.258 0.208  -1.330  6.102
# C(Primary_activity)[T.Glass products]                                      -0.911    2.379 -0.383 0.702  -5.574  3.752
# C(Primary_activity)[T.Health care supplies]                                -2.382    1.904 -1.251 0.211  -6.114  1.350
# C(Primary_activity)[T.Homeware]                                            -1.430    2.423 -0.590 0.555  -6.179  3.318
# C(Primary_activity)[T.Industrial machinery]                                 0.502    1.840  0.273 0.785  -3.105  4.109
# C(Primary_activity)[T.Inorganic base chemicals]                            -0.945    1.942 -0.487 0.626  -4.751  2.860
# C(Primary_activity)[T.Insurance]                                           -3.300    2.151 -1.534 0.125  -7.516  0.916
# C(Primary_activity)[T.Intermodal transport]                                -7.834    2.386 -3.283 0.001 -12.510 -3.158
# C(Primary_activity)[T.Logging]                                              1.632    2.385  0.684 0.494  -3.043  6.306
# C(Primary_activity)[T.Logistics - 3rd party]                               -0.076    2.426 -0.031 0.975  -4.830  4.678
# C(Primary_activity)[T.Logistics - transport]                                0.624    2.413  0.259 0.796  -4.105  5.353
# C(Primary_activity)[T.Marine freight]                                      -1.789    2.379 -0.752 0.452  -6.452  2.873
# C(Primary_activity)[T.Marketing]                                           -2.014    2.046 -0.985 0.325  -6.025  1.996
# C(Primary_activity)[T.Medical equipment]                                   -1.172    1.859 -0.631 0.528  -4.815  2.471
# C(Primary_activity)[T.Metal processing]                                     1.478    2.416  0.612 0.541  -3.257  6.212
# C(Primary_activity)[T.Nitrogenous fertilizers]                              2.079    2.042  1.018 0.309  -1.923  6.081
# C(Primary_activity)[T.Non-alcoholic beverages]                             -2.646    1.942 -1.363 0.173  -6.452  1.160
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                         -0.576    2.382 -0.242 0.809  -5.244  4.092
# C(Primary_activity)[T.Non-residential building construction]                0.006    1.843  0.003 0.997  -3.606  3.618
# C(Primary_activity)[T.Oil & gas extraction]                                 2.926    1.941  1.507 0.132  -0.878  6.730
# C(Primary_activity)[T.Oil & gas marketing & retailing]                     -0.662    2.254 -0.294 0.769  -5.081  3.756
# C(Primary_activity)[T.Oil & gas refining]                                   3.238    2.107  1.536 0.124  -0.892  7.368
# C(Primary_activity)[T.Other base chemicals]                                -1.121    1.812 -0.619 0.536  -4.673  2.430
# C(Primary_activity)[T.Other food processing]                               -3.191    1.861 -1.715 0.086  -6.838  0.455
# C(Primary_activity)[T.Other non-wood building materials]                    2.365    2.458  0.962 0.336  -2.452  7.182
# C(Primary_activity)[T.Other professional services]                         -2.137    1.856 -1.151 0.250  -5.774  1.500
# C(Primary_activity)[T.Other renewable generation]                           3.227    2.970  1.087 0.277  -2.593  9.048
# C(Primary_activity)[T.Paper products]                                      -4.978    2.115 -2.354 0.019  -9.123 -0.834
# C(Primary_activity)[T.Passenger airlines]                                  -4.651    1.944 -2.393 0.017  -8.461 -0.842
# C(Primary_activity)[T.Personal care & household products]                  -0.081    1.817 -0.045 0.964  -3.643  3.481
# C(Primary_activity)[T.Pharmaceuticals]                                     -2.953    1.833 -1.611 0.107  -6.546  0.640
# C(Primary_activity)[T.Plastic products]                                     1.595    2.096  0.761 0.447  -2.513  5.702
# C(Primary_activity)[T.Print publishing]                                    -5.042    2.206 -2.285 0.022  -9.366 -0.717
# C(Primary_activity)[T.Printing services]                                   -5.376    2.383 -2.256 0.024 -10.046 -0.705
# C(Primary_activity)[T.Railroad rolling stock]                               2.373    2.415  0.983 0.326  -2.360  7.105
# C(Primary_activity)[T.Real estate owners & developers]                     -2.909    2.157 -1.349 0.177  -7.136  1.319
# C(Primary_activity)[T.Real estate services]                                 0.314    2.008  0.157 0.876  -3.620  4.249
# C(Primary_activity)[T.Residential building construction]                   -0.184    1.848 -0.100 0.921  -3.807  3.439
# C(Primary_activity)[T.Rubber products]                                      3.254    1.902  1.711 0.087  -0.473  6.981
# C(Primary_activity)[T.Servers & data centers]                               0.410    2.388  0.172 0.864  -4.271  5.091
# C(Primary_activity)[T.Software]                                            -3.051    1.896 -1.609 0.108  -6.766  0.665
# C(Primary_activity)[T.Specialist retail]                                   -0.113    1.947 -0.058 0.954  -3.930  3.703
# C(Primary_activity)[T.Specialty chemicals]                                 -0.527    2.022 -0.261 0.794  -4.489  3.435
# C(Primary_activity)[T.Supermarkets, food & drugstores]                     -0.938    1.818 -0.516 0.606  -4.502  2.625
# C(Primary_activity)[T.Telecommunications services]                         -2.675    1.776 -1.506 0.132  -6.156  0.807
# C(Primary_activity)[T.Tobacco products]                                    -4.669    1.990 -2.346 0.019  -8.569 -0.768
# C(Primary_activity)[T.Transportation infrastructure & other construction]  -2.319    1.840 -1.260 0.208  -5.926  1.288
# C(Primary_activity)[T.Transportation support services]                      0.681    2.284  0.298 0.766  -3.795  5.157
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]               -2.216    2.122 -1.044 0.296  -6.376  1.944
# C(Primary_activity)[T.Waste management]                                   -10.764    2.118 -5.083 0.000 -14.915 -6.614
# C(Primary_activity)[T.Water supply networks]                               -1.396    2.109 -0.662 0.508  -5.529  2.737
# C(Primary_activity)[T.Wood furniture]                                      -2.258    2.408 -0.938 0.348  -6.977  2.461
# slog_Revenue_USD                                                            0.016    0.023  0.710 0.478  -0.029  0.061
# slog_totalAssets_USD                                                        0.517    0.141  3.675 0.000   0.241  0.793
# slog_totalLiabilities_USD                                                   0.158    0.107  1.470 0.141  -0.053  0.369
# slog_scope_1_2_emissions_amount                                             0.105    0.042  2.524 0.012   0.023  0.186
# Group Var                                                                   2.464    0.304
# ======================================================================================================================
#
#
# Optimized Mixed-Effects Model: Test Set Performance Metrics:
# R²(log):    64.57%
# R²(orig):   21.13%
# MAPE:       759.72%
# MAPE(log):  10.48%
# MAE(log):   1.26
# RMSLE:      1.65
# RMSE:       8860492.67
# MAE:        4481484.70
#
# Top Influential Features (by p-value):
#                                                          coef        pvalue
# Group Var                                            4.532832  3.531501e-28
# C(Primary_activity)[T.Waste management]            -10.764147  3.716438e-07
# C(Primary_activity)[T.Banks]                        -8.407565  5.814724e-06
# C(Primary_activity)[T.Energy services & equipment] -10.140854  7.235223e-05
# C(Primary_activity)[T.Asset managers]               -9.629668  7.355360e-05
# slog_totalAssets_USD                                 0.517384  2.382920e-04
# C(Primary_activity)[T.Intermodal transport]         -7.833963  1.025539e-03
# C(Primary_activity)[T.Education services]           -7.013931  3.511102e-03
# slog_scope_1_2_emissions_amount                      0.104921  1.158829e-02
# C(Primary_activity)[T.Passenger airlines]           -4.651370  1.670454e-02
#
# All feature coefficients sorted by absolute value:
#                                                          coef        pvalue
# C(Primary_activity)[T.Waste management]            -10.764147  3.716438e-07
# C(Primary_activity)[T.Energy services & equipment] -10.140854  7.235223e-05
# C(Primary_activity)[T.Asset managers]               -9.629668  7.355360e-05
# C(Primary_activity)[T.Banks]                        -8.407565  5.814724e-06
# C(Primary_activity)[T.Intermodal transport]         -7.833963  1.025539e-03
# ...                                                       ...           ...
# C(Primary_activity)[T.Personal care & household...  -0.081053  9.644277e-01
# C(Primary_activity)[T.Logistics - 3rd party]        -0.075891  9.750398e-01
# C(Primary_activity)[T.Energy infrastructure con...   0.035459  9.868217e-01
# slog_Revenue_USD                                     0.016344  4.778824e-01
# C(Primary_activity)[T.Non-residential building ...   0.006063  9.973749e-01
#
# [115 rows x 2 columns]

# %%
metrics_text_log = (
    f"R²(log):   {r2_log_pct:.2f}%\n"
    f"R²(orig):  {r2_pct:.2f}%\n"
    f"MAPE:      {mape_orig:.2f}%\n"
    f"MAPE(log): {mape_log:.2f}%\n"
    f"MAE(log):  {mae_log:.2f}\n"
    f"RMSLE:     {rmsle:.2f}\n"
    f"RMSE:      {rmse_orig:.2f}\n"
    f"MAE:       {mae_orig:.2f}"
)

fig, ax = plt.subplots(figsize=(9.5, 6))  # Wider to make room for the box

if hasattr(y_pred_log, "nunique"):
    multiple_vals = y_pred_log.nunique() > 1
else:
    multiple_vals = len(set(y_pred_log)) > 1

if multiple_vals:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=ax, color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    ax.plot([], [], ' ', label="Predicted: constant value (no KDE)")

ax.set_title("Use of Sold Products Optimized Model: signed log(Scope 3 Emissions)")
ax.set_xlabel("signed log(metric tons + 1)")
ax.set_ylabel("Density")
ax.legend()

# Place metrics box outside plot to the right
fig.text(
    0.82, 0.75, metrics_text_log,
    va='top', ha='left',
    fontsize=12, bbox=dict(boxstyle='round', alpha=0.15)
)

plt.subplots_adjust(right=0.8)  # Make sure there's room for the box
fig.savefig("use_of_sold_products_scope3_log_density.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Metrics Table for Use of Sold Products

# %%
metrics_dicts = [
    null_model_metrics,
    two_level_model_metrics,
    three_level_model_metrics,
    full_model_metrics,
    optimized_model_metrics
]

for metrics, train, test in zip(
        metrics_dicts,
        [train_df, train_df, train_df, train_df, train_df],
        [test_df, test_df, test_df, test_df, test_df]):
    
    metrics["# Obs (train)"] = len(train)
    metrics["# Obs (test)"] = len(test)
    metrics["# Obs (train/test)"] = f"{len(train)}/{len(test)}"

metrics_df = pd.DataFrame(metrics_dicts)

# Ensure all relevant columns are ordered and present
desired_order = [
    "Model", "R2_log", "R2_orig", "RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "# Obs (train/test)"
]


# Ensure MAE_log is present, fill with NaN if missing
if "MAE_log" not in metrics_df.columns:
    metrics_df["MAE_log"] = np.nan

metrics_df = metrics_df[[col for col in desired_order if col in metrics_df.columns]]

metrics_df_display = metrics_df.copy()
if "R2_log" in metrics_df_display.columns:
    metrics_df_display["R2_log"] = (metrics_df_display["R2_log"] * 100).map("{:.2f}%".format)
if "R2_orig" in metrics_df_display.columns:
    metrics_df_display["R2_orig"] = (metrics_df_display["R2_orig"] * 100).map("{:.2f}%".format)
for col in ["RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "MAPE(log)"]:
    if col in metrics_df_display.columns:
        metrics_df_display[col] = metrics_df_display[col].map("{:.2f}".format)

from IPython.display import display
display(metrics_df_display)
# Out:
#                                      Model  R2_log  R2_orig         RMSE  \
# 0                                Null (RI)  -2.23%  -31.47%  11439902.77
# 1                           2-level (RI+S)  -1.82%  -31.22%  11429091.04
# 2  3-level (Primary Activity/Account/Year)   4.73%  -31.17%  11427052.05
# 3                               Full Model  64.60%   24.56%   8665713.03
# 4                                Optimized  64.57%   21.13%   8860492.67
#
#           MAE MAE_log RMSLE      MAPE # Obs (train/test)
# 0  5909861.15    2.29  2.80  34938.37           1568/336
# 1  5905187.77    2.29  2.79  36364.14           1568/336
# 2  5868880.03    2.24  2.70  11181.09           1568/336
# 3  4353723.74    1.26  1.65    689.83           1568/336
# 4  4481484.70    1.26  1.65    759.72           1568/336
