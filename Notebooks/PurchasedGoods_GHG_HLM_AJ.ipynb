# %% [markdown]
# # GHG HLM on Scope 3 source Purchased Goods and Services

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_log_error, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GroupShuffleSplit
from scipy.stats import zscore
import scipy.stats as stats
from sklearn.feature_selection import mutual_info_regression
from sklearn.impute import SimpleImputer
import warnings
from statsmodels.regression.mixed_linear_model import MixedLM


#read in dataset GHG_post_outliers data set
purchased_goods_and_services=pd.read_csv('/Users/amberjensen/Desktop/GHG_Emissions_Project/purchased_goods_and_services.csv')

# %%
#check for info
purchased_goods_and_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5162 entries, 0 to 5161
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_name                5162 non-null   object
#  1   account_id                  5162 non-null   int64
#  2   Year                        5162 non-null   int64
#  3   incorporated_country        5162 non-null   object
#  4   Primary activity            5162 non-null   object
#  5   Primary sector              5162 non-null   object
#  6   Market_Cap_USD              4334 non-null   float64
#  7   Third_party_verification    5160 non-null   object
#  8   Revenue_USD                 4356 non-null   float64
#  9   ebitda_USD                  4356 non-null   float64
#  10  grossProfit_USD             4356 non-null   float64
#  11  netIncome_USD               4356 non-null   float64
#  12  cashAndCashEquivalents_USD  4356 non-null   float64
#  13  shortTermInvestments_USD    4356 non-null   float64
#  14  longTermInvestments_USD     4356 non-null   float64
#  15  totalAssets_USD             4356 non-null   float64
#  16  totalLiabilities_USD        4356 non-null   float64
#  17  totalInvestments_USD        4356 non-null   float64
#  18  totalDebt_USD               4356 non-null   float64
#  19  totalEquity_USD             4356 non-null   float64
#  20  Scope_3_emissions_type      5162 non-null   object
#  21  Scope_3_emissions_amount    5162 non-null   float64
#  22  scope_1_2_emissions_amount  5150 non-null   float64
#  23  Year_sq                     5162 non-null   int64
# dtypes: float64(15), int64(3), object(6)
# memory usage: 968.0+ KB

# %%
#show a df for purchased_goods_and_services
purchased_goods_and_services.head()
# Out:
#   account_name  account_id  Year incorporated_country  \
# 0     3i Group          44  2018       United Kingdom
# 1        abrdn       17604  2018       United Kingdom
# 2  Antofagasta         820  2018       United Kingdom
# 3        Aptiv        4407  2018       United Kingdom
# 4     Arm Ltd.         950  2018       United Kingdom
#
#                Primary activity                     Primary sector  \
# 0                Asset managers                 Financial services
# 1                     Insurance                 Financial services
# 2  Other non-ferrous ore mining            Metallic mineral mining
# 3          Electrical equipment  Electrical & electronic equipment
# 4         Electronic components  Electrical & electronic equipment
#
#    Market_Cap_USD                           Third_party_verification  \
# 0    9.548124e+09  Third-party verification or assurance process ...
# 1    1.019344e+10  Third-party verification or assurance process ...
# 2    7.721230e+09  Third-party verification or assurance process ...
# 3    1.595156e+10           No third-party verification or assurance
# 4             NaN           No third-party verification or assurance
#
#     Revenue_USD    ebitda_USD  ...  longTermInvestments_USD  totalAssets_USD  \
# 0  1.728470e+09  1.565910e+09  ...             8.544560e+09     1.107567e+10
# 1  2.912110e+09  1.482090e+09  ...             6.626860e+09     1.589659e+10
# 2  4.733100e+09  2.092800e+09  ...             1.060800e+09     1.410250e+10
# 3  1.443500e+10  2.260000e+09  ...             9.900000e+07     1.248000e+10
# 4           NaN           NaN  ...                      NaN              NaN
#
#    totalLiabilities_USD  totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0          1.031240e+09          8.544560e+09   7.302500e+08     1.004443e+10
# 1          6.322060e+09          6.626860e+09   1.647190e+09     9.574530e+09
# 2          4.664400e+09          1.924000e+09   2.493900e+09     9.438100e+09
# 3          8.810000e+09          1.710000e+08   4.344000e+09     3.670000e+09
# 4                   NaN                   NaN            NaN              NaN
#
#          Scope_3_emissions_type  Scope_3_emissions_amount  \
# 0  Purchased goods and services                     17.62
# 1  Purchased goods and services                    425.40
# 2  Purchased goods and services                 271999.00
# 3  Purchased goods and services                4210000.00
# 4  Purchased goods and services                     36.37
#
#    scope_1_2_emissions_amount  Year_sq
# 0                3.389500e+02  4072324
# 1                7.197250e+03  4072324
# 2                3.292186e+06  4072324
# 3                3.804718e+05  4072324
# 4                7.728538e+03  4072324
#
# [5 rows x 24 columns]

# %%
#define a list of numeric columns
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD',
       'grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD',
       'shortTermInvestments_USD', 'longTermInvestments_USD',
       'totalAssets_USD', 'totalLiabilities_USD', 'totalInvestments_USD',
       'totalDebt_USD', 'totalEquity_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount']

# %%
#plot the heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(purchased_goods_and_services[numeric_cols].corr(), annot=True, annot_kws={"size": 8})
plt.show()

# %%
#correlation matrix
purchased_goods_and_services[numeric_cols].corr()
# Out:
#                             Market_Cap_USD  Revenue_USD  ebitda_USD  \
# Market_Cap_USD                    1.000000     0.339371    0.449837
# Revenue_USD                       0.339371     1.000000    0.735622
# ebitda_USD                        0.449837     0.735622    1.000000
# grossProfit_USD                   0.320669     0.799761    0.699523
# netIncome_USD                     0.495487     0.682002    0.888989
# cashAndCashEquivalents_USD        0.053164     0.209816    0.240331
# shortTermInvestments_USD          0.071357     0.180014    0.205174
# longTermInvestments_USD           0.059410     0.259283    0.288616
# totalAssets_USD                   0.085659     0.340856    0.372863
# totalLiabilities_USD              0.072812     0.318587    0.337751
# totalInvestments_USD              0.078064     0.277159    0.310983
# totalDebt_USD                     0.117727     0.408352    0.437708
# totalEquity_USD                   0.227003     0.584941    0.681779
# Scope_3_emissions_amount          0.095380     0.347107    0.202034
# scope_1_2_emissions_amount       -0.000951     0.105740    0.057232
#
#                             grossProfit_USD  netIncome_USD  \
# Market_Cap_USD                     0.320669       0.495487
# Revenue_USD                        0.799761       0.682002
# ebitda_USD                         0.699523       0.888989
# grossProfit_USD                    1.000000       0.685438
# netIncome_USD                      0.685438       1.000000
# cashAndCashEquivalents_USD         0.384143       0.263546
# shortTermInvestments_USD           0.306099       0.192379
# longTermInvestments_USD            0.487517       0.309630
# totalAssets_USD                    0.579015       0.369011
# totalLiabilities_USD               0.551220       0.342114
# totalInvestments_USD               0.508627       0.327854
# totalDebt_USD                      0.560753       0.390088
# totalEquity_USD                    0.724925       0.590439
# Scope_3_emissions_amount           0.148531       0.167859
# scope_1_2_emissions_amount         0.013489       0.015976
#
#                             cashAndCashEquivalents_USD  \
# Market_Cap_USD                                0.053164
# Revenue_USD                                   0.209816
# ebitda_USD                                    0.240331
# grossProfit_USD                               0.384143
# netIncome_USD                                 0.263546
# cashAndCashEquivalents_USD                    1.000000
# shortTermInvestments_USD                      0.035474
# longTermInvestments_USD                       0.718029
# totalAssets_USD                               0.862643
# totalLiabilities_USD                          0.828297
# totalInvestments_USD                          0.671701
# totalDebt_USD                                 0.772558
# totalEquity_USD                               0.610980
# Scope_3_emissions_amount                     -0.039600
# scope_1_2_emissions_amount                   -0.029013
#
#                             shortTermInvestments_USD  longTermInvestments_USD  \
# Market_Cap_USD                              0.071357                 0.059410
# Revenue_USD                                 0.180014                 0.259283
# ebitda_USD                                  0.205174                 0.288616
# grossProfit_USD                             0.306099                 0.487517
# netIncome_USD                               0.192379                 0.309630
# cashAndCashEquivalents_USD                  0.035474                 0.718029
# shortTermInvestments_USD                    1.000000                 0.447625
# longTermInvestments_USD                     0.447625                 1.000000
# totalAssets_USD                             0.278791                 0.878221
# totalLiabilities_USD                        0.274054                 0.806009
# totalInvestments_USD                        0.555311                 0.961476
# totalDebt_USD                               0.056390                 0.628859
# totalEquity_USD                             0.322514                 0.685427
# Scope_3_emissions_amount                   -0.017475                -0.056387
# scope_1_2_emissions_amount                 -0.019541                -0.043919
#
#                             totalAssets_USD  totalLiabilities_USD  \
# Market_Cap_USD                     0.085659              0.072812
# Revenue_USD                        0.340856              0.318587
# ebitda_USD                         0.372863              0.337751
# grossProfit_USD                    0.579015              0.551220
# netIncome_USD                      0.369011              0.342114
# cashAndCashEquivalents_USD         0.862643              0.828297
# shortTermInvestments_USD           0.278791              0.274054
# longTermInvestments_USD            0.878221              0.806009
# totalAssets_USD                    1.000000              0.948757
# totalLiabilities_USD               0.948757              1.000000
# totalInvestments_USD               0.849118              0.788115
# totalDebt_USD                      0.848244              0.827390
# totalEquity_USD                    0.794877              0.742221
# Scope_3_emissions_amount          -0.037668             -0.039429
# scope_1_2_emissions_amount        -0.025431             -0.029720
#
#                             totalInvestments_USD  totalDebt_USD  \
# Market_Cap_USD                          0.078064       0.117727
# Revenue_USD                             0.277159       0.408352
# ebitda_USD                              0.310983       0.437708
# grossProfit_USD                         0.508627       0.560753
# netIncome_USD                           0.327854       0.390088
# cashAndCashEquivalents_USD              0.671701       0.772558
# shortTermInvestments_USD                0.555311       0.056390
# longTermInvestments_USD                 0.961476       0.628859
# totalAssets_USD                         0.849118       0.848244
# totalLiabilities_USD                    0.788115       0.827390
# totalInvestments_USD                    1.000000       0.597904
# totalDebt_USD                           0.597904       1.000000
# totalEquity_USD                         0.685056       0.730866
# Scope_3_emissions_amount               -0.053596       0.033498
# scope_1_2_emissions_amount             -0.042754       0.010694
#
#                             totalEquity_USD  Scope_3_emissions_amount  \
# Market_Cap_USD                     0.227003                  0.095380
# Revenue_USD                        0.584941                  0.347107
# ebitda_USD                         0.681779                  0.202034
# grossProfit_USD                    0.724925                  0.148531
# netIncome_USD                      0.590439                  0.167859
# cashAndCashEquivalents_USD         0.610980                 -0.039600
# shortTermInvestments_USD           0.322514                 -0.017475
# longTermInvestments_USD            0.685427                 -0.056387
# totalAssets_USD                    0.794877                 -0.037668
# totalLiabilities_USD               0.742221                 -0.039429
# totalInvestments_USD               0.685056                 -0.053596
# totalDebt_USD                      0.730866                  0.033498
# totalEquity_USD                    1.000000                  0.072950
# Scope_3_emissions_amount           0.072950                  1.000000
# scope_1_2_emissions_amount         0.080761                  0.110241
#
#                             scope_1_2_emissions_amount
# Market_Cap_USD                               -0.000951
# Revenue_USD                                   0.105740
# ebitda_USD                                    0.057232
# grossProfit_USD                               0.013489
# netIncome_USD                                 0.015976
# cashAndCashEquivalents_USD                   -0.029013
# shortTermInvestments_USD                     -0.019541
# longTermInvestments_USD                      -0.043919
# totalAssets_USD                              -0.025431
# totalLiabilities_USD                         -0.029720
# totalInvestments_USD                         -0.042754
# totalDebt_USD                                 0.010694
# totalEquity_USD                               0.080761
# Scope_3_emissions_amount                      0.110241
# scope_1_2_emissions_amount                    1.000000

# %%
#drop columns due to collinearity, keeping total
purchased_goods_and_services=purchased_goods_and_services.drop(columns=['cashAndCashEquivalents_USD', 'netIncome_USD', 'longTermInvestments_USD','grossProfit_USD',
                                              "account_name", "Third_party_verification", "Scope_3_emissions_type"])

# %%
purchased_goods_and_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5162 entries, 0 to 5161
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  5162 non-null   int64
#  1   Year                        5162 non-null   int64
#  2   incorporated_country        5162 non-null   object
#  3   Primary activity            5162 non-null   object
#  4   Primary sector              5162 non-null   object
#  5   Market_Cap_USD              4334 non-null   float64
#  6   Revenue_USD                 4356 non-null   float64
#  7   ebitda_USD                  4356 non-null   float64
#  8   shortTermInvestments_USD    4356 non-null   float64
#  9   totalAssets_USD             4356 non-null   float64
#  10  totalLiabilities_USD        4356 non-null   float64
#  11  totalInvestments_USD        4356 non-null   float64
#  12  totalDebt_USD               4356 non-null   float64
#  13  totalEquity_USD             4356 non-null   float64
#  14  Scope_3_emissions_amount    5162 non-null   float64
#  15  scope_1_2_emissions_amount  5150 non-null   float64
#  16  Year_sq                     5162 non-null   int64
# dtypes: float64(11), int64(3), object(3)
# memory usage: 685.7+ KB

# %%
sns.boxplot(purchased_goods_and_services)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# copy dataframe
purchased_goods_and_services_no_transform = purchased_goods_and_services.copy()
# Change 'incorporated_country' to 'Countries' in purchased_goods_and_services dataframe
purchased_goods_and_services_no_transform = purchased_goods_and_services_no_transform.rename(columns={'incorporated_country': 'Countries',
                                                       'Primary activity': 'Primary_activity',
                                                        'Primary sector': 'Primary_sector'})

print(purchased_goods_and_services_no_transform.info())
purchased_goods_and_services_no_transform.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5162 entries, 0 to 5161
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  5162 non-null   int64
#  1   Year                        5162 non-null   int64
#  2   Countries                   5162 non-null   object
#  3   Primary_activity            5162 non-null   object
#  4   Primary_sector              5162 non-null   object
#  5   Market_Cap_USD              4334 non-null   float64
#  6   Revenue_USD                 4356 non-null   float64
#  7   ebitda_USD                  4356 non-null   float64
#  8   shortTermInvestments_USD    4356 non-null   float64
#  9   totalAssets_USD             4356 non-null   float64
#  10  totalLiabilities_USD        4356 non-null   float64
#  11  totalInvestments_USD        4356 non-null   float64
#  12  totalDebt_USD               4356 non-null   float64
#  13  totalEquity_USD             4356 non-null   float64
#  14  Scope_3_emissions_amount    5162 non-null   float64
#  15  scope_1_2_emissions_amount  5150 non-null   float64
#  16  Year_sq                     5162 non-null   int64
# dtypes: float64(11), int64(3), object(3)
# memory usage: 685.7+ KB
# None
#    account_id  Year       Countries              Primary_activity  \
# 0          44  2018  United Kingdom                Asset managers
# 1       17604  2018  United Kingdom                     Insurance
# 2         820  2018  United Kingdom  Other non-ferrous ore mining
# 3        4407  2018  United Kingdom          Electrical equipment
# 4         950  2018  United Kingdom         Electronic components
#
#                       Primary_sector  Market_Cap_USD   Revenue_USD  \
# 0                 Financial services    9.548124e+09  1.728470e+09
# 1                 Financial services    1.019344e+10  2.912110e+09
# 2            Metallic mineral mining    7.721230e+09  4.733100e+09
# 3  Electrical & electronic equipment    1.595156e+10  1.443500e+10
# 4  Electrical & electronic equipment             NaN           NaN
#
#      ebitda_USD  shortTermInvestments_USD  totalAssets_USD  \
# 0  1.565910e+09                       0.0     1.107567e+10
# 1  1.482090e+09                 7620000.0     1.589659e+10
# 2  2.092800e+09               863200000.0     1.410250e+10
# 3  2.260000e+09                72000000.0     1.248000e+10
# 4           NaN                       NaN              NaN
#
#    totalLiabilities_USD  totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0          1.031240e+09          8.544560e+09   7.302500e+08     1.004443e+10
# 1          6.322060e+09          6.626860e+09   1.647190e+09     9.574530e+09
# 2          4.664400e+09          1.924000e+09   2.493900e+09     9.438100e+09
# 3          8.810000e+09          1.710000e+08   4.344000e+09     3.670000e+09
# 4                   NaN                   NaN            NaN              NaN
#
#    Scope_3_emissions_amount  scope_1_2_emissions_amount  Year_sq
# 0                     17.62                3.389500e+02  4072324
# 1                    425.40                7.197250e+03  4072324
# 2                 271999.00                3.292186e+06  4072324
# 3                4210000.00                3.804718e+05  4072324
# 4                     36.37                7.728538e+03  4072324

# %%
purchased_goods_and_services_no_transform['Primary_sector'].value_counts()
# Out:
# Primary_sector
# Financial services                                    815
# Electrical & electronic equipment                     527
# Chemicals                                             413
# Food & beverage processing                            265
# Construction                                          236
# Media, telecommunications & data center services      201
# Biotech & pharma                                      188
# Specialized professional services                     170
# Powered machinery                                     143
# Discretionary retail                                  120
# Energy utility networks                               108
# Trading, wholesale, distribution, rental & leasing    102
# Convenience retail                                     91
# Thermal power generation                               88
# Medical equipment & supplies                           88
# Metal products manufacturing                           84
# Paper products & packaging                             82
# Bars, hotels & restaurants                             77
# Plastic product manufacturing                          74
# Leisure & home manufacturing                           63
# IT & software development                              63
# Transportation equipment                               58
# Metal smelting, refining & forming                     58
# Metallic mineral mining                                56
# Intermodal transport & logistics                       55
# Print & publishing services                            55
# Web & marketing services                               53
# Other services                                         51
# Light manufacturing                                    48
# Commercial & consumer services                         44
# 0                                                      43
# Cement & concrete                                      43
# Wood & rubber products                                 43
# Rail transport                                         42
# Land & property ownership & development                41
# Air transport                                          39
# Wood & paper materials                                 38
# Textiles & fabric goods                                35
# Other materials                                        34
# Non-energy utilities                                   34
# Entertainment facilities                               32
# Tobacco                                                30
# Fish & animal farming                                  29
# Industrial support services                            27
# Apparel design                                         26
# Marine transport                                       23
# Health care provision                                  17
# Oil & gas extraction & production                      16
# Oil & gas storage & transportation                     15
# Renewable power generation                             13
# Oil & gas processing                                   12
# Renewable energy equipment                             12
# Road transport                                         11
# Oil & gas retailing                                    10
# Accessories                                             9
# Logging & rubber tapping                                6
# Other mineral mining                                    6
# Name: count, dtype: int64

# %%
purchased_goods_and_services_no_transform['Primary_activity'].value_counts().head(20)
# Out:
# Primary_activity
# Banks                                 450
# Insurance                             205
# Electronic components                 199
# Telecommunications services           189
# Other professional services           155
# Pharmaceuticals                       148
# Specialty chemicals                   127
# Other base chemicals                  121
# Personal care & household products    102
# REIT                                   97
# Supermarkets, food & drugstores        91
# Electronic equipment                   90
# Electrical equipment                   84
# Electricity networks                   84
# Paper products                         82
# Other food processing                  80
# Alcoholic beverages                    78
# CCGT generation                        76
# Communications equipment               74
# Plastic products                       74
# Name: count, dtype: int64

# %%
# Looking at missing data
print(purchased_goods_and_services_no_transform.isnull().mean().sort_values(ascending=False).round(3) * 100)
# Out:
# Market_Cap_USD                16.0
# shortTermInvestments_USD      15.6
# totalInvestments_USD          15.6
# totalEquity_USD               15.6
# Revenue_USD                   15.6
# ebitda_USD                    15.6
# totalDebt_USD                 15.6
# totalAssets_USD               15.6
# totalLiabilities_USD          15.6
# scope_1_2_emissions_amount     0.2
# Scope_3_emissions_amount       0.0
# account_id                     0.0
# Year                           0.0
# Primary_sector                 0.0
# Primary_activity               0.0
# Countries                      0.0
# Year_sq                        0.0
# dtype: float64

# %% [markdown]
# Apply signed log transformation and split data by company and year into train_df (2018-2022) and test_df (2023):

# %%
numeric_cols = [
    'Market_Cap_USD', 'shortTermInvestments_USD', 'totalInvestments_USD', 'totalEquity_USD',
    'Revenue_USD', 'ebitda_USD', 'totalDebt_USD', 'totalAssets_USD', 'totalLiabilities_USD',
    'scope_1_2_emissions_amount', 'Scope_3_emissions_amount'
]
required_cols = [
    'account_id', 'Year', 'Year_sq', 'Countries', 'Primary_activity', 'Primary_sector'
] + numeric_cols

# --- Prepare Data ---
df = purchased_goods_and_services_no_transform[required_cols].dropna()

# --- Signed log transform ---
def signed_log(x):
    return np.sign(x) * np.log(np.abs(x) + 1)

for col in numeric_cols:
    df[f'slog_{col}'] = signed_log(df[col])

# --- Company-level split by year ---
train_df = df[df['Year'].between(2018, 2022)].copy()
test_df  = df[df['Year'] == 2023].copy()

# Keep only companies present in training
valid_companies = set(train_df['account_id'].unique())
test_df = test_df[test_df['account_id'].isin(valid_companies)].copy()

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (3483, 28)
# Test shape: (724, 28)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3483 entries, 0 to 4177
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       3483 non-null   int64
#  1   Year                             3483 non-null   int64
#  2   Year_sq                          3483 non-null   int64
#  3   Countries                        3483 non-null   object
#  4   Primary_activity                 3483 non-null   object
#  5   Primary_sector                   3483 non-null   object
#  6   Market_Cap_USD                   3483 non-null   float64
#  7   shortTermInvestments_USD         3483 non-null   float64
#  8   totalInvestments_USD             3483 non-null   float64
#  9   totalEquity_USD                  3483 non-null   float64
#  10  Revenue_USD                      3483 non-null   float64
#  11  ebitda_USD                       3483 non-null   float64
#  12  totalDebt_USD                    3483 non-null   float64
#  13  totalAssets_USD                  3483 non-null   float64
#  14  totalLiabilities_USD             3483 non-null   float64
#  15  scope_1_2_emissions_amount       3483 non-null   float64
#  16  Scope_3_emissions_amount         3483 non-null   float64
#  17  slog_Market_Cap_USD              3483 non-null   float64
#  18  slog_shortTermInvestments_USD    3483 non-null   float64
#  19  slog_totalInvestments_USD        3483 non-null   float64
#  20  slog_totalEquity_USD             3483 non-null   float64
#  21  slog_Revenue_USD                 3483 non-null   float64
#  22  slog_ebitda_USD                  3483 non-null   float64
#  23  slog_totalDebt_USD               3483 non-null   float64
#  24  slog_totalAssets_USD             3483 non-null   float64
#  25  slog_totalLiabilities_USD        3483 non-null   float64
#  26  slog_scope_1_2_emissions_amount  3483 non-null   float64
#  27  slog_Scope_3_emissions_amount    3483 non-null   float64
# dtypes: float64(22), int64(3), object(3)
# memory usage: 789.1+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 724 entries, 4181 to 5159
# Data columns (total 28 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       724 non-null    int64
#  1   Year                             724 non-null    int64
#  2   Year_sq                          724 non-null    int64
#  3   Countries                        724 non-null    object
#  4   Primary_activity                 724 non-null    object
#  5   Primary_sector                   724 non-null    object
#  6   Market_Cap_USD                   724 non-null    float64
#  7   shortTermInvestments_USD         724 non-null    float64
#  8   totalInvestments_USD             724 non-null    float64
#  9   totalEquity_USD                  724 non-null    float64
#  10  Revenue_USD                      724 non-null    float64
#  11  ebitda_USD                       724 non-null    float64
#  12  totalDebt_USD                    724 non-null    float64
#  13  totalAssets_USD                  724 non-null    float64
#  14  totalLiabilities_USD             724 non-null    float64
#  15  scope_1_2_emissions_amount       724 non-null    float64
#  16  Scope_3_emissions_amount         724 non-null    float64
#  17  slog_Market_Cap_USD              724 non-null    float64
#  18  slog_shortTermInvestments_USD    724 non-null    float64
#  19  slog_totalInvestments_USD        724 non-null    float64
#  20  slog_totalEquity_USD             724 non-null    float64
#  21  slog_Revenue_USD                 724 non-null    float64
#  22  slog_ebitda_USD                  724 non-null    float64
#  23  slog_totalDebt_USD               724 non-null    float64
#  24  slog_totalAssets_USD             724 non-null    float64
#  25  slog_totalLiabilities_USD        724 non-null    float64
#  26  slog_scope_1_2_emissions_amount  724 non-null    float64
#  27  slog_Scope_3_emissions_amount    724 non-null    float64
# dtypes: float64(22), int64(3), object(3)
# memory usage: 164.0+ KB

# %%
print((train_df == 0).sum().sum())
print((test_df == 0).sum().sum())
# Out:
# 1578
# 464

# %% [markdown]
# ## Purchased Goods and Services Null Mixed-Effects Model
#
# Null mixed-effects model (random intercept only) to predict log-transformed Scope 3 emissions. The model serves as a baseline, capturing only the average emission level for each company, without incorporating any explanatory variables, and quantifies the improvement gained by including additional features and structure. The model is trained on 2018–2022 data and evaluated on a test set from 2023.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies
# - Fixed Effects:
#     - Intercept only (no predictors)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE NULL MODEL (random intercept only) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    null_model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ 1",
        train_df,
        groups=train_df["account_id"]
    )
    null_result = null_model.fit(method="lbfgs")

if not null_result.converged:
    print("WARNING: Null model did not fully converge.")

print(null_result.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_null'] = null_result.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_null']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_null'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics text
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[0], color='gray')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Null Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[1], color='gray')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Null Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Null Model Predicted")
plt.xscale("log")
plt.title("Null Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
null_model_metrics = {
    "Model": "Null (RI)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "Random intercept only"
}
# Out:
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 3483    Method:             REML
# No. Groups:       814     Scale:              0.9888
# Min. group size:  1       Log-Likelihood:     -6411.7736
# Max. group size:  5       Converged:          Yes
# Mean group size:  4.3
# ------------------------------------------------------------------------------
#                Coef.      Std.Err.        z        P>|z|     [0.025     0.975]
# ------------------------------------------------------------------------------
# Intercept      12.309        0.109     112.925     0.000     12.095     12.523
# Group Var       9.388        0.550
# ==========================================================================
#
# R²(log):    -4.12%
# R²(orig):   -22.10%
# MAPE:       86705.52%
# MAPE(log):  27.92%
# MAE(log):   2.29
# RMSLE:      2.92
# RMSE:       5685117.65
# MAE:        2513590.11

# %% [markdown]
# ## Purchased Goods and Services Two-Level Mixed-Effects Model
#
# Two-level hierarchical linear mixed-effects model to predict log-transformed Scope 3 emissions at the company level. The model is fit to training data (from 2018–2022), and predictions are evaluated on a test set (from 2023).  This model provides a baseline for including time trends and company-level variability.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies.<br>
# - Fixed Effects:
#     - Year (numeric)
#     - Year squared ('Year_sq', quadratic time trend)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- Check group sizes ---
group_sizes = train_df.groupby('account_id').size()
print("Two-Level Model: Company/year group size summary:")
print(group_sizes.describe())

# --- FIT THE TWO-LEVEL MODEL (random intercept, +Year, +Year_sq) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ Year + Year_sq",
        train_df,
        groups=train_df["account_id"],
        re_formula="1"
    )
    result_twolevel = model.fit(method="lbfgs")

if not result_twolevel.converged:
    print("WARNING: Two-level mixed model did not fully converge.")

print(result_twolevel.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_twolevel.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_mixed']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='orange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Two-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='orange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Two-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="orange", alpha=0.5, label="Two-Level Model Predicted")
plt.xscale("log")
plt.title("Two-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
two_level_model_metrics = {
    "Model": "2-level (RI+S)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "+Year, Year_sq"
}
# Out:
# Two-Level Model: Company/year group size summary:
# count    814.000000
# mean       4.278870
# std        1.265347
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000
# dtype: float64
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 3483    Method:             REML
# No. Groups:       814     Scale:              0.9619
# Min. group size:  1       Log-Likelihood:     -6380.4008
# Max. group size:  5       Converged:          Yes
# Mean group size:  4.3
# ----------------------------------------------------------------------------
#                Coef.      Std.Err.     z      P>|z|     [0.025      0.975]
# ----------------------------------------------------------------------------
# Intercept    99363.161   41567.138    2.390   0.017   17893.068   180833.253
# Year           -98.470      41.155   -2.393   0.017    -179.133      -17.808
# Year_sq          0.024       0.010    2.395   0.017       0.004        0.044
# Group Var        9.380       0.557
# ==========================================================================
#
# R²(log):    -0.20%
# R²(orig):   -19.83%
# MAPE:       136501.40%
# MAPE(log):  27.80%
# MAE(log):   2.15
# RMSLE:      2.86
# RMSE:       5632116.35
# MAE:        2475088.07

# %% [markdown]
# ## Purchased Goods and Services Three-Level Mixed-Effects Model
#
# A three-level hierarchical linear mixed-effects model is used to predict log-transformed Scope 3 emissions. It takes into account differences between primary activity, differences between companies, and changes over time. The model is trained using data from 2018 to 2022, and then tested on new data from 2023. This model provides insight on how emissions are influenced by primary activity, by individual companies, by financial and emissions factors, and by trends over time.
#
# Model Structure:
#
# - Level 3 (Primary Activity):<br>
#     - Random intercept and random slope for Year for each primary activity ('Primary_activity'), capturing baseline primary activity and primary activity-specific time trends.<br>
# - Level 2 (Account/Company):
#     - Random intercept for each company ('account_id'), capturing company-level deviations within each primary activity.
# - Level 1 (Yearly Observations):
#     - Repeated annual observations within each company.
#
# - Fixed Effects:
#     - Signed log-transformed market cap ('slog_Market_Cap_USD')
#     - Signed log-transformed revenue ('slog_Revenue_USD')
#     - Signed log-transformed EBITDA ('slog_ebitda_USD')
#     - Signed log-transformed Scope 1 & 2 emissions ('slog_scope_1_2_emissions_amount')

# %%
# --- Ensure grouping/categorical variables are string ---
for col in ['Countries', 'account_id', 'Primary_activity', 'Primary_sector']:
    train_df[col] = train_df[col].astype(str)
    test_df[col] = test_df[col].astype(str)

# --- Center the Year variable ---
year_mean = train_df['Year'].mean()
train_df['Year_centered'] = train_df['Year'] - year_mean
test_df['Year_centered'] = test_df['Year'] - year_mean

# --- Ensure log-transformed target exists ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE 3-LEVEL MIXED MODEL with Primary_activity as Level 3 group ---
vc = {'account_id': '0 + C(account_id)'}  # Level 2: account_id random intercept

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model_3level = MixedLM.from_formula(
        'log_Scope_3_emissions_amount ~ slog_Market_Cap_USD + slog_Revenue_USD + slog_ebitda_USD + slog_scope_1_2_emissions_amount',
        groups='Primary_activity',
        re_formula='~Year_centered',
        vc_formula=vc,
        data=train_df
    )
    result_3level = model_3level.fit(method="lbfgs", maxiter=1000)

if not result_3level.converged:
    print("WARNING: Three-level mixed model did not fully converge.")

print(result_3level.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_3level.predict(test_df)

# --- Compute back-transformed values ---
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])

# --- Robust Mask for finite values everywhere ---
mask = (
    np.isfinite(test_df['log_Scope_3_emissions_amount']) &
    np.isfinite(test_df['predicted_mixed']) &
    np.isfinite(test_df['Reported_Scope_3']) &
    np.isfinite(test_df['Predicted_Scope_3'])
)
test_df = test_df.loc[mask].copy()

y_true_log = test_df['log_Scope_3_emissions_amount'].values
y_pred_log = test_df['predicted_mixed'].values
y_true = test_df['Reported_Scope_3'].values
y_pred = test_df['Predicted_Scope_3'].values

# Final defensive check and diagnostics
arrays = {
    "y_true_log": y_true_log,
    "y_pred_log": y_pred_log,
    "y_true": y_true,
    "y_pred": y_pred,
}
for arr_name, arr in arrays.items():
    if not np.all(np.isfinite(arr)):
        print(f"ERROR: {arr_name} contains non-finite values!")
        print(f"Non-finite indices: {np.where(~np.isfinite(arr))[0]}")
        print(f"Values: {arr[~np.isfinite(arr)]}")
        raise ValueError(f"{arr_name} contains infs or NaNs after masking!")

# --- METRICS ---
mae_log = mean_absolute_error(y_true_log, y_pred_log)
nonzero_mask = y_true_log != 0
if np.any(nonzero_mask):
    mape_log = np.mean(np.abs((y_true_log[nonzero_mask] - y_pred_log[nonzero_mask]) / y_true_log[nonzero_mask])) * 100
else:
    mape_log = np.nan

r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)

metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
if len(np.unique(y_pred_log)) > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Three-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()
axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

if len(np.unique(y_pred)) > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Three-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()
axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Filter strictly positive values for histogram (log x-axis requires >0)
y_true_pos = y_true[y_true > 0]
y_pred_pos = y_pred[y_pred > 0]

if y_true_pos.size > 0 and y_pred_pos.size > 0:
    min_val = min(y_true_pos.min(), y_pred_pos.min())
    max_val = max(y_true_pos.max(), y_pred_pos.max())
    if min_val == max_val:
        print("Skipping histogram: Only one unique positive value present.")
    else:
        log_bins = np.logspace(np.log10(min_val), np.log10(max_val), 100)

        plt.figure(figsize=(8, 5))
        sns.histplot(y_true_pos, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
        sns.histplot(y_pred_pos, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Three-Level Model Predicted")
        plt.xscale("log")
        plt.title("Three-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
        plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
        plt.ylabel("Density")
        plt.legend()
        plt.tight_layout()
        plt.show()
else:
    print("Skipping histogram: Not enough positive values in y_true or y_pred for log-scale histogram.")

# --- RETURN METRICS FOR SUMMARY TABLE ---
three_level_model_metrics = {
    "Model": "3-level (Primary Activity/Account/Year)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,
    "MAPE(log)": mape_log,
}
# Out:
#                      Mixed Linear Model Regression Results
# ===============================================================================
# Model:               MixedLM  Dependent Variable:  log_Scope_3_emissions_amount
# No. Observations:    3483     Method:              REML
# No. Groups:          124      Scale:               0.8967
# Min. group size:     1        Log-Likelihood:      -6147.1773
# Max. group size:     274      Converged:           Yes
# Mean group size:     28.1
# -------------------------------------------------------------------------------
#                                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------------
# Intercept                             1.981    0.973  2.037 0.042  0.075  3.888
# slog_Market_Cap_USD                   0.282    0.041  6.820 0.000  0.201  0.363
# slog_Revenue_USD                      0.049    0.014  3.546 0.000  0.022  0.076
# slog_ebitda_USD                      -0.003    0.003 -0.932 0.351 -0.010  0.003
# slog_scope_1_2_emissions_amount       0.270    0.028  9.611 0.000  0.215  0.325
# Primary_activity Var                  2.288    0.487
# Primary_activity x Year_centered Cov -0.105    0.067
# Year_centered Var                     0.075    0.017
# account_id Var                        4.368    0.311
# ===============================================================================
#
# R²(log):    18.91%
# R²(orig):   -11.23%
# MAPE:       174131.54%
# MAPE(log):  25.14%
# MAE(log):   1.88
# RMSLE:      2.57
# RMSE:       5426247.23
# MAE:        2319413.04

# %% [markdown]
# ## Purchased Goods and Services Full Mixed-Effects Model
#
# A full mixed-effects model is used to predict company Scope 3 emissions, using financial and emissions data, along with information about country, industry, and year. The model is trained on data from 2018 to 2022, and tested on data from 2023. This full model helps provides insights into how a company’s finances, emissions, primary activity, country and the year influence emissions.<br>
#
# Model Structure:<br>
#
#
# - Random Effects:<br>
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:<br>
#     - Signed log-transformed financial and emissions features:<br>
#         - Market Cap ('slog_Market_Cap_USD')<br>
#         - Revenue ('slog_Revenue_USD')<br>
#         - EBITDA ('slog_ebitda_USD')<br>
#         - Total Investments ('slog_totalInvestments_USD')<br>
#         - Total Debt ('slog_totalDebt_USD')<br>
#         - Total Liabilities ('slog_totalLiabilities_USD')<br>
#         - Short-Term Investments ('slog_shortTermInvestments_USD')<br>
#         - Total Assets ('slog_totalAssets_USD')<br>
#         - Total Equity ('slog_totalEquity_USD')<br>
#         - Scope 1&2 Emissions ('slog_scope_1_2_emissions_amount')<br>
#     - Country ('Countries', as a categorical variable)<br>
#     - Primary Activity ('Primary_activity', as a categorical variable)<br>
#     - Year (numeric)<br>

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3483 entries, 0 to 4177
# Data columns (total 30 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       3483 non-null   object
#  1   Year                             3483 non-null   int64
#  2   Year_sq                          3483 non-null   int64
#  3   Countries                        3483 non-null   object
#  4   Primary_activity                 3483 non-null   object
#  5   Primary_sector                   3483 non-null   object
#  6   Market_Cap_USD                   3483 non-null   float64
#  7   shortTermInvestments_USD         3483 non-null   float64
#  8   totalInvestments_USD             3483 non-null   float64
#  9   totalEquity_USD                  3483 non-null   float64
#  10  Revenue_USD                      3483 non-null   float64
#  11  ebitda_USD                       3483 non-null   float64
#  12  totalDebt_USD                    3483 non-null   float64
#  13  totalAssets_USD                  3483 non-null   float64
#  14  totalLiabilities_USD             3483 non-null   float64
#  15  scope_1_2_emissions_amount       3483 non-null   float64
#  16  Scope_3_emissions_amount         3483 non-null   float64
#  17  slog_Market_Cap_USD              3483 non-null   float64
#  18  slog_shortTermInvestments_USD    3483 non-null   float64
#  19  slog_totalInvestments_USD        3483 non-null   float64
#  20  slog_totalEquity_USD             3483 non-null   float64
#  21  slog_Revenue_USD                 3483 non-null   float64
#  22  slog_ebitda_USD                  3483 non-null   float64
#  23  slog_totalDebt_USD               3483 non-null   float64
#  24  slog_totalAssets_USD             3483 non-null   float64
#  25  slog_totalLiabilities_USD        3483 non-null   float64
#  26  slog_scope_1_2_emissions_amount  3483 non-null   float64
#  27  slog_Scope_3_emissions_amount    3483 non-null   float64
#  28  log_Scope_3_emissions_amount     3483 non-null   float64
#  29  Year_centered                    3483 non-null   float64
# dtypes: float64(24), int64(2), object(4)
# memory usage: 972.6+ KB

# %%
# --- Feature and target columns ---
numeric_cols = [
    'Market_Cap_USD','shortTermInvestments_USD', 'totalInvestments_USD', 'totalEquity_USD', 'Revenue_USD', 'ebitda_USD', 'totalDebt_USD', 'totalAssets_USD',
    'totalLiabilities_USD', 'scope_1_2_emissions_amount', 'Scope_3_emissions_amount'
]
feature_cols_slog = [f'slog_{col}' for col in numeric_cols if col != 'Scope_3_emissions_amount']
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
required_cols = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_full = train_df.dropna(subset=required_cols).copy()
test_df_full = test_df.dropna(subset=required_cols).copy()

if test_df_full.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the full mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_full, groups=train_df_full['account_id'])
        mdf = md.fit(reml=False)
    print(mdf.summary())

    # --- Predict on test set ---
    test_df_full['predicted_log'] = mdf.predict(test_df_full)
    test_df_full['predicted'] = np.sign(test_df_full['predicted_log']) * (np.expm1(np.abs(test_df_full['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_full[target_col_slog]
    y_pred_log = test_df_full['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_full['predicted']

    # Mask for finite values
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nFull Mixed-Effects Model (Full Model) Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf.params,
        'pvalue': mdf.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Full Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Full Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Full Model Predicted")
    plt.xscale("log")
    plt.title("Full Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    full_model_metrics = {
        "Model": "Full Model",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                           Mixed Linear Model Regression Results
# ==========================================================================================================================
# Model:                             MixedLM                Dependent Variable:                slog_Scope_3_emissions_amount
# No. Observations:                  3483                   Method:                            ML
# No. Groups:                        814                    Scale:                             0.9776
# Min. group size:                   1                      Log-Likelihood:                    -5894.9291
# Max. group size:                   5                      Converged:                         Yes
# Mean group size:                   4.3
# --------------------------------------------------------------------------------------------------------------------------
#                                                                            Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 -162.483   25.339 -6.412 0.000 -212.147 -112.819
# C(Countries)[T.Austria]                                                     -0.938    1.051 -0.892 0.372   -2.997    1.122
# C(Countries)[T.Belgium]                                                      0.491    0.786  0.625 0.532   -1.050    2.032
# C(Countries)[T.Bermuda]                                                      0.233    1.322  0.177 0.860   -2.357    2.824
# C(Countries)[T.Brazil]                                                      -2.085    0.706 -2.954 0.003   -3.468   -0.702
# C(Countries)[T.Canada]                                                       0.653    0.586  1.114 0.265   -0.496    1.802
# C(Countries)[T.Chile]                                                        0.032    1.935  0.016 0.987   -3.761    3.824
# C(Countries)[T.China]                                                        0.026    0.682  0.038 0.970   -1.310    1.362
# C(Countries)[T.Denmark]                                                     -1.533    0.907 -1.690 0.091   -3.310    0.245
# C(Countries)[T.Finland]                                                      1.000    0.685  1.460 0.144   -0.342    2.343
# C(Countries)[T.France]                                                       0.387    0.578  0.671 0.502   -0.745    1.519
# C(Countries)[T.Germany]                                                      0.518    0.584  0.888 0.375   -0.626    1.662
# C(Countries)[T.Greece]                                                       0.870    1.125  0.773 0.440   -1.336    3.075
# C(Countries)[T.Hungary]                                                     -2.571    1.753 -1.467 0.142   -6.007    0.864
# C(Countries)[T.India]                                                       -3.701    1.324 -2.795 0.005   -6.296   -1.105
# C(Countries)[T.Ireland]                                                     -0.420    0.776 -0.541 0.589   -1.941    1.101
# C(Countries)[T.Israel]                                                      -2.640    1.442 -1.831 0.067   -5.467    0.187
# C(Countries)[T.Italy]                                                       -1.083    0.683 -1.586 0.113   -2.421    0.255
# C(Countries)[T.Japan]                                                        0.603    0.511  1.179 0.238   -0.399    1.605
# C(Countries)[T.Luxembourg]                                                  -0.506    1.946 -0.260 0.795   -4.321    3.309
# C(Countries)[T.Mexico]                                                      -0.513    1.144 -0.448 0.654   -2.756    1.730
# C(Countries)[T.Netherlands]                                                  0.455    0.742  0.613 0.540   -1.000    1.910
# C(Countries)[T.New Zealand]                                                  1.212    0.969  1.251 0.211   -0.687    3.112
# C(Countries)[T.Norway]                                                       0.259    0.735  0.352 0.724   -1.182    1.700
# C(Countries)[T.Peru]                                                        -0.056    1.752 -0.032 0.974   -3.489    3.377
# C(Countries)[T.Portugal]                                                     1.971    1.410  1.398 0.162   -0.793    4.734
# C(Countries)[T.Singapore]                                                    1.809    1.449  1.248 0.212   -1.031    4.649
# C(Countries)[T.South Africa]                                                -2.532    0.575 -4.400 0.000   -3.660   -1.404
# C(Countries)[T.South Korea]                                                 -2.100    0.615 -3.413 0.001   -3.306   -0.894
# C(Countries)[T.Spain]                                                       -0.942    0.600 -1.570 0.116   -2.118    0.234
# C(Countries)[T.Sweden]                                                       0.268    0.854  0.314 0.753   -1.405    1.942
# C(Countries)[T.Switzerland]                                                 -0.259    0.606 -0.427 0.669   -1.447    0.929
# C(Countries)[T.Thailand]                                                    -1.496    1.012 -1.479 0.139   -3.479    0.487
# C(Countries)[T.Turkey]                                                      -1.143    2.006 -0.570 0.569   -5.075    2.789
# C(Countries)[T.USA]                                                          1.030    0.507  2.033 0.042    0.037    2.022
# C(Countries)[T.United Kingdom]                                               0.766    0.531  1.443 0.149   -0.275    1.807
# C(Primary_activity)[T.Accessories manufacture]                               4.360    1.405  3.103 0.002    1.606    7.114
# C(Primary_activity)[T.Aerospace]                                             2.126    1.844  1.153 0.249   -1.488    5.741
# C(Primary_activity)[T.Agricultural chemicals]                                2.810    1.809  1.553 0.120   -0.735    6.355
# C(Primary_activity)[T.Agriculture, construction & mining machinery]          4.172    1.000  4.171 0.000    2.211    6.132
# C(Primary_activity)[T.Alcoholic beverages]                                   4.168    0.883  4.721 0.000    2.438    5.898
# C(Primary_activity)[T.Animal processing]                                     2.593    1.111  2.333 0.020    0.415    4.770
# C(Primary_activity)[T.Apparel & footwear design]                             4.959    1.048  4.735 0.000    2.906    7.013
# C(Primary_activity)[T.Apparel stores]                                        3.945    0.887  4.445 0.000    2.205    5.684
# C(Primary_activity)[T.Aquaculture]                                           4.271    1.327  3.217 0.001    1.669    6.872
# C(Primary_activity)[T.Asset managers]                                       -1.372    0.899 -1.526 0.127   -3.133    0.390
# C(Primary_activity)[T.Automobiles]                                           4.523    0.995  4.546 0.000    2.573    6.474
# C(Primary_activity)[T.Baked goods & cereals]                                 4.507    1.808  2.493 0.013    0.964    8.050
# C(Primary_activity)[T.Banks]                                                -1.329    0.749 -1.774 0.076   -2.798    0.139
# C(Primary_activity)[T.Batteries]                                             3.040    1.217  2.497 0.013    0.654    5.426
# C(Primary_activity)[T.Biotechnology]                                         2.201    0.958  2.297 0.022    0.323    4.079
# C(Primary_activity)[T.Building sub-contractors]                              3.520    1.217  2.892 0.004    1.134    5.905
# C(Primary_activity)[T.Bus & taxi]                                           -5.301    1.819 -2.914 0.004   -8.867   -1.735
# C(Primary_activity)[T.CCGT generation]                                       1.824    0.909  2.006 0.045    0.042    3.605
# C(Primary_activity)[T.Cattle farming]                                        9.461    1.879  5.036 0.000    5.779   13.143
# C(Primary_activity)[T.Cement]                                                4.168    1.151  3.620 0.000    1.911    6.424
# C(Primary_activity)[T.Chocolate confection]                                  6.498    1.831  3.548 0.000    2.908   10.088
# C(Primary_activity)[T.Clothing manufacture]                                  3.456    1.056  3.272 0.001    1.385    5.526
# C(Primary_activity)[T.Coal generation]                                      -1.125    2.068 -0.544 0.587   -5.177    2.928
# C(Primary_activity)[T.Commercial services]                                   1.929    1.048  1.841 0.066   -0.125    3.983
# C(Primary_activity)[T.Communications equipment]                              2.924    0.884  3.307 0.001    1.191    4.657
# C(Primary_activity)[T.Computer hardware]                                     3.645    0.967  3.768 0.000    1.749    5.541
# C(Primary_activity)[T.Concrete products]                                     4.741    1.908  2.484 0.013    1.000    8.481
# C(Primary_activity)[T.Consumer services]                                     3.218    1.845  1.744 0.081   -0.399    6.834
# C(Primary_activity)[T.Dairy & egg products]                                  6.825    1.137  6.004 0.000    4.597    9.053
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                   3.778    0.920  4.105 0.000    1.974    5.581
# C(Primary_activity)[T.Department stores]                                     3.831    1.381  2.774 0.006    1.124    6.538
# C(Primary_activity)[T.Discretionary delivery retail]                         3.737    1.204  3.104 0.002    1.377    6.097
# C(Primary_activity)[T.Education services]                                    5.888    1.815  3.244 0.001    2.330    9.446
# C(Primary_activity)[T.Electrical equipment]                                  4.248    0.863  4.922 0.000    2.556    5.939
# C(Primary_activity)[T.Electricity networks]                                  1.721    0.884  1.947 0.052   -0.012    3.455
# C(Primary_activity)[T.Electronic components]                                 3.340    0.777  4.297 0.000    1.816    4.863
# C(Primary_activity)[T.Electronic equipment]                                  3.546    0.837  4.236 0.000    1.905    5.186
# C(Primary_activity)[T.Energy infrastructure construction]                    6.029    1.426  4.228 0.000    3.234    8.825
# C(Primary_activity)[T.Energy services & equipment]                           2.568    1.157  2.220 0.026    0.301    4.834
# C(Primary_activity)[T.Engineering services]                                  0.394    1.260  0.313 0.754   -2.075    2.864
# C(Primary_activity)[T.Engines & motors]                                      3.756    0.971  3.868 0.000    1.853    5.659
# C(Primary_activity)[T.Fabricated metal components]                           4.088    0.903  4.528 0.000    2.319    5.858
# C(Primary_activity)[T.Fast food]                                             3.311    1.228  2.695 0.007    0.903    5.718
# C(Primary_activity)[T.Finished wood products]                                2.306    1.946  1.185 0.236   -1.508    6.120
# C(Primary_activity)[T.Fishing]                                               4.420    1.841  2.401 0.016    0.811    8.029
# C(Primary_activity)[T.Food & beverage amenities]                             4.843    1.390  3.484 0.000    2.119    7.567
# C(Primary_activity)[T.Food & beverage wholesale]                             6.076    1.388  4.379 0.000    3.356    8.795
# C(Primary_activity)[T.Furniture]                                             4.000    1.044  3.831 0.000    1.954    6.047
# C(Primary_activity)[T.Gambling]                                              2.224    1.042  2.134 0.033    0.181    4.266
# C(Primary_activity)[T.Gas utilities]                                         1.771    1.126  1.572 0.116   -0.437    3.978
# C(Primary_activity)[T.Glass products]                                        3.604    1.219  2.956 0.003    1.215    5.993
# C(Primary_activity)[T.Grain & corn milling]                                  3.693    1.813  2.037 0.042    0.140    7.247
# C(Primary_activity)[T.Health care facilities]                                0.700    1.412  0.495 0.620   -2.069    3.468
# C(Primary_activity)[T.Health care services]                                  2.086    1.121  1.862 0.063   -0.110    4.283
# C(Primary_activity)[T.Health care supplies]                                  2.963    1.033  2.868 0.004    0.938    4.987
# C(Primary_activity)[T.Homeware]                                              3.741    1.838  2.035 0.042    0.138    7.344
# C(Primary_activity)[T.Hotels & lodging]                                      2.793    0.938  2.978 0.003    0.955    4.631
# C(Primary_activity)[T.Industrial machinery]                                  3.336    0.890  3.750 0.000    1.592    5.079
# C(Primary_activity)[T.Inorganic base chemicals]                              3.694    1.109  3.331 0.001    1.520    5.868
# C(Primary_activity)[T.Insurance]                                            -1.648    0.767 -2.148 0.032   -3.152   -0.144
# C(Primary_activity)[T.Intermodal transport]                                 -0.132    1.812 -0.073 0.942   -3.684    3.421
# C(Primary_activity)[T.Iron & steel]                                          4.756    1.149  4.138 0.000    2.503    7.008
# C(Primary_activity)[T.Logging]                                               4.643    1.811  2.564 0.010    1.093    8.194
# C(Primary_activity)[T.Logistics - 3rd party]                                 1.519    1.064  1.428 0.153   -0.566    3.604
# C(Primary_activity)[T.Logistics - transport]                                 2.471    1.830  1.350 0.177   -1.115    6.057
# C(Primary_activity)[T.Marine freight]                                        0.071    1.240  0.057 0.954   -2.359    2.501
# C(Primary_activity)[T.Marketing]                                             0.848    0.889  0.954 0.340   -0.894    2.589
# C(Primary_activity)[T.Medical equipment]                                     2.319    0.871  2.663 0.008    0.612    4.025
# C(Primary_activity)[T.Metal containers & packaging]                          4.813    1.040  4.629 0.000    2.775    6.851
# C(Primary_activity)[T.Metal processing]                                      4.240    1.414  2.998 0.003    1.468    7.012
# C(Primary_activity)[T.Nitrogenous fertilizers]                               5.652    1.251  4.519 0.000    3.201    8.103
# C(Primary_activity)[T.Non-CCGT generation]                                   1.232    1.450  0.850 0.395   -1.609    4.074
# C(Primary_activity)[T.Non-alcoholic beverages]                               4.200    0.986  4.257 0.000    2.266    6.133
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                           2.589    1.536  1.686 0.092   -0.421    5.598
# C(Primary_activity)[T.Non-residential building construction]                 4.150    0.885  4.687 0.000    2.414    5.885
# C(Primary_activity)[T.Oil & gas extraction]                                 -2.563    1.173 -2.186 0.029   -4.861   -0.265
# C(Primary_activity)[T.Oil & gas marketing & retailing]                       2.852    1.444  1.976 0.048    0.023    5.682
# C(Primary_activity)[T.Oil & gas pipelines & storage]                         1.083    1.233  0.879 0.380   -1.333    3.499
# C(Primary_activity)[T.Oil & gas refining]                                    3.484    1.399  2.490 0.013    0.741    6.227
# C(Primary_activity)[T.Other base chemicals]                                  4.396    0.825  5.329 0.000    2.779    6.012
# C(Primary_activity)[T.Other containers & packaging]                          3.946    1.212  3.256 0.001    1.571    6.322
# C(Primary_activity)[T.Other food processing]                                 4.750    0.892  5.323 0.000    3.001    6.499
# C(Primary_activity)[T.Other non-ferrous ore mining]                          3.157    1.206  2.618 0.009    0.793    5.520
# C(Primary_activity)[T.Other non-metallic minerals]                          -5.609    1.832 -3.062 0.002   -9.200   -2.019
# C(Primary_activity)[T.Other non-wood building materials]                     4.036    1.430  2.823 0.005    1.234    6.839
# C(Primary_activity)[T.Other professional services]                           2.324    0.807  2.879 0.004    0.742    3.906
# C(Primary_activity)[T.Other renewable energy equipment]                      7.168    1.966  3.647 0.000    3.315   11.021
# C(Primary_activity)[T.Other renewable generation]                           -2.207    2.244 -0.983 0.325   -6.605    2.191
# C(Primary_activity)[T.Paper products]                                        3.340    0.925  3.611 0.000    1.527    5.152
# C(Primary_activity)[T.Passenger airlines]                                    0.337    0.946  0.356 0.722   -1.518    2.191
# C(Primary_activity)[T.Passenger rail]                                        0.016    1.398  0.011 0.991   -2.724    2.756
# C(Primary_activity)[T.Personal care & household products]                    3.794    0.841  4.510 0.000    2.145    5.443
# C(Primary_activity)[T.Pharmaceuticals]                                       2.577    0.793  3.251 0.001    1.023    4.131
# C(Primary_activity)[T.Plastic products]                                      3.658    0.937  3.904 0.000    1.822    5.495
# C(Primary_activity)[T.Precious metals & minerals mining]                     2.768    1.022  2.710 0.007    0.766    4.770
# C(Primary_activity)[T.Print publishing]                                      2.419    1.065  2.272 0.023    0.332    4.505
# C(Primary_activity)[T.Printing services]                                     4.577    1.381  3.315 0.001    1.871    7.283
# C(Primary_activity)[T.Pulp & paper mills]                                    3.489    1.109  3.147 0.002    1.316    5.662
# C(Primary_activity)[T.REIT]                                                  0.868    0.823  1.055 0.292   -0.745    2.480
# C(Primary_activity)[T.Rail freight]                                          0.205    1.049  0.195 0.845   -1.850    2.260
# C(Primary_activity)[T.Railroad rolling stock]                                3.632    1.831  1.984 0.047    0.044    7.220
# C(Primary_activity)[T.Real estate owners & developers]                       0.169    1.129  0.149 0.881   -2.043    2.381
# C(Primary_activity)[T.Real estate services]                                  2.111    1.112  1.899 0.058   -0.068    4.290
# C(Primary_activity)[T.Residential building construction]                     3.312    0.889  3.725 0.000    1.570    5.055
# C(Primary_activity)[T.Rubber products]                                       4.894    1.045  4.682 0.000    2.845    6.943
# C(Primary_activity)[T.Semiconductors]                                        3.221    1.153  2.793 0.005    0.961    5.481
# C(Primary_activity)[T.Servers & data centers]                                1.931    1.386  1.393 0.164   -0.787    4.648
# C(Primary_activity)[T.Software]                                              1.744    0.877  1.989 0.047    0.025    3.464
# C(Primary_activity)[T.Solar energy equipment]                                3.153    1.811  1.741 0.082   -0.397    6.703
# C(Primary_activity)[T.Specialist retail]                                     4.471    1.066  4.194 0.000    2.382    6.561
# C(Primary_activity)[T.Specialty chemicals]                                   4.304    0.814  5.286 0.000    2.708    5.900
# C(Primary_activity)[T.Supermarkets, food & drugstores]                       3.917    0.834  4.699 0.000    2.283    5.551
# C(Primary_activity)[T.Telecommunications services]                           2.610    0.783  3.334 0.001    1.076    4.145
# C(Primary_activity)[T.Textiles]                                              4.231    1.871  2.261 0.024    0.564    7.899
# C(Primary_activity)[T.Tobacco products]                                      3.161    1.097  2.882 0.004    1.011    5.311
# C(Primary_activity)[T.Transportation infrastructure & other construction]    4.446    0.953  4.664 0.000    2.577    6.314
# C(Primary_activity)[T.Transportation support services]                       4.409    1.830  2.409 0.016    0.821    7.996
# C(Primary_activity)[T.Travel services]                                      -4.372    1.810 -2.415 0.016   -7.920   -0.824
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]                 2.268    1.105  2.052 0.040    0.101    4.435
# C(Primary_activity)[T.Waste management]                                      1.796    1.381  1.301 0.193   -0.910    4.502
# C(Primary_activity)[T.Water supply networks]                                 0.833    1.138  0.732 0.464   -1.397    3.063
# C(Primary_activity)[T.Wind generation]                                       1.687    1.886  0.895 0.371   -2.009    5.384
# C(Primary_activity)[T.Wood furniture]                                        4.423    1.818  2.433 0.015    0.860    7.986
# slog_Market_Cap_USD                                                          0.099    0.044  2.238 0.025    0.012    0.185
# slog_shortTermInvestments_USD                                                0.004    0.003  1.381 0.167   -0.002    0.009
# slog_totalInvestments_USD                                                   -0.007    0.005 -1.354 0.176   -0.018    0.003
# slog_totalEquity_USD                                                        -0.004    0.006 -0.662 0.508   -0.015    0.007
# slog_Revenue_USD                                                             0.043    0.014  3.028 0.002    0.015    0.071
# slog_ebitda_USD                                                             -0.003    0.003 -0.778 0.437   -0.010    0.004
# slog_totalDebt_USD                                                           0.004    0.017  0.237 0.813   -0.029    0.038
# slog_totalAssets_USD                                                         0.166    0.043  3.835 0.000    0.081    0.250
# slog_totalLiabilities_USD                                                    0.168    0.035  4.791 0.000    0.099    0.236
# slog_scope_1_2_emissions_amount                                              0.247    0.029  8.588 0.000    0.191    0.304
# Year                                                                         0.078    0.013  6.219 0.000    0.054    0.103
# Group Var                                                                    2.548    0.168
# ==========================================================================================================================
#
#
# Full Mixed-Effects Model (Full Model) Test Set Performance Metrics:
# R²(log):    65.77%
# R²(orig):   18.58%
# MAPE:       784.67%
# MAPE(log):  13.83%
# MAE(log):   1.18
# RMSLE:      1.67
# RMSE:       4642385.62
# MAE:        1688206.98
#
# Top Influential Features (by p-value):
#                                                   coef        pvalue
# Group Var                                     2.606567  7.668950e-53
# slog_scope_1_2_emissions_amount               0.247482  8.824950e-18
# Year                                          0.078375  4.990291e-10
# C(Primary_activity)[T.Dairy & egg products]   6.824737  1.921225e-09
# C(Primary_activity)[T.Other base chemicals]   4.395716  9.881692e-08
# C(Primary_activity)[T.Other food processing]  4.750259  1.020672e-07
# C(Primary_activity)[T.Specialty chemicals]    4.303819  1.253252e-07
# C(Primary_activity)[T.Cattle farming]         9.461025  4.760682e-07
# C(Primary_activity)[T.Electrical equipment]   4.247660  8.571438e-07
# slog_totalLiabilities_USD                     0.167679  1.656079e-06

# %% [markdown]
# ## Purchased Goods and Services Optimized Mixed-Effects Model
#
# An optimized mixed-effects model is used to predict company Scope 3 emissions. The model provides accurate prediction using only the most significant predictive features, while still accounting for primary activity, country and company level effects. The model is trained on data from 2018–2022 and evaluated on test data from 2023.
#
# Model Structure:
#
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:
#     - Signed log-transformed features:
#         - Market Cap ('slog_Market_Cap_USD')
#         - Revenue ('slog_Revenue_USD')
#         - Total Assets ('slog_totalAssets_USD')
#         - Total Liabilities ('slog_totalLiabilities_USD')
#         - Scope 1 & 2 Emissions ('slog_scope_1_2_emissions_amount')
#     - Country ('Countries', as a categorical variable)
#     - Primary Activity ('Primary_activity', as a categorical variable)
#     - Year

# %%
feature_cols_slog = [
    'slog_Market_Cap_USD',
    'slog_Revenue_USD',
    'slog_totalAssets_USD',
    'slog_totalLiabilities_USD',
    'slog_scope_1_2_emissions_amount'
]
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
all_model_vars = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_opt = train_df.dropna(subset=all_model_vars).copy()
test_df_opt = test_df.dropna(subset=all_model_vars).copy()

if test_df_opt.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity)  + Year'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the optimized mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_opt, groups=train_df_opt['account_id'])
        mdf_optimized = md.fit(reml=False)
    print(mdf_optimized.summary())

    # --- Predict on test set ---
    test_df_opt['predicted_log'] = mdf_optimized.predict(test_df_opt)
    test_df_opt['predicted'] = np.sign(test_df_opt['predicted_log']) * (np.expm1(np.abs(test_df_opt['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_opt[target_col_slog]
    y_pred_log = test_df_opt['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_opt['predicted']

    # Mask for valid/finites
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <-- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nOptimized Mixed-Effects Model: Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf_optimized.params,
        'pvalue': mdf_optimized.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Optimized Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Optimized Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Optimized Model Predicted")
    plt.xscale("log")
    plt.title("Optimized Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    optimized_model_metrics = {
        "Model": "Optimized",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                           Mixed Linear Model Regression Results
# ==========================================================================================================================
# Model:                             MixedLM                Dependent Variable:                slog_Scope_3_emissions_amount
# No. Observations:                  3483                   Method:                            ML
# No. Groups:                        814                    Scale:                             0.9790
# Min. group size:                   1                      Log-Likelihood:                    -5897.3105
# Max. group size:                   5                      Converged:                         Yes
# Mean group size:                   4.3
# --------------------------------------------------------------------------------------------------------------------------
#                                                                            Coef.   Std.Err.   z    P>|z|  [0.025   0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 -161.342   25.240 -6.392 0.000 -210.811 -111.873
# C(Countries)[T.Austria]                                                     -0.931    1.051 -0.886 0.376   -2.992    1.129
# C(Countries)[T.Belgium]                                                      0.487    0.786  0.619 0.536   -1.054    2.027
# C(Countries)[T.Bermuda]                                                      0.252    1.322  0.191 0.849   -2.339    2.844
# C(Countries)[T.Brazil]                                                      -2.059    0.705 -2.920 0.003   -3.441   -0.677
# C(Countries)[T.Canada]                                                       0.668    0.586  1.140 0.254   -0.481    1.817
# C(Countries)[T.Chile]                                                        0.079    1.936  0.041 0.967   -3.715    3.873
# C(Countries)[T.China]                                                        0.023    0.681  0.034 0.973   -1.312    1.358
# C(Countries)[T.Denmark]                                                     -1.565    0.907 -1.725 0.084   -3.344    0.213
# C(Countries)[T.Finland]                                                      0.963    0.685  1.406 0.160   -0.380    2.306
# C(Countries)[T.France]                                                       0.383    0.578  0.663 0.508   -0.750    1.515
# C(Countries)[T.Germany]                                                      0.523    0.584  0.896 0.370   -0.621    1.667
# C(Countries)[T.Greece]                                                       0.876    1.126  0.778 0.437   -1.330    3.082
# C(Countries)[T.Hungary]                                                     -2.581    1.754 -1.472 0.141   -6.018    0.856
# C(Countries)[T.India]                                                       -3.671    1.324 -2.772 0.006   -6.267   -1.076
# C(Countries)[T.Ireland]                                                     -0.430    0.777 -0.554 0.579   -1.952    1.092
# C(Countries)[T.Israel]                                                      -2.630    1.443 -1.823 0.068   -5.458    0.198
# C(Countries)[T.Italy]                                                       -1.095    0.683 -1.603 0.109   -2.433    0.244
# C(Countries)[T.Japan]                                                        0.563    0.511  1.101 0.271   -0.439    1.564
# C(Countries)[T.Luxembourg]                                                  -0.593    1.947 -0.305 0.761   -4.409    3.223
# C(Countries)[T.Mexico]                                                      -0.530    1.145 -0.463 0.643   -2.774    1.714
# C(Countries)[T.Netherlands]                                                  0.431    0.743  0.581 0.561   -1.024    1.887
# C(Countries)[T.New Zealand]                                                  1.179    0.969  1.217 0.224   -0.720    3.079
# C(Countries)[T.Norway]                                                       0.228    0.735  0.311 0.756   -1.213    1.670
# C(Countries)[T.Peru]                                                        -0.012    1.752 -0.007 0.995   -3.445    3.422
# C(Countries)[T.Portugal]                                                     2.020    1.410  1.432 0.152   -0.744    4.785
# C(Countries)[T.Singapore]                                                    1.798    1.450  1.240 0.215   -1.044    4.640
# C(Countries)[T.South Africa]                                                -2.541    0.576 -4.416 0.000   -3.669   -1.413
# C(Countries)[T.South Korea]                                                 -2.098    0.615 -3.413 0.001   -3.303   -0.893
# C(Countries)[T.Spain]                                                       -0.938    0.600 -1.564 0.118   -2.113    0.238
# C(Countries)[T.Sweden]                                                       0.258    0.854  0.302 0.763   -1.417    1.932
# C(Countries)[T.Switzerland]                                                 -0.258    0.606 -0.425 0.671   -1.446    0.930
# C(Countries)[T.Thailand]                                                    -1.495    1.012 -1.478 0.139   -3.478    0.487
# C(Countries)[T.Turkey]                                                      -1.103    2.006 -0.550 0.582   -5.035    2.828
# C(Countries)[T.USA]                                                          1.060    0.506  2.094 0.036    0.068    2.053
# C(Countries)[T.United Kingdom]                                               0.752    0.531  1.416 0.157   -0.289    1.793
# C(Primary_activity)[T.Accessories manufacture]                               4.373    1.405  3.112 0.002    1.618    7.127
# C(Primary_activity)[T.Aerospace]                                             2.065    1.845  1.119 0.263   -1.551    5.681
# C(Primary_activity)[T.Agricultural chemicals]                                2.827    1.810  1.562 0.118   -0.720    6.374
# C(Primary_activity)[T.Agriculture, construction & mining machinery]          4.229    1.000  4.230 0.000    2.270    6.189
# C(Primary_activity)[T.Alcoholic beverages]                                   4.184    0.883  4.740 0.000    2.454    5.914
# C(Primary_activity)[T.Animal processing]                                     2.638    1.111  2.375 0.018    0.461    4.816
# C(Primary_activity)[T.Apparel & footwear design]                             4.965    1.048  4.739 0.000    2.912    7.018
# C(Primary_activity)[T.Apparel stores]                                        3.983    0.887  4.491 0.000    2.245    5.722
# C(Primary_activity)[T.Aquaculture]                                           4.280    1.328  3.223 0.001    1.677    6.882
# C(Primary_activity)[T.Asset managers]                                       -1.385    0.899 -1.541 0.123   -3.147    0.376
# C(Primary_activity)[T.Automobiles]                                           4.552    0.995  4.575 0.000    2.602    6.503
# C(Primary_activity)[T.Baked goods & cereals]                                 4.502    1.809  2.489 0.013    0.958    8.047
# C(Primary_activity)[T.Banks]                                                -1.360    0.750 -1.814 0.070   -2.829    0.110
# C(Primary_activity)[T.Batteries]                                             3.008    1.217  2.471 0.013    0.622    5.393
# C(Primary_activity)[T.Biotechnology]                                         2.216    0.958  2.313 0.021    0.338    4.094
# C(Primary_activity)[T.Building sub-contractors]                              3.501    1.217  2.876 0.004    1.115    5.888
# C(Primary_activity)[T.Bus & taxi]                                           -5.311    1.820 -2.918 0.004   -8.878   -1.744
# C(Primary_activity)[T.CCGT generation]                                       1.818    0.909  2.000 0.046    0.036    3.599
# C(Primary_activity)[T.Cattle farming]                                        9.521    1.880  5.065 0.000    5.837   13.205
# C(Primary_activity)[T.Cement]                                                4.155    1.151  3.609 0.000    1.899    6.412
# C(Primary_activity)[T.Chocolate confection]                                  6.561    1.832  3.582 0.000    2.971   10.151
# C(Primary_activity)[T.Clothing manufacture]                                  3.483    1.056  3.297 0.001    1.412    5.553
# C(Primary_activity)[T.Coal generation]                                      -1.074    2.069 -0.519 0.603   -5.129    2.980
# C(Primary_activity)[T.Commercial services]                                   2.040    1.044  1.954 0.051   -0.006    4.087
# C(Primary_activity)[T.Communications equipment]                              2.936    0.884  3.320 0.001    1.203    4.670
# C(Primary_activity)[T.Computer hardware]                                     3.693    0.967  3.820 0.000    1.799    5.588
# C(Primary_activity)[T.Concrete products]                                     4.814    1.908  2.523 0.012    1.074    8.554
# C(Primary_activity)[T.Consumer services]                                     3.160    1.845  1.712 0.087   -0.457    6.777
# C(Primary_activity)[T.Dairy & egg products]                                  6.794    1.137  5.977 0.000    4.566    9.022
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                   3.813    0.918  4.152 0.000    2.013    5.614
# C(Primary_activity)[T.Department stores]                                     3.868    1.381  2.800 0.005    1.161    6.575
# C(Primary_activity)[T.Discretionary delivery retail]                         3.748    1.204  3.112 0.002    1.387    6.108
# C(Primary_activity)[T.Education services]                                    5.967    1.815  3.287 0.001    2.409    9.525
# C(Primary_activity)[T.Electrical equipment]                                  4.286    0.863  4.968 0.000    2.595    5.977
# C(Primary_activity)[T.Electricity networks]                                  1.746    0.884  1.975 0.048    0.013    3.480
# C(Primary_activity)[T.Electronic components]                                 3.363    0.777  4.328 0.000    1.840    4.887
# C(Primary_activity)[T.Electronic equipment]                                  3.583    0.837  4.281 0.000    1.943    5.224
# C(Primary_activity)[T.Energy infrastructure construction]                    6.067    1.427  4.253 0.000    3.271    8.864
# C(Primary_activity)[T.Energy services & equipment]                           2.626    1.156  2.271 0.023    0.359    4.892
# C(Primary_activity)[T.Engineering services]                                  0.405    1.260  0.321 0.748   -2.066    2.875
# C(Primary_activity)[T.Engines & motors]                                      3.784    0.971  3.897 0.000    1.881    5.687
# C(Primary_activity)[T.Fabricated metal components]                           4.131    0.902  4.578 0.000    2.362    5.899
# C(Primary_activity)[T.Fast food]                                             3.427    1.207  2.839 0.005    1.062    5.793
# C(Primary_activity)[T.Finished wood products]                                2.289    1.947  1.176 0.240   -1.526    6.105
# C(Primary_activity)[T.Fishing]                                               4.366    1.841  2.372 0.018    0.758    7.974
# C(Primary_activity)[T.Food & beverage amenities]                             4.938    1.386  3.562 0.000    2.221    7.654
# C(Primary_activity)[T.Food & beverage wholesale]                             6.117    1.388  4.408 0.000    3.398    8.837
# C(Primary_activity)[T.Furniture]                                             4.031    1.044  3.861 0.000    1.985    6.078
# C(Primary_activity)[T.Gambling]                                              2.250    1.042  2.160 0.031    0.208    4.292
# C(Primary_activity)[T.Gas utilities]                                         1.778    1.126  1.579 0.114   -0.429    3.985
# C(Primary_activity)[T.Glass products]                                        3.632    1.219  2.979 0.003    1.243    6.021
# C(Primary_activity)[T.Grain & corn milling]                                  3.719    1.814  2.050 0.040    0.164    7.274
# C(Primary_activity)[T.Health care facilities]                                0.724    1.413  0.513 0.608   -2.045    3.494
# C(Primary_activity)[T.Health care services]                                  2.083    1.121  1.858 0.063   -0.114    4.279
# C(Primary_activity)[T.Health care supplies]                                  2.990    1.033  2.894 0.004    0.965    5.015
# C(Primary_activity)[T.Homeware]                                              3.800    1.839  2.067 0.039    0.197    7.404
# C(Primary_activity)[T.Hotels & lodging]                                      2.869    0.934  3.070 0.002    1.038    4.700
# C(Primary_activity)[T.Industrial machinery]                                  3.332    0.889  3.748 0.000    1.589    5.074
# C(Primary_activity)[T.Inorganic base chemicals]                              3.699    1.109  3.334 0.001    1.525    5.873
# C(Primary_activity)[T.Insurance]                                            -1.630    0.767 -2.126 0.034   -3.133   -0.127
# C(Primary_activity)[T.Intermodal transport]                                 -0.179    1.812 -0.099 0.921   -3.731    3.372
# C(Primary_activity)[T.Iron & steel]                                          4.810    1.149  4.186 0.000    2.558    7.062
# C(Primary_activity)[T.Logging]                                               4.707    1.812  2.598 0.009    1.156    8.258
# C(Primary_activity)[T.Logistics - 3rd party]                                 1.543    1.064  1.451 0.147   -0.542    3.629
# C(Primary_activity)[T.Logistics - transport]                                 2.486    1.831  1.358 0.174   -1.102    6.074
# C(Primary_activity)[T.Marine freight]                                        0.049    1.240  0.040 0.968   -2.380    2.479
# C(Primary_activity)[T.Marketing]                                             0.862    0.889  0.970 0.332   -0.880    2.604
# C(Primary_activity)[T.Medical equipment]                                     2.371    0.870  2.725 0.006    0.666    4.077
# C(Primary_activity)[T.Metal containers & packaging]                          4.835    1.038  4.657 0.000    2.800    6.870
# C(Primary_activity)[T.Metal processing]                                      4.292    1.414  3.035 0.002    1.520    7.064
# C(Primary_activity)[T.Nitrogenous fertilizers]                               5.655    1.251  4.520 0.000    3.203    8.107
# C(Primary_activity)[T.Non-CCGT generation]                                   1.276    1.446  0.882 0.378   -1.558    4.109
# C(Primary_activity)[T.Non-alcoholic beverages]                               4.236    0.986  4.295 0.000    2.303    6.169
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                           2.579    1.536  1.679 0.093   -0.432    5.590
# C(Primary_activity)[T.Non-residential building construction]                 4.174    0.885  4.714 0.000    2.439    5.909
# C(Primary_activity)[T.Oil & gas extraction]                                 -2.539    1.173 -2.165 0.030   -4.837   -0.241
# C(Primary_activity)[T.Oil & gas marketing & retailing]                       2.870    1.444  1.987 0.047    0.039    5.701
# C(Primary_activity)[T.Oil & gas pipelines & storage]                         1.084    1.233  0.879 0.379   -1.332    3.501
# C(Primary_activity)[T.Oil & gas refining]                                    3.483    1.400  2.489 0.013    0.740    6.226
# C(Primary_activity)[T.Other base chemicals]                                  4.421    0.824  5.363 0.000    2.805    6.037
# C(Primary_activity)[T.Other containers & packaging]                          4.041    1.210  3.339 0.001    1.669    6.413
# C(Primary_activity)[T.Other food processing]                                 4.759    0.892  5.334 0.000    3.010    6.507
# C(Primary_activity)[T.Other non-ferrous ore mining]                          3.163    1.206  2.622 0.009    0.799    5.527
# C(Primary_activity)[T.Other non-metallic minerals]                          -5.465    1.830 -2.987 0.003   -9.051   -1.879
# C(Primary_activity)[T.Other non-wood building materials]                     4.027    1.429  2.818 0.005    1.226    6.828
# C(Primary_activity)[T.Other professional services]                           2.349    0.807  2.911 0.004    0.768    3.930
# C(Primary_activity)[T.Other renewable energy equipment]                      7.252    1.966  3.688 0.000    3.398   11.106
# C(Primary_activity)[T.Other renewable generation]                           -2.222    2.245 -0.990 0.322   -6.622    2.179
# C(Primary_activity)[T.Paper products]                                        3.350    0.924  3.626 0.000    1.539    5.161
# C(Primary_activity)[T.Passenger airlines]                                    0.458    0.943  0.486 0.627   -1.390    2.306
# C(Primary_activity)[T.Passenger rail]                                        0.070    1.399  0.050 0.960   -2.671    2.812
# C(Primary_activity)[T.Personal care & household products]                    3.839    0.841  4.564 0.000    2.191    5.487
# C(Primary_activity)[T.Pharmaceuticals]                                       2.621    0.793  3.306 0.001    1.067    4.175
# C(Primary_activity)[T.Plastic products]                                      3.665    0.936  3.914 0.000    1.830    5.501
# C(Primary_activity)[T.Precious metals & minerals mining]                     2.775    1.022  2.716 0.007    0.772    4.778
# C(Primary_activity)[T.Print publishing]                                      2.408    1.065  2.261 0.024    0.321    4.495
# C(Primary_activity)[T.Printing services]                                     4.624    1.381  3.349 0.001    1.918    7.331
# C(Primary_activity)[T.Pulp & paper mills]                                    3.447    1.108  3.110 0.002    1.275    5.619
# C(Primary_activity)[T.REIT]                                                  0.858    0.823  1.044 0.297   -0.754    2.471
# C(Primary_activity)[T.Rail freight]                                          0.177    1.049  0.169 0.866   -1.878    2.233
# C(Primary_activity)[T.Railroad rolling stock]                                3.660    1.832  1.998 0.046    0.070    7.250
# C(Primary_activity)[T.Real estate owners & developers]                       0.175    1.129  0.155 0.877   -2.037    2.387
# C(Primary_activity)[T.Real estate services]                                  2.112    1.112  1.900 0.057   -0.067    4.291
# C(Primary_activity)[T.Residential building construction]                     3.321    0.889  3.736 0.000    1.578    5.063
# C(Primary_activity)[T.Rubber products]                                       4.932    1.045  4.720 0.000    2.884    6.981
# C(Primary_activity)[T.Semiconductors]                                        3.252    1.153  2.820 0.005    0.992    5.513
# C(Primary_activity)[T.Servers & data centers]                                1.906    1.387  1.374 0.169   -0.812    4.625
# C(Primary_activity)[T.Software]                                              1.782    0.877  2.033 0.042    0.064    3.501
# C(Primary_activity)[T.Solar energy equipment]                                3.160    1.812  1.744 0.081   -0.392    6.711
# C(Primary_activity)[T.Specialist retail]                                     4.488    1.066  4.210 0.000    2.399    6.578
# C(Primary_activity)[T.Specialty chemicals]                                   4.334    0.814  5.325 0.000    2.739    5.929
# C(Primary_activity)[T.Supermarkets, food & drugstores]                       3.937    0.833  4.723 0.000    2.303    5.570
# C(Primary_activity)[T.Telecommunications services]                           2.641    0.783  3.374 0.001    1.107    4.175
# C(Primary_activity)[T.Textiles]                                              4.258    1.872  2.275 0.023    0.589    7.927
# C(Primary_activity)[T.Tobacco products]                                      3.211    1.093  2.936 0.003    1.068    5.354
# C(Primary_activity)[T.Transportation infrastructure & other construction]    4.455    0.953  4.673 0.000    2.586    6.323
# C(Primary_activity)[T.Transportation support services]                       4.353    1.830  2.378 0.017    0.766    7.940
# C(Primary_activity)[T.Travel services]                                      -4.406    1.810 -2.434 0.015   -7.954   -0.858
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]                 2.322    1.104  2.103 0.035    0.158    4.486
# C(Primary_activity)[T.Waste management]                                      1.786    1.381  1.293 0.196   -0.921    4.493
# C(Primary_activity)[T.Water supply networks]                                 0.863    1.138  0.758 0.448   -1.367    3.093
# C(Primary_activity)[T.Wind generation]                                       1.757    1.886  0.931 0.352   -1.940    5.453
# C(Primary_activity)[T.Wood furniture]                                        4.396    1.818  2.418 0.016    0.833    7.959
# slog_Market_Cap_USD                                                          0.095    0.044  2.170 0.030    0.009    0.180
# slog_Revenue_USD                                                             0.043    0.014  3.026 0.002    0.015    0.071
# slog_totalAssets_USD                                                         0.167    0.041  4.120 0.000    0.088    0.247
# slog_totalLiabilities_USD                                                    0.168    0.034  5.016 0.000    0.103    0.234
# slog_scope_1_2_emissions_amount                                              0.246    0.029  8.536 0.000    0.189    0.302
# Year                                                                         0.078    0.013  6.192 0.000    0.053    0.102
# Group Var                                                                    2.551    0.168
# ==========================================================================================================================
#
#
# Optimized Mixed-Effects Model: Test Set Performance Metrics:
# R²(log):    65.69%
# R²(orig):   22.92%
# MAPE:       787.76%
# MAPE(log):  13.81%
# MAE(log):   1.18
# RMSLE:      1.67
# RMSE:       4517116.25
# MAE:        1668196.42
#
# Top Influential Features (by p-value):
#                                                   coef        pvalue
# Group Var                                     2.606100  6.341655e-53
# slog_scope_1_2_emissions_amount               0.245715  1.387674e-17
# Year                                          0.077762  5.932180e-10
# C(Primary_activity)[T.Dairy & egg products]   6.793999  2.278731e-09
# C(Primary_activity)[T.Other base chemicals]   4.421207  8.198713e-08
# C(Primary_activity)[T.Other food processing]  4.758725  9.601823e-08
# C(Primary_activity)[T.Specialty chemicals]    4.333939  1.009875e-07
# C(Primary_activity)[T.Cattle farming]         9.520771  4.076703e-07
# slog_totalLiabilities_USD                     0.168244  5.278481e-07
# C(Primary_activity)[T.Electrical equipment]   4.286279  6.764332e-07
#
# All feature coefficients sorted by absolute value:
#                                                         coef        pvalue
# C(Primary_activity)[T.Cattle farming]               9.520771  4.076703e-07
# C(Primary_activity)[T.Other renewable energy eq...  7.251924  2.259753e-04
# C(Primary_activity)[T.Dairy & egg products]         6.793999  2.278731e-09
# C(Primary_activity)[T.Chocolate confection]         6.560692  3.410520e-04
# C(Primary_activity)[T.Food & beverage wholesale]    6.117394  1.041448e-05
# ...                                                      ...           ...
# C(Primary_activity)[T.Passenger rail]               0.070250  9.599415e-01
# C(Primary_activity)[T.Marine freight]               0.049471  9.681659e-01
# slog_Revenue_USD                                    0.043146  2.479858e-03
# C(Countries)[T.China]                               0.023123  9.729266e-01
# C(Countries)[T.Peru]                               -0.011580  9.947254e-01
#
# [165 rows x 2 columns]

# %%
# --- Metrics box for plot: Only R²(log), RMSLE, MAE ---
metrics_text_log = (
    f"R²(log):   {r2_log_pct:.2f}%\n"
    f"R²(orig):  {r2_pct:.2f}%\n"
    f"MAPE:      {mape_orig:.2f}%\n"
    f"MAPE(log): {mape_log:.2f}%\n"
    f"MAE(log):  {mae_log:.2f}\n"
    f"RMSLE:     {rmsle:.2f}\n"
    f"RMSE:      {rmse_orig:.2f}\n"
    f"MAE:       {mae_orig:.2f}"
)

fig, ax = plt.subplots(figsize=(9.5, 6))  # Wider to make room for the box

if hasattr(y_pred_log, "nunique"):
    multiple_vals = y_pred_log.nunique() > 1
else:
    multiple_vals = len(set(y_pred_log)) > 1

if multiple_vals:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=ax, color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    ax.plot([], [], ' ', label="Predicted: constant value (no KDE)")

ax.set_title("Purchased Goods and Services Optimized Model: signed log(Scope 3 Emissions)")
ax.set_xlabel("signed log(metric tons + 1)")
ax.set_ylabel("Density")
ax.legend()

# Place metrics box outside plot to the right
fig.text(
    0.82, 0.75, metrics_text_log,
    va='top', ha='left',
    fontsize=12, bbox=dict(boxstyle='round', alpha=0.15)
)

plt.subplots_adjust(right=0.8)  # Make sure there's room for the box
fig.savefig("purchased_goods_and_services_scope3_log_density.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Metrics Table for Purchased Goods and Services

# %%
metrics_dicts = [
    null_model_metrics,
    two_level_model_metrics,
    three_level_model_metrics,
    full_model_metrics,
    optimized_model_metrics
]

for metrics, train, test in zip(
        metrics_dicts,
        [train_df, train_df, train_df, train_df, train_df],
        [test_df, test_df, test_df, test_df, test_df]):
    
    metrics["# Obs (train)"] = len(train)
    metrics["# Obs (test)"] = len(test)
    metrics["# Obs (train/test)"] = f"{len(train)}/{len(test)}"

metrics_df = pd.DataFrame(metrics_dicts)

# Ensure all relevant columns are ordered and present
desired_order = [
    "Model", "R2_log", "R2_orig", "RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "# Obs (train/test)"
]


# Ensure MAE_log is present, fill with NaN if missing
if "MAE_log" not in metrics_df.columns:
    metrics_df["MAE_log"] = np.nan

metrics_df = metrics_df[[col for col in desired_order if col in metrics_df.columns]]

metrics_df_display = metrics_df.copy()
if "R2_log" in metrics_df_display.columns:
    metrics_df_display["R2_log"] = (metrics_df_display["R2_log"] * 100).map("{:.2f}%".format)
if "R2_orig" in metrics_df_display.columns:
    metrics_df_display["R2_orig"] = (metrics_df_display["R2_orig"] * 100).map("{:.2f}%".format)
for col in ["RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "MAPE(log)"]:
    if col in metrics_df_display.columns:
        metrics_df_display[col] = metrics_df_display[col].map("{:.2f}".format)

from IPython.display import display
display(metrics_df_display)
# Out:
#                                      Model  R2_log  R2_orig        RMSE  \
# 0                                Null (RI)  -4.12%  -22.10%  5685117.65
# 1                           2-level (RI+S)  -0.20%  -19.83%  5632116.35
# 2  3-level (Primary Activity/Account/Year)  18.91%  -11.23%  5426247.23
# 3                               Full Model  65.77%   18.58%  4642385.62
# 4                                Optimized  65.69%   22.92%  4517116.25
#
#           MAE MAE_log RMSLE       MAPE # Obs (train/test)
# 0  2513590.11    2.29  2.92   86705.52           3483/724
# 1  2475088.07    2.15  2.86  136501.40           3483/724
# 2  2319413.04    1.88  2.57  174131.54           3483/724
# 3  1688206.98    1.18  1.67     784.67           3483/724
# 4  1668196.42    1.18  1.67     787.76           3483/724
