# %% [markdown]
# # GHG HLM on Scope 3 source Investments

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_log_error, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GroupShuffleSplit
from scipy.stats import zscore
import scipy.stats as stats
from sklearn.feature_selection import mutual_info_regression
from sklearn.impute import SimpleImputer
import warnings
from statsmodels.regression.mixed_linear_model import MixedLM


#read in dataset from GHG_post_outliers data set
investments=pd.read_csv('/Users/amberjensen/Desktop/GHG_Emissions_Project/investments.csv')

# %%
#check for info
investments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 905 entries, 0 to 904
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_name                905 non-null    object
#  1   account_id                  905 non-null    int64
#  2   Year                        905 non-null    int64
#  3   incorporated_country        905 non-null    object
#  4   Primary activity            905 non-null    object
#  5   Primary sector              905 non-null    object
#  6   Market_Cap_USD              810 non-null    float64
#  7   Third_party_verification    904 non-null    object
#  8   Revenue_USD                 824 non-null    float64
#  9   ebitda_USD                  824 non-null    float64
#  10  grossProfit_USD             824 non-null    float64
#  11  netIncome_USD               824 non-null    float64
#  12  cashAndCashEquivalents_USD  824 non-null    float64
#  13  shortTermInvestments_USD    824 non-null    float64
#  14  longTermInvestments_USD     824 non-null    float64
#  15  totalAssets_USD             824 non-null    float64
#  16  totalLiabilities_USD        824 non-null    float64
#  17  totalInvestments_USD        824 non-null    float64
#  18  totalDebt_USD               824 non-null    float64
#  19  totalEquity_USD             824 non-null    float64
#  20  Scope_3_emissions_type      905 non-null    object
#  21  Scope_3_emissions_amount    905 non-null    float64
#  22  scope_1_2_emissions_amount  904 non-null    float64
#  23  Year_sq                     905 non-null    int64
# dtypes: float64(15), int64(3), object(6)
# memory usage: 169.8+ KB

# %%
#show a df for investments
investments.head()
# Out:
#                account_name  account_id  Year incorporated_country  \
# 0                     Aptiv        4407  2018       United Kingdom
# 1  Associated British Foods        1085  2018       United Kingdom
# 2           GlaxoSmithKline        7374  2018       United Kingdom
# 3                Kingfisher       10156  2018       United Kingdom
# 4      Lloyds Banking Group       10781  2018       United Kingdom
#
#        Primary activity                     Primary sector  Market_Cap_USD  \
# 0  Electrical equipment  Electrical & electronic equipment    1.595156e+10
# 1        Apparel stores               Discretionary retail    2.051429e+10
# 2       Pharmaceuticals                   Biotech & pharma    7.508927e+10
# 3     Specialist retail               Discretionary retail    5.248698e+09
# 4                 Banks                 Financial services    5.110653e+10
#
#                             Third_party_verification   Revenue_USD  \
# 0           No third-party verification or assurance  1.443500e+10
# 1  Third-party verification or assurance process ...  1.977898e+10
# 2  Third-party verification or assurance process ...  3.914267e+10
# 3  Third-party verification or assurance process ...  1.483995e+10
# 4  Third-party verification or assurance process ...  2.357882e+10
#
#      ebitda_USD  ...  longTermInvestments_USD  totalAssets_USD  \
# 0  2.260000e+09  ...             9.900000e+07     1.248000e+10
# 1  2.363470e+09  ...             3.429000e+08     1.738884e+10
# 2  9.344660e+09  ...             1.871980e+09     7.374382e+10
# 3  1.195070e+09  ...             1.905000e+07     1.504696e+10
# 4  1.424940e+10  ...             2.694648e+11     1.012949e+12
#
#    totalLiabilities_USD  totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0          8.810000e+09          1.710000e+08   4.344000e+09     3.670000e+09
# 1          5.582920e+09          3.810000e+08   9.880600e+08     1.180592e+10
# 2          6.908038e+10          1.978660e+09   3.310128e+10     4.663440e+09
# 3          7.237730e+09          1.905000e+07   3.512820e+09     7.809230e+09
# 4          9.491967e+11          2.176678e+11   1.396086e+11     6.375273e+10
#
#    Scope_3_emissions_type  Scope_3_emissions_amount  \
# 0             Investments                    3835.0
# 1             Investments                   73157.0
# 2             Investments                   14864.0
# 3             Investments                   10321.0
# 4             Investments                   19248.0
#
#    scope_1_2_emissions_amount  Year_sq
# 0                   380471.81  4072324
# 1                  2801746.25  4072324
# 2                  1227269.00  4072324
# 3                   234624.50  4072324
# 4                   130601.75  4072324
#
# [5 rows x 24 columns]

# %%
#define a list of numeric columns
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD',
       'grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD',
       'shortTermInvestments_USD', 'longTermInvestments_USD',
       'totalAssets_USD', 'totalLiabilities_USD', 'totalInvestments_USD',
       'totalDebt_USD', 'totalEquity_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount']

# %%
#plot the heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(investments[numeric_cols].corr(), annot=True, annot_kws={"size": 8})
plt.show()

# %%
#correlation matrix
investments[numeric_cols].corr()
# Out:
#                             Market_Cap_USD  Revenue_USD  ebitda_USD  \
# Market_Cap_USD                    1.000000     0.123163    0.168321
# Revenue_USD                       0.123163     1.000000    0.601228
# ebitda_USD                        0.168321     0.601228    1.000000
# grossProfit_USD                   0.140534     0.729305    0.561111
# netIncome_USD                     0.179846     0.529290    0.856332
# cashAndCashEquivalents_USD        0.045934     0.206235    0.433292
# shortTermInvestments_USD          0.036170     0.218751    0.275055
# longTermInvestments_USD           0.037818     0.233902    0.376464
# totalAssets_USD                   0.062922     0.349697    0.512444
# totalLiabilities_USD              0.053015     0.322147    0.466042
# totalInvestments_USD              0.038581     0.235880    0.348427
# totalDebt_USD                     0.088885     0.407353    0.647318
# totalEquity_USD                   0.133900     0.546538    0.772683
# Scope_3_emissions_amount          0.005813     0.181159    0.222054
# scope_1_2_emissions_amount        0.006321     0.173647    0.085942
#
#                             grossProfit_USD  netIncome_USD  \
# Market_Cap_USD                     0.140534       0.179846
# Revenue_USD                        0.729305       0.529290
# ebitda_USD                         0.561111       0.856332
# grossProfit_USD                    1.000000       0.579217
# netIncome_USD                      0.579217       1.000000
# cashAndCashEquivalents_USD         0.265050       0.375087
# shortTermInvestments_USD           0.338583       0.287614
# longTermInvestments_USD            0.370151       0.360913
# totalAssets_USD                    0.476625       0.457288
# totalLiabilities_USD               0.449700       0.420058
# totalInvestments_USD               0.376009       0.346954
# totalDebt_USD                      0.399943       0.506669
# totalEquity_USD                    0.591221       0.653607
# Scope_3_emissions_amount           0.174842       0.160348
# scope_1_2_emissions_amount        -0.010208       0.009997
#
#                             cashAndCashEquivalents_USD  \
# Market_Cap_USD                                0.045934
# Revenue_USD                                   0.206235
# ebitda_USD                                    0.433292
# grossProfit_USD                               0.265050
# netIncome_USD                                 0.375087
# cashAndCashEquivalents_USD                    1.000000
# shortTermInvestments_USD                      0.538763
# longTermInvestments_USD                       0.792556
# totalAssets_USD                               0.855720
# totalLiabilities_USD                          0.838754
# totalInvestments_USD                          0.744793
# totalDebt_USD                                 0.748199
# totalEquity_USD                               0.624598
# Scope_3_emissions_amount                      0.330399
# scope_1_2_emissions_amount                   -0.022637
#
#                             shortTermInvestments_USD  longTermInvestments_USD  \
# Market_Cap_USD                              0.036170                 0.037818
# Revenue_USD                                 0.218751                 0.233902
# ebitda_USD                                  0.275055                 0.376464
# grossProfit_USD                             0.338583                 0.370151
# netIncome_USD                               0.287614                 0.360913
# cashAndCashEquivalents_USD                  0.538763                 0.792556
# shortTermInvestments_USD                    1.000000                 0.781962
# longTermInvestments_USD                     0.781962                 1.000000
# totalAssets_USD                             0.613278                 0.910214
# totalLiabilities_USD                        0.639990                 0.898700
# totalInvestments_USD                        0.869656                 0.971928
# totalDebt_USD                               0.372363                 0.663536
# totalEquity_USD                             0.452721                 0.611255
# Scope_3_emissions_amount                    0.275807                 0.366511
# scope_1_2_emissions_amount                 -0.012739                -0.057681
#
#                             totalAssets_USD  totalLiabilities_USD  \
# Market_Cap_USD                     0.062922              0.053015
# Revenue_USD                        0.349697              0.322147
# ebitda_USD                         0.512444              0.466042
# grossProfit_USD                    0.476625              0.449700
# netIncome_USD                      0.457288              0.420058
# cashAndCashEquivalents_USD         0.855720              0.838754
# shortTermInvestments_USD           0.613278              0.639990
# longTermInvestments_USD            0.910214              0.898700
# totalAssets_USD                    1.000000              0.965134
# totalLiabilities_USD               0.965134              1.000000
# totalInvestments_USD               0.855066              0.856057
# totalDebt_USD                      0.849186              0.806406
# totalEquity_USD                    0.747215              0.685774
# Scope_3_emissions_amount           0.407370              0.416238
# scope_1_2_emissions_amount        -0.011087             -0.024407
#
#                             totalInvestments_USD  totalDebt_USD  \
# Market_Cap_USD                          0.038581       0.088885
# Revenue_USD                             0.235880       0.407353
# ebitda_USD                              0.348427       0.647318
# grossProfit_USD                         0.376009       0.399943
# netIncome_USD                           0.346954       0.506669
# cashAndCashEquivalents_USD              0.744793       0.748199
# shortTermInvestments_USD                0.869656       0.372363
# longTermInvestments_USD                 0.971928       0.663536
# totalAssets_USD                         0.855066       0.849186
# totalLiabilities_USD                    0.856057       0.806406
# totalInvestments_USD                    1.000000       0.596109
# totalDebt_USD                           0.596109       1.000000
# totalEquity_USD                         0.577165       0.736723
# Scope_3_emissions_amount                0.359697       0.346266
# scope_1_2_emissions_amount             -0.046476       0.069630
#
#                             totalEquity_USD  Scope_3_emissions_amount  \
# Market_Cap_USD                     0.133900                  0.005813
# Revenue_USD                        0.546538                  0.181159
# ebitda_USD                         0.772683                  0.222054
# grossProfit_USD                    0.591221                  0.174842
# netIncome_USD                      0.653607                  0.160348
# cashAndCashEquivalents_USD         0.624598                  0.330399
# shortTermInvestments_USD           0.452721                  0.275807
# longTermInvestments_USD            0.611255                  0.366511
# totalAssets_USD                    0.747215                  0.407370
# totalLiabilities_USD               0.685774                  0.416238
# totalInvestments_USD               0.577165                  0.359697
# totalDebt_USD                      0.736723                  0.346266
# totalEquity_USD                    1.000000                  0.381868
# Scope_3_emissions_amount           0.381868                  1.000000
# scope_1_2_emissions_amount         0.117438                  0.302976
#
#                             scope_1_2_emissions_amount
# Market_Cap_USD                                0.006321
# Revenue_USD                                   0.173647
# ebitda_USD                                    0.085942
# grossProfit_USD                              -0.010208
# netIncome_USD                                 0.009997
# cashAndCashEquivalents_USD                   -0.022637
# shortTermInvestments_USD                     -0.012739
# longTermInvestments_USD                      -0.057681
# totalAssets_USD                              -0.011087
# totalLiabilities_USD                         -0.024407
# totalInvestments_USD                         -0.046476
# totalDebt_USD                                 0.069630
# totalEquity_USD                               0.117438
# Scope_3_emissions_amount                      0.302976
# scope_1_2_emissions_amount                    1.000000

# %%
#drop columns due to collinearity, keeping total
investments=investments.drop(columns=['longTermInvestments_USD', 'totalLiabilities_USD', 'cashAndCashEquivalents_USD', 'totalInvestments_USD', 'totalDebt_USD',
                                      'netIncome_USD', 'shortTermInvestments_USD', "account_name", "Third_party_verification", "Scope_3_emissions_type"])

# %%
investments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 905 entries, 0 to 904
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  905 non-null    int64
#  1   Year                        905 non-null    int64
#  2   incorporated_country        905 non-null    object
#  3   Primary activity            905 non-null    object
#  4   Primary sector              905 non-null    object
#  5   Market_Cap_USD              810 non-null    float64
#  6   Revenue_USD                 824 non-null    float64
#  7   ebitda_USD                  824 non-null    float64
#  8   grossProfit_USD             824 non-null    float64
#  9   totalAssets_USD             824 non-null    float64
#  10  totalEquity_USD             824 non-null    float64
#  11  Scope_3_emissions_amount    905 non-null    float64
#  12  scope_1_2_emissions_amount  904 non-null    float64
#  13  Year_sq                     905 non-null    int64
# dtypes: float64(8), int64(3), object(3)
# memory usage: 99.1+ KB

# %%
sns.boxplot(investments)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#plot a scatter plot of scope year emissions and scope 1_2 emissions

sns.scatterplot(x='Year', y='Market_Cap_USD', data=investments)
# Out:
# <Axes: xlabel='Year', ylabel='Market_Cap_USD'>

# %%
investments_sorted=investments.sort_values(by='Market_Cap_USD', ascending=False).reset_index(drop=True)

#display sorted df
investments_sorted.head()
# Out:
#    account_id  Year incorporated_country                  Primary activity  \
# 0       21889  2023                Chile                Pulp & paper mills
# 1        5377  2023                  USA                   Pharmaceuticals
# 2       14683  2021                  USA                   Pharmaceuticals
# 3       20182  2020              Denmark  Other renewable energy equipment
# 4       14683  2022                  USA                   Pharmaceuticals
#
#                Primary sector  Market_Cap_USD   Revenue_USD    ebitda_USD  \
# 0      Wood & paper materials    4.259662e+12  8.099816e+09  9.337530e+08
# 1            Biotech & pharma    5.534120e+11  3.412410e+10  1.245550e+10
# 2            Biotech & pharma    3.316838e+11  8.128800e+10  2.853300e+10
# 3  Renewable energy equipment    3.044989e+11  1.600452e+10  1.856520e+09
# 4            Biotech & pharma    2.877126e+11  1.003300e+11  4.363900e+10
#
#    grossProfit_USD  totalAssets_USD  totalEquity_USD  \
# 0     1.754288e+09     1.717731e+10     7.884897e+09
# 1     2.754810e+10     6.400630e+10     1.086370e+10
# 2     5.046700e+10     1.814770e+11     7.746300e+10
# 3     1.661040e+09     1.961280e+10     5.079240e+09
# 4     6.598600e+10     1.972060e+11     9.591700e+10
#
#    Scope_3_emissions_amount  scope_1_2_emissions_amount  Year_sq
# 0                    5368.0                   1968684.0  4092529
# 1                      10.0                    545000.0  4092529
# 2                   36839.0                   1243618.0  4084441
# 3                    7000.0                     80452.0  4080400
# 4                   36178.0                   1181996.0  4088484

# %%
#remove account id=21889

investments=investments[investments['account_id']!=21889]

# %%
#rerun the plot
sns.scatterplot(x='Year', y='Market_Cap_USD', data=investments)
# Out:
# <Axes: xlabel='Year', ylabel='Market_Cap_USD'>

# %%
# copy dataframe
investments_no_transform = investments.copy()
# Change 'incorporated_country' to 'Countries' in investments dataframe
investments_no_transform = investments_no_transform.rename(columns={'incorporated_country': 'Countries',
                                                       'Primary activity': 'Primary_activity',
                                                        'Primary sector': 'Primary_sector'})

print(investments_no_transform.info())
investments_no_transform.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 904 entries, 0 to 904
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  904 non-null    int64
#  1   Year                        904 non-null    int64
#  2   Countries                   904 non-null    object
#  3   Primary_activity            904 non-null    object
#  4   Primary_sector              904 non-null    object
#  5   Market_Cap_USD              809 non-null    float64
#  6   Revenue_USD                 823 non-null    float64
#  7   ebitda_USD                  823 non-null    float64
#  8   grossProfit_USD             823 non-null    float64
#  9   totalAssets_USD             823 non-null    float64
#  10  totalEquity_USD             823 non-null    float64
#  11  Scope_3_emissions_amount    904 non-null    float64
#  12  scope_1_2_emissions_amount  903 non-null    float64
#  13  Year_sq                     904 non-null    int64
# dtypes: float64(8), int64(3), object(3)
# memory usage: 105.9+ KB
# None
#    account_id  Year       Countries      Primary_activity  \
# 0        4407  2018  United Kingdom  Electrical equipment
# 1        1085  2018  United Kingdom        Apparel stores
# 2        7374  2018  United Kingdom       Pharmaceuticals
# 3       10156  2018  United Kingdom     Specialist retail
# 4       10781  2018  United Kingdom                 Banks
#
#                       Primary_sector  Market_Cap_USD   Revenue_USD  \
# 0  Electrical & electronic equipment    1.595156e+10  1.443500e+10
# 1               Discretionary retail    2.051429e+10  1.977898e+10
# 2                   Biotech & pharma    7.508927e+10  3.914267e+10
# 3               Discretionary retail    5.248698e+09  1.483995e+10
# 4                 Financial services    5.110653e+10  2.357882e+10
#
#      ebitda_USD  grossProfit_USD  totalAssets_USD  totalEquity_USD  \
# 0  2.260000e+09     2.729000e+09     1.248000e+10     3.670000e+09
# 1  2.363470e+09     4.551680e+09     1.738884e+10     1.180592e+10
# 2  9.344660e+09     2.613660e+10     7.374382e+10     4.663440e+09
# 3  1.195070e+09     5.483860e+09     1.504696e+10     7.809230e+09
# 4  1.424940e+10     2.357882e+10     1.012949e+12     6.375273e+10
#
#    Scope_3_emissions_amount  scope_1_2_emissions_amount  Year_sq
# 0                    3835.0                   380471.81  4072324
# 1                   73157.0                  2801746.25  4072324
# 2                   14864.0                  1227269.00  4072324
# 3                   10321.0                   234624.50  4072324
# 4                   19248.0                   130601.75  4072324

# %%
investments_no_transform['Primary_sector'].value_counts()
# Out:
# Primary_sector
# Chemicals                                             124
# Electrical & electronic equipment                      95
# Financial services                                     93
# Media, telecommunications & data center services       50
# Construction                                           48
# Food & beverage processing                             43
# Biotech & pharma                                       32
# Discretionary retail                                   25
# Trading, wholesale, distribution, rental & leasing     25
# Metal products manufacturing                           25
# Thermal power generation                               23
# Convenience retail                                     22
# Metallic mineral mining                                22
# Energy utility networks                                22
# Air transport                                          18
# Specialized professional services                      18
# Oil & gas storage & transportation                     14
# Wood & rubber products                                 13
# Print & publishing services                            13
# Land & property ownership & development                10
# Web & marketing services                               10
# Powered machinery                                      10
# Tobacco                                                 9
# Industrial support services                             9
# Intermodal transport & logistics                        9
# Transportation equipment                                9
# Metal smelting, refining & forming                      8
# Paper products & packaging                              8
# Commercial & consumer services                          7
# Marine transport                                        6
# Medical equipment & supplies                            6
# Logging & rubber tapping                                6
# Rail transport                                          6
# Wood & paper materials                                  6
# Bars, hotels & restaurants                              6
# Non-energy utilities                                    5
# Fish & animal farming                                   5
# Renewable energy equipment                              5
# IT & software development                               5
# Renewable power generation                              4
# Textiles & fabric goods                                 4
# Road transport                                          4
# Other materials                                         4
# Other services                                          3
# Apparel design                                          3
# Cement & concrete                                       3
# Light manufacturing                                     2
# 0                                                       2
# Oil & gas retailing                                     2
# Plastic product manufacturing                           1
# Health care provision                                   1
# Entertainment facilities                                1
# Name: count, dtype: int64

# %%
investments_no_transform['Primary_activity'].value_counts().head(20)
# Out:
# Primary_activity
# Telecommunications services                           50
# Banks                                                 42
# Other base chemicals                                  39
# Electronic components                                 35
# Personal care & household products                    32
# Specialty chemicals                                   27
# Electronic equipment                                  26
# Insurance                                             24
# Pharmaceuticals                                       23
# CCGT generation                                       23
# Supermarkets, food & drugstores                       22
# Transportation infrastructure & other construction    22
# Precious metals & minerals mining                     21
# REIT                                                  19
# Passenger airlines                                    18
# Fabricated metal components                           18
# Other professional services                           16
# Inorganic base chemicals                              14
# Other food processing                                 14
# Oil & gas pipelines & storage                         14
# Name: count, dtype: int64

# %%
# Looking at missing data
print(investments_no_transform.isnull().mean().sort_values(ascending=False).round(3) * 100)
# Out:
# Market_Cap_USD                10.5
# Revenue_USD                    9.0
# ebitda_USD                     9.0
# grossProfit_USD                9.0
# totalAssets_USD                9.0
# totalEquity_USD                9.0
# scope_1_2_emissions_amount     0.1
# account_id                     0.0
# Year                           0.0
# Countries                      0.0
# Primary_activity               0.0
# Primary_sector                 0.0
# Scope_3_emissions_amount       0.0
# Year_sq                        0.0
# dtype: float64

# %% [markdown]
# Apply signed log transformation and split data by company and year into train_df (2018-2022) and test_df (2023):

# %%
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD', 'grossProfit_USD', 'totalAssets_USD',
                'totalEquity_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount'
]
required_cols = [
    'account_id', 'Year', 'Year_sq', 'Countries', 'Primary_activity', 'Primary_sector'
] + numeric_cols

# --- Prepare Data ---
df = investments_no_transform[required_cols].dropna()

# --- Signed log transform ---
def signed_log(x):
    return np.sign(x) * np.log(np.abs(x) + 1)

for col in numeric_cols:
    df[f'slog_{col}'] = signed_log(df[col])

# --- Company-level split by year ---
train_df = df[df['Year'].between(2018, 2022)].copy()
test_df  = df[df['Year'] == 2023].copy()

# Keep only companies present in training
valid_companies = set(train_df['account_id'].unique())
test_df = test_df[test_df['account_id'].isin(valid_companies)].copy()

# --- Remove rare categories in Primary_activity and Countries (≤2 rows) to prevent singular matrices ---
for col in ['Primary_activity', 'Countries']:
    value_counts = train_df[col].value_counts()
    allowed = value_counts[value_counts > 2].index
    train_df = train_df[train_df[col].isin(allowed)].copy()
    test_df = test_df[test_df[col].isin(allowed)].copy()

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (572, 22)
# Test shape: (120, 22)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 572 entries, 0 to 681
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       572 non-null    int64
#  1   Year                             572 non-null    int64
#  2   Year_sq                          572 non-null    int64
#  3   Countries                        572 non-null    object
#  4   Primary_activity                 572 non-null    object
#  5   Primary_sector                   572 non-null    object
#  6   Market_Cap_USD                   572 non-null    float64
#  7   Revenue_USD                      572 non-null    float64
#  8   ebitda_USD                       572 non-null    float64
#  9   grossProfit_USD                  572 non-null    float64
#  10  totalAssets_USD                  572 non-null    float64
#  11  totalEquity_USD                  572 non-null    float64
#  12  Scope_3_emissions_amount         572 non-null    float64
#  13  scope_1_2_emissions_amount       572 non-null    float64
#  14  slog_Market_Cap_USD              572 non-null    float64
#  15  slog_Revenue_USD                 572 non-null    float64
#  16  slog_ebitda_USD                  572 non-null    float64
#  17  slog_grossProfit_USD             572 non-null    float64
#  18  slog_totalAssets_USD             572 non-null    float64
#  19  slog_totalEquity_USD             572 non-null    float64
#  20  slog_Scope_3_emissions_amount    572 non-null    float64
#  21  slog_scope_1_2_emissions_amount  572 non-null    float64
# dtypes: float64(16), int64(3), object(3)
# memory usage: 102.8+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 120 entries, 683 to 901
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       120 non-null    int64
#  1   Year                             120 non-null    int64
#  2   Year_sq                          120 non-null    int64
#  3   Countries                        120 non-null    object
#  4   Primary_activity                 120 non-null    object
#  5   Primary_sector                   120 non-null    object
#  6   Market_Cap_USD                   120 non-null    float64
#  7   Revenue_USD                      120 non-null    float64
#  8   ebitda_USD                       120 non-null    float64
#  9   grossProfit_USD                  120 non-null    float64
#  10  totalAssets_USD                  120 non-null    float64
#  11  totalEquity_USD                  120 non-null    float64
#  12  Scope_3_emissions_amount         120 non-null    float64
#  13  scope_1_2_emissions_amount       120 non-null    float64
#  14  slog_Market_Cap_USD              120 non-null    float64
#  15  slog_Revenue_USD                 120 non-null    float64
#  16  slog_ebitda_USD                  120 non-null    float64
#  17  slog_grossProfit_USD             120 non-null    float64
#  18  slog_totalAssets_USD             120 non-null    float64
#  19  slog_totalEquity_USD             120 non-null    float64
#  20  slog_Scope_3_emissions_amount    120 non-null    float64
#  21  slog_scope_1_2_emissions_amount  120 non-null    float64
# dtypes: float64(16), int64(3), object(3)
# memory usage: 21.6+ KB

# %%
# Check number of 0's in train and test df's
print((train_df == 0).sum().sum())
print((test_df == 0).sum().sum())
# Out:
# 2
# 0

# %% [markdown]
# ## Investments Null Mixed-Effects Model
#
# Null mixed-effects model (random intercept only) to predict log-transformed Scope 3 emissions. The model serves as a baseline, capturing only the average emission level for each company, without incorporating any explanatory variables, and quantifies the improvement gained by including additional features and structure. The model is trained on 2018–2022 data and evaluated on a test set from 2023.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies
# - Fixed Effects:
#     - Intercept only (no predictors)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE NULL MODEL (random intercept only) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    null_model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ 1",
        train_df,
        groups=train_df["account_id"]
    )
    null_result = null_model.fit(method="lbfgs")

if not null_result.converged:
    print("WARNING: Null model did not fully converge.")

print(null_result.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_null'] = null_result.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_null']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_null'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics text
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[0], color='gray')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Null Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[1], color='gray')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Null Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Null Model Predicted")
plt.xscale("log")
plt.title("Null Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
null_model_metrics = {
    "Model": "Null (RI)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "Random intercept only"
}
# Out:
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 572     Method:             REML
# No. Groups:       192     Scale:              0.9500
# Min. group size:  1       Log-Likelihood:     -1093.5240
# Max. group size:  5       Converged:          Yes
# Mean group size:  3.0
# ------------------------------------------------------------------------------
#                 Coef.      Std.Err.       z        P>|z|     [0.025     0.975]
# ------------------------------------------------------------------------------
# Intercept       10.457        0.209     49.967     0.000     10.046     10.867
# Group Var        7.945        1.095
# ==========================================================================
#
# R²(log):    -0.29%
# R²(orig):   -16.51%
# MAPE:       2090.92%
# MAPE(log):  23.42%
# MAE(log):   2.09
# RMSLE:      2.61
# RMSE:       970248.65
# MAE:        386960.88

# %% [markdown]
# ## Investments Two-Level Mixed-Effects Model
#
# Two-level hierarchical linear mixed-effects model to predict log-transformed Scope 3 emissions at the company level. The model is fit to training data (from 2018–2022), and predictions are evaluated on a test set (from 2023).  This model provides a baseline for including time trends and company-level variability.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies.<br>
# - Fixed Effects:
#     - Year (numeric)
#     - Year squared ('Year_sq', quadratic time trend)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- Check group sizes ---
group_sizes = train_df.groupby('account_id').size()
print("Two-Level Model: Company/year group size summary:")
print(group_sizes.describe())

# --- FIT THE TWO-LEVEL MODEL (random intercept, +Year, +Year_sq) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ Year + Year_sq",
        train_df,
        groups=train_df["account_id"],
        re_formula="1"
    )
    result_twolevel = model.fit(method="lbfgs")

if not result_twolevel.converged:
    print("WARNING: Two-level mixed model did not fully converge.")

print(result_twolevel.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_twolevel.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_mixed']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='orange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Two-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='orange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Two-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="orange", alpha=0.5, label="Two-Level Model Predicted")
plt.xscale("log")
plt.title("Two-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
two_level_model_metrics = {
    "Model": "2-level (RI+S)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "+Year, Year_sq"
}
# Out:
# Two-Level Model: Company/year group size summary:
# count    192.000000
# mean       2.979167
# std        1.627507
# min        1.000000
# 25%        1.000000
# 50%        3.000000
# 75%        5.000000
# max        5.000000
# dtype: float64
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 572     Method:             REML
# No. Groups:       192     Scale:              0.9514
# Min. group size:  1       Log-Likelihood:     -1097.6345
# Max. group size:  5       Converged:          Yes
# Mean group size:  3.0
# ---------------------------------------------------------------------------
#                Coef.      Std.Err.     z     P>|z|     [0.025      0.975]
# ---------------------------------------------------------------------------
# Intercept   -108997.615  107309.883  -1.016  0.310  -319321.122  101325.891
# Year            107.963     106.245   1.016  0.310     -100.275     316.200
# Year_sq          -0.027       0.026  -1.017  0.309       -0.078       0.025
# Group Var         7.914       1.091
# ==========================================================================
#
# R²(log):    -2.51%
# R²(orig):   -17.27%
# MAPE:       1594.70%
# MAPE(log):  23.30%
# MAE(log):   2.14
# RMSLE:      2.64
# RMSE:       973413.01
# MAE:        388494.28

# %% [markdown]
# ## Investments Three-Level Mixed-Effects Model
#
# A three-level hierarchical linear mixed-effects model is used to predict log-transformed Scope 3 emissions. It takes into account differences between primary activity, differences between companies, and changes over time. The model is trained using data from 2018 to 2022, and then tested on new data from 2023. This model provides insight on how emissions are influenced by primary activity, by individual companies, by financial and emissions factors, and by trends over time.
#
# Model Structure:
#
# - Level 3 (Primary Activity):<br>
#     - Random intercept and random slope for Year for each primary activity ('Primary_activity'), capturing baseline primary activity and primary activity-specific time trends.<br>
# - Level 2 (Account/Company):
#     - Random intercept for each company ('account_id'), capturing company-level deviations within each primary activity.
# - Level 1 (Yearly Observations):
#     - Repeated annual observations within each company.
#
# - Fixed Effects:
#     - Signed log-transformed market cap ('slog_Market_Cap_USD')
#     - Signed log-transformed revenue ('slog_Revenue_USD')
#     - Signed log-transformed EBITDA ('slog_ebitda_USD') due to possible collinearity
#     - Signed log-transformed Scope 1 & 2 emissions ('slog_scope_1_2_emissions_amount')

# %%
# --- Ensure grouping/categorical variables are string ---
for col in ['Countries', 'account_id', 'Primary_activity', 'Primary_sector']:
    train_df[col] = train_df[col].astype(str)
    test_df[col] = test_df[col].astype(str)

# --- Center the Year variable ---
year_mean = train_df['Year'].mean()
train_df['Year_centered'] = train_df['Year'] - year_mean
test_df['Year_centered'] = test_df['Year'] - year_mean

# --- Ensure log-transformed target exists ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE 3-LEVEL MIXED MODEL with Primary_activity as Level 3 group ---
vc = {'account_id': '0 + C(account_id)'}  # Level 2: account_id random intercept

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model_3level = MixedLM.from_formula(
        'log_Scope_3_emissions_amount ~ slog_Market_Cap_USD + slog_Revenue_USD + slog_ebitda_USD + slog_scope_1_2_emissions_amount',
        groups='Primary_activity',
        re_formula='~Year_centered',
        vc_formula=vc,
        data=train_df
    )
    result_3level = model_3level.fit(method="lbfgs", maxiter=1000)

if not result_3level.converged:
    print("WARNING: Three-level mixed model did not fully converge.")

print(result_3level.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_3level.predict(test_df)

# --- Compute back-transformed values ---
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])

# --- Robust Mask for finite values everywhere ---
mask = (
    np.isfinite(test_df['log_Scope_3_emissions_amount']) &
    np.isfinite(test_df['predicted_mixed']) &
    np.isfinite(test_df['Reported_Scope_3']) &
    np.isfinite(test_df['Predicted_Scope_3'])
)
test_df = test_df.loc[mask].copy()

y_true_log = test_df['log_Scope_3_emissions_amount'].values
y_pred_log = test_df['predicted_mixed'].values
y_true = test_df['Reported_Scope_3'].values
y_pred = test_df['Predicted_Scope_3'].values

# Final defensive check and diagnostics
arrays = {
    "y_true_log": y_true_log,
    "y_pred_log": y_pred_log,
    "y_true": y_true,
    "y_pred": y_pred,
}
for arr_name, arr in arrays.items():
    if not np.all(np.isfinite(arr)):
        print(f"ERROR: {arr_name} contains non-finite values!")
        print(f"Non-finite indices: {np.where(~np.isfinite(arr))[0]}")
        print(f"Values: {arr[~np.isfinite(arr)]}")
        raise ValueError(f"{arr_name} contains infs or NaNs after masking!")

# --- METRICS ---
mae_log = mean_absolute_error(y_true_log, y_pred_log)
nonzero_mask = y_true_log != 0
if np.any(nonzero_mask):
    mape_log = np.mean(np.abs((y_true_log[nonzero_mask] - y_pred_log[nonzero_mask]) / y_true_log[nonzero_mask])) * 100
else:
    mape_log = np.nan

r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)

metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
if len(np.unique(y_pred_log)) > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Three-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()
axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

if len(np.unique(y_pred)) > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Three-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()
axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Filter strictly positive values for histogram (log x-axis requires >0)
y_true_pos = y_true[y_true > 0]
y_pred_pos = y_pred[y_pred > 0]

if y_true_pos.size > 0 and y_pred_pos.size > 0:
    min_val = min(y_true_pos.min(), y_pred_pos.min())
    max_val = max(y_true_pos.max(), y_pred_pos.max())
    if min_val == max_val:
        print("Skipping histogram: Only one unique positive value present.")
    else:
        log_bins = np.logspace(np.log10(min_val), np.log10(max_val), 100)

        plt.figure(figsize=(8, 5))
        sns.histplot(y_true_pos, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
        sns.histplot(y_pred_pos, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Three-Level Model Predicted")
        plt.xscale("log")
        plt.title("Three-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
        plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
        plt.ylabel("Density")
        plt.legend()
        plt.tight_layout()
        plt.show()
else:
    print("Skipping histogram: Not enough positive values in y_true or y_pred for log-scale histogram.")

# --- RETURN METRICS FOR SUMMARY TABLE ---
three_level_model_metrics = {
    "Model": "3-level (Primary Activity/Account/Year)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,
    "MAPE(log)": mape_log,
}
# Out:
#                      Mixed Linear Model Regression Results
# ===============================================================================
# Model:               MixedLM  Dependent Variable:  log_Scope_3_emissions_amount
# No. Observations:    572      Method:              REML
# No. Groups:          63       Scale:               0.8256
# Min. group size:     3        Log-Likelihood:      -1076.3319
# Max. group size:     34       Converged:           Yes
# Mean group size:     9.1
# -------------------------------------------------------------------------------
#                                      Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------------
# Intercept                            -2.551    3.380 -0.755 0.450 -9.176  4.073
# slog_Market_Cap_USD                   0.001    0.117  0.009 0.993 -0.228  0.230
# slog_Revenue_USD                      0.459    0.169  2.710 0.007  0.127  0.791
# slog_ebitda_USD                      -0.024    0.010 -2.348 0.019 -0.044 -0.004
# slog_scope_1_2_emissions_amount       0.241    0.061  3.951 0.000  0.122  0.361
# Primary_activity Var                  0.511    0.472
# Primary_activity x Year_centered Cov  0.086    0.115
# Year_centered Var                     0.067    0.035
# account_id Var                        6.292    1.049
# ===============================================================================
#
# R²(log):    17.06%
# R²(orig):   -13.41%
# MAPE:       2244.70%
# MAPE(log):  21.13%
# MAE(log):   1.89
# RMSLE:      2.38
# RMSE:       957257.50
# MAE:        379498.51

# %% [markdown]
# ## Investments Full Mixed-Effects Model
#
# A full mixed-effects model is used to predict company Scope 3 emissions, using financial and emissions data, along with information about country, industry, and year. The model is trained on data from 2018 to 2022, and tested on data from 2023. This full model helps provides insights into how a company’s finances, emissions, primary activity, country and the year influence emissions.<br>
#
# Model Structure:<br>
#
# - Random Effects:<br>
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:<br>
#     - Signed log-transformed financial and emissions features:<br>
#         - Market Cap ('slog_Market_Cap_USD')<br>
#         - Revenue ('slog_Revenue_USD')<br>
#         - EBITDA ('slog_ebitda_USD')<br>
#         - Gross Profit ('slog_grossProfit_USD')<br>
#         - Total Assets ('slog_totalAssets_USD')<br>
#         - Total Equity ('slog_totalEquity_USD')<br>
#         - Scope 1&2 Emissions ('slog_scope_1_2_emissions_amount')<br>
#     - Country ('Countries', as a categorical variable)<br>
#     - Primary Activity ('Primary_activity', as a categorical variable)<br>
#     - Year (numeric)<br>

# %%
# --- Feature and target columns ---
numeric_cols = ['Market_Cap_USD',
 'Revenue_USD',
 'ebitda_USD',
 'grossProfit_USD',
 'totalAssets_USD',
 'totalEquity_USD',
 'Scope_3_emissions_amount',
 'scope_1_2_emissions_amount'
]
feature_cols_slog = [f'slog_{col}' for col in numeric_cols if col != 'Scope_3_emissions_amount']
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
required_cols = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_full = train_df.dropna(subset=required_cols).copy()
test_df_full = test_df.dropna(subset=required_cols).copy()

if test_df_full.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the full mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_full, groups=train_df_full['account_id'])
        mdf = md.fit(reml=False)
    print(mdf.summary())

    # --- Predict on test set ---
    test_df_full['predicted_log'] = mdf.predict(test_df_full)
    test_df_full['predicted'] = np.sign(test_df_full['predicted_log']) * (np.expm1(np.abs(test_df_full['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_full[target_col_slog]
    y_pred_log = test_df_full['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_full['predicted']

    # Mask for finite values
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nFull Mixed-Effects Model (Full Model) Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf.params,
        'pvalue': mdf.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Full Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Full Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Full Model Predicted")
    plt.xscale("log")
    plt.title("Full Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    full_model_metrics = {
        "Model": "Full Model",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                         Mixed Linear Model Regression Results
# ======================================================================================================================
# Model:                           MixedLM               Dependent Variable:               slog_Scope_3_emissions_amount
# No. Observations:                572                   Method:                           ML
# No. Groups:                      192                   Scale:                            0.9507
# Min. group size:                 1                     Log-Likelihood:                   -1005.8360
# Max. group size:                 5                     Converged:                        Yes
# Mean group size:                 3.0
# ----------------------------------------------------------------------------------------------------------------------
#                                                                           Coef.  Std.Err.   z    P>|z|  [0.025  0.975]
# ----------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 87.923   71.162  1.236 0.217 -51.552 227.397
# C(Countries)[T.Belgium]                                                    3.798    1.688  2.250 0.024   0.490   7.107
# C(Countries)[T.Brazil]                                                     1.437    2.125  0.676 0.499  -2.728   5.602
# C(Countries)[T.Canada]                                                     3.445    1.142  3.015 0.003   1.206   5.684
# C(Countries)[T.China]                                                      2.870    1.319  2.176 0.030   0.285   5.456
# C(Countries)[T.Denmark]                                                    5.413    1.540  3.515 0.000   2.395   8.431
# C(Countries)[T.Finland]                                                    2.050    2.038  1.006 0.314  -1.945   6.045
# C(Countries)[T.France]                                                     2.603    1.193  2.181 0.029   0.264   4.942
# C(Countries)[T.Germany]                                                    1.379    1.350  1.022 0.307  -1.267   4.025
# C(Countries)[T.Ireland]                                                    4.038    2.204  1.832 0.067  -0.282   8.358
# C(Countries)[T.Italy]                                                      4.601    1.499  3.070 0.002   1.663   7.540
# C(Countries)[T.Japan]                                                      2.376    0.989  2.403 0.016   0.438   4.314
# C(Countries)[T.Mexico]                                                     4.664    1.675  2.784 0.005   1.381   7.946
# C(Countries)[T.Netherlands]                                                4.833    1.175  4.115 0.000   2.531   7.135
# C(Countries)[T.New Zealand]                                               -2.108    1.885 -1.118 0.263  -5.802   1.587
# C(Countries)[T.Norway]                                                     5.046    1.305  3.865 0.000   2.487   7.604
# C(Countries)[T.Portugal]                                                   8.667    2.893  2.996 0.003   2.997  14.337
# C(Countries)[T.South Africa]                                               2.976    1.348  2.207 0.027   0.334   5.619
# C(Countries)[T.South Korea]                                                1.456    1.082  1.346 0.178  -0.664   3.576
# C(Countries)[T.Spain]                                                      1.380    1.125  1.227 0.220  -0.824   3.585
# C(Countries)[T.Sweden]                                                    -0.818    2.057 -0.398 0.691  -4.850   3.214
# C(Countries)[T.Switzerland]                                               -0.107    1.210 -0.088 0.930  -2.479   2.266
# C(Countries)[T.USA]                                                        2.402    0.997  2.410 0.016   0.448   4.355
# C(Countries)[T.United Kingdom]                                             2.105    1.130  1.862 0.063  -0.110   4.320
# C(Primary_activity)[T.Animal processing]                                   3.931    2.562  1.534 0.125  -1.090   8.952
# C(Primary_activity)[T.Aquaculture]                                        -1.194    2.208 -0.541 0.589  -5.521   3.134
# C(Primary_activity)[T.Asset managers]                                      3.351    2.211  1.515 0.130  -0.983   7.685
# C(Primary_activity)[T.Automobiles]                                        -0.195    2.529 -0.077 0.938  -5.153   4.762
# C(Primary_activity)[T.Baked goods & cereals]                               5.046    2.363  2.135 0.033   0.414   9.678
# C(Primary_activity)[T.Banks]                                               2.451    1.561  1.570 0.116  -0.609   5.512
# C(Primary_activity)[T.Biotechnology]                                       1.422    1.930  0.737 0.461  -2.362   5.206
# C(Primary_activity)[T.Building sub-contractors]                            3.652    2.493  1.465 0.143  -1.234   8.538
# C(Primary_activity)[T.CCGT generation]                                     2.597    1.830  1.419 0.156  -0.990   6.184
# C(Primary_activity)[T.Commercial services]                                 2.220    2.396  0.927 0.354  -2.476   6.915
# C(Primary_activity)[T.Communications equipment]                            2.278    2.402  0.949 0.343  -2.429   6.986
# C(Primary_activity)[T.Computer hardware]                                   4.896    2.094  2.339 0.019   0.793   8.999
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                 3.424    2.219  1.543 0.123  -0.925   7.774
# C(Primary_activity)[T.Department stores]                                  -3.144    2.418 -1.301 0.193  -7.883   1.594
# C(Primary_activity)[T.Discretionary delivery retail]                       1.241    2.567  0.483 0.629  -3.791   6.273
# C(Primary_activity)[T.Electrical equipment]                                1.824    1.823  1.000 0.317  -1.749   5.396
# C(Primary_activity)[T.Electricity networks]                               -0.149    2.610 -0.057 0.955  -5.264   4.967
# C(Primary_activity)[T.Electronic components]                               1.230    1.696  0.725 0.468  -2.095   4.554
# C(Primary_activity)[T.Electronic equipment]                               -0.083    1.797 -0.046 0.963  -3.606   3.440
# C(Primary_activity)[T.Fabricated metal components]                         1.802    1.815  0.993 0.321  -1.755   5.358
# C(Primary_activity)[T.Food & beverage wholesale]                          -0.605    2.465 -0.245 0.806  -5.437   4.227
# C(Primary_activity)[T.Gas utilities]                                       1.698    1.995  0.851 0.395  -2.212   5.608
# C(Primary_activity)[T.Glass products]                                      1.904    2.387  0.798 0.425  -2.774   6.583
# C(Primary_activity)[T.Industrial machinery]                               -1.317    2.405 -0.548 0.584  -6.031   3.396
# C(Primary_activity)[T.Inorganic base chemicals]                            5.114    1.851  2.762 0.006   1.485   8.742
# C(Primary_activity)[T.Insurance]                                           3.447    1.625  2.122 0.034   0.263   6.631
# C(Primary_activity)[T.Intermodal transport]                                0.752    2.404  0.313 0.754  -3.960   5.465
# C(Primary_activity)[T.Iron & steel]                                        6.577    2.411  2.728 0.006   1.852  11.302
# C(Primary_activity)[T.Logging]                                             3.320    2.382  1.394 0.163  -1.348   7.987
# C(Primary_activity)[T.Marine freight]                                      4.768    2.382  2.002 0.045   0.099   9.436
# C(Primary_activity)[T.Marketing]                                           4.019    1.969  2.041 0.041   0.160   7.877
# C(Primary_activity)[T.Medical equipment]                                   0.820    2.103  0.390 0.697  -3.302   4.942
# C(Primary_activity)[T.Metal containers & packaging]                        4.157    2.363  1.759 0.079  -0.475   8.789
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                         3.926    2.366  1.659 0.097  -0.711   8.562
# C(Primary_activity)[T.Oil & gas pipelines & storage]                       3.607    1.922  1.877 0.061  -0.160   7.374
# C(Primary_activity)[T.Other base chemicals]                                3.273    1.688  1.939 0.053  -0.036   6.581
# C(Primary_activity)[T.Other food processing]                               1.527    1.866  0.818 0.413  -2.130   5.184
# C(Primary_activity)[T.Other professional services]                         0.018    1.779  0.010 0.992  -3.469   3.505
# C(Primary_activity)[T.Other renewable generation]                         -7.315    3.604 -2.030 0.042 -14.378  -0.252
# C(Primary_activity)[T.Paper products]                                      1.924    2.281  0.843 0.399  -2.547   6.394
# C(Primary_activity)[T.Passenger airlines]                                  2.442    1.737  1.405 0.160  -0.963   5.847
# C(Primary_activity)[T.Passenger rail]                                      3.403    2.535  1.343 0.179  -1.565   8.371
# C(Primary_activity)[T.Personal care & household products]                  2.751    1.706  1.613 0.107  -0.592   6.095
# C(Primary_activity)[T.Pharmaceuticals]                                     0.215    1.853  0.116 0.908  -3.416   3.846
# C(Primary_activity)[T.Precious metals & minerals mining]                   2.550    1.883  1.354 0.176  -1.141   6.242
# C(Primary_activity)[T.Print publishing]                                    0.705    2.041  0.345 0.730  -3.295   4.705
# C(Primary_activity)[T.Printing services]                                   0.304    2.369  0.129 0.898  -4.338   4.947
# C(Primary_activity)[T.REIT]                                                2.020    1.939  1.042 0.297  -1.780   5.820
# C(Primary_activity)[T.Residential building construction]                   1.017    2.196  0.463 0.643  -3.288   5.322
# C(Primary_activity)[T.Rubber products]                                     2.658    1.898  1.400 0.161  -1.062   6.378
# C(Primary_activity)[T.Semiconductors]                                      4.538    2.519  1.802 0.072  -0.398   9.475
# C(Primary_activity)[T.Software]                                            0.268    2.390  0.112 0.911  -4.415   4.952
# C(Primary_activity)[T.Solar energy equipment]                              2.250    2.430  0.926 0.355  -2.513   7.012
# C(Primary_activity)[T.Specialist retail]                                   0.728    2.437  0.299 0.765  -4.048   5.503
# C(Primary_activity)[T.Specialty chemicals]                                 2.541    1.726  1.472 0.141  -0.842   5.923
# C(Primary_activity)[T.Supermarkets, food & drugstores]                     2.259    1.767  1.278 0.201  -1.205   5.723
# C(Primary_activity)[T.Telecommunications services]                         3.943    1.660  2.375 0.018   0.689   7.196
# C(Primary_activity)[T.Tobacco products]                                    5.216    2.042  2.554 0.011   1.214   9.219
# C(Primary_activity)[T.Transportation infrastructure & other construction]  5.251    1.947  2.697 0.007   1.436   9.067
# C(Primary_activity)[T.Transportation support services]                     4.244    2.526  1.680 0.093  -0.707   9.194
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]              -0.810    2.129 -0.381 0.703  -4.983   3.362
# C(Primary_activity)[T.Waste management]                                   -0.683    2.362 -0.289 0.773  -5.312   3.947
# slog_Market_Cap_USD                                                       -0.094    0.128 -0.735 0.462  -0.345   0.157
# slog_Revenue_USD                                                           0.491    0.194  2.524 0.012   0.110   0.871
# slog_ebitda_USD                                                           -0.026    0.012 -2.102 0.036  -0.050  -0.002
# slog_grossProfit_USD                                                       0.006    0.019  0.293 0.769  -0.032   0.044
# slog_totalAssets_USD                                                       0.021    0.046  0.459 0.646  -0.069   0.111
# slog_totalEquity_USD                                                       0.000    0.015  0.018 0.986  -0.029   0.029
# slog_scope_1_2_emissions_amount                                            0.233    0.081  2.881 0.004   0.075   0.392
# Year                                                                      -0.047    0.036 -1.313 0.189  -0.116   0.023
# Group Var                                                                  2.915    0.470
# ======================================================================================================================
#
#
# Full Mixed-Effects Model (Full Model) Test Set Performance Metrics:
# R²(log):    40.32%
# R²(orig):   -47.01%
# MAPE:       1914.88%
# MAPE(log):  16.46%
# MAE(log):   1.57
# RMSLE:      2.02
# RMSE:       1089882.89
# MAE:        416062.39
#
# Top Influential Features (by p-value):
#                                                      coef        pvalue
# Group Var                                        3.065885  2.076816e-10
# C(Countries)[T.Netherlands]                      4.832917  3.876333e-05
# C(Countries)[T.Norway]                           5.045552  1.110680e-04
# C(Countries)[T.Denmark]                          5.413208  4.394092e-04
# C(Countries)[T.Italy]                            4.601473  2.144076e-03
# C(Countries)[T.Canada]                           3.444944  2.566728e-03
# C(Countries)[T.Portugal]                         8.666666  2.736997e-03
# slog_scope_1_2_emissions_amount                  0.233204  3.969433e-03
# C(Countries)[T.Mexico]                           4.663597  5.364038e-03
# C(Primary_activity)[T.Inorganic base chemicals]  5.113544  5.742799e-03

# %% [markdown]
# ## Investments Optimized Mixed-Effects Model
#
# An optimized mixed-effects model is used to predict company Scope 3 emissions. The model provides accurate prediction using only the most significant predictive features, while still accounting for primary activity, country and company level effects. The model is trained on data from 2018–2022 and evaluated on test data from 2023.
#
# Model Structure:
#
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:
#     - Signed log-transformed features:
#         - Revenue ('slog_Revenue_USD')
#         - Total Assets ('slog_totalAssets_USD')
#         - Scope 1 & 2 Emissions ('slog_scope_1_2_emissions_amount')
#     - Country ('Countries', as a categorical variable)
#     - Primary Activity ('Primary_activity', as a categorical variable)

# %%
feature_cols_slog = [
    'slog_Revenue_USD',
    'slog_totalAssets_USD',
    'slog_scope_1_2_emissions_amount'
]
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
all_model_vars = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_opt = train_df.dropna(subset=all_model_vars).copy()
test_df_opt = test_df.dropna(subset=all_model_vars).copy()

if test_df_opt.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity)'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the optimized mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_opt, groups=train_df_opt['account_id'])
        mdf_optimized = md.fit(reml=False)
    print(mdf_optimized.summary())

    # --- Predict on test set ---
    test_df_opt['predicted_log'] = mdf_optimized.predict(test_df_opt)
    test_df_opt['predicted'] = np.sign(test_df_opt['predicted_log']) * (np.expm1(np.abs(test_df_opt['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_opt[target_col_slog]
    y_pred_log = test_df_opt['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_opt['predicted']

    # Mask for valid/finites
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <-- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nOptimized Mixed-Effects Model: Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf_optimized.params,
        'pvalue': mdf_optimized.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Optimized Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Optimized Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Optimized Model Predicted")
    plt.xscale("log")
    plt.title("Optimized Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    optimized_model_metrics = {
        "Model": "Optimized",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                         Mixed Linear Model Regression Results
# =====================================================================================================================
# Model:                          MixedLM               Dependent Variable:               slog_Scope_3_emissions_amount
# No. Observations:               572                   Method:                           ML
# No. Groups:                     192                   Scale:                            0.9641
# Min. group size:                1                     Log-Likelihood:                   -1009.2618
# Max. group size:                5                     Converged:                        Yes
# Mean group size:                3.0
# ---------------------------------------------------------------------------------------------------------------------
#                                                                           Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Intercept                                                                 -4.929    3.988 -1.236 0.216 -12.746  2.887
# C(Countries)[T.Belgium]                                                    3.673    1.692  2.170 0.030   0.356  6.990
# C(Countries)[T.Brazil]                                                     1.424    2.122  0.671 0.502  -2.734  5.582
# C(Countries)[T.Canada]                                                     3.225    1.142  2.824 0.005   0.987  5.464
# C(Countries)[T.China]                                                      2.748    1.310  2.097 0.036   0.179  5.316
# C(Countries)[T.Denmark]                                                    5.174    1.542  3.355 0.001   2.151  8.196
# C(Countries)[T.Finland]                                                    1.830    2.045  0.895 0.371  -2.177  5.837
# C(Countries)[T.France]                                                     2.774    1.194  2.323 0.020   0.434  5.115
# C(Countries)[T.Germany]                                                    0.990    1.347  0.736 0.462  -1.649  3.629
# C(Countries)[T.Ireland]                                                    3.815    2.210  1.726 0.084  -0.517  8.147
# C(Countries)[T.Italy]                                                      4.484    1.503  2.982 0.003   1.537  7.430
# C(Countries)[T.Japan]                                                      2.338    0.984  2.375 0.018   0.409  4.267
# C(Countries)[T.Mexico]                                                     4.473    1.680  2.663 0.008   1.180  7.766
# C(Countries)[T.Netherlands]                                                4.625    1.172  3.947 0.000   2.328  6.922
# C(Countries)[T.New Zealand]                                               -2.331    1.886 -1.236 0.216  -6.028  1.366
# C(Countries)[T.Norway]                                                     4.748    1.304  3.640 0.000   2.191  7.305
# C(Countries)[T.Portugal]                                                   8.607    2.886  2.982 0.003   2.950 14.263
# C(Countries)[T.South Africa]                                               2.804    1.350  2.076 0.038   0.157  5.450
# C(Countries)[T.South Korea]                                                1.376    1.083  1.271 0.204  -0.746  3.498
# C(Countries)[T.Spain]                                                      1.267    1.126  1.125 0.261  -0.941  3.474
# C(Countries)[T.Sweden]                                                    -1.004    2.064 -0.486 0.627  -5.049  3.042
# C(Countries)[T.Switzerland]                                               -0.159    1.214 -0.131 0.896  -2.540  2.221
# C(Countries)[T.USA]                                                        2.288    0.996  2.296 0.022   0.335  4.240
# C(Countries)[T.United Kingdom]                                             2.052    1.133  1.811 0.070  -0.168  4.272
# C(Primary_activity)[T.Animal processing]                                   3.865    2.568  1.505 0.132  -1.169  8.899
# C(Primary_activity)[T.Aquaculture]                                        -1.280    2.208 -0.580 0.562  -5.608  3.048
# C(Primary_activity)[T.Asset managers]                                      3.054    2.215  1.379 0.168  -1.288  7.396
# C(Primary_activity)[T.Automobiles]                                        -0.251    2.538 -0.099 0.921  -5.224  4.723
# C(Primary_activity)[T.Baked goods & cereals]                               5.003    2.368  2.112 0.035   0.361  9.645
# C(Primary_activity)[T.Banks]                                               2.432    1.566  1.554 0.120  -0.636  5.501
# C(Primary_activity)[T.Biotechnology]                                       1.138    1.935  0.588 0.556  -2.654  4.930
# C(Primary_activity)[T.Building sub-contractors]                            3.722    2.484  1.498 0.134  -1.148  8.591
# C(Primary_activity)[T.CCGT generation]                                     2.523    1.825  1.382 0.167  -1.055  6.100
# C(Primary_activity)[T.Commercial services]                                 2.026    2.404  0.843 0.399  -2.685  6.737
# C(Primary_activity)[T.Communications equipment]                            2.220    2.400  0.925 0.355  -2.484  6.924
# C(Primary_activity)[T.Computer hardware]                                   4.731    2.100  2.253 0.024   0.616  8.847
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                 3.467    2.224  1.559 0.119  -0.891  7.825
# C(Primary_activity)[T.Department stores]                                  -3.400    2.425 -1.402 0.161  -8.154  1.353
# C(Primary_activity)[T.Discretionary delivery retail]                       1.457    2.574  0.566 0.571  -3.588  6.502
# C(Primary_activity)[T.Electrical equipment]                                1.632    1.828  0.893 0.372  -1.951  5.216
# C(Primary_activity)[T.Electricity networks]                               -0.199    2.611 -0.076 0.939  -5.317  4.919
# C(Primary_activity)[T.Electronic components]                               1.154    1.700  0.679 0.497  -2.178  4.485
# C(Primary_activity)[T.Electronic equipment]                               -0.091    1.803 -0.050 0.960  -3.625  3.444
# C(Primary_activity)[T.Fabricated metal components]                         1.792    1.811  0.989 0.323  -1.758  5.342
# C(Primary_activity)[T.Food & beverage wholesale]                          -0.174    2.403 -0.072 0.942  -4.883  4.536
# C(Primary_activity)[T.Gas utilities]                                       1.623    1.999  0.812 0.417  -2.295  5.541
# C(Primary_activity)[T.Glass products]                                      1.878    2.393  0.785 0.433  -2.813  6.569
# C(Primary_activity)[T.Industrial machinery]                               -1.475    2.413 -0.611 0.541  -6.205  3.255
# C(Primary_activity)[T.Inorganic base chemicals]                            4.925    1.856  2.653 0.008   1.287  8.564
# C(Primary_activity)[T.Insurance]                                           3.859    1.620  2.383 0.017   0.685  7.034
# C(Primary_activity)[T.Intermodal transport]                                0.492    2.410  0.204 0.838  -4.233  5.216
# C(Primary_activity)[T.Iron & steel]                                        6.681    2.413  2.769 0.006   1.952 11.410
# C(Primary_activity)[T.Logging]                                             3.352    2.384  1.406 0.160  -1.320  8.024
# C(Primary_activity)[T.Marine freight]                                      4.765    2.374  2.007 0.045   0.112  9.418
# C(Primary_activity)[T.Marketing]                                           3.891    1.973  1.972 0.049   0.024  7.758
# C(Primary_activity)[T.Medical equipment]                                   0.573    2.109  0.272 0.786  -3.561  4.707
# C(Primary_activity)[T.Metal containers & packaging]                        4.091    2.369  1.727 0.084  -0.552  8.734
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                         3.898    2.365  1.648 0.099  -0.738  8.534
# C(Primary_activity)[T.Oil & gas pipelines & storage]                       3.334    1.927  1.730 0.084  -0.443  7.110
# C(Primary_activity)[T.Other base chemicals]                                3.233    1.689  1.914 0.056  -0.077  6.543
# C(Primary_activity)[T.Other food processing]                               1.522    1.872  0.813 0.416  -2.148  5.191
# C(Primary_activity)[T.Other professional services]                        -0.098    1.785 -0.055 0.956  -3.596  3.401
# C(Primary_activity)[T.Other renewable generation]                         -7.386    3.614 -2.044 0.041 -14.470 -0.302
# C(Primary_activity)[T.Paper products]                                      1.838    2.284  0.804 0.421  -2.640  6.315
# C(Primary_activity)[T.Passenger airlines]                                  2.753    1.722  1.598 0.110  -0.623  6.128
# C(Primary_activity)[T.Passenger rail]                                      3.158    2.537  1.245 0.213  -1.814  8.131
# C(Primary_activity)[T.Personal care & household products]                  2.570    1.711  1.502 0.133  -0.783  5.924
# C(Primary_activity)[T.Pharmaceuticals]                                     0.123    1.858  0.066 0.947  -3.519  3.765
# C(Primary_activity)[T.Precious metals & minerals mining]                   2.406    1.889  1.274 0.203  -1.296  6.107
# C(Primary_activity)[T.Print publishing]                                    0.546    2.046  0.267 0.790  -3.464  4.556
# C(Primary_activity)[T.Printing services]                                   0.270    2.375  0.114 0.910  -4.386  4.925
# C(Primary_activity)[T.REIT]                                                1.453    1.934  0.752 0.452  -2.336  5.243
# C(Primary_activity)[T.Residential building construction]                   0.775    2.203  0.352 0.725  -3.544  5.094
# C(Primary_activity)[T.Rubber products]                                     2.591    1.896  1.366 0.172  -1.126  6.307
# C(Primary_activity)[T.Semiconductors]                                      4.394    2.526  1.740 0.082  -0.556  9.345
# C(Primary_activity)[T.Software]                                            0.101    2.395  0.042 0.966  -4.594  4.796
# C(Primary_activity)[T.Solar energy equipment]                              2.131    2.435  0.875 0.381  -2.641  6.902
# C(Primary_activity)[T.Specialist retail]                                   0.771    2.439  0.316 0.752  -4.009  5.551
# C(Primary_activity)[T.Specialty chemicals]                                 2.573    1.721  1.495 0.135  -0.800  5.947
# C(Primary_activity)[T.Supermarkets, food & drugstores]                     2.393    1.762  1.358 0.174  -1.060  5.846
# C(Primary_activity)[T.Telecommunications services]                         3.898    1.664  2.342 0.019   0.636  7.160
# C(Primary_activity)[T.Tobacco products]                                    5.091    2.034  2.503 0.012   1.105  9.078
# C(Primary_activity)[T.Transportation infrastructure & other construction]  5.182    1.949  2.659 0.008   1.362  9.003
# C(Primary_activity)[T.Transportation support services]                     3.956    2.530  1.564 0.118  -1.003  8.916
# C(Primary_activity)[T.Vehicles & machinery rental & leasing]              -0.892    2.134 -0.418 0.676  -5.075  3.291
# C(Primary_activity)[T.Waste management]                                   -0.858    2.370 -0.362 0.717  -5.502  3.787
# slog_Revenue_USD                                                           0.314    0.163  1.928 0.054  -0.005  0.634
# slog_totalAssets_USD                                                       0.026    0.046  0.572 0.567  -0.064  0.117
# slog_scope_1_2_emissions_amount                                            0.242    0.080  3.036 0.002   0.086  0.399
# Group Var                                                                  2.936    0.467
# =====================================================================================================================
#
#
# Optimized Mixed-Effects Model: Test Set Performance Metrics:
# R²(log):    40.84%
# R²(orig):   -64.07%
# MAPE:       2313.22%
# MAPE(log):  16.45%
# MAE(log):   1.56
# RMSLE:      2.01
# RMSE:       1151394.92
# MAE:        426051.80
#
# Top Influential Features (by p-value):
#                                          coef        pvalue
# Group Var                            3.045712  1.456483e-10
# C(Countries)[T.Netherlands]          4.625178  7.918497e-05
# C(Countries)[T.Norway]               4.747875  2.728380e-04
# C(Countries)[T.Denmark]              5.173894  7.936313e-04
# slog_scope_1_2_emissions_amount      0.242300  2.393882e-03
# C(Countries)[T.Italy]                4.483548  2.861361e-03
# C(Countries)[T.Portugal]             8.606798  2.862151e-03
# C(Countries)[T.Canada]               3.225368  4.740029e-03
# C(Primary_activity)[T.Iron & steel]  6.681028  5.625604e-03
# C(Countries)[T.Mexico]               4.473038  7.755986e-03
#
# All feature coefficients sorted by absolute value:
#                                                         coef    pvalue
# C(Countries)[T.Portugal]                            8.606798  0.002862
# C(Primary_activity)[T.Other renewable generation]  -7.386207  0.040989
# C(Primary_activity)[T.Iron & steel]                 6.681028  0.005626
# C(Primary_activity)[T.Transportation infrastruc...  5.182475  0.007847
# C(Countries)[T.Denmark]                             5.173894  0.000794
# ...                                                      ...       ...
# C(Primary_activity)[T.Pharmaceuticals]              0.123337  0.947079
# C(Primary_activity)[T.Software]                     0.101149  0.966318
# C(Primary_activity)[T.Other professional services] -0.097849  0.956284
# C(Primary_activity)[T.Electronic equipment]        -0.090739  0.959868
# slog_totalAssets_USD                                0.026356  0.567216
#
# [89 rows x 2 columns]

# %%
metrics_text_log = (
    f"R²(log):   {r2_log_pct:.2f}%\n"
    f"R²(orig):  {r2_pct:.2f}%\n"
    f"MAPE:      {mape_orig:.2f}%\n"
    f"MAPE(log): {mape_log:.2f}%\n"
    f"MAE(log):  {mae_log:.2f}\n"
    f"RMSLE:     {rmsle:.2f}\n"
    f"RMSE:      {rmse_orig:.2f}\n"
    f"MAE:       {mae_orig:.2f}"
)

fig, ax = plt.subplots(figsize=(9.5, 6))  # Wider to make room for the box

if hasattr(y_pred_log, "nunique"):
    multiple_vals = y_pred_log.nunique() > 1
else:
    multiple_vals = len(set(y_pred_log)) > 1

if multiple_vals:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=ax, color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    ax.plot([], [], ' ', label="Predicted: constant value (no KDE)")

ax.set_title("Investments Optimized Model: signed log(Scope 3 Emissions)")
ax.set_xlabel("signed log(metric tons + 1)")
ax.set_ylabel("Density")
ax.legend()

# Place metrics box outside plot to the right
fig.text(
    0.82, 0.75, metrics_text_log,
    va='top', ha='left',
    fontsize=12, bbox=dict(boxstyle='round', alpha=0.15)
)

plt.subplots_adjust(right=0.8)  # Make sure there's room for the box
fig.savefig("investments_scope3_log_density.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Metrics Table for Investments

# %%
metrics_dicts = [
    null_model_metrics,
    two_level_model_metrics,
    three_level_model_metrics,
    full_model_metrics,
    optimized_model_metrics
]

for metrics, train, test in zip(
        metrics_dicts,
        [train_df, train_df, train_df, train_df, train_df],
        [test_df, test_df, test_df, test_df, test_df]):
    
    metrics["# Obs (train)"] = len(train)
    metrics["# Obs (test)"] = len(test)
    metrics["# Obs (train/test)"] = f"{len(train)}/{len(test)}"

metrics_df = pd.DataFrame(metrics_dicts)

# Ensure all relevant columns are ordered and present
desired_order = [
    "Model", "R2_log", "R2_orig", "RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "# Obs (train/test)"
]


# Ensure MAE_log is present, fill with NaN if missing
if "MAE_log" not in metrics_df.columns:
    metrics_df["MAE_log"] = np.nan

metrics_df = metrics_df[[col for col in desired_order if col in metrics_df.columns]]

metrics_df_display = metrics_df.copy()
if "R2_log" in metrics_df_display.columns:
    metrics_df_display["R2_log"] = (metrics_df_display["R2_log"] * 100).map("{:.2f}%".format)
if "R2_orig" in metrics_df_display.columns:
    metrics_df_display["R2_orig"] = (metrics_df_display["R2_orig"] * 100).map("{:.2f}%".format)
for col in ["RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "MAPE(log)"]:
    if col in metrics_df_display.columns:
        metrics_df_display[col] = metrics_df_display[col].map("{:.2f}".format)

from IPython.display import display
display(metrics_df_display)
# Out:
#                                      Model  R2_log  R2_orig        RMSE  \
# 0                                Null (RI)  -0.29%  -16.51%   970248.65
# 1                           2-level (RI+S)  -2.51%  -17.27%   973413.01
# 2  3-level (Primary Activity/Account/Year)  17.06%  -13.41%   957257.50
# 3                               Full Model  40.32%  -47.01%  1089882.89
# 4                                Optimized  40.84%  -64.07%  1151394.92
#
#          MAE MAE_log RMSLE     MAPE # Obs (train/test)
# 0  386960.88    2.09  2.61  2090.92            572/120
# 1  388494.28    2.14  2.64  1594.70            572/120
# 2  379498.51    1.89  2.38  2244.70            572/120
# 3  416062.39    1.57  2.02  1914.88            572/120
# 4  426051.80    1.56  2.01  2313.22            572/120
