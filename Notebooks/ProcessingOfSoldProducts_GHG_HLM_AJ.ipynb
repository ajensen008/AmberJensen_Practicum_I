# %% [markdown]
# # GHG HLM on Scope 3 source Processing of Sold Products

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score, mean_squared_log_error, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GroupShuffleSplit
from scipy.stats import zscore
import scipy.stats as stats
from sklearn.feature_selection import mutual_info_regression
from sklearn.impute import SimpleImputer
import warnings
from statsmodels.regression.mixed_linear_model import MixedLM


#read in dataset from GHG_post_outliers data set
processing_of_sold_products=pd.read_csv('/Users/amberjensen/Desktop/GHG_Emissions_Project/processing_of_sold_products.csv')

# %%
#check for info
processing_of_sold_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 628 entries, 0 to 627
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_name                628 non-null    object
#  1   account_id                  628 non-null    int64
#  2   Year                        628 non-null    int64
#  3   incorporated_country        628 non-null    object
#  4   Primary activity            628 non-null    object
#  5   Primary sector              628 non-null    object
#  6   Market_Cap_USD              556 non-null    float64
#  7   Third_party_verification    628 non-null    object
#  8   Revenue_USD                 562 non-null    float64
#  9   ebitda_USD                  562 non-null    float64
#  10  grossProfit_USD             562 non-null    float64
#  11  netIncome_USD               562 non-null    float64
#  12  cashAndCashEquivalents_USD  562 non-null    float64
#  13  shortTermInvestments_USD    562 non-null    float64
#  14  longTermInvestments_USD     562 non-null    float64
#  15  totalAssets_USD             562 non-null    float64
#  16  totalLiabilities_USD        562 non-null    float64
#  17  totalInvestments_USD        562 non-null    float64
#  18  totalDebt_USD               562 non-null    float64
#  19  totalEquity_USD             562 non-null    float64
#  20  Scope_3_emissions_type      628 non-null    object
#  21  Scope_3_emissions_amount    628 non-null    float64
#  22  scope_1_2_emissions_amount  628 non-null    float64
#  23  Year_sq                     628 non-null    int64
# dtypes: float64(15), int64(3), object(6)
# memory usage: 117.9+ KB

# %%
#show a df for processing_of_sold_products
processing_of_sold_products.head()
# Out:
#                   account_name  account_id  Year incorporated_country  \
# 0                        Aptiv        4407  2018       United Kingdom
# 1            CNH Industrial NV       49607  2018       United Kingdom
# 2  Marks and Spencer Group plc       11328  2018       United Kingdom
# 3     Morgan Sindall Group plc       12392  2018       United Kingdom
# 4               Travis Perkins       19376  2018       United Kingdom
#
#                                Primary activity  \
# 0                          Electrical equipment
# 1  Agriculture, construction & mining machinery
# 2               Supermarkets, food & drugstores
# 3                      Building sub-contractors
# 4           Dealers, wholesalers & distributors
#
#                                       Primary sector  Market_Cap_USD  \
# 0                  Electrical & electronic equipment    1.595156e+10
# 1                                  Powered machinery    1.231232e+10
# 2                                 Convenience retail    4.877304e+09
# 3                                       Construction    6.518885e+08
# 4  Trading, wholesale, distribution, rental & lea...    3.382624e+09
#
#                             Third_party_verification   Revenue_USD  \
# 0           No third-party verification or assurance  1.443500e+10
# 1  Third-party verification or assurance process ...  2.970600e+10
# 2  Third-party verification or assurance process ...  1.317917e+10
# 3  Third-party verification or assurance process ...  3.773805e+09
# 4           No third-party verification or assurance  8.560435e+09
#
#      ebitda_USD  ...  longTermInvestments_USD  totalAssets_USD  \
# 0  2.260000e+09  ...               99000000.0     1.248000e+10
# 1  2.339000e+09  ...              526000000.0     4.610000e+10
# 2  1.089406e+09  ...               36195000.0     1.124077e+10
# 3  1.346200e+08  ...              128905000.0     1.723517e+09
# 4  7.391400e+07  ...               50292000.0     6.499352e+09
#
#    totalLiabilities_USD  totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0          8.810000e+09           171000000.0   4.344000e+09     3.670000e+09
# 1          4.100200e+10           526000000.0   2.444500e+10     5.098000e+09
# 2          8.104886e+09           209931000.0   5.443093e+09     3.135884e+09
# 3          1.283335e+09           105156000.0   7.251700e+07     4.401820e+08
# 4          3.047873e+09            50292000.0   7.734300e+08     3.451479e+09
#
#         Scope_3_emissions_type  Scope_3_emissions_amount  \
# 0  Processing of sold products                 110596.00
# 1  Processing of sold products                 396435.00
# 2  Processing of sold products                   1000.00
# 3  Processing of sold products                  10000.00
# 4  Processing of sold products                 107785.69
#
#    scope_1_2_emissions_amount  Year_sq
# 0                   380471.81  4072324
# 1                   310663.50  4072324
# 2                   218956.75  4072324
# 3                    20893.25  4072324
# 4                   152461.25  4072324
#
# [5 rows x 24 columns]

# %%
#define a list of numeric columns
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'ebitda_USD',
       'grossProfit_USD', 'netIncome_USD', 'cashAndCashEquivalents_USD',
       'shortTermInvestments_USD', 'longTermInvestments_USD',
       'totalAssets_USD', 'totalLiabilities_USD', 'totalInvestments_USD',
       'totalDebt_USD', 'totalEquity_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount']

# %%
#plot the heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(processing_of_sold_products[numeric_cols].corr(), annot=True, annot_kws={"size": 8})
plt.show()

# %%
#correlation matrix
processing_of_sold_products[numeric_cols].corr()
# Out:
#                             Market_Cap_USD  Revenue_USD  ebitda_USD  \
# Market_Cap_USD                    1.000000     0.062493    0.077635
# Revenue_USD                       0.062493     1.000000    0.798781
# ebitda_USD                        0.077635     0.798781    1.000000
# grossProfit_USD                   0.082495     0.870155    0.903723
# netIncome_USD                     0.082557     0.708970    0.918360
# cashAndCashEquivalents_USD        0.061909     0.726520    0.681257
# shortTermInvestments_USD         -0.012666     0.510562    0.634534
# longTermInvestments_USD           0.032799     0.465769    0.363171
# totalAssets_USD                   0.083292     0.814444    0.836068
# totalLiabilities_USD              0.078161     0.805279    0.755972
# totalInvestments_USD              0.028270     0.516073    0.444935
# totalDebt_USD                     0.097232     0.729965    0.749300
# totalEquity_USD                   0.073648     0.653994    0.782057
# Scope_3_emissions_amount          0.074726     0.143420    0.256263
# scope_1_2_emissions_amount        0.001629     0.167056    0.119169
#
#                             grossProfit_USD  netIncome_USD  \
# Market_Cap_USD                     0.082495       0.082557
# Revenue_USD                        0.870155       0.708970
# ebitda_USD                         0.903723       0.918360
# grossProfit_USD                    1.000000       0.843881
# netIncome_USD                      0.843881       1.000000
# cashAndCashEquivalents_USD         0.743256       0.610118
# shortTermInvestments_USD           0.502348       0.593249
# longTermInvestments_USD            0.314645       0.314219
# totalAssets_USD                    0.829639       0.714428
# totalLiabilities_USD               0.776878       0.629612
# totalInvestments_USD               0.374782       0.393700
# totalDebt_USD                      0.800189       0.627483
# totalEquity_USD                    0.734355       0.694338
# Scope_3_emissions_amount           0.208287       0.257005
# scope_1_2_emissions_amount         0.091424       0.041493
#
#                             cashAndCashEquivalents_USD  \
# Market_Cap_USD                                0.061909
# Revenue_USD                                   0.726520
# ebitda_USD                                    0.681257
# grossProfit_USD                               0.743256
# netIncome_USD                                 0.610118
# cashAndCashEquivalents_USD                    1.000000
# shortTermInvestments_USD                      0.411855
# longTermInvestments_USD                       0.526410
# totalAssets_USD                               0.812308
# totalLiabilities_USD                          0.796504
# totalInvestments_USD                          0.549803
# totalDebt_USD                                 0.687692
# totalEquity_USD                               0.661724
# Scope_3_emissions_amount                      0.224565
# scope_1_2_emissions_amount                    0.059708
#
#                             shortTermInvestments_USD  longTermInvestments_USD  \
# Market_Cap_USD                             -0.012666                 0.032799
# Revenue_USD                                 0.510562                 0.465769
# ebitda_USD                                  0.634534                 0.363171
# grossProfit_USD                             0.502348                 0.314645
# netIncome_USD                               0.593249                 0.314219
# cashAndCashEquivalents_USD                  0.411855                 0.526410
# shortTermInvestments_USD                    1.000000                 0.375843
# longTermInvestments_USD                     0.375843                 1.000000
# totalAssets_USD                             0.603404                 0.627043
# totalLiabilities_USD                        0.507189                 0.707597
# totalInvestments_USD                        0.524109                 0.985538
# totalDebt_USD                               0.412346                 0.277594
# totalEquity_USD                             0.624770                 0.364851
# Scope_3_emissions_amount                    0.129689                 0.097638
# scope_1_2_emissions_amount                  0.034985                 0.002483
#
#                             totalAssets_USD  totalLiabilities_USD  \
# Market_Cap_USD                     0.083292              0.078161
# Revenue_USD                        0.814444              0.805279
# ebitda_USD                         0.836068              0.755972
# grossProfit_USD                    0.829639              0.776878
# netIncome_USD                      0.714428              0.629612
# cashAndCashEquivalents_USD         0.812308              0.796504
# shortTermInvestments_USD           0.603404              0.507189
# longTermInvestments_USD            0.627043              0.707597
# totalAssets_USD                    1.000000              0.948289
# totalLiabilities_USD               0.948289              1.000000
# totalInvestments_USD               0.678947              0.737260
# totalDebt_USD                      0.834082              0.852602
# totalEquity_USD                    0.866485              0.663595
# Scope_3_emissions_amount           0.215279              0.238996
# scope_1_2_emissions_amount         0.169418              0.176110
#
#                             totalInvestments_USD  totalDebt_USD  \
# Market_Cap_USD                          0.028270       0.097232
# Revenue_USD                             0.516073       0.729965
# ebitda_USD                              0.444935       0.749300
# grossProfit_USD                         0.374782       0.800189
# netIncome_USD                           0.393700       0.627483
# cashAndCashEquivalents_USD              0.549803       0.687692
# shortTermInvestments_USD                0.524109       0.412346
# longTermInvestments_USD                 0.985538       0.277594
# totalAssets_USD                         0.678947       0.834082
# totalLiabilities_USD                    0.737260       0.852602
# totalInvestments_USD                    1.000000       0.324454
# totalDebt_USD                           0.324454       1.000000
# totalEquity_USD                         0.440609       0.625766
# Scope_3_emissions_amount                0.111796       0.365083
# scope_1_2_emissions_amount              0.008436       0.234404
#
#                             totalEquity_USD  Scope_3_emissions_amount  \
# Market_Cap_USD                     0.073648                  0.074726
# Revenue_USD                        0.653994                  0.143420
# ebitda_USD                         0.782057                  0.256263
# grossProfit_USD                    0.734355                  0.208287
# netIncome_USD                      0.694338                  0.257005
# cashAndCashEquivalents_USD         0.661724                  0.224565
# shortTermInvestments_USD           0.624770                  0.129689
# longTermInvestments_USD            0.364851                  0.097638
# totalAssets_USD                    0.866485                  0.215279
# totalLiabilities_USD               0.663595                  0.238996
# totalInvestments_USD               0.440609                  0.111796
# totalDebt_USD                      0.625766                  0.365083
# totalEquity_USD                    1.000000                  0.131263
# Scope_3_emissions_amount           0.131263                  1.000000
# scope_1_2_emissions_amount         0.128937                  0.153367
#
#                             scope_1_2_emissions_amount
# Market_Cap_USD                                0.001629
# Revenue_USD                                   0.167056
# ebitda_USD                                    0.119169
# grossProfit_USD                               0.091424
# netIncome_USD                                 0.041493
# cashAndCashEquivalents_USD                    0.059708
# shortTermInvestments_USD                      0.034985
# longTermInvestments_USD                       0.002483
# totalAssets_USD                               0.169418
# totalLiabilities_USD                          0.176110
# totalInvestments_USD                          0.008436
# totalDebt_USD                                 0.234404
# totalEquity_USD                               0.128937
# Scope_3_emissions_amount                      0.153367
# scope_1_2_emissions_amount                    1.000000

# %%
#drop columns due to collinearity, keeping total
processing_of_sold_products=processing_of_sold_products.drop(columns=['grossProfit_USD', 'netIncome_USD', 'ebitda_USD', 'totalLiabilities_USD', 'longTermInvestments_USD', 
                                                                      'cashAndCashEquivalents_USD', "account_name", "Third_party_verification", "Scope_3_emissions_type"])

# %%
processing_of_sold_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 628 entries, 0 to 627
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  628 non-null    int64
#  1   Year                        628 non-null    int64
#  2   incorporated_country        628 non-null    object
#  3   Primary activity            628 non-null    object
#  4   Primary sector              628 non-null    object
#  5   Market_Cap_USD              556 non-null    float64
#  6   Revenue_USD                 562 non-null    float64
#  7   shortTermInvestments_USD    562 non-null    float64
#  8   totalAssets_USD             562 non-null    float64
#  9   totalInvestments_USD        562 non-null    float64
#  10  totalDebt_USD               562 non-null    float64
#  11  totalEquity_USD             562 non-null    float64
#  12  Scope_3_emissions_amount    628 non-null    float64
#  13  scope_1_2_emissions_amount  628 non-null    float64
#  14  Year_sq                     628 non-null    int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 73.7+ KB

# %%
sns.boxplot(processing_of_sold_products)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
#plot a scatter plot of scope year emissions and scope 1_2 emissions

sns.scatterplot(x='Year', y='Market_Cap_USD', data=processing_of_sold_products)
# Out:
# <Axes: xlabel='Year', ylabel='Market_Cap_USD'>

# %%
processing_of_sold_products_sorted=processing_of_sold_products.sort_values(by='Market_Cap_USD', ascending=False).reset_index(drop=True)

#display sorted df
processing_of_sold_products_sorted.head()
# Out:
#    account_id  Year incorporated_country    Primary activity  \
# 0       21889  2020                Chile  Pulp & paper mills
# 1       21889  2023                Chile  Pulp & paper mills
# 2       21889  2021                Chile  Pulp & paper mills
# 3       21889  2022                Chile  Pulp & paper mills
# 4       45103  2022                  USA     Pharmaceuticals
#
#            Primary sector  Market_Cap_USD   Revenue_USD  \
# 0  Wood & paper materials    4.634520e+12  5.286927e+09
# 1  Wood & paper materials    4.259662e+12  8.099816e+09
# 2  Wood & paper materials    3.570000e+12  6.323022e+09
# 3  Wood & paper materials    3.539750e+12  7.821345e+09
# 4        Biotech & pharma    2.859174e+11  5.805400e+10
#
#    shortTermInvestments_USD  totalAssets_USD  totalInvestments_USD  \
# 0             -3.293868e+09     1.472695e+10             2589000.0
# 1              5.186400e+07     1.717731e+10            16092000.0
# 2             -3.212794e+09     1.522630e+10             5603000.0
# 3              9.440000e+06     1.657198e+10            76173000.0
# 4              2.800000e+07     1.388050e+11           269000000.0
#
#    totalDebt_USD  totalEquity_USD  Scope_3_emissions_amount  \
# 0   4.163993e+09     7.866137e+09                 2329772.0
# 1   5.774675e+09     7.884897e+09                 1266561.0
# 2   4.499243e+09     7.548950e+09                 2104000.0
# 3   5.040226e+09     7.910821e+09                 1411165.0
# 4   6.327100e+10     1.728700e+10                  167412.0
#
#    scope_1_2_emissions_amount  Year_sq
# 0                   2135992.5  4080400
# 1                   1968684.0  4092529
# 2                   2154818.0  4084441
# 3                   2023386.0  4088484
# 4                    624662.0  4088484

# %%
#remove account id=21889

processing_of_sold_products=processing_of_sold_products[processing_of_sold_products['account_id']!=21889]

# %%
#rerun the plot
sns.scatterplot(x='Year', y='Market_Cap_USD', data=processing_of_sold_products)
# Out:
# <Axes: xlabel='Year', ylabel='Market_Cap_USD'>

# %%
# copy dataframe
processing_of_sold_products_no_transform = processing_of_sold_products.copy()
# Change 'incorporated_country' to 'Countries' in processing_of_sold_products dataframe
processing_of_sold_products_no_transform = processing_of_sold_products_no_transform.rename(columns={'incorporated_country': 'Countries',
                                                       'Primary activity': 'Primary_activity',
                                                        'Primary sector': 'Primary_sector'})

print(processing_of_sold_products_no_transform.info())
processing_of_sold_products_no_transform.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 624 entries, 0 to 627
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   account_id                  624 non-null    int64
#  1   Year                        624 non-null    int64
#  2   Countries                   624 non-null    object
#  3   Primary_activity            624 non-null    object
#  4   Primary_sector              624 non-null    object
#  5   Market_Cap_USD              552 non-null    float64
#  6   Revenue_USD                 558 non-null    float64
#  7   shortTermInvestments_USD    558 non-null    float64
#  8   totalAssets_USD             558 non-null    float64
#  9   totalInvestments_USD        558 non-null    float64
#  10  totalDebt_USD               558 non-null    float64
#  11  totalEquity_USD             558 non-null    float64
#  12  Scope_3_emissions_amount    624 non-null    float64
#  13  scope_1_2_emissions_amount  624 non-null    float64
#  14  Year_sq                     624 non-null    int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 78.0+ KB
# None
#    account_id  Year       Countries  \
# 0        4407  2018  United Kingdom
# 1       49607  2018  United Kingdom
# 2       11328  2018  United Kingdom
# 3       12392  2018  United Kingdom
# 4       19376  2018  United Kingdom
#
#                                Primary_activity  \
# 0                          Electrical equipment
# 1  Agriculture, construction & mining machinery
# 2               Supermarkets, food & drugstores
# 3                      Building sub-contractors
# 4           Dealers, wholesalers & distributors
#
#                                       Primary_sector  Market_Cap_USD  \
# 0                  Electrical & electronic equipment    1.595156e+10
# 1                                  Powered machinery    1.231232e+10
# 2                                 Convenience retail    4.877304e+09
# 3                                       Construction    6.518885e+08
# 4  Trading, wholesale, distribution, rental & lea...    3.382624e+09
#
#     Revenue_USD  shortTermInvestments_USD  totalAssets_USD  \
# 0  1.443500e+10                72000000.0     1.248000e+10
# 1  2.970600e+10                       0.0     4.610000e+10
# 2  1.317917e+10               173736000.0     1.124077e+10
# 3  3.773805e+09               -23749000.0     1.723517e+09
# 4  8.560435e+09                       0.0     6.499352e+09
#
#    totalInvestments_USD  totalDebt_USD  totalEquity_USD  \
# 0           171000000.0   4.344000e+09     3.670000e+09
# 1           526000000.0   2.444500e+10     5.098000e+09
# 2           209931000.0   5.443093e+09     3.135884e+09
# 3           105156000.0   7.251700e+07     4.401820e+08
# 4            50292000.0   7.734300e+08     3.451479e+09
#
#    Scope_3_emissions_amount  scope_1_2_emissions_amount  Year_sq
# 0                 110596.00                   380471.81  4072324
# 1                 396435.00                   310663.50  4072324
# 2                   1000.00                   218956.75  4072324
# 3                  10000.00                    20893.25  4072324
# 4                 107785.69                   152461.25  4072324

# %%
processing_of_sold_products_no_transform['Primary_sector'].value_counts()
# Out:
# Primary_sector
# Electrical & electronic equipment                     117
# Chemicals                                              78
# Food & beverage processing                             70
# Metallic mineral mining                                28
# Paper products & packaging                             27
# Biotech & pharma                                       25
# Oil & gas extraction & production                      24
# Wood & paper materials                                 21
# Powered machinery                                      18
# Metal products manufacturing                           15
# Construction                                           14
# Transportation equipment                               14
# Thermal power generation                               13
# Wood & rubber products                                 13
# Energy utility networks                                13
# Metal smelting, refining & forming                     13
# Specialized professional services                      12
# Plastic product manufacturing                          11
# Medical equipment & supplies                           10
# Convenience retail                                      9
# Other materials                                         9
# Light manufacturing                                     7
# Trading, wholesale, distribution, rental & leasing      7
# Bars, hotels & restaurants                              7
# Textiles & fabric goods                                 7
# Leisure & home manufacturing                            6
# Logging & rubber tapping                                6
# Tobacco                                                 6
# Cement & concrete                                       6
# Health care provision                                   4
# Non-energy utilities                                    3
# Fish & animal farming                                   3
# Media, telecommunications & data center services        2
# Road transport                                          2
# Financial services                                      2
# Intermodal transport & logistics                        1
# 0                                                       1
# Name: count, dtype: int64

# %%
processing_of_sold_products_no_transform['Primary_activity'].value_counts().head(20)
# Out:
# Primary_activity
# Electronic components                           54
# Other food processing                           37
# Electronic equipment                            31
# Other base chemicals                            29
# Specialty chemicals                             27
# Paper products                                  27
# Pharmaceuticals                                 25
# Oil & gas extraction                            24
# Precious metals & minerals mining               21
# Pulp & paper mills                              21
# Non-alcoholic beverages                         16
# Computer hardware                               14
# Automobiles                                     13
# Gas utilities                                   13
# Personal care & household products              12
# Metal containers & packaging                    12
# Other professional services                     12
# Agriculture, construction & mining machinery    11
# Plastic products                                11
# Electrical equipment                            11
# Name: count, dtype: int64

# %%
# Looking at missing data
print(processing_of_sold_products_no_transform.isnull().mean().sort_values(ascending=False).round(3) * 100)
# Out:
# Market_Cap_USD                11.5
# Revenue_USD                   10.6
# shortTermInvestments_USD      10.6
# totalAssets_USD               10.6
# totalInvestments_USD          10.6
# totalDebt_USD                 10.6
# totalEquity_USD               10.6
# account_id                     0.0
# Year                           0.0
# Countries                      0.0
# Primary_activity               0.0
# Primary_sector                 0.0
# Scope_3_emissions_amount       0.0
# scope_1_2_emissions_amount     0.0
# Year_sq                        0.0
# dtype: float64

# %% [markdown]
# Apply signed log transformation and split data by company and year into train_df (2018-2022) and test_df (2023):

# %%
numeric_cols = ['Market_Cap_USD', 'Revenue_USD', 'shortTermInvestments_USD', 'totalAssets_USD',
                'totalInvestments_USD', 'totalEquity_USD', 'Scope_3_emissions_amount', 'scope_1_2_emissions_amount'
]
required_cols = [
    'account_id', 'Year', 'Year_sq', 'Countries', 'Primary_activity', 'Primary_sector'
] + numeric_cols

# --- Prepare Data ---
df = processing_of_sold_products_no_transform[required_cols].dropna()

# --- Signed log transform ---
def signed_log(x):
    return np.sign(x) * np.log(np.abs(x) + 1)

for col in numeric_cols:
    df[f'slog_{col}'] = signed_log(df[col])

# --- Company-level split by year ---
train_df = df[df['Year'].between(2018, 2022)].copy()
test_df  = df[df['Year'] == 2023].copy()

# Keep only companies present in training
valid_companies = set(train_df['account_id'].unique())
test_df = test_df[test_df['account_id'].isin(valid_companies)].copy()

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (429, 22)
# Test shape: (91, 22)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 429 entries, 0 to 488
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       429 non-null    int64
#  1   Year                             429 non-null    int64
#  2   Year_sq                          429 non-null    int64
#  3   Countries                        429 non-null    object
#  4   Primary_activity                 429 non-null    object
#  5   Primary_sector                   429 non-null    object
#  6   Market_Cap_USD                   429 non-null    float64
#  7   Revenue_USD                      429 non-null    float64
#  8   shortTermInvestments_USD         429 non-null    float64
#  9   totalAssets_USD                  429 non-null    float64
#  10  totalInvestments_USD             429 non-null    float64
#  11  totalEquity_USD                  429 non-null    float64
#  12  Scope_3_emissions_amount         429 non-null    float64
#  13  scope_1_2_emissions_amount       429 non-null    float64
#  14  slog_Market_Cap_USD              429 non-null    float64
#  15  slog_Revenue_USD                 429 non-null    float64
#  16  slog_shortTermInvestments_USD    429 non-null    float64
#  17  slog_totalAssets_USD             429 non-null    float64
#  18  slog_totalInvestments_USD        429 non-null    float64
#  19  slog_totalEquity_USD             429 non-null    float64
#  20  slog_Scope_3_emissions_amount    429 non-null    float64
#  21  slog_scope_1_2_emissions_amount  429 non-null    float64
# dtypes: float64(16), int64(3), object(3)
# memory usage: 77.1+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91 entries, 491 to 624
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   account_id                       91 non-null     int64
#  1   Year                             91 non-null     int64
#  2   Year_sq                          91 non-null     int64
#  3   Countries                        91 non-null     object
#  4   Primary_activity                 91 non-null     object
#  5   Primary_sector                   91 non-null     object
#  6   Market_Cap_USD                   91 non-null     float64
#  7   Revenue_USD                      91 non-null     float64
#  8   shortTermInvestments_USD         91 non-null     float64
#  9   totalAssets_USD                  91 non-null     float64
#  10  totalInvestments_USD             91 non-null     float64
#  11  totalEquity_USD                  91 non-null     float64
#  12  Scope_3_emissions_amount         91 non-null     float64
#  13  scope_1_2_emissions_amount       91 non-null     float64
#  14  slog_Market_Cap_USD              91 non-null     float64
#  15  slog_Revenue_USD                 91 non-null     float64
#  16  slog_shortTermInvestments_USD    91 non-null     float64
#  17  slog_totalAssets_USD             91 non-null     float64
#  18  slog_totalInvestments_USD        91 non-null     float64
#  19  slog_totalEquity_USD             91 non-null     float64
#  20  slog_Scope_3_emissions_amount    91 non-null     float64
#  21  slog_scope_1_2_emissions_amount  91 non-null     float64
# dtypes: float64(16), int64(3), object(3)
# memory usage: 16.4+ KB

# %%
# Check number of 0's in train and test df's
print((train_df == 0).sum().sum())
print((test_df == 0).sum().sum())
# Out:
# 180
# 72

# %% [markdown]
# ## Processing of Sold Products Null Mixed-Effects Model
#
# Null mixed-effects model (random intercept only) to predict log-transformed Scope 3 emissions. The model serves as a baseline, capturing only the average emission level for each company, without incorporating any explanatory variables, and quantifies the improvement gained by including additional features and structure. The model is trained on 2018–2022 data and evaluated on a test set from 2023.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies
# - Fixed Effects:
#     - Intercept only (no predictors)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE NULL MODEL (random intercept only) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    null_model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ 1",
        train_df,
        groups=train_df["account_id"]
    )
    null_result = null_model.fit(method="lbfgs")

if not null_result.converged:
    print("WARNING: Null model did not fully converge.")

print(null_result.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_null'] = null_result.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_null']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_null'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics text
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[0], color='gray')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Null Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Null Model Predicted', linewidth=2, fill=True, ax=axes[1], color='gray')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Null Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Null Model Predicted")
plt.xscale("log")
plt.title("Null Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
null_model_metrics = {
    "Model": "Null (RI)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "Random intercept only"
}
# Out:
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 429     Method:             REML
# No. Groups:       126     Scale:              0.6686
# Min. group size:  1       Log-Likelihood:     -758.6159
# Max. group size:  5       Converged:          Yes
# Mean group size:  3.4
# ------------------------------------------------------------------------------
#                 Coef.      Std.Err.       z        P>|z|     [0.025     0.975]
# ------------------------------------------------------------------------------
# Intercept       10.765        0.283     38.081     0.000     10.211     11.319
# Group Var        9.773        1.875
# ==========================================================================
#
# R²(log):    -0.02%
# R²(orig):   -9.77%
# MAPE:       96736.11%
# MAPE(log):  55.33%
# MAE(log):   2.41
# RMSLE:      3.17
# RMSE:       2547951.19
# MAE:        789958.71

# %% [markdown]
# ## Processing of Sold Products Two-Level Mixed-Effects Model
#
# Two-level hierarchical linear mixed-effects model to predict log-transformed Scope 3 emissions at the company level. The model is fit to training data (from 2018–2022), and predictions are evaluated on a test set (from 2023).  This model provides a baseline for including time trends and company-level variability.
#
# Model Structure:
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing baseline differences between companies.<br>
# - Fixed Effects:
#     - Year (numeric)
#     - Year squared ('Year_sq', quadratic time trend)

# %%
# --- Ensure log_Scope_3_emissions_amount exists (if not, create it) ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- Check group sizes ---
group_sizes = train_df.groupby('account_id').size()
print("Two-Level Model: Company/year group size summary:")
print(group_sizes.describe())

# --- FIT THE TWO-LEVEL MODEL (random intercept, +Year, +Year_sq) ---
with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model = smf.mixedlm(
        "log_Scope_3_emissions_amount ~ Year + Year_sq",
        train_df,
        groups=train_df["account_id"],
        re_formula="1"
    )
    result_twolevel = model.fit(method="lbfgs")

if not result_twolevel.converged:
    print("WARNING: Two-level mixed model did not fully converge.")

print(result_twolevel.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_twolevel.predict(test_df)

# --- METRICS ---
y_true_log = test_df['log_Scope_3_emissions_amount']
y_pred_log = test_df['predicted_mixed']

# Remove inf/nan for robust metrics
mask = np.isfinite(y_true_log) & np.isfinite(y_pred_log)
y_true_log = y_true_log[mask]
y_pred_log = y_pred_log[mask]
test_df = test_df.loc[mask].copy()

# Log-scale MAPE
mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100

# Back-transform for original scale metrics
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])
y_true = test_df['Reported_Scope_3']
y_pred = test_df['Predicted_Scope_3']

# Remove inf/nan for robust metrics
mask2 = np.isfinite(y_true) & np.isfinite(y_pred)
y_true = y_true[mask2]
y_pred = y_pred[mask2]

# Metrics calculations
r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_orig_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)
mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

# Print metrics
metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_orig_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# 1. Density plot on log scale
if y_pred_log.nunique() > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='orange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Two-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()

axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

# 2. Density plot on original scale
if y_pred.nunique() > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Two-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='orange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Two-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()

axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Histogram on original scale with log x-axis
min_val = min(y_true.min(), y_pred.min())
max_val = max(y_true.max(), y_pred.max())
log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

plt.figure(figsize=(8, 5))
sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
sns.histplot(y_pred, bins=log_bins, stat="density", color="orange", alpha=0.5, label="Two-Level Model Predicted")
plt.xscale("log")
plt.title("Two-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
plt.ylabel("Density")
plt.legend()
plt.tight_layout()
plt.show()

# --- RETURN METRICS FOR SUMMARY TABLE ---
two_level_model_metrics = {
    "Model": "2-level (RI+S)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_orig_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,  # <--- include MAE for log-transformed emissions
    "Notes": "+Year, Year_sq"
}
# Out:
# Two-Level Model: Company/year group size summary:
# count    126.000000
# mean       3.404762
# std        1.716641
# min        1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000
# dtype: float64
#                   Mixed Linear Model Regression Results
# ==========================================================================
# Model:            MixedLM Dependent Variable: log_Scope_3_emissions_amount
# No. Observations: 429     Method:             REML
# No. Groups:       126     Scale:              0.6598
# Min. group size:  1       Log-Likelihood:     -761.1660
# Max. group size:  5       Converged:          Yes
# Mean group size:  3.4
# ---------------------------------------------------------------------------
#                Coef.      Std.Err.     z     P>|z|     [0.025      0.975]
# ---------------------------------------------------------------------------
# Intercept    -78240.806  101373.809  -0.772  0.440  -276929.821  120448.208
# Year             77.405     100.368   0.771  0.441     -119.312     274.122
# Year_sq          -0.019       0.025  -0.771  0.441       -0.068       0.030
# Group Var         9.812       1.897
# ==========================================================================
#
# R²(log):    -0.09%
# R²(orig):   -9.70%
# MAPE:       101836.67%
# MAPE(log):  55.53%
# MAE(log):   2.40
# RMSLE:      3.17
# RMSE:       2547207.70
# MAE:        789629.13

# %% [markdown]
# ## Processing of Sold Products Three-Level Mixed-Effects Model
#
# A three-level hierarchical linear mixed-effects model is used to predict log-transformed Scope 3 emissions. It takes into account differences between primary activity, differences between companies, and changes over time. The model is trained using data from 2018 to 2022, and then tested on new data from 2023. This model provides insight on how emissions are influenced by primary activity, by individual companies, by financial and emissions factors, and by trends over time.
#
# Model Structure:
#
# - Level 3 (Primary Activity):<br>
#     - Random intercept and random slope for Year for each primary activity ('Primary_activity'), capturing baseline primary activity and primary activity-specific time trends.<br>
# - Level 2 (Account/Company):
#     - Random intercept for each company ('account_id'), capturing company-level deviations within each primary activity.
# - Level 1 (Yearly Observations):
#     - Repeated annual observations within each company.
#
# - Fixed Effects:
#     - Signed log-transformed market cap ('slog_Market_Cap_USD')
#     - Signed log-transformed revenue ('slog_Revenue_USD')
#     - *Removed: Signed log-transformed EBITDA ('slog_ebitda_USD') due to collinearity*
#     - Signed log-transformed Scope 1 & 2 emissions ('slog_scope_1_2_emissions_amount')

# %%
# --- Ensure grouping/categorical variables are string ---
for col in ['Countries', 'account_id', 'Primary_activity', 'Primary_sector']:
    train_df[col] = train_df[col].astype(str)
    test_df[col] = test_df[col].astype(str)

# --- Center the Year variable ---
year_mean = train_df['Year'].mean()
train_df['Year_centered'] = train_df['Year'] - year_mean
test_df['Year_centered'] = test_df['Year'] - year_mean

# --- Ensure log-transformed target exists ---
if 'log_Scope_3_emissions_amount' not in train_df.columns:
    train_df['log_Scope_3_emissions_amount'] = np.log1p(train_df['Scope_3_emissions_amount'])
if 'log_Scope_3_emissions_amount' not in test_df.columns:
    test_df['log_Scope_3_emissions_amount'] = np.log1p(test_df['Scope_3_emissions_amount'])

# --- FIT THE 3-LEVEL MIXED MODEL with Primary_activity as Level 3 group ---
vc = {'account_id': '0 + C(account_id)'}  # Level 2: account_id random intercept

with warnings.catch_warnings():
    warnings.filterwarnings('ignore')
    model_3level = MixedLM.from_formula(
        'log_Scope_3_emissions_amount ~ slog_Market_Cap_USD + slog_Revenue_USD + slog_scope_1_2_emissions_amount',
        groups='Primary_activity',
        re_formula='~Year_centered',
        vc_formula=vc,
        data=train_df
    )
    result_3level = model_3level.fit(method="lbfgs", maxiter=1000)

if not result_3level.converged:
    print("WARNING: Three-level mixed model did not fully converge.")

print(result_3level.summary())

# --- PREDICT ON TEST SET ---
test_df = test_df.copy()
test_df['predicted_mixed'] = result_3level.predict(test_df)

# --- Compute back-transformed values ---
test_df['Reported_Scope_3'] = np.expm1(test_df['log_Scope_3_emissions_amount'])
test_df['Predicted_Scope_3'] = np.expm1(test_df['predicted_mixed'])

# --- Robust Mask for finite values everywhere ---
mask = (
    np.isfinite(test_df['log_Scope_3_emissions_amount']) &
    np.isfinite(test_df['predicted_mixed']) &
    np.isfinite(test_df['Reported_Scope_3']) &
    np.isfinite(test_df['Predicted_Scope_3'])
)
test_df = test_df.loc[mask].copy()

y_true_log = test_df['log_Scope_3_emissions_amount'].values
y_pred_log = test_df['predicted_mixed'].values
y_true = test_df['Reported_Scope_3'].values
y_pred = test_df['Predicted_Scope_3'].values

# Final defensive check and diagnostics
arrays = {
    "y_true_log": y_true_log,
    "y_pred_log": y_pred_log,
    "y_true": y_true,
    "y_pred": y_pred,
}
for arr_name, arr in arrays.items():
    if not np.all(np.isfinite(arr)):
        print(f"ERROR: {arr_name} contains non-finite values!")
        print(f"Non-finite indices: {np.where(~np.isfinite(arr))[0]}")
        print(f"Values: {arr[~np.isfinite(arr)]}")
        raise ValueError(f"{arr_name} contains infs or NaNs after masking!")

# --- METRICS ---
mae_log = mean_absolute_error(y_true_log, y_pred_log)
nonzero_mask = y_true_log != 0
if np.any(nonzero_mask):
    mape_log = np.mean(np.abs((y_true_log[nonzero_mask] - y_pred_log[nonzero_mask]) / y_true_log[nonzero_mask])) * 100
else:
    mape_log = np.nan

r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
r2_pct = r2_score(y_true, y_pred) * 100
mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
mae_orig = mean_absolute_error(y_true, y_pred)

metrics_text = (
    f"R²(log):    {r2_log_pct:.2f}%\n"
    f"R²(orig):   {r2_pct:.2f}%\n"
    f"MAPE:       {mape_orig:.2f}%\n"
    f"MAPE(log):  {mape_log:.2f}%\n"
    f"MAE(log):   {mae_log:.2f}\n"
    f"RMSLE:      {rmsle:.2f}\n"
    f"RMSE:       {rmse_orig:.2f}\n"
    f"MAE:        {mae_orig:.2f}"
)
print(metrics_text)

# --- VISUALIZATION ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
if len(np.unique(y_pred_log)) > 1:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    sns.kdeplot(y_pred_log, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
    axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[0].set_title("Three-Level Model: log(Scope 3 Emissions)")
axes[0].set_xlabel("log(metric tons + 1)")
axes[0].set_ylabel("Density")
axes[0].legend()
axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

if len(np.unique(y_pred)) > 1:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    sns.kdeplot(y_pred, label='Three-Level Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
else:
    sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
    axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
axes[1].set_title("Three-Level Model: Scope 3 Emissions (Original Scale)")
axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
axes[1].set_ylabel("Density")
axes[1].legend()
axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
             verticalalignment='top', fontsize=10, bbox=dict(boxstyle='round', alpha=0.1))

plt.tight_layout()
plt.show()

# Filter strictly positive values for histogram (log x-axis requires >0)
y_true_pos = y_true[y_true > 0]
y_pred_pos = y_pred[y_pred > 0]

if y_true_pos.size > 0 and y_pred_pos.size > 0:
    min_val = min(y_true_pos.min(), y_pred_pos.min())
    max_val = max(y_true_pos.max(), y_pred_pos.max())
    if min_val == max_val:
        print("Skipping histogram: Only one unique positive value present.")
    else:
        log_bins = np.logspace(np.log10(min_val), np.log10(max_val), 100)

        plt.figure(figsize=(8, 5))
        sns.histplot(y_true_pos, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
        sns.histplot(y_pred_pos, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Three-Level Model Predicted")
        plt.xscale("log")
        plt.title("Three-Level Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
        plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
        plt.ylabel("Density")
        plt.legend()
        plt.tight_layout()
        plt.show()
else:
    print("Skipping histogram: Not enough positive values in y_true or y_pred for log-scale histogram.")

# --- RETURN METRICS FOR SUMMARY TABLE ---
three_level_model_metrics = {
    "Model": "3-level (Primary Activity/Account/Year)",
    "R2_log": r2_log_pct / 100,
    "R2_orig": r2_pct / 100,
    "RMSE": rmse_orig,
    "MAE": mae_orig,
    "RMSLE": rmsle,
    "MAPE": mape_orig,
    "MAE_log": mae_log,
    "MAPE(log)": mape_log,
}
# Out:
#                      Mixed Linear Model Regression Results
# ================================================================================
# Model:              MixedLM   Dependent Variable:   log_Scope_3_emissions_amount
# No. Observations:   429       Method:               REML
# No. Groups:         55        Scale:                0.5019
# Min. group size:    1         Log-Likelihood:       -719.8545
# Max. group size:    44        Converged:            Yes
# Mean group size:    7.8
# --------------------------------------------------------------------------------
#                                      Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# --------------------------------------------------------------------------------
# Intercept                            -5.313    3.874 -1.372 0.170 -12.906  2.279
# slog_Market_Cap_USD                   0.112    0.108  1.035 0.300  -0.100  0.323
# slog_Revenue_USD                      0.154    0.204  0.752 0.452  -0.247  0.554
# slog_scope_1_2_emissions_amount       0.753    0.120  6.255 0.000   0.517  0.989
# Primary_activity Var                  0.154    0.822
# Primary_activity x Year_centered Cov -0.002    0.135
# Year_centered Var                     0.069    0.038
# account_id Var                        7.051    1.764
# ================================================================================
#
# R²(log):    26.86%
# R²(orig):   -5.42%
# MAPE:       36384.31%
# MAPE(log):  47.92%
# MAE(log):   2.02
# RMSLE:      2.71
# RMSE:       2496961.89
# MAE:        772827.84

# %% [markdown]
# ## Processing of Sold Products Full Mixed-Effects Model
#
# A full mixed-effects model is used to predict company Scope 3 emissions, using financial and emissions data, along with information about country, industry, and year. The model is trained on data from 2018 to 2022, and tested on data from 2023. This full model helps provides insights into how a company’s finances, emissions, primary activity, country and the year influence emissions.<br>
#
# Model Structure:<br>
#
# - Random Effects:<br>
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:<br>
#     - Signed log-transformed financial and emissions features:<br>
#         - Market Cap ('slog_Market_Cap_USD')<br>
#         - Revenue ('slog_Revenue_USD')<br>
#         - Short Term Investments ('slog_shortTermInvestments_USD')
#         - Total Assets ('slog_totalAssets_USD')<br>
#         - Total Investments ('slog_totalInvestments_USD')
#         - Total Equity ('slog_totalEquity_USD')<br>
#         - Scope 1&2 Emissions ('slog_scope_1_2_emissions_amount')<br>
#     - Country ('Countries', as a categorical variable)<br>
#     - Primary Activity ('Primary_activity', as a categorical variable)<br>
#     - Year (numeric)<br>

# %%
# --- Feature and target columns ---
numeric_cols = ['Market_Cap_USD',
 'Revenue_USD',
 'shortTermInvestments_USD',
 'totalAssets_USD',
 'totalInvestments_USD',
 'totalEquity_USD',
 'Scope_3_emissions_amount',
 'scope_1_2_emissions_amount'
]
feature_cols_slog = [f'slog_{col}' for col in numeric_cols if col != 'Scope_3_emissions_amount']
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
required_cols = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_full = train_df.dropna(subset=required_cols).copy()
test_df_full = test_df.dropna(subset=required_cols).copy()

if test_df_full.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity) + Year'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the full mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_full, groups=train_df_full['account_id'])
        mdf = md.fit(reml=False)
    print(mdf.summary())

    # --- Predict on test set ---
    test_df_full['predicted_log'] = mdf.predict(test_df_full)
    test_df_full['predicted'] = np.sign(test_df_full['predicted_log']) * (np.expm1(np.abs(test_df_full['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_full[target_col_slog]
    y_pred_log = test_df_full['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_full['predicted']

    # Mask for finite values
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <--- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nFull Mixed-Effects Model (Full Model) Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf.params,
        'pvalue': mdf.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Full Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Full Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Full Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Full Model Predicted")
    plt.xscale("log")
    plt.title("Full Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    full_model_metrics = {
        "Model": "Full Model",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                             Mixed Linear Model Regression Results
# =============================================================================================================================
# Model:                              MixedLM                 Dependent Variable:                 slog_Scope_3_emissions_amount
# No. Observations:                   429                     Method:                             ML
# No. Groups:                         126                     Scale:                              0.6724
# Min. group size:                    1                       Log-Likelihood:                     -665.9756
# Max. group size:                    5                       Converged:                          No
# Mean group size:                    3.4
# -----------------------------------------------------------------------------------------------------------------------------
#                                                                            Coef.         Std.Err.   z    P>|z|  [0.025 0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# Intercept                                                                        -11.912    7.930 -1.502 0.133 -27.454  3.630
# C(Countries)[T.Belgium]                                                            4.496
# C(Countries)[T.Brazil]                                                             7.985    1.795  4.449 0.000   4.467 11.503
# C(Countries)[T.Canada]                                                             6.942    2.068  3.357 0.001   2.888 10.995
# C(Countries)[T.China]                                                              2.095    1.406  1.490 0.136  -0.661  4.850
# C(Countries)[T.Denmark]                                             -610063340744519.250
# C(Countries)[T.Finland]                                                            7.777    2.460  3.161 0.002   2.955 12.599
# C(Countries)[T.France]                                                             7.081    1.797  3.939 0.000   3.558 10.604
# C(Countries)[T.Germany]                                                           11.933    2.434  4.903 0.000   7.162 16.703
# C(Countries)[T.Ireland]                                                           -1.291    1.377 -0.938 0.348  -3.990  1.408
# C(Countries)[T.Italy]                                                              7.598    2.293  3.314 0.001   3.104 12.092
# C(Countries)[T.Japan]                                                              5.416    1.612  3.361 0.001   2.257  8.574
# C(Countries)[T.Mexico]                                                            10.260    2.803  3.661 0.000   4.767 15.753
# C(Countries)[T.Norway]                                                             1.494    2.344  0.637 0.524  -3.102  6.089
# C(Countries)[T.Portugal]                                                           8.913    3.020  2.951 0.003   2.994 14.832
# C(Countries)[T.South Africa]                                                       9.017    2.566  3.514 0.000   3.988 14.047
# C(Countries)[T.South Korea]                                                        5.857    1.053  5.562 0.000   3.793  7.921
# C(Countries)[T.Spain]                                                              6.151    3.103  1.983 0.047   0.070 12.232
# C(Countries)[T.Switzerland]                                                        2.686    2.669  1.007 0.314  -2.545  7.917
# C(Countries)[T.Thailand]                                                           6.656    1.367  4.870 0.000   3.977  9.334
# C(Countries)[T.USA]                                                                5.559    1.431  3.885 0.000   2.755  8.363
# C(Countries)[T.United Kingdom]                                                     4.751    1.919  2.476 0.013   0.990  8.513
# C(Primary_activity)[T.Agriculture, construction & mining machinery]               -1.638    2.186 -0.749 0.454  -5.922  2.647
# C(Primary_activity)[T.Alcoholic beverages]                           610063340744515.750
# C(Primary_activity)[T.Animal processing]                                          -1.247    2.193 -0.569 0.570  -5.546  3.052
# C(Primary_activity)[T.Aquaculture]                                                 0.046    2.472  0.019 0.985  -4.799  4.891
# C(Primary_activity)[T.Automobiles]                                                -5.382    2.195 -2.452 0.014  -9.685 -1.079
# C(Primary_activity)[T.Building sub-contractors]                                   -2.611    2.577 -1.013 0.311  -7.661  2.439
# C(Primary_activity)[T.CCGT generation]                                            -5.110    2.573 -1.986 0.047 -10.153 -0.067
# C(Primary_activity)[T.Cement]                                                     -9.475    3.014 -3.143 0.002 -15.383 -3.567
# C(Primary_activity)[T.Communications equipment]                                   -3.098    2.358 -1.314 0.189  -7.720  1.523
# C(Primary_activity)[T.Computer hardware]                                          -0.361    2.213 -0.163 0.870  -4.698  3.975
# C(Primary_activity)[T.Dealers, wholesalers & distributors]                        -1.536    2.487 -0.618 0.537  -6.409  3.338
# C(Primary_activity)[T.Electrical equipment]                                       -5.677    2.010 -2.824 0.005  -9.617 -1.737
# C(Primary_activity)[T.Electronic components]                                      -4.920    1.919 -2.564 0.010  -8.680 -1.159
# C(Primary_activity)[T.Electronic equipment]                                       -4.295    2.041 -2.104 0.035  -8.296 -0.294
# C(Primary_activity)[T.Engines & motors]                                           -2.360    2.121 -1.113 0.266  -6.517  1.797
# C(Primary_activity)[T.Fabricated metal components]                               -14.353    2.988 -4.804 0.000 -20.209 -8.497
# C(Primary_activity)[T.Finished wood products]                                      5.056    3.110  1.626 0.104  -1.040 11.151
# C(Primary_activity)[T.Food & beverage amenities]                                  -5.715    2.384 -2.397 0.017 -10.388 -1.043
# C(Primary_activity)[T.Furniture]                                                  -0.191    2.487 -0.077 0.939  -5.065  4.683
# C(Primary_activity)[T.Gas utilities]                                              -4.143    2.135 -1.941 0.052  -8.328  0.041
# C(Primary_activity)[T.Glass products]                                             -3.058    2.031 -1.506 0.132  -7.039  0.922
# C(Primary_activity)[T.Grain & corn milling]                                       -0.118    2.372 -0.050 0.960  -4.768  4.532
# C(Primary_activity)[T.Health care supplies]                                       -4.826    2.296 -2.102 0.036  -9.326 -0.325
# C(Primary_activity)[T.Hotels & lodging]                                           -7.713    3.017 -2.556 0.011 -13.627 -1.799
# C(Primary_activity)[T.Iron & steel]                                               -7.198    2.656 -2.710 0.007 -12.403 -1.992
# C(Primary_activity)[T.Logging]                                                    -3.158    2.447 -1.290 0.197  -7.954  1.639
# C(Primary_activity)[T.Logistics - 3rd party]                                      -5.915    2.630 -2.249 0.024 -11.069 -0.761
# C(Primary_activity)[T.Medical equipment]                                          -3.248    2.475 -1.312 0.189  -8.099  1.603
# C(Primary_activity)[T.Metal containers & packaging]                               -3.414    2.058 -1.658 0.097  -7.448  0.621
# C(Primary_activity)[T.Non-CCGT generation]                                        -5.227    2.424 -2.156 0.031  -9.977 -0.476
# C(Primary_activity)[T.Non-alcoholic beverages]                                    -1.329    1.993 -0.667 0.505  -5.235  2.577
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                                -7.256    2.248 -3.228 0.001 -11.662 -2.850
# C(Primary_activity)[T.Non-residential building construction]                      -8.089    2.621 -3.086 0.002 -13.226 -2.952
# C(Primary_activity)[T.Oil & gas extraction]                                       -0.828    1.866 -0.444 0.657  -4.485  2.830
# C(Primary_activity)[T.Other base chemicals]                                       -3.157    1.933 -1.634 0.102  -6.946  0.631
# C(Primary_activity)[T.Other containers & packaging]                               -1.697    2.450 -0.692 0.489  -6.500  3.106
# C(Primary_activity)[T.Other food processing]                                      -3.349    1.908 -1.755 0.079  -7.089  0.390
# C(Primary_activity)[T.Other non-ferrous ore mining]                               -4.072    2.369 -1.719 0.086  -8.716  0.571
# C(Primary_activity)[T.Other professional services]                                -6.270    2.235 -2.805 0.005 -10.651 -1.889
# C(Primary_activity)[T.Paper products]                                             -3.043    1.891 -1.609 0.108  -6.748  0.663
# C(Primary_activity)[T.Personal care & household products]                         -1.866    2.158 -0.865 0.387  -6.096  2.363
# C(Primary_activity)[T.Pharmaceuticals]                                            -5.243    2.059 -2.547 0.011  -9.278 -1.208
# C(Primary_activity)[T.Plastic products]                                           -1.037    2.320 -0.447 0.655  -5.583  3.510
# C(Primary_activity)[T.Precious metals & minerals mining]                          -5.479    2.057 -2.664 0.008  -9.510 -1.448
# C(Primary_activity)[T.Pulp & paper mills]                                         -4.150    2.118 -1.959 0.050  -8.302  0.001
# C(Primary_activity)[T.Residential building construction]                          -3.607    2.396 -1.505 0.132  -8.304  1.089
# C(Primary_activity)[T.Rubber products]                                            -3.808    2.157 -1.766 0.077  -8.035  0.419
# C(Primary_activity)[T.Specialty chemicals]                                        -0.112    1.884 -0.059 0.953  -3.804  3.580
# C(Primary_activity)[T.Supermarkets, food & drugstores]                            -6.679    2.275 -2.935 0.003 -11.139 -2.220
# C(Primary_activity)[T.Telecommunications services]                                -6.002    2.637 -2.276 0.023 -11.170 -0.834
# C(Primary_activity)[T.Textiles]                                                    1.476    2.277  0.648 0.517  -2.988  5.940
# C(Primary_activity)[T.Tobacco products]                                           -7.437    2.401 -3.098 0.002 -12.143 -2.732
# C(Primary_activity)[T.Water supply networks]                                      -2.136    2.919 -0.732 0.464  -7.857  3.585
# C(Primary_activity)[T.Wood furniture]                                             -1.248    2.432 -0.513 0.608  -6.016  3.520
# slog_Market_Cap_USD                                                               -0.022    0.112 -0.199 0.843  -0.241  0.197
# slog_Revenue_USD                                                                   0.717    0.319  2.250 0.024   0.093  1.341
# slog_shortTermInvestments_USD                                                     -0.006    0.007 -0.894 0.371  -0.019  0.007
# slog_totalAssets_USD                                                              -0.031    0.323 -0.096 0.923  -0.665  0.603
# slog_totalInvestments_USD                                                          0.004    0.014  0.290 0.772  -0.024  0.032
# slog_totalEquity_USD                                                              -0.017    0.012 -1.380 0.168  -0.040  0.007
# slog_scope_1_2_emissions_amount                                                    0.574    0.147  3.891 0.000   0.285  0.863
# Year                                                                              -0.001    0.016 -0.051 0.959  -0.032  0.031
# Group Var                                                                          1.985    0.381
# =============================================================================================================================
#
#
# Full Mixed-Effects Model (Full Model) Test Set Performance Metrics:
# R²(log):    67.70%
# R²(orig):   40.07%
# MAPE:       2513.27%
# MAPE(log):  23.25%
# MAE(log):   1.23
# RMSLE:      1.80
# RMSE:       1882661.27
# MAE:        485952.65
#
# Top Influential Features (by p-value):
#                                                          coef        pvalue
# Group Var                                            2.952134  2.097822e-10
# C(Countries)[T.South Korea]                          5.856935  2.661507e-08
# C(Countries)[T.Germany]                             11.932781  9.449470e-07
# C(Countries)[T.Thailand]                             6.655578  1.117369e-06
# C(Primary_activity)[T.Fabricated metal components] -14.352869  1.555046e-06
# C(Countries)[T.Brazil]                               7.984933  8.646435e-06
# C(Countries)[T.France]                               7.081009  8.169053e-05
# slog_scope_1_2_emissions_amount                      0.573707  9.964988e-05
# C(Countries)[T.USA]                                  5.558918  1.022659e-04
# C(Countries)[T.Mexico]                              10.260119  2.512499e-04
# /Users/amberjensen/anaconda3/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2704: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))

# %% [markdown]
# ## Processing of Sold Products Optimized Mixed-Effects Model
#
# An optimized mixed-effects model is used to predict company Scope 3 emissions. The model provides accurate prediction using only the most significant predictive features, while still accounting for primary activity, country and company level effects. The model is trained on data from 2018–2022 and evaluated on test data from 2023.
#
# Model Structure:
#
# - Random Effects:
#     - Random intercept for each company ('account_id'), capturing company-level baseline differences
# - Fixed Effects:
#     - Signed log-transformed features:
#         - Revenue ('slog_Revenue_USD')
#         - Scope 1 & 2 Emissions ('slog_scope_1_2_emissions_amount')
#     - Country ('Countries', as a categorical variable)
#     - Primary Activity ('Primary_activity', as a categorical variable)

# %%
feature_cols_slog = [
    'slog_Revenue_USD',
    'slog_scope_1_2_emissions_amount'
]
target_col_slog = 'slog_Scope_3_emissions_amount'

# --- Filter for required columns only ---
all_model_vars = feature_cols_slog + [target_col_slog, 'Countries', 'Year', 'account_id', 'Primary_activity']
train_df_opt = train_df.dropna(subset=all_model_vars).copy()
test_df_opt = test_df.dropna(subset=all_model_vars).copy()

if test_df_opt.empty:
    print("WARNING: The filtered test set is empty. No predictions or metrics can be computed.")
else:
    # --- Model formula ---
    fixed_effects = (
        ' + '.join(feature_cols_slog) +
        ' + C(Countries) + C(Primary_activity)'
    )
    formula = f'{target_col_slog} ~ {fixed_effects}'

    # --- Fit the optimized mixed-effects model ---
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        md = smf.mixedlm(formula, data=train_df_opt, groups=train_df_opt['account_id'])
        mdf_optimized = md.fit(reml=False)
    print(mdf_optimized.summary())

    # --- Predict on test set ---
    test_df_opt['predicted_log'] = mdf_optimized.predict(test_df_opt)
    test_df_opt['predicted'] = np.sign(test_df_opt['predicted_log']) * (np.expm1(np.abs(test_df_opt['predicted_log'])))

    # --- Metrics ---
    y_true_log = test_df_opt[target_col_slog]
    y_pred_log = test_df_opt['predicted_log']
    y_true = np.sign(y_true_log) * (np.expm1(np.abs(y_true_log)))
    y_pred = test_df_opt['predicted']

    # Mask for valid/finites
    mask = (
        np.isfinite(y_true_log) & np.isfinite(y_pred_log) &
        np.isfinite(y_true) & np.isfinite(y_pred)
    )
    y_true_log = y_true_log[mask]
    y_pred_log = y_pred_log[mask]
    y_true = y_true[mask]
    y_pred = y_pred[mask]

    # Metrics calculations
    r2_log_pct = r2_score(y_true_log, y_pred_log) * 100
    r2_pct = r2_score(y_true, y_pred) * 100
    mape_log = np.mean(np.abs((y_true_log - y_pred_log) / np.clip(y_true_log, 1e-8, None))) * 100
    mape_orig = np.mean(np.abs((y_true - y_pred) / np.clip(y_true, 1e-8, None))) * 100
    rmsle = np.sqrt(mean_squared_log_error(np.abs(y_true) + 1, np.abs(y_pred) + 1))
    rmse_orig = np.sqrt(mean_squared_error(y_true, y_pred))
    mae_orig = mean_absolute_error(y_true, y_pred)
    mae_log = mean_absolute_error(y_true_log, y_pred_log)  # <-- MAE for log-transformed emissions

    metrics_text = (
        f"R²(log):    {r2_log_pct:.2f}%\n"
        f"R²(orig):   {r2_pct:.2f}%\n"
        f"MAPE:       {mape_orig:.2f}%\n"
        f"MAPE(log):  {mape_log:.2f}%\n"
        f"MAE(log):   {mae_log:.2f}\n"
        f"RMSLE:      {rmsle:.2f}\n"
        f"RMSE:       {rmse_orig:.2f}\n"
        f"MAE:        {mae_orig:.2f}"
    )

    print("\nOptimized Mixed-Effects Model: Test Set Performance Metrics:")
    print(metrics_text)

    # --- Feature coefficients ---
    coef_df = pd.DataFrame({
        'coef': mdf_optimized.params,
        'pvalue': mdf_optimized.pvalues
    }).drop(index="Intercept", errors='ignore').sort_values(by="pvalue")
    print("\nTop Influential Features (by p-value):")
    print(coef_df.head(10))

    print("\nAll feature coefficients sorted by absolute value:")
    print(coef_df.reindex(coef_df['coef'].abs().sort_values(ascending=False).index))

    # --- VISUALIZATION ---
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))

    # 1. Density plot on log scale
    if y_pred_log.nunique() > 1:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[0], color='darkorange')
    else:
        sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=axes[0], color='steelblue')
        axes[0].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[0].set_title("Optimized Model: signed log(Scope 3 Emissions)")
    axes[0].set_xlabel("signed log(metric tons + 1)")
    axes[0].set_ylabel("Density")
    axes[0].legend()

    axes[0].text(1.05, 0.95, metrics_text, transform=axes[0].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    # 2. Density plot on original scale
    if y_pred.nunique() > 1:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        sns.kdeplot(y_pred, label='Optimized Model Predicted', linewidth=2, fill=True, ax=axes[1], color='darkorange')
    else:
        sns.kdeplot(y_true, label='Reported', linewidth=2, fill=True, ax=axes[1], color='steelblue')
        axes[1].plot([], [], ' ', label="Predicted: constant value (no KDE)")
    axes[1].set_title("Optimized Model: Scope 3 Emissions (Original Scale)")
    axes[1].set_xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    axes[1].set_ylabel("Density")
    axes[1].legend()

    axes[1].text(1.05, 0.95, metrics_text, transform=axes[1].transAxes,
                 verticalalignment='top', fontsize=12, bbox=dict(boxstyle='round', alpha=0.15))

    plt.tight_layout()
    plt.show()

    # Histogram on original scale with log x-axis
    min_val = min(y_true.min(), y_pred.min())
    max_val = max(y_true.max(), y_pred.max())
    log_bins = np.logspace(np.log10(min_val + 1), np.log10(max_val + 1), 100)

    plt.figure(figsize=(8, 5))
    sns.histplot(y_true, bins=log_bins, stat="density", color="steelblue", alpha=0.5, label="Reported")
    sns.histplot(y_pred, bins=log_bins, stat="density", color="darkorange", alpha=0.5, label="Optimized Model Predicted")
    plt.xscale("log")
    plt.title("Optimized Model: Scope 3 Emissions (MT CO₂e): Histogram (log x-axis)")
    plt.xlabel("Scope 3 Emissions (Metric Tons CO₂e)")
    plt.ylabel("Density")
    plt.legend()
    plt.tight_layout()
    plt.show()

    # --- RETURN METRICS FOR SUMMARY TABLE ---
    optimized_model_metrics = {
        "Model": "Optimized",
        "R2_log": r2_log_pct / 100,
        "R2_orig": r2_pct / 100,
        "RMSE": rmse_orig,
        "MAE": mae_orig,
        "RMSLE": rmsle,
        "MAPE": mape_orig,
        "MAE_log": mae_log
    }
# Out:
#                                      Mixed Linear Model Regression Results
# ================================================================================================================
# Model:                         MixedLM             Dependent Variable:             slog_Scope_3_emissions_amount
# No. Observations:              429                 Method:                         ML
# No. Groups:                    126                 Scale:                          0.6449
# Min. group size:               1                   Log-Likelihood:                 -666.0799
# Max. group size:               5                   Converged:                      Yes
# Mean group size:               3.4
# ----------------------------------------------------------------------------------------------------------------
#                                                                      Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# ----------------------------------------------------------------------------------------------------------------
# Intercept                                                           -12.462
# C(Countries)[T.Belgium]                                               4.829    1.889  2.557 0.011   1.127  8.531
# C(Countries)[T.Brazil]                                                8.204    2.541  3.228 0.001   3.223 13.185
# C(Countries)[T.Canada]                                                7.064    2.185  3.233 0.001   2.781 11.346
# C(Countries)[T.China]                                                 2.242    2.379  0.943 0.346  -2.420  6.904
# C(Countries)[T.Denmark]                                              -3.325
# C(Countries)[T.Finland]                                               7.955    1.995  3.986 0.000   4.044 11.866
# C(Countries)[T.France]                                                7.223    2.634  2.742 0.006   2.059 12.386
# C(Countries)[T.Germany]                                              11.835    2.367  4.999 0.000   7.195 16.475
# C(Countries)[T.Ireland]                                              -1.006    3.114 -0.323 0.747  -7.108  5.097
# C(Countries)[T.Italy]                                                 7.560    2.631  2.874 0.004   2.404 12.716
# C(Countries)[T.Japan]                                                 5.579    1.844  3.026 0.002   1.965  9.193
# C(Countries)[T.Mexico]                                               10.364    2.629  3.942 0.000   5.211 15.516
# C(Countries)[T.Norway]                                                1.662    1.998  0.832 0.406  -2.254  5.577
# C(Countries)[T.Portugal]                                              8.934    1.977  4.520 0.000   5.060 12.809
# C(Countries)[T.South Africa]                                          9.195    2.110  4.357 0.000   5.059 13.331
# C(Countries)[T.South Korea]                                           5.951    2.103  2.830 0.005   1.830 10.072
# C(Countries)[T.Spain]                                                 6.138    2.318  2.648 0.008   1.594 10.681
# C(Countries)[T.Switzerland]                                           2.983    3.148  0.948 0.343  -3.186  9.153
# C(Countries)[T.Thailand]                                              6.792    2.309  2.942 0.003   2.266 11.317
# C(Countries)[T.USA]                                                   5.690    1.954  2.912 0.004   1.860  9.521
# C(Countries)[T.United Kingdom]                                        4.906    1.979  2.479 0.013   1.028  8.784
# C(Primary_activity)[T.Agriculture, construction & mining machinery]  -1.651    2.846 -0.580 0.562  -7.228  3.926
# C(Primary_activity)[T.Alcoholic beverages]                           -0.051
# C(Primary_activity)[T.Animal processing]                             -1.296    1.957 -0.662 0.508  -5.132  2.540
# C(Primary_activity)[T.Aquaculture]                                   -0.005    1.651 -0.003 0.997  -3.241  3.230
# C(Primary_activity)[T.Automobiles]                                   -5.268    2.589 -2.035 0.042 -10.342 -0.194
# C(Primary_activity)[T.Building sub-contractors]                      -2.410    2.373 -1.016 0.310  -7.061  2.240
# C(Primary_activity)[T.CCGT generation]                               -5.221    1.799 -2.903 0.004  -8.747 -1.696
# C(Primary_activity)[T.Cement]                                        -9.451    3.794 -2.491 0.013 -16.886 -2.016
# C(Primary_activity)[T.Communications equipment]                      -2.994    1.882 -1.591 0.112  -6.682  0.694
# C(Primary_activity)[T.Computer hardware]                             -0.502
# C(Primary_activity)[T.Dealers, wholesalers & distributors]           -1.488    2.586 -0.575 0.565  -6.556  3.580
# C(Primary_activity)[T.Electrical equipment]                          -5.731    2.182 -2.626 0.009 -10.009 -1.454
# C(Primary_activity)[T.Electronic components]                         -4.880    1.818 -2.685 0.007  -8.442 -1.318
# C(Primary_activity)[T.Electronic equipment]                          -4.283    2.519 -1.700 0.089  -9.221  0.655
# C(Primary_activity)[T.Engines & motors]                              -2.303    2.081 -1.106 0.269  -6.382  1.777
# C(Primary_activity)[T.Fabricated metal components]                  -14.445    2.554 -5.656 0.000 -19.451 -9.440
# C(Primary_activity)[T.Finished wood products]                         5.210    2.667  1.953 0.051  -0.018 10.437
# C(Primary_activity)[T.Food & beverage amenities]                     -5.099    2.487 -2.050 0.040  -9.973 -0.225
# C(Primary_activity)[T.Furniture]                                     -0.305    1.792 -0.170 0.865  -3.817  3.208
# C(Primary_activity)[T.Gas utilities]                                 -4.002    2.563 -1.562 0.118  -9.024  1.021
# C(Primary_activity)[T.Glass products]                                -3.100    1.802 -1.720 0.085  -6.631  0.432
# C(Primary_activity)[T.Grain & corn milling]                          -0.168    1.641 -0.102 0.919  -3.385  3.049
# C(Primary_activity)[T.Health care supplies]                          -4.784    1.989 -2.406 0.016  -8.681 -0.886
# C(Primary_activity)[T.Hotels & lodging]                              -7.218
# C(Primary_activity)[T.Iron & steel]                                  -7.266    3.397 -2.139 0.032 -13.924 -0.608
# C(Primary_activity)[T.Logging]                                       -3.172    2.584 -1.228 0.220  -8.237  1.892
# C(Primary_activity)[T.Logistics - 3rd party]                         -5.859    2.460 -2.382 0.017 -10.680 -1.037
# C(Primary_activity)[T.Medical equipment]                             -3.472    1.263 -2.749 0.006  -5.948 -0.996
# C(Primary_activity)[T.Metal containers & packaging]                  -3.318    1.748 -1.898 0.058  -6.744  0.109
# C(Primary_activity)[T.Non-CCGT generation]                           -5.078    2.522 -2.013 0.044 -10.021 -0.134
# C(Primary_activity)[T.Non-alcoholic beverages]                       -1.407    1.719 -0.818 0.413  -4.777  1.963
# C(Primary_activity)[T.Non-nitrogenous fertilizers]                   -7.220    1.817 -3.973 0.000 -10.781 -3.658
# C(Primary_activity)[T.Non-residential building construction]         -7.998    3.092 -2.586 0.010 -14.059 -1.937
# C(Primary_activity)[T.Oil & gas extraction]                          -0.974
# C(Primary_activity)[T.Other base chemicals]                          -3.198    1.027 -3.114 0.002  -5.211 -1.186
# C(Primary_activity)[T.Other containers & packaging]                  -1.763    2.708 -0.651 0.515  -7.071  3.544
# C(Primary_activity)[T.Other food processing]                         -3.348    1.729 -1.936 0.053  -6.737  0.041
# C(Primary_activity)[T.Other non-ferrous ore mining]                  -3.905    2.555 -1.528 0.127  -8.913  1.104
# C(Primary_activity)[T.Other professional services]                   -6.169    2.912 -2.119 0.034 -11.876 -0.462
# C(Primary_activity)[T.Paper products]                                -3.010    1.878 -1.603 0.109  -6.691  0.671
# C(Primary_activity)[T.Personal care & household products]            -1.983    1.910 -1.039 0.299  -5.726  1.759
# C(Primary_activity)[T.Pharmaceuticals]                               -5.280    2.560 -2.062 0.039 -10.298 -0.262
# C(Primary_activity)[T.Plastic products]                              -0.753    1.187 -0.634 0.526  -3.079  1.573
# C(Primary_activity)[T.Precious metals & minerals mining]             -5.567    1.944 -2.864 0.004  -9.377 -1.758
# C(Primary_activity)[T.Pulp & paper mills]                            -4.130    2.931 -1.409 0.159  -9.875  1.614
# C(Primary_activity)[T.Residential building construction]             -3.462    2.485 -1.393 0.164  -8.333  1.408
# C(Primary_activity)[T.Rubber products]                               -3.871    1.476 -2.623 0.009  -6.763 -0.979
# C(Primary_activity)[T.Specialty chemicals]                           -0.177    0.976 -0.181 0.856  -2.089  1.736
# C(Primary_activity)[T.Supermarkets, food & drugstores]               -6.688    2.787 -2.399 0.016 -12.150 -1.225
# C(Primary_activity)[T.Telecommunications services]                   -6.085    1.162 -5.236 0.000  -8.363 -3.808
# C(Primary_activity)[T.Textiles]                                       1.229
# C(Primary_activity)[T.Tobacco products]                              -7.515    2.908 -2.584 0.010 -13.215 -1.816
# C(Primary_activity)[T.Water supply networks]                         -2.533
# C(Primary_activity)[T.Wood furniture]                                -1.166    1.166 -1.000 0.317  -3.451  1.119
# slog_Revenue_USD                                                      0.587    0.227  2.584 0.010   0.142  1.032
# slog_scope_1_2_emissions_amount                                       0.585    0.150  3.896 0.000   0.291  0.879
# Group Var                                                             2.241    0.450
# ================================================================================================================
#
#
# Optimized Mixed-Effects Model: Test Set Performance Metrics:
# R²(log):    67.05%
# R²(orig):   39.75%
# MAPE:       2763.51%
# MAPE(log):  23.66%
# MAE(log):   1.25
# RMSLE:      1.82
# RMSE:       1887665.82
# MAE:        479132.99
#
# Top Influential Features (by p-value):
#                                                          coef        pvalue
# Group Var                                            3.474469  5.740977e-10
# C(Primary_activity)[T.Fabricated metal components] -14.445059  1.548670e-08
# C(Primary_activity)[T.Telecommunications services]  -6.085398  1.636846e-07
# C(Countries)[T.Germany]                             11.834942  5.754461e-07
# C(Countries)[T.Portugal]                             8.934170  6.196692e-06
# C(Countries)[T.South Africa]                         9.195213  1.315661e-05
# C(Countries)[T.Finland]                              7.954883  6.707961e-05
# C(Primary_activity)[T.Non-nitrogenous fertilizers]  -7.219526  7.104210e-05
# C(Countries)[T.Mexico]                              10.363622  8.076914e-05
# slog_scope_1_2_emissions_amount                      0.584702  9.771565e-05
#
# All feature coefficients sorted by absolute value:
#                                                          coef        pvalue
# C(Primary_activity)[T.Fabricated metal components] -14.445059  1.548670e-08
# C(Countries)[T.Germany]                             11.834942  5.754461e-07
# C(Countries)[T.Mexico]                              10.363622  8.076914e-05
# C(Primary_activity)[T.Cement]                       -9.451161  1.272439e-02
# C(Countries)[T.South Africa]                         9.195213  1.315661e-05
# ...                                                       ...           ...
# C(Primary_activity)[T.Furniture]                    -0.304857  8.649240e-01
# C(Primary_activity)[T.Specialty chemicals]          -0.176632  8.563720e-01
# C(Primary_activity)[T.Grain & corn milling]         -0.167880  9.185267e-01
# C(Primary_activity)[T.Alcoholic beverages]          -0.051144           NaN
# C(Primary_activity)[T.Aquaculture]                  -0.005364  9.974072e-01
#
# [78 rows x 2 columns]
# /Users/amberjensen/anaconda3/lib/python3.11/site-packages/statsmodels/regression/mixed_linear_model.py:2704: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))

# %%
metrics_text_log = (
    f"R²(log):   {r2_log_pct:.2f}%\n"
    f"R²(orig):  {r2_pct:.2f}%\n"
    f"MAPE:      {mape_orig:.2f}%\n"
    f"MAPE(log): {mape_log:.2f}%\n"
    f"MAE(log):  {mae_log:.2f}\n"
    f"RMSLE:     {rmsle:.2f}\n"
    f"RMSE:      {rmse_orig:.2f}\n"
    f"MAE:       {mae_orig:.2f}"
)

fig, ax = plt.subplots(figsize=(9.5, 6))  # Wider to make room for the box

if hasattr(y_pred_log, "nunique"):
    multiple_vals = y_pred_log.nunique() > 1
else:
    multiple_vals = len(set(y_pred_log)) > 1

if multiple_vals:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    sns.kdeplot(y_pred_log, label='Optimized Model Predicted', linewidth=2, fill=True, ax=ax, color='darkorange')
else:
    sns.kdeplot(y_true_log, label='Reported', linewidth=2, fill=True, ax=ax, color='steelblue')
    ax.plot([], [], ' ', label="Predicted: constant value (no KDE)")

ax.set_title("Processing of Sold Products Optimized Model: signed log(Scope 3 Emissions)")
ax.set_xlabel("signed log(metric tons + 1)")
ax.set_ylabel("Density")
ax.legend()

# Place metrics box outside plot to the right
fig.text(
    0.82, 0.75, metrics_text_log,
    va='top', ha='left',
    fontsize=12, bbox=dict(boxstyle='round', alpha=0.15)
)

plt.subplots_adjust(right=0.8)  # Make sure there's room for the box
fig.savefig("processing_of_sold_products_scope3_log_density.png", dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Metrics Table for processing_of_sold_products

# %%
metrics_dicts = [
    null_model_metrics,
    two_level_model_metrics,
    three_level_model_metrics,
    full_model_metrics,
    optimized_model_metrics
]

for metrics, train, test in zip(
        metrics_dicts,
        [train_df, train_df, train_df, train_df, train_df],
        [test_df, test_df, test_df, test_df, test_df]):
    
    metrics["# Obs (train)"] = len(train)
    metrics["# Obs (test)"] = len(test)
    metrics["# Obs (train/test)"] = f"{len(train)}/{len(test)}"

metrics_df = pd.DataFrame(metrics_dicts)

# Ensure all relevant columns are ordered and present
desired_order = [
    "Model", "R2_log", "R2_orig", "RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "# Obs (train/test)"
]


# Ensure MAE_log is present, fill with NaN if missing
if "MAE_log" not in metrics_df.columns:
    metrics_df["MAE_log"] = np.nan

metrics_df = metrics_df[[col for col in desired_order if col in metrics_df.columns]]

metrics_df_display = metrics_df.copy()
if "R2_log" in metrics_df_display.columns:
    metrics_df_display["R2_log"] = (metrics_df_display["R2_log"] * 100).map("{:.2f}%".format)
if "R2_orig" in metrics_df_display.columns:
    metrics_df_display["R2_orig"] = (metrics_df_display["R2_orig"] * 100).map("{:.2f}%".format)
for col in ["RMSE", "MAE", "MAE_log", "RMSLE", "MAPE", "MAPE(log)"]:
    if col in metrics_df_display.columns:
        metrics_df_display[col] = metrics_df_display[col].map("{:.2f}".format)

from IPython.display import display
display(metrics_df_display)
# Out:
#                                      Model  R2_log R2_orig        RMSE  \
# 0                                Null (RI)  -0.02%  -9.77%  2547951.19
# 1                           2-level (RI+S)  -0.09%  -9.70%  2547207.70
# 2  3-level (Primary Activity/Account/Year)  26.86%  -5.42%  2496961.89
# 3                               Full Model  67.70%  40.07%  1882661.27
# 4                                Optimized  67.05%  39.75%  1887665.82
#
#          MAE MAE_log RMSLE       MAPE # Obs (train/test)
# 0  789958.71    2.41  3.17   96736.11             429/91
# 1  789629.13    2.40  3.17  101836.67             429/91
# 2  772827.84    2.02  2.71   36384.31             429/91
# 3  485952.65    1.23  1.80    2513.27             429/91
# 4  479132.99    1.25  1.82    2763.51             429/91
